# %% [markdown]
# # Create indicators and find signals
# This code is designed to calculate the features for model training.
#
# We will also bring in if the target price was hit within 8 weeks for ML training and validation.
#
# Each share has it's own trading pattern so we will train a different model for each share but use the same set of features, just the hyper paramenters will be tuned differenty.
#
# V5 build - Normalise vs rolling max 5 year window

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import tables
import os
import datetime as dt
from rf_modules import *

# %%
#Import the ftse list
path = r"C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices"
tick_ftse = pd.read_csv(path + r"\tick_ftse.csv")
tick_ftse = tick_ftse.iloc[:,1:]
for col in tick_ftse:
    tick_ftse.rename(columns={col:clean_col_name(col)},inplace=True)
tick_ftse.head()
# Out:
#   ticker         company    index
# 0    III         3I GRP.  FTSE100
# 1    ABF        A.B.FOOD  FTSE100
# 2    ADM     ADMIRAL GRP  FTSE100
# 3    AAL  ANGLO AMERICAN  FTSE100
# 4   ANTO     ANTOFAGASTA  FTSE100

# %%
#Import and combine prices files
df_prices_w = pd.read_hdf(path + r"\all_hist_prices_w.h5")
#Rename columns
for col in df_prices_w:
    df_prices_w.rename(columns={col:clean_col_name(col)},inplace=True)
#Drop unwanted columns
try:
    df_prices_w.drop(columns=["unnamed_0","index"],inplace=True)
except Exception as e:
    print(e)
#Reformat columns where neccessary
df_prices_w["date"] = df_prices_w["date"].astype("datetime64")
print(df_prices_w.shape)
print(df_prices_w.dtypes)
df_prices_w.head()
# Out:
# "['unnamed_0' 'index'] not found in axis"
# (260985, 13)
# ticker                 object
# date           datetime64[ns]
# high                  float64
# low                   float64
# volume                float64
# open                  float64
# close                 float64
# change                float64
# ema12                 float64
# ema26                 float64
# macd_line             float64
# signal_line           float64
# macd                  float64
# dtype: object
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Remove tickers with fewer than 34 entries as this is where the MACD can be calculated
print('START ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('START TICK COUNT -> {}'.format(tick_ftse.shape[0]))
for tick in tick_ftse.ticker:
    print(tick,' ->',df_prices_w[df_prices_w.ticker == tick].shape[0])
    if df_prices_w[df_prices_w.ticker == tick].shape[0] < 34:
        #Remove from dataframe
        print('\nTOO FEW RECORDS FOR {}'.format(tick))
        df_prices_w = df_prices_w.loc[df_prices_w.ticker != tick]
        print('\tNEW ROW COUNT -> {}'.format(df_prices_w.shape[0]))
        #Remove from tick_ftse
        tick_ftse = tick_ftse.loc[tick_ftse.ticker != tick]
        print('\tNEW TICK COUNT -> {}'.format(tick_ftse.shape[0]))
print('\nEND ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('END TICK COUNT -> {}'.format(tick_ftse.shape[0]))
# Out:
# START ROW COUNT -> 260985
# START TICK COUNT -> 351
# III  -> 613
# ABF  -> 1045
# ADM  -> 353
# AAL  -> 1008
# ANTO  -> 1045
# AHT  -> 1023
# AZN  -> 1045
# AUTO  -> 238
# AVV  -> 1045
# AV.  -> 0
#
# TOO FEW RECORDS FOR AV.
# 	NEW ROW COUNT -> 260985
# 	NEW TICK COUNT -> 350
# BA.  -> 0
#
# TOO FEW RECORDS FOR BA.
# 	NEW ROW COUNT -> 260985
# 	NEW TICK COUNT -> 349
# BARC  -> 1045
# BDEV  -> 1045
# BKG  -> 1045
# BHP  -> 524
# BP.  -> 0
#
# TOO FEW RECORDS FOR BP.
# 	NEW ROW COUNT -> 260985
# 	NEW TICK COUNT -> 348
# BATS  -> 1045
# BLND  -> 1045
# BT.A  -> 1536
# BNZL  -> 1042
# BRBY  -> 900
# CCL  -> 989
# CNA  -> 1045
# CCH  -> 336
# CPG  -> 1031
# CRH  -> 1031
# CRDA  -> 1037
# DCC  -> 1027
# DGE  -> 1045
# EVR  -> 414
# EXPN  -> 678
# FERG  -> 1046
# FLTR  -> 18
#
# TOO FEW RECORDS FOR FLTR
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 347
# FRES  -> 596
# GSK  -> 1045
# GLEN  -> 438
# HLMA  -> 1013
# HL.  -> 0
#
# TOO FEW RECORDS FOR HL.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 346
# HIK  -> 708
# HSX  -> 1012
# HSBA  -> 1256
# IMB  -> 1180
# INF  -> 1066
# IHG  -> 844
# ITRK  -> 884
# IAG  -> 856
# ITV  -> 1012
# JD.  -> 0
#
# TOO FEW RECORDS FOR JD.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 345
# JMAT  -> 1237
# JE.  -> 0
#
# TOO FEW RECORDS FOR JE.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 344
# KGF  -> 1256
# LAND  -> 1264
# LGEN  -> 1256
# LLOY  -> 1222
# LSE  -> 932
# MGGT  -> 1475
# MRO  -> 812
# MNDI  -> 614
# MRW  -> 1256
# NG.  -> 0
#
# TOO FEW RECORDS FOR NG.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 343
# NXT  -> 1523
# NMC  -> 373
# OCDO  -> 462
# PSON  -> 1273
# PSN  -> 1463
# PHNX  -> 495
# POLY  -> 396
# PRU  -> 1502
# RDSA  -> 257
# RDSB  -> 993
# RB.  -> 0
#
# TOO FEW RECORDS FOR RB.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 342
# REL  -> 1273
# RTO  -> 1241
# RMV  -> 690
# RIO  -> 1526
# RR.  -> 0
#
# TOO FEW RECORDS FOR RR.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 341
# RBS  -> 1256
# RSA  -> 1243
# SGE  -> 1251
# SBRY  -> 1256
# SDR  -> 1246
# SMT  -> 136
# SGRO  -> 1534
# SVT  -> 1241
# SN.  -> 0
#
# TOO FEW RECORDS FOR SN.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 340
# SMDS  -> 1424
# SMIN  -> 1486
# SKG  -> 637
# SPX  -> 1454
# SSE  -> 1273
# STJ  -> 1463
# STAN  -> 1527
# SLA  -> 672
# TW.  -> 0
#
# TOO FEW RECORDS FOR TW.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 339
# TSCO  -> 1256
# TUI  -> 251
# ULVR  -> 1026
# UU.  -> 0
#
# TOO FEW RECORDS FOR UU.
# 	NEW ROW COUNT -> 260967
# 	NEW TICK COUNT -> 338
# VOD  -> 1045
# WTB  -> 1045
# WPP  -> 682
# 3IN  -> 586
# FOUR  -> 1036
# ASL  -> 603
# AGK  -> 1045
# AAF  -> 14
#
# TOO FEW RECORDS FOR AAF
# 	NEW ROW COUNT -> 260953
# 	NEW TICK COUNT -> 337
# AJB  -> 44
# ATST  -> 614
# APAX  -> 216
# ASCL  -> 191
# ASHM  -> 678
# AGR  -> 827
# AML  -> 53
# AVST  -> 74
# AGT  -> 11
#
# TOO FEW RECORDS FOR AGT
# 	NEW ROW COUNT -> 260942
# 	NEW TICK COUNT -> 336
# BME  -> 278
# BAB  -> 1025
# BGFD  -> 606
# BAKK  -> 99
# BBY  -> 1045
# BGEO  -> 618
# BNKR  -> 614
# BAG  -> 1045
# BBA  -> 1045
# BBGI  -> 398
# BCA  -> 247
# BEZ  -> 161
# BWY  -> 1433
# BYG  -> 994
# BRSC  -> 274
# BCPT  -> 9
#
# TOO FEW RECORDS FOR BCPT
# 	NEW ROW COUNT -> 260933
# 	NEW TICK COUNT -> 335
# BGSC  -> 594
# BOY  -> 1247
# BVS  -> 1114
# BRW  -> 1124
# BVIC  -> 703
# CNE  -> 1400
# CLDN  -> 591
# CAPC  -> 472
# CPI  -> 1302
# CARD  -> 282
# CEY  -> 909
# CCFS  -> 106
# CINE  -> 631
# CTY  -> 595
# CKN  -> 1304
# CBG  -> 1239
# CLI  -> 1275
# COA  -> 1372
# COB  -> 1256
# CCC  -> 1097
# GLO  -> 100
# CTEC  -> 154
# CSP  -> 410
# CWK  -> 1112
# CRST  -> 328
# CYBG  -> 192
# DJAN  -> 1122
# DPH  -> 954
# DLN  -> 1193
# DPLM  -> 1479
# DLG  -> 346
# DC.  -> 0
#
# TOO FEW RECORDS FOR DC.
# 	NEW ROW COUNT -> 260933
# 	NEW TICK COUNT -> 334
# DOM  -> 1018
# DRX  -> 702
# DNLM  -> 658
# EZJ  -> 967
# EDIN  -> 585
# EIG  -> 660
# ECM  -> 1256
# ELM  -> 1534
# ENOG  -> 82
# ETO  -> 594
# EQN  -> 206
# ESNT  -> 729
# ERM  -> 1112
# FCIT  -> 586
# FDM  -> 277
# FXPO  -> 618
# FEV  -> 585
# FSV  -> 585
# FCSS  -> 465
# FIN  -> 21
#
# TOO FEW RECORDS FOR FIN
# 	NEW ROW COUNT -> 260912
# 	NEW TICK COUNT -> 333
# FGT  -> 585
# FGP  -> 1249
# FSJ  -> 1092
# FSFL  -> 282
# FUTR  -> 1040
# GFS  -> 828
# GFRD  -> 1462
# GAW  -> 1284
# GCP  -> 452
# DIGS  -> 305
# GSS  -> 594
# GNS  -> 936
# GOG  -> 1298
# GPOR  -> 1026
# GFTU  -> 896
# GRI  -> 1045
# UKW  -> 332
# GNC  -> 1031
# GNK  -> 1045
# GRG  -> 1045
# GVC  -> 736
# HMSO  -> 1044
# HVPE  -> 394
# HSTG  -> 208
# HAS  -> 1026
# HRI  -> 585
# HGT  -> 585
# HICL  -> 585
# HILS  -> 1025
# HFG  -> 627
# HOC  -> 656
# HSV  -> 1015
# HWDN  -> 1026
# HTG  -> 995
# IBST  -> 207
# IGG  -> 735
# IMI  -> 1026
# INCH  -> 1026
# ISAT  -> 728
# ICP  -> 1026
# IHP  -> 84
# INPP  -> 509
# INVP  -> 879
# IPO  -> 815
# IWG  -> 539
# JLG  -> 243
# JII  -> 594
# JAM  -> 585
# JMG  -> 585
# JFJ  -> 595
# JEO  -> 586
# JUP  -> 467
# KNOS  -> 222
# KAZ  -> 712
# LRE  -> 702
# LWDB  -> 382
# LMP  -> 510
# EMG  -> 1026
# MKS  -> 1026
# MSLH  -> 1026
# MARS  -> 778
# MCS  -> 103
# MDC  -> 190
# MRC  -> 568
# MERL  -> 290
# MCRO  -> 733
# MAB  -> 842
# MONY  -> 612
# MNKS  -> 586
# MGAM  -> 1463
# MYI  -> 585
# NEX  -> 1365
# NBLS  -> 412
# NETW  -> 26
#
# TOO FEW RECORDS FOR NETW
# 	NEW ROW COUNT -> 260886
# 	NEW TICK COUNT -> 332
# NRR  -> 464
# NESF  -> 276
# OSB  -> 279
# OXIG  -> 1459
# PAGE  -> 916
# PIN  -> 585
# PAG  -> 1480
# PAY  -> 766
# PNN  -> 1519
# PLI  -> 584
# PSH  -> 126
# PNL  -> 585
# PFC  -> 712
# PETS  -> 291
# PTEC  -> 687
# PLUS  -> 305
# PCT  -> 586
# PLP  -> 287
# PPH  -> 572
# PMO  -> 1457
# PHP  -> 1083
# PFG  -> 1026
# PRTC  -> 225
# PZC  -> 1011
# QQ.  -> 0
#
# TOO FEW RECORDS FOR QQ.
# 	NEW ROW COUNT -> 260886
# 	NEW TICK COUNT -> 331
# QLT  -> 67
# RNK  -> 1026
# RAT  -> 1019
# RDW  -> 1023
# TRIG  -> 295
# RSW  -> 1020
# RTN  -> 1026
# RHIM  -> 102
# RCP  -> 73
# RSE  -> 283
# ROR  -> 1026
# RMG  -> 294
# SBRE  -> 96
# SAFE  -> 462
# SNN  -> 236
# SVS  -> 1412
# SDP  -> 586
# SOI  -> 585
# SCIN  -> 586
# SNR  -> 1428
# SEQI  -> 230
# SRP  -> 1285
# SHB  -> 1152
# SHI  -> 1318
# SXX  -> 659
# SRE  -> 623
# SSON  -> 41
# SCT  -> 204
# SOPH  -> 224
# SXS  -> 1478
# SPT  -> 1255
# SPD  -> 639
# SSPG  -> 274
# SMP  -> 1423
# SGC  -> 1151
# SYNC  -> 335
# SYNT  -> 1453
# TALK  -> 479
# TATE  -> 1260
# TBCG  -> 165
# TEP  -> 983
# TMPL  -> 586
# TEM  -> 585
# TIFS  -> 102
# TCAP  -> 960
# TRY  -> 584
# TRN  -> 15
#
# TOO FEW RECORDS FOR TRN
# 	NEW ROW COUNT -> 260871
# 	NEW TICK COUNT -> 330
# TPK  -> 1026
# BBOX  -> 276
# TLW  -> 1018
# UDG  -> 1007
# UKCM  -> 586
# ULE  -> 1022
# UTG  -> 342
# VSVS  -> 1256
# VCT  -> 1185
# VEIL  -> 160
# VOF  -> 595
# VVO  -> 75
# WOSG  -> 18
#
# TOO FEW RECORDS FOR WOSG
# 	NEW ROW COUNT -> 260853
# 	NEW TICK COUNT -> 329
# WEIR  -> 1468
# JDW  -> 1342
# SMWH  -> 668
# WMH  -> 884
# WTAN  -> 594
# WIZZ  -> 241
# WG.  -> 0
#
# TOO FEW RECORDS FOR WG.
# 	NEW ROW COUNT -> 260853
# 	NEW TICK COUNT -> 328
# WKP  -> 946
# WWH  -> 595
#
# END ROW COUNT -> 260853
# END TICK COUNT -> 328

# %%
#Function for calculating ema
def calc_ema(_s_in,_periods):
    #Calc mod val
    _mod = 2/(_periods+1)
    #Calc sma
    _sma_s = [0] * _s_in.shape[0]
    for _i in range(0,_periods):
        _sma_s += _s_in.shift(_i) / _periods
    #Calc ema
    _ema_s = _sma_s.copy()
    _ema_s[(_ema_s > 0) & (np.isnan(_ema_s) == False)] = _mod*(_s_in - _ema_s.shift(1)) + _ema_s.shift(1)
    return _ema_s.copy()

# %%
#Function for calculating the MACD
def calc_macd(_ema_lng_s,_ema_sht_s,_sig_period:int):
    #Make a df
    _tmp_df = pd.DataFrame([])
    _tmp_df['ema_lng'] = _ema_lng_s
    _tmp_df['ema_sht'] = _ema_sht_s
    #Calc the signal line
    _tmp_df['macd_line'] = _tmp_df['ema_sht'] - _tmp_df['ema_lng']
    _tmp_df['signal_line'] = calc_ema(_tmp_df['macd_line'],_sig_period)
    _tmp_df['macd_hist'] = _tmp_df['macd_line'] - _tmp_df['signal_line']
    return (_tmp_df['macd_line'].copy(),_tmp_df['signal_line'].copy(),_tmp_df['macd_hist'].copy())

# %%
#Calc the ema and macds for the data
def calc_ema_macd(_df_in):
    _tick_df = _df_in.copy()
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
#         _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal_line'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return _tick_df

# %%
#Create a function which normalises a feature based only on the values which have come before it - avoids time series bias
def norm_time_s(_ind,_s_in,_window):
    _this_ind = _ind - _s_in.index.min()
    if _this_ind < _window:
        _min_ind = 0
    else:
        _min_ind = _this_ind - _window
    _min = np.nanmin(_s_in[_min_ind:_this_ind+1].values)
    _max = np.nanmax(_s_in[_min_ind:_this_ind+1].values)
    _norm_val = (_s_in[_ind] - _min) / (_max - _min)
    return _norm_val

# %%
#Runt he functions
def norm_prices(_df_in):
    _df_out = _df_in.copy()
    #Normalise the columns which need it
    _norm_cols = [
        #Standard features
        "open"
        ,"close"
        ,"high"
        ,"low"
        ,"volume"
    ]
    #Reset the index
    _df_out.sort_values(['date'],ascending=True,inplace=True)
    #Calc the 5yr window
    _5yr = 5*52
    #Normalise
    for _col in _norm_cols:
        _tmp_s = _df_out[_col].copy() #Take a copy so as the values are changed this does not affect following calculations
        _df_out[_col] = [norm_time_s(_x,_tmp_s,_5yr) for _x in _df_out.index]
    return _df_out

# %%
df_prices_w[df_prices_w.ticker == 'III'].head()
# Out:
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Normalize the prices by ticker and time then create emas and macds for each ticker
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print('NORALISING AND CALCULATING EMA & MACD VALUES')
count = 0
error_li = []
run_time = process_time()
run_time.lap()
for tick in tick_ftse.ticker:
    count += 1
    print('\nRUN FOR {} - {}'.format(tick,count))
    try:
        this_tick_df = df_prices_w[df_prices_w.ticker == tick]
        this_tick_df = norm_prices(this_tick_df.copy())
        #Calculate the ema and macd
        this_tick_df = calc_ema_macd(this_tick_df)
        #Append back on to the dataframe
#         df_prices_w[df_prices_w.ticker == tick] = this_tick_df.copy()
        print('\tSUCCESS')
        run_time.lap()
        run_time.show_latest_lap_time()
    except Exception as e:
        print('\tERROR -> {}'.format(e))
        error_li.append(e)
run_time.end()
print('\n\nCOMPLETED - ERRORS ENCOUNTERED -> {}'.format(len(error_li)))
if len(error_li) > 0:
    print(error_li)
# Out:
# NORALISING AND CALCULATING EMA & MACD VALUES
#
# RUN FOR III - 1
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# 	SUCCESS
# LAP 2 TIME -> 0:0:1
#
# RUN FOR ABF - 2
# 	SUCCESS
# LAP 3 TIME -> 0:0:2
#
# RUN FOR ADM - 3
# 	SUCCESS
# LAP 4 TIME -> 0:0:0
#
# RUN FOR AAL - 4
# 	SUCCESS
# LAP 5 TIME -> 0:0:2
#
# RUN FOR ANTO - 5
# 	SUCCESS
# LAP 6 TIME -> 0:0:2
#
# RUN FOR AHT - 6
# 	SUCCESS
# LAP 7 TIME -> 0:0:2
#
# RUN FOR AZN - 7
# 	SUCCESS
# LAP 8 TIME -> 0:0:2
#
# RUN FOR AUTO - 8
# 	SUCCESS
# LAP 9 TIME -> 0:0:0
#
# RUN FOR AVV - 9
# 	SUCCESS
# LAP 10 TIME -> 0:0:2
#
# RUN FOR BARC - 10
# 	SUCCESS
# LAP 11 TIME -> 0:0:2
#
# RUN FOR BDEV - 11
# 	SUCCESS
# LAP 12 TIME -> 0:0:2
#
# RUN FOR BKG - 12
# 	SUCCESS
# LAP 13 TIME -> 0:0:2
#
# RUN FOR BHP - 13
# 	SUCCESS
# LAP 14 TIME -> 0:0:1
#
# RUN FOR BATS - 14
# 	SUCCESS
# LAP 15 TIME -> 0:0:2
#
# RUN FOR BLND - 15
# 	SUCCESS
# LAP 16 TIME -> 0:0:2
#
# RUN FOR BT.A - 16
# 	SUCCESS
# LAP 17 TIME -> 0:0:3
#
# RUN FOR BNZL - 17
# 	SUCCESS
# LAP 18 TIME -> 0:0:2
#
# RUN FOR BRBY - 18
# 	SUCCESS
# LAP 19 TIME -> 0:0:2
#
# RUN FOR CCL - 19
# 	SUCCESS
# LAP 20 TIME -> 0:0:2
#
# RUN FOR CNA - 20
# 	SUCCESS
# LAP 21 TIME -> 0:0:2
#
# RUN FOR CCH - 21
# 	SUCCESS
# LAP 22 TIME -> 0:0:0
#
# RUN FOR CPG - 22
# 	SUCCESS
# LAP 23 TIME -> 0:0:2
#
# RUN FOR CRH - 23
# 	SUCCESS
# LAP 24 TIME -> 0:0:2
#
# RUN FOR CRDA - 24
# 	SUCCESS
# LAP 25 TIME -> 0:0:2
#
# RUN FOR DCC - 25
# 	SUCCESS
# LAP 26 TIME -> 0:0:2
#
# RUN FOR DGE - 26
# 	SUCCESS
# LAP 27 TIME -> 0:0:2
#
# RUN FOR EVR - 27
# 	SUCCESS
# LAP 28 TIME -> 0:0:1
#
# RUN FOR EXPN - 28
# 	SUCCESS
# LAP 29 TIME -> 0:0:1
#
# RUN FOR FERG - 29
# 	SUCCESS
# LAP 30 TIME -> 0:0:2
#
# RUN FOR FRES - 30
# 	SUCCESS
# LAP 31 TIME -> 0:0:1
#
# RUN FOR GSK - 31
# 	SUCCESS
# LAP 32 TIME -> 0:0:2
#
# RUN FOR GLEN - 32
# 	SUCCESS
# LAP 33 TIME -> 0:0:1
#
# RUN FOR HLMA - 33
# 	SUCCESS
# LAP 34 TIME -> 0:0:2
#
# RUN FOR HIK - 34
# 	SUCCESS
# LAP 35 TIME -> 0:0:1
#
# RUN FOR HSX - 35
# 	SUCCESS
# LAP 36 TIME -> 0:0:2
#
# RUN FOR HSBA - 36
# 	SUCCESS
# LAP 37 TIME -> 0:0:3
#
# RUN FOR IMB - 37
# 	SUCCESS
# LAP 38 TIME -> 0:0:2
#
# RUN FOR INF - 38
# 	SUCCESS
# LAP 39 TIME -> 0:0:2
#
# RUN FOR IHG - 39
# 	SUCCESS
# LAP 40 TIME -> 0:0:2
#
# RUN FOR ITRK - 40
# 	SUCCESS
# LAP 41 TIME -> 0:0:2
#
# RUN FOR IAG - 41
# 	SUCCESS
# LAP 42 TIME -> 0:0:2
#
# RUN FOR ITV - 42
# 	SUCCESS
# LAP 43 TIME -> 0:0:2
#
# RUN FOR JMAT - 43
# 	SUCCESS
# LAP 44 TIME -> 0:0:2
#
# RUN FOR KGF - 44
# 	SUCCESS
# LAP 45 TIME -> 0:0:2
#
# RUN FOR LAND - 45
# 	SUCCESS
# LAP 46 TIME -> 0:0:2
#
# RUN FOR LGEN - 46
# 	SUCCESS
# LAP 47 TIME -> 0:0:2
#
# RUN FOR LLOY - 47
# 	SUCCESS
# LAP 48 TIME -> 0:0:2
#
# RUN FOR LSE - 48
# 	SUCCESS
# LAP 49 TIME -> 0:0:2
#
# RUN FOR MGGT - 49
# 	SUCCESS
# LAP 50 TIME -> 0:0:3
#
# RUN FOR MRO - 50
# 	SUCCESS
# LAP 51 TIME -> 0:0:1
#
# RUN FOR MNDI - 51
# 	SUCCESS
# LAP 52 TIME -> 0:0:1
#
# RUN FOR MRW - 52
# 	SUCCESS
# LAP 53 TIME -> 0:0:2
#
# RUN FOR NXT - 53
# 	SUCCESS
# LAP 54 TIME -> 0:0:3
#
# RUN FOR NMC - 54
# 	SUCCESS
# LAP 55 TIME -> 0:0:0
#
# RUN FOR OCDO - 55
# 	SUCCESS
# LAP 56 TIME -> 0:0:1
#
# RUN FOR PSON - 56
# 	SUCCESS
# LAP 57 TIME -> 0:0:2
#
# RUN FOR PSN - 57
# 	SUCCESS
# LAP 58 TIME -> 0:0:3
#
# RUN FOR PHNX - 58
# 	SUCCESS
# LAP 59 TIME -> 0:0:1
#
# RUN FOR POLY - 59
# 	SUCCESS
# LAP 60 TIME -> 0:0:1
#
# RUN FOR PRU - 60
# 	SUCCESS
# LAP 61 TIME -> 0:0:3
#
# RUN FOR RDSA - 61
# 	SUCCESS
# LAP 62 TIME -> 0:0:0
#
# RUN FOR RDSB - 62
# 	SUCCESS
# LAP 63 TIME -> 0:0:2
#
# RUN FOR REL - 63
# 	SUCCESS
# LAP 64 TIME -> 0:0:2
#
# RUN FOR RTO - 64
# 	SUCCESS
# LAP 65 TIME -> 0:0:2
#
# RUN FOR RMV - 65
# 	SUCCESS
# LAP 66 TIME -> 0:0:1
#
# RUN FOR RIO - 66
# 	SUCCESS
# LAP 67 TIME -> 0:0:3
#
# RUN FOR RBS - 67
# 	SUCCESS
# LAP 68 TIME -> 0:0:2
#
# RUN FOR RSA - 68
# 	SUCCESS
# LAP 69 TIME -> 0:0:3
#
# RUN FOR SGE - 69
# 	SUCCESS
# LAP 70 TIME -> 0:0:2
#
# RUN FOR SBRY - 70
# 	SUCCESS
# LAP 71 TIME -> 0:0:3
#
# RUN FOR SDR - 71
# 	SUCCESS
# LAP 72 TIME -> 0:0:2
#
# RUN FOR SMT - 72
# 	SUCCESS
# LAP 73 TIME -> 0:0:0
#
# RUN FOR SGRO - 73
# 	SUCCESS
# LAP 74 TIME -> 0:0:3
#
# RUN FOR SVT - 74
# 	SUCCESS
# LAP 75 TIME -> 0:0:3
#
# RUN FOR SMDS - 75
# 	SUCCESS
# LAP 76 TIME -> 0:0:3
#
# RUN FOR SMIN - 76
# 	SUCCESS
# LAP 77 TIME -> 0:0:3
#
# RUN FOR SKG - 77
# 	SUCCESS
# LAP 78 TIME -> 0:0:1
#
# RUN FOR SPX - 78
# 	SUCCESS
# LAP 79 TIME -> 0:0:3
#
# RUN FOR SSE - 79
# 	SUCCESS
# LAP 80 TIME -> 0:0:2
#
# RUN FOR STJ - 80
# 	SUCCESS
# LAP 81 TIME -> 0:0:3
#
# RUN FOR STAN - 81
# 	SUCCESS
# LAP 82 TIME -> 0:0:3
#
# RUN FOR SLA - 82
# 	SUCCESS
# LAP 83 TIME -> 0:0:1
#
# RUN FOR TSCO - 83
# 	SUCCESS
# LAP 84 TIME -> 0:0:2
#
# RUN FOR TUI - 84
# 	SUCCESS
# LAP 85 TIME -> 0:0:0
#
# RUN FOR ULVR - 85
# 	SUCCESS
# LAP 86 TIME -> 0:0:2
#
# RUN FOR VOD - 86
# 	SUCCESS
# LAP 87 TIME -> 0:0:2
#
# RUN FOR WTB - 87
# 	SUCCESS
# LAP 88 TIME -> 0:0:2
#
# RUN FOR WPP - 88
# 	SUCCESS
# LAP 89 TIME -> 0:0:1
#
# RUN FOR 3IN - 89
# 	SUCCESS
# LAP 90 TIME -> 0:0:1
#
# RUN FOR FOUR - 90
# 	SUCCESS
# LAP 91 TIME -> 0:0:2
#
# RUN FOR ASL - 91
# 	SUCCESS
# LAP 92 TIME -> 0:0:1
#
# RUN FOR AGK - 92
# 	SUCCESS
# LAP 93 TIME -> 0:0:2
#
# RUN FOR AJB - 93
# 	SUCCESS
# LAP 94 TIME -> 0:0:0
#
# RUN FOR ATST - 94
# 	SUCCESS
# LAP 95 TIME -> 0:0:1
#
# RUN FOR APAX - 95
# 	SUCCESS
# LAP 96 TIME -> 0:0:0
#
# RUN FOR ASCL - 96
# 	SUCCESS
# LAP 97 TIME -> 0:0:0
#
# RUN FOR ASHM - 97
# 	SUCCESS
# LAP 98 TIME -> 0:0:1
#
# RUN FOR AGR - 98
# 	SUCCESS
# LAP 99 TIME -> 0:0:1
#
# RUN FOR AML - 99
# 	SUCCESS
# LAP 100 TIME -> 0:0:0
#
# RUN FOR AVST - 100
# 	SUCCESS
# LAP 101 TIME -> 0:0:0
#
# RUN FOR BME - 101
# 	SUCCESS
# LAP 102 TIME -> 0:0:0
#
# RUN FOR BAB - 102
# 	SUCCESS
# LAP 103 TIME -> 0:0:2
#
# RUN FOR BGFD - 103
# 	SUCCESS
# LAP 104 TIME -> 0:0:2
#
# RUN FOR BAKK - 104
# 	SUCCESS
# LAP 105 TIME -> 0:0:0
#
# RUN FOR BBY - 105
# 	SUCCESS
# LAP 106 TIME -> 0:0:2
#
# RUN FOR BGEO - 106
# 	SUCCESS
# LAP 107 TIME -> 0:0:1
#
# RUN FOR BNKR - 107
# 	SUCCESS
# LAP 108 TIME -> 0:0:1
#
# RUN FOR BAG - 108
# 	SUCCESS
# LAP 109 TIME -> 0:0:2
#
# RUN FOR BBA - 109
# 	SUCCESS
# LAP 110 TIME -> 0:0:2
#
# RUN FOR BBGI - 110
# 	SUCCESS
# LAP 111 TIME -> 0:0:1
#
# RUN FOR BCA - 111
# 	SUCCESS
# LAP 112 TIME -> 0:0:0
#
# RUN FOR BEZ - 112
# 	SUCCESS
# LAP 113 TIME -> 0:0:0
#
# RUN FOR BWY - 113
# 	SUCCESS
# LAP 114 TIME -> 0:0:3
#
# RUN FOR BYG - 114
# 	SUCCESS
# LAP 115 TIME -> 0:0:2
#
# RUN FOR BRSC - 115
# 	SUCCESS
# LAP 116 TIME -> 0:0:0
#
# RUN FOR BGSC - 116
# 	SUCCESS
# LAP 117 TIME -> 0:0:1
#
# RUN FOR BOY - 117
# 	SUCCESS
# LAP 118 TIME -> 0:0:2
#
# RUN FOR BVS - 118
# 	SUCCESS
# LAP 119 TIME -> 0:0:2
#
# RUN FOR BRW - 119
# 	SUCCESS
# LAP 120 TIME -> 0:0:2
#
# RUN FOR BVIC - 120
# 	SUCCESS
# LAP 121 TIME -> 0:0:1
#
# RUN FOR CNE - 121
# 	SUCCESS
# LAP 122 TIME -> 0:0:3
#
# RUN FOR CLDN - 122
# 	SUCCESS
# LAP 123 TIME -> 0:0:1
#
# RUN FOR CAPC - 123
# 	SUCCESS
# LAP 124 TIME -> 0:0:1
#
# RUN FOR CPI - 124
# 	SUCCESS
# LAP 125 TIME -> 0:0:3
#
# RUN FOR CARD - 125
# 	SUCCESS
# LAP 126 TIME -> 0:0:0
#
# RUN FOR CEY - 126
# 	SUCCESS
# LAP 127 TIME -> 0:0:2
#
# RUN FOR CCFS - 127
# 	SUCCESS
# LAP 128 TIME -> 0:0:0
#
# RUN FOR CINE - 128
# 	SUCCESS
# LAP 129 TIME -> 0:0:1
#
# RUN FOR CTY - 129
# 	SUCCESS
# LAP 130 TIME -> 0:0:1
#
# RUN FOR CKN - 130
# 	SUCCESS
# LAP 131 TIME -> 0:0:3
#
# RUN FOR CBG - 131
# 	SUCCESS
# LAP 132 TIME -> 0:0:3
#
# RUN FOR CLI - 132
# 	SUCCESS
# LAP 133 TIME -> 0:0:2
#
# RUN FOR COA - 133
# 	SUCCESS
# LAP 134 TIME -> 0:0:3
#
# RUN FOR COB - 134
# 	SUCCESS
# LAP 135 TIME -> 0:0:2
#
# RUN FOR CCC - 135
# 	SUCCESS
# LAP 136 TIME -> 0:0:2
#
# RUN FOR GLO - 136
# 	SUCCESS
# LAP 137 TIME -> 0:0:0
#
# RUN FOR CTEC - 137
# 	SUCCESS
# LAP 138 TIME -> 0:0:0
#
# RUN FOR CSP - 138
# 	SUCCESS
# LAP 139 TIME -> 0:0:1
#
# RUN FOR CWK - 139
# 	SUCCESS
# LAP 140 TIME -> 0:0:3
#
# RUN FOR CRST - 140
# 	SUCCESS
# LAP 141 TIME -> 0:0:1
#
# RUN FOR CYBG - 141
# 	SUCCESS
# LAP 142 TIME -> 0:0:0
#
# RUN FOR DJAN - 142
# 	SUCCESS
# LAP 143 TIME -> 0:0:3
#
# RUN FOR DPH - 143
# 	SUCCESS
# LAP 144 TIME -> 0:0:2
#
# RUN FOR DLN - 144
# 	SUCCESS
# LAP 145 TIME -> 0:0:3
#
# RUN FOR DPLM - 145
# 	SUCCESS
# LAP 146 TIME -> 0:0:3
#
# RUN FOR DLG - 146
# 	SUCCESS
# LAP 147 TIME -> 0:0:0
#
# RUN FOR DOM - 147
# 	SUCCESS
# LAP 148 TIME -> 0:0:2
#
# RUN FOR DRX - 148
# 	SUCCESS
# LAP 149 TIME -> 0:0:1
#
# RUN FOR DNLM - 149
# 	SUCCESS
# LAP 150 TIME -> 0:0:1
#
# RUN FOR EZJ - 150
# 	SUCCESS
# LAP 151 TIME -> 0:0:2
#
# RUN FOR EDIN - 151
# 	SUCCESS
# LAP 152 TIME -> 0:0:1
#
# RUN FOR EIG - 152
# 	SUCCESS
# LAP 153 TIME -> 0:0:1
#
# RUN FOR ECM - 153
# 	SUCCESS
# LAP 154 TIME -> 0:0:2
#
# RUN FOR ELM - 154
# 	SUCCESS
# LAP 155 TIME -> 0:0:3
#
# RUN FOR ENOG - 155
# 	SUCCESS
# LAP 156 TIME -> 0:0:0
#
# RUN FOR ETO - 156
# 	SUCCESS
# LAP 157 TIME -> 0:0:1
#
# RUN FOR EQN - 157
# 	SUCCESS
# LAP 158 TIME -> 0:0:0
#
# RUN FOR ESNT - 158
# 	SUCCESS
# LAP 159 TIME -> 0:0:2
#
# RUN FOR ERM - 159
# 	SUCCESS
# LAP 160 TIME -> 0:0:2
#
# RUN FOR FCIT - 160
# 	SUCCESS
# LAP 161 TIME -> 0:0:1
#
# RUN FOR FDM - 161
# 	SUCCESS
# LAP 162 TIME -> 0:0:0
#
# RUN FOR FXPO - 162
# 	SUCCESS
# LAP 163 TIME -> 0:0:1
#
# RUN FOR FEV - 163
# 	SUCCESS
# LAP 164 TIME -> 0:0:1
#
# RUN FOR FSV - 164
# 	SUCCESS
# LAP 165 TIME -> 0:0:1
#
# RUN FOR FCSS - 165
# 	SUCCESS
# LAP 166 TIME -> 0:0:1
#
# RUN FOR FGT - 166
# 	SUCCESS
# LAP 167 TIME -> 0:0:1
#
# RUN FOR FGP - 167
# 	SUCCESS
# LAP 168 TIME -> 0:0:2
#
# RUN FOR FSJ - 168
# 	SUCCESS
# LAP 169 TIME -> 0:0:2
#
# RUN FOR FSFL - 169
# 	SUCCESS
# LAP 170 TIME -> 0:0:0
#
# RUN FOR FUTR - 170
# 	SUCCESS
# LAP 171 TIME -> 0:0:2
#
# RUN FOR GFS - 171
# 	SUCCESS
# LAP 172 TIME -> 0:0:1
#
# RUN FOR GFRD - 172
# 	SUCCESS
# LAP 173 TIME -> 0:0:3
#
# RUN FOR GAW - 173
# 	SUCCESS
# LAP 174 TIME -> 0:0:2
#
# RUN FOR GCP - 174
# 	SUCCESS
# LAP 175 TIME -> 0:0:1
#
# RUN FOR DIGS - 175
# 	SUCCESS
# LAP 176 TIME -> 0:0:0
#
# RUN FOR GSS - 176
# 	SUCCESS
# LAP 177 TIME -> 0:0:1
#
# RUN FOR GNS - 177
# 	SUCCESS
# LAP 178 TIME -> 0:0:2
#
# RUN FOR GOG - 178
# 	SUCCESS
# LAP 179 TIME -> 0:0:2
#
# RUN FOR GPOR - 179
# 	SUCCESS
# LAP 180 TIME -> 0:0:2
#
# RUN FOR GFTU - 180
# 	SUCCESS
# LAP 181 TIME -> 0:0:2
#
# RUN FOR GRI - 181
# 	SUCCESS
# LAP 182 TIME -> 0:0:2
#
# RUN FOR UKW - 182
# 	SUCCESS
# LAP 183 TIME -> 0:0:0
#
# RUN FOR GNC - 183
# 	SUCCESS
# LAP 184 TIME -> 0:0:2
#
# RUN FOR GNK - 184
# 	SUCCESS
# LAP 185 TIME -> 0:0:2
#
# RUN FOR GRG - 185
# 	SUCCESS
# LAP 186 TIME -> 0:0:2
#
# RUN FOR GVC - 186
# 	SUCCESS
# LAP 187 TIME -> 0:0:1
#
# RUN FOR HMSO - 187
# 	SUCCESS
# LAP 188 TIME -> 0:0:2
#
# RUN FOR HVPE - 188
# 	SUCCESS
# LAP 189 TIME -> 0:0:1
#
# RUN FOR HSTG - 189
# 	SUCCESS
# LAP 190 TIME -> 0:0:0
#
# RUN FOR HAS - 190
# 	SUCCESS
# LAP 191 TIME -> 0:0:2
#
# RUN FOR HRI - 191
# 	SUCCESS
# LAP 192 TIME -> 0:0:1
#
# RUN FOR HGT - 192
# 	SUCCESS
# LAP 193 TIME -> 0:0:1
#
# RUN FOR HICL - 193
# 	SUCCESS
# LAP 194 TIME -> 0:0:1
#
# RUN FOR HILS - 194
# 	SUCCESS
# LAP 195 TIME -> 0:0:2
#
# RUN FOR HFG - 195
# 	SUCCESS
# LAP 196 TIME -> 0:0:1
#
# RUN FOR HOC - 196
# 	SUCCESS
# LAP 197 TIME -> 0:0:1
#
# RUN FOR HSV - 197
# 	SUCCESS
# LAP 198 TIME -> 0:0:2
#
# RUN FOR HWDN - 198
# 	SUCCESS
# LAP 199 TIME -> 0:0:2
#
# RUN FOR HTG - 199
# 	SUCCESS
# LAP 200 TIME -> 0:0:2
#
# RUN FOR IBST - 200
# 	SUCCESS
# LAP 201 TIME -> 0:0:0
#
# RUN FOR IGG - 201
# 	SUCCESS
# LAP 202 TIME -> 0:0:1
#
# RUN FOR IMI - 202
# 	SUCCESS
# LAP 203 TIME -> 0:0:2
#
# RUN FOR INCH - 203
# 	SUCCESS
# LAP 204 TIME -> 0:0:2
#
# RUN FOR ISAT - 204
# 	SUCCESS
# LAP 205 TIME -> 0:0:1
#
# RUN FOR ICP - 205
# 	SUCCESS
# LAP 206 TIME -> 0:0:2
#
# RUN FOR IHP - 206
# 	SUCCESS
# LAP 207 TIME -> 0:0:0
#
# RUN FOR INPP - 207
# 	SUCCESS
# LAP 208 TIME -> 0:0:1
#
# RUN FOR INVP - 208
# 	SUCCESS
# LAP 209 TIME -> 0:0:2
#
# RUN FOR IPO - 209
# 	SUCCESS
# LAP 210 TIME -> 0:0:1
#
# RUN FOR IWG - 210
# 	SUCCESS
# LAP 211 TIME -> 0:0:1
#
# RUN FOR JLG - 211
# 	SUCCESS
# LAP 212 TIME -> 0:0:0
#
# RUN FOR JII - 212
# 	SUCCESS
# LAP 213 TIME -> 0:0:1
#
# RUN FOR JAM - 213
# 	SUCCESS
# LAP 214 TIME -> 0:0:1
#
# RUN FOR JMG - 214
# 	SUCCESS
# LAP 215 TIME -> 0:0:1
#
# RUN FOR JFJ - 215
# 	SUCCESS
# LAP 216 TIME -> 0:0:1
#
# RUN FOR JEO - 216
# 	SUCCESS
# LAP 217 TIME -> 0:0:1
#
# RUN FOR JUP - 217
# 	SUCCESS
# LAP 218 TIME -> 0:0:1
#
# RUN FOR KNOS - 218
# 	SUCCESS
# LAP 219 TIME -> 0:0:0
#
# RUN FOR KAZ - 219
# 	SUCCESS
# LAP 220 TIME -> 0:0:1
#
# RUN FOR LRE - 220
# 	SUCCESS
# LAP 221 TIME -> 0:0:1
#
# RUN FOR LWDB - 221
# 	SUCCESS
# LAP 222 TIME -> 0:0:0
#
# RUN FOR LMP - 222
# 	SUCCESS
# LAP 223 TIME -> 0:0:1
#
# RUN FOR EMG - 223
# 	SUCCESS
# LAP 224 TIME -> 0:0:2
#
# RUN FOR MKS - 224
# 	SUCCESS
# LAP 225 TIME -> 0:0:2
#
# RUN FOR MSLH - 225
# 	SUCCESS
# LAP 226 TIME -> 0:0:2
#
# RUN FOR MARS - 226
# 	SUCCESS
# LAP 227 TIME -> 0:0:1
#
# RUN FOR MCS - 227
# 	SUCCESS
# LAP 228 TIME -> 0:0:0
#
# RUN FOR MDC - 228
# 	SUCCESS
# LAP 229 TIME -> 0:0:0
#
# RUN FOR MRC - 229
# 	SUCCESS
# LAP 230 TIME -> 0:0:1
#
# RUN FOR MERL - 230
# 	SUCCESS
# LAP 231 TIME -> 0:0:0
#
# RUN FOR MCRO - 231
# 	SUCCESS
# LAP 232 TIME -> 0:0:1
#
# RUN FOR MAB - 232
# 	SUCCESS
# LAP 233 TIME -> 0:0:1
#
# RUN FOR MONY - 233
# 	SUCCESS
# LAP 234 TIME -> 0:0:1
#
# RUN FOR MNKS - 234
# 	SUCCESS
# LAP 235 TIME -> 0:0:1
#
# RUN FOR MGAM - 235
# 	SUCCESS
# LAP 236 TIME -> 0:0:3
#
# RUN FOR MYI - 236
# 	SUCCESS
# LAP 237 TIME -> 0:0:1
#
# RUN FOR NEX - 237
# 	SUCCESS
# LAP 238 TIME -> 0:0:3
#
# RUN FOR NBLS - 238
# 	SUCCESS
# LAP 239 TIME -> 0:0:1
#
# RUN FOR NRR - 239
# 	SUCCESS
# LAP 240 TIME -> 0:0:1
#
# RUN FOR NESF - 240
# 	SUCCESS
# LAP 241 TIME -> 0:0:0
#
# RUN FOR OSB - 241
# 	SUCCESS
# LAP 242 TIME -> 0:0:0
#
# RUN FOR OXIG - 242
# 	SUCCESS
# LAP 243 TIME -> 0:0:3
#
# RUN FOR PAGE - 243
# 	SUCCESS
# LAP 244 TIME -> 0:0:2
#
# RUN FOR PIN - 244
# 	SUCCESS
# LAP 245 TIME -> 0:0:1
#
# RUN FOR PAG - 245
# 	SUCCESS
# LAP 246 TIME -> 0:0:3
#
# RUN FOR PAY - 246
# 	SUCCESS
# LAP 247 TIME -> 0:0:1
#
# RUN FOR PNN - 247
# 	SUCCESS
# LAP 248 TIME -> 0:0:3
#
# RUN FOR PLI - 248
# 	SUCCESS
# LAP 249 TIME -> 0:0:1
#
# RUN FOR PSH - 249
# 	SUCCESS
# LAP 250 TIME -> 0:0:0
#
# RUN FOR PNL - 250
# 	SUCCESS
# LAP 251 TIME -> 0:0:1
#
# RUN FOR PFC - 251
# 	SUCCESS
# LAP 252 TIME -> 0:0:1
#
# RUN FOR PETS - 252
# 	SUCCESS
# LAP 253 TIME -> 0:0:0
#
# RUN FOR PTEC - 253
# 	SUCCESS
# LAP 254 TIME -> 0:0:1
#
# RUN FOR PLUS - 254
# 	SUCCESS
# LAP 255 TIME -> 0:0:0
#
# RUN FOR PCT - 255
# 	SUCCESS
# LAP 256 TIME -> 0:0:1
#
# RUN FOR PLP - 256
# 	SUCCESS
# LAP 257 TIME -> 0:0:0
#
# RUN FOR PPH - 257
# 	SUCCESS
# LAP 258 TIME -> 0:0:1
#
# RUN FOR PMO - 258
# 	SUCCESS
# LAP 259 TIME -> 0:0:3
#
# RUN FOR PHP - 259
# 	SUCCESS
# LAP 260 TIME -> 0:0:3
#
# RUN FOR PFG - 260
# 	SUCCESS
# LAP 261 TIME -> 0:0:2
#
# RUN FOR PRTC - 261
# 	SUCCESS
# LAP 262 TIME -> 0:0:0
#
# RUN FOR PZC - 262
# 	SUCCESS
# LAP 263 TIME -> 0:0:2
#
# RUN FOR QLT - 263
# 	SUCCESS
# LAP 264 TIME -> 0:0:0
#
# RUN FOR RNK - 264
# 	SUCCESS
# LAP 265 TIME -> 0:0:2
#
# RUN FOR RAT - 265
# 	SUCCESS
# LAP 266 TIME -> 0:0:2
#
# RUN FOR RDW - 266
# 	SUCCESS
# LAP 267 TIME -> 0:0:2
#
# RUN FOR TRIG - 267
# 	SUCCESS
# LAP 268 TIME -> 0:0:0
#
# RUN FOR RSW - 268
# 	SUCCESS
# LAP 269 TIME -> 0:0:2
#
# RUN FOR RTN - 269
# 	SUCCESS
# LAP 270 TIME -> 0:0:2
#
# RUN FOR RHIM - 270
# 	SUCCESS
# LAP 271 TIME -> 0:0:0
#
# RUN FOR RCP - 271
# 	SUCCESS
# LAP 272 TIME -> 0:0:0
#
# RUN FOR RSE - 272
# 	SUCCESS
# LAP 273 TIME -> 0:0:0
#
# RUN FOR ROR - 273
# 	SUCCESS
# LAP 274 TIME -> 0:0:2
#
# RUN FOR RMG - 274
# 	SUCCESS
# LAP 275 TIME -> 0:0:0
#
# RUN FOR SBRE - 275
# 	SUCCESS
# LAP 276 TIME -> 0:0:0
#
# RUN FOR SAFE - 276
# 	SUCCESS
# LAP 277 TIME -> 0:0:1
#
# RUN FOR SNN - 277
# 	SUCCESS
# LAP 278 TIME -> 0:0:0
#
# RUN FOR SVS - 278
# 	SUCCESS
# LAP 279 TIME -> 0:0:3
#
# RUN FOR SDP - 279
# 	SUCCESS
# LAP 280 TIME -> 0:0:1
#
# RUN FOR SOI - 280
# 	SUCCESS
# LAP 281 TIME -> 0:0:1
#
# RUN FOR SCIN - 281
# 	SUCCESS
# LAP 282 TIME -> 0:0:1
#
# RUN FOR SNR - 282
# 	SUCCESS
# LAP 283 TIME -> 0:0:3
#
# RUN FOR SEQI - 283
# 	SUCCESS
# LAP 284 TIME -> 0:0:0
#
# RUN FOR SRP - 284
# 	SUCCESS
# LAP 285 TIME -> 0:0:3
#
# RUN FOR SHB - 285
# 	SUCCESS
# LAP 286 TIME -> 0:0:2
#
# RUN FOR SHI - 286
# 	SUCCESS
# LAP 287 TIME -> 0:0:3
#
# RUN FOR SXX - 287
# 	SUCCESS
# LAP 288 TIME -> 0:0:1
#
# RUN FOR SRE - 288
# 	SUCCESS
# LAP 289 TIME -> 0:0:1
#
# RUN FOR SSON - 289
# 	SUCCESS
# LAP 290 TIME -> 0:0:0
#
# RUN FOR SCT - 290
# 	SUCCESS
# LAP 291 TIME -> 0:0:0
#
# RUN FOR SOPH - 291
# 	SUCCESS
# LAP 292 TIME -> 0:0:0
#
# RUN FOR SXS - 292
# 	SUCCESS
# LAP 293 TIME -> 0:0:4
#
# RUN FOR SPT - 293
# 	SUCCESS
# LAP 294 TIME -> 0:0:3
#
# RUN FOR SPD - 294
# 	SUCCESS
# LAP 295 TIME -> 0:0:1
#
# RUN FOR SSPG - 295
# 	SUCCESS
# LAP 296 TIME -> 0:0:0
#
# RUN FOR SMP - 296
# 	SUCCESS
# LAP 297 TIME -> 0:0:3
#
# RUN FOR SGC - 297
# 	SUCCESS
# LAP 298 TIME -> 0:0:3
#
# RUN FOR SYNC - 298
# 	SUCCESS
# LAP 299 TIME -> 0:0:1
#
# RUN FOR SYNT - 299
# 	SUCCESS
# LAP 300 TIME -> 0:0:3
#
# RUN FOR TALK - 300
# 	SUCCESS
# LAP 301 TIME -> 0:0:1
#
# RUN FOR TATE - 301
# 	SUCCESS
# LAP 302 TIME -> 0:0:3
#
# RUN FOR TBCG - 302
# 	SUCCESS
# LAP 303 TIME -> 0:0:0
#
# RUN FOR TEP - 303
# 	SUCCESS
# LAP 304 TIME -> 0:0:2
#
# RUN FOR TMPL - 304
# 	SUCCESS
# LAP 305 TIME -> 0:0:1
#
# RUN FOR TEM - 305
# 	SUCCESS
# LAP 306 TIME -> 0:0:1
#
# RUN FOR TIFS - 306
# 	SUCCESS
# LAP 307 TIME -> 0:0:0
#
# RUN FOR TCAP - 307
# 	SUCCESS
# LAP 308 TIME -> 0:0:2
#
# RUN FOR TRY - 308
# 	SUCCESS
# LAP 309 TIME -> 0:0:1
#
# RUN FOR TPK - 309
# 	SUCCESS
# LAP 310 TIME -> 0:0:2
#
# RUN FOR BBOX - 310
# 	SUCCESS
# LAP 311 TIME -> 0:0:0
#
# RUN FOR TLW - 311
# 	SUCCESS
# LAP 312 TIME -> 0:0:2
#
# RUN FOR UDG - 312
# 	SUCCESS
# LAP 313 TIME -> 0:0:2
#
# RUN FOR UKCM - 313
# 	SUCCESS
# LAP 314 TIME -> 0:0:1
#
# RUN FOR ULE - 314
# 	SUCCESS
# LAP 315 TIME -> 0:0:4
#
# RUN FOR UTG - 315
# 	SUCCESS
# LAP 316 TIME -> 0:0:1
#
# RUN FOR VSVS - 316
# 	SUCCESS
# LAP 317 TIME -> 0:0:5
#
# RUN FOR VCT - 317
# 	SUCCESS
# LAP 318 TIME -> 0:0:4
#
# RUN FOR VEIL - 318
# 	SUCCESS
# LAP 319 TIME -> 0:0:0
#
# RUN FOR VOF - 319
# 	SUCCESS
# LAP 320 TIME -> 0:0:2
#
# RUN FOR VVO - 320
# 	SUCCESS
# LAP 321 TIME -> 0:0:0
#
# RUN FOR WEIR - 321
# 	SUCCESS
# LAP 322 TIME -> 0:0:4
#
# RUN FOR JDW - 322
# 	SUCCESS
# LAP 323 TIME -> 0:0:4
#
# RUN FOR SMWH - 323
# 	SUCCESS
# LAP 324 TIME -> 0:0:1
#
# RUN FOR WMH - 324
# 	SUCCESS
# LAP 325 TIME -> 0:0:2
#
# RUN FOR WTAN - 325
# 	SUCCESS
# LAP 326 TIME -> 0:0:1
#
# RUN FOR WIZZ - 326
# 	SUCCESS
# LAP 327 TIME -> 0:0:0
#
# RUN FOR WKP - 327
# 	SUCCESS
# LAP 328 TIME -> 0:0:2
#
# RUN FOR WWH - 328
# 	SUCCESS
# LAP 329 TIME -> 0:0:1
# TOTAL ELAPSED TIME -> 0:10:51
#
#
# COMPLETED - ERRORS ENCOUNTERED -> 0

# %%
#Get in-row price change
def calc_changes(_s_in,_prev_s_in):
    _s_change = _s_in - _prev_s_in
    _s_per_change = _s_change / _s_in
    return (_s_change,_s_per_change)

#Relabel col names
for col in df_prices_w:
    df_prices_w.rename(columns={col:col.lower()},inplace=True)
    
df_prices_w["change_price"],df_prices_w["per_change_price"] = calc_changes(df_prices_w.close.copy(),df_prices_w.open.copy())
df_prices_w.head()
# Out:
#   ticker       date    high     low     volume    open   close  change  ema12  \
# 0    3IN 2007-12-31  149.89  147.07  1373801.0  149.18  147.43   -1.75    NaN
# 1    3IN 2008-01-07  149.54  147.07  2345191.0  147.07  148.83    1.76    NaN
# 2    3IN 2008-01-14  150.59  147.43  2150049.0  148.48  149.18    0.70    NaN
# 3    3IN 2008-01-21  154.82  145.32  3070968.0  147.78  152.00    4.22    NaN
# 4    3IN 2008-01-28  154.82  148.83  2510972.0  149.89  152.00    2.11    NaN
#
#    ema26  macd_line  signal_line  macd  change_price  per_change_price
# 0    NaN        NaN          NaN   NaN         -1.75         -0.011870
# 1    NaN        NaN          NaN   NaN          1.76          0.011826
# 2    NaN        NaN          NaN   NaN          0.70          0.004692
# 3    NaN        NaN          NaN   NaN          4.22          0.027763
# 4    NaN        NaN          NaN   NaN          2.11          0.013882

# %%
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print(df_prices_w.ticker.unique())
df_prices_w.head()
# Out:
# ['3IN' 'AAL' 'ABF' 'ADM' 'AGK' 'AGR' 'AHT' 'AJB' 'AML' 'ANTO' 'APAX'
#  'ASCL' 'ASHM' 'ASL' 'ATST' 'AUTO' 'AVST' 'AVV' 'AZN' 'BAB' 'BAG' 'BAKK'
#  'BARC' 'BATS' 'BBA' 'BBGI' 'BBOX' 'BBY' 'BCA' 'BDEV' 'BEZ' 'BGEO' 'BGFD'
#  'BGSC' 'BHP' 'BKG' 'BLND' 'BME' 'BNKR' 'BNZL' 'BOY' 'BRBY' 'BRSC' 'BRW'
#  'BT.A' 'BVIC' 'BVS' 'BWY' 'BYG' 'CAPC' 'CARD' 'CBG' 'CCC' 'CCFS' 'CCH'
#  'CCL' 'CEY' 'CINE' 'CKN' 'CLDN' 'CLI' 'CNA' 'CNE' 'COA' 'COB' 'CPG' 'CPI'
#  'CRDA' 'CRH' 'CRST' 'CSP' 'CTEC' 'CTY' 'CWK' 'CYBG' 'DCC' 'DGE' 'DIGS'
#  'DJAN' 'DLG' 'DLN' 'DNLM' 'DOM' 'DPH' 'DPLM' 'DRX' 'ECM' 'EDIN' 'EIG'
#  'ELM' 'EMG' 'ENOG' 'EQN' 'ERM' 'ESNT' 'ETO' 'EVR' 'EXPN' 'EZJ' 'FCIT'
#  'FCSS' 'FDM' 'FERG' 'FEV' 'FGP' 'FGT' 'FOUR' 'FRES' 'FSFL' 'FSJ' 'FSV'
#  'FUTR' 'FXPO' 'GAW' 'GCP' 'GFRD' 'GFS' 'GFTU' 'GLEN' 'GLO' 'GNC' 'GNK'
#  'GNS' 'GOG' 'GPOR' 'GRG' 'GRI' 'GSK' 'GSS' 'GVC' 'HAS' 'HFG' 'HGT' 'HICL'
#  'HIK' 'HILS' 'HLMA' 'HMSO' 'HOC' 'HRI' 'HSBA' 'HSTG' 'HSV' 'HSX' 'HTG'
#  'HVPE' 'HWDN' 'IAG' 'IBST' 'ICP' 'IGG' 'IHG' 'IHP' 'III' 'IMB' 'IMI'
#  'INCH' 'INF' 'INPP' 'INVP' 'IPO' 'ISAT' 'ITRK' 'ITV' 'IWG' 'JAM' 'JDW'
#  'JEO' 'JFJ' 'JII' 'JLG' 'JMAT' 'JMG' 'JUP' 'KAZ' 'KGF' 'KNOS' 'LAND'
#  'LGEN' 'LLOY' 'LMP' 'LRE' 'LSE' 'LWDB' 'MAB' 'MARS' 'MCRO' 'MCS' 'MDC'
#  'MERL' 'MGAM' 'MGGT' 'MKS' 'MNDI' 'MNKS' 'MONY' 'MRC' 'MRO' 'MRW' 'MSLH'
#  'MYI' 'NBLS' 'NESF' 'NEX' 'NMC' 'NRR' 'NXT' 'OCDO' 'OSB' 'OXIG' 'PAG'
#  'PAGE' 'PAY' 'PCT' 'PETS' 'PFC' 'PFG' 'PHNX' 'PHP' 'PIN' 'PLI' 'PLP'
#  'PLUS' 'PMO' 'PNL' 'PNN' 'POLY' 'PPH' 'PRTC' 'PRU' 'PSH' 'PSN' 'PSON'
#  'PTEC' 'PZC' 'QLT' 'RAT' 'RBS' 'RCP' 'RDSA' 'RDSB' 'RDW' 'REL' 'RHIM'
#  'RIO' 'RMG' 'RMV' 'RNK' 'ROR' 'RSA' 'RSE' 'RSW' 'RTN' 'RTO' 'SAFE' 'SBRE'
#  'SBRY' 'SCIN' 'SCT' 'SDP' 'SDR' 'SEQI' 'SGC' 'SGE' 'SGRO' 'SHB' 'SHI'
#  'SKG' 'SLA' 'SMDS' 'SMIN' 'SMP' 'SMT' 'SMWH' 'SNN' 'SNR' 'SOI' 'SOPH'
#  'SPD' 'SPT' 'SPX' 'SRE' 'SRP' 'SSE' 'SSON' 'SSPG' 'STAN' 'STJ' 'SVS'
#  'SVT' 'SXS' 'SXX' 'SYNC' 'SYNT' 'TALK' 'TATE' 'TBCG' 'TCAP' 'TEM' 'TEP'
#  'TIFS' 'TLW' 'TMPL' 'TPK' 'TRIG' 'TRY' 'TSCO' 'TUI' 'UDG' 'UKCM' 'UKW'
#  'ULE' 'ULVR' 'UTG' 'VCT' 'VEIL' 'VOD' 'VOF' 'VSVS' 'VVO' 'WEIR' 'WIZZ'
#  'WKP' 'WMH' 'WPP' 'WTAN' 'WTB' 'WWH']
#   ticker       date    high     low     volume    open   close  change  ema12  \
# 0    3IN 2007-12-31  149.89  147.07  1373801.0  149.18  147.43   -1.75    NaN
# 1    3IN 2008-01-07  149.54  147.07  2345191.0  147.07  148.83    1.76    NaN
# 2    3IN 2008-01-14  150.59  147.43  2150049.0  148.48  149.18    0.70    NaN
# 3    3IN 2008-01-21  154.82  145.32  3070968.0  147.78  152.00    4.22    NaN
# 4    3IN 2008-01-28  154.82  148.83  2510972.0  149.89  152.00    2.11    NaN
#
#    ema26  macd_line  signal_line  macd  change_price  per_change_price
# 0    NaN        NaN          NaN   NaN         -1.75         -0.011870
# 1    NaN        NaN          NaN   NaN          1.76          0.011826
# 2    NaN        NaN          NaN   NaN          0.70          0.004692
# 3    NaN        NaN          NaN   NaN          4.22          0.027763
# 4    NaN        NaN          NaN   NaN          2.11          0.013882

# %% [markdown]
# # Create buy signals, and sell signals
# I am classifying a stock worth buying if it meets all the below criteria:
# - The target price (previous max) is hit within x (set as variable target_price_period) periods proceeding this period
# - The target price is an increase of x% (set as variable min_gain) over the proceeding day's open price
# - There is a drop in the closing price of less x% (set as variable max_drop) between this period and the x periods proceeding this period
#
# I am classifying the sell signals as:
# - The close price dips below the target price (previous max) x (set as variable target_price_period) periods proceeding this period
# - There is an increase in the closing price of less x% (set as variable max_drop) over the next x periods

# %%
#Define the variables
target_price_period = 12
period_high_volatility = 5
period_low_volatility = 2
min_gain = 0.1
max_drop = -0.05

# %%
#Programming note
#df.shift(1) looks 1 period into the past
#df.shift(-1) looks 1 period into the future

# %%
#Check if the target price is hit within the target_price_period
def min_gain_check(_var_s,_target_s,_periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,_periods+1):
        _tmp_check_s = _var_s.shift(-_i) > _target_s #True if price is >= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def max_drop_check(_var_s,_target_s,periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,periods+1):
        _tmp_check_s = _var_s.shift(-_i) < _target_s #True if price is <= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def close_vs_close(_var_s,_shift:int=1):
    _check_s = _var_s.shift(_shift) - _var_s
    return _check_s

# %%
#Create a function for finding buy signals
def get_buys(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == True #Function returns True when min_gain is hit
    print('BUY min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the sell price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == False #Function returns False when does not go below target
    print('BUY max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Check if the following day is a positive change on today's close price
    close_vs_close_pos_s = close_vs_close(var_s,-1) > 0
    print('BUY close_vs_close_pos_s -> {}'.format(close_vs_close_pos_s[max_drop_s == True].shape))
    
    #Find the buy signals
    s_out = min_gain_s & max_drop_s & close_vs_close_pos_s
    print('BUY ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Function for finding sell signals
def get_sells(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == True #Function returns True when max_drop is hit
    print('SELL max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Perform if the target is crossed again
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == False #Function returns False when min_gain is not hit
    print('SELL min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the following day is a negative change on today's close price
    close_vs_close_neg_s = close_vs_close(var_s,-1) < 0
    print('SELL close_vs_close_pos_s -> {}'.format(close_vs_close_neg_s[max_drop_s == True].shape))
    
    #Find the sell signals
    s_out = max_drop_s & min_gain_s & close_vs_close_neg_s
    print('SELL ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Get buy signals
df_prices_w['buy'] = get_buys(df_prices_w['close'])

#Get sell signals
df_prices_w['sell'] = get_sells(df_prices_w['close'])

#Get hold signals
df_prices_w["hold"] = (df_prices_w["buy"] == False) & (df_prices_w["sell"] == False)

print('BUY PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['buy'] == True].shape[0]*100/df_prices_w.shape[0]))
print('SELL PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['sell'] == True].shape[0]*100/df_prices_w.shape[0]))
print('HOLD PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['hold'] == True].shape[0]*100/df_prices_w.shape[0]))
# Out:
# BUY min_gain_s -> (102147,)
# BUY max_drop_s -> (133816,)
# BUY close_vs_close_pos_s -> (133816,)
# BUY ALL -> (56253,)
# SELL max_drop_s -> (127037,)
# SELL min_gain_s -> (158706,)
# SELL close_vs_close_pos_s -> (127037,)
# SELL ALL -> (65840,)
# BUY PERCENTAGE -> 21.57%
# SELL PERCENTAGE -> 25.24%
# HOLD PERCENTAGE -> 53.19%

# %%
df_prices_w[df_prices_w.ticker=='SBRY'].iloc[-5:]
# Out:
#        ticker       date    high     low      volume   open  close  change  \
# 201623   SBRY 2019-09-02  203.00  194.20  37468487.0  196.1  201.6     5.5
# 201624   SBRY 2019-09-09  222.40  199.85  61436062.0  202.6  221.4    18.8
# 201625   SBRY 2019-09-16  224.50  212.80  40962295.0  220.0  215.9    -4.1
# 201626   SBRY 2019-09-23  222.80  212.31  45313711.0  218.9  222.5     3.6
# 201627   SBRY 2019-09-30  223.23  205.70  33549408.0  221.9  210.1   -11.8
#
#              ema12       ema26  macd_line  signal_line      macd  \
# 201623  198.661239  212.032367 -13.371128   -16.307069  2.935941
# 201624  202.159510  212.726265 -10.566756   -15.159006  4.592251
# 201625  204.273432  212.961357  -8.687925   -13.864790  5.176865
# 201626  207.077519  213.667923  -6.590404   -12.409913  5.819509
# 201627  207.542516  213.403632  -5.861116   -11.100154  5.239037
#
#         change_price  per_change_price    buy   sell   hold
# 201623           5.5          0.027282   True  False  False
# 201624          18.8          0.084914  False  False   True
# 201625          -4.1         -0.018990   True  False  False
# 201626           3.6          0.016180  False  False   True
# 201627         -11.8         -0.056164   True  False  False

# %% [markdown]
# # Create additional features

# %%
#Mark minimums and maximums
def flag_mins(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in > s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value > the previous value
        s_out += (s_in > s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value > the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out
def flag_maxs(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in < s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value < the previous value (if the previous value is not null)
        s_out += (s_in < s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value < the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out

# %%
#Calc vol as proportion of previous n-rows
def calc_prop_of_prev(s_in,periods:int = 4):
    s_cum = s_in.copy()
    for i in range(1,periods):
        s_cum += s_in.shift(i)
    return s_in / s_cum

# %%
#Mark points of macd positive entry
def pos_entry(s_in):
    return (s_in > s_in.shift(1)) & (s_in > 0) & (s_in.shift(1) < 0)
def neg_entry(s_in):
    return (s_in < s_in.shift(1)) & (s_in < 0) & (s_in.shift(1) > 0)

# %%
#Function to normalise current price compared to another
def norm_s(s_in,max_in,min_in):
    s_out = (s_in - min_in) / (max_in - min_in)
    s_out.fillna(1.0,inplace=True)
    return s_out

# %%
#Function to find last max and mins
def prev_value(df_in,var_col,bool_col):
    df_in["prev_val"] = df_in.loc[df_in[bool_col],var_col]
    df_in["prev_val"] = df_in["prev_val"].fillna(method='ffill')
    df_in["prev_marker_date"] = df_in.loc[df_in[bool_col],"date"]
    df_in["prev_marker_date"] = df_in["prev_marker_date"].fillna(method='ffill')
    return (df_in["prev_val"],df_in["prev_marker_date"])

# %%
#Create separate columns for pos and neg values - allows for normalisation
def pos_neg_cols(s_in,gt_lt = "GT"):
    if gt_lt.upper() == "GT":
        bool_s = s_in >= 0
    elif gt_lt.upper() == "LT":
        bool_s = s_in <= 0
    df_out = s_in.to_frame()
    df_out["s_in"] = s_in
    df_out["val"] = abs(s_in[bool_s])
    val_s = df_out["val"].fillna(0,method=None)
    return (bool_s,val_s)

# %%
#Function for calculating the max and mins within a period
def max_min_period(s_in,periods:int=4):
    #Copy into max and min
    max_s = s_in.copy()
    min_s = s_in.copy()
    #Go through periods and mark where it is a new max or min
    for i in range(1,(periods+1)):
        #Calc max
        tmp_check_s = s_in.shift(i) >= max_s
        max_s[tmp_check_s] = s_in.shift(i)
        #Calc min
        tmp_check_s = s_in.shift(i) <= min_s
        min_s[tmp_check_s] = s_in.shift(i)
    #Normalise the series
    s_out = norm_s(s_in,max_s,min_s)
    return s_out

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(df_prices_w)
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'high': 8,
#  'low': 8,
#  'volume': 13,
#  'open': 8,
#  'close': 8,
#  'change': 21,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23,
#  'change_price': 21,
#  'per_change_price': 23,
#  'buy': 5,
#  'sell': 5,
#  'hold': 5}

# %%
#Create a single function to run each stock through feature creation
def create_features(df_in):  
    
    df_out = df_in.copy() 
    
    #Calc vol as proportion of previous n-rows
    df_out["prop_vol"] = calc_prop_of_prev(df_out["volume"].copy().astype("float"),6)

    #Get period-period changes
    for col in ['close','volume','macd','ema26']:
        df_out["{}_shift1".format(col)] = df_out[col].shift(1)
        df_out["change_{}_shift1".format(col)],df_out["per_change_{}_shift1".format(col)] = calc_changes(df_out[col].copy(),df_out["{}_shift1".format(col)].copy())
    
    #Compare close to the max/mins within 13, 26 and 52 periods
    df_out["close_13_norm"] = max_min_period(df_out["close"],13)
    df_out["close_26_norm"] = max_min_period(df_out["close"],26)
    df_out["close_52_norm"] = max_min_period(df_out["close"],52)
    
    #Compare macd to the max/mins within 13, 26 and 52 periods
    df_out["macd_line_13_norm"] = max_min_period(df_out["macd_line"],13)
    df_out["macd_line_26_norm"] = max_min_period(df_out["macd_line"],26)
    df_out["macd_line_52_norm"] = max_min_period(df_out["macd_line"],52)
        
    #Mark points of macd positive entry
    df_out["macd_pos_ent"] = pos_entry(df_out["macd"])
    df_out["macd_neg_ent"] = neg_entry(df_out["macd"])
    
    #Create max min columns
    def mk_cols_max_min(tmp_df,col,period:int=4):
        tmp_df["{}_min".format(col)] = flag_mins(tmp_df[col],period)
        tmp_df["{}_max".format(col)] = flag_maxs(tmp_df[col],period)
        
    #Find previous max and mins, then look at:
        # - how many positive or negative moves in a row there has been
        # - what the move since the last (n-1) max/min was
        # - what the gradient is since the last (n-1) max/min
        # - what the move since the first max/min was
        # - what the gradient since the first max/min was
    def mk_cols_prev_max_min(tmp_df,col,period:int=4):
        #GETTING THE MAX/MINS
        tmp_df["prev_max_{}".format(col)],tmp_df["prev_max_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_max".format(col)]].copy(),col,"{}_max".format(col))
        tmp_df["prev_min_{}".format(col)],tmp_df["prev_min_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_min".format(col)]].copy(),col,"{}_min".format(col))
        #Shift the max min columns by n periods to not leak future information
        tmp_df["prev_max_{}".format(col)] = tmp_df["prev_max_{}".format(col)].shift(period)
        tmp_df["prev_min_{}".format(col)] = tmp_df["prev_min_{}".format(col)].shift(period)
        tmp_df["prev_max_{}_date".format(col)] = tmp_df["prev_max_{}_date".format(col)].shift(period)
        tmp_df["prev_min_{}_date".format(col)] = tmp_df["prev_min_{}_date".format(col)].shift(period)
        def mk_prev_move_float(_s_in):
            _s_out = _s_in - _s_in.shift(1)
            _s_out[_s_out == 0] = np.nan
            _s_out = _s_out.fillna(method='ffill')
            return _s_out
        def mk_prev_move_date(_s_in,_periods:int=7):
            _s_out = _s_in - _s_in.shift(1)
            _s_check = pd.Series([np.floor(_x.days) for _x in _s_out])
            _s_check[_s_check == 0] = np.nan
            _s_check = _s_check.fillna(method='ffill')
            _s_check = [np.floor(_x/_periods) for _x in _s_check]
            return _s_check
        #Create features for the cumulative sequential count of max/mins in a certain direction
        def mk_move_cum(_s_in):
            _li_out = []
            _prev_x = None
            #Loop through each value in _s_in
            for _i,_x in _s_in.iteritems():
                if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
                    _li_out.append(0)
                else:
                    _prev_x = _prev_x if not np.isnan(_prev_x) else 0
                    if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                        _li_out.append(0)
                    else:
                        if _prev_x != _x: #if there has been a change in value from this and the previous value increment it by 1
                            if _x > 0: #for positive value increment by 1
                                _li_out.append(_li_out[-1] + 1)                                    
                            else: #for negative values increment by -1
                                _li_out.append(_li_out[-1] - 1)
                        else: #Otherwise just use the last added value
                            _li_out.append(_li_out[-1])
                _prev_x = _x
            return _li_out
        #Create features showing the value change since the first min/max
        def mk_long_prev_move_float(_ref_s,_val_s):
            _li_out = []
            _st_x = None
            _prev_x = None
            #Loop through each value in _s_in
            for _i,_x in _ref_s.iteritems():
                if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
                    _li_out.append(0)
                else:
                    _prev_x = _prev_x if not np.isnan(_prev_x) else 0
                    if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
                _prev_x = _x
            return _li_out
        def mk_long_prev_move_date(_ref_s,_val_s,_periods:int=7):
            _li_out = []
            _st_x = None
            _prev_x = None
            #Loop through each value in _s_in
            for _i,_x in _ref_s.iteritems():
                if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
                    _li_out.append(0)
                else:
                    _prev_x = _prev_x if not np.isnan(_prev_x) else 0
                    if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
                _prev_x = _x
            return _li_out
        #WHAT WAS THE MOVE SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_max_{}".format(col)])
        tmp_df['prev_max_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_max_{}_date".format(col)])        
        tmp_df['prev_min_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_min_{}".format(col)])
        tmp_df['prev_min_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_min_{}_date".format(col)])
        #WHAT IS THE GRADIENT SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_grad_{}'.format(col)] = tmp_df['prev_max_move_{}'.format(col)] / tmp_df['prev_max_date_move_{}'.format(col)]
        tmp_df['prev_min_grad_{}'.format(col)] = tmp_df['prev_min_move_{}'.format(col)] / tmp_df['prev_min_date_move_{}'.format(col)]
        #HOW MANY PROGRESSIVE MAX/MINS IN A ROW HAVE THERE BEEN - UP OR DOWN FOR BOTH OPTIONS
        tmp_df['max_move_cum_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)])
        tmp_df['min_move_cum_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)])
        #WHAT WAS THE MOVE SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)])
        tmp_df['long_prev_min_move_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)])
        #WHAT WAS THE TIMEDELTA SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)])
        tmp_df['long_prev_min_move_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)])
        #WHAT IS THE GRADIENT SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_max_grad_{}'.format(col)] = tmp_df['long_prev_max_move_{}'.format(col)] / tmp_df['long_prev_max_move_date_{}'.format(col)]
        tmp_df['long_max_grad_{}'.format(col)] = tmp_df['long_max_grad_{}'.format(col)].fillna(0)
        tmp_df['long_min_grad_{}'.format(col)] = tmp_df['long_prev_min_move_{}'.format(col)] / tmp_df['long_prev_min_move_date_{}'.format(col)]
        tmp_df['long_min_grad_{}'.format(col)] = tmp_df['long_min_grad_{}'.format(col)].fillna(0)
        
    #Calc the value changes and percentage changes of these movements
    def mk_cols_prev_max_min_change(tmp_df,col):
        tmp_df["max_change_{}".format(col)],tmp_df["max_per_change_{}".format(col)] = calc_changes(tmp_df[col].copy(),tmp_df["prev_max_{}".format(col)].copy())
        tmp_df["min_change_{}".format(col)],tmp_df["min_per_change_{}".format(col)] = calc_changes(tmp_df[col].copy(),tmp_df["prev_min_{}".format(col)].copy())
        
    #Mark date change since max and mins and convert to periods
    def mk_cols_prev_max_min_date_change(tmp_df,col,period:int=7):
        tmp_df["prev_max_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_max_{}_date".format(col)]
        tmp_df["prev_min_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_min_{}_date".format(col)]
        #Convert all to period changes
        tmp_df["prev_max_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_max_{}_date_change".format(col)]]
        tmp_df["prev_min_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_min_{}_date_change".format(col)]]
    
    #Run function for columns - high volatility
    for col in ['close','signal_line']:
        mk_cols_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
    #Run function for columns - low volatility
    for col in ['macd','ema26','macd_line']:
        mk_cols_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
    
    #Check for undefined
    df_out["no_signal"] = (df_out["buy"] == False) & (df_out["hold"] == False) & (df_out["sell"] == False)
    
    #Composite all singals into one column
    df_out["signal"] = None
    df_out.loc[df_out["buy"] == True,"signal"] = "buy"
    df_out.loc[df_out["hold"] == True,"signal"] = "hold"
    df_out.loc[df_out["sell"] == True,"signal"] = "sell"
    df_out.drop(columns=["buy","hold","sell"],inplace=True)
    print("SIGNAL COUNTS: \n{}".format(df_out["signal"].value_counts()))
    
    return df_out

# %%
#Define the columns for the output
out_cols = [
    #NON-NORMALISED COLS
    "ticker"
    ,"date"
    #NORMALISED COLS
    #Standard features
    ,"open"
    ,"close"
    ,"high"
    ,"low"
    ,"volume"
    ,"change_price"
    ,"per_change_price"
    ,"ema26"
    ,"macd"
    ,"signal_line"
    ,"macd_line"
    #Shifted features
    ,"close_shift1"
    ,"change_close_shift1"
    ,"volume_shift1"
    ,"change_volume_shift1"
    ,"ema26_shift1"
    ,"change_ema26_shift1"
    #change to periodic max mins
    ,"close_13_norm"
    ,"close_26_norm"
    ,"close_52_norm"
    ,"macd_line_13_norm"
    ,"macd_line_26_norm"
    ,"macd_line_52_norm"
]
#Append additional columns for key areas
for col in ['close','macd','ema26','signal_line','macd_line']:
    out_cols
    #Max/min flags
    out_cols.append("{}_max".format(col))    
    out_cols.append("{}_min".format(col))    
    #Prev max/min features
    out_cols.append("prev_max_{}".format(col))
    out_cols.append("prev_min_{}".format(col))
    #date changes
    out_cols.append("prev_max_{}_date_change".format(col))
    out_cols.append("prev_min_{}_date_change".format(col))
    #Min max change features
    out_cols.append("max_change_{}".format(col))
    out_cols.append("min_change_{}".format(col))
    #prev max/mins (n-1) - compared to previous
    out_cols.append('prev_max_grad_{}'.format(col))
    out_cols.append('prev_min_grad_{}'.format(col))
    #prev max/mins (n=0) - compared to first in this run
    out_cols.append('max_move_cum_{}'.format(col))
    out_cols.append('min_move_cum_{}'.format(col))
    out_cols.append('long_prev_max_move_date_{}'.format(col))
    out_cols.append('long_prev_min_move_date_{}'.format(col))
    out_cols.append('long_max_grad_{}'.format(col))
    out_cols.append('long_min_grad_{}'.format(col))
#Append signal
out_cols.append("signal")

# %%
#Then loop the tickers and combine these into one large dataset
hf_store_name = path+r'\all_hist_prices_w_ft_eng2_TMP.h5'
h_store = pd.HDFStore(hf_store_name)
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse["ticker"]:
# for tick in ['SBRY']: #TEMP
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print("\n{}".format(count))
        print("RUN FOR {}".format(tick))
        #Isolate this ticker
        this_tick_df = df_prices_w[df_prices_w["ticker"] == re.sub('[^a-zA-Z0-9\-]','',tick)].copy()
        print("shape before: {}".format(this_tick_df.shape))
        #Create the features
        this_tick_df = create_features(this_tick_df)
#         print(this_tick_df[out_cols])
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in out_cols:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
        print("shape after: {}".format(this_tick_df.shape))
        #Append this data to the group
        try:
            this_tick_df[out_cols].to_hdf(hf_store_name,key='weekly_data',append=True,min_itemsize=col_lens_tmp)
            print('ADDED TO {}'.format(hf_store_name))
        except Exception as e:
            print('ERROR READING TO FILE {}'.format(e))
    except Exception as e:
        h_store.close()
        errors.append({"ticker":tick,"Error":e})
        print('ERROR PROCESSING DATA {}'.format(e))
h_store.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1
# RUN FOR III
# shape before: (613, 18)
# SIGNAL COUNTS:
# hold    314
# sell    165
# buy     134
# Name: signal, dtype: int64
# shape after: (613, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 1 TIME -> 0:0:0
#
# 2
# RUN FOR ABF
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    583
# sell    256
# buy     206
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 2 TIME -> 0:0:3
#
# 3
# RUN FOR ADM
# shape before: (353, 18)
# SIGNAL COUNTS:
# hold    193
# buy      99
# sell     61
# Name: signal, dtype: int64
# shape after: (353, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 3 TIME -> 0:0:4
#
# 4
# RUN FOR AAL
# shape before: (1008, 18)
# SIGNAL COUNTS:
# hold    455
# sell    290
# buy     263
# Name: signal, dtype: int64
# shape after: (1008, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 4 TIME -> 0:0:2
#
# 5
# RUN FOR ANTO
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    458
# buy     300
# sell    287
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 5 TIME -> 0:0:5
#
# 6
# RUN FOR AHT
# shape before: (1023, 18)
# SIGNAL COUNTS:
# hold    479
# buy     300
# sell    244
# Name: signal, dtype: int64
# shape after: (1023, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 6 TIME -> 0:0:4
#
# 7
# RUN FOR AZN
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    557
# sell    287
# buy     201
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 7 TIME -> 0:0:4
#
# 8
# RUN FOR AUTO
# shape before: (238, 18)
# SIGNAL COUNTS:
# hold    114
# sell     67
# buy      57
# Name: signal, dtype: int64
# shape after: (238, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 8 TIME -> 0:0:5
#
# 9
# RUN FOR AVV
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    519
# buy     306
# sell    220
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 9 TIME -> 0:0:3
#
# 10
# RUN FOR BARC
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    510
# sell    346
# buy     189
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 10 TIME -> 0:0:4
#
# 11
# RUN FOR BDEV
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    458
# buy     299
# sell    288
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 11 TIME -> 0:0:3
#
# 12
# RUN FOR BKG
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    515
# buy     280
# sell    250
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 12 TIME -> 0:0:4
#
# 13
# RUN FOR BHP
# shape before: (524, 18)
# SIGNAL COUNTS:
# hold    244
# buy     153
# sell    127
# Name: signal, dtype: int64
# shape after: (524, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 13 TIME -> 0:0:4
#
# 14
# RUN FOR BATS
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    589
# sell    238
# buy     218
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 14 TIME -> 0:0:3
#
# 15
# RUN FOR BLND
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    572
# sell    278
# buy     195
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 15 TIME -> 0:0:4
#
# 16
# RUN FOR BT.A
# shape before: (0, 18)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 16 TIME -> 0:0:3
#
# 17
# RUN FOR BNZL
# shape before: (1042, 18)
# SIGNAL COUNTS:
# hold    615
# sell    237
# buy     190
# Name: signal, dtype: int64
# shape after: (1042, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 17 TIME -> 0:0:1
#
# 18
# RUN FOR BRBY
# shape before: (900, 18)
# SIGNAL COUNTS:
# hold    434
# buy     245
# sell    221
# Name: signal, dtype: int64
# shape after: (900, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 18 TIME -> 0:0:4
#
# 19
# RUN FOR CCL
# shape before: (989, 18)
# SIGNAL COUNTS:
# hold    464
# sell    280
# buy     245
# Name: signal, dtype: int64
# shape after: (989, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 19 TIME -> 0:0:3
#
# 20
# RUN FOR CNA
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    569
# sell    336
# buy     140
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 20 TIME -> 0:0:3
#
# 21
# RUN FOR CCH
# shape before: (336, 18)
# SIGNAL COUNTS:
# hold    171
# sell     96
# buy      69
# Name: signal, dtype: int64
# shape after: (336, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 21 TIME -> 0:0:3
#
# 22
# RUN FOR CPG
# shape before: (1031, 18)
# SIGNAL COUNTS:
# hold    577
# sell    246
# buy     208
# Name: signal, dtype: int64
# shape after: (1031, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 22 TIME -> 0:0:2
#
# 23
# RUN FOR CRH
# shape before: (1031, 18)
# SIGNAL COUNTS:
# hold    511
# sell    295
# buy     225
# Name: signal, dtype: int64
# shape after: (1031, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 23 TIME -> 0:0:4
#
# 24
# RUN FOR CRDA
# shape before: (1037, 18)
# SIGNAL COUNTS:
# hold    547
# buy     250
# sell    240
# Name: signal, dtype: int64
# shape after: (1037, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 24 TIME -> 0:0:5
#
# 25
# RUN FOR DCC
# shape before: (1027, 18)
# SIGNAL COUNTS:
# hold    542
# buy     250
# sell    235
# Name: signal, dtype: int64
# shape after: (1027, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 25 TIME -> 0:0:4
#
# 26
# RUN FOR DGE
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    692
# sell    216
# buy     137
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 26 TIME -> 0:0:4
#
# 27
# RUN FOR EVR
# shape before: (414, 18)
# SIGNAL COUNTS:
# hold    189
# sell    118
# buy     107
# Name: signal, dtype: int64
# shape after: (414, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 27 TIME -> 0:0:4
#
# 28
# RUN FOR EXPN
# shape before: (678, 18)
# SIGNAL COUNTS:
# hold    375
# sell    161
# buy     142
# Name: signal, dtype: int64
# shape after: (678, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 28 TIME -> 0:0:3
#
# 29
# RUN FOR FERG
# shape before: (1046, 18)
# SIGNAL COUNTS:
# hold    564
# sell    266
# buy     216
# Name: signal, dtype: int64
# shape after: (1046, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 29 TIME -> 0:0:3
#
# 30
# RUN FOR FRES
# shape before: (596, 18)
# SIGNAL COUNTS:
# hold    281
# sell    189
# buy     126
# Name: signal, dtype: int64
# shape after: (596, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 30 TIME -> 0:0:4
#
# 31
# RUN FOR GSK
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    612
# sell    297
# buy     136
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 31 TIME -> 0:0:3
#
# 32
# RUN FOR GLEN
# shape before: (438, 18)
# SIGNAL COUNTS:
# hold    186
# sell    154
# buy      98
# Name: signal, dtype: int64
# shape after: (438, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 32 TIME -> 0:0:4
#
# 33
# RUN FOR HLMA
# shape before: (1013, 18)
# SIGNAL COUNTS:
# hold    549
# buy     234
# sell    230
# Name: signal, dtype: int64
# shape after: (1013, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 33 TIME -> 0:0:3
#
# 34
# RUN FOR HIK
# shape before: (708, 18)
# SIGNAL COUNTS:
# hold    326
# buy     201
# sell    181
# Name: signal, dtype: int64
# shape after: (708, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 34 TIME -> 0:0:4
#
# 35
# RUN FOR HSX
# shape before: (1012, 18)
# SIGNAL COUNTS:
# hold    537
# sell    238
# buy     237
# Name: signal, dtype: int64
# shape after: (1012, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 35 TIME -> 0:0:4
#
# 36
# RUN FOR HSBA
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    692
# sell    339
# buy     225
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 36 TIME -> 0:0:4
#
# 37
# RUN FOR IMB
# shape before: (1180, 18)
# SIGNAL COUNTS:
# hold    641
# sell    289
# buy     250
# Name: signal, dtype: int64
# shape after: (1180, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 37 TIME -> 0:0:4
#
# 38
# RUN FOR INF
# shape before: (1066, 18)
# SIGNAL COUNTS:
# hold    549
# sell    275
# buy     242
# Name: signal, dtype: int64
# shape after: (1066, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 38 TIME -> 0:0:4
#
# 39
# RUN FOR IHG
# shape before: (844, 18)
# SIGNAL COUNTS:
# hold    434
# sell    211
# buy     199
# Name: signal, dtype: int64
# shape after: (844, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 39 TIME -> 0:0:4
#
# 40
# RUN FOR ITRK
# shape before: (884, 18)
# SIGNAL COUNTS:
# hold    455
# buy     232
# sell    197
# Name: signal, dtype: int64
# shape after: (884, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 40 TIME -> 0:0:3
#
# 41
# RUN FOR IAG
# shape before: (856, 18)
# SIGNAL COUNTS:
# hold    392
# buy     234
# sell    230
# Name: signal, dtype: int64
# shape after: (856, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 41 TIME -> 0:0:3
#
# 42
# RUN FOR ITV
# shape before: (1012, 18)
# SIGNAL COUNTS:
# hold    494
# sell    312
# buy     206
# Name: signal, dtype: int64
# shape after: (1012, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 42 TIME -> 0:0:3
#
# 43
# RUN FOR JMAT
# shape before: (1237, 18)
# SIGNAL COUNTS:
# hold    615
# sell    334
# buy     288
# Name: signal, dtype: int64
# shape after: (1237, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 43 TIME -> 0:0:3
#
# 44
# RUN FOR KGF
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    618
# sell    385
# buy     253
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 44 TIME -> 0:0:4
#
# 45
# RUN FOR LAND
# shape before: (1264, 18)
# SIGNAL COUNTS:
# hold    712
# sell    328
# buy     224
# Name: signal, dtype: int64
# shape after: (1264, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 45 TIME -> 0:0:4
#
# 46
# RUN FOR LGEN
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    664
# sell    320
# buy     272
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 46 TIME -> 0:0:4
#
# 47
# RUN FOR LLOY
# shape before: (1222, 18)
# SIGNAL COUNTS:
# hold    603
# sell    392
# buy     227
# Name: signal, dtype: int64
# shape after: (1222, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 47 TIME -> 0:0:4
#
# 48
# RUN FOR LSE
# shape before: (932, 18)
# SIGNAL COUNTS:
# hold    464
# buy     257
# sell    211
# Name: signal, dtype: int64
# shape after: (932, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 48 TIME -> 0:0:4
#
# 49
# RUN FOR MGGT
# shape before: (1475, 18)
# SIGNAL COUNTS:
# hold    749
# sell    376
# buy     350
# Name: signal, dtype: int64
# shape after: (1475, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 49 TIME -> 0:0:3
#
# 50
# RUN FOR MRO
# shape before: (812, 18)
# SIGNAL COUNTS:
# hold    390
# buy     217
# sell    205
# Name: signal, dtype: int64
# shape after: (812, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 50 TIME -> 0:0:4
#
# 51
# RUN FOR MNDI
# shape before: (614, 18)
# SIGNAL COUNTS:
# hold    307
# sell    156
# buy     151
# Name: signal, dtype: int64
# shape after: (614, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 51 TIME -> 0:0:3
#
# 52
# RUN FOR MRW
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    672
# sell    350
# buy     234
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 52 TIME -> 0:0:3
#
# 53
# RUN FOR NXT
# shape before: (1523, 18)
# SIGNAL COUNTS:
# hold    792
# buy     390
# sell    341
# Name: signal, dtype: int64
# shape after: (1523, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 53 TIME -> 0:0:4
#
# 54
# RUN FOR NMC
# shape before: (373, 18)
# SIGNAL COUNTS:
# hold    177
# buy     118
# sell     78
# Name: signal, dtype: int64
# shape after: (373, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 54 TIME -> 0:0:5
#
# 55
# RUN FOR OCDO
# shape before: (462, 18)
# SIGNAL COUNTS:
# hold    222
# sell    121
# buy     119
# Name: signal, dtype: int64
# shape after: (462, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 55 TIME -> 0:0:3
#
# 56
# RUN FOR PSON
# shape before: (1273, 18)
# SIGNAL COUNTS:
# hold    692
# sell    342
# buy     239
# Name: signal, dtype: int64
# shape after: (1273, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 56 TIME -> 0:0:3
#
# 57
# RUN FOR PSN
# shape before: (1463, 18)
# SIGNAL COUNTS:
# hold    690
# sell    396
# buy     377
# Name: signal, dtype: int64
# shape after: (1463, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 57 TIME -> 0:0:4
#
# 58
# RUN FOR PHNX
# shape before: (495, 18)
# SIGNAL COUNTS:
# hold    290
# sell    138
# buy      67
# Name: signal, dtype: int64
# shape after: (495, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 58 TIME -> 0:0:5
#
# 59
# RUN FOR POLY
# shape before: (396, 18)
# SIGNAL COUNTS:
# hold    178
# sell    128
# buy      90
# Name: signal, dtype: int64
# shape after: (396, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 59 TIME -> 0:0:3
#
# 60
# RUN FOR PRU
# shape before: (1502, 18)
# SIGNAL COUNTS:
# hold    748
# sell    406
# buy     348
# Name: signal, dtype: int64
# shape after: (1502, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 60 TIME -> 0:0:3
#
# 61
# RUN FOR RDSA
# shape before: (257, 18)
# SIGNAL COUNTS:
# hold    157
# sell     78
# buy      22
# Name: signal, dtype: int64
# shape after: (257, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 61 TIME -> 0:0:4
#
# 62
# RUN FOR RDSB
# shape before: (993, 18)
# SIGNAL COUNTS:
# hold    531
# sell    300
# buy     162
# Name: signal, dtype: int64
# shape after: (993, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 62 TIME -> 0:0:2
#
# 63
# RUN FOR REL
# shape before: (1273, 18)
# SIGNAL COUNTS:
# hold    730
# sell    301
# buy     242
# Name: signal, dtype: int64
# shape after: (1273, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 63 TIME -> 0:0:4
#
# 64
# RUN FOR RTO
# shape before: (1241, 18)
# SIGNAL COUNTS:
# hold    635
# sell    314
# buy     292
# Name: signal, dtype: int64
# shape after: (1241, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 64 TIME -> 0:0:4
#
# 65
# RUN FOR RMV
# shape before: (690, 18)
# SIGNAL COUNTS:
# hold    323
# buy     209
# sell    158
# Name: signal, dtype: int64
# shape after: (690, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 65 TIME -> 0:0:4
#
# 66
# RUN FOR RIO
# shape before: (1526, 18)
# SIGNAL COUNTS:
# hold    722
# sell    422
# buy     382
# Name: signal, dtype: int64
# shape after: (1526, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 66 TIME -> 0:0:3
#
# 67
# RUN FOR RBS
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    616
# sell    381
# buy     259
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 67 TIME -> 0:0:4
#
# 68
# RUN FOR RSA
# shape before: (1243, 18)
# SIGNAL COUNTS:
# hold    659
# sell    345
# buy     239
# Name: signal, dtype: int64
# shape after: (1243, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 68 TIME -> 0:0:5
#
# 69
# RUN FOR SGE
# shape before: (1251, 18)
# SIGNAL COUNTS:
# hold    628
# buy     321
# sell    302
# Name: signal, dtype: int64
# shape after: (1251, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 69 TIME -> 0:0:6
#
# 70
# RUN FOR SBRY
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    671
# sell    369
# buy     216
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 70 TIME -> 0:0:5
#
# 71
# RUN FOR SDR
# shape before: (1246, 18)
# SIGNAL COUNTS:
# hold    591
# sell    359
# buy     296
# Name: signal, dtype: int64
# shape after: (1246, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 71 TIME -> 0:0:4
#
# 72
# RUN FOR SMT
# shape before: (136, 18)
# SIGNAL COUNTS:
# hold    86
# sell    27
# buy     23
# Name: signal, dtype: int64
# shape after: (136, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 72 TIME -> 0:0:4
#
# 73
# RUN FOR SGRO
# shape before: (1534, 18)
# SIGNAL COUNTS:
# hold    817
# sell    417
# buy     300
# Name: signal, dtype: int64
# shape after: (1534, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 73 TIME -> 0:0:2
#
# 74
# RUN FOR SVT
# shape before: (1241, 18)
# SIGNAL COUNTS:
# hold    743
# sell    310
# buy     188
# Name: signal, dtype: int64
# shape after: (1241, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 74 TIME -> 0:0:5
#
# 75
# RUN FOR SMDS
# shape before: (1424, 18)
# SIGNAL COUNTS:
# hold    734
# sell    372
# buy     318
# Name: signal, dtype: int64
# shape after: (1424, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 75 TIME -> 0:0:4
#
# 76
# RUN FOR SMIN
# shape before: (1486, 18)
# SIGNAL COUNTS:
# hold    796
# sell    379
# buy     311
# Name: signal, dtype: int64
# shape after: (1486, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 76 TIME -> 0:0:4
#
# 77
# RUN FOR SKG
# shape before: (637, 18)
# SIGNAL COUNTS:
# hold    287
# sell    177
# buy     173
# Name: signal, dtype: int64
# shape after: (637, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 77 TIME -> 0:0:5
#
# 78
# RUN FOR SPX
# shape before: (1454, 18)
# SIGNAL COUNTS:
# hold    796
# buy     359
# sell    299
# Name: signal, dtype: int64
# shape after: (1454, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 78 TIME -> 0:0:3
#
# 79
# RUN FOR SSE
# shape before: (1273, 18)
# SIGNAL COUNTS:
# hold    778
# sell    327
# buy     168
# Name: signal, dtype: int64
# shape after: (1273, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 79 TIME -> 0:0:4
#
# 80
# RUN FOR STJ
# shape before: (1463, 18)
# SIGNAL COUNTS:
# hold    713
# sell    389
# buy     361
# Name: signal, dtype: int64
# shape after: (1463, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 80 TIME -> 0:0:4
#
# 81
# RUN FOR STAN
# shape before: (1527, 18)
# SIGNAL COUNTS:
# hold    705
# sell    439
# buy     383
# Name: signal, dtype: int64
# shape after: (1527, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 81 TIME -> 0:0:5
#
# 82
# RUN FOR SLA
# shape before: (672, 18)
# SIGNAL COUNTS:
# hold    315
# sell    220
# buy     137
# Name: signal, dtype: int64
# shape after: (672, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 82 TIME -> 0:0:5
#
# 83
# RUN FOR TSCO
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    706
# sell    305
# buy     245
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 83 TIME -> 0:0:3
#
# 84
# RUN FOR TUI
# shape before: (251, 18)
# SIGNAL COUNTS:
# hold    137
# sell     71
# buy      43
# Name: signal, dtype: int64
# shape after: (251, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 84 TIME -> 0:0:5
#
# 85
# RUN FOR ULVR
# shape before: (1026, 18)
# SIGNAL COUNTS:
# hold    613
# sell    238
# buy     175
# Name: signal, dtype: int64
# shape after: (1026, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 85 TIME -> 0:0:3
#
# 86
# RUN FOR VOD
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    562
# sell    309
# buy     174
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 86 TIME -> 0:0:4
#
# 87
# RUN FOR WTB
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    524
# sell    268
# buy     253
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 87 TIME -> 0:0:4
#
# 88
# RUN FOR WPP
# shape before: (682, 18)
# SIGNAL COUNTS:
# hold    352
# sell    193
# buy     137
# Name: signal, dtype: int64
# shape after: (682, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 88 TIME -> 0:0:4
#
# 89
# RUN FOR 3IN
# shape before: (586, 18)
# SIGNAL COUNTS:
# hold    482
# sell     60
# buy      44
# Name: signal, dtype: int64
# shape after: (586, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 89 TIME -> 0:0:3
#
# 90
# RUN FOR FOUR
# shape before: (1036, 18)
# SIGNAL COUNTS:
# hold    547
# buy     249
# sell    240
# Name: signal, dtype: int64
# shape after: (1036, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 90 TIME -> 0:0:3
#
# 91
# RUN FOR ASL
# shape before: (603, 18)
# SIGNAL COUNTS:
# hold    358
# sell    131
# buy     114
# Name: signal, dtype: int64
# shape after: (603, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 91 TIME -> 0:0:4
#
# 92
# RUN FOR AGK
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    476
# sell    297
# buy     272
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 92 TIME -> 0:0:3
#
# 93
# RUN FOR AJB
# shape before: (44, 18)
# SIGNAL COUNTS:
# buy     22
# hold    16
# sell     6
# Name: signal, dtype: int64
# shape after: (44, 168)
# ERROR READING TO FILE cannot match existing table structure for [change_close_shift1,change_ema26_shift1,change_volume_shift1,close_13_norm,close_26_norm,close_52_norm,close_shift1,ema26_shift1,long_max_grad_close,long_max_grad_ema26,long_max_grad_macd,long_max_grad_macd_line,long_max_grad_signal_line,long_min_grad_close,long_min_grad_ema26,long_min_grad_macd,long_min_grad_macd_line,long_min_grad_signal_line,long_prev_max_move_date_close,long_prev_max_move_date_ema26,long_prev_max_move_date_macd,long_prev_max_move_date_macd_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_close,long_prev_min_move_date_ema26,long_prev_min_move_date_macd,long_prev_min_move_date_macd_line,long_prev_min_move_date_signal_line,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,max_change_close,max_change_ema26,max_change_macd,max_change_macd_line,max_change_signal_line,min_change_close,min_change_ema26,min_change_macd,min_change_macd_line,min_change_signal_line,prev_max_close,prev_max_close_date_change,prev_max_ema26,prev_max_ema26_date_change,prev_max_grad_close,prev_max_grad_ema26,prev_max_grad_macd,prev_max_grad_macd_line,prev_max_grad_signal_line,prev_max_macd,prev_max_macd_date_change,prev_max_macd_line,prev_max_macd_line_date_change,prev_max_signal_line,prev_max_signal_line_date_change,prev_min_close,prev_min_close_date_change,prev_min_ema26,prev_min_ema26_date_change,prev_min_grad_close,prev_min_grad_ema26,prev_min_grad_macd,prev_min_grad_macd_line,prev_min_grad_signal_line,prev_min_macd,prev_min_macd_date_change,prev_min_macd_line,prev_min_macd_line_date_change,prev_min_signal_line,prev_min_signal_line_date_change,volume_shift1] on appending data
# LAP 93 TIME -> 0:0:4
#
# 94
# RUN FOR ATST
# shape before: (614, 18)
# SIGNAL COUNTS:
# hold    447
# sell    109
# buy      58
# Name: signal, dtype: int64
# shape after: (614, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 94 TIME -> 0:0:1
#
# 95
# RUN FOR APAX
# shape before: (216, 18)
# SIGNAL COUNTS:
# hold    139
# sell     52
# buy      25
# Name: signal, dtype: int64
# shape after: (216, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 95 TIME -> 0:0:3
#
# 96
# RUN FOR ASCL
# shape before: (191, 18)
# SIGNAL COUNTS:
# hold    90
# buy     55
# sell    46
# Name: signal, dtype: int64
# shape after: (191, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 96 TIME -> 0:0:3
#
# 97
# RUN FOR ASHM
# shape before: (678, 18)
# SIGNAL COUNTS:
# hold    329
# sell    188
# buy     161
# Name: signal, dtype: int64
# shape after: (678, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 97 TIME -> 0:0:3
#
# 98
# RUN FOR AGR
# shape before: (827, 18)
# SIGNAL COUNTS:
# hold    513
# sell    180
# buy     134
# Name: signal, dtype: int64
# shape after: (827, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 98 TIME -> 0:0:4
#
# 99
# RUN FOR AML
# shape before: (53, 18)
# SIGNAL COUNTS:
# hold    30
# sell    23
# Name: signal, dtype: int64
# shape after: (53, 168)
# ERROR READING TO FILE cannot match existing table structure for [change_close_shift1,change_ema26_shift1,change_volume_shift1,close_13_norm,close_26_norm,close_52_norm,close_shift1,ema26_shift1,long_max_grad_close,long_max_grad_ema26,long_max_grad_macd,long_max_grad_macd_line,long_max_grad_signal_line,long_min_grad_close,long_min_grad_ema26,long_min_grad_macd,long_min_grad_macd_line,long_min_grad_signal_line,long_prev_max_move_date_close,long_prev_max_move_date_ema26,long_prev_max_move_date_macd,long_prev_max_move_date_macd_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_close,long_prev_min_move_date_ema26,long_prev_min_move_date_macd,long_prev_min_move_date_macd_line,long_prev_min_move_date_signal_line,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,max_change_close,max_change_ema26,max_change_macd,max_change_macd_line,max_change_signal_line,min_change_close,min_change_ema26,min_change_macd,min_change_macd_line,min_change_signal_line,prev_max_close,prev_max_close_date_change,prev_max_ema26,prev_max_ema26_date_change,prev_max_grad_close,prev_max_grad_ema26,prev_max_grad_macd,prev_max_grad_macd_line,prev_max_grad_signal_line,prev_max_macd,prev_max_macd_date_change,prev_max_macd_line,prev_max_macd_line_date_change,prev_max_signal_line,prev_max_signal_line_date_change,prev_min_close,prev_min_close_date_change,prev_min_ema26,prev_min_ema26_date_change,prev_min_grad_close,prev_min_grad_ema26,prev_min_grad_macd,prev_min_grad_macd_line,prev_min_grad_signal_line,prev_min_macd,prev_min_macd_date_change,prev_min_macd_line,prev_min_macd_line_date_change,prev_min_signal_line,prev_min_signal_line_date_change,volume_shift1] on appending data
# LAP 99 TIME -> 0:0:4
#
# 100
# RUN FOR AVST
# shape before: (74, 18)
# SIGNAL COUNTS:
# hold    32
# buy     25
# sell    17
# Name: signal, dtype: int64
# shape after: (74, 168)
# ERROR READING TO FILE cannot match existing table structure for [change_close_shift1,change_ema26_shift1,change_volume_shift1,close_13_norm,close_26_norm,close_52_norm,close_shift1,ema26_shift1,long_max_grad_close,long_max_grad_ema26,long_max_grad_macd,long_max_grad_macd_line,long_max_grad_signal_line,long_min_grad_close,long_min_grad_ema26,long_min_grad_macd,long_min_grad_macd_line,long_min_grad_signal_line,long_prev_max_move_date_close,long_prev_max_move_date_ema26,long_prev_max_move_date_macd,long_prev_max_move_date_macd_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_close,long_prev_min_move_date_ema26,long_prev_min_move_date_macd,long_prev_min_move_date_macd_line,long_prev_min_move_date_signal_line,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,max_change_close,max_change_ema26,max_change_macd,max_change_macd_line,max_change_signal_line,min_change_close,min_change_ema26,min_change_macd,min_change_macd_line,min_change_signal_line,prev_max_close,prev_max_close_date_change,prev_max_ema26,prev_max_ema26_date_change,prev_max_grad_close,prev_max_grad_ema26,prev_max_grad_macd,prev_max_grad_macd_line,prev_max_grad_signal_line,prev_max_macd,prev_max_macd_date_change,prev_max_macd_line,prev_max_macd_line_date_change,prev_max_signal_line,prev_max_signal_line_date_change,prev_min_close,prev_min_close_date_change,prev_min_ema26,prev_min_ema26_date_change,prev_min_grad_close,prev_min_grad_ema26,prev_min_grad_macd,prev_min_grad_macd_line,prev_min_grad_signal_line,prev_min_macd,prev_min_macd_date_change,prev_min_macd_line,prev_min_macd_line_date_change,prev_min_signal_line,prev_min_signal_line_date_change,volume_shift1] on appending data
# LAP 100 TIME -> 0:0:1
#
# 101
# RUN FOR BME
# shape before: (278, 18)
# SIGNAL COUNTS:
# hold    131
# sell     85
# buy      62
# Name: signal, dtype: int64
# shape after: (278, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 101 TIME -> 0:0:1
#
# 102
# RUN FOR BAB
# shape before: (1025, 18)
# SIGNAL COUNTS:
# hold    524
# sell    271
# buy     230
# Name: signal, dtype: int64
# shape after: (1025, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 102 TIME -> 0:0:3
#
# 103
# RUN FOR BGFD
# shape before: (606, 18)
# SIGNAL COUNTS:
# hold    336
# buy     145
# sell    125
# Name: signal, dtype: int64
# shape after: (606, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 103 TIME -> 0:0:4
#
# 104
# RUN FOR BAKK
# shape before: (99, 18)
# SIGNAL COUNTS:
# hold    49
# sell    35
# buy     15
# Name: signal, dtype: int64
# shape after: (99, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 104 TIME -> 0:0:3
#
# 105
# RUN FOR BBY
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    511
# sell    308
# buy     226
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 105 TIME -> 0:0:3
#
# 106
# RUN FOR BGEO
# shape before: (618, 18)
# SIGNAL COUNTS:
# hold    276
# buy     171
# sell    171
# Name: signal, dtype: int64
# shape after: (618, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 106 TIME -> 0:0:4
#
# 107
# RUN FOR BNKR
# shape before: (614, 18)
# SIGNAL COUNTS:
# hold    442
# sell    108
# buy      64
# Name: signal, dtype: int64
# shape after: (614, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 107 TIME -> 0:0:3
#
# 108
# RUN FOR BAG
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    610
# sell    236
# buy     199
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 108 TIME -> 0:0:3
#
# 109
# RUN FOR BBA
# shape before: (1045, 18)
# SIGNAL COUNTS:
# hold    536
# sell    292
# buy     217
# Name: signal, dtype: int64
# shape after: (1045, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 109 TIME -> 0:0:4
#
# 110
# RUN FOR BBGI
# shape before: (398, 18)
# SIGNAL COUNTS:
# hold    365
# sell     25
# buy       8
# Name: signal, dtype: int64
# shape after: (398, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 110 TIME -> 0:0:4
#
# 111
# RUN FOR BCA
# shape before: (247, 18)
# SIGNAL COUNTS:
# hold    131
# sell     69
# buy      47
# Name: signal, dtype: int64
# shape after: (247, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 111 TIME -> 0:0:3
#
# 112
# RUN FOR BEZ
# shape before: (161, 18)
# SIGNAL COUNTS:
# hold    91
# sell    36
# buy     34
# Name: signal, dtype: int64
# shape after: (161, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 112 TIME -> 0:0:3
#
# 113
# RUN FOR BWY
# shape before: (1433, 18)
# SIGNAL COUNTS:
# hold    674
# buy     381
# sell    378
# Name: signal, dtype: int64
# shape after: (1433, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 113 TIME -> 0:0:3
#
# 114
# RUN FOR BYG
# shape before: (994, 18)
# SIGNAL COUNTS:
# hold    506
# sell    253
# buy     235
# Name: signal, dtype: int64
# shape after: (994, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 114 TIME -> 0:0:5
#
# 115
# RUN FOR BRSC
# shape before: (274, 18)
# SIGNAL COUNTS:
# hold    146
# buy      79
# sell     49
# Name: signal, dtype: int64
# shape after: (274, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 115 TIME -> 0:0:4
#
# 116
# RUN FOR BGSC
# shape before: (594, 18)
# SIGNAL COUNTS:
# hold    403
# sell    102
# buy      89
# Name: signal, dtype: int64
# shape after: (594, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 116 TIME -> 0:0:3
#
# 117
# RUN FOR BOY
# shape before: (1247, 18)
# SIGNAL COUNTS:
# hold    580
# sell    345
# buy     322
# Name: signal, dtype: int64
# shape after: (1247, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 117 TIME -> 0:0:4
#
# 118
# RUN FOR BVS
# shape before: (1114, 18)
# SIGNAL COUNTS:
# hold    526
# sell    303
# buy     285
# Name: signal, dtype: int64
# shape after: (1114, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 118 TIME -> 0:0:5
#
# 119
# RUN FOR BRW
# shape before: (1124, 18)
# SIGNAL COUNTS:
# hold    540
# buy     297
# sell    287
# Name: signal, dtype: int64
# shape after: (1124, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 119 TIME -> 0:0:4
#
# 120
# RUN FOR BVIC
# shape before: (703, 18)
# SIGNAL COUNTS:
# hold    352
# buy     180
# sell    171
# Name: signal, dtype: int64
# shape after: (703, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 120 TIME -> 0:0:4
#
# 121
# RUN FOR CNE
# shape before: (1400, 18)
# SIGNAL COUNTS:
# hold    763
# sell    365
# buy     272
# Name: signal, dtype: int64
# shape after: (1400, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 121 TIME -> 0:0:4
#
# 122
# RUN FOR CLDN
# shape before: (591, 18)
# SIGNAL COUNTS:
# hold    399
# sell    134
# buy      58
# Name: signal, dtype: int64
# shape after: (591, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 122 TIME -> 0:0:5
#
# 123
# RUN FOR CAPC
# shape before: (472, 18)
# SIGNAL COUNTS:
# hold    241
# sell    125
# buy     106
# Name: signal, dtype: int64
# shape after: (472, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 123 TIME -> 0:0:4
#
# 124
# RUN FOR CPI
# shape before: (1302, 18)
# SIGNAL COUNTS:
# hold    705
# sell    303
# buy     294
# Name: signal, dtype: int64
# shape after: (1302, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 124 TIME -> 0:0:3
#
# 125
# RUN FOR CARD
# shape before: (282, 18)
# SIGNAL COUNTS:
# hold    134
# sell     83
# buy      65
# Name: signal, dtype: int64
# shape after: (282, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 125 TIME -> 0:0:5
#
# 126
# RUN FOR CEY
# shape before: (909, 18)
# SIGNAL COUNTS:
# hold    462
# sell    227
# buy     220
# Name: signal, dtype: int64
# shape after: (909, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 126 TIME -> 0:0:3
#
# 127
# RUN FOR CCFS
# shape before: (106, 18)
# SIGNAL COUNTS:
# hold    48
# buy     33
# sell    25
# Name: signal, dtype: int64
# shape after: (106, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 127 TIME -> 0:0:4
#
# 128
# RUN FOR CINE
# shape before: (631, 18)
# SIGNAL COUNTS:
# hold    313
# sell    169
# buy     149
# Name: signal, dtype: int64
# shape after: (631, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 128 TIME -> 0:0:3
#
# 129
# RUN FOR CTY
# shape before: (595, 18)
# SIGNAL COUNTS:
# hold    451
# sell    111
# buy      33
# Name: signal, dtype: int64
# shape after: (595, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 129 TIME -> 0:0:4
#
# 130
# RUN FOR CKN
# shape before: (1304, 18)
# SIGNAL COUNTS:
# hold    642
# buy     355
# sell    307
# Name: signal, dtype: int64
# shape after: (1304, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 130 TIME -> 0:0:4
#
# 131
# RUN FOR CBG
# shape before: (1239, 18)
# SIGNAL COUNTS:
# hold    626
# sell    339
# buy     274
# Name: signal, dtype: int64
# shape after: (1239, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 131 TIME -> 0:0:5
#
# 132
# RUN FOR CLI
# shape before: (1275, 18)
# SIGNAL COUNTS:
# hold    711
# buy     284
# sell    280
# Name: signal, dtype: int64
# shape after: (1275, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 132 TIME -> 0:0:5
#
# 133
# RUN FOR COA
# shape before: (1372, 18)
# SIGNAL COUNTS:
# hold    786
# sell    359
# buy     227
# Name: signal, dtype: int64
# shape after: (1372, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 133 TIME -> 0:0:5
#
# 134
# RUN FOR COB
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    637
# sell    340
# buy     279
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 134 TIME -> 0:0:5
#
# 135
# RUN FOR CCC
# shape before: (1097, 18)
# SIGNAL COUNTS:
# hold    522
# sell    311
# buy     264
# Name: signal, dtype: int64
# shape after: (1097, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 135 TIME -> 0:0:5
#
# 136
# RUN FOR GLO
# shape before: (100, 18)
# SIGNAL COUNTS:
# hold    49
# sell    38
# buy     13
# Name: signal, dtype: int64
# shape after: (100, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 136 TIME -> 0:0:5
#
# 137
# RUN FOR CTEC
# shape before: (154, 18)
# SIGNAL COUNTS:
# hold    67
# sell    45
# buy     42
# Name: signal, dtype: int64
# shape after: (154, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 137 TIME -> 0:0:3
#
# 138
# RUN FOR CSP
# shape before: (410, 18)
# SIGNAL COUNTS:
# hold    217
# sell    103
# buy      90
# Name: signal, dtype: int64
# shape after: (410, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 138 TIME -> 0:0:3
#
# 139
# RUN FOR CWK
# shape before: (1112, 18)
# SIGNAL COUNTS:
# hold    603
# buy     271
# sell    238
# Name: signal, dtype: int64
# shape after: (1112, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 139 TIME -> 0:0:4
#
# 140
# RUN FOR CRST
# shape before: (328, 18)
# SIGNAL COUNTS:
# hold    153
# sell    103
# buy      72
# Name: signal, dtype: int64
# shape after: (328, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 140 TIME -> 0:0:5
#
# 141
# RUN FOR CYBG
# shape before: (192, 18)
# SIGNAL COUNTS:
# hold    105
# sell     48
# buy      39
# Name: signal, dtype: int64
# shape after: (192, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 141 TIME -> 0:0:4
#
# 142
# RUN FOR DJAN
# shape before: (1122, 18)
# SIGNAL COUNTS:
# hold    606
# sell    269
# buy     247
# Name: signal, dtype: int64
# shape after: (1122, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 142 TIME -> 0:0:4
#
# 143
# RUN FOR DPH
# shape before: (954, 18)
# SIGNAL COUNTS:
# hold    513
# buy     237
# sell    204
# Name: signal, dtype: int64
# shape after: (954, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 143 TIME -> 0:0:6
#
# 144
# RUN FOR DLN
# shape before: (1193, 18)
# SIGNAL COUNTS:
# hold    657
# buy     283
# sell    253
# Name: signal, dtype: int64
# shape after: (1193, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 144 TIME -> 0:0:5
#
# 145
# RUN FOR DPLM
# shape before: (1479, 18)
# SIGNAL COUNTS:
# hold    777
# buy     365
# sell    337
# Name: signal, dtype: int64
# shape after: (1479, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 145 TIME -> 0:0:5
#
# 146
# RUN FOR DLG
# shape before: (346, 18)
# SIGNAL COUNTS:
# hold    192
# sell     89
# buy      65
# Name: signal, dtype: int64
# shape after: (346, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 146 TIME -> 0:0:5
#
# 147
# RUN FOR DOM
# shape before: (1018, 18)
# SIGNAL COUNTS:
# hold    491
# buy     286
# sell    241
# Name: signal, dtype: int64
# shape after: (1018, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 147 TIME -> 0:0:3
#
# 148
# RUN FOR DRX
# shape before: (702, 18)
# SIGNAL COUNTS:
# hold    339
# sell    221
# buy     142
# Name: signal, dtype: int64
# shape after: (702, 168)
# ...
# shape before: (585, 18)
# SIGNAL COUNTS:
# hold    385
# sell    124
# buy      76
# Name: signal, dtype: int64
# shape after: (585, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 280 TIME -> 0:0:4
#
# 281
# RUN FOR SCIN
# shape before: (586, 18)
# SIGNAL COUNTS:
# hold    406
# sell    121
# buy      59
# Name: signal, dtype: int64
# shape after: (586, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 281 TIME -> 0:0:3
#
# 282
# RUN FOR SNR
# shape before: (1428, 18)
# SIGNAL COUNTS:
# hold    675
# sell    395
# buy     358
# Name: signal, dtype: int64
# shape after: (1428, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 282 TIME -> 0:0:3
#
# 283
# RUN FOR SEQI
# shape before: (230, 18)
# SIGNAL COUNTS:
# hold    211
# sell     19
# Name: signal, dtype: int64
# shape after: (230, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 283 TIME -> 0:0:5
#
# 284
# RUN FOR SRP
# shape before: (1285, 18)
# SIGNAL COUNTS:
# hold    691
# sell    306
# buy     288
# Name: signal, dtype: int64
# shape after: (1285, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 284 TIME -> 0:0:3
#
# 285
# RUN FOR SHB
# shape before: (1152, 18)
# SIGNAL COUNTS:
# hold    667
# sell    256
# buy     229
# Name: signal, dtype: int64
# shape after: (1152, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 285 TIME -> 0:0:4
#
# 286
# RUN FOR SHI
# shape before: (1318, 18)
# SIGNAL COUNTS:
# hold    615
# sell    383
# buy     320
# Name: signal, dtype: int64
# shape after: (1318, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 286 TIME -> 0:0:4
#
# 287
# RUN FOR SXX
# shape before: (659, 18)
# SIGNAL COUNTS:
# hold    353
# sell    185
# buy     121
# Name: signal, dtype: int64
# shape after: (659, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 287 TIME -> 0:0:4
#
# 288
# RUN FOR SRE
# shape before: (623, 18)
# SIGNAL COUNTS:
# hold    369
# sell    148
# buy     106
# Name: signal, dtype: int64
# shape after: (623, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 288 TIME -> 0:0:3
#
# 289
# RUN FOR SSON
# shape before: (41, 18)
# SIGNAL COUNTS:
# hold    29
# sell     7
# buy      5
# Name: signal, dtype: int64
# shape after: (41, 168)
# ERROR READING TO FILE cannot match existing table structure for [change_close_shift1,change_ema26_shift1,change_volume_shift1,close_13_norm,close_26_norm,close_52_norm,close_shift1,ema26_shift1,long_max_grad_close,long_max_grad_ema26,long_max_grad_macd,long_max_grad_macd_line,long_max_grad_signal_line,long_min_grad_close,long_min_grad_ema26,long_min_grad_macd,long_min_grad_macd_line,long_min_grad_signal_line,long_prev_max_move_date_close,long_prev_max_move_date_ema26,long_prev_max_move_date_macd,long_prev_max_move_date_macd_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_close,long_prev_min_move_date_ema26,long_prev_min_move_date_macd,long_prev_min_move_date_macd_line,long_prev_min_move_date_signal_line,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,max_change_close,max_change_ema26,max_change_macd,max_change_macd_line,max_change_signal_line,min_change_close,min_change_ema26,min_change_macd,min_change_macd_line,min_change_signal_line,prev_max_close,prev_max_close_date_change,prev_max_ema26,prev_max_ema26_date_change,prev_max_grad_close,prev_max_grad_ema26,prev_max_grad_macd,prev_max_grad_macd_line,prev_max_grad_signal_line,prev_max_macd,prev_max_macd_date_change,prev_max_macd_line,prev_max_macd_line_date_change,prev_max_signal_line,prev_max_signal_line_date_change,prev_min_close,prev_min_close_date_change,prev_min_ema26,prev_min_ema26_date_change,prev_min_grad_close,prev_min_grad_ema26,prev_min_grad_macd,prev_min_grad_macd_line,prev_min_grad_signal_line,prev_min_macd,prev_min_macd_date_change,prev_min_macd_line,prev_min_macd_line_date_change,prev_min_signal_line,prev_min_signal_line_date_change,volume_shift1] on appending data
# LAP 289 TIME -> 0:0:3
#
# 290
# RUN FOR SCT
# shape before: (204, 18)
# SIGNAL COUNTS:
# hold    80
# buy     78
# sell    46
# Name: signal, dtype: int64
# shape after: (204, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 290 TIME -> 0:0:1
#
# 291
# RUN FOR SOPH
# shape before: (224, 18)
# SIGNAL COUNTS:
# hold    121
# sell     55
# buy      48
# Name: signal, dtype: int64
# shape after: (224, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 291 TIME -> 0:0:3
#
# 292
# RUN FOR SXS
# shape before: (1478, 18)
# SIGNAL COUNTS:
# hold    717
# buy     391
# sell    370
# Name: signal, dtype: int64
# shape after: (1478, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 292 TIME -> 0:0:3
#
# 293
# RUN FOR SPT
# shape before: (1255, 18)
# SIGNAL COUNTS:
# hold    625
# sell    324
# buy     306
# Name: signal, dtype: int64
# shape after: (1255, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 293 TIME -> 0:0:5
#
# 294
# RUN FOR SPD
# shape before: (639, 18)
# SIGNAL COUNTS:
# hold    295
# sell    175
# buy     169
# Name: signal, dtype: int64
# shape after: (639, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 294 TIME -> 0:0:5
#
# 295
# RUN FOR SSPG
# shape before: (274, 18)
# SIGNAL COUNTS:
# hold    155
# buy      72
# sell     47
# Name: signal, dtype: int64
# shape after: (274, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 295 TIME -> 0:0:4
#
# 296
# RUN FOR SMP
# shape before: (1423, 18)
# SIGNAL COUNTS:
# hold    790
# sell    330
# buy     303
# Name: signal, dtype: int64
# shape after: (1423, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 296 TIME -> 0:0:3
#
# 297
# RUN FOR SGC
# shape before: (1151, 18)
# SIGNAL COUNTS:
# hold    544
# buy     310
# sell    297
# Name: signal, dtype: int64
# shape after: (1151, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 297 TIME -> 0:0:5
#
# 298
# RUN FOR SYNC
# shape before: (335, 18)
# SIGNAL COUNTS:
# hold    253
# buy      43
# sell     39
# Name: signal, dtype: int64
# shape after: (335, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 298 TIME -> 0:0:4
#
# 299
# RUN FOR SYNT
# shape before: (1453, 18)
# SIGNAL COUNTS:
# hold    740
# sell    394
# buy     319
# Name: signal, dtype: int64
# shape after: (1453, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 299 TIME -> 0:0:3
#
# 300
# RUN FOR TALK
# shape before: (479, 18)
# SIGNAL COUNTS:
# hold    219
# sell    145
# buy     115
# Name: signal, dtype: int64
# shape after: (479, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 300 TIME -> 0:0:5
#
# 301
# RUN FOR TATE
# shape before: (1260, 18)
# SIGNAL COUNTS:
# hold    690
# sell    307
# buy     263
# Name: signal, dtype: int64
# shape after: (1260, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 301 TIME -> 0:0:3
#
# 302
# RUN FOR TBCG
# shape before: (165, 18)
# SIGNAL COUNTS:
# hold    80
# sell    53
# buy     32
# Name: signal, dtype: int64
# shape after: (165, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 302 TIME -> 0:0:5
#
# 303
# RUN FOR TEP
# shape before: (983, 18)
# SIGNAL COUNTS:
# hold    461
# sell    266
# buy     256
# Name: signal, dtype: int64
# shape after: (983, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 303 TIME -> 0:0:4
#
# 304
# RUN FOR TMPL
# shape before: (586, 18)
# SIGNAL COUNTS:
# hold    407
# sell    125
# buy      54
# Name: signal, dtype: int64
# shape after: (586, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 304 TIME -> 0:0:6
#
# 305
# RUN FOR TEM
# shape before: (585, 18)
# SIGNAL COUNTS:
# hold    337
# sell    143
# buy     105
# Name: signal, dtype: int64
# shape after: (585, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 305 TIME -> 0:0:5
#
# 306
# RUN FOR TIFS
# shape before: (102, 18)
# SIGNAL COUNTS:
# hold    48
# sell    38
# buy     16
# Name: signal, dtype: int64
# shape after: (102, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 306 TIME -> 0:0:4
#
# 307
# RUN FOR TCAP
# shape before: (960, 18)
# SIGNAL COUNTS:
# hold    474
# sell    263
# buy     223
# Name: signal, dtype: int64
# shape after: (960, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 307 TIME -> 0:0:3
#
# 308
# RUN FOR TRY
# shape before: (584, 18)
# SIGNAL COUNTS:
# hold    329
# sell    148
# buy     107
# Name: signal, dtype: int64
# shape after: (584, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 308 TIME -> 0:0:4
#
# 309
# RUN FOR TPK
# shape before: (1026, 18)
# SIGNAL COUNTS:
# hold    521
# sell    283
# buy     222
# Name: signal, dtype: int64
# shape after: (1026, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 309 TIME -> 0:0:4
#
# 310
# RUN FOR BBOX
# shape before: (276, 18)
# SIGNAL COUNTS:
# hold    227
# sell     38
# buy      11
# Name: signal, dtype: int64
# shape after: (276, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 310 TIME -> 0:0:5
#
# 311
# RUN FOR TLW
# shape before: (1018, 18)
# SIGNAL COUNTS:
# hold    481
# sell    288
# buy     249
# Name: signal, dtype: int64
# shape after: (1018, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 311 TIME -> 0:0:3
#
# 312
# RUN FOR UDG
# shape before: (1007, 18)
# SIGNAL COUNTS:
# hold    573
# sell    219
# buy     215
# Name: signal, dtype: int64
# shape after: (1007, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 312 TIME -> 0:0:4
#
# 313
# RUN FOR UKCM
# shape before: (586, 18)
# SIGNAL COUNTS:
# hold    429
# sell    117
# buy      40
# Name: signal, dtype: int64
# shape after: (586, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 313 TIME -> 0:0:4
#
# 314
# RUN FOR ULE
# shape before: (1022, 18)
# SIGNAL COUNTS:
# hold    593
# sell    240
# buy     189
# Name: signal, dtype: int64
# shape after: (1022, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 314 TIME -> 0:0:4
#
# 315
# RUN FOR UTG
# shape before: (342, 18)
# SIGNAL COUNTS:
# hold    208
# buy      74
# sell     60
# Name: signal, dtype: int64
# shape after: (342, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 315 TIME -> 0:0:4
#
# 316
# RUN FOR VSVS
# shape before: (1256, 18)
# SIGNAL COUNTS:
# hold    590
# sell    372
# buy     294
# Name: signal, dtype: int64
# shape after: (1256, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 316 TIME -> 0:0:3
#
# 317
# RUN FOR VCT
# shape before: (1185, 18)
# SIGNAL COUNTS:
# hold    588
# sell    301
# buy     296
# Name: signal, dtype: int64
# shape after: (1185, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 317 TIME -> 0:0:5
#
# 318
# RUN FOR VEIL
# shape before: (160, 18)
# SIGNAL COUNTS:
# hold    92
# buy     35
# sell    33
# Name: signal, dtype: int64
# shape after: (160, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 318 TIME -> 0:0:5
#
# 319
# RUN FOR VOF
# shape before: (595, 18)
# SIGNAL COUNTS:
# hold    366
# sell    127
# buy     102
# Name: signal, dtype: int64
# shape after: (595, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 319 TIME -> 0:0:3
#
# 320
# RUN FOR VVO
# shape before: (75, 18)
# SIGNAL COUNTS:
# hold    37
# sell    29
# buy      9
# Name: signal, dtype: int64
# shape after: (75, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 320 TIME -> 0:0:4
#
# 321
# RUN FOR WEIR
# shape before: (1468, 18)
# SIGNAL COUNTS:
# hold    692
# buy     394
# sell    382
# Name: signal, dtype: int64
# shape after: (1468, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 321 TIME -> 0:0:3
#
# 322
# RUN FOR JDW
# shape before: (1342, 18)
# SIGNAL COUNTS:
# hold    659
# buy     356
# sell    327
# Name: signal, dtype: int64
# shape after: (1342, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 322 TIME -> 0:0:5
#
# 323
# RUN FOR SMWH
# shape before: (668, 18)
# SIGNAL COUNTS:
# hold    340
# sell    169
# buy     159
# Name: signal, dtype: int64
# shape after: (668, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 323 TIME -> 0:0:5
#
# 324
# RUN FOR WMH
# shape before: (884, 18)
# SIGNAL COUNTS:
# hold    438
# sell    261
# buy     185
# Name: signal, dtype: int64
# shape after: (884, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 324 TIME -> 0:0:4
#
# 325
# RUN FOR WTAN
# shape before: (594, 18)
# SIGNAL COUNTS:
# hold    419
# sell    105
# buy      70
# Name: signal, dtype: int64
# shape after: (594, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 325 TIME -> 0:0:4
#
# 326
# RUN FOR WIZZ
# shape before: (241, 18)
# SIGNAL COUNTS:
# hold    101
# buy      73
# sell     67
# Name: signal, dtype: int64
# shape after: (241, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 326 TIME -> 0:0:4
#
# 327
# RUN FOR WKP
# shape before: (946, 18)
# SIGNAL COUNTS:
# hold    468
# buy     255
# sell    223
# Name: signal, dtype: int64
# shape after: (946, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 327 TIME -> 0:0:3
#
# 328
# RUN FOR WWH
# shape before: (595, 18)
# SIGNAL COUNTS:
# hold    378
# buy     119
# sell     98
# Name: signal, dtype: int64
# shape after: (595, 168)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
#
#
#
# TOTAL ELAPSED TIME -> 0:22:31
#
# ERROR COUNT: 0

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
tmp_df = pd.read_hdf(hf_store_name,key='weekly_data',mode='r')
print("")
print("FINAL HDFSTORE SIZE: {}".format(tmp_df.shape))
print("FINAL BUY COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "buy"])))
print("FINAL SELL COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "sell"])))
h_store.close()
tmp_df.head(50)
# tmp_df[(tmp_df["ticker"] == 'ADM') & (tmp_df["date"] > '2013-12-01') & (tmp_df["date"] < '2014-02-01')].head(200)
# Out:
# FINAL HDFSTORE SIZE: (258764, 106)
# FINAL BUY COUNT: 55842
# FINAL SELL COUNT: 65235
#        ticker       date    open   close     high     low      volume  \
# 119903    III 2007-12-31  995.00  965.00  1023.00  964.00   4511565.0
# 119904    III 2008-01-07  967.50  924.00   989.00  917.50  16056554.0
# 119905    III 2008-01-14  917.00  901.00   936.00  881.00  21691287.0
# 119906    III 2008-01-21  891.00  917.50   965.00  847.00  17850580.0
# 119907    III 2008-01-28  911.00  961.00   971.00  903.00  12079245.0
# 119908    III 2008-02-04  970.00  923.50   987.50  915.00  15446478.0
# 119909    III 2008-02-11  910.00  919.50   946.50  906.00  12183466.0
# 119910    III 2008-02-18  921.00  883.00   960.00  880.00  12692521.0
# 119911    III 2008-02-25  891.50  818.00   907.00  806.50  20641227.0
# 119912    III 2008-03-03  814.50  777.50   828.50  776.50  18670109.0
# 119913    III 2008-03-10  778.00  766.50   814.50  758.00  15754920.0
# 119914    III 2008-03-17  750.50  782.50   787.00  724.50  15855220.0
# 119915    III 2008-03-24  800.00  838.50   845.00  800.00  11615169.0
# 119916    III 2008-03-31  834.50  882.00   894.50  814.00  15192588.0
# 119917    III 2008-04-07  888.00  853.00   897.50  847.00   9445941.0
# 119918    III 2008-04-14  846.00  888.50   896.00  839.00   8156868.0
# 119919    III 2008-04-21  892.00  877.00   893.50  839.00   9071925.0
# 119920    III 2008-04-28  881.00  864.00   883.00  850.00   8128444.0
# 119921    III 2008-05-05  865.00  882.50   908.00  845.50   7591685.0
# 119922    III 2008-05-12  886.00  919.50   932.50  851.50  18227558.0
# 119923    III 2008-05-19  925.50  859.00   929.00  859.00  14291476.0
# 119924    III 2008-05-26  865.50  885.50   905.00  859.00   8320405.0
# 119925    III 2008-06-02  885.50  861.50   894.00  860.50  12531455.0
# 119926    III 2008-06-09  858.50  828.00   865.00  804.00  13010012.0
# 119927    III 2008-06-16  826.00  828.50   851.00  813.00  14231934.0
# 119928    III 2008-06-23  820.50  819.50   849.50  810.00  13393420.0
# 119929    III 2008-06-30  814.50  803.50   832.50  795.00  12423638.0
# 119930    III 2008-07-07  808.50  785.00   829.00  777.00  13843822.0
# 119931    III 2008-07-14  800.50  918.50   920.00  795.00  16064438.0
# 119932    III 2008-07-21  915.00  886.50   954.50  863.00  15573620.0
# 119933    III 2008-07-28  886.50  906.50   919.50  855.00   8989584.0
# 119934    III 2008-08-04  911.00  955.50   960.00  898.00   9215608.0
# 119935    III 2008-08-11  961.50  909.00   966.00  898.00   7241169.0
# 119936    III 2008-08-18  909.00  889.00   910.00  852.00   6552252.0
# 119937    III 2008-08-25  872.50  919.50   921.00  863.00   7093498.0
# 119938    III 2008-09-01  914.00  889.50   945.00  887.50  10993673.0
# 119939    III 2008-09-08  923.50  902.00   946.50  878.50  10235568.0
# 119940    III 2008-09-15  875.00  847.00   880.00  750.00  23977621.0
# 119941    III 2008-09-22  872.00  789.00   875.00  783.50  13515797.0
# 119942    III 2008-09-29  786.50  721.00   789.50  665.50  17307029.0
# 119943    III 2008-10-06  722.00  500.50   724.00  500.50  22143905.0
# 119944    III 2008-10-13  525.50  456.00   607.50  438.25  23569245.0
# 119945    III 2008-10-20  476.00  494.75   534.00  437.75  21611591.0
# 119946    III 2008-10-27  466.00  540.00   548.50  446.25  12772985.0
# 119947    III 2008-11-03  557.00  480.00   613.00  470.00  14283484.0
# 119948    III 2008-11-10  491.25  425.00   503.50  409.75  12754743.0
# 119949    III 2008-11-17  412.25  362.50   426.00  350.50  12220375.0
# 119950    III 2008-11-24  375.50  411.75   454.50  374.75  11752897.0
# 119951    III 2008-12-01  414.75  340.50   414.75  328.00  11284456.0
# 119952    III 2008-12-08  369.00  310.50   371.00  305.50  17124301.0
#
#         change_price  per_change_price       ema26  ...  min_change_macd_line  \
# 119903        -30.00         -0.031088         NaN  ...                   NaN
# 119904        -43.50         -0.047078         NaN  ...                   NaN
# 119905        -16.00         -0.017758         NaN  ...                   NaN
# 119906         26.50          0.028883         NaN  ...                   NaN
# 119907         50.00          0.052029         NaN  ...                   NaN
# 119908        -46.50         -0.050352         NaN  ...                   NaN
# 119909          9.50          0.010332         NaN  ...                   NaN
# 119910        -38.00         -0.043035         NaN  ...                   NaN
# 119911        -73.50         -0.089853         NaN  ...                   NaN
# 119912        -37.00         -0.047588         NaN  ...                   NaN
# 119913        -11.50         -0.015003         NaN  ...                   NaN
# 119914         32.00          0.040895         NaN  ...                   NaN
# 119915         38.50          0.045915         NaN  ...                   NaN
# 119916         47.50          0.053855         NaN  ...                   NaN
# 119917        -35.00         -0.041032         NaN  ...                   NaN
# 119918         42.50          0.047833         NaN  ...                   NaN
# 119919        -15.00         -0.017104         NaN  ...                   NaN
# 119920        -17.00         -0.019676         NaN  ...                   NaN
# 119921         17.50          0.019830         NaN  ...                   NaN
# 119922         33.50          0.036433         NaN  ...                   NaN
# 119923        -66.50         -0.077416         NaN  ...                   NaN
# 119924         20.00          0.022586         NaN  ...                   NaN
# 119925        -24.00         -0.027858         NaN  ...                   NaN
# 119926        -30.50         -0.036836         NaN  ...                   NaN
# 119927          2.50          0.003018         NaN  ...                   NaN
# 119928         -1.00         -0.001220  870.230769  ...                   NaN
# 119929        -11.00         -0.013690  865.287749  ...                   NaN
# 119930        -23.50         -0.029936  859.340509  ...                   NaN
# 119931        118.00          0.128470  863.722693  ...                   NaN
# 119932        -28.50         -0.032149  865.409901  ...             11.823172
# 119933         20.00          0.022063  868.453612  ...             16.539077
# 119934         44.50          0.046572  874.901493  ...             24.195487
# 119935        -52.50         -0.057756  877.427308  ...             26.450225
# 119936        -20.00         -0.022497  878.284544  ...             26.561149
# 119937         47.00          0.051115  881.337541  ...             29.019673
# 119938        -24.50         -0.027544  881.942168  ...             28.463257
# 119939        -21.50         -0.023836  883.427933  ...             28.941361
# 119940        -28.00         -0.033058  880.729568  ...             -3.623333
# 119941        -83.00         -0.105196  873.934785  ...            -11.505306
# 119942        -65.50         -0.090846  862.606282  ...            -23.057135
# 119943       -221.50         -0.442557  835.783595  ...            -49.517805
# 119944        -69.50         -0.152412  807.651477  ...            -73.317759
# 119945         18.75          0.037898  784.473589  ...            -88.120856
# 119946         74.00          0.137037  766.364435  ...            -95.187918
# 119947        -77.00         -0.160417  745.152254  ...           -104.509460
# 119948        -66.25         -0.155882  721.437273  ...           -115.092244
# 119949        -49.75         -0.137241  694.849326  ...           -127.140868
# 119950         36.25          0.088039  673.879006  ...           -131.286107
# 119951        -74.25         -0.218062  649.184265  ...           -138.804532
# 119952        -58.50         -0.188406  624.096541  ...           -145.589487
#
#         prev_max_grad_macd_line  prev_min_grad_macd_line  \
# 119903                      NaN                      NaN
# 119904                      NaN                      NaN
# 119905                      NaN                      NaN
# 119906                      NaN                      NaN
# 119907                      NaN                      NaN
# 119908                      NaN                      NaN
# 119909                      NaN                      NaN
# 119910                      NaN                      NaN
# 119911                      NaN                      NaN
# 119912                      NaN                      NaN
# 119913                      NaN                      NaN
# 119914                      NaN                      NaN
# 119915                      NaN                      NaN
# 119916                      NaN                      NaN
# 119917                      NaN                      NaN
# 119918                      NaN                      NaN
# 119919                      NaN                      NaN
# 119920                      NaN                      NaN
# 119921                      NaN                      NaN
# 119922                      NaN                      NaN
# 119923                      NaN                      NaN
# 119924                      NaN                      NaN
# 119925                      NaN                      NaN
# 119926                      NaN                      NaN
# 119927                      NaN                      NaN
# 119928                      NaN                      NaN
# 119929                      NaN                      NaN
# 119930                      NaN                      NaN
# 119931                      NaN                      NaN
# 119932                      NaN                      NaN
# 119933                      NaN                      NaN
# 119934                      NaN                      NaN
# 119935                      NaN                      NaN
# 119936                      NaN                      NaN
# 119937                      NaN                      NaN
# 119938                      NaN                      NaN
# 119939                 2.464596                      NaN
# 119940                 2.464596                 3.557907
# 119941                -0.039156                 3.557907
# 119942                -0.039156                 3.557907
# 119943                -0.039156                 3.557907
# 119944                -0.039156                 3.557907
# 119945                -0.039156                 3.557907
# 119946                -0.039156                 3.557907
# 119947                -0.039156                 3.557907
# 119948                -0.039156                 3.557907
# 119949                -0.039156                 3.557907
# 119950                -0.039156                 3.557907
# 119951                -0.039156                 3.557907
# 119952                -0.039156                 3.557907
#
#         max_move_cum_macd_line  min_move_cum_macd_line  \
# 119903                       0                       0
# 119904                       0                       0
# 119905                       0                       0
# 119906                       0                       0
# 119907                       0                       0
# 119908                       0                       0
# 119909                       0                       0
# 119910                       0                       0
# 119911                       0                       0
# 119912                       0                       0
# 119913                       0                       0
# 119914                       0                       0
# 119915                       0                       0
# 119916                       0                       0
# 119917                       0                       0
# 119918                       0                       0
# 119919                       0                       0
# 119920                       0                       0
# 119921                       0                       0
# 119922                       0                       0
# 119923                       0                       0
# 119924                       0                       0
# 119925                       0                       0
# 119926                       0                       0
# 119927                       0                       0
# 119928                       0                       0
# 119929                       0                       0
# 119930                       0                       0
# 119931                       0                       0
# 119932                       0                       0
# 119933                       0                       0
# 119934                       0                       0
# 119935                       0                       0
# 119936                       0                       0
# 119937                       0                       0
# 119938                       0                       0
# 119939                       1                       0
# 119940                       1                       1
# 119941                       0                       1
# 119942                       0                       1
# 119943                       0                       1
# 119944                       0                       1
# 119945                       0                       1
# 119946                       0                       1
# 119947                       0                       1
# 119948                       0                       1
# 119949                       0                       1
# 119950                       0                       1
# 119951                       0                       1
# 119952                       0                       1
#
#         long_prev_max_move_date_macd_line  long_prev_min_move_date_macd_line  \
# 119903                                0.0                                0.0
# 119904                                0.0                                0.0
# 119905                                0.0                                0.0
# 119906                                0.0                                0.0
# 119907                                0.0                                0.0
# 119908                                0.0                                0.0
# 119909                                0.0                                0.0
# 119910                                0.0                                0.0
# 119911                                0.0                                0.0
# 119912                                0.0                                0.0
# 119913                                0.0                                0.0
# 119914                                0.0                                0.0
# 119915                                0.0                                0.0
# 119916                                0.0                                0.0
# 119917                                0.0                                0.0
# 119918                                0.0                                0.0
# 119919                                0.0                                0.0
# 119920                                0.0                                0.0
# 119921                                0.0                                0.0
# 119922                                0.0                                0.0
# 119923                                0.0                                0.0
# 119924                                0.0                                0.0
# 119925                                0.0                                0.0
# 119926                                0.0                                0.0
# 119927                                0.0                                0.0
# 119928                                0.0                                0.0
# 119929                                0.0                                0.0
# 119930                                0.0                                0.0
# 119931                                0.0                                0.0
# 119932                                0.0                                0.0
# 119933                                0.0                                0.0
# 119934                                0.0                                0.0
# 119935                                0.0                                0.0
# 119936                                0.0                                0.0
# 119937                                0.0                                0.0
# 119938                                0.0                                0.0
# 119939                                0.0                                0.0
# 119940                                0.0                                0.0
# 119941                                0.0                                0.0
# 119942                                0.0                                0.0
# 119943                                0.0                                0.0
# 119944                                0.0                                0.0
# 119945                                0.0                                0.0
# 119946                                0.0                                0.0
# 119947                                0.0                                0.0
# 119948                                0.0                                0.0
# 119949                                0.0                                0.0
# 119950                                0.0                                0.0
# 119951                                0.0                                0.0
# 119952                                0.0                                0.0
#
#         long_max_grad_macd_line  long_min_grad_macd_line  signal
# 119903                      0.0                      0.0    sell
# 119904                      0.0                      0.0    sell
# 119905                      0.0                      0.0    hold
# 119906                      0.0                      0.0    hold
# 119907                      0.0                      0.0    sell
# 119908                      0.0                      0.0    sell
# 119909                      0.0                      0.0    sell
# 119910                      0.0                      0.0    sell
# 119911                      0.0                      0.0    hold
# 119912                      0.0                      0.0    hold
# 119913                      0.0                      0.0     buy
# 119914                      0.0                      0.0     buy
# 119915                      0.0                      0.0    hold
# 119916                      0.0                      0.0    sell
# 119917                      0.0                      0.0    hold
# 119918                      0.0                      0.0    sell
# 119919                      0.0                      0.0    sell
# 119920                      0.0                      0.0    hold
# 119921                      0.0                      0.0    hold
# 119922                      0.0                      0.0    sell
# 119923                      0.0                      0.0    hold
# 119924                      0.0                      0.0    sell
# 119925                      0.0                      0.0    hold
# 119926                      0.0                      0.0    hold
# 119927                      0.0                      0.0    hold
# 119928                      0.0                      0.0    hold
# 119929                      0.0                      0.0    hold
# 119930                      0.0                      0.0    hold
# 119931                      0.0                      0.0    sell
# 119932                      0.0                      0.0    hold
# 119933                      0.0                      0.0    hold
# 119934                      0.0                      0.0    sell
# 119935                      0.0                      0.0    sell
# 119936                      0.0                      0.0    hold
# 119937                      0.0                      0.0    sell
# 119938                      0.0                      0.0    hold
# 119939                      0.0                      0.0    sell
# 119940                      0.0                      0.0    sell
# 119941                      0.0                      0.0    sell
# 119942                      0.0                      0.0    sell
# 119943                      0.0                      0.0    sell
# 119944                      0.0                      0.0    hold
# 119945                      0.0                      0.0    hold
# 119946                      0.0                      0.0    sell
# 119947                      0.0                      0.0    sell
# 119948                      0.0                      0.0    sell
# 119949                      0.0                      0.0    hold
# 119950                      0.0                      0.0    sell
# 119951                      0.0                      0.0    sell
# 119952                      0.0                      0.0    hold
#
# [50 rows x 106 columns]

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5

# %%
#Remove 'date' from out_cols
out_cols.remove('date')

# %%
#Export a list of the features for this model
file_object = open(path+r'\feature_engineering_feature_list.txt','w')
feature_str = ''
for i in out_cols:
    feature_str += '{},'.format(i)
feature_str = feature_str[:-1]
file_object.write(feature_str)
file_object.close()
feature_str
# Out:
# 'ticker,open,close,high,low,volume,change_price,per_change_price,ema26,macd,signal_line,macd_line,close_shift1,change_close_shift1,volume_shift1,change_volume_shift1,ema26_shift1,change_ema26_shift1,close_13_norm,close_26_norm,close_52_norm,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,close_max,close_min,prev_max_close,prev_min_close,prev_max_close_date_change,prev_min_close_date_change,max_change_close,min_change_close,prev_max_grad_close,prev_min_grad_close,max_move_cum_close,min_move_cum_close,long_prev_max_move_date_close,long_prev_min_move_date_close,long_max_grad_close,long_min_grad_close,macd_max,macd_min,prev_max_macd,prev_min_macd,prev_max_macd_date_change,prev_min_macd_date_change,max_change_macd,min_change_macd,prev_max_grad_macd,prev_min_grad_macd,max_move_cum_macd,min_move_cum_macd,long_prev_max_move_date_macd,long_prev_min_move_date_macd,long_max_grad_macd,long_min_grad_macd,ema26_max,ema26_min,prev_max_ema26,prev_min_ema26,prev_max_ema26_date_change,prev_min_ema26_date_change,max_change_ema26,min_change_ema26,prev_max_grad_ema26,prev_min_grad_ema26,max_move_cum_ema26,min_move_cum_ema26,long_prev_max_move_date_ema26,long_prev_min_move_date_ema26,long_max_grad_ema26,long_min_grad_ema26,signal_line_max,signal_line_min,prev_max_signal_line,prev_min_signal_line,prev_max_signal_line_date_change,prev_min_signal_line_date_change,max_change_signal_line,min_change_signal_line,prev_max_grad_signal_line,prev_min_grad_signal_line,max_move_cum_signal_line,min_move_cum_signal_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_signal_line,long_max_grad_signal_line,long_min_grad_signal_line,macd_line_max,macd_line_min,prev_max_macd_line,prev_min_macd_line,prev_max_macd_line_date_change,prev_min_macd_line_date_change,max_change_macd_line,min_change_macd_line,prev_max_grad_macd_line,prev_min_grad_macd_line,max_move_cum_macd_line,min_move_cum_macd_line,long_prev_max_move_date_macd_line,long_prev_min_move_date_macd_line,long_max_grad_macd_line,long_min_grad_macd_line,signal'
