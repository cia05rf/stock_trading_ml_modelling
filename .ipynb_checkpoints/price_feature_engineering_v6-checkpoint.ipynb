# %% [markdown]
# # Create indicators and find signals
# This code is designed to calculate the features for model training.
#
# We will also bring in if the target price was hit within 8 weeks for ML training and validation.
#
# Each share has it's own trading pattern so we will train a different model for each share but use the same set of features, just the hyper paramenters will be tuned differenty.
#
# V5 build - Normalise vs rolling max 5 year window

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import tables
import os
import datetime as dt
from rf_modules import *

# %%
#Import the ftse list
path = r"C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices"
tick_ftse = pd.read_csv(path + r"\tick_ftse.csv")
tick_ftse = tick_ftse.iloc[:,1:]
for col in tick_ftse:
    tick_ftse.rename(columns={col:clean_col_name(col)},inplace=True)
tick_ftse.head()
tick_ftse['ticker'] = [re.sub('(?=[0-9A-Z])*\.(?=[0-9A-Z]+)','-',tick) for tick in tick_ftse['ticker']]
tick_ftse['ticker'] = [re.sub('[^0-9A-Z\-]','',tick) for tick in tick_ftse['ticker']]

# %%
#Import and combine prices files
df_prices_w = pd.read_hdf(path + r"\all_hist_prices_w.h5")
#Rename columns
for col in df_prices_w:
    df_prices_w.rename(columns={col:clean_col_name(col)},inplace=True)
#Drop unwanted columns
try:
    df_prices_w.drop(columns=["unnamed_0","index"],inplace=True)
except Exception as e:
    print(e)
#Reformat columns where neccessary
df_prices_w["date"] = df_prices_w["date"].astype("datetime64")
print(df_prices_w.shape)
print(df_prices_w.dtypes)
df_prices_w.head()
# Out:
# "['unnamed_0' 'index'] not found in axis"
# (280168, 13)
# ticker                 object
# date           datetime64[ns]
# high                  float64
# low                   float64
# volume                float64
# open                  float64
# close                 float64
# change                float64
# ema12                 float64
# ema26                 float64
# macd_line             float64
# signal_line           float64
# macd                  float64
# dtype: object
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Remove tickers with fewer than 34 entries as this is where the MACD can be calculated
print('START ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('START TICK COUNT -> {}'.format(tick_ftse.shape[0]))
for tick in tick_ftse.ticker:
    print(tick,' ->',df_prices_w[df_prices_w.ticker == tick].shape[0])
    if df_prices_w[df_prices_w.ticker == tick].shape[0] < 34:
        #Remove from dataframe
        print('\tTOO FEW RECORDS FOR {}'.format(tick))
        df_prices_w = df_prices_w.loc[df_prices_w.ticker != tick]
        print('\tNEW ROW COUNT -> {}'.format(df_prices_w.shape[0]))
        #Remove from tick_ftse
        tick_ftse = tick_ftse.loc[tick_ftse.ticker != tick]
        print('\tNEW TICK COUNT -> {}'.format(tick_ftse.shape[0]))
print('\nEND ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('END TICK COUNT -> {}'.format(tick_ftse.shape[0]))
# Out:
# START ROW COUNT -> 280168
# START TICK COUNT -> 351
# III  -> 623
# ABF  -> 1055
# ADM  -> 363
# AAL  -> 1018
# ANTO  -> 1055
# AHT  -> 1033
# AZN  -> 1055
# AUTO  -> 248
# AVV  -> 1055
# AV  -> 2788
# BA  -> 1546
# BARC  -> 1055
# BDEV  -> 1055
# BKG  -> 1055
# BHP  -> 534
# BP  -> 1575
# BATS  -> 1055
# BLND  -> 1055
# BT-A  -> 1546
# BNZL  -> 1052
# BRBY  -> 910
# CCL  -> 999
# CNA  -> 1055
# CCH  -> 346
# CPG  -> 1041
# CRH  -> 1041
# CRDA  -> 1047
# DCC  -> 1037
# DGE  -> 1055
# EVR  -> 424
# EXPN  -> 688
# FERG  -> 1056
# FLTR  -> 28
# 	TOO FEW RECORDS FOR FLTR
# 	NEW ROW COUNT -> 280140
# 	NEW TICK COUNT -> 350
# FRES  -> 606
# GSK  -> 1055
# GLEN  -> 448
# HLMA  -> 1023
# HL  -> 651
# HIK  -> 718
# HSX  -> 1022
# HSBA  -> 1266
# IMB  -> 1190
# INF  -> 1076
# IHG  -> 854
# ITRK  -> 894
# IAG  -> 866
# ITV  -> 1022
# JD  -> 92
# JMAT  -> 1247
# KGF  -> 1266
# LAND  -> 1274
# LGEN  -> 1266
# LLOY  -> 1232
# LSE  -> 942
# MNG  -> 8
# 	TOO FEW RECORDS FOR MNG
# 	NEW ROW COUNT -> 280132
# 	NEW TICK COUNT -> 349
# MGGT  -> 1485
# MRO  -> 822
# MNDI  -> 624
# MRW  -> 1266
# NG  -> 1253
# NXT  -> 1533
# NMC  -> 383
# OCDO  -> 472
# PSON  -> 1283
# PSN  -> 1473
# PHNX  -> 505
# POLY  -> 406
# PRU  -> 1512
# RDSA  -> 267
# RDSB  -> 1003
# RB  -> 1293
# REL  -> 1283
# RTO  -> 1251
# RMV  -> 700
# RIO  -> 1536
# RR  -> 1563
# RBS  -> 1266
# RSA  -> 1253
# SGE  -> 1261
# SBRY  -> 1266
# SDR  -> 1256
# SMT  -> 145
# SGRO  -> 1544
# SVT  -> 1251
# SN  -> 1597
# SMDS  -> 1434
# SMIN  -> 1496
# SKG  -> 647
# SPX  -> 1464
# SSE  -> 1283
# STJ  -> 1472
# STAN  -> 1537
# SLA  -> 682
# TW  -> 1563
# TSCO  -> 1266
# TUI  -> 261
# ULVR  -> 1036
# UU  -> 1302
# VOD  -> 1055
# WTB  -> 1055
# WPP  -> 692
# 3IN  -> 595
# FOUR  -> 1046
# 888  -> 742
# ASL  -> 612
# AGK  -> 1055
# AAF  -> 24
# 	TOO FEW RECORDS FOR AAF
# 	NEW ROW COUNT -> 280108
# 	NEW TICK COUNT -> 348
# AJB  -> 54
# ATST  -> 624
# APAX  -> 225
# ASCL  -> 201
# ASHM  -> 688
# AGR  -> 837
# AML  -> 63
# AVST  -> 84
# AGT  -> 20
# 	TOO FEW RECORDS FOR AGT
# 	NEW ROW COUNT -> 280088
# 	NEW TICK COUNT -> 347
# BME  -> 288
# BAB  -> 1035
# BGFD  -> 615
# BAKK  -> 109
# BBY  -> 1055
# BGEO  -> 628
# BNKR  -> 618
# BAG  -> 1055
# BBGI  -> 407
# BEZ  -> 171
# BWY  -> 1443
# BYG  -> 1004
# BRSC  -> 283
# BRWM  -> 591
# BCPT  -> 18
# 	TOO FEW RECORDS FOR BCPT
# 	NEW ROW COUNT -> 280070
# 	NEW TICK COUNT -> 346
# BGSC  -> 603
# BOY  -> 1257
# BVS  -> 1124
# BRW  -> 1134
# BVIC  -> 713
# CNE  -> 1410
# CLDN  -> 601
# CAPC  -> 482
# CPI  -> 1312
# CARD  -> 292
# CEY  -> 919
# CINE  -> 641
# CTY  -> 605
# CKN  -> 1314
# CBG  -> 1249
# CLI  -> 1285
# COA  -> 1382
# COB  -> 1266
# CCC  -> 1107
# GLO  -> 110
# CTEC  -> 164
# CSP  -> 420
# CWK  -> 1122
# CRST  -> 338
# DJAN  -> 1132
# DPH  -> 964
# DLN  -> 1203
# DPLM  -> 1489
# DLG  -> 356
# DC  -> 533
# DOM  -> 1028
# DRX  -> 712
# DNLM  -> 668
# EZJ  -> 977
# EDIN  -> 589
# EIG  -> 670
# ECM  -> 1266
# ELM  -> 1544
# ENOG  -> 92
# ETO  -> 604
# EQN  -> 216
# ESNT  -> 739
# JEO  -> 595
# ERM  -> 1122
# FCIT  -> 595
# FDM  -> 287
# FXPO  -> 628
# FEV  -> 594
# FSV  -> 594
# FCSS  -> 474
# FIN  -> 31
# 	TOO FEW RECORDS FOR FIN
# 	NEW ROW COUNT -> 280039
# 	NEW TICK COUNT -> 345
# FGT  -> 589
# FGP  -> 1259
# FSJ  -> 1102
# FSFL  -> 291
# FUTR  -> 1050
# GFS  -> 838
# GFRD  -> 1472
# GAW  -> 1294
# GCP  -> 461
# DIGS  -> 314
# GSS  -> 603
# GNS  -> 946
# GOG  -> 1308
# GPOR  -> 1036
# GFTU  -> 906
# GRI  -> 1055
# UKW  -> 341
# GNC  -> 1041
# GRG  -> 1055
# GVC  -> 746
# HMSO  -> 1054
# HVPE  -> 403
# HSTG  -> 218
# HAS  -> 1036
# HSL  -> 611
# HRI  -> 594
# HGT  -> 594
# HICL  -> 594
# HILS  -> 1035
# HFG  -> 637
# HOC  -> 666
# HSV  -> 1025
# HWDN  -> 1036
# HTG  -> 1005
# IBST  -> 217
# ICGT  -> 607
# IGG  -> 745
# IMI  -> 1036
# INCH  -> 1036
# ICP  -> 1036
# IHP  -> 94
# INPP  -> 518
# INVP  -> 889
# IPO  -> 825
# IWG  -> 549
# JLG  -> 253
# JII  -> 603
# JAM  -> 594
# JMG  -> 594
# JFJ  -> 605
# JUP  -> 477
# JE  -> 298
# KNOS  -> 232
# KAZ  -> 722
# LRE  -> 712
# LWDB  -> 392
# LMP  -> 520
# EMG  -> 1036
# MKS  -> 1036
# MSLH  -> 1036
# MARS  -> 788
# MCS  -> 113
# MDC  -> 200
# MRC  -> 577
# MCRO  -> 743
# MAB  -> 852
# MONY  -> 622
# MNKS  -> 595
# MGAM  -> 1473
# MYI  -> 594
# NEX  -> 1375
# NBLS  -> 421
# NETW  -> 36
# NRR  -> 474
# NESF  -> 285
# OSB  -> 289
# OXIG  -> 1469
# PAGE  -> 926
# PIN  -> 594
# PAG  -> 1490
# PAY  -> 776
# PNN  -> 1529
# PLI  -> 594
# PSH  -> 136
# PNL  -> 595
# PFC  -> 722
# PETS  -> 301
# PTEC  -> 697
# PLUS  -> 315
# PCT  -> 596
# PSSL  -> 12
# 	TOO FEW RECORDS FOR PSSL
# 	NEW ROW COUNT -> 280027
# 	NEW TICK COUNT -> 344
# PLP  -> 297
# PPH  -> 582
# PMO  -> 1467
# PHP  -> 1093
# PFG  -> 1036
# PRTC  -> 235
# PZC  -> 1021
# QQ  -> 723
# QLT  -> 77
# RNK  -> 1036
# RAT  -> 1029
# RDW  -> 1033
# TRIG  -> 305
# RSW  -> 1030
# RTN  -> 1036
# RHIM  -> 112
# RCP  -> 83
# RSE  -> 293
# ROR  -> 1036
# RMG  -> 304
# SBRE  -> 106
# SAFE  -> 472
# SNN  -> 246
# SVS  -> 1422
# SDP  -> 596
# SOI  -> 594
# SCIN  -> 596
# SNR  -> 1438
# SEQI  -> 240
# SRP  -> 1295
# SHB  -> 1162
# SHI  -> 1328
# SIG  -> 2
# 	TOO FEW RECORDS FOR SIG
# 	NEW ROW COUNT -> 280025
# 	NEW TICK COUNT -> 343
# SRE  -> 633
# SSON  -> 51
# SCT  -> 214
# SOPH  -> 234
# SXS  -> 1488
# SPT  -> 1265
# SPD  -> 649
# SSPG  -> 284
# SMP  -> 1433
# SGC  -> 1161
# SYNC  -> 345
# SYNT  -> 1463
# TALK  -> 489
# TATE  -> 1270
# TBCG  -> 175
# TEP  -> 993
# TMPL  -> 596
# TEM  -> 595
# TIFS  -> 112
# TCAP  -> 970
# TRY  -> 594
# TRN  -> 25
# 	TOO FEW RECORDS FOR TRN
# 	NEW ROW COUNT -> 280000
# 	NEW TICK COUNT -> 342
# TPK  -> 1036
# BBOX  -> 286
# TLW  -> 1028
# UDG  -> 1017
# UKCM  -> 596
# ULE  -> 1032
# UTG  -> 352
# VSVS  -> 1266
# VCT  -> 1195
# VEIL  -> 170
# VOF  -> 604
# VMUK  -> 5
# 	TOO FEW RECORDS FOR VMUK
# 	NEW ROW COUNT -> 279995
# 	NEW TICK COUNT -> 341
# VVO  -> 85
# WOSG  -> 28
# 	TOO FEW RECORDS FOR WOSG
# 	NEW ROW COUNT -> 279967
# 	NEW TICK COUNT -> 340
# WEIR  -> 1478
# JDW  -> 1352
# SMWH  -> 678
# WMH  -> 894
# WTAN  -> 603
# WIZZ  -> 251
# WG  -> 916
# WKP  -> 956
# WWH  -> 605
#
# END ROW COUNT -> 279967
# END TICK COUNT -> 340

# %%
#Function for calculating ema
def calc_ema(_s_in,_periods):
    """Function used to create EMA for a series
    
    args:
    -----
    _s_in - pandas series - series of float values
    _periods - int - value describing how far to look at for EMA calc
    
    returns:
    ------
    pandas series    
    """
    #Calc mod val
    _mod = 2/(_periods+1)
    #Calc sma
    _sma_s = [0] * _s_in.shape[0]
    for _i in range(0,_periods):
        _sma_s += _s_in.shift(_i) / _periods
    #Calc ema
    _ema_s = _sma_s.copy()
    _ema_s[(_ema_s > 0) & (np.isnan(_ema_s) == False)] = _mod*(_s_in - _ema_s.shift(1)) + _ema_s.shift(1)
    return _ema_s.copy()

# %%
#Function for calculating the MACD
def calc_macd(_ema_lng_s,_ema_sht_s,_sig_period:int):
    """Function used to create MACD for a series
    
    args:
    -----
    _ema_lng_s - pandas series - series of float values for the long term EMA 
    _ema_sht_s - pandas series - series of float values for the short term EMA
    _sig_period - int - value describing how far to look at for MACD calc
    
    returns:
    ------
    tuple of pandas series,pandas series,pandas series - MACD line, signal line, macd histogram  
    """
    #Make a df
    _tmp_df = pd.DataFrame([])
    _tmp_df['ema_lng'] = _ema_lng_s
    _tmp_df['ema_sht'] = _ema_sht_s
    #Calc the signal line
    _tmp_df['macd_line'] = _tmp_df['ema_sht'] - _tmp_df['ema_lng']
    _tmp_df['signal_line'] = calc_ema(_tmp_df['macd_line'],_sig_period)
    _tmp_df['macd_hist'] = _tmp_df['macd_line'] - _tmp_df['signal_line']
    return (_tmp_df['macd_line'].copy(),_tmp_df['signal_line'].copy(),_tmp_df['macd_hist'].copy())

# %%
#Calc the ema and macds for the data
def calc_ema_macd(_df_in):
    """Function used to call EMA and MACD functions
    
    args:
    -----
    _df_in - pandas dataframe - must have columns 'close' and 'date' 
    
    returns:
    ------
    pandas dataframe - with new columns for ema12,ema26,macd_line,signal_line,macd
    """
    _tick_df = _df_in.copy()
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
#         _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal_line'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return _tick_df

# %%
#Create a function which normalises a feature based only on the values which have come before it - avoids time series bias
def norm_time_s(_ind,_s_in,_window):
    """Function used to call EMA and MACD functions
    
    args:
    -----
    _ind - int - the index of this value in the series
    _s_in - pandas series - a series of values to be normalised
    _window - int - the number of values to look over
    
    returns:
    ------
    float - normalised value in the window period
    """
    _this_ind = _ind - _s_in.index.min()
    if _this_ind < _window:
        _st_ind = 0
    else:
        _st_ind = _this_ind - _window
    _min = np.nanmin(_s_in[_st_ind:_this_ind+1].values)
    _max = np.nanmax(_s_in[_st_ind:_this_ind+1].values)
    _norm_val = (_s_in[_ind] - _min) / (_max - _min)
    return _norm_val

# %%
#Run the functions
def norm_prices(_df_in):
    """Function used to normalise all prices in the dataframe
    
    args:
    -----
    _df_in - pandas dataframe - must contain values 'open','close','high','low','volume'
    
    returns:
    ------
    pandas dataframe - with normalised values for 'open','close','high','low','volume'
    """
    _df_out = _df_in.copy()
    #Normalise the columns which need it
    _norm_cols = [
        #Standard features
        "open"
        ,"close"
        ,"high"
        ,"low"
        ,"volume"
    ]
    #Reset the index
    _df_out.sort_values(['date'],ascending=True,inplace=True)
    #Calc the 5yr window
    _5yr = 5*52
    #Normalise
    for _col in _norm_cols:
        _df_out["{}_orig".format(_col)] = _df_out[_col].copy() #Take a copy so as the values are changed this does not affect following calculations
        _df_out[_col] = [norm_time_s(_x,_df_out["{}_orig".format(_col)],_5yr) for _x in _df_out.index]
    return _df_out

# %%
#Set records into the correct order
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)

# %%
# Normalize the prices by ticker and time then create emas and macds for each ticker
print('NORALISING AND CALCULATING EMA & MACD VALUES')
error_li = []
run_time = process_time()
run_time.lap()
new_df = pd.DataFrame([])
for tick in tick_ftse.ticker:
    print('\nRUN FOR {} - {}'.format(tick,len(run_time.lap_li)))
    try:
        this_tick_df = df_prices_w[df_prices_w.ticker == tick]
        this_tick_df = norm_prices(this_tick_df.copy())
        #Calculate the ema and macd
        this_tick_df = calc_ema_macd(this_tick_df)
        #Append back on to the dataframe
        new_df = new_df.append(this_tick_df)
        print('\tSUCCESS')
        run_time.lap()
        run_time.show_latest_lap_time()
    except Exception as e:
        print('\tERROR -> {}'.format(e))
        error_li.append(e)
df_prices_w = new_df
run_time.end()
print('\n\nCOMPLETED - ERRORS ENCOUNTERED -> {}'.format(len(error_li)))
if len(error_li) > 0:
    print(error_li)
# Out:
# NORALISING AND CALCULATING EMA & MACD VALUES
#
# RUN FOR III - 1
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: RuntimeWarning: invalid value encountered in double_scalars
# 	SUCCESS
# LAP 2 TIME -> 0:0:1
#
# RUN FOR ABF - 2
# 	SUCCESS
# LAP 3 TIME -> 0:0:2
#
# RUN FOR ADM - 3
# 	SUCCESS
# LAP 4 TIME -> 0:0:0
#
# RUN FOR AAL - 4
# 	SUCCESS
# LAP 5 TIME -> 0:0:2
#
# RUN FOR ANTO - 5
# 	SUCCESS
# LAP 6 TIME -> 0:0:2
#
# RUN FOR AHT - 6
# 	SUCCESS
# LAP 7 TIME -> 0:0:2
#
# RUN FOR AZN - 7
# 	SUCCESS
# LAP 8 TIME -> 0:0:2
#
# RUN FOR AUTO - 8
# 	SUCCESS
# LAP 9 TIME -> 0:0:0
#
# RUN FOR AVV - 9
# 	SUCCESS
# LAP 10 TIME -> 0:0:2
#
# RUN FOR AV - 10
# 	SUCCESS
# LAP 11 TIME -> 0:0:7
#
# RUN FOR BA - 11
# 	SUCCESS
# LAP 12 TIME -> 0:0:3
#
# RUN FOR BARC - 12
# 	SUCCESS
# LAP 13 TIME -> 0:0:2
#
# RUN FOR BDEV - 13
# 	SUCCESS
# LAP 14 TIME -> 0:0:2
#
# RUN FOR BKG - 14
# 	SUCCESS
# LAP 15 TIME -> 0:0:2
#
# RUN FOR BHP - 15
# 	SUCCESS
# LAP 16 TIME -> 0:0:1
#
# RUN FOR BP - 16
# 	SUCCESS
# LAP 17 TIME -> 0:0:3
#
# RUN FOR BATS - 17
# 	SUCCESS
# LAP 18 TIME -> 0:0:2
#
# RUN FOR BLND - 18
# 	SUCCESS
# LAP 19 TIME -> 0:0:2
#
# RUN FOR BT-A - 19
# 	SUCCESS
# LAP 20 TIME -> 0:0:3
#
# RUN FOR BNZL - 20
# 	SUCCESS
# LAP 21 TIME -> 0:0:2
#
# RUN FOR BRBY - 21
# 	SUCCESS
# LAP 22 TIME -> 0:0:2
#
# RUN FOR CCL - 22
# 	SUCCESS
# LAP 23 TIME -> 0:0:2
#
# RUN FOR CNA - 23
# 	SUCCESS
# LAP 24 TIME -> 0:0:2
#
# RUN FOR CCH - 24
# 	SUCCESS
# LAP 25 TIME -> 0:0:0
#
# RUN FOR CPG - 25
# 	SUCCESS
# LAP 26 TIME -> 0:0:2
#
# RUN FOR CRH - 26
# 	SUCCESS
# LAP 27 TIME -> 0:0:2
#
# RUN FOR CRDA - 27
# 	SUCCESS
# LAP 28 TIME -> 0:0:2
#
# RUN FOR DCC - 28
# 	SUCCESS
# LAP 29 TIME -> 0:0:2
#
# RUN FOR DGE - 29
# 	SUCCESS
# LAP 30 TIME -> 0:0:2
#
# RUN FOR EVR - 30
# 	SUCCESS
# LAP 31 TIME -> 0:0:1
#
# RUN FOR EXPN - 31
# 	SUCCESS
# LAP 32 TIME -> 0:0:1
#
# RUN FOR FERG - 32
# 	SUCCESS
# LAP 33 TIME -> 0:0:2
#
# RUN FOR FRES - 33
# 	SUCCESS
# LAP 34 TIME -> 0:0:1
#
# RUN FOR GSK - 34
# 	SUCCESS
# LAP 35 TIME -> 0:0:2
#
# RUN FOR GLEN - 35
# 	SUCCESS
# LAP 36 TIME -> 0:0:1
#
# RUN FOR HLMA - 36
# 	SUCCESS
# LAP 37 TIME -> 0:0:2
#
# RUN FOR HL - 37
# 	SUCCESS
# LAP 38 TIME -> 0:0:1
#
# RUN FOR HIK - 38
# 	SUCCESS
# LAP 39 TIME -> 0:0:1
#
# RUN FOR HSX - 39
# 	SUCCESS
# LAP 40 TIME -> 0:0:2
#
# RUN FOR HSBA - 40
# 	SUCCESS
# LAP 41 TIME -> 0:0:2
#
# RUN FOR IMB - 41
# 	SUCCESS
# LAP 42 TIME -> 0:0:2
#
# RUN FOR INF - 42
# 	SUCCESS
# LAP 43 TIME -> 0:0:2
#
# RUN FOR IHG - 43
# 	SUCCESS
# LAP 44 TIME -> 0:0:1
#
# RUN FOR ITRK - 44
# 	SUCCESS
# LAP 45 TIME -> 0:0:2
#
# RUN FOR IAG - 45
# 	SUCCESS
# LAP 46 TIME -> 0:0:2
#
# RUN FOR ITV - 46
# 	SUCCESS
# LAP 47 TIME -> 0:0:2
#
# RUN FOR JD - 47
# 	SUCCESS
# LAP 48 TIME -> 0:0:0
#
# RUN FOR JMAT - 48
# 	SUCCESS
# LAP 49 TIME -> 0:0:2
#
# RUN FOR KGF - 49
# 	SUCCESS
# LAP 50 TIME -> 0:0:3
#
# RUN FOR LAND - 50
# 	SUCCESS
# LAP 51 TIME -> 0:0:2
#
# RUN FOR LGEN - 51
# 	SUCCESS
# LAP 52 TIME -> 0:0:3
#
# RUN FOR LLOY - 52
# 	SUCCESS
# LAP 53 TIME -> 0:0:2
#
# RUN FOR LSE - 53
# 	SUCCESS
# LAP 54 TIME -> 0:0:2
#
# RUN FOR MGGT - 54
# 	SUCCESS
# LAP 55 TIME -> 0:0:3
#
# RUN FOR MRO - 55
# 	SUCCESS
# LAP 56 TIME -> 0:0:1
#
# RUN FOR MNDI - 56
# 	SUCCESS
# LAP 57 TIME -> 0:0:1
#
# RUN FOR MRW - 57
# 	SUCCESS
# LAP 58 TIME -> 0:0:2
#
# RUN FOR NG - 58
# 	SUCCESS
# LAP 59 TIME -> 0:0:2
#
# RUN FOR NXT - 59
# 	SUCCESS
# LAP 60 TIME -> 0:0:3
#
# RUN FOR NMC - 60
# 	SUCCESS
# LAP 61 TIME -> 0:0:0
#
# RUN FOR OCDO - 61
# 	SUCCESS
# LAP 62 TIME -> 0:0:1
#
# RUN FOR PSON - 62
# 	SUCCESS
# LAP 63 TIME -> 0:0:2
#
# RUN FOR PSN - 63
# 	SUCCESS
# LAP 64 TIME -> 0:0:3
#
# RUN FOR PHNX - 64
# 	SUCCESS
# LAP 65 TIME -> 0:0:1
#
# RUN FOR POLY - 65
# 	SUCCESS
# LAP 66 TIME -> 0:0:1
#
# RUN FOR PRU - 66
# 	SUCCESS
# LAP 67 TIME -> 0:0:3
#
# RUN FOR RDSA - 67
# 	SUCCESS
# LAP 68 TIME -> 0:0:0
#
# RUN FOR RDSB - 68
# 	SUCCESS
# LAP 69 TIME -> 0:0:2
#
# RUN FOR RB - 69
# 	SUCCESS
# LAP 70 TIME -> 0:0:2
#
# RUN FOR REL - 70
# 	SUCCESS
# LAP 71 TIME -> 0:0:2
#
# RUN FOR RTO - 71
# 	SUCCESS
# LAP 72 TIME -> 0:0:2
#
# RUN FOR RMV - 72
# 	SUCCESS
# LAP 73 TIME -> 0:0:1
#
# RUN FOR RIO - 73
# 	SUCCESS
# LAP 74 TIME -> 0:0:3
#
# RUN FOR RR - 74
# 	SUCCESS
# LAP 75 TIME -> 0:0:3
#
# RUN FOR RBS - 75
# 	SUCCESS
# LAP 76 TIME -> 0:0:3
#
# RUN FOR RSA - 76
# 	SUCCESS
# LAP 77 TIME -> 0:0:2
#
# RUN FOR SGE - 77
# 	SUCCESS
# LAP 78 TIME -> 0:0:3
#
# RUN FOR SBRY - 78
# 	SUCCESS
# LAP 79 TIME -> 0:0:3
#
# RUN FOR SDR - 79
# 	SUCCESS
# LAP 80 TIME -> 0:0:3
#
# RUN FOR SMT - 80
# 	SUCCESS
# LAP 81 TIME -> 0:0:0
#
# RUN FOR SGRO - 81
# 	SUCCESS
# LAP 82 TIME -> 0:0:4
#
# RUN FOR SVT - 82
# 	SUCCESS
# LAP 83 TIME -> 0:0:3
#
# RUN FOR SN - 83
# 	SUCCESS
# LAP 84 TIME -> 0:0:3
#
# RUN FOR SMDS - 84
# 	SUCCESS
# LAP 85 TIME -> 0:0:3
#
# RUN FOR SMIN - 85
# 	SUCCESS
# LAP 86 TIME -> 0:0:3
#
# RUN FOR SKG - 86
# 	SUCCESS
# LAP 87 TIME -> 0:0:1
#
# RUN FOR SPX - 87
# 	SUCCESS
# LAP 88 TIME -> 0:0:3
#
# RUN FOR SSE - 88
# 	SUCCESS
# LAP 89 TIME -> 0:0:2
#
# RUN FOR STJ - 89
# 	SUCCESS
# LAP 90 TIME -> 0:0:3
#
# RUN FOR STAN - 90
# 	SUCCESS
# LAP 91 TIME -> 0:0:3
#
# RUN FOR SLA - 91
# 	SUCCESS
# LAP 92 TIME -> 0:0:1
#
# RUN FOR TW - 92
# 	SUCCESS
# LAP 93 TIME -> 0:0:3
#
# RUN FOR TSCO - 93
# 	SUCCESS
# LAP 94 TIME -> 0:0:2
#
# RUN FOR TUI - 94
# 	SUCCESS
# LAP 95 TIME -> 0:0:0
#
# RUN FOR ULVR - 95
# 	SUCCESS
# LAP 96 TIME -> 0:0:2
#
# RUN FOR UU - 96
# 	SUCCESS
# LAP 97 TIME -> 0:0:3
#
# RUN FOR VOD - 97
# 	SUCCESS
# LAP 98 TIME -> 0:0:2
#
# RUN FOR WTB - 98
# 	SUCCESS
# LAP 99 TIME -> 0:0:2
#
# RUN FOR WPP - 99
# 	SUCCESS
# LAP 100 TIME -> 0:0:1
#
# RUN FOR 3IN - 100
# 	SUCCESS
# LAP 101 TIME -> 0:0:1
#
# RUN FOR FOUR - 101
# 	SUCCESS
# LAP 102 TIME -> 0:0:2
#
# RUN FOR 888 - 102
# 	SUCCESS
# LAP 103 TIME -> 0:0:1
#
# RUN FOR ASL - 103
# 	SUCCESS
# LAP 104 TIME -> 0:0:1
#
# RUN FOR AGK - 104
# 	SUCCESS
# LAP 105 TIME -> 0:0:2
#
# RUN FOR AJB - 105
# 	SUCCESS
# LAP 106 TIME -> 0:0:0
#
# RUN FOR ATST - 106
# 	SUCCESS
# LAP 107 TIME -> 0:0:1
#
# RUN FOR APAX - 107
# 	SUCCESS
# LAP 108 TIME -> 0:0:0
#
# RUN FOR ASCL - 108
# 	SUCCESS
# LAP 109 TIME -> 0:0:0
#
# RUN FOR ASHM - 109
# 	SUCCESS
# LAP 110 TIME -> 0:0:1
#
# RUN FOR AGR - 110
# 	SUCCESS
# LAP 111 TIME -> 0:0:2
#
# RUN FOR AML - 111
# 	SUCCESS
# LAP 112 TIME -> 0:0:0
#
# RUN FOR AVST - 112
# 	SUCCESS
# LAP 113 TIME -> 0:0:0
#
# RUN FOR BME - 113
# 	SUCCESS
# LAP 114 TIME -> 0:0:0
#
# RUN FOR BAB - 114
# 	SUCCESS
# LAP 115 TIME -> 0:0:2
#
# RUN FOR BGFD - 115
# 	SUCCESS
# LAP 116 TIME -> 0:0:1
#
# RUN FOR BAKK - 116
# 	SUCCESS
# LAP 117 TIME -> 0:0:0
#
# RUN FOR BBY - 117
# 	SUCCESS
# LAP 118 TIME -> 0:0:2
#
# RUN FOR BGEO - 118
# 	SUCCESS
# LAP 119 TIME -> 0:0:1
#
# RUN FOR BNKR - 119
# 	SUCCESS
# LAP 120 TIME -> 0:0:1
#
# RUN FOR BAG - 120
# 	SUCCESS
# LAP 121 TIME -> 0:0:2
#
# RUN FOR BBGI - 121
# 	SUCCESS
# LAP 122 TIME -> 0:0:1
#
# RUN FOR BEZ - 122
# 	SUCCESS
# LAP 123 TIME -> 0:0:0
#
# RUN FOR BWY - 123
# 	SUCCESS
# LAP 124 TIME -> 0:0:3
#
# RUN FOR BYG - 124
# 	SUCCESS
# LAP 125 TIME -> 0:0:2
#
# RUN FOR BRSC - 125
# 	SUCCESS
# LAP 126 TIME -> 0:0:0
#
# RUN FOR BRWM - 126
# 	SUCCESS
# LAP 127 TIME -> 0:0:1
#
# RUN FOR BGSC - 127
# 	SUCCESS
# LAP 128 TIME -> 0:0:1
#
# RUN FOR BOY - 128
# 	SUCCESS
# LAP 129 TIME -> 0:0:2
#
# RUN FOR BVS - 129
# 	SUCCESS
# LAP 130 TIME -> 0:0:2
#
# RUN FOR BRW - 130
# 	SUCCESS
# LAP 131 TIME -> 0:0:2
#
# RUN FOR BVIC - 131
# 	SUCCESS
# LAP 132 TIME -> 0:0:1
#
# RUN FOR CNE - 132
# 	SUCCESS
# LAP 133 TIME -> 0:0:3
#
# RUN FOR CLDN - 133
# 	SUCCESS
# LAP 134 TIME -> 0:0:1
#
# RUN FOR CAPC - 134
# 	SUCCESS
# LAP 135 TIME -> 0:0:1
#
# RUN FOR CPI - 135
# 	SUCCESS
# LAP 136 TIME -> 0:0:3
#
# RUN FOR CARD - 136
# 	SUCCESS
# LAP 137 TIME -> 0:0:0
#
# RUN FOR CEY - 137
# 	SUCCESS
# LAP 138 TIME -> 0:0:2
#
# RUN FOR CINE - 138
# 	SUCCESS
# LAP 139 TIME -> 0:0:1
#
# RUN FOR CTY - 139
# 	SUCCESS
# LAP 140 TIME -> 0:0:1
#
# RUN FOR CKN - 140
# 	SUCCESS
# LAP 141 TIME -> 0:0:3
#
# RUN FOR CBG - 141
# 	SUCCESS
# LAP 142 TIME -> 0:0:2
#
# RUN FOR CLI - 142
# 	SUCCESS
# LAP 143 TIME -> 0:0:3
#
# RUN FOR COA - 143
# 	SUCCESS
# LAP 144 TIME -> 0:0:3
#
# RUN FOR COB - 144
# 	SUCCESS
# LAP 145 TIME -> 0:0:2
#
# RUN FOR CCC - 145
# 	SUCCESS
# LAP 146 TIME -> 0:0:2
#
# RUN FOR GLO - 146
# 	SUCCESS
# LAP 147 TIME -> 0:0:0
#
# RUN FOR CTEC - 147
# 	SUCCESS
# LAP 148 TIME -> 0:0:0
#
# RUN FOR CSP - 148
# 	SUCCESS
# LAP 149 TIME -> 0:0:1
#
# RUN FOR CWK - 149
# 	SUCCESS
# LAP 150 TIME -> 0:0:2
#
# RUN FOR CRST - 150
# 	SUCCESS
# LAP 151 TIME -> 0:0:0
#
# RUN FOR DJAN - 151
# 	SUCCESS
# LAP 152 TIME -> 0:0:2
#
# RUN FOR DPH - 152
# 	SUCCESS
# LAP 153 TIME -> 0:0:2
#
# RUN FOR DLN - 153
# 	SUCCESS
# LAP 154 TIME -> 0:0:2
#
# RUN FOR DPLM - 154
# 	SUCCESS
# LAP 155 TIME -> 0:0:3
#
# RUN FOR DLG - 155
# 	SUCCESS
# LAP 156 TIME -> 0:0:0
#
# RUN FOR DC - 156
# 	SUCCESS
# LAP 157 TIME -> 0:0:1
#
# RUN FOR DOM - 157
# 	SUCCESS
# LAP 158 TIME -> 0:0:2
#
# RUN FOR DRX - 158
# 	SUCCESS
# LAP 159 TIME -> 0:0:1
#
# RUN FOR DNLM - 159
# 	SUCCESS
# LAP 160 TIME -> 0:0:1
#
# RUN FOR EZJ - 160
# 	SUCCESS
# LAP 161 TIME -> 0:0:2
#
# RUN FOR EDIN - 161
# 	SUCCESS
# LAP 162 TIME -> 0:0:1
#
# RUN FOR EIG - 162
# 	SUCCESS
# LAP 163 TIME -> 0:0:1
#
# RUN FOR ECM - 163
# 	SUCCESS
# LAP 164 TIME -> 0:0:2
#
# RUN FOR ELM - 164
# 	SUCCESS
# LAP 165 TIME -> 0:0:3
#
# RUN FOR ENOG - 165
# 	SUCCESS
# LAP 166 TIME -> 0:0:0
#
# RUN FOR ETO - 166
# 	SUCCESS
# LAP 167 TIME -> 0:0:1
#
# RUN FOR EQN - 167
# 	SUCCESS
# LAP 168 TIME -> 0:0:0
#
# RUN FOR ESNT - 168
# 	SUCCESS
# LAP 169 TIME -> 0:0:1
#
# RUN FOR JEO - 169
# 	SUCCESS
# LAP 170 TIME -> 0:0:1
#
# RUN FOR ERM - 170
# 	SUCCESS
# LAP 171 TIME -> 0:0:2
#
# RUN FOR FCIT - 171
# 	SUCCESS
# LAP 172 TIME -> 0:0:1
#
# RUN FOR FDM - 172
# 	SUCCESS
# LAP 173 TIME -> 0:0:0
#
# RUN FOR FXPO - 173
# 	SUCCESS
# LAP 174 TIME -> 0:0:1
#
# RUN FOR FEV - 174
# 	SUCCESS
# LAP 175 TIME -> 0:0:1
#
# RUN FOR FSV - 175
# 	SUCCESS
# LAP 176 TIME -> 0:0:1
#
# RUN FOR FCSS - 176
# 	SUCCESS
# LAP 177 TIME -> 0:0:1
#
# RUN FOR FGT - 177
# 	SUCCESS
# LAP 178 TIME -> 0:0:1
#
# RUN FOR FGP - 178
# 	SUCCESS
# LAP 179 TIME -> 0:0:2
#
# RUN FOR FSJ - 179
# 	SUCCESS
# LAP 180 TIME -> 0:0:2
#
# RUN FOR FSFL - 180
# 	SUCCESS
# LAP 181 TIME -> 0:0:0
#
# RUN FOR FUTR - 181
# 	SUCCESS
# LAP 182 TIME -> 0:0:2
#
# RUN FOR GFS - 182
# 	SUCCESS
# LAP 183 TIME -> 0:0:1
#
# RUN FOR GFRD - 183
# 	SUCCESS
# LAP 184 TIME -> 0:0:3
#
# RUN FOR GAW - 184
# 	SUCCESS
# LAP 185 TIME -> 0:0:3
#
# RUN FOR GCP - 185
# 	SUCCESS
# LAP 186 TIME -> 0:0:1
#
# RUN FOR DIGS - 186
# 	SUCCESS
# LAP 187 TIME -> 0:0:0
#
# RUN FOR GSS - 187
# 	SUCCESS
# LAP 188 TIME -> 0:0:1
#
# RUN FOR GNS - 188
# 	SUCCESS
# LAP 189 TIME -> 0:0:2
#
# RUN FOR GOG - 189
# 	SUCCESS
# LAP 190 TIME -> 0:0:2
#
# RUN FOR GPOR - 190
# 	SUCCESS
# LAP 191 TIME -> 0:0:2
#
# RUN FOR GFTU - 191
# 	SUCCESS
# LAP 192 TIME -> 0:0:2
#
# RUN FOR GRI - 192
# 	SUCCESS
# LAP 193 TIME -> 0:0:2
#
# RUN FOR UKW - 193
# 	SUCCESS
# LAP 194 TIME -> 0:0:0
#
# RUN FOR GNC - 194
# 	SUCCESS
# LAP 195 TIME -> 0:0:2
#
# RUN FOR GRG - 195
# 	SUCCESS
# LAP 196 TIME -> 0:0:2
#
# RUN FOR GVC - 196
# 	SUCCESS
# LAP 197 TIME -> 0:0:1
#
# RUN FOR HMSO - 197
# 	SUCCESS
# LAP 198 TIME -> 0:0:2
#
# RUN FOR HVPE - 198
# 	SUCCESS
# LAP 199 TIME -> 0:0:1
#
# RUN FOR HSTG - 199
# 	SUCCESS
# LAP 200 TIME -> 0:0:0
#
# RUN FOR HAS - 200
# 	SUCCESS
# LAP 201 TIME -> 0:0:2
#
# RUN FOR HSL - 201
# 	SUCCESS
# LAP 202 TIME -> 0:0:1
#
# RUN FOR HRI - 202
# 	SUCCESS
# LAP 203 TIME -> 0:0:1
#
# RUN FOR HGT - 203
# 	SUCCESS
# LAP 204 TIME -> 0:0:1
#
# RUN FOR HICL - 204
# 	SUCCESS
# LAP 205 TIME -> 0:0:1
#
# RUN FOR HILS - 205
# 	SUCCESS
# LAP 206 TIME -> 0:0:2
#
# RUN FOR HFG - 206
# 	SUCCESS
# LAP 207 TIME -> 0:0:1
#
# RUN FOR HOC - 207
# 	SUCCESS
# LAP 208 TIME -> 0:0:1
#
# RUN FOR HSV - 208
# 	SUCCESS
# LAP 209 TIME -> 0:0:2
#
# RUN FOR HWDN - 209
# 	SUCCESS
# LAP 210 TIME -> 0:0:2
#
# RUN FOR HTG - 210
# 	SUCCESS
# LAP 211 TIME -> 0:0:2
#
# RUN FOR IBST - 211
# 	SUCCESS
# LAP 212 TIME -> 0:0:0
#
# RUN FOR ICGT - 212
# 	SUCCESS
# LAP 213 TIME -> 0:0:1
#
# RUN FOR IGG - 213
# 	SUCCESS
# LAP 214 TIME -> 0:0:1
#
# RUN FOR IMI - 214
# 	SUCCESS
# LAP 215 TIME -> 0:0:2
#
# RUN FOR INCH - 215
# 	SUCCESS
# LAP 216 TIME -> 0:0:2
#
# RUN FOR ICP - 216
# 	SUCCESS
# LAP 217 TIME -> 0:0:2
#
# RUN FOR IHP - 217
# 	SUCCESS
# LAP 218 TIME -> 0:0:0
#
# RUN FOR INPP - 218
# 	SUCCESS
# LAP 219 TIME -> 0:0:1
#
# RUN FOR INVP - 219
# 	SUCCESS
# LAP 220 TIME -> 0:0:2
#
# RUN FOR IPO - 220
# 	SUCCESS
# LAP 221 TIME -> 0:0:1
#
# RUN FOR IWG - 221
# 	SUCCESS
# LAP 222 TIME -> 0:0:1
#
# RUN FOR JLG - 222
# 	SUCCESS
# LAP 223 TIME -> 0:0:0
#
# RUN FOR JII - 223
# 	SUCCESS
# LAP 224 TIME -> 0:0:1
#
# RUN FOR JAM - 224
# 	SUCCESS
# LAP 225 TIME -> 0:0:1
#
# RUN FOR JMG - 225
# 	SUCCESS
# LAP 226 TIME -> 0:0:1
#
# RUN FOR JFJ - 226
# 	SUCCESS
# LAP 227 TIME -> 0:0:1
#
# RUN FOR JUP - 227
# 	SUCCESS
# LAP 228 TIME -> 0:0:1
#
# RUN FOR JE - 228
# 	SUCCESS
# LAP 229 TIME -> 0:0:0
#
# RUN FOR KNOS - 229
# 	SUCCESS
# LAP 230 TIME -> 0:0:0
#
# RUN FOR KAZ - 230
# 	SUCCESS
# LAP 231 TIME -> 0:0:1
#
# RUN FOR LRE - 231
# 	SUCCESS
# LAP 232 TIME -> 0:0:1
#
# RUN FOR LWDB - 232
# 	SUCCESS
# LAP 233 TIME -> 0:0:1
#
# RUN FOR LMP - 233
# 	SUCCESS
# LAP 234 TIME -> 0:0:1
#
# RUN FOR EMG - 234
# 	SUCCESS
# LAP 235 TIME -> 0:0:2
#
# RUN FOR MKS - 235
# 	SUCCESS
# LAP 236 TIME -> 0:0:2
#
# RUN FOR MSLH - 236
# 	SUCCESS
# LAP 237 TIME -> 0:0:2
#
# RUN FOR MARS - 237
# 	SUCCESS
# LAP 238 TIME -> 0:0:1
#
# RUN FOR MCS - 238
# 	SUCCESS
# LAP 239 TIME -> 0:0:0
#
# RUN FOR MDC - 239
# 	SUCCESS
# LAP 240 TIME -> 0:0:0
#
# RUN FOR MRC - 240
# 	SUCCESS
# LAP 241 TIME -> 0:0:1
#
# RUN FOR MCRO - 241
# 	SUCCESS
# LAP 242 TIME -> 0:0:2
#
# RUN FOR MAB - 242
# 	SUCCESS
# LAP 243 TIME -> 0:0:2
#
# RUN FOR MONY - 243
# 	SUCCESS
# LAP 244 TIME -> 0:0:2
#
# RUN FOR MNKS - 244
# 	SUCCESS
# LAP 245 TIME -> 0:0:1
#
# RUN FOR MGAM - 245
# 	SUCCESS
# LAP 246 TIME -> 0:0:4
#
# RUN FOR MYI - 246
# 	SUCCESS
# LAP 247 TIME -> 0:0:1
#
# RUN FOR NEX - 247
# 	SUCCESS
# LAP 248 TIME -> 0:0:3
#
# RUN FOR NBLS - 248
# 	SUCCESS
# LAP 249 TIME -> 0:0:1
#
# RUN FOR NETW - 249
# 	SUCCESS
# LAP 250 TIME -> 0:0:0
#
# RUN FOR NRR - 250
# 	SUCCESS
# LAP 251 TIME -> 0:0:1
#
# RUN FOR NESF - 251
# 	SUCCESS
# LAP 252 TIME -> 0:0:0
#
# RUN FOR OSB - 252
# 	SUCCESS
# LAP 253 TIME -> 0:0:0
#
# RUN FOR OXIG - 253
# 	SUCCESS
# LAP 254 TIME -> 0:0:3
#
# RUN FOR PAGE - 254
# 	SUCCESS
# LAP 255 TIME -> 0:0:2
#
# RUN FOR PIN - 255
# 	SUCCESS
# LAP 256 TIME -> 0:0:1
#
# RUN FOR PAG - 256
# 	SUCCESS
# LAP 257 TIME -> 0:0:3
#
# RUN FOR PAY - 257
# 	SUCCESS
# LAP 258 TIME -> 0:0:1
#
# RUN FOR PNN - 258
# 	SUCCESS
# LAP 259 TIME -> 0:0:3
#
# RUN FOR PLI - 259
# 	SUCCESS
# LAP 260 TIME -> 0:0:1
#
# RUN FOR PSH - 260
# 	SUCCESS
# LAP 261 TIME -> 0:0:0
#
# RUN FOR PNL - 261
# 	SUCCESS
# LAP 262 TIME -> 0:0:1
#
# RUN FOR PFC - 262
# 	SUCCESS
# LAP 263 TIME -> 0:0:1
#
# RUN FOR PETS - 263
# 	SUCCESS
# LAP 264 TIME -> 0:0:0
#
# RUN FOR PTEC - 264
# 	SUCCESS
# LAP 265 TIME -> 0:0:1
#
# RUN FOR PLUS - 265
# 	SUCCESS
# LAP 266 TIME -> 0:0:0
#
# RUN FOR PCT - 266
# 	SUCCESS
# LAP 267 TIME -> 0:0:1
#
# RUN FOR PLP - 267
# 	SUCCESS
# LAP 268 TIME -> 0:0:0
#
# RUN FOR PPH - 268
# 	SUCCESS
# LAP 269 TIME -> 0:0:1
#
# RUN FOR PMO - 269
# 	SUCCESS
# LAP 270 TIME -> 0:0:3
#
# RUN FOR PHP - 270
# 	SUCCESS
# LAP 271 TIME -> 0:0:2
#
# RUN FOR PFG - 271
# 	SUCCESS
# LAP 272 TIME -> 0:0:2
#
# RUN FOR PRTC - 272
# 	SUCCESS
# LAP 273 TIME -> 0:0:0
#
# RUN FOR PZC - 273
# 	SUCCESS
# LAP 274 TIME -> 0:0:2
#
# RUN FOR QQ - 274
# 	SUCCESS
# LAP 275 TIME -> 0:0:1
#
# RUN FOR QLT - 275
# 	SUCCESS
# LAP 276 TIME -> 0:0:0
#
# RUN FOR RNK - 276
# 	SUCCESS
# LAP 277 TIME -> 0:0:2
#
# RUN FOR RAT - 277
# 	SUCCESS
# LAP 278 TIME -> 0:0:2
#
# RUN FOR RDW - 278
# 	SUCCESS
# LAP 279 TIME -> 0:0:2
#
# RUN FOR TRIG - 279
# 	SUCCESS
# LAP 280 TIME -> 0:0:0
#
# RUN FOR RSW - 280
# 	SUCCESS
# LAP 281 TIME -> 0:0:2
#
# RUN FOR RTN - 281
# 	SUCCESS
# LAP 282 TIME -> 0:0:2
#
# RUN FOR RHIM - 282
# 	SUCCESS
# LAP 283 TIME -> 0:0:0
#
# RUN FOR RCP - 283
# 	SUCCESS
# LAP 284 TIME -> 0:0:0
#
# RUN FOR RSE - 284
# 	SUCCESS
# LAP 285 TIME -> 0:0:0
#
# RUN FOR ROR - 285
# 	SUCCESS
# LAP 286 TIME -> 0:0:2
#
# RUN FOR RMG - 286
# 	SUCCESS
# LAP 287 TIME -> 0:0:0
#
# RUN FOR SBRE - 287
# 	SUCCESS
# LAP 288 TIME -> 0:0:0
#
# RUN FOR SAFE - 288
# 	SUCCESS
# LAP 289 TIME -> 0:0:1
#
# RUN FOR SNN - 289
# 	SUCCESS
# LAP 290 TIME -> 0:0:0
#
# RUN FOR SVS - 290
# 	SUCCESS
# LAP 291 TIME -> 0:0:3
#
# RUN FOR SDP - 291
# 	SUCCESS
# LAP 292 TIME -> 0:0:1
#
# RUN FOR SOI - 292
# 	SUCCESS
# LAP 293 TIME -> 0:0:1
#
# RUN FOR SCIN - 293
# 	SUCCESS
# LAP 294 TIME -> 0:0:1
#
# RUN FOR SNR - 294
# 	SUCCESS
# LAP 295 TIME -> 0:0:3
#
# RUN FOR SEQI - 295
# 	SUCCESS
# LAP 296 TIME -> 0:0:0
#
# RUN FOR SRP - 296
# 	SUCCESS
# LAP 297 TIME -> 0:0:3
#
# RUN FOR SHB - 297
# 	SUCCESS
# LAP 298 TIME -> 0:0:2
#
# RUN FOR SHI - 298
# 	SUCCESS
# LAP 299 TIME -> 0:0:3
#
# RUN FOR SRE - 299
# 	SUCCESS
# LAP 300 TIME -> 0:0:1
#
# RUN FOR SSON - 300
# 	SUCCESS
# LAP 301 TIME -> 0:0:0
#
# RUN FOR SCT - 301
# 	SUCCESS
# LAP 302 TIME -> 0:0:0
#
# RUN FOR SOPH - 302
# 	SUCCESS
# LAP 303 TIME -> 0:0:0
#
# RUN FOR SXS - 303
# 	SUCCESS
# LAP 304 TIME -> 0:0:3
#
# RUN FOR SPT - 304
# 	SUCCESS
# LAP 305 TIME -> 0:0:2
#
# RUN FOR SPD - 305
# 	SUCCESS
# LAP 306 TIME -> 0:0:1
#
# RUN FOR SSPG - 306
# 	SUCCESS
# LAP 307 TIME -> 0:0:0
#
# RUN FOR SMP - 307
# 	SUCCESS
# LAP 308 TIME -> 0:0:3
#
# RUN FOR SGC - 308
# 	SUCCESS
# LAP 309 TIME -> 0:0:2
#
# RUN FOR SYNC - 309
# 	SUCCESS
# LAP 310 TIME -> 0:0:0
#
# RUN FOR SYNT - 310
# 	SUCCESS
# LAP 311 TIME -> 0:0:3
#
# RUN FOR TALK - 311
# 	SUCCESS
# LAP 312 TIME -> 0:0:1
#
# RUN FOR TATE - 312
# 	SUCCESS
# LAP 313 TIME -> 0:0:2
#
# RUN FOR TBCG - 313
# 	SUCCESS
# LAP 314 TIME -> 0:0:0
#
# RUN FOR TEP - 314
# 	SUCCESS
# LAP 315 TIME -> 0:0:2
#
# RUN FOR TMPL - 315
# 	SUCCESS
# LAP 316 TIME -> 0:0:1
#
# RUN FOR TEM - 316
# 	SUCCESS
# LAP 317 TIME -> 0:0:1
#
# RUN FOR TIFS - 317
# 	SUCCESS
# LAP 318 TIME -> 0:0:0
#
# RUN FOR TCAP - 318
# 	SUCCESS
# LAP 319 TIME -> 0:0:2
#
# RUN FOR TRY - 319
# 	SUCCESS
# LAP 320 TIME -> 0:0:1
#
# RUN FOR TPK - 320
# 	SUCCESS
# LAP 321 TIME -> 0:0:2
#
# RUN FOR BBOX - 321
# 	SUCCESS
# LAP 322 TIME -> 0:0:0
#
# RUN FOR TLW - 322
# 	SUCCESS
# LAP 323 TIME -> 0:0:2
#
# RUN FOR UDG - 323
# 	SUCCESS
# LAP 324 TIME -> 0:0:2
#
# RUN FOR UKCM - 324
# 	SUCCESS
# LAP 325 TIME -> 0:0:1
#
# RUN FOR ULE - 325
# 	SUCCESS
# LAP 326 TIME -> 0:0:2
#
# RUN FOR UTG - 326
# 	SUCCESS
# LAP 327 TIME -> 0:0:0
#
# RUN FOR VSVS - 327
# 	SUCCESS
# LAP 328 TIME -> 0:0:2
#
# RUN FOR VCT - 328
# 	SUCCESS
# LAP 329 TIME -> 0:0:2
#
# RUN FOR VEIL - 329
# 	SUCCESS
# LAP 330 TIME -> 0:0:0
#
# RUN FOR VOF - 330
# 	SUCCESS
# LAP 331 TIME -> 0:0:1
#
# RUN FOR VVO - 331
# 	SUCCESS
# LAP 332 TIME -> 0:0:0
#
# RUN FOR WEIR - 332
# 	SUCCESS
# LAP 333 TIME -> 0:0:3
#
# RUN FOR JDW - 333
# 	SUCCESS
# LAP 334 TIME -> 0:0:3
#
# RUN FOR SMWH - 334
# 	SUCCESS
# LAP 335 TIME -> 0:0:1
#
# RUN FOR WMH - 335
# 	SUCCESS
# LAP 336 TIME -> 0:0:2
#
# RUN FOR WTAN - 336
# 	SUCCESS
# LAP 337 TIME -> 0:0:1
#
# RUN FOR WIZZ - 337
# 	SUCCESS
# LAP 338 TIME -> 0:0:0
#
# RUN FOR WG - 338
# 	SUCCESS
# LAP 339 TIME -> 0:0:2
#
# RUN FOR WKP - 339
# 	SUCCESS
# LAP 340 TIME -> 0:0:2
#
# RUN FOR WWH - 340
# 	SUCCESS
# LAP 341 TIME -> 0:0:1
# TOTAL ELAPSED TIME -> 0:11:19
#
#
# COMPLETED - ERRORS ENCOUNTERED -> 0

# %%
#Get in-row price change
def calc_changes(_s_in,_prev_s_in):
    """Function used to calculate the change between two values, absolute and percentage
    
    args:
    -----
    _s_in - pandas series - the current value to be compared
    _prev_s_in - pandas series - the base value to compare the values to
    
    returns:
    ------
    tuple - pandas series, pandas series - absolute change, percentage change
    """
    _s_change = _s_in - _prev_s_in
    _s_per_change = _s_change / _s_in
    return (_s_change,_s_per_change)

#Relabel col names
for col in df_prices_w:
    df_prices_w.rename(columns={col:col.lower()},inplace=True)
    
df_prices_w["change_price"],df_prices_w["per_change_price"] = calc_changes(df_prices_w.close.copy(),df_prices_w.open.copy())
df_prices_w.head()
# Out:
#        ticker       date      high       low    volume      open     close  \
# 128355    III 2007-12-31       NaN       NaN       NaN       NaN       NaN
# 128356    III 2008-01-07  0.000000  0.000000  1.000000  0.000000  0.000000
# 128357    III 2008-01-14  0.000000  0.000000  1.000000  0.000000  0.000000
# 128358    III 2008-01-21  0.333333  0.000000  0.776440  0.000000  0.257812
# 128359    III 2008-01-28  0.402299  0.478632  0.440501  0.192308  0.937500
#
#         change  ema12  ema26  macd_line  signal_line  macd  open_orig  \
# 128355   -30.0    NaN    NaN        NaN          NaN   NaN      995.0
# 128356   -43.5    NaN    NaN        NaN          NaN   NaN      967.5
# 128357   -16.0    NaN    NaN        NaN          NaN   NaN      917.0
# 128358    26.5    NaN    NaN        NaN          NaN   NaN      891.0
# 128359    50.0    NaN    NaN        NaN          NaN   NaN      911.0
#
#         close_orig  high_orig  low_orig  volume_orig  change_price  \
# 128355       965.0     1023.0     964.0    4511565.0           NaN
# 128356       924.0      989.0     917.5   16056554.0      0.000000
# 128357       901.0      936.0     881.0   21691287.0      0.000000
# 128358       917.5      965.0     847.0   17850580.0      0.257812
# 128359       961.0      971.0     903.0   12079245.0      0.745192
#
#         per_change_price
# 128355               NaN
# 128356               NaN
# 128357               NaN
# 128358          1.000000
# 128359          0.794872

# %%
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print(df_prices_w.ticker.unique())
df_prices_w.head()
# Out:
# ['3IN' '888' 'AAL' 'ABF' 'ADM' 'AGK' 'AGR' 'AHT' 'AJB' 'AML' 'ANTO' 'APAX'
#  'ASCL' 'ASHM' 'ASL' 'ATST' 'AUTO' 'AV' 'AVST' 'AVV' 'AZN' 'BA' 'BAB'
#  'BAG' 'BAKK' 'BARC' 'BATS' 'BBGI' 'BBOX' 'BBY' 'BDEV' 'BEZ' 'BGEO' 'BGFD'
#  'BGSC' 'BHP' 'BKG' 'BLND' 'BME' 'BNKR' 'BNZL' 'BOY' 'BP' 'BRBY' 'BRSC'
#  'BRW' 'BRWM' 'BT-A' 'BVIC' 'BVS' 'BWY' 'BYG' 'CAPC' 'CARD' 'CBG' 'CCC'
#  'CCH' 'CCL' 'CEY' 'CINE' 'CKN' 'CLDN' 'CLI' 'CNA' 'CNE' 'COA' 'COB' 'CPG'
#  'CPI' 'CRDA' 'CRH' 'CRST' 'CSP' 'CTEC' 'CTY' 'CWK' 'DC' 'DCC' 'DGE'
#  'DIGS' 'DJAN' 'DLG' 'DLN' 'DNLM' 'DOM' 'DPH' 'DPLM' 'DRX' 'ECM' 'EDIN'
#  'EIG' 'ELM' 'EMG' 'ENOG' 'EQN' 'ERM' 'ESNT' 'ETO' 'EVR' 'EXPN' 'EZJ'
#  'FCIT' 'FCSS' 'FDM' 'FERG' 'FEV' 'FGP' 'FGT' 'FOUR' 'FRES' 'FSFL' 'FSJ'
#  'FSV' 'FUTR' 'FXPO' 'GAW' 'GCP' 'GFRD' 'GFS' 'GFTU' 'GLEN' 'GLO' 'GNC'
#  'GNS' 'GOG' 'GPOR' 'GRG' 'GRI' 'GSK' 'GSS' 'GVC' 'HAS' 'HFG' 'HGT' 'HICL'
#  'HIK' 'HILS' 'HL' 'HLMA' 'HMSO' 'HOC' 'HRI' 'HSBA' 'HSL' 'HSTG' 'HSV'
#  'HSX' 'HTG' 'HVPE' 'HWDN' 'IAG' 'IBST' 'ICGT' 'ICP' 'IGG' 'IHG' 'IHP'
#  'III' 'IMB' 'IMI' 'INCH' 'INF' 'INPP' 'INVP' 'IPO' 'ITRK' 'ITV' 'IWG'
#  'JAM' 'JD' 'JDW' 'JE' 'JEO' 'JFJ' 'JII' 'JLG' 'JMAT' 'JMG' 'JUP' 'KAZ'
#  'KGF' 'KNOS' 'LAND' 'LGEN' 'LLOY' 'LMP' 'LRE' 'LSE' 'LWDB' 'MAB' 'MARS'
#  'MCRO' 'MCS' 'MDC' 'MGAM' 'MGGT' 'MKS' 'MNDI' 'MNKS' 'MONY' 'MRC' 'MRO'
#  'MRW' 'MSLH' 'MYI' 'NBLS' 'NESF' 'NETW' 'NEX' 'NG' 'NMC' 'NRR' 'NXT'
#  'OCDO' 'OSB' 'OXIG' 'PAG' 'PAGE' 'PAY' 'PCT' 'PETS' 'PFC' 'PFG' 'PHNX'
#  'PHP' 'PIN' 'PLI' 'PLP' 'PLUS' 'PMO' 'PNL' 'PNN' 'POLY' 'PPH' 'PRTC'
#  'PRU' 'PSH' 'PSN' 'PSON' 'PTEC' 'PZC' 'QLT' 'QQ' 'RAT' 'RB' 'RBS' 'RCP'
#  'RDSA' 'RDSB' 'RDW' 'REL' 'RHIM' 'RIO' 'RMG' 'RMV' 'RNK' 'ROR' 'RR' 'RSA'
#  'RSE' 'RSW' 'RTN' 'RTO' 'SAFE' 'SBRE' 'SBRY' 'SCIN' 'SCT' 'SDP' 'SDR'
#  'SEQI' 'SGC' 'SGE' 'SGRO' 'SHB' 'SHI' 'SKG' 'SLA' 'SMDS' 'SMIN' 'SMP'
#  'SMT' 'SMWH' 'SN' 'SNN' 'SNR' 'SOI' 'SOPH' 'SPD' 'SPT' 'SPX' 'SRE' 'SRP'
#  'SSE' 'SSON' 'SSPG' 'STAN' 'STJ' 'SVS' 'SVT' 'SXS' 'SYNC' 'SYNT' 'TALK'
#  'TATE' 'TBCG' 'TCAP' 'TEM' 'TEP' 'TIFS' 'TLW' 'TMPL' 'TPK' 'TRIG' 'TRY'
#  'TSCO' 'TUI' 'TW' 'UDG' 'UKCM' 'UKW' 'ULE' 'ULVR' 'UTG' 'UU' 'VCT' 'VEIL'
#  'VOD' 'VOF' 'VSVS' 'VVO' 'WEIR' 'WG' 'WIZZ' 'WKP' 'WMH' 'WPP' 'WTAN'
#  'WTB' 'WWH']
#   ticker       date  high  low    volume      open  close  change  ema12  \
# 0    3IN 2007-12-31   NaN  NaN       NaN       NaN    NaN   -1.75    NaN
# 1    3IN 2008-01-07   0.0  NaN  1.000000  0.000000    1.0    1.76    NaN
# 2    3IN 2008-01-14   1.0  1.0  0.799111  0.668246    1.0    0.70    NaN
# 3    3IN 2008-01-21   1.0  0.0  1.000000  0.336493    1.0    4.22    NaN
# 4    3IN 2008-01-28   1.0  1.0  0.670041  1.000000    1.0    2.11    NaN
#
#    ema26  macd_line  signal_line  macd  open_orig  close_orig  high_orig  \
# 0    NaN        NaN          NaN   NaN     149.18      147.43     149.89
# 1    NaN        NaN          NaN   NaN     147.07      148.83     149.54
# 2    NaN        NaN          NaN   NaN     148.48      149.18     150.59
# 3    NaN        NaN          NaN   NaN     147.78      152.00     154.82
# 4    NaN        NaN          NaN   NaN     149.89      152.00     154.82
#
#    low_orig  volume_orig  change_price  per_change_price
# 0    147.07    1373801.0           NaN               NaN
# 1    147.07    2345191.0      1.000000          1.000000
# 2    147.43    2150049.0      0.331754          0.331754
# 3    145.32    3070968.0      0.663507          0.663507
# 4    148.83    2510972.0      0.000000          0.000000

# %% [markdown]
# # Create buy signals, and sell signals
# I am classifying a stock worth buying if it meets all the below criteria:
# - The target price (previous max) is hit within x (set as variable target_price_period) periods proceeding this period
# - The target price is an increase of x% (set as variable min_gain) over the proceeding day's open price
# - There is a drop in the closing price of less x% (set as variable max_drop) between this period and the x periods proceeding this period
#
# I am classifying the sell signals as:
# - The close price dips below the target price (previous max) x (set as variable target_price_period) periods proceeding this period
# - There is an increase in the closing price of less x% (set as variable max_drop) over the next x periods

# %%
#Define the variables for buy sell signals
target_price_period = 12
min_gain = 0.1
max_drop = -0.05

# %%
#Programming note
#df.shift(1) looks 1 period into the past
#df.shift(-1) looks 1 period into the future

# %%
#Check if the target price is hit within the target_price_period
def min_gain_check(_var_s,_target_s,_periods:int=12):
    """Function used to check if the value meets the min gain criteria
    
    args:
    -----
    _var_s - pandas series - value to be compared
    _target_s - pandas series - the target value to be hit
    _periods - int - time period to check for gain over
    
    returns:
    ------
    pandas series - bools
    """
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,_periods+1):
        _tmp_check_s = _var_s.shift(-_i) > _target_s #True if price is >= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def max_drop_check(_var_s,_target_s,_periods:int=12):
    """Function used to check if the value meets the max drop criteria
    
    args:
    -----
    _var_s - pandas series - value to be compared
    _target_s - pandas series - the target value to be hit
    _periods - int - time period to check for gain over
    
    returns:
    ------
    pandas series - bools
    """
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,_periods+1):
        _tmp_check_s = _var_s.shift(-_i) < _target_s #True if price is <= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def close_vs_close(_var_s,_shift:int=1):
    """Function used to calculate the change over a given period
    
    args:
    -----
    _var_s - pandas series - values to be compared
    _shift - int - time period to shift _var_s over for comparison
    
    returns:
    ------
    pandas series - floats
    """
    _check_s = _var_s.shift(_shift) - _var_s
    return _check_s

# %%
#Create a function for finding buy signals
def get_buys(var_s):
    """Function used to find if a value meets the requirements for a buy signal
    
    args:
    -----
    _var_s - pandas series - values to be checked
    
    returns:
    ------
    pandas series - bools
    """
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == True #Function returns True when min_gain is hit
    print('BUY min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the sell price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == False #Function returns False when does not go below target
    print('BUY max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Check if the following day is a positive change on today's close price
    close_vs_close_pos_s = close_vs_close(var_s,-1) > 0
    print('BUY close_vs_close_pos_s -> {}'.format(close_vs_close_pos_s[max_drop_s == True].shape))
    
    #Find the buy signals
    s_out = min_gain_s & max_drop_s & close_vs_close_pos_s
    print('BUY ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Function for finding sell signals
def get_sells(var_s):
    """Function used to find if a value meets the requirements for a sell signal
    
    args:
    -----
    _var_s - pandas series - values to be compared
    
    returns:
    ------
    pandas series - bools
    """
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == True #Function returns True when max_drop is hit
    print('SELL max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Perform if the target is crossed again
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == False #Function returns False when min_gain is not hit
    print('SELL min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the following day is a negative change on today's close price
    close_vs_close_neg_s = close_vs_close(var_s,-1) < 0
    print('SELL close_vs_close_pos_s -> {}'.format(close_vs_close_neg_s[max_drop_s == True].shape))
    
    #Find the sell signals
    s_out = max_drop_s & min_gain_s & close_vs_close_neg_s
    print('SELL ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Get buy signals
df_prices_w['buy'] = get_buys(df_prices_w['close'])

#Get sell signals
df_prices_w['sell'] = get_sells(df_prices_w['close'])

#Get hold signals
df_prices_w["hold"] = (df_prices_w["buy"] == False) & (df_prices_w["sell"] == False)

print('BUY PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['buy'] == True].shape[0]*100/df_prices_w.shape[0]))
print('SELL PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['sell'] == True].shape[0]*100/df_prices_w.shape[0]))
print('HOLD PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['hold'] == True].shape[0]*100/df_prices_w.shape[0]))
# Out:
# BUY min_gain_s -> (144669,)
# BUY max_drop_s -> (88005,)
# BUY close_vs_close_pos_s -> (88005,)
# BUY ALL -> (51959,)
# SELL max_drop_s -> (191962,)
# SELL min_gain_s -> (135298,)
# SELL close_vs_close_pos_s -> (191962,)
# SELL ALL -> (69302,)
# BUY PERCENTAGE -> 18.56%
# SELL PERCENTAGE -> 24.75%
# HOLD PERCENTAGE -> 56.69%

# %% [markdown]
# # Create additional features

# %%
#Define the variables for additional features
period_high_volatility = 5
period_low_volatility = 3
gap_high_volatility = 3
gap_low_volatility = 2

# %%
#Mark minimums and maximums
def flag_mins(_s_in,_period:int=3,_gap:int=3,_cur:bool=False):
    """Function used to identify values in a series as mins
    
    args:
    -----
    _s_in - pandas series - values to be compared
    _period - int:3 - window to check values over
    _gap - int:3 - the number of period which must have elapsed before a min is 
        identified (prevents changing of min_flags on current week vs same week next week)
    _cur - bool:False - is this looking at current or past values
    
    returns:
    ------
    pandas series - bools
    """
    _s_out = 0
    #Create a benchmark series
    _bench_s = _s_in.shift(_gap)
    #Check within window
    for i in range(1,_period+1):
        _s_out += (_bench_s > _bench_s.shift(i)) | (_bench_s.shift(i).isnull())
    #Check within gap
    for i in range(1,_gap+1):
        _s_out += (_bench_s > _bench_s.shift(-i))
    _s_out = _s_out == 0
    return _s_out
def flag_maxs(_s_in,_period:int=3,_gap:int=3,_cur:bool=False):
    """Function used to identify values in a series as maxs
    
    args:
    -----
    _s_in - pandas series - values to be compared
    _period - int:3 - window to check values over
    _gap - int:3 - the number of period which must have elapsed before a min is 
        identified (prevents changing of min_flags on current week vs same week next week)
    _cur - bool:False - is this looking at current or past values
    
    returns:
    ------
    pandas series - bools
    """
    _s_out = 0
    #Create a benchmark series
    _bench_s = _s_in.shift(_gap)
    #Check within window
    for i in range(1,_period+1):
        _s_out += (_bench_s < _bench_s.shift(i)) | (_bench_s.shift(i).isnull())
    #Check within gap
    for i in range(1,_gap+1):
        _s_out += (_bench_s < _bench_s.shift(-i))
    _s_out = _s_out == 0
    return _s_out

# %%
#Function to find last max and mins
def prev_max_min(_df_in,_var_col,_bool_col,_gap:int=0):
    """Function to find last max and mins
    
    args:
    -----
    _df_in - pandas dataframe - must contain 'date', _var_col and _bool_col as column names
    _var_col - str - the name of the column containing the current variables
    _bool_col - str - the name of the column containing the bool values defining max and min vlaues
    _gap - int:0 - the number of period which must have elapsed before a min is 
        identified (prevents changing of min_flags on current week vs same week next week)
    
    returns:
    ------
    tuple - pandas series,pandas series - last max/min value, last max/min date
    """
    _df_in["prev_val"] = _df_in.loc[_df_in[_bool_col].shift(-_gap).fillna(False),_var_col]
    _df_in["prev_val"] = _df_in["prev_val"].fillna(method='ffill')
    _df_in["prev_marker_date"] = _df_in.loc[_df_in[_bool_col].shift(-_gap).fillna(False),"date"]
    _df_in["prev_marker_date"] = _df_in["prev_marker_date"].fillna(method='ffill')
    return (_df_in["prev_val"],_df_in["prev_marker_date"])

# %%
#Function for finding the gradient of a variable overa set period
def gradient(_s_in,_period:int=1):
    """Function for finding the gradient of a variable over a set period
    
    args:
    -----
    _s_in - pandas series - the series from which the gradient will be found
    _period - int:1 - the period over which the gradient will be found
    
    returns:
    ------
    pandas series
    """
    _s_out = _s_in - _s_in.shift(_period)
    return _s_out

# %%
#Calc vol as proportion of previous n-rows
def calc_prop_of_prev(_s_in,_periods:int = 4):
    """Function to this value as a proportion of the cum previous values
    
    args:
    -----
    _s_in - pandas series - values to be looked at
    _period - int - window to sum values over
    
    returns:
    ------
    pandas series - floats
    """
    _s_cum = _s_in.copy()
    for i in range(1,_periods):
        _s_cum += _s_in.shift(i)
    return _s_in / _s_cum

# %%
#Mark points of macd positive entry
def pos_entry(_s_in):
    """Function to check if this value is a new positive after a negative value
    
    args:
    -----
    _s_in - pandas series - values to be looked at
    
    returns:
    ------
    pandas series - bools
    """
    return (_s_in > _s_in.shift(1)) & (_s_in > 0) & (_s_in.shift(1) < 0)
def neg_entry(_s_in):
    """Function to check if this value is a new negative after a positive value
    
    args:
    -----
    _s_in - pandas series - values to be looked at
    
    returns:
    ------
    pandas series - bools
    """
    return (_s_in < _s_in.shift(1)) & (_s_in < 0) & (_s_in.shift(1) > 0)

# %%
#Function to normalise current price compared to another
def norm_s(_s_in):
    """Function to normalise current price compared to another
    
    args:
    -----
    _s_in - pandas series - values to be looked at
    
    returns:
    ------
    pandas series - bools
    """
    _s_out = (_s_in - _s_in.min()) / (_max_in - _s_in.max())
    return _s_out

# %%
#Create separate columns for pos and neg values - allows for normalisation
def pos_neg_cols(_s_in,_gt_lt = "GT"):
    """Function to separate columns for pos and neg values - allows for normalisation
    
    args:
    -----
    _s_in - pandas series - the vlaues ot be looked at
    _gt_lt - str:'GT' - defines if looking for positive or negative values
    
    returns:
    ------
    tuple - pandas series,pandas series - bools,floats
    """
    if _gt_lt.upper() == "GT":
        _bool_s = _s_in >= 0
    elif _gt_lt.upper() == "LT":
        _bool_s = _s_in <= 0
    _df_out = _s_in.to_frame()
    _df_out["_s_in"] = _s_in
    _df_out["_val"] = abs(_s_in[_bool_s])
    _val_s = _df_out["_val"].fillna(0,method=None)
    return (_bool_s,_val_s)

# %%
#Function for finding the max within a given time period using indexes
def max_min_period(_s_in,_period:int=1,_normalise:bool=False,_max_min:str='max'):
    """Function for calculating the max and mins within a period
    
    args:
    -----
    _s_in - pandas series - the vlaues to be looked at
    _period - int:1 - the time window to look over
    _max_min - str:max - looking for the max or min
    _normalise - bool:False - should the returned value be normalised?
    
    returns:
    ------
    pandas series - floats
    """
    #Find the min index
    _min_i = _s_in.index.min()
    if _normalise:
        _s_max = pd.Series([_s_in.loc[x-_period if x-_period >= _min_i else _min_i:x].max() for x in _s_in.index])
        _s_min = pd.Series([_s_in.loc[x-_period if x-_period >= _min_i else _min_i:x].min() for x in _s_in.index])
        _s_out = (_s_in - _s_min) / (_s_max - _s_min)
    else:
        #Get the max or min within a time period, ensuring not to go into negative indexes
        if _max_min == 'max':
            _s_out = pd.Series([_s_in.loc[x-_period if x-_period >= _min_i else _min_i:x].max() for x in _s_in.index])
        elif _max_min == 'min':
            _s_out = pd.Series([_s_in.loc[x-_period if x-_period >= _min_i else _min_i:x].min() for x in _s_in.index])
        else:
            raise ValueError('_max_min must be either \'max\' or \'min\'')
    return pd.Series(_s_out)

# %%
#Function for calculating the percentage change within a range
def per_change_in_range(_s_in,_period:int=1,**kwargs):
    """Function for calculating the percentage change of a value from it's max or min within a range
    
    args:
    -----
    _s_in - pandas series - the vlaues to be looked at
    _period - int:1 - the time window to look over
    
    returns:
    ------
    pandas series - floats
    """
    return ((_s_in - max_min_period(_s_in,_period,_normalise=False,**kwargs)) / max_min_period(_s_in,_period,_normalise=False,**kwargs))

# %%
def mk_prev_move_float(_s_in):
    """Function to find the the magnitude of the most recent value change.
    
    args:
    ------
    _s_in - pandas series - float values
    
    returns:
    ------
    pandas series - float values
    """
    _s_out = _s_in - _s_in.shift(1)
    _s_out[_s_out == 0] = np.nan
    _s_out = _s_out.fillna(method='ffill')
    return _s_out

def mk_prev_move_date(_s_in,_periods:int=7):
    """Function to find the time elapsed between two different changes.
    
    args:
    ------
    _s_in - pandas dataframe - datetime values
    _periods - int:7 - used to modify days of datetime into the period required
    
    
    returns:
    ------
    pandas series - int values
    """
    _s_out = _s_in - _s_in.shift(1)
    _s_check = pd.Series([np.floor(_x.days) for _x in _s_out])
    _s_check[_s_check == 0] = np.nan
    _s_check = _s_check.fillna(method='ffill')
    _s_check = [np.floor(_x/_periods) for _x in _s_check]
    return _s_check
#Create features for the cumulative sequential count of max/mins in a certain direction
def mk_move_cum(_s_in):
    """Function for counting the number of changes of the same sign sequentially.
    EG how many positive moves have there been in a row.
    
    args:
    ------
    _s_in - pandas series - floats
    
    returns:
    pandas series - floats
    """
    _li_out = []
    _prev_x = None
    #Loop through each value in _s_in
    for _i,_x in _s_in.iteritems():
        if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
            _li_out.append(0)
        else:
            _prev_x = _prev_x if not np.isnan(_prev_x) else 0
            if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                _li_out.append(0)
            else:
                if _prev_x != _x: #if there has been a change in value from this and the previous value increment it by 1
                    if _x > 0: #for positive value increment by 1
                        _li_out.append(_li_out[-1] + 1)                                    
                    else: #for negative values increment by -1
                        _li_out.append(_li_out[-1] - 1)
                else: #Otherwise just use the last added value
                    _li_out.append(_li_out[-1])
        _prev_x = _x
    return _li_out
#Create features showing the value change since the first min/max
def mk_long_prev_move_float(_ref_s,_val_s):
    """Function to find the value change since the first max/min move in the current sequential series.
    
    args:
    ------
    _ref_s - pandas series - the reference series from which changes will be detected
    _val_s - pandas series - the values series from which outputs will be created
    
    returns:
    ------
    pandas series - float values
    """
    _li_out = []
    _st_x = None
    _prev_x = None
    #Loop through each value in _s_in
    for _i,_x in _ref_s.iteritems():
        if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
            _li_out.append(0)
        else:
            _prev_x = _prev_x if not np.isnan(_prev_x) else 0
            if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                _li_out.append(0)
                _st_x = None
            else:
                if _st_x == None: #If _st_x has not been set yet set it to this value
                    _st_x = _val_s[_i]
                _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
        _prev_x = _x
    return _li_out
def mk_long_prev_move_date(_ref_s,_val_s,_periods:int=7):
    """Function to find the date change since the first max/min move in the current sequential series.
    
    args:
    ------
    _ref_s - pandas series - the reference series from which changes will be detected
    _val_s - pandas series - the values series from which outputs will be created
    _periods - int:7 - used to modify days of datetime into the period required
    
    returns:
    ------
    pandas series - int values
    """
    _li_out = []
    _st_x = None
    _prev_x = None
    #Loop through each value in _s_in
    for _i,_x in _ref_s.iteritems():
        if np.isnan(_x) or _prev_x == None: #If this is the first value add it to the list
            _li_out.append(0)
        else:
            _prev_x = _prev_x if not np.isnan(_prev_x) else 0
            if ((_x < 0) & (_prev_x > 0)) or ((_x > 0) & (_prev_x < 0)): #If a sign change then reset to 0
                _li_out.append(0)
                _st_x = None
            else:
                if _st_x == None: #If _st_x has not been set yet set it to this value
                    _st_x = _val_s[_i]
                _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
        _prev_x = _x
    return _li_out

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_len_s(_s_in):
    """Get the max length of value in the series
    
    args:
    -----
    _s_in - pandas series - series holding values to look at for max field lengths
    
    returns:
    ------
    float
    """
    _tmp_s = pd.Series([len(str(x)) for x in _s_in])
    return _tmp_s.max()
    
def get_col_len_df(_df_in):
    """Create a dictionary of max character lengths of fields for use later in h5 file appending
    
    args:
    -----
    _df_in - pandas dataframe - dataframe holding values to look at for max field lengths
    
    returns:
    ------
    pandas series - floats
    """
    _col_lens = {}
    for _c in _df_in:
        _col_lens[_c] = get_col_len_s(_df_in[_c])
    return _col_lens
col_lens = get_col_len_df(df_prices_w)
col_lens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7cd85de44973> in <module>()
#      29         _col_lens[_c] = get_col_len_s(_df_in[_c])
#      30     return _col_lens
# ---> 31 col_lens = get_col_len_df(df_prices_w)
#      32 col_lens
#
# NameError: name 'df_prices_w' is not defined

# %%
#Create a single function to run each stock through feature creation
def create_features(_df_in):
    """A single function to run each stock through feature creation
    
    args:
    -----
    _df_in - pandas dataframe
    
    returns:
    ------
    pandas dataframe
    """
    
    _df_out = _df_in.copy() 
    
    #Calc vol as proportion of previous n-rows
    _df_out["prop_vol"] = calc_prop_of_prev(_df_out["volume"].copy().astype("float"),6)

    #Get period-period changes
    for col in ['close','volume','macd','ema26','signal_line','macd_line']:
        _df_out["change_{}_shift1".format(col)] = gradient(_df_out[col],1)
        
    #Compare close to the max/mins within 4,13,26,52 periods
    for col in ['close_orig','macd_line']:
        for max_min in ['max','min']:
            for period in [4,13,26,52]:
                _df_out["{}_per_change_{}_{}".format(col,max_min,period)] = per_change_in_range(_df_out[col],period,_max_min=max_min)
            
    #Mark points of macd positive entry
    _df_out["macd_pos_ent"] = pos_entry(_df_out["macd"])
    _df_out["macd_neg_ent"] = neg_entry(_df_out["macd"])
    
    #Create max min columns
    def mk_cols_max_min(tmp_df,col,period:int=4,gap:int=2):
        #Historic max mins
        tmp_df["{}_min".format(col)] = flag_mins(tmp_df[col],period,gap)
        tmp_df["{}_max".format(col)] = flag_maxs(tmp_df[col],period,gap)
        
    #Find previous max and mins, then look at:
        # - how many positive or negative moves in a row there has been
        # - what the move since the last (n-1) max/min was
        # - what the gradient is since the last (n-1) max/min
        # - what the move since the first max/min was
        # - what the gradient since the first max/min was
    def mk_cols_prev_max_min(tmp_df,col,period:int=4):
        #GETTING THE MAX/MINS - includes "gap" to account for time lag before declaring something as mn/max
        tmp_df["prev_max_{}".format(col)],tmp_df["prev_max_{}_date".format(col)] = prev_max_min(tmp_df[["date",col,"{}_max".format(col)]].copy(),col,"{}_max".format(col))
        tmp_df["prev_min_{}".format(col)],tmp_df["prev_min_{}_date".format(col)] = prev_max_min(tmp_df[["date",col,"{}_min".format(col)]].copy(),col,"{}_min".format(col))
#         #Shift the max min columns by n periods to not leak future information
#         tmp_df["prev_max_{}".format(col)] = tmp_df["prev_max_{}".format(col)].shift(period)
#         tmp_df["prev_min_{}".format(col)] = tmp_df["prev_min_{}".format(col)].shift(period)
#         tmp_df["prev_max_{}_date".format(col)] = tmp_df["prev_max_{}_date".format(col)].shift(period)
#         tmp_df["prev_min_{}_date".format(col)] = tmp_df["prev_min_{}_date".format(col)].shift(period)
        #WHAT WAS THE MOVE SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_max_{}".format(col)])
        tmp_df['prev_max_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_max_{}_date".format(col)])        
        tmp_df['prev_min_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_min_{}".format(col)])
        tmp_df['prev_min_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_min_{}_date".format(col)])
        #WHAT IS THE GRADIENT SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_grad_{}'.format(col)] = tmp_df['prev_max_move_{}'.format(col)] / tmp_df['prev_max_date_move_{}'.format(col)]
        tmp_df['prev_min_grad_{}'.format(col)] = tmp_df['prev_min_move_{}'.format(col)] / tmp_df['prev_min_date_move_{}'.format(col)]
        #HOW MANY PROGRESSIVE MAX/MINS IN A ROW HAVE THERE BEEN - UP OR DOWN FOR BOTH OPTIONS
        tmp_df['max_move_cum_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)])
        tmp_df['min_move_cum_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)])
        #WHAT WAS THE MOVE SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)])
        tmp_df['long_prev_min_move_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)])
        #WHAT WAS THE TIMEDELTA SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)])
        tmp_df['long_prev_min_move_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)])
        #WHAT IS THE GRADIENT SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_max_grad_{}'.format(col)] = tmp_df['long_prev_max_move_{}'.format(col)] / tmp_df['long_prev_max_move_date_{}'.format(col)]
        tmp_df['long_min_grad_{}'.format(col)] = tmp_df['long_prev_min_move_{}'.format(col)] / tmp_df['long_prev_min_move_date_{}'.format(col)]
        #WHAT IS THE MAX MIN CONVERGENCE/DIVERGENCE
        tmp_df['prev_grad_conv_{}'.format(col)] = tmp_df['prev_min_grad_{}'.format(col)] - tmp_df['prev_max_grad_{}'.format(col)]
        tmp_df['long_grad_conv_{}'.format(col)] = tmp_df['long_min_grad_{}'.format(col)] - tmp_df['long_max_grad_{}'.format(col)]
        
    #Calc the value changes and percentage changes of these movements
    def mk_cols_prev_max_min_change(tmp_df,col):
        tmp_df["max_change_{}".format(col)],tmp_df["max_per_change_{}".format(col)] = calc_changes(tmp_df[col].copy(),tmp_df["prev_max_{}".format(col)].copy())
        tmp_df["min_change_{}".format(col)],tmp_df["min_per_change_{}".format(col)] = calc_changes(tmp_df[col].copy(),tmp_df["prev_min_{}".format(col)].copy())
        
    #Mark date change since max and mins and convert to periods
    def mk_cols_prev_max_min_date_change(tmp_df,col,period:int=7):
        tmp_df["prev_max_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_max_{}_date".format(col)]
        tmp_df["prev_min_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_min_{}_date".format(col)]
        #Convert all to period changes
        tmp_df["prev_max_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_max_{}_date_change".format(col)]]
        tmp_df["prev_min_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_min_{}_date_change".format(col)]]
    
    #Run function for columns - high volatility
    for col in ['close','signal_line','volume']:
        mk_cols_max_min(_df_out,col,period_high_volatility,gap_high_volatility)
        mk_cols_prev_max_min(_df_out,col,period_high_volatility)
        mk_cols_prev_max_min_change(_df_out,col) 
        mk_cols_prev_max_min_date_change(_df_out,col,7)
    #Run function for columns - low volatility
    for col in ['macd','ema26','macd_line']:
        mk_cols_max_min(_df_out,col,period_low_volatility,gap_low_volatility)
        mk_cols_prev_max_min(_df_out,col,period_low_volatility)
        mk_cols_prev_max_min_change(_df_out,col) 
        mk_cols_prev_max_min_date_change(_df_out,col,7)
    
    #Check for undefined
    _df_out["no_signal"] = (_df_out["buy"] == False) & (_df_out["hold"] == False) & (_df_out["sell"] == False)
    
    #Composite all singals into one column
    _df_out["signal"] = None
    _df_out.loc[_df_out["buy"] == True,"signal"] = "buy"
    _df_out.loc[_df_out["hold"] == True,"signal"] = "hold"
    _df_out.loc[_df_out["sell"] == True,"signal"] = "sell"
    _df_out.drop(columns=["buy","hold","sell"],inplace=True)
    print("SIGNAL COUNTS: \n{}".format(_df_out["signal"].value_counts()))
    
    return _df_out

# %%
#Define the columns for the output
out_cols = [
    #NON-NORMALISED COLS
    "ticker"
    ,"date"
    #NORMALISED COLS
    #Standard features
    ,"open"
    ,"close"
    ,"high"
    ,"low"
    ,"volume"
    ,"change_price"
    ,"per_change_price"
    ,"ema26"
    ,"macd"
    ,"signal_line"
    ,"macd_line"
]
#Append additional columns for key areas
for col in ['close_orig','macd_line']:
    for max_min in ['max','min']:
        for period in [4,13,26,52]:
            out_cols.append("{}_per_change_{}_{}".format(col,max_min,period))
for col in ['close','macd','ema26','signal_line','macd_line','volume']:
    #Shifted features
    out_cols.append("change_{}_shift1".format(col))
    #Max/min flags
    out_cols.append("{}_max".format(col))    
    out_cols.append("{}_min".format(col))    
    #Prev max/min features
    out_cols.append("prev_max_{}".format(col))
    out_cols.append("prev_min_{}".format(col))
    #date changes
    out_cols.append("prev_max_{}_date_change".format(col))
    out_cols.append("prev_min_{}_date_change".format(col))
    #Min max change features
    out_cols.append("max_change_{}".format(col))
    out_cols.append("min_change_{}".format(col))
    #prev max/mins (n-1) - compared to previous
    out_cols.append('prev_max_grad_{}'.format(col))
    out_cols.append('prev_min_grad_{}'.format(col))
    out_cols.append('prev_grad_conv_{}'.format(col))
    #prev max/mins (n=0) - compared to first in this run
    out_cols.append('max_move_cum_{}'.format(col))
    out_cols.append('min_move_cum_{}'.format(col))
    out_cols.append('long_prev_max_move_date_{}'.format(col))
    out_cols.append('long_prev_min_move_date_{}'.format(col))
    out_cols.append('long_max_grad_{}'.format(col))
    out_cols.append('long_min_grad_{}'.format(col))
    out_cols.append('long_grad_conv_{}'.format(col))
#Append signal
out_cols.append("signal")

# %%
#A conversion for all variables ot the correct dtype
conv_di = {
    #NON-NORMALISED COLS
    "ticker":'object'
    ,"date":'datetime64'
    #NORMALISED COLS
    #Standard features
    ,"open":'float64'
    ,"close":'float64'
    ,"high":'float64'
    ,"low":'float64'
    ,"volume":'float64'
    ,"change_price":'float64'
    ,"per_change_price":'float64'
    ,"ema26":'float64'
    ,"macd":'float64'
    ,"signal_line":'float64'
    ,"macd_line":'float64'
}
#Append additional columns for key areas
for col in ['close_orig','macd_line']:
    for max_min in ['max','min']:
        for period in [4,13,26,52]:
            conv_di["{}_per_change_{}_{}".format(col,max_min,period)] = 'float64'
for col in ['close','macd','ema26','signal_line','macd_line','volume']:
    #Shifted features
    conv_di["change_{}_shift1".format(col)] = 'float64'
    #Max/min flags
    conv_di["{}_max".format(col)] = 'bool'
    conv_di["{}_min".format(col)] = 'bool'
    #Prev max/min features
    conv_di["prev_max_{}".format(col)] = 'float64'
    conv_di["prev_min_{}".format(col)] = 'float64'
    #date changes
    conv_di["prev_max_{}_date_change".format(col)] = 'float64'
    conv_di["prev_min_{}_date_change".format(col)] = 'float64'
    #Min max change features
    conv_di["max_change_{}".format(col)] = 'float64'
    conv_di["min_change_{}".format(col)] = 'float64'
    #prev max/mins (n-1) - compared to previous
    conv_di['prev_max_grad_{}'.format(col)] = 'float64'
    conv_di['prev_min_grad_{}'.format(col)] = 'float64'
    conv_di['prev_grad_conv_{}'.format(col)] = 'float64'
    #prev max/mins (n=0) - compared to first in this run
    conv_di['max_move_cum_{}'.format(col)] = 'int64'
    conv_di['min_move_cum_{}'.format(col)] = 'int64'
    conv_di['long_prev_max_move_date_{}'.format(col)] = 'float64'
    conv_di['long_prev_min_move_date_{}'.format(col)] = 'float64'
    conv_di['long_max_grad_{}'.format(col)] = 'float64'
    conv_di['long_min_grad_{}'.format(col)] = 'float64'
    conv_di['long_grad_conv_{}'.format(col)] = 'float64'
#Append signal
conv_di["signal"] = 'object'

# %%
#Then loop the tickers and combine these into one large dataset
hf_store_name = path+r'\all_hist_prices_w_ft_eng2_TMP.h5'
h_store = pd.HDFStore(hf_store_name)
errors = []
run_time = process_time()
for tick in tick_ftse["ticker"]:
# for tick in ['SBRY','AJB']: #TEMP
    try:
        print("\n{}".format(len(run_time.lap_li)))
        print("RUN FOR {}".format(tick))
        #Isolate this ticker
        this_tick_df = df_prices_w[df_prices_w["ticker"] == re.sub('[^a-zA-Z0-9\-]','',tick)].copy()
        print("shape before -> {}".format(this_tick_df.shape))
        #Create the features
        this_tick_df = create_features(this_tick_df)
        #Clarify col_lens with cur cols in data
        this_col_lens = get_col_len_df(this_tick_df)
        min_itemsize_di = {}
        for col in out_cols:
            if col in col_lens:
                if this_col_lens[col] > col_lens[col]:
                    col_lens[col] = this_col_lens[col]
            else:
                col_lens[col] = this_col_lens[col]
            min_itemsize_di = col_lens[col]
        print("shape after -> {}".format(this_tick_df.shape))
        #Create function for appending to hdf file
        def append_to_hdf(df_in):
            df_in[out_cols].to_hdf(hf_store_name,key='weekly_data',append=True,min_itemsize=min_itemsize_di)
        #Append this data to the group
        try:
            append_to_hdf(this_tick_df)
            print('ADDED TO {}'.format(hf_store_name))
        except ValueError:
            print('WARNING -> Attempting to change dtypes')
            #Try changing the dtypes
            try:
                for col in out_cols:
                    # print(r'CONVERT {} FROM {} TO {}'.format(col,this_tick_df[col].dtype,conv_di[col]))
                    this_tick_df[col] = this_tick_df[col].astype(conv_di[col])
                append_to_hdf(this_tick_df)
                print('ADDED TO {}'.format(hf_store_name))
            except Exception as e:
                errors.append({"ticker":tick,"Error":e})
                print('ERROR READING TO FILE {}'.format(e))
        except Exception as e:
            errors.append({"ticker":tick,"Error":e})
            print('ERROR READING TO FILE {}'.format(e))
        #Lap
        run_time.lap()
        run_time.show_latest_lap_time()
    except Exception as e:
        h_store.close()
        errors.append({"ticker":tick,"Error":e})
        print('ERROR PROCESSING DATA {}'.format(e))
h_store.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT -> {}'.format(len(errors)))
if len(errors) > 0:
    print('\tERRORS -> ')
    display(pd.DataFrame(errors))
# Out:
# 0
# RUN FOR III
# shape before -> (623, 23)
# SIGNAL COUNTS:
# hold    360
# sell    141
# buy     122
# Name: signal, dtype: int64
# shape after -> (623, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 1 TIME -> 0:0:6
#
# 1
# RUN FOR ABF
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    584
# sell    290
# buy     181
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 2 TIME -> 0:0:9
#
# 2
# RUN FOR ADM
# shape before -> (363, 23)
# SIGNAL COUNTS:
# hold    236
# sell     91
# buy      36
# Name: signal, dtype: int64
# shape after -> (363, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 3 TIME -> 0:0:3
#
# 3
# RUN FOR AAL
# shape before -> (1018, 23)
# SIGNAL COUNTS:
# hold    579
# buy     224
# sell    215
# Name: signal, dtype: int64
# shape after -> (1018, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 4 TIME -> 0:0:10
#
# 4
# RUN FOR ANTO
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    584
# sell    259
# buy     212
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 5 TIME -> 0:0:9
#
# 5
# RUN FOR AHT
# shape before -> (1033, 23)
# SIGNAL COUNTS:
# hold    586
# sell    238
# buy     209
# Name: signal, dtype: int64
# shape after -> (1033, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 6 TIME -> 0:0:10
#
# 6
# RUN FOR AZN
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    598
# sell    264
# buy     193
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 7 TIME -> 0:0:9
#
# 7
# RUN FOR AUTO
# shape before -> (248, 23)
# SIGNAL COUNTS:
# hold    151
# sell     55
# buy      42
# Name: signal, dtype: int64
# shape after -> (248, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 8 TIME -> 0:0:2
#
# 8
# RUN FOR AVV
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    608
# sell    240
# buy     207
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 9 TIME -> 0:0:10
#
# 9
# RUN FOR AV
# shape before -> (2788, 23)
# SIGNAL COUNTS:
# hold    1497
# sell     728
# buy      563
# Name: signal, dtype: int64
# shape after -> (2788, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 10 TIME -> 0:0:27
#
# 10
# RUN FOR BA
# shape before -> (1546, 23)
# SIGNAL COUNTS:
# hold    873
# sell    367
# buy     306
# Name: signal, dtype: int64
# shape after -> (1546, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 11 TIME -> 0:0:15
#
# 11
# RUN FOR BARC
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    590
# sell    271
# buy     194
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 12 TIME -> 0:0:11
#
# 12
# RUN FOR BDEV
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    534
# sell    278
# buy     243
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 13 TIME -> 0:0:15
#
# 13
# RUN FOR BKG
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    592
# sell    245
# buy     218
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 14 TIME -> 0:0:11
#
# 14
# RUN FOR BHP
# shape before -> (534, 23)
# SIGNAL COUNTS:
# hold    301
# sell    137
# buy      96
# Name: signal, dtype: int64
# shape after -> (534, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 15 TIME -> 0:0:5
#
# 15
# RUN FOR BP
# shape before -> (1575, 23)
# SIGNAL COUNTS:
# hold    890
# sell    377
# buy     308
# Name: signal, dtype: int64
# shape after -> (1575, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 16 TIME -> 0:0:15
#
# 16
# RUN FOR BATS
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    569
# sell    308
# buy     178
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 17 TIME -> 0:0:9
#
# 17
# RUN FOR BLND
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    568
# sell    269
# buy     218
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 18 TIME -> 0:0:10
#
# 18
# RUN FOR BT-A
# shape before -> (1546, 23)
# SIGNAL COUNTS:
# hold    868
# sell    374
# buy     304
# Name: signal, dtype: int64
# shape after -> (1546, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 19 TIME -> 0:0:14
#
# 19
# RUN FOR BNZL
# shape before -> (1052, 23)
# SIGNAL COUNTS:
# hold    595
# sell    291
# buy     166
# Name: signal, dtype: int64
# shape after -> (1052, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 20 TIME -> 0:0:9
#
# 20
# RUN FOR BRBY
# shape before -> (910, 23)
# SIGNAL COUNTS:
# hold    508
# sell    234
# buy     168
# Name: signal, dtype: int64
# shape after -> (910, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 21 TIME -> 0:0:8
#
# 21
# RUN FOR CCL
# shape before -> (999, 23)
# SIGNAL COUNTS:
# hold    563
# sell    266
# buy     170
# Name: signal, dtype: int64
# shape after -> (999, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 22 TIME -> 0:0:9
#
# 22
# RUN FOR CNA
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    621
# sell    266
# buy     168
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 23 TIME -> 0:0:9
#
# 23
# RUN FOR CCH
# shape before -> (346, 23)
# SIGNAL COUNTS:
# hold    212
# sell     72
# buy      62
# Name: signal, dtype: int64
# shape after -> (346, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 24 TIME -> 0:0:3
#
# 24
# RUN FOR CPG
# shape before -> (1041, 23)
# SIGNAL COUNTS:
# hold    601
# sell    251
# buy     189
# Name: signal, dtype: int64
# shape after -> (1041, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 25 TIME -> 0:0:9
#
# 25
# RUN FOR CRH
# shape before -> (1041, 23)
# SIGNAL COUNTS:
# hold    588
# sell    248
# buy     205
# Name: signal, dtype: int64
# shape after -> (1041, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 26 TIME -> 0:0:9
#
# 26
# RUN FOR CRDA
# shape before -> (1047, 23)
# SIGNAL COUNTS:
# hold    615
# sell    277
# buy     155
# Name: signal, dtype: int64
# shape after -> (1047, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 27 TIME -> 0:0:9
#
# 27
# RUN FOR DCC
# shape before -> (1037, 23)
# SIGNAL COUNTS:
# hold    578
# sell    260
# buy     199
# Name: signal, dtype: int64
# shape after -> (1037, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 28 TIME -> 0:0:9
#
# 28
# RUN FOR DGE
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    572
# sell    295
# buy     188
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 29 TIME -> 0:0:9
#
# 29
# RUN FOR EVR
# shape before -> (424, 23)
# SIGNAL COUNTS:
# hold    232
# sell    103
# buy      89
# Name: signal, dtype: int64
# shape after -> (424, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 30 TIME -> 0:0:4
#
# 30
# RUN FOR EXPN
# shape before -> (688, 23)
# SIGNAL COUNTS:
# hold    408
# sell    167
# buy     113
# Name: signal, dtype: int64
# shape after -> (688, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 31 TIME -> 0:0:6
#
# 31
# RUN FOR FERG
# shape before -> (1056, 23)
# SIGNAL COUNTS:
# hold    572
# sell    283
# buy     201
# Name: signal, dtype: int64
# shape after -> (1056, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 32 TIME -> 0:0:10
#
# 32
# RUN FOR FRES
# shape before -> (606, 23)
# SIGNAL COUNTS:
# hold    353
# sell    159
# buy      94
# Name: signal, dtype: int64
# shape after -> (606, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 33 TIME -> 0:0:6
#
# 33
# RUN FOR GSK
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    659
# sell    219
# buy     177
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 34 TIME -> 0:0:9
#
# 34
# RUN FOR GLEN
# shape before -> (448, 23)
# SIGNAL COUNTS:
# hold    244
# sell    104
# buy     100
# Name: signal, dtype: int64
# shape after -> (448, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 35 TIME -> 0:0:4
#
# 35
# RUN FOR HLMA
# shape before -> (1023, 23)
# SIGNAL COUNTS:
# hold    570
# sell    273
# buy     180
# Name: signal, dtype: int64
# shape after -> (1023, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 36 TIME -> 0:0:9
#
# 36
# RUN FOR HL
# shape before -> (651, 23)
# SIGNAL COUNTS:
# hold    359
# sell    169
# buy     123
# Name: signal, dtype: int64
# shape after -> (651, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 37 TIME -> 0:0:6
#
# 37
# RUN FOR HIK
# shape before -> (718, 23)
# SIGNAL COUNTS:
# hold    394
# sell    179
# buy     145
# Name: signal, dtype: int64
# shape after -> (718, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 38 TIME -> 0:0:6
#
# 38
# RUN FOR HSX
# shape before -> (1022, 23)
# SIGNAL COUNTS:
# hold    558
# sell    271
# buy     193
# Name: signal, dtype: int64
# shape after -> (1022, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 39 TIME -> 0:0:9
#
# 39
# RUN FOR HSBA
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    647
# sell    364
# buy     255
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 40 TIME -> 0:0:11
#
# 40
# RUN FOR IMB
# shape before -> (1190, 23)
# SIGNAL COUNTS:
# hold    686
# sell    312
# buy     192
# Name: signal, dtype: int64
# shape after -> (1190, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 41 TIME -> 0:0:10
#
# 41
# RUN FOR INF
# shape before -> (1076, 23)
# SIGNAL COUNTS:
# hold    569
# sell    264
# buy     243
# Name: signal, dtype: int64
# shape after -> (1076, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 42 TIME -> 0:0:9
#
# 42
# RUN FOR IHG
# shape before -> (854, 23)
# SIGNAL COUNTS:
# hold    480
# sell    202
# buy     172
# Name: signal, dtype: int64
# shape after -> (854, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 43 TIME -> 0:0:8
#
# 43
# RUN FOR ITRK
# shape before -> (894, 23)
# SIGNAL COUNTS:
# hold    488
# sell    253
# buy     153
# Name: signal, dtype: int64
# shape after -> (894, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 44 TIME -> 0:0:8
#
# 44
# RUN FOR IAG
# shape before -> (866, 23)
# SIGNAL COUNTS:
# hold    481
# sell    226
# buy     159
# Name: signal, dtype: int64
# shape after -> (866, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 45 TIME -> 0:0:8
#
# 45
# RUN FOR ITV
# shape before -> (1022, 23)
# SIGNAL COUNTS:
# hold    574
# sell    236
# buy     212
# Name: signal, dtype: int64
# shape after -> (1022, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 46 TIME -> 0:0:9
#
# 46
# RUN FOR JD
# shape before -> (92, 23)
# SIGNAL COUNTS:
# hold    52
# sell    21
# buy     19
# Name: signal, dtype: int64
# shape after -> (92, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 47 TIME -> 0:0:1
#
# 47
# RUN FOR JMAT
# shape before -> (1247, 23)
# SIGNAL COUNTS:
# hold    647
# sell    344
# buy     256
# Name: signal, dtype: int64
# shape after -> (1247, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 48 TIME -> 0:0:13
#
# 48
# RUN FOR KGF
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    694
# sell    326
# buy     246
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 49 TIME -> 0:0:13
#
# 49
# RUN FOR LAND
# shape before -> (1274, 23)
# SIGNAL COUNTS:
# hold    697
# sell    335
# buy     242
# Name: signal, dtype: int64
# shape after -> (1274, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 50 TIME -> 0:0:11
#
# 50
# RUN FOR LGEN
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    691
# sell    324
# buy     251
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 51 TIME -> 0:0:11
#
# 51
# RUN FOR LLOY
# shape before -> (1232, 23)
# SIGNAL COUNTS:
# hold    660
# sell    324
# buy     248
# Name: signal, dtype: int64
# shape after -> (1232, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 52 TIME -> 0:0:11
#
# 52
# RUN FOR LSE
# shape before -> (942, 23)
# SIGNAL COUNTS:
# hold    569
# sell    219
# buy     154
# Name: signal, dtype: int64
# shape after -> (942, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 53 TIME -> 0:0:8
#
# 53
# RUN FOR MGGT
# shape before -> (1485, 23)
# SIGNAL COUNTS:
# hold    809
# sell    388
# buy     288
# Name: signal, dtype: int64
# shape after -> (1485, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 54 TIME -> 0:0:13
#
# 54
# RUN FOR MRO
# shape before -> (822, 23)
# SIGNAL COUNTS:
# hold    443
# sell    223
# buy     156
# Name: signal, dtype: int64
# shape after -> (822, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 55 TIME -> 0:0:7
#
# 55
# RUN FOR MNDI
# shape before -> (624, 23)
# SIGNAL COUNTS:
# hold    362
# sell    155
# buy     107
# Name: signal, dtype: int64
# shape after -> (624, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 56 TIME -> 0:0:5
#
# 56
# RUN FOR MRW
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    736
# sell    283
# buy     247
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 57 TIME -> 0:0:11
#
# 57
# RUN FOR NG
# shape before -> (1253, 23)
# SIGNAL COUNTS:
# hold    678
# sell    322
# buy     253
# Name: signal, dtype: int64
# shape after -> (1253, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 58 TIME -> 0:0:11
#
# 58
# RUN FOR NXT
# shape before -> (1533, 23)
# SIGNAL COUNTS:
# hold    919
# sell    378
# buy     236
# Name: signal, dtype: int64
# shape after -> (1533, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 59 TIME -> 0:0:13
#
# 59
# RUN FOR NMC
# shape before -> (383, 23)
# SIGNAL COUNTS:
# hold    232
# sell     98
# buy      53
# Name: signal, dtype: int64
# shape after -> (383, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 60 TIME -> 0:0:4
#
# 60
# RUN FOR OCDO
# shape before -> (472, 23)
# SIGNAL COUNTS:
# hold    246
# sell    124
# buy     102
# Name: signal, dtype: int64
# shape after -> (472, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 61 TIME -> 0:0:4
#
# 61
# RUN FOR PSON
# shape before -> (1283, 23)
# SIGNAL COUNTS:
# hold    752
# sell    300
# buy     231
# Name: signal, dtype: int64
# shape after -> (1283, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 62 TIME -> 0:0:11
#
# 62
# RUN FOR PSN
# shape before -> (1473, 23)
# SIGNAL COUNTS:
# hold    833
# sell    366
# buy     274
# Name: signal, dtype: int64
# shape after -> (1473, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 63 TIME -> 0:0:13
#
# 63
# RUN FOR PHNX
# shape before -> (505, 23)
# SIGNAL COUNTS:
# hold    273
# sell    123
# buy     109
# Name: signal, dtype: int64
# shape after -> (505, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 64 TIME -> 0:0:4
#
# 64
# RUN FOR POLY
# shape before -> (406, 23)
# SIGNAL COUNTS:
# hold    219
# sell    103
# buy      84
# Name: signal, dtype: int64
# shape after -> (406, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 65 TIME -> 0:0:4
#
# 65
# RUN FOR PRU
# shape before -> (1512, 23)
# SIGNAL COUNTS:
# hold    824
# sell    395
# buy     293
# Name: signal, dtype: int64
# shape after -> (1512, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 66 TIME -> 0:0:13
#
# 66
# RUN FOR RDSA
# shape before -> (267, 23)
# SIGNAL COUNTS:
# hold    162
# sell     66
# buy      39
# Name: signal, dtype: int64
# shape after -> (267, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 67 TIME -> 0:0:2
#
# 67
# RUN FOR RDSB
# shape before -> (1003, 23)
# SIGNAL COUNTS:
# hold    567
# sell    237
# buy     199
# Name: signal, dtype: int64
# shape after -> (1003, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 68 TIME -> 0:0:9
#
# 68
# RUN FOR RB
# shape before -> (1293, 23)
# SIGNAL COUNTS:
# hold    748
# sell    347
# buy     198
# Name: signal, dtype: int64
# shape after -> (1293, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 69 TIME -> 0:0:11
#
# 69
# RUN FOR REL
# shape before -> (1283, 23)
# SIGNAL COUNTS:
# hold    764
# sell    295
# buy     224
# Name: signal, dtype: int64
# shape after -> (1283, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 70 TIME -> 0:0:11
#
# 70
# RUN FOR RTO
# shape before -> (1251, 23)
# SIGNAL COUNTS:
# hold    727
# sell    307
# buy     217
# Name: signal, dtype: int64
# shape after -> (1251, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 71 TIME -> 0:0:11
#
# 71
# RUN FOR RMV
# shape before -> (700, 23)
# SIGNAL COUNTS:
# hold    406
# sell    170
# buy     124
# Name: signal, dtype: int64
# shape after -> (700, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 72 TIME -> 0:0:6
#
# 72
# RUN FOR RIO
# shape before -> (1536, 23)
# SIGNAL COUNTS:
# hold    803
# sell    409
# buy     324
# Name: signal, dtype: int64
# shape after -> (1536, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 73 TIME -> 0:0:13
#
# 73
# RUN FOR RR
# shape before -> (1563, 23)
# SIGNAL COUNTS:
# hold    864
# sell    406
# buy     293
# Name: signal, dtype: int64
# shape after -> (1563, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 74 TIME -> 0:0:14
#
# 74
# RUN FOR RBS
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    687
# sell    328
# buy     251
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 75 TIME -> 0:0:11
#
# 75
# RUN FOR RSA
# shape before -> (1253, 23)
# SIGNAL COUNTS:
# hold    744
# sell    265
# buy     244
# Name: signal, dtype: int64
# shape after -> (1253, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 76 TIME -> 0:0:11
#
# 76
# RUN FOR SGE
# shape before -> (1261, 23)
# SIGNAL COUNTS:
# hold    695
# sell    327
# buy     239
# Name: signal, dtype: int64
# shape after -> (1261, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 77 TIME -> 0:0:11
#
# 77
# RUN FOR SBRY
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    757
# sell    255
# buy     254
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 78 TIME -> 0:0:11
#
# 78
# RUN FOR SDR
# shape before -> (1256, 23)
# SIGNAL COUNTS:
# hold    700
# sell    294
# buy     262
# Name: signal, dtype: int64
# shape after -> (1256, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 79 TIME -> 0:0:13
#
# 79
# RUN FOR SMT
# shape before -> (145, 23)
# SIGNAL COUNTS:
# hold    92
# sell    36
# buy     17
# Name: signal, dtype: int64
# shape after -> (145, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 80 TIME -> 0:0:2
#
# 80
# RUN FOR SGRO
# shape before -> (1544, 23)
# SIGNAL COUNTS:
# hold    869
# sell    380
# buy     295
# Name: signal, dtype: int64
# shape after -> (1544, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 81 TIME -> 0:0:14
#
# 81
# RUN FOR SVT
# shape before -> (1251, 23)
# SIGNAL COUNTS:
# hold    684
# sell    317
# buy     250
# Name: signal, dtype: int64
# shape after -> (1251, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 82 TIME -> 0:0:11
#
# 82
# RUN FOR SN
# shape before -> (1597, 23)
# SIGNAL COUNTS:
# hold    896
# sell    420
# buy     281
# Name: signal, dtype: int64
# shape after -> (1597, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 83 TIME -> 0:0:14
#
# 83
# RUN FOR SMDS
# shape before -> (1434, 23)
# SIGNAL COUNTS:
# hold    839
# sell    339
# buy     256
# Name: signal, dtype: int64
# shape after -> (1434, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 84 TIME -> 0:0:12
#
# 84
# RUN FOR SMIN
# shape before -> (1496, 23)
# SIGNAL COUNTS:
# hold    849
# sell    334
# buy     313
# Name: signal, dtype: int64
# shape after -> (1496, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 85 TIME -> 0:0:14
#
# 85
# RUN FOR SKG
# shape before -> (647, 23)
# SIGNAL COUNTS:
# hold    348
# sell    153
# buy     146
# Name: signal, dtype: int64
# shape after -> (647, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 86 TIME -> 0:0:6
#
# 86
# RUN FOR SPX
# shape before -> (1464, 23)
# SIGNAL COUNTS:
# hold    879
# sell    331
# buy     254
# Name: signal, dtype: int64
# shape after -> (1464, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 87 TIME -> 0:0:13
#
# 87
# RUN FOR SSE
# shape before -> (1283, 23)
# SIGNAL COUNTS:
# hold    731
# sell    338
# buy     214
# Name: signal, dtype: int64
# shape after -> (1283, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 88 TIME -> 0:0:11
#
# 88
# RUN FOR STJ
# shape before -> (1472, 23)
# SIGNAL COUNTS:
# hold    821
# sell    374
# buy     277
# Name: signal, dtype: int64
# shape after -> (1472, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 89 TIME -> 0:0:13
#
# 89
# RUN FOR STAN
# shape before -> (1537, 23)
# SIGNAL COUNTS:
# hold    825
# sell    385
# buy     327
# Name: signal, dtype: int64
# shape after -> (1537, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 90 TIME -> 0:0:13
#
# 90
# RUN FOR SLA
# shape before -> (682, 23)
# SIGNAL COUNTS:
# hold    395
# sell    165
# buy     122
# Name: signal, dtype: int64
# shape after -> (682, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 91 TIME -> 0:0:6
#
# 91
# RUN FOR TW
# shape before -> (1563, 23)
# SIGNAL COUNTS:
# hold    838
# sell    383
# buy     342
# Name: signal, dtype: int64
# shape after -> (1563, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 92 TIME -> 0:0:14
#
# 92
# RUN FOR TSCO
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    699
# sell    309
# buy     258
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 93 TIME -> 0:0:11
#
# 93
# RUN FOR TUI
# shape before -> (261, 23)
# SIGNAL COUNTS:
# hold    168
# sell     52
# buy      41
# Name: signal, dtype: int64
# shape after -> (261, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 94 TIME -> 0:0:2
#
# 94
# RUN FOR ULVR
# shape before -> (1036, 23)
# SIGNAL COUNTS:
# hold    550
# sell    274
# buy     212
# Name: signal, dtype: int64
# shape after -> (1036, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 95 TIME -> 0:0:9
#
# 95
# RUN FOR UU
# shape before -> (1302, 23)
# SIGNAL COUNTS:
# hold    737
# sell    309
# buy     256
# Name: signal, dtype: int64
# shape after -> (1302, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 96 TIME -> 0:0:11
#
# 96
# RUN FOR VOD
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    598
# sell    240
# buy     217
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 97 TIME -> 0:0:10
#
# 97
# RUN FOR WTB
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    593
# sell    262
# buy     200
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 98 TIME -> 0:0:10
#
# 98
# RUN FOR WPP
# shape before -> (692, 23)
# SIGNAL COUNTS:
# hold    395
# sell    177
# buy     120
# Name: signal, dtype: int64
# shape after -> (692, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 99 TIME -> 0:0:6
#
# 99
# RUN FOR 3IN
# shape before -> (595, 23)
# SIGNAL COUNTS:
# hold    356
# sell    135
# buy     104
# Name: signal, dtype: int64
# shape after -> (595, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 100 TIME -> 0:0:5
#
# 100
# RUN FOR FOUR
# shape before -> (1046, 23)
# SIGNAL COUNTS:
# hold    603
# sell    264
# buy     179
# Name: signal, dtype: int64
# shape after -> (1046, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 101 TIME -> 0:0:9
#
# 101
# RUN FOR 888
# shape before -> (742, 23)
# SIGNAL COUNTS:
# hold    435
# sell    170
# buy     137
# Name: signal, dtype: int64
# shape after -> (742, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 102 TIME -> 0:0:6
#
# 102
# RUN FOR ASL
# shape before -> (612, 23)
# SIGNAL COUNTS:
# hold    340
# sell    153
# buy     119
# Name: signal, dtype: int64
# shape after -> (612, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 103 TIME -> 0:0:5
#
# 103
# RUN FOR AGK
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    614
# sell    254
# buy     187
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 104 TIME -> 0:0:9
#
# 104
# RUN FOR AJB
# shape before -> (54, 23)
# SIGNAL COUNTS:
# hold    38
# sell    11
# buy      5
# Name: signal, dtype: int64
# shape after -> (54, 215)
# WARNING -> Attempting to change dtypes
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 105 TIME -> 0:0:1
#
# 105
# RUN FOR ATST
# shape before -> (624, 23)
# SIGNAL COUNTS:
# hold    371
# sell    148
# buy     105
# Name: signal, dtype: int64
# shape after -> (624, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 106 TIME -> 0:0:6
#
# 106
# RUN FOR APAX
# shape before -> (225, 23)
# SIGNAL COUNTS:
# hold    129
# sell     54
# buy      42
# Name: signal, dtype: int64
# shape after -> (225, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 107 TIME -> 0:0:2
#
# 107
# RUN FOR ASCL
# shape before -> (201, 23)
# SIGNAL COUNTS:
# hold    120
# sell     52
# buy      29
# Name: signal, dtype: int64
# shape after -> (201, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 108 TIME -> 0:0:2
#
# 108
# RUN FOR ASHM
# shape before -> (688, 23)
# SIGNAL COUNTS:
# hold    387
# sell    166
# buy     135
# Name: signal, dtype: int64
# shape after -> (688, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 109 TIME -> 0:0:6
#
# 109
# RUN FOR AGR
# shape before -> (837, 23)
# SIGNAL COUNTS:
# hold    495
# sell    190
# buy     152
# Name: signal, dtype: int64
# shape after -> (837, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 110 TIME -> 0:0:7
#
# 110
# RUN FOR AML
# shape before -> (63, 23)
# SIGNAL COUNTS:
# hold    38
# buy     16
# sell     9
# Name: signal, dtype: int64
# shape after -> (63, 215)
# WARNING -> Attempting to change dtypes
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 111 TIME -> 0:0:1
#
# 111
# RUN FOR AVST
# shape before -> (84, 23)
# SIGNAL COUNTS:
# hold    45
# sell    20
# buy     19
# Name: signal, dtype: int64
# shape after -> (84, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 112 TIME -> 0:0:1
#
# 112
# RUN FOR BME
# shape before -> (288, 23)
# SIGNAL COUNTS:
# hold    178
# sell     63
# buy      47
# Name: signal, dtype: int64
# shape after -> (288, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 113 TIME -> 0:0:3
#
# 113
# RUN FOR BAB
# shape before -> (1035, 23)
# SIGNAL COUNTS:
# hold    627
# sell    253
# buy     155
# Name: signal, dtype: int64
# shape after -> (1035, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 114 TIME -> 0:0:9
#
# 114
# RUN FOR BGFD
# shape before -> (615, 23)
# SIGNAL COUNTS:
# hold    340
# sell    150
# buy     125
# Name: signal, dtype: int64
# shape after -> (615, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 115 TIME -> 0:0:5
#
# 115
# RUN FOR BAKK
# shape before -> (109, 23)
# SIGNAL COUNTS:
# hold    73
# buy     18
# sell    18
# Name: signal, dtype: int64
# shape after -> (109, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 116 TIME -> 0:0:1
#
# 116
# RUN FOR BBY
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    599
# sell    266
# buy     190
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 117 TIME -> 0:0:10
#
# 117
# RUN FOR BGEO
# shape before -> (628, 23)
# SIGNAL COUNTS:
# hold    342
# sell    173
# buy     113
# Name: signal, dtype: int64
# shape after -> (628, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 118 TIME -> 0:0:7
#
# 118
# RUN FOR BNKR
# shape before -> (618, 23)
# SIGNAL COUNTS:
# hold    371
# sell    153
# buy      94
# Name: signal, dtype: int64
# shape after -> (618, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 119 TIME -> 0:0:7
#
# 119
# RUN FOR BAG
# shape before -> (1055, 23)
# SIGNAL COUNTS:
# hold    582
# sell    300
# buy     173
# Name: signal, dtype: int64
# shape after -> (1055, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 120 TIME -> 0:0:10
#
# 120
# RUN FOR BBGI
# shape before -> (407, 23)
# SIGNAL COUNTS:
# hold    239
# sell    100
# buy      68
# Name: signal, dtype: int64
# shape after -> (407, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 121 TIME -> 0:0:4
#
# 121
# RUN FOR BEZ
# shape before -> (171, 23)
# SIGNAL COUNTS:
# hold    99
# sell    40
# buy     32
# Name: signal, dtype: int64
# shape after -> (171, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 122 TIME -> 0:0:2
#
# 122
# RUN FOR BWY
# shape before -> (1443, 23)
# SIGNAL COUNTS:
# hold    816
# sell    380
# buy     247
# Name: signal, dtype: int64
# shape after -> (1443, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 123 TIME -> 0:0:12
#
# 123
# RUN FOR BYG
# shape before -> (1004, 23)
# SIGNAL COUNTS:
# hold    567
# sell    265
# buy     172
# Name: signal, dtype: int64
# shape after -> (1004, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 124 TIME -> 0:0:9
#
# 124
# RUN FOR BRSC
# shape before -> (283, 23)
# SIGNAL COUNTS:
# hold    191
# sell     51
# buy      41
# Name: signal, dtype: int64
# shape after -> (283, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 125 TIME -> 0:0:3
#
# 125
# RUN FOR BRWM
# shape before -> (591, 23)
# SIGNAL COUNTS:
# hold    304
# buy     145
# sell    142
# Name: signal, dtype: int64
# shape after -> (591, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 126 TIME -> 0:0:5
#
# 126
# RUN FOR BGSC
# shape before -> (603, 23)
# SIGNAL COUNTS:
# hold    403
# sell    132
# buy      68
# Name: signal, dtype: int64
# shape after -> (603, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 127 TIME -> 0:0:5
#
# 127
# RUN FOR BOY
# shape before -> (1257, 23)
# SIGNAL COUNTS:
# hold    697
# sell    303
# buy     257
# Name: signal, dtype: int64
# shape after -> (1257, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 128 TIME -> 0:0:11
#
# 128
# RUN FOR BVS
# shape before -> (1124, 23)
# SIGNAL COUNTS:
# hold    626
# sell    291
# buy     207
# Name: signal, dtype: int64
# shape after -> (1124, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 129 TIME -> 0:0:10
#
# 129
# RUN FOR BRW
# shape before -> (1134, 23)
# SIGNAL COUNTS:
# hold    598
# sell    295
# buy     241
# Name: signal, dtype: int64
# shape after -> (1134, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 130 TIME -> 0:0:10
#
# 130
# RUN FOR BVIC
# shape before -> (713, 23)
# SIGNAL COUNTS:
# hold    370
# sell    186
# buy     157
# Name: signal, dtype: int64
# shape after -> (713, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 131 TIME -> 0:0:6
#
# 131
# RUN FOR CNE
# shape before -> (1410, 23)
# SIGNAL COUNTS:
# hold    803
# sell    352
# buy     255
# Name: signal, dtype: int64
# shape after -> (1410, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 132 TIME -> 0:0:12
#
# 132
# RUN FOR CLDN
# shape before -> (601, 23)
# SIGNAL COUNTS:
# hold    328
# sell    151
# buy     122
# Name: signal, dtype: int64
# shape after -> (601, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 133 TIME -> 0:0:5
#
# 133
# RUN FOR CAPC
# shape before -> (482, 23)
# SIGNAL COUNTS:
# hold    271
# sell    140
# buy      71
# Name: signal, dtype: int64
# shape after -> (482, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 134 TIME -> 0:0:4
#
# 134
# RUN FOR CPI
# shape before -> (1312, 23)
# SIGNAL COUNTS:
# hold    732
# sell    312
# buy     268
# Name: signal, dtype: int64
# shape after -> (1312, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 135 TIME -> 0:0:12
#
# 135
# RUN FOR CARD
# shape before -> (292, 23)
# SIGNAL COUNTS:
# hold    192
# sell     65
# buy      35
# Name: signal, dtype: int64
# shape after -> (292, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 136 TIME -> 0:0:3
#
# 136
# RUN FOR CEY
# shape before -> (919, 23)
# SIGNAL COUNTS:
# hold    529
# sell    242
# buy     148
# Name: signal, dtype: int64
# shape after -> (919, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 137 TIME -> 0:0:8
#
# 137
# RUN FOR CINE
# shape before -> (641, 23)
# SIGNAL COUNTS:
# hold    373
# sell    162
# buy     106
# Name: signal, dtype: int64
# shape after -> (641, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 138 TIME -> 0:0:6
#
# 138
# RUN FOR CTY
# shape before -> (605, 23)
# SIGNAL COUNTS:
# hold    356
# sell    145
# buy     104
# Name: signal, dtype: int64
# shape after -> (605, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 139 TIME -> 0:0:5
#
# 139
# RUN FOR CKN
# shape before -> (1314, 23)
# SIGNAL COUNTS:
# hold    750
# sell    294
# buy     270
# Name: signal, dtype: int64
# shape after -> (1314, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 140 TIME -> 0:0:11
#
# 140
# RUN FOR CBG
# shape before -> (1249, 23)
# SIGNAL COUNTS:
# hold    678
# sell    316
# buy     255
# Name: signal, dtype: int64
# shape after -> (1249, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 141 TIME -> 0:0:11
#
# 141
# RUN FOR CLI
# shape before -> (1285, 23)
# SIGNAL COUNTS:
# hold    727
# sell    343
# buy     215
# Name: signal, dtype: int64
# shape after -> (1285, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 142 TIME -> 0:0:11
#
# 142
# RUN FOR COA
# shape before -> (1382, 23)
# SIGNAL COUNTS:
# hold    839
# sell    302
# buy     241
# Name: signal, dtype: int64
# shape after -> (1382, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 143 TIME -> 0:0:12
#
# 143
# RUN FOR COB
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    683
# sell    341
# buy     242
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 144 TIME -> 0:0:11
#
# 144
# RUN FOR CCC
# shape before -> (1107, 23)
# SIGNAL COUNTS:
# hold    638
# sell    250
# buy     219
# Name: signal, dtype: int64
# shape after -> (1107, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 145 TIME -> 0:0:10
#
# 145
# RUN FOR GLO
# shape before -> (110, 23)
# SIGNAL COUNTS:
# hold    74
# sell    19
# buy     17
# Name: signal, dtype: int64
# shape after -> (110, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 146 TIME -> 0:0:1
#
# 146
# RUN FOR CTEC
# shape before -> (164, 23)
# SIGNAL COUNTS:
# hold    112
# buy      29
# sell     23
# Name: signal, dtype: int64
# shape after -> (164, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 147 TIME -> 0:0:1
#
# 147
# RUN FOR CSP
# shape before -> (420, 23)
# SIGNAL COUNTS:
# hold    246
# sell     94
# buy      80
# Name: signal, dtype: int64
# shape after -> (420, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 148 TIME -> 0:0:4
#
# 148
# RUN FOR CWK
# shape before -> (1122, 23)
# SIGNAL COUNTS:
# hold    637
# sell    291
# buy     194
# Name: signal, dtype: int64
# shape after -> (1122, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 149 TIME -> 0:0:10
#
# 149
# RUN FOR CRST
# shape before -> (338, 23)
# SIGNAL COUNTS:
# hold    193
# sell     94
# buy      51
# Name: signal, dtype: int64
# shape after -> (338, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 150 TIME -> 0:0:3
#
# 150
# RUN FOR DJAN
# shape before -> (1132, 23)
# SIGNAL COUNTS:
# hold    698
# sell    252
# buy     182
# Name: signal, dtype: int64
# shape after -> (1132, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 151 TIME -> 0:0:10
#
# 151
# RUN FOR DPH
# shape before -> (964, 23)
# SIGNAL COUNTS:
# hold    527
# sell    262
# buy     175
# Name: signal, dtype: int64
# shape after -> (964, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 152 TIME -> 0:0:9
#
# 152
# RUN FOR DLN
# shape before -> (1203, 23)
# SIGNAL COUNTS:
# hold    702
# sell    301
# buy     200
# Name: signal, dtype: int64
# shape after -> (1203, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 153 TIME -> 0:0:10
#
# 153
# RUN FOR DPLM
# shape before -> (1489, 23)
# SIGNAL COUNTS:
# hold    864
# sell    380
# buy     245
# Name: signal, dtype: int64
# shape after -> (1489, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 154 TIME -> 0:0:13
#
# 154
# RUN FOR DLG
# shape before -> (356, 23)
# SIGNAL COUNTS:
# hold    189
# sell    102
# buy      65
# Name: signal, dtype: int64
# shape after -> (356, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 155 TIME -> 0:0:3
#
# 155
# RUN FOR DC
# shape before -> (533, 23)
# SIGNAL COUNTS:
# hold    299
# sell    136
# buy      98
# Name: signal, dtype: int64
# shape after -> (533, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 156 TIME -> 0:0:5
#
# 156
# RUN FOR DOM
# shape before -> (1028, 23)
# SIGNAL COUNTS:
# hold    597
# sell    256
# buy     175
# Name: signal, dtype: int64
# shape after -> (1028, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 157 TIME -> 0:0:11
#
# 157
# RUN FOR DRX
# shape before -> (712, 23)
# SIGNAL COUNTS:
# hold    420
# sell    156
# buy     136
# Name: signal, dtype: int64
# shape after -> (712, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 158 TIME -> 0:0:7
#
# 158
# RUN FOR DNLM
# shape before -> (668, 23)
# SIGNAL COUNTS:
# hold    382
# sell    180
# buy     106
# Name: signal, dtype: int64
# shape after -> (668, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 159 TIME -> 0:0:6
#
# 159
# RUN FOR EZJ
# shape before -> (977, 23)
# SIGNAL COUNTS:
# hold    522
# buy     229
# sell    226
# Name: signal, dtype: int64
# shape after -> (977, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 160 TIME -> 0:0:9
#
# 160
# RUN FOR EDIN
# shape before -> (589, 23)
# SIGNAL COUNTS:
# hold    342
# sell    156
# buy      91
# Name: signal, dtype: int64
# shape after -> (589, 215)
# ...
# LAP 287 TIME -> 0:0:1
#
# 287
# RUN FOR SAFE
# shape before -> (472, 23)
# SIGNAL COUNTS:
# hold    281
# sell    125
# buy      66
# Name: signal, dtype: int64
# shape after -> (472, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 288 TIME -> 0:0:5
#
# 288
# RUN FOR SNN
# shape before -> (246, 23)
# SIGNAL COUNTS:
# hold    141
# sell     60
# buy      45
# Name: signal, dtype: int64
# shape after -> (246, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 289 TIME -> 0:0:3
#
# 289
# RUN FOR SVS
# shape before -> (1422, 23)
# SIGNAL COUNTS:
# hold    779
# sell    381
# buy     262
# Name: signal, dtype: int64
# shape after -> (1422, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 290 TIME -> 0:0:19
#
# 290
# RUN FOR SDP
# shape before -> (596, 23)
# SIGNAL COUNTS:
# hold    342
# sell    144
# buy     110
# Name: signal, dtype: int64
# shape after -> (596, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 291 TIME -> 0:0:9
#
# 291
# RUN FOR SOI
# shape before -> (594, 23)
# SIGNAL COUNTS:
# hold    344
# sell    144
# buy     106
# Name: signal, dtype: int64
# shape after -> (594, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 292 TIME -> 0:0:10
#
# 292
# RUN FOR SCIN
# shape before -> (596, 23)
# SIGNAL COUNTS:
# hold    340
# sell    151
# buy     105
# Name: signal, dtype: int64
# shape after -> (596, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 293 TIME -> 0:0:7
#
# 293
# RUN FOR SNR
# shape before -> (1438, 23)
# SIGNAL COUNTS:
# hold    832
# sell    367
# buy     239
# Name: signal, dtype: int64
# shape after -> (1438, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 294 TIME -> 0:0:16
#
# 294
# RUN FOR SEQI
# shape before -> (240, 23)
# SIGNAL COUNTS:
# hold    155
# sell     46
# buy      39
# Name: signal, dtype: int64
# shape after -> (240, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 295 TIME -> 0:0:3
#
# 295
# RUN FOR SRP
# shape before -> (1295, 23)
# SIGNAL COUNTS:
# hold    736
# sell    312
# buy     247
# Name: signal, dtype: int64
# shape after -> (1295, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 296 TIME -> 0:0:14
#
# 296
# RUN FOR SHB
# shape before -> (1162, 23)
# SIGNAL COUNTS:
# hold    645
# sell    310
# buy     207
# Name: signal, dtype: int64
# shape after -> (1162, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 297 TIME -> 0:0:12
#
# 297
# RUN FOR SHI
# shape before -> (1328, 23)
# SIGNAL COUNTS:
# hold    707
# sell    366
# buy     255
# Name: signal, dtype: int64
# shape after -> (1328, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 298 TIME -> 0:0:14
#
# 298
# RUN FOR SRE
# shape before -> (633, 23)
# SIGNAL COUNTS:
# hold    389
# sell    130
# buy     114
# Name: signal, dtype: int64
# shape after -> (633, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 299 TIME -> 0:0:7
#
# 299
# RUN FOR SSON
# shape before -> (51, 23)
# SIGNAL COUNTS:
# hold    32
# sell    10
# buy      9
# Name: signal, dtype: int64
# shape after -> (51, 215)
# WARNING -> Attempting to change dtypes
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 300 TIME -> 0:0:1
#
# 300
# RUN FOR SCT
# shape before -> (214, 23)
# SIGNAL COUNTS:
# hold    116
# sell     56
# buy      42
# Name: signal, dtype: int64
# shape after -> (214, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 301 TIME -> 0:0:3
#
# 301
# RUN FOR SOPH
# shape before -> (234, 23)
# SIGNAL COUNTS:
# hold    159
# sell     42
# buy      33
# Name: signal, dtype: int64
# shape after -> (234, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 302 TIME -> 0:0:3
#
# 302
# RUN FOR SXS
# shape before -> (1488, 23)
# SIGNAL COUNTS:
# hold    867
# sell    354
# buy     267
# Name: signal, dtype: int64
# shape after -> (1488, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 303 TIME -> 0:0:14
#
# 303
# RUN FOR SPT
# shape before -> (1265, 23)
# SIGNAL COUNTS:
# hold    690
# sell    314
# buy     261
# Name: signal, dtype: int64
# shape after -> (1265, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 304 TIME -> 0:0:11
#
# 304
# RUN FOR SPD
# shape before -> (649, 23)
# SIGNAL COUNTS:
# hold    375
# sell    142
# buy     132
# Name: signal, dtype: int64
# shape after -> (649, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 305 TIME -> 0:0:6
#
# 305
# RUN FOR SSPG
# shape before -> (284, 23)
# SIGNAL COUNTS:
# hold    169
# sell     69
# buy      46
# Name: signal, dtype: int64
# shape after -> (284, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 306 TIME -> 0:0:3
#
# 306
# RUN FOR SMP
# shape before -> (1433, 23)
# SIGNAL COUNTS:
# hold    822
# sell    358
# buy     253
# Name: signal, dtype: int64
# shape after -> (1433, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 307 TIME -> 0:0:13
#
# 307
# RUN FOR SGC
# shape before -> (1161, 23)
# SIGNAL COUNTS:
# hold    671
# sell    249
# buy     241
# Name: signal, dtype: int64
# shape after -> (1161, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 308 TIME -> 0:0:10
#
# 308
# RUN FOR SYNC
# shape before -> (345, 23)
# SIGNAL COUNTS:
# hold    212
# sell     89
# buy      44
# Name: signal, dtype: int64
# shape after -> (345, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 309 TIME -> 0:0:3
#
# 309
# RUN FOR SYNT
# shape before -> (1463, 23)
# SIGNAL COUNTS:
# hold    838
# sell    356
# buy     269
# Name: signal, dtype: int64
# shape after -> (1463, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 310 TIME -> 0:0:13
#
# 310
# RUN FOR TALK
# shape before -> (489, 23)
# SIGNAL COUNTS:
# hold    291
# sell    114
# buy      84
# Name: signal, dtype: int64
# shape after -> (489, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 311 TIME -> 0:0:5
#
# 311
# RUN FOR TATE
# shape before -> (1270, 23)
# SIGNAL COUNTS:
# hold    728
# sell    282
# buy     260
# Name: signal, dtype: int64
# shape after -> (1270, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 312 TIME -> 0:0:11
#
# 312
# RUN FOR TBCG
# shape before -> (175, 23)
# SIGNAL COUNTS:
# hold    112
# sell     42
# buy      21
# Name: signal, dtype: int64
# shape after -> (175, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 313 TIME -> 0:0:2
#
# 313
# RUN FOR TEP
# shape before -> (993, 23)
# SIGNAL COUNTS:
# hold    539
# sell    258
# buy     196
# Name: signal, dtype: int64
# shape after -> (993, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 314 TIME -> 0:0:9
#
# 314
# RUN FOR TMPL
# shape before -> (596, 23)
# SIGNAL COUNTS:
# hold    353
# sell    161
# buy      82
# Name: signal, dtype: int64
# shape after -> (596, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 315 TIME -> 0:0:5
#
# 315
# RUN FOR TEM
# shape before -> (595, 23)
# SIGNAL COUNTS:
# hold    310
# sell    159
# buy     126
# Name: signal, dtype: int64
# shape after -> (595, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 316 TIME -> 0:0:5
#
# 316
# RUN FOR TIFS
# shape before -> (112, 23)
# SIGNAL COUNTS:
# hold    82
# sell    16
# buy     14
# Name: signal, dtype: int64
# shape after -> (112, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 317 TIME -> 0:0:1
#
# 317
# RUN FOR TCAP
# shape before -> (970, 23)
# SIGNAL COUNTS:
# hold    542
# sell    242
# buy     186
# Name: signal, dtype: int64
# shape after -> (970, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 318 TIME -> 0:0:8
#
# 318
# RUN FOR TRY
# shape before -> (594, 23)
# SIGNAL COUNTS:
# hold    330
# sell    146
# buy     118
# Name: signal, dtype: int64
# shape after -> (594, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 319 TIME -> 0:0:5
#
# 319
# RUN FOR TPK
# shape before -> (1036, 23)
# SIGNAL COUNTS:
# hold    579
# sell    283
# buy     174
# Name: signal, dtype: int64
# shape after -> (1036, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 320 TIME -> 0:0:9
#
# 320
# RUN FOR BBOX
# shape before -> (286, 23)
# SIGNAL COUNTS:
# hold    156
# sell     78
# buy      52
# Name: signal, dtype: int64
# shape after -> (286, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 321 TIME -> 0:0:3
#
# 321
# RUN FOR TLW
# shape before -> (1028, 23)
# SIGNAL COUNTS:
# hold    594
# sell    266
# buy     168
# Name: signal, dtype: int64
# shape after -> (1028, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 322 TIME -> 0:0:9
#
# 322
# RUN FOR UDG
# shape before -> (1017, 23)
# SIGNAL COUNTS:
# hold    600
# sell    264
# buy     153
# Name: signal, dtype: int64
# shape after -> (1017, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 323 TIME -> 0:0:10
#
# 323
# RUN FOR UKCM
# shape before -> (596, 23)
# SIGNAL COUNTS:
# hold    302
# sell    171
# buy     123
# Name: signal, dtype: int64
# shape after -> (596, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 324 TIME -> 0:0:5
#
# 324
# RUN FOR ULE
# shape before -> (1032, 23)
# SIGNAL COUNTS:
# hold    619
# sell    257
# buy     156
# Name: signal, dtype: int64
# shape after -> (1032, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 325 TIME -> 0:0:10
#
# 325
# RUN FOR UTG
# shape before -> (352, 23)
# SIGNAL COUNTS:
# hold    206
# sell    100
# buy      46
# Name: signal, dtype: int64
# shape after -> (352, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 326 TIME -> 0:0:4
#
# 326
# RUN FOR VSVS
# shape before -> (1266, 23)
# SIGNAL COUNTS:
# hold    662
# buy     305
# sell    299
# Name: signal, dtype: int64
# shape after -> (1266, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 327 TIME -> 0:0:11
#
# 327
# RUN FOR VCT
# shape before -> (1195, 23)
# SIGNAL COUNTS:
# hold    660
# sell    309
# buy     226
# Name: signal, dtype: int64
# shape after -> (1195, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 328 TIME -> 0:0:13
#
# 328
# RUN FOR VEIL
# shape before -> (170, 23)
# SIGNAL COUNTS:
# hold    93
# sell    52
# buy     25
# Name: signal, dtype: int64
# shape after -> (170, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 329 TIME -> 0:0:2
#
# 329
# RUN FOR VOF
# shape before -> (604, 23)
# SIGNAL COUNTS:
# hold    361
# buy     123
# sell    120
# Name: signal, dtype: int64
# shape after -> (604, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 330 TIME -> 0:0:6
#
# 330
# RUN FOR VVO
# shape before -> (85, 23)
# SIGNAL COUNTS:
# hold    57
# sell    16
# buy     12
# Name: signal, dtype: int64
# shape after -> (85, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 331 TIME -> 0:0:1
#
# 331
# RUN FOR WEIR
# shape before -> (1478, 23)
# SIGNAL COUNTS:
# hold    836
# sell    354
# buy     288
# Name: signal, dtype: int64
# shape after -> (1478, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 332 TIME -> 0:0:13
#
# 332
# RUN FOR JDW
# shape before -> (1352, 23)
# SIGNAL COUNTS:
# hold    753
# sell    352
# buy     247
# Name: signal, dtype: int64
# shape after -> (1352, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 333 TIME -> 0:0:12
#
# 333
# RUN FOR SMWH
# shape before -> (678, 23)
# SIGNAL COUNTS:
# hold    404
# sell    178
# buy      96
# Name: signal, dtype: int64
# shape after -> (678, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 334 TIME -> 0:0:6
#
# 334
# RUN FOR WMH
# shape before -> (894, 23)
# SIGNAL COUNTS:
# hold    488
# sell    233
# buy     173
# Name: signal, dtype: int64
# shape after -> (894, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 335 TIME -> 0:0:8
#
# 335
# RUN FOR WTAN
# shape before -> (603, 23)
# SIGNAL COUNTS:
# hold    371
# sell    131
# buy     101
# Name: signal, dtype: int64
# shape after -> (603, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 336 TIME -> 0:0:5
#
# 336
# RUN FOR WIZZ
# shape before -> (251, 23)
# SIGNAL COUNTS:
# hold    144
# sell     61
# buy      46
# Name: signal, dtype: int64
# shape after -> (251, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 337 TIME -> 0:0:2
#
# 337
# RUN FOR WG
# shape before -> (916, 23)
# SIGNAL COUNTS:
# hold    508
# sell    216
# buy     192
# Name: signal, dtype: int64
# shape after -> (916, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 338 TIME -> 0:0:8
#
# 338
# RUN FOR WKP
# shape before -> (956, 23)
# SIGNAL COUNTS:
# hold    548
# sell    228
# buy     180
# Name: signal, dtype: int64
# shape after -> (956, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 339 TIME -> 0:0:8
#
# 339
# RUN FOR WWH
# shape before -> (605, 23)
# SIGNAL COUNTS:
# hold    368
# sell    152
# buy      85
# Name: signal, dtype: int64
# shape after -> (605, 215)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 340 TIME -> 0:0:5
#
#
#
# TOTAL ELAPSED TIME -> 0:45:54
#
# ERROR COUNT -> 0

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
tmp_df = pd.read_hdf(hf_store_name,key='weekly_data',mode='r')
print("")
print("FINAL HDFSTORE SIZE: {}".format(tmp_df.shape))
print("FINAL BUY COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "buy"])))
print("FINAL SELL COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "sell"])))
h_store.close()
tmp_df.head(50)
# tmp_df[(tmp_df["ticker"] == 'ADM') & (tmp_df["date"] > '2013-12-01') & (tmp_df["date"] < '2014-02-01')].head(200)
# Out:
# FINAL HDFSTORE SIZE: (281287, 144)
# FINAL BUY COUNT: 52218
# FINAL SELL COUNT: 69568
#        ticker       date      open     close      high       low    volume  \
# 214063   SBRY 1995-01-02       NaN       NaN       NaN       NaN       NaN
# 214064   SBRY 1995-01-09  1.000000  1.000000  1.000000  1.000000  1.000000
# 214065   SBRY 1995-01-16  1.000000  1.000000  1.000000  1.000000  1.000000
# 214066   SBRY 1995-01-23  0.125278  1.000000  1.000000  0.599644  0.861339
# 214067   SBRY 1995-01-30  1.000000  0.833416  0.861097  1.000000  0.546860
# 214068   SBRY 1995-02-06  0.924822  0.333169  0.944637  0.666337  0.328915
# 214069   SBRY 1995-02-13  0.524911  0.055858  0.333169  0.555610  0.226638
# 214070   SBRY 1995-02-20  0.125000  0.000000  0.000000  0.277805  0.245291
# 214071   SBRY 1995-02-27  0.050267  0.000000  0.000000  0.166584  0.019576
# 214072   SBRY 1995-03-06  0.000000  0.136327  0.000000  0.000000  0.126197
# 214073   SBRY 1995-03-13  0.185844  0.704288  0.657611  0.405002  0.258601
# 214074   SBRY 1995-03-20  1.000000  0.772654  1.000000  1.000000  0.366260
# 214075   SBRY 1995-03-27  0.640085  1.000000  1.000000  0.866693  0.000000
# 214076   SBRY 1995-07-31  1.000000  1.000000  1.000000  1.000000  0.000000
# 214077   SBRY 1995-08-07  0.863238  0.847057  1.000000  0.855417  0.195300
# 214078   SBRY 1995-08-14  0.741760  1.000000  1.000000  0.775186  0.463483
# 214079   SBRY 1995-08-21  1.000000  1.000000  1.000000  1.000000  0.138136
# 214080   SBRY 1995-08-28  1.000000  0.956544  1.000000  0.926695  0.267977
# 214081   SBRY 1995-09-04  0.942739  1.000000  0.922965  0.970652  0.635920
# 214082   SBRY 1995-09-11  1.000000  0.943684  0.916564  1.000000  0.283571
# 214083   SBRY 1995-09-18  0.890197  0.636287  0.820326  0.707036  0.471771
# 214084   SBRY 1995-09-25  0.643080  0.434558  0.576418  0.443419  0.555264
# 214085   SBRY 1995-10-02  0.427439  0.354947  0.371140  0.399462  0.438261
# 214086   SBRY 1995-10-09  0.340942  0.409822  0.383942  0.370114  0.785323
# 214087   SBRY 1995-10-16  0.340942  0.039385  0.383942  0.106498  0.527227
# 214088   SBRY 1995-10-23  0.025228  0.107949  0.063111  0.003973  0.804352
# 214089   SBRY 1995-10-30  0.121336  0.000000  0.242785  0.000000  1.000000
# 214090   SBRY 1995-11-06  0.000000  0.106395  0.000000  0.000000  0.278607
# 214091   SBRY 1995-11-13  0.033346  0.000000  0.000000  0.102054  0.430311
# 214092   SBRY 1995-11-20  0.000000  0.000000  0.000000  0.000000  0.559804
# 214093   SBRY 1995-11-27  0.000000  0.098044  0.000000  0.039986  0.143238
# 214094   SBRY 1995-12-04  0.126215  0.000000  0.050468  0.009975  0.321880
# 214095   SBRY 1995-12-11  0.010076  0.019918  0.000000  0.000000  0.201774
# 214096   SBRY 1995-12-18  0.000000  0.105675  0.000000  0.000000  0.307988
# 214097   SBRY 1995-12-25  0.095250  0.232137  0.128583  0.141560  0.024885
# 214098   SBRY 1996-01-01  0.209500  0.123775  0.114250  0.150970  0.290484
# 214099   SBRY 1996-01-08  0.076167  0.331489  0.266667  0.160380  0.864424
# 214100   SBRY 1996-01-15  0.342833  0.448941  0.407583  0.377383  0.642606
# 214101   SBRY 1996-01-22  0.466667  0.196016  0.500000  0.254726  0.925536
# 214102   SBRY 1996-01-29  0.171417  0.214116  0.161917  0.217004  0.672450
# 214103   SBRY 1996-02-05  0.142833  0.177996  0.133333  0.217004  0.350777
# 214104   SBRY 1996-02-12  0.138083  0.168906  0.066667  0.160380  0.557739
# 214105   SBRY 1996-02-19  0.104750  0.123775  0.061917  0.160380  0.114939
# 214106   SBRY 1996-02-26  0.104750  0.074059  0.028583  0.113248  0.633372
# 214107   SBRY 1996-03-04  0.066667  0.105675  0.157167  0.113248  0.168319
# 214108   SBRY 1996-03-11  0.009500  0.037939  0.014250  0.066034  0.365429
# 214109   SBRY 1996-03-18  0.000000  0.060544  0.000000  0.075526  0.151433
# 214110   SBRY 1996-03-25  0.007526  0.000000  0.000000  0.000000  0.882522
# 214111   SBRY 1996-04-01  0.000000  0.117912  0.070314  0.018472  0.274896
# 214112   SBRY 1996-04-08  0.138614  0.100413  0.054075  0.101839  0.198743
#
#         change_price  per_change_price     ema26  ...  prev_min_grad_volume  \
# 214063           NaN               NaN       NaN  ...                   NaN
# 214064      0.000000          0.000000       NaN  ...                   NaN
# 214065      0.000000          0.000000       NaN  ...                   NaN
# 214066      0.874722          0.874722       NaN  ...                   NaN
# 214067     -0.166584         -0.199881       NaN  ...                   NaN
# 214068     -0.591654         -1.775838       NaN  ...                   NaN
# 214069     -0.469053         -8.397301       NaN  ...                   NaN
# 214070     -0.125000              -inf       NaN  ...                   NaN
# 214071     -0.050267              -inf       NaN  ...                   NaN
# 214072      0.136327          1.000000       NaN  ...                   NaN
# 214073      0.518444          0.736124       NaN  ...                   NaN
# 214074     -0.227346         -0.294241       NaN  ...                   NaN
# 214075      0.359915          0.359915       NaN  ...                   NaN
# 214076      0.000000          0.000000       NaN  ...                   NaN
# 214077     -0.016181         -0.019102       NaN  ...                   NaN
# 214078      0.258240          0.258240       NaN  ...              0.004630
# 214079      0.000000          0.000000       NaN  ...             -0.325346
# 214080     -0.043456         -0.045430       NaN  ...             -0.325346
# 214081      0.057261          0.057261       NaN  ...             -0.325346
# 214082     -0.056316         -0.059677       NaN  ...             -0.325346
# 214083     -0.253910         -0.399049       NaN  ...             -0.325346
# 214084     -0.208522         -0.479849       NaN  ...             -0.325346
# 214085     -0.072492         -0.204232       NaN  ...             -0.325346
# 214086      0.068880          0.168074       NaN  ...             -0.325346
# 214087     -0.301557         -7.656597       NaN  ...             -0.325346
# 214088      0.082721          0.766295       NaN  ...             -0.325346
# 214089     -0.121336              -inf       NaN  ...             -0.325346
# 214090      0.106395          1.000000  0.562224  ...             -0.325346
# 214091     -0.033346              -inf  0.522519  ...             -0.325346
# 214092      0.000000               NaN  0.486907  ...             -0.325346
# 214093      0.098044          1.000000  0.458557  ...             -0.325346
# 214094     -0.126215              -inf  0.425106  ...             -0.325346
# 214095      0.009842          0.494120  0.414716  ...             -0.325346
# 214096      0.105675          1.000000  0.419789  ...              0.009991
# 214097      0.136887          0.589682  0.432920  ...              0.009991
# 214098     -0.085725         -0.692589  0.433160  ...              0.009991
# 214099      0.255322          0.770229  0.448099  ...              0.009991
# 214100      0.106108          0.236351  0.443523  ...              0.083654
# 214101     -0.270650         -1.380753  0.413259  ...              0.083654
# 214102      0.042700          0.199423  0.385968  ...              0.083654
# 214103      0.035162          0.197546  0.355305  ...              0.083654
# 214104      0.030823          0.182485  0.330805  ...              0.083654
# 214105      0.019025          0.153706  0.297865  ...              0.083654
# 214106     -0.030691         -0.414404  0.262977  ...              0.083654
# 214107      0.039008          0.369135  0.233892  ...              0.083654
# 214108      0.028439          0.749596  0.197025  ...             -0.034647
# 214109      0.060544          1.000000  0.166444  ...             -0.034647
# 214110     -0.007526              -inf  0.141455  ...             -0.034647
# 214111      0.117912          1.000000  0.134714  ...             -0.034647
# 214112     -0.038201         -0.380442  0.124976  ...             -0.034647
#
#         prev_grad_conv_volume  max_move_cum_volume  min_move_cum_volume  \
# 214063                    NaN                    0                    0
# 214064                    NaN                    0                    0
# 214065                    NaN                    0                    0
# 214066                    NaN                    0                    0
# 214067                    NaN                    0                    0
# 214068                    NaN                    0                    0
# 214069                    NaN                    0                    0
# 214070                    NaN                    0                    0
# 214071                    NaN                    0                    0
# 214072                    NaN                    0                    0
# 214073                    NaN                    0                    0
# 214074                    NaN                    0                    0
# 214075                    NaN                    0                    0
# 214076                    NaN                    0                    0
# 214077                    NaN                    0                    0
# 214078                    NaN                    0                    1
# 214079                    NaN                    0                    0
# 214080                    NaN                    0                    0
# 214081                    NaN                    0                    0
# 214082                    NaN                    0                    0
# 214083                    NaN                    0                    0
# 214084              -0.376770                    1                    0
# 214085              -0.376770                    1                    0
# 214086              -0.376770                    1                    0
# 214087              -0.376770                    1                    0
# 214088              -0.376770                    1                    0
# 214089              -0.376770                    1                    0
# 214090              -0.376770                    1                    0
# 214091              -0.376770                    1                    0
# 214092              -0.325914                    2                    0
# 214093              -0.325914                    2                    0
# 214094              -0.325914                    2                    0
# 214095              -0.325914                    2                    0
# 214096               0.009424                    2                    0
# 214097               0.009424                    2                    0
# 214098               0.009424                    2                    0
# 214099               0.009424                    2                    0
# 214100               0.083087                    2                    1
# 214101               0.083087                    2                    1
# 214102               0.083087                    2                    1
# 214103               0.083087                    2                    1
# 214104               0.083827                    0                    1
# 214105               0.083827                    0                    1
# 214106               0.083827                    0                    1
# 214107               0.083827                    0                    1
# 214108              -0.034475                    0                    0
# 214109              -0.034475                    0                    0
# 214110              -0.034475                    0                    0
# 214111              -0.034475                    0                    0
# 214112              -0.034475                    0                    0
#
#         long_prev_max_move_date_volume  long_prev_min_move_date_volume  \
# 214063                             0.0                             0.0
# 214064                             0.0                             0.0
# 214065                             0.0                             0.0
# 214066                             0.0                             0.0
# 214067                             0.0                             0.0
# 214068                             0.0                             0.0
# 214069                             0.0                             0.0
# 214070                             0.0                             0.0
# 214071                             0.0                             0.0
# 214072                             0.0                             0.0
# 214073                             0.0                             0.0
# 214074                             0.0                             0.0
# 214075                             0.0                             0.0
# 214076                             0.0                             0.0
# 214077                             0.0                             0.0
# 214078                             0.0                             0.0
# 214079                             0.0                             0.0
# 214080                             0.0                             0.0
# 214081                             0.0                             0.0
# 214082                             0.0                             0.0
# 214083                             0.0                             0.0
# 214084                             0.0                             0.0
# 214085                             0.0                             0.0
# 214086                             0.0                             0.0
# 214087                             0.0                             0.0
# 214088                             0.0                             0.0
# 214089                             0.0                             0.0
# 214090                             0.0                             0.0
# 214091                             0.0                             0.0
# 214092                             8.0                             0.0
# 214093                             8.0                             0.0
# 214094                             8.0                             0.0
# 214095                             8.0                             0.0
# 214096                             8.0                             0.0
# 214097                             8.0                             0.0
# 214098                             8.0                             0.0
# 214099                             8.0                             0.0
# 214100                             8.0                             4.0
# 214101                             8.0                             4.0
# 214102                             8.0                             4.0
# 214103                             8.0                             4.0
# 214104                             0.0                             4.0
# 214105                             0.0                             4.0
# 214106                             0.0                             4.0
# 214107                             0.0                             4.0
# 214108                             0.0                             0.0
# 214109                             0.0                             0.0
# 214110                             0.0                             0.0
# 214111                             0.0                             0.0
# 214112                             0.0                             0.0
#
#         long_max_grad_volume  long_min_grad_volume  long_grad_conv_volume  \
# 214063                   NaN                   NaN                    NaN
# 214064                   NaN                   NaN                    NaN
# 214065                   NaN                   NaN                    NaN
# 214066                   NaN                   NaN                    NaN
# 214067                   NaN                   NaN                    NaN
# 214068                   NaN                   NaN                    NaN
# 214069                   NaN                   NaN                    NaN
# 214070                   NaN                   NaN                    NaN
# 214071                   NaN                   NaN                    NaN
# 214072                   NaN                   NaN                    NaN
# 214073                   NaN                   NaN                    NaN
# 214074                   NaN                   NaN                    NaN
# 214075                   NaN                   NaN                    NaN
# 214076                   NaN                   NaN                    NaN
# 214077                   NaN                   NaN                    NaN
# 214078                   NaN                   NaN                    NaN
# 214079                   NaN                   NaN                    NaN
# 214080                   NaN                   NaN                    NaN
# 214081                   NaN                   NaN                    NaN
# 214082                   NaN                   NaN                    NaN
# 214083                   NaN                   NaN                    NaN
# 214084                   NaN                   NaN                    NaN
# 214085                   NaN                   NaN                    NaN
# 214086                   NaN                   NaN                    NaN
# 214087                   NaN                   NaN                    NaN
# 214088                   NaN                   NaN                    NaN
# 214089                   NaN                   NaN                    NaN
# 214090                   NaN                   NaN                    NaN
# 214091                   NaN                   NaN                    NaN
# 214092              0.000567                   NaN                    NaN
# 214093              0.000567                   NaN                    NaN
# 214094              0.000567                   NaN                    NaN
# 214095              0.000567                   NaN                    NaN
# 214096              0.000567                   NaN                    NaN
# 214097              0.000567                   NaN                    NaN
# 214098              0.000567                   NaN                    NaN
# 214099              0.000567                   NaN                    NaN
# 214100              0.000567              0.083654               0.083087
# 214101              0.000567              0.083654               0.083087
# 214102              0.000567              0.083654               0.083087
# 214103              0.000567              0.083654               0.083087
# 214104                   NaN              0.083654                    NaN
# 214105                   NaN              0.083654                    NaN
# 214106                   NaN              0.083654                    NaN
# 214107                   NaN              0.083654                    NaN
# 214108                   NaN                   NaN                    NaN
# 214109                   NaN                   NaN                    NaN
# 214110                   NaN                   NaN                    NaN
# 214111                   NaN                   NaN                    NaN
# 214112                   NaN                   NaN                    NaN
#
#         signal
# 214063    hold
# 214064    hold
# 214065    hold
# 214066    sell
# 214067    hold
# 214068    hold
# 214069    hold
# 214070    hold
# 214071     buy
# 214072     buy
# 214073    hold
# 214074    hold
# 214075    hold
# 214076    sell
# 214077    hold
# 214078    hold
# 214079    sell
# 214080    hold
# 214081    sell
# 214082    sell
# 214083    sell
# 214084    sell
# 214085    hold
# 214086    sell
# 214087    hold
# 214088    hold
# 214089     buy
# 214090    hold
# 214091    hold
# 214092     buy
# 214093    hold
# 214094     buy
# 214095     buy
# 214096    hold
# 214097    hold
# 214098    hold
# 214099    hold
# 214100    sell
# 214101    hold
# 214102    sell
# 214103    sell
# 214104    sell
# 214105    hold
# 214106    hold
# 214107    hold
# 214108    hold
# 214109    hold
# 214110     buy
# 214111    hold
# 214112    hold
#
# [50 rows x 144 columns]

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5

# %%
#Remove 'date' from out_cols
out_cols.remove('date')

# %%
#Export a list of the features for this model
file_object = open(path+r'\feature_engineering_feature_list.txt','w')
feature_str = ''
for i in out_cols:
    feature_str += '{},'.format(i)
feature_str = feature_str[:-1]
file_object.write(feature_str)
file_object.close()
feature_str
# Out:
# 'ticker,open,close,high,low,volume,change_price,per_change_price,ema26,macd,signal_line,macd_line,close_orig_per_change_max_4,close_orig_per_change_max_13,close_orig_per_change_max_26,close_orig_per_change_max_52,close_orig_per_change_min_4,close_orig_per_change_min_13,close_orig_per_change_min_26,close_orig_per_change_min_52,macd_line_per_change_max_4,macd_line_per_change_max_13,macd_line_per_change_max_26,macd_line_per_change_max_52,macd_line_per_change_min_4,macd_line_per_change_min_13,macd_line_per_change_min_26,macd_line_per_change_min_52,change_close_shift1,close_max,close_min,prev_max_close,prev_min_close,prev_max_close_date_change,prev_min_close_date_change,max_change_close,min_change_close,prev_max_grad_close,prev_min_grad_close,prev_grad_conv_close,max_move_cum_close,min_move_cum_close,long_prev_max_move_date_close,long_prev_min_move_date_close,long_max_grad_close,long_min_grad_close,long_grad_conv_close,change_macd_shift1,macd_max,macd_min,prev_max_macd,prev_min_macd,prev_max_macd_date_change,prev_min_macd_date_change,max_change_macd,min_change_macd,prev_max_grad_macd,prev_min_grad_macd,prev_grad_conv_macd,max_move_cum_macd,min_move_cum_macd,long_prev_max_move_date_macd,long_prev_min_move_date_macd,long_max_grad_macd,long_min_grad_macd,long_grad_conv_macd,change_ema26_shift1,ema26_max,ema26_min,prev_max_ema26,prev_min_ema26,prev_max_ema26_date_change,prev_min_ema26_date_change,max_change_ema26,min_change_ema26,prev_max_grad_ema26,prev_min_grad_ema26,prev_grad_conv_ema26,max_move_cum_ema26,min_move_cum_ema26,long_prev_max_move_date_ema26,long_prev_min_move_date_ema26,long_max_grad_ema26,long_min_grad_ema26,long_grad_conv_ema26,change_signal_line_shift1,signal_line_max,signal_line_min,prev_max_signal_line,prev_min_signal_line,prev_max_signal_line_date_change,prev_min_signal_line_date_change,max_change_signal_line,min_change_signal_line,prev_max_grad_signal_line,prev_min_grad_signal_line,prev_grad_conv_signal_line,max_move_cum_signal_line,min_move_cum_signal_line,long_prev_max_move_date_signal_line,long_prev_min_move_date_signal_line,long_max_grad_signal_line,long_min_grad_signal_line,long_grad_conv_signal_line,change_macd_line_shift1,macd_line_max,macd_line_min,prev_max_macd_line,prev_min_macd_line,prev_max_macd_line_date_change,prev_min_macd_line_date_change,max_change_macd_line,min_change_macd_line,prev_max_grad_macd_line,prev_min_grad_macd_line,prev_grad_conv_macd_line,max_move_cum_macd_line,min_move_cum_macd_line,long_prev_max_move_date_macd_line,long_prev_min_move_date_macd_line,long_max_grad_macd_line,long_min_grad_macd_line,long_grad_conv_macd_line,change_volume_shift1,volume_max,volume_min,prev_max_volume,prev_min_volume,prev_max_volume_date_change,prev_min_volume_date_change,max_change_volume,min_change_volume,prev_max_grad_volume,prev_min_grad_volume,prev_grad_conv_volume,max_move_cum_volume,min_move_cum_volume,long_prev_max_move_date_volume,long_prev_min_move_date_volume,long_max_grad_volume,long_min_grad_volume,long_grad_conv_volume,signal'
