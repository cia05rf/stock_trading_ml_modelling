# %% [markdown]
# # Daily web scrape of stock prices
# This code accesses site to retrieve stock price information daily ad add it to the h5 file. The steps are:
# 1. Get FTSE 100 and FTSE 250 lists from wikipedia, then compile into one list.
# 2. open pipe to h5 file holding current price data.
# 3. Loop though the tickers and for each one;
#     1. find the most recent price date.
#     2. convert this into a time stamp to be used on Yahoo finance.
#     3. go to Yahoo Finance and get all the prices between the last time stamp and the current timestamp.
# 4. Add these new prices to the h5 file.
# 5. Create a new (empty) h5 file and transfer all the data from the old file into the new one.
# 6. Delete the old h5 file and rename the new one.
#
# The sources of data are:
# - https://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/summary/summary-indices-constituents.html?index=NMX&page=1 -> list of FTSE 350 company stock tickers
# - https://finance.yahoo.com/quote/{stock-ticker}/history?period1={start-time-mark}&period2={end-time-mark}&interval={interval}&filter=history&frequency={frequency} -> Example web address to retrieve information from Yahoo finance
#     - Data on this page is scroll loaded so many time indexes must be used toretrieve the dcorrect data
#     - Up to 145 records can be seen from initial page load note that this includes dividends so limit to 140 for safety
#
# The inputs required for scrapping are:
#  - {stock-ticker} -> this is the ticker taken from wiki with '.L' appended to it
#  - {start-tme-mark} -> This is the time in seconds since 01/01/1970 at which you would like the data retrieval to start, data retrieved is inclusive of this time
#  - {end-tme-mark} -> This is the time in seconds since 01/01/1970, data retrieved is inclusive of this time
#  - {interval} & {frequency} -> This is the interval for which values are given, the two must match
#      - 1d = 1 every 1 days
#      - 1wk = 1 every week
#      - 1mo = 1 eveery month

# %%
#Import libraries
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import datetime as dt
import os
import tables
from rf_modules import *

# %% [markdown]
# # Delete the old temporary files (if they exist)

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 files
src_fldr_pth = r'C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices'
try:
    os.remove(src_fldr_pth + r'\all_hist_prices_d_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_d_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.remove(src_fldr_pth + r'all_hist_prices_w_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_w_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
# Out:
# ERROR - REMOVING:[WinError 2] The system cannot find the file specified: 'C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d_TMP.h5'
#
# ERROR - REMOVING:[WinError 2] The system cannot find the file specified: 'C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_pricesall_hist_prices_w_TMP.h5'

# %% [markdown]
# # Scraping tickers
# This section will scrap the ticker values for the FTSE 100 and FTSE 250 and store them in dataframes 'tick_ftse100' and 'tick_ftse250'.
#
# Finally concatenate into 1 dataframe 'tick_ftse'.

# %%
#Fetch the data for ftse 100
web_add = r'https://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/summary/summary-indices-constituents.html?index=UKX&page=1'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Find how many pages there are to collect
par_elem = parser.find_all('div',id='pi-colonna1-display')[0]
num_pages = int(re.sub('[^0-9]','',par_elem.find_all('p')[0].text[-3:]))

#Collect the rows of data
row_li = []
for page in range(1,num_pages+1):
    web_add = r'https://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/summary/summary-indices-constituents.html?index=UKX&page={}'.format(page)
    resp = rq.get(web_add)
    parser = bs(resp.content,'html.parser')
    #Find how many pages there are to collect
    par_elem = parser.find_all('div',id='pi-colonna1-display')[0]
    #Collect the table
    table = par_elem.find_all('table')[0]
    #Collect the rows of data
    for row in table.tbody.find_all('tr'):
        temp_row = []
        for cell in row.find_all('td')[:2]:
            temp_row.append(re.sub('\n','',cell.text.upper()))
        row_li.append(temp_row)
print('count -> {}'.format(len(row_li)))
#Create a dataframe
tick_ftse100 = pd.DataFrame(data=row_li,columns=['ticker','company'])
tick_ftse100['index'] = 'FTSE100'
tick_ftse100.head()
# Out:
# count -> 101
#   ticker         company    index
# 0    III         3I GRP.  FTSE100
# 1    ABF        A.B.FOOD  FTSE100
# 2    ADM     ADMIRAL GRP  FTSE100
# 3    AAL  ANGLO AMERICAN  FTSE100
# 4   ANTO     ANTOFAGASTA  FTSE100

# %%
#Fetch the data for ftse 250
web_add = r'https://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/summary/summary-indices-constituents.html?index=MCX&page=1'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Find how many pages there are to collect
par_elem = parser.find_all('div',id='pi-colonna1-display')[0]
num_pages = int(re.sub('[^0-9]','',par_elem.find_all('p')[0].text[-3:]))

#Collect the rows of data
row_li = []
for page in range(1,num_pages+1):
    web_add = r'https://www.londonstockexchange.com/exchange/prices-and-markets/stocks/indices/summary/summary-indices-constituents.html?index=MCX&page={}'.format(page)
    resp = rq.get(web_add)
    parser = bs(resp.content,'html.parser')
    #Find how many pages there are to collect
    par_elem = parser.find_all('div',id='pi-colonna1-display')[0]
    #Collect the table
    table = par_elem.find_all('table')[0]
    #Collect the rows of data
    for row in table.tbody.find_all('tr'):
        temp_row = []
        for cell in row.find_all('td')[:2]:
            temp_row.append(re.sub('\n','',cell.text.upper()))
        row_li.append(temp_row)
print('count -> {}'.format(len(row_li)))
#Create a dataframe
tick_ftse250 = pd.DataFrame(data=row_li,columns=['ticker','company'])
tick_ftse250['index'] = 'FTSE250'
tick_ftse250.head()
# Out:
# count -> 250
#   ticker          company    index
# 0    3IN      3I INF. ORD  FTSE250
# 1   FOUR    4IMPRINT GRP.  FTSE250
# 2    888        888 HLDGS  FTSE250
# 3    ASL  ABERFTH.SMLL.CO  FTSE250
# 4    AGK          AGGREKO  FTSE250

# %%
#Combine into 1 dataframe
tick_ftse = pd.concat([tick_ftse100,tick_ftse250])
print('shape -> {}'.format(tick_ftse.shape))
print(tick_ftse.ticker.value_counts())
tick_ftse.sort_values(['ticker'])
tick_ftse['ticker'] = [re.sub('(?=[0-9A-Z])*\.(?=[0-9A-Z]+)','-',tick) for tick in tick_ftse['ticker']]
tick_ftse['ticker'] = [re.sub('[^0-9A-Z\-]','',tick) for tick in tick_ftse['ticker']]
# Out:
# shape -> (351, 3)
# IHG     1
# BBOX    1
# AGK     1
# PLI     1
# JFJ     1
#        ..
# JDW     1
# BAB     1
# WTAN    1
# FRES    1
# AVV     1
# Name: ticker, Length: 351, dtype: int64

# %% [markdown]
# # Get the latest price dates
# Get the latest price file.
#
# Loop through the tickers in tick_ftse and for each one get the latest date of scrape.
#
# Convert this date into a timestamp and add to the dataframe.

# %%
#open the price file
hist_prices_df = pd.read_hdf(src_fldr_pth + r'\all_hist_prices_d.h5')
hist_prices_df.head()
# Out:
#   ticker       date    open   close    high    low  change     volume  ema12  \
# 0    III 2008-01-02   995.0  1005.0  1023.0  995.0    10.0   785944.0    NaN
# 1    III 2008-01-03  1005.0   988.0  1020.0  981.0   -17.0  1805560.0    NaN
# 2    III 2008-01-04   985.5   965.0  1000.0  964.0   -20.5  1920061.0    NaN
# 3    III 2008-01-07   967.5   971.5   974.0  953.0     4.0  3167216.0    NaN
# 4    III 2008-01-08   975.0   978.5   989.0  971.5     3.5  2297118.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Convert date
def conv_date(_str_in):
    if type(_str_in) == str:
        return dt.datetime.strptime(_str_in,'%Y-%m-%d')
    else:
        return _str_in
hist_prices_df.date = [conv_date(x) for x in hist_prices_df.date]
hist_prices_df.dtypes
# Out:
# ticker                 object
# date           datetime64[ns]
# open                  float64
# close                 float64
# high                  float64
# low                   float64
# change                float64
# volume                float64
# ema12                 float64
# ema26                 float64
# macd_line             float64
# signal_line           float64
# macd                  float64
# dtype: object

# %% [markdown]
# # Scraping a stock history
# Working backwards through time from now until the last price scrape date collect all the daily data for a stock. Daily is used as it can later be summarised into weekly or monthly if required.
#
# This will then be put into a dataframe containing:
# - ticker
# - Company name
# - date
# - open
# - high
# - low
# - close
# - Adjusted close (for divs and splits)
# - volume

# %%
#Create a list of time intervals to be used with 140 days in each item
def create_sec_ref_li(_st_date:int,_en_date:int):
    #make sure the dates are different
    if _st_date == _en_date:
        return []
    #Establish the day ref of the dates compared to 01/01/1970
    _ep_date = pd.to_datetime(dt.datetime(1970,1,1),errors='coerce')
    _en_date = pd.to_datetime(_en_date,errors='coerce')
    _st_date = pd.to_datetime(_st_date,errors='coerce')
    print('_st_date: ' + str(_st_date))
    print('_en_date: ' + str(_en_date))
    _st_days = (_st_date - _ep_date).days
    _en_days = (_en_date - _ep_date).days
    #Loop adding to a list until reaching 0
    _sec_ref_li = []
    _days = 140
    while _en_days > _st_days:
        if _en_days - _days > _st_days:
            _sec_ref_li.append([(_en_days - _days)*86400,_en_days*86400])
        else:
            _sec_ref_li.append([_st_days*86400,_en_days*86400])        
        _en_days += -_days
    return _sec_ref_li

# %%
def calc_ema(s_in,periods):
    #Calc mod val
    mod = 2/(periods+1)
    #Make a df
    tmp_df = pd.DataFrame(s_in)
    #Calc sma
    tmp_df['sma'] = pd.Series([0] * len(s_in))
    for i in range(0,periods):
        tmp_df['sma'] += tmp_df[s_in.name].shift(i) / periods
    #Calc ema
    tmp_df['ema'] = tmp_df['sma'].copy()
    for row in tmp_df.iterrows():
        i = row[0]
        if i > 0 and not np.isnan(tmp_df['sma'][i-1]):
            tmp_df['ema'][i] = mod*(tmp_df[s_in.name][i] - tmp_df['ema'][i-1]) + tmp_df['ema'][i-1]
    return tmp_df['ema'].copy()

# %%
def calc_macd(ema_lng_s,ema_sht_s,sig_period):
    #Make a df
    tmp_df = pd.DataFrame([])
    tmp_df['ema_lng'] = ema_lng_s
    tmp_df['ema_sht'] = ema_sht_s
    #Calc the signal line
    tmp_df['macd_line'] = tmp_df['ema_sht'] - tmp_df['ema_lng']
    tmp_df['signal_line'] = calc_ema(tmp_df['macd_line'],sig_period)
    tmp_df['macd_hist'] = tmp_df['macd_line'] - tmp_df['signal_line']
    return (tmp_df['macd_line'].copy(),tmp_df['signal_line'].copy(),tmp_df['macd_hist'].copy())

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(hist_prices_df)
# col_lens = {'ticker': 4,
#  'date': 19,
#  'open': 8,
#  'close': 8,
#  'high': 8,
#  'low': 8,
#  'change': 22,
#  'volume': 12,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23}
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'open': 8,
#  'close': 8,
#  'high': 8,
#  'low': 8,
#  'change': 21,
#  'volume': 13,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23}

# %%
#Get the price history for a specific ticker
def get_price_hist_d(_tick:str,_sec_ref_li:list):
    try:
        print('Getting DAILY prices for -> {}'.format(_tick))
        _tick_df = pd.DataFrame([])
        _cols = []
        print('Number of webscrapes to perform -> {}'.format(len(_sec_ref_li)))
        i = 0
        for _secs in _sec_ref_li:
            i += 1
            print('Making call {} -> {} - {}'.format(i,dt.datetime.fromtimestamp(_secs[0]),dt.datetime.fromtimestamp(_secs[1])))
            try:
                _web_add = 'https://finance.yahoo.com/quote/{0}/history?period1={1}&period2={2}&interval={3}&filter=history&frequency={3}'.format(re.sub('\.','-',_tick)+'.L',_secs[0],_secs[1],'1d')
#                 print('_web_add: {}'.format(_web_add))
                
                _resp = rq.get(_web_add)
                if int(_resp.status_code) != 200:
                    print('status code -> {}'.format(_resp.status_code))
                    continue
                _parser = bs(_resp.content,'html.parser')
                #Get the table
                _table = _parser.find_all('table',attrs={'data-test':'historical-prices'})[0]
                #Grab the data rows
                _rows = _table.find_all('tbody')[0].find_all('tr')
                #If there are no dates there's no point going back further
                if len(_rows) == 0:
                    print('No more records to collect')
                    break
                #Put the rows into the dataframe
                for _r in _rows:
                    if len(_tick_df) == 0:
                        _cols = [clean_col_name(x.text) for x in _table.find_all('th')]
                        _tick_df = pd.DataFrame([],columns=_cols)
                    if len(_r.find_all('td')) == len(_cols):
                        _tick_df = _tick_df.append(pd.Series([x.text for x in _r.find_all('td')],index=_cols),ignore_index=True)
                    else:
                        continue
            except Exception as e:
                print('ERROR - CONTINUE -> {}'.format(e))
                continue
        #Check for rows - if none then return
        if len(_tick_df) == 0:
            return _tick_df
        #Reformat
        def float_format(_str_in):
            if type(_str_in) == str:
                _str_in = _str_in.strip()
                _str_in = re.sub('[^0-9.]','',_str_in)
                if _str_in == '':
                    _str_in = 0
                return _str_in
            else:
                return _str_in
        _tick_df.loc[:,'open'] = _tick_df.loc[:,'open'].apply(float_format).astype(float)
        _tick_df.loc[:,'high'] = _tick_df.loc[:,'high'].apply(float_format).astype(float)
        _tick_df.loc[:,'low'] = _tick_df.loc[:,'low'].apply(float_format).astype(float)
        _tick_df.loc[:,'close'] = _tick_df.loc[:,'close'].apply(float_format).astype(float)
        _tick_df.loc[:,'adj_close'] = _tick_df.loc[:,'adj_close'].apply(float_format).astype(float)
        _tick_df.loc[:,'volume'] = _tick_df.loc[:,'volume'].apply(float_format).astype(float)
        _tick_df.loc[:,'change'] = _tick_df.loc[:,'close'] - _tick_df.loc[:,'open']
        def conv_date(_str_in):
            if type(_str_in) == str:
                return dt.datetime.strptime(_str_in,'%b %d, %Y')
            else:
                return _str_in
        _tick_df.loc[:,'date'] = _tick_df.loc[:,'date'].apply(conv_date)
        #Add the ticker series
        _tick_df.loc[:,'ticker'] = _tick    
        _tick_df = _tick_df.loc[:,['ticker','date','open','close','high','low','change','volume']]
        #CLEANING - Remove any rows with zero volume
        _tick_df = _tick_df[_tick_df['volume'] > 0]
        #CLEANING - Copy row above where the change has been more than 90%
        _tick_df['cl_change'] = (_tick_df['close'] - _tick_df['close'].shift(1))/_tick_df['close'].shift(1)
        _check_s = _tick_df['cl_change'] < -0.9
        _tick_df.loc[_check_s,'open'] = _tick_df['open'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'close'] = _tick_df['close'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'high'] = _tick_df['high'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'low'] = _tick_df['low'].shift(-1).copy().loc[_check_s]
        _tick_df.drop(columns='cl_change',inplace=True)
        return _tick_df
    except Exception as e:
        print('ERROR -> {}'.format(e))
        return False

#Calc the ema and macds for the data
def calc_ema_macd(_tick_df):
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal_line'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        #Sort clean and export
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        return _tick_df
    except Exception as e:
        print('ERROR -> {}'.format(e))
        return False

# %%
#Create a weekly table
def get_price_hist_w(_df_d):
    print('Converting daily prices to weekly prices')
    try:
        #Create a copy of the data
        _df_d = _df_d.copy()
        #Establish a week number for each date
        _df_d['isocalendar'] = [x.isocalendar()[:2] for x in _df_d['date']]
        #Get highs and lows
        _high_df = _df_d.loc[_df_d['high'] > 0,['high','isocalendar']].groupby('isocalendar').max().reset_index()
        _low_df = _df_d.loc[_df_d['low'] > 0,['low','isocalendar']].groupby('isocalendar').min().reset_index()
        #Get total volume for the week
        _vol_df = _df_d.loc[_df_d['volume'] > 0,['volume','isocalendar']].groupby('isocalendar').sum().reset_index()
        #Get open price
        _min_wk_day = _df_d.loc[_df_d['open'] > 0,['date','isocalendar']].groupby('isocalendar').min().reset_index()
        _open_df = pd.merge(_df_d[['date','open']],_min_wk_day,left_on='date',right_on='date')
        #Get close price
        _max_wk_day = _df_d.loc[_df_d['close'] > 0,['date','isocalendar']].groupby('isocalendar').max().reset_index()
        _close_df = pd.merge(_df_d[['date','close']],_max_wk_day,left_on='date',right_on='date').reset_index()
        #Form the final df
        _wk_df = pd.merge(_df_d[['ticker','isocalendar']],_min_wk_day,left_on='isocalendar',right_on='isocalendar') #date
        _wk_df = pd.merge(_wk_df,_high_df,left_on='isocalendar',right_on='isocalendar') #high
        _wk_df = pd.merge(_wk_df,_low_df,left_on='isocalendar',right_on='isocalendar') #low
        _wk_df = pd.merge(_wk_df,_vol_df,left_on='isocalendar',right_on='isocalendar') #volume
        _wk_df = pd.merge(_wk_df,_open_df[['isocalendar','open']],left_on='isocalendar',right_on='isocalendar') #open
        _wk_df = pd.merge(_wk_df,_close_df[['isocalendar','close']],left_on='isocalendar',right_on='isocalendar') #close
        _wk_df['change'] = _wk_df['close'] - _wk_df['open']
        _wk_df = _wk_df.drop_duplicates().reset_index(drop=True)
        #Get the monday of each week
        _wk_df['weekday'] = [dt.date.weekday(x) for x in _wk_df['date']]
        _wk_df['date'] = _wk_df['date'] - pd.Series([dt.timedelta(days=x) for x in _wk_df['weekday']])
        _wk_df.drop(columns=['isocalendar','weekday'],inplace=True)
        return _wk_df
    except Exception as e:
        print('ERROR -> {}'.format(e))
        return False

# %%
#Setup stores
hf_store_name_d = src_fldr_pth + r'\all_hist_prices_d_TMP.h5'#open the price file
hf_d = pd.HDFStore(hf_store_name_d)
group_name_d = r'daily_data'
hf_store_name_w = src_fldr_pth + r'\all_hist_prices_w_TMP.h5'
hf_w = pd.HDFStore(hf_store_name_w)
group_name_w = r'weekly_data'

# %%
#close any open h5 files
tables.file._open_files.close_all()
# Out:
# Closing remaining open files:C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_d_TMP.h5...doneC:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_TMP.h5...done

# %%
#Scrape daily price data
out_cols = ['ticker','date','open','close','high','low','change','volume']
errors = []
run_time = process_time()
for tick in tick_ftse['ticker']:
    try:
        print('\n{} RUNNING FOR -> {}'.format(len(run_time.lap_li),tick))
        
        #Get the existing prices
        tick_df = hist_prices_df[hist_prices_df.ticker == tick][out_cols]
        print('DAILY SHAPE BEFORE -> {}'.format(tick_df.shape))
        
        #DAILY PRICES
        #Establish the date to start scrapping on
        st_date = tick_df.date.max()
        if pd.isnull(st_date):
            #Treat as a new share
            st_date = dt.datetime(1970,1,1)
            
        #Establish the end date for scrapping
        en_date = dt.date.today()+dt.timedelta(days=1)
        en_date = dt.datetime(en_date.year,en_date.month,en_date.day,0,0,0)
        #Match to friday if sat or sunday
        if en_date.weekday() in (5,6):
            en_date = en_date-dt.timedelta(days=(en_date.weekday()-4))
        
        #Get new price data if neccesary
        if st_date < en_date:
            new_tick_df = get_price_hist_d(tick,create_sec_ref_li(st_date,en_date))
            #Join onto existing data if exists, if not create a new df for it
            if tick_df.shape[0] > 0:
                tick_df = tick_df.append(new_tick_df)
            else:
                tick_df = new_tick_df
            #Drop duplicates
            tick_df = tick_df.drop_duplicates()
        else:
            print('No new records to collect')

        #Calc emas and macd
        tick_df = calc_ema_macd(tick_df)
        print('DAILY FINAL SHAPE -> {}'.format(tick_df.shape))
        
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in tick_df:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
                
        #Add to daily h5 file
        tick_df.to_hdf(hf_store_name_d,key=group_name_d,append=True,min_itemsize=col_lens_tmp)
        
        #WEEKLY PRICES
        #Convert to weekly prices
        df_w = get_price_hist_w(tick_df)
        
        #Drop duplicates
        df_w = df_w.drop_duplicates()

        #Calc emas and macd
        df_w = calc_ema_macd(df_w)
        print('WEEKLY FINAL SHAPE -> {}'.format(df_w.shape))

        #Add to weekly h5 file
        df_w.to_hdf(hf_store_name_w,key=group_name_w,append=True,min_itemsize=col_lens)
        
        #Lap
        run_time.lap()
        run_time.show_latest_lap_time(show_time=True)
    except Exception as e:
        print('ERROR -> {}'.format(e))
        errors.append(e)
hf_d.close()
hf_w.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT -> {}'.format(len(errors)))
if len(errors) > 0:
    print('ERRORS -> {}'.format(errors))
# Out:
# 0 RUNNING FOR -> III
# DAILY SHAPE BEFORE -> (2968, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> III
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2972, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (620, 13)
# LAP 1 TIMES ->
# 	START: 2019-11-22 19:45:56
# 	  END: 2019-11-22 19:46:02
# LAP 1 TIME -> 0:0:6
#
# 1 RUNNING FOR -> ABF
# DAILY SHAPE BEFORE -> (5048, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ABF
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5053, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 2 TIMES ->
# 	START: 2019-11-22 19:46:02
# 	  END: 2019-11-22 19:46:10
# LAP 2 TIME -> 0:0:7
#
# 2 RUNNING FOR -> ADM
# DAILY SHAPE BEFORE -> (1702, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ADM
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1707, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (360, 13)
# LAP 3 TIMES ->
# 	START: 2019-11-22 19:46:10
# 	  END: 2019-11-22 19:46:14
# LAP 3 TIME -> 0:0:3
#
# 3 RUNNING FOR -> AAL
# DAILY SHAPE BEFORE -> (4319, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AAL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4324, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1015, 13)
# LAP 4 TIMES ->
# 	START: 2019-11-22 19:46:14
# 	  END: 2019-11-22 19:46:24
# LAP 4 TIME -> 0:0:10
#
# 4 RUNNING FOR -> ANTO
# DAILY SHAPE BEFORE -> (5074, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ANTO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5079, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 5 TIMES ->
# 	START: 2019-11-22 19:46:24
# 	  END: 2019-11-22 19:46:35
# LAP 5 TIME -> 0:0:10
#
# 5 RUNNING FOR -> AHT
# DAILY SHAPE BEFORE -> (4644, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AHT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4649, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1030, 13)
# LAP 6 TIMES ->
# 	START: 2019-11-22 19:46:35
# 	  END: 2019-11-22 19:46:44
# LAP 6 TIME -> 0:0:9
#
# 6 RUNNING FOR -> AZN
# DAILY SHAPE BEFORE -> (5033, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AZN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5038, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 7 TIMES ->
# 	START: 2019-11-22 19:46:44
# 	  END: 2019-11-22 19:46:54
# LAP 7 TIME -> 0:0:9
#
# 7 RUNNING FOR -> AUTO
# DAILY SHAPE BEFORE -> (1180, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AUTO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1185, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (245, 13)
# LAP 8 TIMES ->
# 	START: 2019-11-22 19:46:54
# 	  END: 2019-11-22 19:47:01
# LAP 8 TIME -> 0:0:6
#
# 8 RUNNING FOR -> AVV
# DAILY SHAPE BEFORE -> (5001, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AVV
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5006, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 9 TIMES ->
# 	START: 2019-11-22 19:47:01
# 	  END: 2019-11-22 19:47:11
# LAP 9 TIME -> 0:0:10
#
# 9 RUNNING FOR -> AV
# DAILY SHAPE BEFORE -> (8600, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AV
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (8605, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (2785, 13)
# LAP 10 TIMES ->
# 	START: 2019-11-22 19:47:11
# 	  END: 2019-11-22 19:47:25
# LAP 10 TIME -> 0:0:13
#
# 10 RUNNING FOR -> BA
# DAILY SHAPE BEFORE -> (7420, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7425, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1543, 13)
# LAP 11 TIMES ->
# 	START: 2019-11-22 19:47:25
# 	  END: 2019-11-22 19:47:35
# LAP 11 TIME -> 0:0:10
#
# 11 RUNNING FOR -> BARC
# DAILY SHAPE BEFORE -> (5012, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BARC
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5017, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 12 TIMES ->
# 	START: 2019-11-22 19:47:35
# 	  END: 2019-11-22 19:47:44
# LAP 12 TIME -> 0:0:9
#
# 12 RUNNING FOR -> BDEV
# DAILY SHAPE BEFORE -> (5071, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BDEV
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5076, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 13 TIMES ->
# 	START: 2019-11-22 19:47:44
# 	  END: 2019-11-22 19:47:53
# LAP 13 TIME -> 0:0:8
#
# 13 RUNNING FOR -> BKG
# DAILY SHAPE BEFORE -> (5063, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BKG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 14 TIMES ->
# 	START: 2019-11-22 19:47:53
# 	  END: 2019-11-22 19:48:01
# LAP 14 TIME -> 0:0:8
#
# 14 RUNNING FOR -> BHP
# DAILY SHAPE BEFORE -> (2492, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BHP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2497, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (531, 13)
# LAP 15 TIMES ->
# 	START: 2019-11-22 19:48:01
# 	  END: 2019-11-22 19:48:08
# LAP 15 TIME -> 0:0:6
#
# 15 RUNNING FOR -> BP
# DAILY SHAPE BEFORE -> (7483, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7488, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1572, 13)
# LAP 16 TIMES ->
# 	START: 2019-11-22 19:48:08
# 	  END: 2019-11-22 19:48:18
# LAP 16 TIME -> 0:0:10
#
# 16 RUNNING FOR -> BATS
# DAILY SHAPE BEFORE -> (5040, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BATS
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 17 TIMES ->
# 	START: 2019-11-22 19:48:18
# 	  END: 2019-11-22 19:48:28
# LAP 17 TIME -> 0:0:9
#
# 17 RUNNING FOR -> BLND
# DAILY SHAPE BEFORE -> (5072, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BLND
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5077, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 18 TIMES ->
# 	START: 2019-11-22 19:48:28
# 	  END: 2019-11-22 19:48:36
# LAP 18 TIME -> 0:0:7
#
# 18 RUNNING FOR -> BT-A
# DAILY SHAPE BEFORE -> (7428, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BT-A
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7433, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1543, 13)
# LAP 19 TIMES ->
# 	START: 2019-11-22 19:48:36
# 	  END: 2019-11-22 19:48:48
# LAP 19 TIME -> 0:0:12
#
# 19 RUNNING FOR -> BNZL
# DAILY SHAPE BEFORE -> (4992, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BNZL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4997, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1049, 13)
# LAP 20 TIMES ->
# 	START: 2019-11-22 19:48:48
# 	  END: 2019-11-22 19:48:57
# LAP 20 TIME -> 0:0:8
#
# 20 RUNNING FOR -> BRBY
# DAILY SHAPE BEFORE -> (4380, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BRBY
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4385, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (907, 13)
# LAP 21 TIMES ->
# 	START: 2019-11-22 19:48:57
# 	  END: 2019-11-22 19:49:05
# LAP 21 TIME -> 0:0:8
#
# 21 RUNNING FOR -> CCL
# DAILY SHAPE BEFORE -> (4794, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CCL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4799, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (996, 13)
# LAP 22 TIMES ->
# 	START: 2019-11-22 19:49:05
# 	  END: 2019-11-22 19:49:14
# LAP 22 TIME -> 0:0:8
#
# 22 RUNNING FOR -> CNA
# DAILY SHAPE BEFORE -> (5070, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CNA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5075, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 23 TIMES ->
# 	START: 2019-11-22 19:49:14
# 	  END: 2019-11-22 19:49:22
# LAP 23 TIME -> 0:0:8
#
# 23 RUNNING FOR -> CCH
# DAILY SHAPE BEFORE -> (1659, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CCH
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1664, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (343, 13)
# LAP 24 TIMES ->
# 	START: 2019-11-22 19:49:22
# 	  END: 2019-11-22 19:49:26
# LAP 24 TIME -> 0:0:4
#
# 24 RUNNING FOR -> CPG
# DAILY SHAPE BEFORE -> (5009, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CPG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5014, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1038, 13)
# LAP 25 TIMES ->
# 	START: 2019-11-22 19:49:26
# 	  END: 2019-11-22 19:49:34
# LAP 25 TIME -> 0:0:7
#
# 25 RUNNING FOR -> CRH
# DAILY SHAPE BEFORE -> (5010, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CRH
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5015, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1038, 13)
# LAP 26 TIMES ->
# 	START: 2019-11-22 19:49:34
# 	  END: 2019-11-22 19:49:43
# LAP 26 TIME -> 0:0:8
#
# 26 RUNNING FOR -> CRDA
# DAILY SHAPE BEFORE -> (5031, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> CRDA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5036, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1044, 13)
# LAP 27 TIMES ->
# 	START: 2019-11-22 19:49:43
# 	  END: 2019-11-22 19:49:51
# LAP 27 TIME -> 0:0:8
#
# 27 RUNNING FOR -> DCC
# DAILY SHAPE BEFORE -> (4780, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> DCC
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4785, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1034, 13)
# LAP 28 TIMES ->
# 	START: 2019-11-22 19:49:51
# 	  END: 2019-11-22 19:50:00
# LAP 28 TIME -> 0:0:8
#
# 28 RUNNING FOR -> DGE
# DAILY SHAPE BEFORE -> (5066, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> DGE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5071, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 29 TIMES ->
# 	START: 2019-11-22 19:50:00
# 	  END: 2019-11-22 19:50:10
# LAP 29 TIME -> 0:0:9
#
# 29 RUNNING FOR -> EVR
# DAILY SHAPE BEFORE -> (2029, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> EVR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2034, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (421, 13)
# LAP 30 TIMES ->
# 	START: 2019-11-22 19:50:10
# 	  END: 2019-11-22 19:50:17
# LAP 30 TIME -> 0:0:7
#
# 30 RUNNING FOR -> EXPN
# DAILY SHAPE BEFORE -> (3314, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> EXPN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3319, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (685, 13)
# LAP 31 TIMES ->
# 	START: 2019-11-22 19:50:17
# 	  END: 2019-11-22 19:50:27
# LAP 31 TIME -> 0:0:9
#
# 31 RUNNING FOR -> FERG
# DAILY SHAPE BEFORE -> (5074, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> FERG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5079, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1053, 13)
# LAP 32 TIMES ->
# 	START: 2019-11-22 19:50:27
# 	  END: 2019-11-22 19:50:36
# LAP 32 TIME -> 0:0:9
#
# 32 RUNNING FOR -> FLTR
# DAILY SHAPE BEFORE -> (120, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> FLTR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (125, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (25, 13)
# LAP 33 TIMES ->
# 	START: 2019-11-22 19:50:36
# 	  END: 2019-11-22 19:50:41
# LAP 33 TIME -> 0:0:4
#
# 33 RUNNING FOR -> FRES
# DAILY SHAPE BEFORE -> (2911, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> FRES
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2916, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (603, 13)
# LAP 34 TIMES ->
# 	START: 2019-11-22 19:50:41
# 	  END: 2019-11-22 19:50:48
# LAP 34 TIME -> 0:0:6
#
# 34 RUNNING FOR -> GSK
# DAILY SHAPE BEFORE -> (5026, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> GSK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5031, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 35 TIMES ->
# 	START: 2019-11-22 19:50:48
# 	  END: 2019-11-22 19:50:57
# LAP 35 TIME -> 0:0:9
#
# 35 RUNNING FOR -> GLEN
# DAILY SHAPE BEFORE -> (2150, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> GLEN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2155, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (445, 13)
# LAP 36 TIMES ->
# 	START: 2019-11-22 19:50:57
# 	  END: 2019-11-22 19:51:03
# LAP 36 TIME -> 0:0:5
#
# 36 RUNNING FOR -> HLMA
# DAILY SHAPE BEFORE -> (4484, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> HLMA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4489, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1020, 13)
# LAP 37 TIMES ->
# 	START: 2019-11-22 19:51:03
# 	  END: 2019-11-22 19:51:10
# LAP 37 TIME -> 0:0:7
#
# 37 RUNNING FOR -> HL
# DAILY SHAPE BEFORE -> (3109, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> HL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3114, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (648, 13)
# LAP 38 TIMES ->
# 	START: 2019-11-22 19:51:10
# 	  END: 2019-11-22 19:51:17
# LAP 38 TIME -> 0:0:6
#
# 38 RUNNING FOR -> HIK
# DAILY SHAPE BEFORE -> (3451, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> HIK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3456, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (715, 13)
# LAP 39 TIMES ->
# 	START: 2019-11-22 19:51:17
# 	  END: 2019-11-22 19:51:23
# LAP 39 TIME -> 0:0:6
#
# 39 RUNNING FOR -> HSX
# DAILY SHAPE BEFORE -> (4893, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> HSX
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4898, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1019, 13)
# LAP 40 TIMES ->
# 	START: 2019-11-22 19:51:23
# 	  END: 2019-11-22 19:51:32
# LAP 40 TIME -> 0:0:8
#
# 40 RUNNING FOR -> HSBA
# DAILY SHAPE BEFORE -> (6035, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> HSBA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6040, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 41 TIMES ->
# 	START: 2019-11-22 19:51:32
# 	  END: 2019-11-22 19:51:42
# LAP 41 TIME -> 0:0:9
#
# 41 RUNNING FOR -> IMB
# DAILY SHAPE BEFORE -> (5458, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> IMB
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5463, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1187, 13)
# LAP 42 TIMES ->
# 	START: 2019-11-22 19:51:42
# 	  END: 2019-11-22 19:51:50
# LAP 42 TIME -> 0:0:8
#
# 42 RUNNING FOR -> INF
# DAILY SHAPE BEFORE -> (5177, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> INF
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5182, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1073, 13)
# LAP 43 TIMES ->
# 	START: 2019-11-22 19:51:50
# 	  END: 2019-11-22 19:51:58
# LAP 43 TIME -> 0:0:8
#
# 43 RUNNING FOR -> IHG
# DAILY SHAPE BEFORE -> (4102, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> IHG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4107, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (851, 13)
# LAP 44 TIMES ->
# 	START: 2019-11-22 19:51:58
# 	  END: 2019-11-22 19:52:06
# LAP 44 TIME -> 0:0:7
#
# 44 RUNNING FOR -> ITRK
# DAILY SHAPE BEFORE -> (4132, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ITRK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4137, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (891, 13)
# LAP 45 TIMES ->
# 	START: 2019-11-22 19:52:06
# 	  END: 2019-11-22 19:52:14
# LAP 45 TIME -> 0:0:8
#
# 45 RUNNING FOR -> IAG
# DAILY SHAPE BEFORE -> (4166, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> IAG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4171, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (863, 13)
# LAP 46 TIMES ->
# 	START: 2019-11-22 19:52:14
# 	  END: 2019-11-22 19:52:21
# LAP 46 TIME -> 0:0:7
#
# 46 RUNNING FOR -> ITV
# DAILY SHAPE BEFORE -> (4886, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ITV
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4891, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1019, 13)
# LAP 47 TIMES ->
# 	START: 2019-11-22 19:52:21
# 	  END: 2019-11-22 19:52:28
# LAP 47 TIME -> 0:0:7
#
# 47 RUNNING FOR -> JD
# DAILY SHAPE BEFORE -> (424, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> JD
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (429, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (89, 13)
# LAP 48 TIMES ->
# 	START: 2019-11-22 19:52:28
# 	  END: 2019-11-22 19:52:32
# LAP 48 TIME -> 0:0:3
#
# 48 RUNNING FOR -> JMAT
# DAILY SHAPE BEFORE -> (5977, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> JMAT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5982, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1244, 13)
# LAP 49 TIMES ->
# 	START: 2019-11-22 19:52:32
# 	  END: 2019-11-22 19:52:44
# LAP 49 TIME -> 0:0:11
#
# 49 RUNNING FOR -> KGF
# DAILY SHAPE BEFORE -> (6067, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> KGF
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6072, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 50 TIMES ->
# 	START: 2019-11-22 19:52:44
# 	  END: 2019-11-22 19:52:54
# LAP 50 TIME -> 0:0:10
#
# 50 RUNNING FOR -> LAND
# DAILY SHAPE BEFORE -> (6059, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> LAND
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1271, 13)
# LAP 51 TIMES ->
# 	START: 2019-11-22 19:52:54
# 	  END: 2019-11-22 19:53:06
# LAP 51 TIME -> 0:0:11
#
# 51 RUNNING FOR -> LGEN
# DAILY SHAPE BEFORE -> (6034, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> LGEN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6039, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 52 TIMES ->
# 	START: 2019-11-22 19:53:06
# 	  END: 2019-11-22 19:53:15
# LAP 52 TIME -> 0:0:9
#
# 52 RUNNING FOR -> LLOY
# DAILY SHAPE BEFORE -> (5919, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> LLOY
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5924, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1229, 13)
# LAP 53 TIMES ->
# 	START: 2019-11-22 19:53:15
# 	  END: 2019-11-22 19:53:24
# LAP 53 TIME -> 0:0:9
#
# 53 RUNNING FOR -> LSE
# DAILY SHAPE BEFORE -> (4522, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> LSE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4527, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (939, 13)
# LAP 54 TIMES ->
# 	START: 2019-11-22 19:53:24
# 	  END: 2019-11-22 19:53:34
# LAP 54 TIME -> 0:0:9
#
# 54 RUNNING FOR -> MNG
# DAILY SHAPE BEFORE -> (20, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> MNG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (25, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (5, 13)
# LAP 55 TIMES ->
# 	START: 2019-11-22 19:53:34
# 	  END: 2019-11-22 19:53:37
# LAP 55 TIME -> 0:0:3
#
# 55 RUNNING FOR -> MGGT
# DAILY SHAPE BEFORE -> (6689, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> MGGT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6694, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1482, 13)
# LAP 56 TIMES ->
# 	START: 2019-11-22 19:53:37
# 	  END: 2019-11-22 19:53:53
# LAP 56 TIME -> 0:0:15
#
# 56 RUNNING FOR -> MRO
# DAILY SHAPE BEFORE -> (3804, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> MRO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3809, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (819, 13)
# LAP 57 TIMES ->
# 	START: 2019-11-22 19:53:53
# 	  END: 2019-11-22 19:54:03
# LAP 57 TIME -> 0:0:10
#
# 57 RUNNING FOR -> MNDI
# DAILY SHAPE BEFORE -> (2982, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> MNDI
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2987, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (621, 13)
# LAP 58 TIMES ->
# 	START: 2019-11-22 19:54:03
# 	  END: 2019-11-22 19:54:11
# LAP 58 TIME -> 0:0:8
#
# 58 RUNNING FOR -> MRW
# DAILY SHAPE BEFORE -> (6063, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> MRW
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 59 TIMES ->
# 	START: 2019-11-22 19:54:11
# 	  END: 2019-11-22 19:54:22
# LAP 59 TIME -> 0:0:10
#
# 59 RUNNING FOR -> NG
# DAILY SHAPE BEFORE -> (6018, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> NG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6023, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1250, 13)
# LAP 60 TIMES ->
# 	START: 2019-11-22 19:54:22
# 	  END: 2019-11-22 19:54:32
# LAP 60 TIME -> 0:0:9
#
# 60 RUNNING FOR -> NXT
# DAILY SHAPE BEFORE -> (7314, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> NXT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7319, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1530, 13)
# LAP 61 TIMES ->
# 	START: 2019-11-22 19:54:32
# 	  END: 2019-11-22 19:54:45
# LAP 61 TIME -> 0:0:13
#
# 61 RUNNING FOR -> NMC
# DAILY SHAPE BEFORE -> (1831, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> NMC
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1836, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (380, 13)
# LAP 62 TIMES ->
# 	START: 2019-11-22 19:54:45
# 	  END: 2019-11-22 19:54:50
# LAP 62 TIME -> 0:0:4
#
# 62 RUNNING FOR -> OCDO
# DAILY SHAPE BEFORE -> (2262, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> OCDO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2267, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (469, 13)
# LAP 63 TIMES ->
# 	START: 2019-11-22 19:54:50
# 	  END: 2019-11-22 19:54:58
# LAP 63 TIME -> 0:0:8
#
# 63 RUNNING FOR -> PSON
# DAILY SHAPE BEFORE -> (6164, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> PSON
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6169, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1280, 13)
# LAP 64 TIMES ->
# 	START: 2019-11-22 19:54:58
# 	  END: 2019-11-22 19:55:12
# LAP 64 TIME -> 0:0:14
#
# 64 RUNNING FOR -> PSN
# DAILY SHAPE BEFORE -> (7032, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> PSN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7037, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1470, 13)
# LAP 65 TIMES ->
# 	START: 2019-11-22 19:55:12
# 	  END: 2019-11-22 19:55:26
# LAP 65 TIME -> 0:0:13
#
# 65 RUNNING FOR -> PHNX
# DAILY SHAPE BEFORE -> (2368, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> PHNX
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2373, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (502, 13)
# LAP 66 TIMES ->
# 	START: 2019-11-22 19:55:26
# 	  END: 2019-11-22 19:56:04
# LAP 66 TIME -> 0:0:37
#
# 66 RUNNING FOR -> POLY
# DAILY SHAPE BEFORE -> (1939, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> POLY
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1944, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (403, 13)
# LAP 67 TIMES ->
# 	START: 2019-11-22 19:56:04
# 	  END: 2019-11-22 19:56:09
# LAP 67 TIME -> 0:0:5
#
# 67 RUNNING FOR -> PRU
# DAILY SHAPE BEFORE -> (7216, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> PRU
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7221, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1509, 13)
# LAP 68 TIMES ->
# 	START: 2019-11-22 19:56:09
# 	  END: 2019-11-22 19:56:26
# LAP 68 TIME -> 0:0:17
#
# 68 RUNNING FOR -> RDSA
# DAILY SHAPE BEFORE -> (1243, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RDSA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1248, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (264, 13)
# LAP 69 TIMES ->
# 	START: 2019-11-22 19:56:26
# 	  END: 2019-11-22 19:56:30
# LAP 69 TIME -> 0:0:4
#
# 69 RUNNING FOR -> RDSB
# DAILY SHAPE BEFORE -> (4814, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RDSB
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4819, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1000, 13)
# LAP 70 TIMES ->
# 	START: 2019-11-22 19:56:30
# 	  END: 2019-11-22 19:56:39
# LAP 70 TIME -> 0:0:9
#
# 70 RUNNING FOR -> RB
# DAILY SHAPE BEFORE -> (6197, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RB
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6202, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1290, 13)
# LAP 71 TIMES ->
# 	START: 2019-11-22 19:56:39
# 	  END: 2019-11-22 19:56:54
# LAP 71 TIME -> 0:0:14
#
# 71 RUNNING FOR -> REL
# DAILY SHAPE BEFORE -> (6164, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> REL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6169, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1280, 13)
# LAP 72 TIMES ->
# 	START: 2019-11-22 19:56:54
# 	  END: 2019-11-22 19:57:04
# LAP 72 TIME -> 0:0:10
#
# 72 RUNNING FOR -> RTO
# DAILY SHAPE BEFORE -> (5975, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RTO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5980, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1248, 13)
# LAP 73 TIMES ->
# 	START: 2019-11-22 19:57:04
# 	  END: 2019-11-22 19:57:15
# LAP 73 TIME -> 0:0:10
#
# 73 RUNNING FOR -> RMV
# DAILY SHAPE BEFORE -> (3361, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RMV
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3366, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (697, 13)
# LAP 74 TIMES ->
# 	START: 2019-11-22 19:57:15
# 	  END: 2019-11-22 19:57:22
# LAP 74 TIME -> 0:0:6
#
# 74 RUNNING FOR -> RIO
# DAILY SHAPE BEFORE -> (7336, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RIO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7341, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1533, 13)
# LAP 75 TIMES ->
# 	START: 2019-11-22 19:57:22
# 	  END: 2019-11-22 19:57:32
# LAP 75 TIME -> 0:0:10
#
# 75 RUNNING FOR -> RR
# DAILY SHAPE BEFORE -> (7528, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7533, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1560, 13)
# LAP 76 TIMES ->
# 	START: 2019-11-22 19:57:32
# 	  END: 2019-11-22 19:57:43
# LAP 76 TIME -> 0:0:11
#
# 76 RUNNING FOR -> RBS
# DAILY SHAPE BEFORE -> (6070, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RBS
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6075, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 77 TIMES ->
# 	START: 2019-11-22 19:57:43
# 	  END: 2019-11-22 19:57:53
# LAP 77 TIME -> 0:0:9
#
# 77 RUNNING FOR -> RSA
# DAILY SHAPE BEFORE -> (6008, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> RSA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6013, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1250, 13)
# LAP 78 TIMES ->
# 	START: 2019-11-22 19:57:53
# 	  END: 2019-11-22 19:58:02
# LAP 78 TIME -> 0:0:8
#
# 78 RUNNING FOR -> SGE
# DAILY SHAPE BEFORE -> (5963, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SGE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5968, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1258, 13)
# LAP 79 TIMES ->
# 	START: 2019-11-22 19:58:02
# 	  END: 2019-11-22 19:58:11
# LAP 79 TIME -> 0:0:9
#
# 79 RUNNING FOR -> SBRY
# DAILY SHAPE BEFORE -> (6067, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SBRY
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6072, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 80 TIMES ->
# 	START: 2019-11-22 19:58:11
# 	  END: 2019-11-22 19:58:21
# LAP 80 TIME -> 0:0:9
#
# 80 RUNNING FOR -> SDR
# DAILY SHAPE BEFORE -> (5994, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SDR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5999, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1253, 13)
# LAP 81 TIMES ->
# 	START: 2019-11-22 19:58:21
# 	  END: 2019-11-22 19:58:30
# LAP 81 TIME -> 0:0:9
#
# 81 RUNNING FOR -> SMT
# DAILY SHAPE BEFORE -> (642, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SMT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (644, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (143, 13)
# LAP 82 TIMES ->
# 	START: 2019-11-22 19:58:30
# 	  END: 2019-11-22 19:58:34
# LAP 82 TIME -> 0:0:3
#
# 82 RUNNING FOR -> SGRO
# DAILY SHAPE BEFORE -> (7408, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SGRO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7413, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1541, 13)
# LAP 83 TIMES ->
# 	START: 2019-11-22 19:58:34
# 	  END: 2019-11-22 19:58:47
# LAP 83 TIME -> 0:0:12
#
# 83 RUNNING FOR -> SVT
# DAILY SHAPE BEFORE -> (5984, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SVT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5989, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1248, 13)
# LAP 84 TIMES ->
# 	START: 2019-11-22 19:58:47
# 	  END: 2019-11-22 19:58:57
# LAP 84 TIME -> 0:0:10
#
# 84 RUNNING FOR -> SN
# DAILY SHAPE BEFORE -> (7668, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7673, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1594, 13)
# LAP 85 TIMES ->
# 	START: 2019-11-22 19:58:57
# 	  END: 2019-11-22 19:59:07
# LAP 85 TIME -> 0:0:10
#
# 85 RUNNING FOR -> SMDS
# DAILY SHAPE BEFORE -> (6855, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SMDS
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6860, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1431, 13)
# LAP 86 TIMES ->
# 	START: 2019-11-22 19:59:07
# 	  END: 2019-11-22 19:59:17
# LAP 86 TIME -> 0:0:9
#
# 86 RUNNING FOR -> SMIN
# DAILY SHAPE BEFORE -> (6746, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SMIN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6751, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1493, 13)
# LAP 87 TIMES ->
# 	START: 2019-11-22 19:59:17
# 	  END: 2019-11-22 19:59:26
# LAP 87 TIME -> 0:0:9
#
# 87 RUNNING FOR -> SKG
# DAILY SHAPE BEFORE -> (3108, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SKG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3113, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (644, 13)
# LAP 88 TIMES ->
# 	START: 2019-11-22 19:59:26
# 	  END: 2019-11-22 19:59:32
# LAP 88 TIME -> 0:0:6
#
# 88 RUNNING FOR -> SPX
# DAILY SHAPE BEFORE -> (6857, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SPX
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6862, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1461, 13)
# LAP 89 TIMES ->
# 	START: 2019-11-22 19:59:32
# 	  END: 2019-11-22 19:59:42
# LAP 89 TIME -> 0:0:10
#
# 89 RUNNING FOR -> SSE
# DAILY SHAPE BEFORE -> (6129, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SSE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6134, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1280, 13)
# LAP 90 TIMES ->
# 	START: 2019-11-22 19:59:42
# 	  END: 2019-11-22 19:59:52
# LAP 90 TIME -> 0:0:9
#
# 90 RUNNING FOR -> STJ
# DAILY SHAPE BEFORE -> (6974, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> STJ
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6979, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1470, 13)
# LAP 91 TIMES ->
# 	START: 2019-11-22 19:59:52
# 	  END: 2019-11-22 20:00:03
# LAP 91 TIME -> 0:0:10
#
# 91 RUNNING FOR -> STAN
# DAILY SHAPE BEFORE -> (7346, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> STAN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7351, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1534, 13)
# LAP 92 TIMES ->
# 	START: 2019-11-22 20:00:03
# 	  END: 2019-11-22 20:00:13
# LAP 92 TIME -> 0:0:10
#
# 92 RUNNING FOR -> SLA
# DAILY SHAPE BEFORE -> (3296, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SLA
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3301, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (679, 13)
# LAP 93 TIMES ->
# 	START: 2019-11-22 20:00:13
# 	  END: 2019-11-22 20:00:20
# LAP 93 TIME -> 0:0:6
#
# 93 RUNNING FOR -> TW
# DAILY SHAPE BEFORE -> (7509, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TW
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (7514, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1560, 13)
# LAP 94 TIMES ->
# 	START: 2019-11-22 20:00:20
# 	  END: 2019-11-22 20:00:31
# LAP 94 TIME -> 0:0:11
#
# 94 RUNNING FOR -> TSCO
# DAILY SHAPE BEFORE -> (6045, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TSCO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6050, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 95 TIMES ->
# 	START: 2019-11-22 20:00:31
# 	  END: 2019-11-22 20:00:40
# LAP 95 TIME -> 0:0:9
#
# 95 RUNNING FOR -> TUI
# DAILY SHAPE BEFORE -> (1242, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TUI
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1247, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (258, 13)
# LAP 96 TIMES ->
# 	START: 2019-11-22 20:00:40
# 	  END: 2019-11-22 20:00:44
# LAP 96 TIME -> 0:0:3
#
# 96 RUNNING FOR -> ULVR
# DAILY SHAPE BEFORE -> (4976, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ULVR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4981, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1033, 13)
# LAP 97 TIMES ->
# 	START: 2019-11-22 20:00:44
# 	  END: 2019-11-22 20:00:52
# LAP 97 TIME -> 0:0:8
#
# 97 RUNNING FOR -> UU
# DAILY SHAPE BEFORE -> (6266, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> UU
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6271, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1299, 13)
# LAP 98 TIMES ->
# 	START: 2019-11-22 20:00:52
# 	  END: 2019-11-22 20:01:02
# LAP 98 TIME -> 0:0:9
#
# 98 RUNNING FOR -> VOD
# DAILY SHAPE BEFORE -> (5075, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VOD
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 99 TIMES ->
# 	START: 2019-11-22 20:01:02
# 	  END: 2019-11-22 20:01:13
# LAP 99 TIME -> 0:0:10
#
# 99 RUNNING FOR -> WTB
# DAILY SHAPE BEFORE -> (5072, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WTB
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5077, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 100 TIMES ->
# 	START: 2019-11-22 20:01:13
# 	  END: 2019-11-22 20:01:23
# LAP 100 TIME -> 0:0:9
#
# 100 RUNNING FOR -> WPP
# DAILY SHAPE BEFORE -> (2918, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WPP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2923, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (689, 13)
# LAP 101 TIMES ->
# 	START: 2019-11-22 20:01:23
# 	  END: 2019-11-22 20:01:32
# LAP 101 TIME -> 0:0:9
#
# 101 RUNNING FOR -> 3IN
# DAILY SHAPE BEFORE -> (2812, 8)
# _st_date: 2019-11-13 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> 3IN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-13 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2815, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (592, 13)
# LAP 102 TIMES ->
# 	START: 2019-11-22 20:01:32
# 	  END: 2019-11-22 20:01:42
# LAP 102 TIME -> 0:0:9
#
# 102 RUNNING FOR -> FOUR
# DAILY SHAPE BEFORE -> (4670, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> FOUR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4675, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1043, 13)
# LAP 103 TIMES ->
# 	START: 2019-11-22 20:01:42
# 	  END: 2019-11-22 20:01:50
# LAP 103 TIME -> 0:0:8
#
# 103 RUNNING FOR -> 888
# DAILY SHAPE BEFORE -> (3564, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> 888
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3569, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (739, 13)
# LAP 104 TIMES ->
# 	START: 2019-11-22 20:01:50
# 	  END: 2019-11-22 20:01:57
# LAP 104 TIME -> 0:0:7
#
# 104 RUNNING FOR -> ASL
# DAILY SHAPE BEFORE -> (2812, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ASL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2813, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (610, 13)
# LAP 105 TIMES ->
# 	START: 2019-11-22 20:01:57
# 	  END: 2019-11-22 20:02:03
# LAP 105 TIME -> 0:0:6
#
# 105 RUNNING FOR -> AGK
# DAILY SHAPE BEFORE -> (5075, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AGK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1052, 13)
# LAP 106 TIMES ->
# 	START: 2019-11-22 20:02:03
# 	  END: 2019-11-22 20:02:12
# LAP 106 TIME -> 0:0:8
#
# 106 RUNNING FOR -> AAF
# DAILY SHAPE BEFORE -> (99, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AAF
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (104, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (21, 13)
# LAP 107 TIMES ->
# 	START: 2019-11-22 20:02:12
# 	  END: 2019-11-22 20:02:16
# LAP 107 TIME -> 0:0:3
#
# 107 RUNNING FOR -> AJB
# DAILY SHAPE BEFORE -> (238, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> AJB
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (243, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (51, 13)
# LAP 108 TIMES ->
# 	START: 2019-11-22 20:02:16
# 	  END: 2019-11-22 20:02:19
# LAP 108 TIME -> 0:0:3
#
# 108 RUNNING FOR -> ATST
# DAILY SHAPE BEFORE -> (2846, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# ...
# Getting DAILY prices for -> SGC
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5534, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1158, 13)
# LAP 316 TIMES ->
# 	START: 2019-11-22 20:24:43
# 	  END: 2019-11-22 20:24:51
# LAP 316 TIME -> 0:0:8
#
# 316 RUNNING FOR -> SYNC
# DAILY SHAPE BEFORE -> (1593, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SYNC
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1594, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (342, 13)
# LAP 317 TIMES ->
# 	START: 2019-11-22 20:24:51
# 	  END: 2019-11-22 20:24:56
# LAP 317 TIME -> 0:0:4
#
# 317 RUNNING FOR -> SYNT
# DAILY SHAPE BEFORE -> (6765, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SYNT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6770, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1460, 13)
# LAP 318 TIMES ->
# 	START: 2019-11-22 20:24:56
# 	  END: 2019-11-22 20:25:05
# LAP 318 TIME -> 0:0:9
#
# 318 RUNNING FOR -> TALK
# DAILY SHAPE BEFORE -> (2342, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TALK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2347, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (486, 13)
# LAP 319 TIMES ->
# 	START: 2019-11-22 20:25:05
# 	  END: 2019-11-22 20:25:10
# LAP 319 TIME -> 0:0:4
#
# 319 RUNNING FOR -> TATE
# DAILY SHAPE BEFORE -> (6062, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TATE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6067, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1267, 13)
# LAP 320 TIMES ->
# 	START: 2019-11-22 20:25:10
# 	  END: 2019-11-22 20:25:19
# LAP 320 TIME -> 0:0:9
#
# 320 RUNNING FOR -> TBCG
# DAILY SHAPE BEFORE -> (816, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TBCG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (821, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (172, 13)
# LAP 321 TIMES ->
# 	START: 2019-11-22 20:25:19
# 	  END: 2019-11-22 20:25:23
# LAP 321 TIME -> 0:0:3
#
# 321 RUNNING FOR -> TEP
# DAILY SHAPE BEFORE -> (4769, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TEP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4774, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (990, 13)
# LAP 322 TIMES ->
# 	START: 2019-11-22 20:25:23
# 	  END: 2019-11-22 20:25:31
# LAP 322 TIME -> 0:0:8
#
# 322 RUNNING FOR -> TMPL
# DAILY SHAPE BEFORE -> (2813, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TMPL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2814, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (593, 13)
# LAP 323 TIMES ->
# 	START: 2019-11-22 20:25:31
# 	  END: 2019-11-22 20:25:37
# LAP 323 TIME -> 0:0:5
#
# 323 RUNNING FOR -> TEM
# DAILY SHAPE BEFORE -> (2725, 8)
# _st_date: 2019-11-12 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TEM
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-12 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2728, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (592, 13)
# LAP 324 TIMES ->
# 	START: 2019-11-22 20:25:37
# 	  END: 2019-11-22 20:25:43
# LAP 324 TIME -> 0:0:6
#
# 324 RUNNING FOR -> TIFS
# DAILY SHAPE BEFORE -> (521, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TIFS
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (526, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (109, 13)
# LAP 325 TIMES ->
# 	START: 2019-11-22 20:25:43
# 	  END: 2019-11-22 20:25:45
# LAP 325 TIME -> 0:0:2
#
# 325 RUNNING FOR -> TCAP
# DAILY SHAPE BEFORE -> (4635, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TCAP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4640, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (967, 13)
# LAP 326 TIMES ->
# 	START: 2019-11-22 20:25:45
# 	  END: 2019-11-22 20:25:52
# LAP 326 TIME -> 0:0:6
#
# 326 RUNNING FOR -> TRY
# DAILY SHAPE BEFORE -> (2809, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TRY
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2810, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (591, 13)
# LAP 327 TIMES ->
# 	START: 2019-11-22 20:25:52
# 	  END: 2019-11-22 20:25:57
# LAP 327 TIME -> 0:0:4
#
# 327 RUNNING FOR -> TRN
# DAILY SHAPE BEFORE -> (104, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TRN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (109, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (22, 13)
# LAP 328 TIMES ->
# 	START: 2019-11-22 20:25:57
# 	  END: 2019-11-22 20:25:59
# LAP 328 TIME -> 0:0:1
#
# 328 RUNNING FOR -> TPK
# DAILY SHAPE BEFORE -> (4981, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TPK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4986, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1033, 13)
# LAP 329 TIMES ->
# 	START: 2019-11-22 20:25:59
# 	  END: 2019-11-22 20:26:06
# LAP 329 TIME -> 0:0:7
#
# 329 RUNNING FOR -> BBOX
# DAILY SHAPE BEFORE -> (1315, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> BBOX
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1316, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (283, 13)
# LAP 330 TIMES ->
# 	START: 2019-11-22 20:26:06
# 	  END: 2019-11-22 20:26:09
# LAP 330 TIME -> 0:0:3
#
# 330 RUNNING FOR -> TLW
# DAILY SHAPE BEFORE -> (4872, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> TLW
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4877, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1025, 13)
# LAP 331 TIMES ->
# 	START: 2019-11-22 20:26:09
# 	  END: 2019-11-22 20:26:16
# LAP 331 TIME -> 0:0:7
#
# 331 RUNNING FOR -> UDG
# DAILY SHAPE BEFORE -> (4286, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> UDG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4291, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1014, 13)
# LAP 332 TIMES ->
# 	START: 2019-11-22 20:26:16
# 	  END: 2019-11-22 20:26:23
# LAP 332 TIME -> 0:0:6
#
# 332 RUNNING FOR -> UKCM
# DAILY SHAPE BEFORE -> (2813, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> UKCM
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2814, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (593, 13)
# LAP 333 TIMES ->
# 	START: 2019-11-22 20:26:23
# 	  END: 2019-11-22 20:26:28
# LAP 333 TIME -> 0:0:5
#
# 333 RUNNING FOR -> ULE
# DAILY SHAPE BEFORE -> (4848, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> ULE
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4853, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1029, 13)
# LAP 334 TIMES ->
# 	START: 2019-11-22 20:26:28
# 	  END: 2019-11-22 20:26:35
# LAP 334 TIME -> 0:0:7
#
# 334 RUNNING FOR -> UTG
# DAILY SHAPE BEFORE -> (1682, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> UTG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1687, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (349, 13)
# LAP 335 TIMES ->
# 	START: 2019-11-22 20:26:35
# 	  END: 2019-11-22 20:26:39
# LAP 335 TIME -> 0:0:3
#
# 335 RUNNING FOR -> VSVS
# DAILY SHAPE BEFORE -> (6074, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VSVS
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6079, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1263, 13)
# LAP 336 TIMES ->
# 	START: 2019-11-22 20:26:39
# 	  END: 2019-11-22 20:26:47
# LAP 336 TIME -> 0:0:8
#
# 336 RUNNING FOR -> VCT
# DAILY SHAPE BEFORE -> (5261, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VCT
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (5266, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1192, 13)
# LAP 337 TIMES ->
# 	START: 2019-11-22 20:26:47
# 	  END: 2019-11-22 20:26:55
# LAP 337 TIME -> 0:0:7
#
# 337 RUNNING FOR -> VEIL
# DAILY SHAPE BEFORE -> (759, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VEIL
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (760, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (167, 13)
# LAP 338 TIMES ->
# 	START: 2019-11-22 20:26:55
# 	  END: 2019-11-22 20:26:58
# LAP 338 TIME -> 0:0:2
#
# 338 RUNNING FOR -> VOF
# DAILY SHAPE BEFORE -> (2855, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VOF
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2860, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (602, 13)
# LAP 339 TIMES ->
# 	START: 2019-11-22 20:26:58
# 	  END: 2019-11-22 20:27:04
# LAP 339 TIME -> 0:0:5
#
# 339 RUNNING FOR -> VMUK
# DAILY SHAPE BEFORE -> (4, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VMUK
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (9, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (2, 13)
# LAP 340 TIMES ->
# 	START: 2019-11-22 20:27:04
# 	  END: 2019-11-22 20:27:06
# LAP 340 TIME -> 0:0:2
#
# 340 RUNNING FOR -> VVO
# DAILY SHAPE BEFORE -> (388, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> VVO
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (393, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (82, 13)
# LAP 341 TIMES ->
# 	START: 2019-11-22 20:27:06
# 	  END: 2019-11-22 20:27:09
# LAP 341 TIME -> 0:0:2
#
# 341 RUNNING FOR -> WOSG
# DAILY SHAPE BEFORE -> (118, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WOSG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (123, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (25, 13)
# LAP 342 TIMES ->
# 	START: 2019-11-22 20:27:09
# 	  END: 2019-11-22 20:27:11
# LAP 342 TIME -> 0:0:2
#
# 342 RUNNING FOR -> WEIR
# DAILY SHAPE BEFORE -> (6948, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WEIR
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6953, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1475, 13)
# LAP 343 TIMES ->
# 	START: 2019-11-22 20:27:11
# 	  END: 2019-11-22 20:27:21
# LAP 343 TIME -> 0:0:9
#
# 343 RUNNING FOR -> JDW
# DAILY SHAPE BEFORE -> (6276, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> JDW
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (6281, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (1349, 13)
# LAP 344 TIMES ->
# 	START: 2019-11-22 20:27:21
# 	  END: 2019-11-22 20:27:30
# LAP 344 TIME -> 0:0:9
#
# 344 RUNNING FOR -> SMWH
# DAILY SHAPE BEFORE -> (3251, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> SMWH
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3256, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (675, 13)
# LAP 345 TIMES ->
# 	START: 2019-11-22 20:27:30
# 	  END: 2019-11-22 20:27:36
# LAP 345 TIME -> 0:0:5
#
# 345 RUNNING FOR -> WMH
# DAILY SHAPE BEFORE -> (4286, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WMH
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4291, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (891, 13)
# LAP 346 TIMES ->
# 	START: 2019-11-22 20:27:36
# 	  END: 2019-11-22 20:27:42
# LAP 346 TIME -> 0:0:6
#
# 346 RUNNING FOR -> WTAN
# DAILY SHAPE BEFORE -> (2870, 8)
# _st_date: 2019-11-12 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WTAN
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-12 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2874, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (601, 13)
# LAP 347 TIMES ->
# 	START: 2019-11-22 20:27:42
# 	  END: 2019-11-22 20:27:48
# LAP 347 TIME -> 0:0:5
#
# 347 RUNNING FOR -> WIZZ
# DAILY SHAPE BEFORE -> (1196, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WIZZ
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (1201, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (248, 13)
# LAP 348 TIMES ->
# 	START: 2019-11-22 20:27:48
# 	  END: 2019-11-22 20:27:51
# LAP 348 TIME -> 0:0:3
#
# 348 RUNNING FOR -> WG
# DAILY SHAPE BEFORE -> (4408, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WG
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (4413, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (913, 13)
# LAP 349 TIMES ->
# 	START: 2019-11-22 20:27:51
# 	  END: 2019-11-22 20:27:59
# LAP 349 TIME -> 0:0:7
#
# 349 RUNNING FOR -> WKP
# DAILY SHAPE BEFORE -> (3896, 8)
# _st_date: 2019-11-14 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WKP
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-14 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (3901, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (953, 13)
# LAP 350 TIMES ->
# 	START: 2019-11-22 20:27:59
# 	  END: 2019-11-22 20:28:06
# LAP 350 TIME -> 0:0:7
#
# 350 RUNNING FOR -> WWH
# DAILY SHAPE BEFORE -> (2869, 8)
# _st_date: 2019-11-12 00:00:00
# _en_date: 2019-11-22 00:00:00
# Getting DAILY prices for -> WWH
# Number of webscrapes to perform -> 1
# Making call 1 -> 2019-11-12 00:00:00 - 2019-11-22 00:00:00
# DAILY FINAL SHAPE -> (2873, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE -> (602, 13)
# LAP 351 TIMES ->
# 	START: 2019-11-22 20:28:06
# 	  END: 2019-11-22 20:28:12
# LAP 351 TIME -> 0:0:6
#
#
#
# TOTAL ELAPSED TIME -> 0:42:16
#
# ERROR COUNT -> 0

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'\all_hist_prices_d.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'\all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'\all_hist_prices_d_TMP.h5',src_fldr_pth + r'\all_hist_prices_d.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'\all_hist_prices_d_TMP.h5',src_fldr_pth + r'\all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_d.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_d_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_d.h5

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'\all_hist_prices_w.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'\all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'\all_hist_prices_w_TMP.h5',src_fldr_pth + r'\all_hist_prices_w.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'\all_hist_prices_w_TMP.h5',src_fldr_pth + r'\all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w.h5

# %% [markdown]
# # Exporting the FTSE ticker

# %%
#Export the ftse list
tick_ftse.to_csv(path_or_buf=src_fldr_pth + r"\tick_ftse.csv")

# %%
#End the program
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Robert\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
