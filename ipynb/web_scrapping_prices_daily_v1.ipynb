# %% [markdown]
# # Daily web scrape of stock prices
# This code accesses site to retrieve stock price information daily ad add it to the h5 file. The steps are:
# 1. Get FTSE 100 and FTSE 250 lists from wikipedia, then compile into one list.
# 2. open pipe to h5 file holding current price data.
# 3. Loop though the tickers and for each one;
#     1. find the most recent price date.
#     2. convert this into a time stamp to be used on Yahoo finance.
#     3. go to Yahoo Finance and get all the prices between the last time stamp and the current timestamp.
# 4. Add these new prices to the h5 file.
# 5. Create a new (empty) h5 file and transfer all the data from the old file into the new one.
# 6. Delete the old h5 file and rename the new one.
#
# The sources of data are:
# - https://en.wikipedia.org/wiki/FTSE_100_Index -> list of FTSE 100 company stock tickers
# - https://en.wikipedia.org/wiki/FTSE_250_Index -> list of FTSE 250 company stock tickers
# - https://finance.yahoo.com/quote/{stock-ticker}/history?period1={start-time-mark}&period2={end-time-mark}&interval={interval}&filter=history&frequency={frequency} -> Example web address to retrieve information from Yahoo finance
#     - Data on this page is scroll loaded so many time indexes must be used toretrieve the dcorrect data
#     - Up to 145 records can be seen from initial page load note that this includes dividends so limit to 140 for safety
#
# The inputs required for scrapping are:
#  - {stock-ticker} -> this is the ticker taken from wiki with '.L' appended to it
#  - {start-tme-mark} -> This is the time in seconds since 01/01/1970 at which you would like the data retrieval to start, data retrieved is inclusive of this time
#  - {end-tme-mark} -> This is the time in seconds since 01/01/1970, data retrieved is inclusive of this time
#  - {interval} & {frequency} -> This is the interval for which values are given, the two must match
#      - 1d = 1 every 1 days
#      - 1wk = 1 every week
#      - 1mo = 1 eveery month

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import datetime as dt
import os
import tables

# %%
#Set options for matplotlib
# %matplotlib inline

# %%
#Clean column names
def clean_col_name(str_in):
    str_out = str_in.lower() #Change all to lower case
    str_out = re.sub(r'.*\.','',str_out) #Remove everything before a .
    str_out = re.sub(r' ','_',str_out) #Replace spaces with _
    str_out = re.sub(r'_?&_?','_and_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'_?@_?','_at_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'[^0-9a-z_]','',str_out) #Remove all non allowed characters
    str_out = re.sub(r'^_','',str_out) #Remove leading _
    return str_out

# %%
class process_time:
    def __init__(self,name:str = ''):
        self.st_time = dt.datetime.now()
        self.lap_li = []
        self.en_time = None
        self.name = name
    def calc_el_time(self,st_time,en_time):
        diff_time = en_time - st_time
        duration_in_s = diff_time.total_seconds()
        hours = int(divmod(duration_in_s, 3600)[0])
        duration_in_s += -(hours * 3600)
        minutes = int(divmod(duration_in_s, 60)[0])
        duration_in_s += -(minutes * 60)
        seconds = int(duration_in_s)
        return [hours,minutes,seconds]
    def lap(self):
        self.lap_li.append(dt.datetime.now())
    def end(self):
        self.en_time = dt.datetime.now()
        lap_time = self.calc_el_time(self.st_time,self.en_time)
        if self.name != '':
            print('TOTAL ELAPSED TIME OF {} -> {}:{}:{}'.format(self.name,lap_time[0],lap_time[1],lap_time[2]))
        else:
            print('TOTAL ELAPSED TIME -> {}:{}:{}'.format(lap_time[0],lap_time[1],lap_time[2]))
    def show_lap_times(self):
        tmp_count = 0
        for lap in self.lap_li:
            tmp_count += 1
            lap_time = self.calc_el_time(self.st_time,lap)
            print('LAP {} TIME -> {}:{}:{}'.format(tmp_count,lap_time[0],lap_time[1],lap_time[2]))
    def show_latest_lap_time(self):
        if len(self.lap_li) == 0:
            return
        elif len(self.lap_li) < 2:
            lap_time = self.calc_el_time(self.st_time,self.lap_li[-1])
        else:
            lap_time = self.calc_el_time(self.lap_li[-2],self.lap_li[-1])
        print('LAP {} TIME -> {}:{}:{}'.format(len(self.lap_li),lap_time[0],lap_time[1],lap_time[2]))

# %% [markdown]
# # Delete the old temporary files (if they exist)

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 files
src_fldr_pth = r'C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\'
try:
    os.remove(src_fldr_pth + r'all_hist_prices_d_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_d_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.remove(src_fldr_pth + r'all_hist_prices_w_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_w_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d_TMP.h5
#
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w_TMP.h5

# %% [markdown]
# # Scraping tickers
# This section will scrap the ticker values for the FTSE 100 and FTSE 250 and store them in dataframes 'tick_ftse100' and 'tick_ftse250'.
#
# Finally concatenate into 1 dataframe 'tick_ftse'.

# %%
#Fetch the data for ftse 100
web_add = 'https://en.wikipedia.org/wiki/FTSE_100_Index'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Get the table id=constituents
table = parser.find_all('table',id='constituents')[0]
#Get rows ignoring first row
rows = table.find_all('tr')[1:]
row_li = []
for r in rows:
    temp_row = []
    for r2 in r.find_all('td'):
        temp_row.append(re.sub('(?=[A-Z]*)\..*','',r2.text.upper().rstrip()))
    temp_row = temp_row[:2]
    row_li.append(temp_row)
#Create a dataframe
tick_ftse100 = pd.DataFrame(data=row_li,columns=['company','ticker'])
tick_ftse100['index'] = 'FTSE100'
tick_ftse100
# Out:
#                company ticker    index
# 0                   3I    III  FTSE100
# 1        ADMIRAL GROUP    ADM  FTSE100
# 2   ANGLO AMERICAN PLC    AAL  FTSE100
# 3          ANTOFAGASTA   ANTO  FTSE100
# 4        ASHTEAD GROUP    AHT  FTSE100
# ..                 ...    ...      ...
# 95            UNILEVER   ULVR  FTSE100
# 96    UNITED UTILITIES     UU  FTSE100
# 97      VODAFONE GROUP    VOD  FTSE100
# 98           WHITBREAD    WTB  FTSE100
# 99             WPP PLC    WPP  FTSE100
#
# [100 rows x 3 columns]

# %%
#Fetch the data for ftse 250
web_add = 'https://en.wikipedia.org/wiki/FTSE_250_Index'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Get the table id=constituents
table = parser.find_all('table',id='constituents')[0]
#Get rows ignoring first row
rows = table.find_all('tr')[1:]
row_li = []
for r in rows:
    temp_row = []
    for r2 in r.find_all('td'):
        temp_row.append(re.sub('(?=[A-Z]*)\..*','',r2.text.upper().rstrip()))
    temp_row = temp_row[:2]
    row_li.append(temp_row)
#Create a dataframe
tick_ftse250 = pd.DataFrame(data=row_li,columns=['company','ticker'])
tick_ftse250['index'] = 'FTSE250'
tick_ftse250
# Out:
#                                company ticker    index
# 0                    3I INFRASTRUCTURE    3IN  FTSE250
# 1                             4IMPRINT   FOUR  FTSE250
# 2    ABERFORTH SMALLER COMPANIES TRUST    ASL  FTSE250
# 3                              AGGREKO    AGK  FTSE250
# 4                        AIRTEL AFRICA    AAF  FTSE250
# ..                                 ...    ...      ...
# 245             WITAN INVESTMENT TRUST   WTAN  FTSE250
# 246                           WIZZ AIR   WIZZ  FTSE250
# 247                         WOOD GROUP     WG  FTSE250
# 248                    WORKSPACE GROUP    WKP  FTSE250
# 249         WORLDWIDE HEALTHCARE TRUST    WWH  FTSE250
#
# [250 rows x 3 columns]

# %%
#Combine into 1 dataframe
tick_ftse = pd.concat([tick_ftse100,tick_ftse250])
tick_ftse
# Out:
#                         company ticker    index
# 0                            3I    III  FTSE100
# 1                 ADMIRAL GROUP    ADM  FTSE100
# 2            ANGLO AMERICAN PLC    AAL  FTSE100
# 3                   ANTOFAGASTA   ANTO  FTSE100
# 4                 ASHTEAD GROUP    AHT  FTSE100
# ..                          ...    ...      ...
# 245      WITAN INVESTMENT TRUST   WTAN  FTSE250
# 246                    WIZZ AIR   WIZZ  FTSE250
# 247                  WOOD GROUP     WG  FTSE250
# 248             WORKSPACE GROUP    WKP  FTSE250
# 249  WORLDWIDE HEALTHCARE TRUST    WWH  FTSE250
#
# [350 rows x 3 columns]

# %% [markdown]
# # Get the latest price dates
# Get the latest price file.
#
# Loop through the tickers in tick_ftse and for each one get the latest date of scrape.
#
# Convert this date into a timestamp and add to the dataframe.

# %%
#open the price file
hist_prices_df = pd.read_hdf(src_fldr_pth + r'all_hist_prices_d.h5')
hist_prices_df.head()
# Out:
#   ticker       date    open   close    high    low  change     volume  ema12  \
# 0    III 2008-01-02   995.0  1005.0  1023.0  995.0    10.0   785944.0    NaN
# 1    III 2008-01-03  1005.0   988.0  1020.0  981.0   -17.0  1805560.0    NaN
# 2    III 2008-01-04   985.5   965.0  1000.0  964.0   -20.5  1920061.0    NaN
# 3    III 2008-01-07   967.5   971.5   974.0  953.0     4.0  3167216.0    NaN
# 4    III 2008-01-08   975.0   978.5   989.0  971.5     3.5  2297118.0    NaN
#
#    ema26  macd_line  signal  macd
# 0    NaN        NaN     NaN   NaN
# 1    NaN        NaN     NaN   NaN
# 2    NaN        NaN     NaN   NaN
# 3    NaN        NaN     NaN   NaN
# 4    NaN        NaN     NaN   NaN

# %%
#Convert date
def conv_date(_str_in):
    if type(_str_in) == str:
        return dt.datetime.strptime(_str_in,'%Y-%m-%d')
    else:
        return _str_in
hist_prices_df.date = [conv_date(x) for x in hist_prices_df.date]
hist_prices_df.dtypes
# Out:
# ticker               object
# date         datetime64[ns]
# open                float64
# close               float64
# high                float64
# low                 float64
# change              float64
# volume              float64
# ema12               float64
# ema26               float64
# macd_line           float64
# signal              float64
# macd                float64
# dtype: object

# %% [markdown]
# # Scraping a stock history
# Working backwards through time from now until the last price scrape date collect all the daily data for a stock. Daily is used as it can later be summarised into weekly or monthly if required.
#
# This will then be put into a dataframe containing:
# - ticker
# - Company name
# - date
# - open
# - high
# - low
# - close
# - Adjusted close (for divs and splits)
# - volume

# %%
#Create a list of time intervals to be used with 140 days in each item
def create_sec_ref_li(_st_date:int,_en_date:int):
    #Establish the day ref of the dates compared to 01/01/1970
    _ep_date = pd.to_datetime(dt.datetime(1970,1,1),errors='coerce')
    _en_date = pd.to_datetime(_en_date,errors='coerce')
    _st_date = pd.to_datetime(_st_date,errors='coerce')
    print('_st_date: ' + str(_st_date))
    print('_en_date: ' + str(_en_date))
    _st_days = (_st_date - _ep_date).days
    _en_days = (_en_date - _ep_date).days
    #Loop adding to a list until reaching 0
    _sec_ref_li = []
    _days = 140
    while _en_days > _st_days:
        if _en_days - _days > _st_days:
            _sec_ref_li.append([(_en_days - _days)*86400,_en_days*86400])
        else:
            _sec_ref_li.append([_st_days*86400,_en_days*86400])        
        _en_days += -_days
    return _sec_ref_li

# %%
def calc_ema(s_in,periods):
    #Calc mod val
    mod = 2/(periods+1)
    #Make a df
    tmp_df = pd.DataFrame(s_in)
    #Calc sma
    tmp_df['sma'] = pd.Series([0] * len(s_in))
    for i in range(0,periods):
        tmp_df['sma'] += tmp_df[s_in.name].shift(i) / periods
    #Calc ema
    tmp_df['ema'] = tmp_df['sma'].copy()
    for row in tmp_df.iterrows():
        i = row[0]
        if i > 0 and not np.isnan(tmp_df['sma'][i-1]):
            tmp_df['ema'][i] = mod*(tmp_df[s_in.name][i] - tmp_df['ema'][i-1]) + tmp_df['ema'][i-1]
    return tmp_df['ema'].copy()

# %%
def calc_macd(ema_lng_s,ema_sht_s,sig_period):
    #Make a df
    tmp_df = pd.DataFrame([])
    tmp_df['ema_lng'] = ema_lng_s
    tmp_df['ema_sht'] = ema_sht_s
    #Calc the signal line
    tmp_df['macd_line'] = tmp_df['ema_sht'] - tmp_df['ema_lng']
    tmp_df['signal_line'] = calc_ema(tmp_df['macd_line'],sig_period)
    tmp_df['macd_hist'] = tmp_df['macd_line'] - tmp_df['signal_line']
    return (tmp_df['macd_line'].copy(),tmp_df['signal_line'].copy(),tmp_df['macd_hist'].copy())

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(hist_prices_df)
# col_lens = {'ticker': 4,
#  'date': 19,
#  'open': 8,
#  'close': 8,
#  'high': 8,
#  'low': 8,
#  'change': 22,
#  'volume': 12,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23}
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'open': 8,
#  'close': 8,
#  'high': 8,
#  'low': 8,
#  'change': 22,
#  'volume': 12,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23}

# %%
#Get the price history for a specific ticker
def get_price_hist_d(_tick:str,_sec_ref_li:list):
    try:
        _tick = re.sub('[^A-Z0-9\-]','',_tick)
        print('Getting DAILY prices for:{}'.format(_tick))
        _tick_df = pd.DataFrame([])
        _cols = []

        for _secs in _sec_ref_li:
            try:
                _web_add = 'https://finance.yahoo.com/quote/{0}/history?period1={1}&period2={2}&interval={3}&filter=history&frequency={3}'.format(_tick+'.L',_secs[0],_secs[1],'1d')
#                 print('_web_add: {}'.format(_web_add))
                
                _resp = rq.get(_web_add)
                if int(_resp.status_code) != 200:
                    print('status code: {}'.format(_resp.status_code))
                    continue
                _parser = bs(_resp.content,'html.parser')
                #Get the table
                _table = _parser.find_all('table',attrs={'data-test':'historical-prices'})[0]
                #Grab the data rows
                _rows = _table.find_all('tbody')[0].find_all('tr')
                #Put the rows into the dataframe
                for _r in _rows:
                    if len(_tick_df) == 0:
                        _cols = [clean_col_name(x.text) for x in _table.find_all('th')]
                        _tick_df = pd.DataFrame([],columns=_cols)
                    if len(_r.find_all('td')) == len(_cols):
                        _tick_df = _tick_df.append(pd.Series([x.text for x in _r.find_all('td')],index=_cols),ignore_index=True)
                    else:
                        continue
            except Exception as e:
                print('ERROR - CONTINUE:{}'.format(e))
                continue
        #Check for rows - if none then return
        if len(_tick_df) == 0:
            return _tick_df
        #Reformat
        def float_format(_str_in):
            if type(_str_in) == str:
                _str_in = _str_in.strip()
                _str_in = re.sub('[^0-9.]','',_str_in)
                if _str_in == '':
                    _str_in = 0
                return _str_in
            else:
                return _str_in
        _tick_df.loc[:,'open'] = _tick_df.loc[:,'open'].apply(float_format).astype(float)
        _tick_df.loc[:,'high'] = _tick_df.loc[:,'high'].apply(float_format).astype(float)
        _tick_df.loc[:,'low'] = _tick_df.loc[:,'low'].apply(float_format).astype(float)
        _tick_df.loc[:,'close'] = _tick_df.loc[:,'close'].apply(float_format).astype(float)
        _tick_df.loc[:,'adj_close'] = _tick_df.loc[:,'adj_close'].apply(float_format).astype(float)
        _tick_df.loc[:,'volume'] = _tick_df.loc[:,'volume'].apply(float_format).astype(float)
        _tick_df.loc[:,'change'] = _tick_df.loc[:,'close'] - _tick_df.loc[:,'open']
        def conv_date(_str_in):
            if type(_str_in) == str:
                return dt.datetime.strptime(_str_in,'%b %d, %Y')
            else:
                return _str_in
        _tick_df.loc[:,'date'] = _tick_df.loc[:,'date'].apply(conv_date)
        #Add the ticker series
        _tick_df.loc[:,'ticker'] = _tick    
        _tick_df = _tick_df.loc[:,['ticker','date','open','close','high','low','change','volume']]
        #CLEANING - Remove any rows with zero volume
        _tick_df = _tick_df[_tick_df['volume'] > 0]
        #CLEANING - Copy row above where the change has been more than 90%
        _tick_df['cl_change'] = (_tick_df['close'] - _tick_df['close'].shift(1))/_tick_df['close'].shift(1)
        _check_s = _tick_df['cl_change'] < -0.9
        _tick_df.loc[_check_s,'open'] = _tick_df['open'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'close'] = _tick_df['close'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'high'] = _tick_df['high'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'low'] = _tick_df['low'].shift(-1).copy().loc[_check_s]
        _tick_df.drop(columns='cl_change',inplace=True)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

#Calc the ema and macds for the data
def calc_ema_macd(_tick_df):
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal_line'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        #Sort clean and export
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

# %%
#Create a weekly table
def get_price_hist_w(_df_d):
    print('Converting daily prices to weekly prices')
    try:
        #Create a copy of the data
        _df_d = _df_d.copy()
        #Establish a week number for each date
        _df_d['isocalendar'] = [x.isocalendar()[:2] for x in _df_d['date']]
        #Get highs and lows
        _high_df = _df_d.loc[_df_d['high'] > 0,['high','isocalendar']].groupby('isocalendar').max().reset_index()
        _low_df = _df_d.loc[_df_d['low'] > 0,['low','isocalendar']].groupby('isocalendar').min().reset_index()
        #Get total volume for the week
        _vol_df = _df_d.loc[_df_d['volume'] > 0,['volume','isocalendar']].groupby('isocalendar').sum().reset_index()
        #Get open price
        _min_wk_day = _df_d.loc[_df_d['open'] > 0,['date','isocalendar']].groupby('isocalendar').min().reset_index()
        _open_df = pd.merge(_df_d[['date','open']],_min_wk_day,left_on='date',right_on='date')
        #Get close price
        _max_wk_day = _df_d.loc[_df_d['close'] > 0,['date','isocalendar']].groupby('isocalendar').max().reset_index()
        _close_df = pd.merge(_df_d[['date','close']],_max_wk_day,left_on='date',right_on='date').reset_index()
        #Form the final df
        _wk_df = pd.merge(_df_d[['ticker','isocalendar']],_min_wk_day,left_on='isocalendar',right_on='isocalendar') #date
        _wk_df = pd.merge(_wk_df,_high_df,left_on='isocalendar',right_on='isocalendar') #high
        _wk_df = pd.merge(_wk_df,_low_df,left_on='isocalendar',right_on='isocalendar') #low
        _wk_df = pd.merge(_wk_df,_vol_df,left_on='isocalendar',right_on='isocalendar') #volume
        _wk_df = pd.merge(_wk_df,_open_df[['isocalendar','open']],left_on='isocalendar',right_on='isocalendar') #open
        _wk_df = pd.merge(_wk_df,_close_df[['isocalendar','close']],left_on='isocalendar',right_on='isocalendar') #close
        _wk_df['change'] = _wk_df['close'] - _wk_df['open']
        _wk_df = _wk_df.drop_duplicates().reset_index(drop=True)
        #Get the monday of each week
        _wk_df['weekday'] = [dt.date.weekday(x) for x in _wk_df['date']]
        _wk_df['date'] = _wk_df['date'] - pd.Series([dt.timedelta(days=x) for x in _wk_df['weekday']])
        _wk_df.drop(columns=['isocalendar','weekday'],inplace=True)
        return _wk_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

# %%
#Scrape daily price data
hf_store_name_d = src_fldr_pth + r'all_hist_prices_d_TMP.h5'
hf_d = pd.HDFStore(hf_store_name_d)
group_name_d = r'daily_data'
hf_store_name_w = src_fldr_pth + r'all_hist_prices_w_TMP.h5'
hf_w = pd.HDFStore(hf_store_name_w)
group_name_w = r'weekly_data'
out_cols = ['ticker','date','open','close','high','low','change','volume']
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse['ticker']:
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print('\n{} RUNNING FOR: {}'.format(count,tick))
        tick_df = hist_prices_df[hist_prices_df.ticker == tick][out_cols]
        print('DAILY SHAPE BEFORE: {}'.format(tick_df.shape))
        
        #DAILY PRICES
        #Get last scrapped date
        st_date = tick_df.date.max()
        if pd.isnull(st_date):
            #Treat as a new share
            st_date = dt.datetime(1970,1,1)
        
        #Get new price data
        new_tick_df = get_price_hist_d(tick,create_sec_ref_li(st_date,dt.datetime.today()+dt.timedelta(days=1))) #1 day ahead so today is included
        
        #Join onto existing data
        tick_df = tick_df.append(new_tick_df)
        
        #Drop duplicates
        tick_df = tick_df.drop_duplicates()

        #Calc emas and macd
        tick_df = calc_ema_macd(tick_df)
        print('DAILY FINAL SHAPE: {}'.format(tick_df.shape))
        
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in tick_df:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
                
        #Add to daily h5 file
        tick_df.to_hdf(hf_store_name_d,key=group_name_d,append=True,min_itemsize=col_lens_tmp)
        
        #WEEKLY PRICES
        #Convert to weekly prices
        df_w = get_price_hist_w(tick_df)
        
        #Drop duplicates
        df_w = df_w.drop_duplicates()

        #Calc emas and macd
        df_w = calc_ema_macd(df_w)
        print('WEEKLY FINAL SHAPE: {}'.format(df_w.shape))

        #Add to weekly h5 file
        df_w.to_hdf(hf_store_name_w,key=group_name_w,append=True,min_itemsize=col_lens)
    except Exception as e:
        print('ERROR:{}'.format(e))
        errors.append(e)
hf_d.close()
hf_w.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1 RUNNING FOR: III
# DAILY SHAPE BEFORE: (2951, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:07:32.293414
# Getting DAILY prices for:III
# DAILY FINAL SHAPE: (2952, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 1 TIME -> 0:0:0
#
# 2 RUNNING FOR: ADM
# DAILY SHAPE BEFORE: (1751, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:07:37.431312
# Getting DAILY prices for:ADM
# DAILY FINAL SHAPE: (1753, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (372, 13)
# LAP 2 TIME -> 0:0:5
#
# 3 RUNNING FOR: AAL
# DAILY SHAPE BEFORE: (4322, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:07:40.720029
# Getting DAILY prices for:AAL
# DAILY FINAL SHAPE: (4323, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1015, 13)
# LAP 3 TIME -> 0:0:3
#
# 4 RUNNING FOR: ANTO
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:07:47.317979
# Getting DAILY prices for:ANTO
# DAILY FINAL SHAPE: (5083, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 4 TIME -> 0:0:6
#
# 5 RUNNING FOR: AHT
# DAILY SHAPE BEFORE: (4650, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:07:54.459077
# Getting DAILY prices for:AHT
# DAILY FINAL SHAPE: (4652, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1032, 13)
# LAP 5 TIME -> 0:0:7
#
# 6 RUNNING FOR: ABF
# DAILY SHAPE BEFORE: (5057, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:01.113643
# Getting DAILY prices for:ABF
# DAILY FINAL SHAPE: (5058, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 6 TIME -> 0:0:6
#
# 7 RUNNING FOR: AZN
# DAILY SHAPE BEFORE: (5041, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:08.916804
# Getting DAILY prices for:AZN
# DAILY FINAL SHAPE: (5042, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 7 TIME -> 0:0:7
#
# 8 RUNNING FOR: AUTO
# DAILY SHAPE BEFORE: (1149, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:19.184335
# Getting DAILY prices for:AUTO
# DAILY FINAL SHAPE: (1150, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (238, 13)
# LAP 8 TIME -> 0:0:10
#
# 9 RUNNING FOR: AVV
# DAILY SHAPE BEFORE: (5005, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:22.603365
# Getting DAILY prices for:AVV
# DAILY FINAL SHAPE: (5006, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 9 TIME -> 0:0:3
#
# 10 RUNNING FOR: AV
# DAILY SHAPE BEFORE: (5063, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:32.553522
# Getting DAILY prices for:AV
# DAILY FINAL SHAPE: (5064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1057, 13)
# LAP 10 TIME -> 0:0:9
#
# 11 RUNNING FOR: BA
# DAILY SHAPE BEFORE: (5079, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:40.311362
# Getting DAILY prices for:BA
# DAILY FINAL SHAPE: (5080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 11 TIME -> 0:0:7
#
# 12 RUNNING FOR: BARC
# DAILY SHAPE BEFORE: (5020, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:47.746027
# Getting DAILY prices for:BARC
# DAILY FINAL SHAPE: (5021, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 12 TIME -> 0:0:7
#
# 13 RUNNING FOR: BDEV
# DAILY SHAPE BEFORE: (5079, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:08:54.967820
# Getting DAILY prices for:BDEV
# DAILY FINAL SHAPE: (5080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 13 TIME -> 0:0:7
#
# 14 RUNNING FOR: BKG
# DAILY SHAPE BEFORE: (5072, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:09:02.434443
# Getting DAILY prices for:BKG
# DAILY FINAL SHAPE: (5073, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 14 TIME -> 0:0:7
#
# 15 RUNNING FOR: BHP
# DAILY SHAPE BEFORE: (2353, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:09:11.370122
# Getting DAILY prices for:BHP
# DAILY FINAL SHAPE: (2354, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (499, 13)
# LAP 15 TIME -> 0:0:8
#
# 16 RUNNING FOR: BP
# DAILY SHAPE BEFORE: (5037, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:09:15.966688
# Getting DAILY prices for:BP
# DAILY FINAL SHAPE: (5039, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 16 TIME -> 0:0:4
#
# 17 RUNNING FOR: BATS
# DAILY SHAPE BEFORE: (5046, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:09:23.309161
# Getting DAILY prices for:BATS
# DAILY FINAL SHAPE: (5047, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 17 TIME -> 0:0:7
#
# 18 RUNNING FOR: BLND
# DAILY SHAPE BEFORE: (5080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:09:30.779232
# Getting DAILY prices for:BLND
# DAILY FINAL SHAPE: (5081, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 18 TIME -> 0:0:7
#
# 19 RUNNING FOR: BT
# DAILY SHAPE BEFORE: (0, 8)
# _st_date: 1970-01-01 00:00:00
# _en_date: 2019-09-30 08:09:38.298373
# Getting DAILY prices for:BT
# DAILY FINAL SHAPE: (0, 13)
# Converting daily prices to weekly prices
# ERROR:cannot subtract float64-dtype from DatetimeArray
# ERROR:'bool' object has no attribute 'drop_duplicates'
# LAP 19 TIME -> 0:0:7
#
# 20 RUNNING FOR: BNZL
# DAILY SHAPE BEFORE: (5001, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:10:31.827087
# Getting DAILY prices for:BNZL
# DAILY FINAL SHAPE: (5002, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1049, 13)
# LAP 20 TIME -> 0:0:53
#
# 21 RUNNING FOR: BRBY
# DAILY SHAPE BEFORE: (4349, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:10:39.383214
# Getting DAILY prices for:BRBY
# DAILY FINAL SHAPE: (4350, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (900, 13)
# LAP 21 TIME -> 0:0:7
#
# 22 RUNNING FOR: CCL
# DAILY SHAPE BEFORE: (4762, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:10:46.248684
# Getting DAILY prices for:CCL
# DAILY FINAL SHAPE: (4763, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (988, 13)
# LAP 22 TIME -> 0:0:6
#
# 23 RUNNING FOR: CNA
# DAILY SHAPE BEFORE: (5077, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:10:53.633090
# Getting DAILY prices for:CNA
# DAILY FINAL SHAPE: (5078, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 23 TIME -> 0:0:7
#
# 24 RUNNING FOR: CCH
# DAILY SHAPE BEFORE: (1628, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:01.417707
# Getting DAILY prices for:CCH
# DAILY FINAL SHAPE: (1629, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (335, 13)
# LAP 24 TIME -> 0:0:7
#
# 25 RUNNING FOR: CPG
# DAILY SHAPE BEFORE: (4978, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:05.272283
# Getting DAILY prices for:CPG
# DAILY FINAL SHAPE: (4979, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1030, 13)
# LAP 25 TIME -> 0:0:3
#
# 26 RUNNING FOR: CRH
# DAILY SHAPE BEFORE: (4978, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:13.219047
# Getting DAILY prices for:CRH
# DAILY FINAL SHAPE: (4979, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1030, 13)
# LAP 26 TIME -> 0:0:7
#
# 27 RUNNING FOR: CRDA
# DAILY SHAPE BEFORE: (5041, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:21.176391
# Getting DAILY prices for:CRDA
# DAILY FINAL SHAPE: (5042, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 27 TIME -> 0:0:7
#
# 28 RUNNING FOR: DCC
# DAILY SHAPE BEFORE: (4753, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:29.076457
# Getting DAILY prices for:DCC
# DAILY FINAL SHAPE: (4754, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1026, 13)
# LAP 28 TIME -> 0:0:7
#
# 29 RUNNING FOR: DGE
# DAILY SHAPE BEFORE: (5073, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:37.228520
# Getting DAILY prices for:DGE
# DAILY FINAL SHAPE: (5074, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 29 TIME -> 0:0:8
#
# 30 RUNNING FOR: EVR
# DAILY SHAPE BEFORE: (1998, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:45.626833
# Getting DAILY prices for:EVR
# DAILY FINAL SHAPE: (2000, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (413, 13)
# LAP 30 TIME -> 0:0:8
#
# 31 RUNNING FOR: EXPN
# DAILY SHAPE BEFORE: (3282, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:50.353988
# Getting DAILY prices for:EXPN
# DAILY FINAL SHAPE: (3283, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (677, 13)
# LAP 31 TIME -> 0:0:4
#
# 32 RUNNING FOR: FERG
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:11:56.323855
# Getting DAILY prices for:FERG
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 32 TIME -> 0:0:5
#
# 33 RUNNING FOR: FLTR
# DAILY SHAPE BEFORE: (88, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:04.832947
# Getting DAILY prices for:FLTR
# DAILY FINAL SHAPE: (89, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (17, 13)
# LAP 33 TIME -> 0:0:8
#
# 34 RUNNING FOR: FRES
# DAILY SHAPE BEFORE: (2879, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:06.450545
# Getting DAILY prices for:FRES
# DAILY FINAL SHAPE: (2881, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (596, 13)
# LAP 34 TIME -> 0:0:1
#
# 35 RUNNING FOR: GSK
# DAILY SHAPE BEFORE: (5034, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:11.154487
# Getting DAILY prices for:GSK
# DAILY FINAL SHAPE: (5035, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 35 TIME -> 0:0:4
#
# 36 RUNNING FOR: GLEN
# DAILY SHAPE BEFORE: (2118, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:18.235188
# Getting DAILY prices for:GLEN
# DAILY FINAL SHAPE: (2119, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (437, 13)
# LAP 36 TIME -> 0:0:7
#
# 37 RUNNING FOR: HLMA
# DAILY SHAPE BEFORE: (4492, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:22.277272
# Getting DAILY prices for:HLMA
# DAILY FINAL SHAPE: (4494, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 37 TIME -> 0:0:4
#
# 38 RUNNING FOR: HL
# DAILY SHAPE BEFORE: (3079, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:29.016801
# Getting DAILY prices for:HL
# DAILY FINAL SHAPE: (3080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (640, 13)
# LAP 38 TIME -> 0:0:6
#
# 39 RUNNING FOR: HSX
# DAILY SHAPE BEFORE: (4957, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:34.098135
# Getting DAILY prices for:HSX
# DAILY FINAL SHAPE: (4958, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1030, 13)
# LAP 39 TIME -> 0:0:5
#
# 40 RUNNING FOR: HSBA
# DAILY SHAPE BEFORE: (5052, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:41.452351
# Getting DAILY prices for:HSBA
# DAILY FINAL SHAPE: (5053, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 40 TIME -> 0:0:7
#
# 41 RUNNING FOR: HIK
# DAILY SHAPE BEFORE: (3514, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:49.144088
# Getting DAILY prices for:HIK
# DAILY FINAL SHAPE: (3515, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (726, 13)
# LAP 41 TIME -> 0:0:7
#
# 42 RUNNING FOR: IMB
# DAILY SHAPE BEFORE: (4817, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:12:54.566429
# Getting DAILY prices for:IMB
# DAILY FINAL SHAPE: (4818, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1051, 13)
# LAP 42 TIME -> 0:0:5
#
# 43 RUNNING FOR: INF
# DAILY SHAPE BEFORE: (5089, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:01.687261
# Getting DAILY prices for:INF
# DAILY FINAL SHAPE: (5091, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 43 TIME -> 0:0:7
#
# 44 RUNNING FOR: IHG
# DAILY SHAPE BEFORE: (4170, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:08.946194
# Getting DAILY prices for:IHG
# DAILY FINAL SHAPE: (4171, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (873, 13)
# LAP 44 TIME -> 0:0:7
#
# 45 RUNNING FOR: IAG
# DAILY SHAPE BEFORE: (4230, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:15.232665
# Getting DAILY prices for:IAG
# DAILY FINAL SHAPE: (4232, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (875, 13)
# LAP 45 TIME -> 0:0:6
#
# 46 RUNNING FOR: ITRK
# DAILY SHAPE BEFORE: (4199, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:21.948748
# Getting DAILY prices for:ITRK
# DAILY FINAL SHAPE: (4200, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (904, 13)
# LAP 46 TIME -> 0:0:6
#
# 47 RUNNING FOR: ITV
# DAILY SHAPE BEFORE: (4951, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:28.340360
# Getting DAILY prices for:ITV
# DAILY FINAL SHAPE: (4952, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1030, 13)
# LAP 47 TIME -> 0:0:6
#
# 48 RUNNING FOR: JD
# DAILY SHAPE BEFORE: (777, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:35.514570
# Getting DAILY prices for:JD
# DAILY FINAL SHAPE: (778, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (169, 13)
# LAP 48 TIME -> 0:0:7
#
# 49 RUNNING FOR: JMAT
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:38.337094
# Getting DAILY prices for:JMAT
# DAILY FINAL SHAPE: (5083, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 49 TIME -> 0:0:2
#
# 50 RUNNING FOR: JE
# DAILY SHAPE BEFORE: (1391, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:45.831261
# Getting DAILY prices for:JE
# DAILY FINAL SHAPE: (1393, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (287, 13)
# LAP 50 TIME -> 0:0:7
#
# 51 RUNNING FOR: KGF
# DAILY SHAPE BEFORE: (5080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:49.342257
# Getting DAILY prices for:KGF
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 51 TIME -> 0:0:3
#
# 52 RUNNING FOR: LAND
# DAILY SHAPE BEFORE: (5055, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:13:56.833362
# Getting DAILY prices for:LAND
# DAILY FINAL SHAPE: (5056, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 52 TIME -> 0:0:7
#
# 53 RUNNING FOR: LGEN
# DAILY SHAPE BEFORE: (5051, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:04.490741
# Getting DAILY prices for:LGEN
# DAILY FINAL SHAPE: (5052, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 53 TIME -> 0:0:7
#
# 54 RUNNING FOR: LLOY
# DAILY SHAPE BEFORE: (5084, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:12.130887
# Getting DAILY prices for:LLOY
# DAILY FINAL SHAPE: (5085, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 54 TIME -> 0:0:7
#
# 55 RUNNING FOR: LSE
# DAILY SHAPE BEFORE: (4587, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:19.723098
# Getting DAILY prices for:LSE
# DAILY FINAL SHAPE: (4588, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (950, 13)
# LAP 55 TIME -> 0:0:7
#
# 56 RUNNING FOR: MGGT
# DAILY SHAPE BEFORE: (4642, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:26.946514
# Getting DAILY prices for:MGGT
# DAILY FINAL SHAPE: (4643, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1047, 13)
# LAP 56 TIME -> 0:0:7
#
# 57 RUNNING FOR: MRO
# DAILY SHAPE BEFORE: (3869, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:34.269567
# Getting DAILY prices for:MRO
# DAILY FINAL SHAPE: (3870, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (830, 13)
# LAP 57 TIME -> 0:0:7
#
# 58 RUNNING FOR: MNDI
# DAILY SHAPE BEFORE: (3046, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:40.907725
# Getting DAILY prices for:MNDI
# DAILY FINAL SHAPE: (3047, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (633, 13)
# LAP 58 TIME -> 0:0:6
#
# 59 RUNNING FOR: MRW
# DAILY SHAPE BEFORE: (5074, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:46.620829
# Getting DAILY prices for:MRW
# DAILY FINAL SHAPE: (5075, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 59 TIME -> 0:0:5
#
# 60 RUNNING FOR: NG
# DAILY SHAPE BEFORE: (5077, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:14:54.453306
# Getting DAILY prices for:NG
# DAILY FINAL SHAPE: (5078, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 60 TIME -> 0:0:7
#
# 61 RUNNING FOR: NXT
# DAILY SHAPE BEFORE: (5057, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:02.795551
# Getting DAILY prices for:NXT
# DAILY FINAL SHAPE: (5058, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 61 TIME -> 0:0:8
#
# 62 RUNNING FOR: NMC
# DAILY SHAPE BEFORE: (1895, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:10.622147
# Getting DAILY prices for:NMC
# DAILY FINAL SHAPE: (1896, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (391, 13)
# LAP 62 TIME -> 0:0:7
#
# 63 RUNNING FOR: OCDO
# DAILY SHAPE BEFORE: (2325, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:15.336468
# Getting DAILY prices for:OCDO
# DAILY FINAL SHAPE: (2326, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (480, 13)
# LAP 63 TIME -> 0:0:4
#
# 64 RUNNING FOR: PSON
# DAILY SHAPE BEFORE: (5077, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:20.327650
# Getting DAILY prices for:PSON
# DAILY FINAL SHAPE: (5078, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 64 TIME -> 0:0:4
#
# 65 RUNNING FOR: PSN
# DAILY SHAPE BEFORE: (5064, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:29.906880
# Getting DAILY prices for:PSN
# DAILY FINAL SHAPE: (5065, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 65 TIME -> 0:0:9
#
# 66 RUNNING FOR: PHNX
# DAILY SHAPE BEFORE: (2431, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:39.743376
# Getting DAILY prices for:PHNX
# DAILY FINAL SHAPE: (2432, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (513, 13)
# LAP 66 TIME -> 0:0:9
#
# 67 RUNNING FOR: POLY
# DAILY SHAPE BEFORE: (2004, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:44.045838
# Getting DAILY prices for:POLY
# DAILY FINAL SHAPE: (2005, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (414, 13)
# LAP 67 TIME -> 0:0:4
#
# 68 RUNNING FOR: PRU
# DAILY SHAPE BEFORE: (5052, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:47.891186
# Getting DAILY prices for:PRU
# DAILY FINAL SHAPE: (5054, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 68 TIME -> 0:0:3
#
# 69 RUNNING FOR: RB
# DAILY SHAPE BEFORE: (5085, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:15:55.113281
# Getting DAILY prices for:RB
# DAILY FINAL SHAPE: (5086, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 69 TIME -> 0:0:7
#
# 70 RUNNING FOR: REL
# DAILY SHAPE BEFORE: (5080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:02.270036
# Getting DAILY prices for:REL
# DAILY FINAL SHAPE: (5081, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 70 TIME -> 0:0:7
#
# 71 RUNNING FOR: RTO
# DAILY SHAPE BEFORE: (5060, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:09.511534
# Getting DAILY prices for:RTO
# DAILY FINAL SHAPE: (5061, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 71 TIME -> 0:0:7
#
# 72 RUNNING FOR: RIO
# DAILY SHAPE BEFORE: (5072, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:16.978059
# Getting DAILY prices for:RIO
# DAILY FINAL SHAPE: (5073, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 72 TIME -> 0:0:7
#
# 73 RUNNING FOR: RMV
# DAILY SHAPE BEFORE: (3424, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:24.706482
# Getting DAILY prices for:RMV
# DAILY FINAL SHAPE: (3425, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (708, 13)
# LAP 73 TIME -> 0:0:7
#
# 74 RUNNING FOR: RR
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:31.853519
# Getting DAILY prices for:RR
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 74 TIME -> 0:0:7
#
# 75 RUNNING FOR: RBS
# DAILY SHAPE BEFORE: (5084, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:41.035705
# Getting DAILY prices for:RBS
# DAILY FINAL SHAPE: (5085, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 75 TIME -> 0:0:9
#
# 76 RUNNING FOR: RDSA
# DAILY SHAPE BEFORE: (2348, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:49.838274
# Getting DAILY prices for:RDSA
# DAILY FINAL SHAPE: (2349, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (495, 13)
# LAP 76 TIME -> 0:0:8
#
# 77 RUNNING FOR: RSA
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:16:56.004648
# Getting DAILY prices for:RSA
# DAILY FINAL SHAPE: (5085, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 77 TIME -> 0:0:6
#
# 78 RUNNING FOR: SGE
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:03.649924
# Getting DAILY prices for:SGE
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 78 TIME -> 0:0:7
#
# 79 RUNNING FOR: SBRY
# DAILY SHAPE BEFORE: (5081, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:11.861646
# Getting DAILY prices for:SBRY
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 79 TIME -> 0:0:8
#
# 80 RUNNING FOR: SDR
# DAILY SHAPE BEFORE: (5064, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:19.982866
# Getting DAILY prices for:SDR
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 80 TIME -> 0:0:8
#
# 81 RUNNING FOR: SMT
# DAILY SHAPE BEFORE: (640, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:28.042614
# Getting DAILY prices for:SMT
# DAILY FINAL SHAPE: (641, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (139, 13)
# LAP 81 TIME -> 0:0:8
#
# 82 RUNNING FOR: SGRO
# DAILY SHAPE BEFORE: (5075, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:31.122217
# Getting DAILY prices for:SGRO
# DAILY FINAL SHAPE: (5076, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 82 TIME -> 0:0:3
#
# 83 RUNNING FOR: SVT
# DAILY SHAPE BEFORE: (5074, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:39.082605
# Getting DAILY prices for:SVT
# DAILY FINAL SHAPE: (5075, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 83 TIME -> 0:0:8
#
# 84 RUNNING FOR: SN
# DAILY SHAPE BEFORE: (5081, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:47.134096
# Getting DAILY prices for:SN
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 84 TIME -> 0:0:8
#
# 85 RUNNING FOR: SMDS
# DAILY SHAPE BEFORE: (5084, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:17:55.663049
# Getting DAILY prices for:SMDS
# DAILY FINAL SHAPE: (5085, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 85 TIME -> 0:0:8
#
# 86 RUNNING FOR: SMIN
# DAILY SHAPE BEFORE: (4582, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:03.862261
# Getting DAILY prices for:SMIN
# DAILY FINAL SHAPE: (4583, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1037, 13)
# LAP 86 TIME -> 0:0:8
#
# 87 RUNNING FOR: SKG
# DAILY SHAPE BEFORE: (3172, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:11.861731
# Getting DAILY prices for:SKG
# DAILY FINAL SHAPE: (3173, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (655, 13)
# LAP 87 TIME -> 0:0:7
#
# 88 RUNNING FOR: SPX
# DAILY SHAPE BEFORE: (5079, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:17.892582
# Getting DAILY prices for:SPX
# DAILY FINAL SHAPE: (5080, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1051, 13)
# LAP 88 TIME -> 0:0:6
#
# 89 RUNNING FOR: SSE
# DAILY SHAPE BEFORE: (5043, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:26.444156
# Getting DAILY prices for:SSE
# DAILY FINAL SHAPE: (5044, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1054, 13)
# LAP 89 TIME -> 0:0:8
#
# 90 RUNNING FOR: STAN
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:34.565259
# Getting DAILY prices for:STAN
# DAILY FINAL SHAPE: (5083, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 90 TIME -> 0:0:8
#
# 91 RUNNING FOR: SLA
# DAILY SHAPE BEFORE: (3345, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:44.588354
# Getting DAILY prices for:SLA
# DAILY FINAL SHAPE: (3346, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (690, 13)
# LAP 91 TIME -> 0:0:10
#
# 92 RUNNING FOR: STJ
# DAILY SHAPE BEFORE: (5017, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:50.928378
# Getting DAILY prices for:STJ
# DAILY FINAL SHAPE: (5019, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1058, 13)
# LAP 92 TIME -> 0:0:6
#
# 93 RUNNING FOR: TW
# DAILY SHAPE BEFORE: (5077, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:18:59.752446
# Getting DAILY prices for:TW
# DAILY FINAL SHAPE: (5078, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 93 TIME -> 0:0:8
#
# 94 RUNNING FOR: TSCO
# DAILY SHAPE BEFORE: (5058, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:10.363744
# Getting DAILY prices for:TSCO
# DAILY FINAL SHAPE: (5059, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 94 TIME -> 0:0:10
#
# 95 RUNNING FOR: TUI
# DAILY SHAPE BEFORE: (1211, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:19.994720
# Getting DAILY prices for:TUI
# DAILY FINAL SHAPE: (1212, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (250, 13)
# LAP 95 TIME -> 0:0:9
#
# 96 RUNNING FOR: ULVR
# DAILY SHAPE BEFORE: (5081, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:23.389980
# Getting DAILY prices for:ULVR
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 96 TIME -> 0:0:3
#
# 97 RUNNING FOR: UU
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:30.863858
# Getting DAILY prices for:UU
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 97 TIME -> 0:0:7
#
# 98 RUNNING FOR: VOD
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:38.821380
# Getting DAILY prices for:VOD
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 98 TIME -> 0:0:7
#
# 99 RUNNING FOR: WTB
# DAILY SHAPE BEFORE: (5081, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:46.497726
# Getting DAILY prices for:WTB
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 99 TIME -> 0:0:7
#
# 100 RUNNING FOR: WPP
# DAILY SHAPE BEFORE: (2892, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:19:54.378693
# Getting DAILY prices for:WPP
# DAILY FINAL SHAPE: (2893, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (684, 13)
# LAP 100 TIME -> 0:0:7
#
# 101 RUNNING FOR: 3IN
# DAILY SHAPE BEFORE: (2907, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:00.246163
# Getting DAILY prices for:3IN
# DAILY FINAL SHAPE: (2909, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (608, 13)
# LAP 101 TIME -> 0:0:5
#
# 102 RUNNING FOR: FOUR
# DAILY SHAPE BEFORE: (4679, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:05.768406
# Getting DAILY prices for:FOUR
# DAILY FINAL SHAPE: (4680, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 102 TIME -> 0:0:5
#
# 103 RUNNING FOR: ASL
# DAILY SHAPE BEFORE: (2812, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:13.191177
# Getting DAILY prices for:ASL
# DAILY FINAL SHAPE: (2813, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (607, 13)
# LAP 103 TIME -> 0:0:7
#
# 104 RUNNING FOR: AGK
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:18.494744
# Getting DAILY prices for:AGK
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 104 TIME -> 0:0:5
#
# 105 RUNNING FOR: AAF
# DAILY SHAPE BEFORE: (64, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:26.094172
# Getting DAILY prices for:AAF
# DAILY FINAL SHAPE: (65, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (13, 13)
# LAP 105 TIME -> 0:0:7
#
# 106 RUNNING FOR: ATST
# DAILY SHAPE BEFORE: (2834, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:28.280656
# Getting DAILY prices for:ATST
# DAILY FINAL SHAPE: (2836, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 106 TIME -> 0:0:2
#
# 107 RUNNING FOR: APAX
# DAILY SHAPE BEFORE: (1027, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:33.498426
# Getting DAILY prices for:APAX
# DAILY FINAL SHAPE: (1028, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (219, 13)
# LAP 107 TIME -> 0:0:5
#
# 108 RUNNING FOR: ASCL
# DAILY SHAPE BEFORE: (923, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:36.772009
# Getting DAILY prices for:ASCL
# DAILY FINAL SHAPE: (924, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (191, 13)
# LAP 108 TIME -> 0:0:3
#
# 109 RUNNING FOR: ASHM
# DAILY SHAPE BEFORE: (3276, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:40.312135
# Getting DAILY prices for:ASHM
# DAILY FINAL SHAPE: (3278, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (677, 13)
# LAP 109 TIME -> 0:0:3
#
# 110 RUNNING FOR: AGR
# DAILY SHAPE BEFORE: (3834, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:47.441756
# Getting DAILY prices for:AGR
# DAILY FINAL SHAPE: (3835, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (826, 13)
# LAP 110 TIME -> 0:0:7
#
# 111 RUNNING FOR: AML
# DAILY SHAPE BEFORE: (253, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:55.311189
# Getting DAILY prices for:AML
# DAILY FINAL SHAPE: (254, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (52, 13)
# LAP 111 TIME -> 0:0:7
#
# 112 RUNNING FOR: AVST
# DAILY SHAPE BEFORE: (355, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:20:58.318237
# Getting DAILY prices for:AVST
# DAILY FINAL SHAPE: (356, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (73, 13)
# LAP 112 TIME -> 0:0:3
#
# 113 RUNNING FOR: AGT
# DAILY SHAPE BEFORE: (30, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:01.307652
# Getting DAILY prices for:AGT
# DAILY FINAL SHAPE: (31, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (14, 13)
# LAP 113 TIME -> 0:0:2
#
# 114 RUNNING FOR: BAB
# DAILY SHAPE BEFORE: (4617, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:03.586241
# Getting DAILY prices for:BAB
# DAILY FINAL SHAPE: (4618, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1034, 13)
# LAP 114 TIME -> 0:0:2
#
# 115 RUNNING FOR: BGFD
# DAILY SHAPE BEFORE: (2910, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:12.009874
# Getting DAILY prices for:BGFD
# DAILY FINAL SHAPE: (2911, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (610, 13)
# LAP 115 TIME -> 0:0:8
#
# 116 RUNNING FOR: BAKK
# DAILY SHAPE BEFORE: (474, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:17.937674
# Getting DAILY prices for:BAKK
# DAILY FINAL SHAPE: (474, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (98, 13)
# LAP 116 TIME -> 0:0:5
#
# 117 RUNNING FOR: BBY
# DAILY SHAPE BEFORE: (5084, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:20.696708
# Getting DAILY prices for:BBY
# DAILY FINAL SHAPE: (5086, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 117 TIME -> 0:0:2
#
# 118 RUNNING FOR: BNKR
# DAILY SHAPE BEFORE: (2945, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:29.175062
# Getting DAILY prices for:BNKR
# DAILY FINAL SHAPE: (2946, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 118 TIME -> 0:0:8
#
# 119 RUNNING FOR: BAG
# DAILY SHAPE BEFORE: (5019, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:34.859818
# Getting DAILY prices for:BAG
# DAILY FINAL SHAPE: (5020, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 119 TIME -> 0:0:5
#
# 120 RUNNING FOR: BBA
# DAILY SHAPE BEFORE: (5078, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:42.878145
# Getting DAILY prices for:BBA
# DAILY FINAL SHAPE: (5079, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 120 TIME -> 0:0:8
#
# 121 RUNNING FOR: BBGI
# DAILY SHAPE BEFORE: (1901, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:50.845582
# Getting DAILY prices for:BBGI
# DAILY FINAL SHAPE: (1902, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (401, 13)
# LAP 121 TIME -> 0:0:7
#
# 122 RUNNING FOR: BCA
# DAILY SHAPE BEFORE: (1160, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:55.611595
# Getting DAILY prices for:BCA
# DAILY FINAL SHAPE: (1161, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (246, 13)
# LAP 122 TIME -> 0:0:4
#
# 123 RUNNING FOR: BGEO
# DAILY SHAPE BEFORE: (2954, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:21:59.499794
# Getting DAILY prices for:BGEO
# DAILY FINAL SHAPE: (2956, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (618, 13)
# LAP 123 TIME -> 0:0:3
#
# 124 RUNNING FOR: BEZ
# DAILY SHAPE BEFORE: (4205, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:05.367743
# Getting DAILY prices for:BEZ
# DAILY FINAL SHAPE: (4206, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (882, 13)
# LAP 124 TIME -> 0:0:5
#
# 125 RUNNING FOR: AJB
# DAILY SHAPE BEFORE: (207, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:12.513130
# Getting DAILY prices for:AJB
# DAILY FINAL SHAPE: (208, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (43, 13)
# LAP 125 TIME -> 0:0:7
#
# 126 RUNNING FOR: BWY
# DAILY SHAPE BEFORE: (4435, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:15.385179
# Getting DAILY prices for:BWY
# DAILY FINAL SHAPE: (4436, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1017, 13)
# LAP 126 TIME -> 0:0:2
#
# 127 RUNNING FOR: BYG
# DAILY SHAPE BEFORE: (4705, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:22.876429
# Getting DAILY prices for:BYG
# DAILY FINAL SHAPE: (4706, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1012, 13)
# LAP 127 TIME -> 0:0:7
#
# 128 RUNNING FOR: BME
# DAILY SHAPE BEFORE: (1345, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:30.834238
# Getting DAILY prices for:BME
# DAILY FINAL SHAPE: (1346, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (277, 13)
# LAP 128 TIME -> 0:0:7
#
# 129 RUNNING FOR: BRSC
# DAILY SHAPE BEFORE: (709, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:34.886924
# Getting DAILY prices for:BRSC
# DAILY FINAL SHAPE: (710, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (158, 13)
# LAP 129 TIME -> 0:0:4
#
# 130 RUNNING FOR: BGSC
# DAILY SHAPE BEFORE: (2938, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:38.329050
# Getting DAILY prices for:BGSC
# DAILY FINAL SHAPE: (2940, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 130 TIME -> 0:0:3
#
# 131 RUNNING FOR: BOY
# DAILY SHAPE BEFORE: (5072, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:44.212334
# Getting DAILY prices for:BOY
# DAILY FINAL SHAPE: (5073, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 131 TIME -> 0:0:5
#
# 132 RUNNING FOR: BVS
# DAILY SHAPE BEFORE: (4963, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:22:52.525367
# Getting DAILY prices for:BVS
# DAILY FINAL SHAPE: (4964, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1046, 13)
# LAP 132 TIME -> 0:0:8
#
# 133 RUNNING FOR: BTEM
# DAILY SHAPE BEFORE: (2879, 8)
# _st_date: 2019-06-28 00:00:00
# _en_date: 2019-09-30 08:23:00.861262
# Getting DAILY prices for:BTEM
# ERROR - CONTINUE:list index out of range
# DAILY FINAL SHAPE: (2879, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (597, 13)
# LAP 133 TIME -> 0:0:8
#
# 134 RUNNING FOR: BVIC
# DAILY SHAPE BEFORE: (3487, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:06.792612
# Getting DAILY prices for:BVIC
# DAILY FINAL SHAPE: (3488, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (721, 13)
# LAP 134 TIME -> 0:0:5
#
# 135 RUNNING FOR: CNE
# DAILY SHAPE BEFORE: (5094, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:13.168591
# Getting DAILY prices for:CNE
# DAILY FINAL SHAPE: (5096, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 135 TIME -> 0:0:6
#
# 136 RUNNING FOR: CLDN
# DAILY SHAPE BEFORE: (2918, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:21.319725
# Getting DAILY prices for:CLDN
# DAILY FINAL SHAPE: (2919, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (611, 13)
# LAP 136 TIME -> 0:0:8
#
# 137 RUNNING FOR: CAPC
# DAILY SHAPE BEFORE: (2377, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:27.221465
# Getting DAILY prices for:CAPC
# DAILY FINAL SHAPE: (2378, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (490, 13)
# LAP 137 TIME -> 0:0:5
#
# 138 RUNNING FOR: CPI
# DAILY SHAPE BEFORE: (5091, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:32.725763
# Getting DAILY prices for:CPI
# DAILY FINAL SHAPE: (5092, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1063, 13)
# LAP 138 TIME -> 0:0:5
#
# 139 RUNNING FOR: CARD
# DAILY SHAPE BEFORE: (1364, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:40.181896
# Getting DAILY prices for:CARD
# DAILY FINAL SHAPE: (1365, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (281, 13)
# LAP 139 TIME -> 0:0:7
#
# 140 RUNNING FOR: CEY
# DAILY SHAPE BEFORE: (4452, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:43.777554
# Getting DAILY prices for:CEY
# DAILY FINAL SHAPE: (4453, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (928, 13)
# LAP 140 TIME -> 0:0:3
#
# 141 RUNNING FOR: CCFS
# DAILY SHAPE BEFORE: (507, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:50.714739
# Getting DAILY prices for:CCFS
# DAILY FINAL SHAPE: (507, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (105, 13)
# LAP 141 TIME -> 0:0:6
#
# 142 RUNNING FOR: CINE
# DAILY SHAPE BEFORE: (3105, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:53.373852
# Getting DAILY prices for:CINE
# DAILY FINAL SHAPE: (3107, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (650, 13)
# LAP 142 TIME -> 0:0:2
#
# 143 RUNNING FOR: CTY
# DAILY SHAPE BEFORE: (2951, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:23:58.871483
# Getting DAILY prices for:CTY
# DAILY FINAL SHAPE: (2952, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 143 TIME -> 0:0:5
#
# 144 RUNNING FOR: CKN
# DAILY SHAPE BEFORE: (4894, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:04.373155
# Getting DAILY prices for:CKN
# DAILY FINAL SHAPE: (4895, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1034, 13)
# LAP 144 TIME -> 0:0:5
#
# 145 RUNNING FOR: CBG
# DAILY SHAPE BEFORE: (4971, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:12.653086
# Getting DAILY prices for:CBG
# DAILY FINAL SHAPE: (4972, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 145 TIME -> 0:0:8
#
# 146 RUNNING FOR: CLI
# DAILY SHAPE BEFORE: (5045, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:21.964315
# Getting DAILY prices for:CLI
# DAILY FINAL SHAPE: (5046, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1051, 13)
# LAP 146 TIME -> 0:0:9
#
# 147 RUNNING FOR: COA
# DAILY SHAPE BEFORE: (3579, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:29.915134
# Getting DAILY prices for:COA
# DAILY FINAL SHAPE: (3580, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (955, 13)
# LAP 147 TIME -> 0:0:7
#
# 148 RUNNING FOR: COB
# DAILY SHAPE BEFORE: (5077, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:36.210695
# Getting DAILY prices for:COB
# DAILY FINAL SHAPE: (5079, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 148 TIME -> 0:0:6
#
# 149 RUNNING FOR: CCC
# DAILY SHAPE BEFORE: (5086, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:44.470767
# Getting DAILY prices for:CCC
# DAILY FINAL SHAPE: (5087, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 149 TIME -> 0:0:8
#
# 150 RUNNING FOR: GLO
# DAILY SHAPE BEFORE: (477, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:52.429579
# Getting DAILY prices for:GLO
# DAILY FINAL SHAPE: (477, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (99, 13)
# LAP 150 TIME -> 0:0:7
#
# 151 RUNNING FOR: CTEC
# DAILY SHAPE BEFORE: (742, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:55.241234
# Getting DAILY prices for:CTEC
# DAILY FINAL SHAPE: (744, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (154, 13)
# LAP 151 TIME -> 0:0:2
#
# 152 RUNNING FOR: CSP
# DAILY SHAPE BEFORE: (1962, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:24:59.047559
# Getting DAILY prices for:CSP
# DAILY FINAL SHAPE: (1963, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (409, 13)
# LAP 152 TIME -> 0:0:3
#
# 153 RUNNING FOR: CWK
# DAILY SHAPE BEFORE: (5044, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:03.719127
# Getting DAILY prices for:CWK
# DAILY FINAL SHAPE: (5045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 153 TIME -> 0:0:4
#
# 154 RUNNING FOR: CRST
# DAILY SHAPE BEFORE: (1678, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:12.623128
# Getting DAILY prices for:CRST
# DAILY FINAL SHAPE: (1680, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (346, 13)
# LAP 154 TIME -> 0:0:8
#
# 155 RUNNING FOR: CYBG
# DAILY SHAPE BEFORE: (927, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:17.394624
# Getting DAILY prices for:CYBG
# DAILY FINAL SHAPE: (928, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (191, 13)
# LAP 155 TIME -> 0:0:4
#
# 156 RUNNING FOR: DJAN
# DAILY SHAPE BEFORE: (4838, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:21.064960
# Getting DAILY prices for:DJAN
# DAILY FINAL SHAPE: (4839, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1051, 13)
# LAP 156 TIME -> 0:0:3
#
# 157 RUNNING FOR: DPH
# DAILY SHAPE BEFORE: (4412, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:29.511304
# Getting DAILY prices for:DPH
# DAILY FINAL SHAPE: (4413, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (973, 13)
# LAP 157 TIME -> 0:0:8
#
# 158 RUNNING FOR: DLN
# DAILY SHAPE BEFORE: (5030, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:37.550620
# Getting DAILY prices for:DLN
# DAILY FINAL SHAPE: (5031, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 158 TIME -> 0:0:8
#
# 159 RUNNING FOR: DPLM
# DAILY SHAPE BEFORE: (5036, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:46.392000
# Getting DAILY prices for:DPLM
# DAILY FINAL SHAPE: (5037, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 159 TIME -> 0:0:8
#
# 160 RUNNING FOR: DLG
# DAILY SHAPE BEFORE: (1765, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:25:55.480400
# Getting DAILY prices for:DLG
# DAILY FINAL SHAPE: (1766, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (364, 13)
# LAP 160 TIME -> 0:0:9
#
# 161 RUNNING FOR: DC
# DAILY SHAPE BEFORE: (2480, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:01.096917
# Getting DAILY prices for:DC
# DAILY FINAL SHAPE: (2481, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (522, 13)
# LAP 161 TIME -> 0:0:5
#
# 162 RUNNING FOR: DOM
# DAILY SHAPE BEFORE: (5001, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:08.031147
# Getting DAILY prices for:DOM
# DAILY FINAL SHAPE: (5002, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1036, 13)
# LAP 162 TIME -> 0:0:6
#
# 163 RUNNING FOR: DRX
# DAILY SHAPE BEFORE: (3482, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:19.281068
# Getting DAILY prices for:DRX
# DAILY FINAL SHAPE: (3483, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (720, 13)
# LAP 163 TIME -> 0:0:11
#
# 164 RUNNING FOR: DNLM
# DAILY SHAPE BEFORE: (3270, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:26.870665
# Getting DAILY prices for:DNLM
# DAILY FINAL SHAPE: (3271, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (676, 13)
# LAP 164 TIME -> 0:0:7
#
# 165 RUNNING FOR: EZJ
# DAILY SHAPE BEFORE: (4740, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:33.597867
# Getting DAILY prices for:EZJ
# DAILY FINAL SHAPE: (4741, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (986, 13)
# LAP 165 TIME -> 0:0:6
#
# 166 RUNNING FOR: EDIN
# DAILY SHAPE BEFORE: (2906, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:41.902636
# Getting DAILY prices for:EDIN
# DAILY FINAL SHAPE: (2907, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (607, 13)
# LAP 166 TIME -> 0:0:8
#
# 167 RUNNING FOR: EIG
# DAILY SHAPE BEFORE: (3257, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:48.695438
# Getting DAILY prices for:EIG
# DAILY FINAL SHAPE: (3258, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (678, 13)
# LAP 167 TIME -> 0:0:6
#
# 168 RUNNING FOR: ECM
# DAILY SHAPE BEFORE: (5039, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:26:54.733531
# Getting DAILY prices for:ECM
# DAILY FINAL SHAPE: (5040, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 168 TIME -> 0:0:6
#
# 169 RUNNING FOR: ELM
# DAILY SHAPE BEFORE: (5087, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:02.721312
# Getting DAILY prices for:ELM
# DAILY FINAL SHAPE: (5088, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 169 TIME -> 0:0:7
#
# 170 RUNNING FOR: ENOG
# DAILY SHAPE BEFORE: (390, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:12.031424
# Getting DAILY prices for:ENOG
# DAILY FINAL SHAPE: (391, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (81, 13)
# LAP 170 TIME -> 0:0:9
#
# 171 RUNNING FOR: ETO
# DAILY SHAPE BEFORE: (2663, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:16.101821
# Getting DAILY prices for:ETO
# DAILY FINAL SHAPE: (2664, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (612, 13)
# LAP 171 TIME -> 0:0:4
#
# 172 RUNNING FOR: EQN
# DAILY SHAPE BEFORE: (995, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:22.447698
# Getting DAILY prices for:EQN
# DAILY FINAL SHAPE: (997, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (206, 13)
# LAP 172 TIME -> 0:0:6
#
# 173 RUNNING FOR: ESNT
# DAILY SHAPE BEFORE: (3621, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:26.618930
# Getting DAILY prices for:ESNT
# DAILY FINAL SHAPE: (3622, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (747, 13)
# LAP 173 TIME -> 0:0:4
#
# 174 RUNNING FOR: ERM
# DAILY SHAPE BEFORE: (4715, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:34.018974
# Getting DAILY prices for:ERM
# DAILY FINAL SHAPE: (4716, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1046, 13)
# LAP 174 TIME -> 0:0:7
#
# 175 RUNNING FOR: FCPT
# DAILY SHAPE BEFORE: (2884, 8)
# _st_date: 2019-06-28 00:00:00
# _en_date: 2019-09-30 08:27:43.030609
# Getting DAILY prices for:FCPT
# ERROR - CONTINUE:list index out of range
# DAILY FINAL SHAPE: (2884, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (598, 13)
# LAP 175 TIME -> 0:0:9
#
# 176 RUNNING FOR: FDM
# DAILY SHAPE BEFORE: (1335, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:49.556689
# Getting DAILY prices for:FDM
# DAILY FINAL SHAPE: (1336, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (276, 13)
# LAP 176 TIME -> 0:0:6
#
# 177 RUNNING FOR: FXPO
# DAILY SHAPE BEFORE: (3055, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:27:54.550963
# Getting DAILY prices for:FXPO
# DAILY FINAL SHAPE: (3056, 13)
# ...
# DAILY FINAL SHAPE: (5081, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 292 TIME -> 0:0:4
#
# 293 RUNNING FOR: RMG
# DAILY SHAPE BEFORE: (1512, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:26.583148
# Getting DAILY prices for:RMG
# DAILY FINAL SHAPE: (1513, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (313, 13)
# LAP 293 TIME -> 0:0:8
#
# 294 RUNNING FOR: SBRE
# DAILY SHAPE BEFORE: (460, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:30.863348
# Getting DAILY prices for:SBRE
# DAILY FINAL SHAPE: (461, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (96, 13)
# LAP 294 TIME -> 0:0:4
#
# 295 RUNNING FOR: SAFE
# DAILY SHAPE BEFORE: (3170, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:34.346394
# Getting DAILY prices for:SAFE
# DAILY FINAL SHAPE: (3171, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (656, 13)
# LAP 295 TIME -> 0:0:3
#
# 296 RUNNING FOR: SNN
# DAILY SHAPE BEFORE: (1132, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:40.428489
# Getting DAILY prices for:SNN
# DAILY FINAL SHAPE: (1133, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (235, 13)
# LAP 296 TIME -> 0:0:6
#
# 297 RUNNING FOR: SVS
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:44.520666
# Getting DAILY prices for:SVS
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 297 TIME -> 0:0:4
#
# 298 RUNNING FOR: SDP
# DAILY SHAPE BEFORE: (2907, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:52.830331
# Getting DAILY prices for:SDP
# DAILY FINAL SHAPE: (2908, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (608, 13)
# LAP 298 TIME -> 0:0:8
#
# 299 RUNNING FOR: SOI
# DAILY SHAPE BEFORE: (2897, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:39:59.044450
# Getting DAILY prices for:SOI
# DAILY FINAL SHAPE: (2898, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (604, 13)
# LAP 299 TIME -> 0:0:6
#
# 300 RUNNING FOR: SCIN
# DAILY SHAPE BEFORE: (2910, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:05.381271
# Getting DAILY prices for:SCIN
# DAILY FINAL SHAPE: (2911, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (609, 13)
# LAP 300 TIME -> 0:0:6
#
# 301 RUNNING FOR: SNR
# DAILY SHAPE BEFORE: (4572, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:10.722141
# Getting DAILY prices for:SNR
# DAILY FINAL SHAPE: (4573, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1033, 13)
# LAP 301 TIME -> 0:0:5
#
# 302 RUNNING FOR: SEQI
# DAILY SHAPE BEFORE: (1096, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:17.715749
# Getting DAILY prices for:SEQI
# DAILY FINAL SHAPE: (1097, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (233, 13)
# LAP 302 TIME -> 0:0:6
#
# 303 RUNNING FOR: SRP
# DAILY SHAPE BEFORE: (5080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:21.041624
# Getting DAILY prices for:SRP
# DAILY FINAL SHAPE: (5081, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 303 TIME -> 0:0:3
#
# 304 RUNNING FOR: SHB
# DAILY SHAPE BEFORE: (4570, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:28.946739
# Getting DAILY prices for:SHB
# DAILY FINAL SHAPE: (4571, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1037, 13)
# LAP 304 TIME -> 0:0:7
#
# 305 RUNNING FOR: SHI
# DAILY SHAPE BEFORE: (4974, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:36.272158
# Getting DAILY prices for:SHI
# DAILY FINAL SHAPE: (4975, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1047, 13)
# LAP 305 TIME -> 0:0:7
#
# 306 RUNNING FOR: SXX
# DAILY SHAPE BEFORE: (2974, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:44.371925
# Getting DAILY prices for:SXX
# DAILY FINAL SHAPE: (2975, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (677, 13)
# LAP 306 TIME -> 0:0:8
#
# 307 RUNNING FOR: SRE
# DAILY SHAPE BEFORE: (2740, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:49.767451
# Getting DAILY prices for:SRE
# DAILY FINAL SHAPE: (2741, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (642, 13)
# LAP 307 TIME -> 0:0:5
#
# 308 RUNNING FOR: SSON
# DAILY SHAPE BEFORE: (176, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:55.227700
# Getting DAILY prices for:SSON
# DAILY FINAL SHAPE: (177, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (44, 13)
# LAP 308 TIME -> 0:0:5
#
# 309 RUNNING FOR: SCT
# DAILY SHAPE BEFORE: (982, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:40:57.749278
# Getting DAILY prices for:SCT
# DAILY FINAL SHAPE: (983, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (203, 13)
# LAP 309 TIME -> 0:0:2
#
# 310 RUNNING FOR: SOPH
# DAILY SHAPE BEFORE: (1080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:01.230560
# Getting DAILY prices for:SOPH
# DAILY FINAL SHAPE: (1082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (224, 13)
# LAP 310 TIME -> 0:0:3
#
# 311 RUNNING FOR: SXS
# DAILY SHAPE BEFORE: (4974, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:04.653191
# Getting DAILY prices for:SXS
# DAILY FINAL SHAPE: (4975, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1050, 13)
# LAP 311 TIME -> 0:0:3
#
# 312 RUNNING FOR: SPT
# DAILY SHAPE BEFORE: (5082, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:12.535060
# Getting DAILY prices for:SPT
# DAILY FINAL SHAPE: (5083, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 312 TIME -> 0:0:7
#
# 313 RUNNING FOR: SPD
# DAILY SHAPE BEFORE: (3182, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:21.082364
# Getting DAILY prices for:SPD
# DAILY FINAL SHAPE: (3183, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (657, 13)
# LAP 313 TIME -> 0:0:8
#
# 314 RUNNING FOR: SSPG
# DAILY SHAPE BEFORE: (1325, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:27.925992
# Getting DAILY prices for:SSPG
# DAILY FINAL SHAPE: (1327, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (274, 13)
# LAP 314 TIME -> 0:0:6
#
# 315 RUNNING FOR: SMP
# DAILY SHAPE BEFORE: (4944, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:31.785525
# Getting DAILY prices for:SMP
# DAILY FINAL SHAPE: (4945, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1046, 13)
# LAP 315 TIME -> 0:0:3
#
# 316 RUNNING FOR: SGC
# DAILY SHAPE BEFORE: (4733, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:39.892047
# Getting DAILY prices for:SGC
# DAILY FINAL SHAPE: (4734, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (987, 13)
# LAP 316 TIME -> 0:0:8
#
# 317 RUNNING FOR: SYNC
# DAILY SHAPE BEFORE: (1685, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:47.810483
# Getting DAILY prices for:SYNC
# DAILY FINAL SHAPE: (1687, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (357, 13)
# LAP 317 TIME -> 0:0:7
#
# 318 RUNNING FOR: SYNT
# DAILY SHAPE BEFORE: (5080, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:41:52.238904
# Getting DAILY prices for:SYNT
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 318 TIME -> 0:0:4
#
# 319 RUNNING FOR: TALK
# DAILY SHAPE BEFORE: (2406, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:01.538729
# Getting DAILY prices for:TALK
# DAILY FINAL SHAPE: (2407, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (497, 13)
# LAP 319 TIME -> 0:0:9
#
# 320 RUNNING FOR: TATE
# DAILY SHAPE BEFORE: (5057, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:07.897148
# Getting DAILY prices for:TATE
# DAILY FINAL SHAPE: (5059, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 320 TIME -> 0:0:6
#
# 321 RUNNING FOR: TBCG
# DAILY SHAPE BEFORE: (786, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:17.829452
# Getting DAILY prices for:TBCG
# DAILY FINAL SHAPE: (788, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (165, 13)
# LAP 321 TIME -> 0:0:9
#
# 322 RUNNING FOR: TEP
# DAILY SHAPE BEFORE: (4831, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:21.843318
# Getting DAILY prices for:TEP
# DAILY FINAL SHAPE: (4832, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1003, 13)
# LAP 322 TIME -> 0:0:3
#
# 323 RUNNING FOR: TMPL
# DAILY SHAPE BEFORE: (2907, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:30.090674
# Getting DAILY prices for:TMPL
# DAILY FINAL SHAPE: (2908, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (608, 13)
# LAP 323 TIME -> 0:0:8
#
# 324 RUNNING FOR: TEM
# DAILY SHAPE BEFORE: (2813, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:35.705374
# Getting DAILY prices for:TEM
# DAILY FINAL SHAPE: (2814, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (609, 13)
# LAP 324 TIME -> 0:0:5
#
# 325 RUNNING FOR: TIFS
# DAILY SHAPE BEFORE: (490, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:41.444706
# Getting DAILY prices for:TIFS
# DAILY FINAL SHAPE: (491, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (101, 13)
# LAP 325 TIME -> 0:0:5
#
# 326 RUNNING FOR: TCAP
# DAILY SHAPE BEFORE: (4699, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:44.642448
# Getting DAILY prices for:TCAP
# DAILY FINAL SHAPE: (4700, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (978, 13)
# LAP 326 TIME -> 0:0:3
#
# 327 RUNNING FOR: TRN
# DAILY SHAPE BEFORE: (69, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:52.434214
# Getting DAILY prices for:TRN
# DAILY FINAL SHAPE: (70, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (14, 13)
# LAP 327 TIME -> 0:0:7
#
# 328 RUNNING FOR: TRY
# DAILY SHAPE BEFORE: (2906, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:42:55.254441
# Getting DAILY prices for:TRY
# DAILY FINAL SHAPE: (2907, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (607, 13)
# LAP 328 TIME -> 0:0:2
#
# 329 RUNNING FOR: TPK
# DAILY SHAPE BEFORE: (5083, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:01.310616
# Getting DAILY prices for:TPK
# DAILY FINAL SHAPE: (5084, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 329 TIME -> 0:0:6
#
# 330 RUNNING FOR: BBOX
# DAILY SHAPE BEFORE: (1407, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:09.527412
# Getting DAILY prices for:BBOX
# DAILY FINAL SHAPE: (1408, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (298, 13)
# LAP 330 TIME -> 0:0:8
#
# 331 RUNNING FOR: TLW
# DAILY SHAPE BEFORE: (4976, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:13.810962
# Getting DAILY prices for:TLW
# DAILY FINAL SHAPE: (4977, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 331 TIME -> 0:0:4
#
# 332 RUNNING FOR: UDG
# DAILY SHAPE BEFORE: (4360, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:22.191967
# Getting DAILY prices for:UDG
# DAILY FINAL SHAPE: (4361, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1031, 13)
# LAP 332 TIME -> 0:0:8
#
# 333 RUNNING FOR: UKCM
# DAILY SHAPE BEFORE: (2907, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:30.129321
# Getting DAILY prices for:UKCM
# DAILY FINAL SHAPE: (2909, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (608, 13)
# LAP 333 TIME -> 0:0:7
#
# 334 RUNNING FOR: ULE
# DAILY SHAPE BEFORE: (4950, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:36.004246
# Getting DAILY prices for:ULE
# DAILY FINAL SHAPE: (4951, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1050, 13)
# LAP 334 TIME -> 0:0:5
#
# 335 RUNNING FOR: UTG
# DAILY SHAPE BEFORE: (5044, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:44.227853
# Getting DAILY prices for:UTG
# DAILY FINAL SHAPE: (5045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1053, 13)
# LAP 335 TIME -> 0:0:8
#
# 336 RUNNING FOR: VSVS
# DAILY SHAPE BEFORE: (5087, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:43:52.707882
# Getting DAILY prices for:VSVS
# DAILY FINAL SHAPE: (5088, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1052, 13)
# LAP 336 TIME -> 0:0:8
#
# 337 RUNNING FOR: VCT
# DAILY SHAPE BEFORE: (4456, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:01.380393
# Getting DAILY prices for:VCT
# DAILY FINAL SHAPE: (4457, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1018, 13)
# LAP 337 TIME -> 0:0:8
#
# 338 RUNNING FOR: VEIL
# DAILY SHAPE BEFORE: (759, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:09.379837
# Getting DAILY prices for:VEIL
# DAILY FINAL SHAPE: (760, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (164, 13)
# LAP 338 TIME -> 0:0:8
#
# 339 RUNNING FOR: VOF
# DAILY SHAPE BEFORE: (2940, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:13.416098
# Getting DAILY prices for:VOF
# DAILY FINAL SHAPE: (2941, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (613, 13)
# LAP 339 TIME -> 0:0:4
#
# 340 RUNNING FOR: VVO
# DAILY SHAPE BEFORE: (358, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:19.901893
# Getting DAILY prices for:VVO
# DAILY FINAL SHAPE: (359, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (74, 13)
# LAP 340 TIME -> 0:0:6
#
# 341 RUNNING FOR: WOSG
# DAILY SHAPE BEFORE: (84, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:22.565370
# Getting DAILY prices for:WOSG
# DAILY FINAL SHAPE: (85, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (17, 13)
# LAP 341 TIME -> 0:0:2
#
# 342 RUNNING FOR: WEIR
# DAILY SHAPE BEFORE: (4972, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:25.200648
# Getting DAILY prices for:WEIR
# DAILY FINAL SHAPE: (4973, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1051, 13)
# LAP 342 TIME -> 0:0:2
#
# 343 RUNNING FOR: JDW
# DAILY SHAPE BEFORE: (4961, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:33.039353
# Getting DAILY prices for:JDW
# DAILY FINAL SHAPE: (4962, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1048, 13)
# LAP 343 TIME -> 0:0:7
#
# 344 RUNNING FOR: SMWH
# DAILY SHAPE BEFORE: (3315, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:40.640689
# Getting DAILY prices for:SMWH
# DAILY FINAL SHAPE: (3316, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (686, 13)
# LAP 344 TIME -> 0:0:7
#
# 345 RUNNING FOR: WMH
# DAILY SHAPE BEFORE: (4349, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:46.730560
# Getting DAILY prices for:WMH
# DAILY FINAL SHAPE: (4350, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (902, 13)
# LAP 345 TIME -> 0:0:6
#
# 346 RUNNING FOR: WTAN
# DAILY SHAPE BEFORE: (2949, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:53.738629
# Getting DAILY prices for:WTAN
# DAILY FINAL SHAPE: (2950, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
# LAP 346 TIME -> 0:0:7
#
# 347 RUNNING FOR: WIZZ
# DAILY SHAPE BEFORE: (1165, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:44:59.464235
# Getting DAILY prices for:WIZZ
# DAILY FINAL SHAPE: (1166, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (240, 13)
# LAP 347 TIME -> 0:0:5
#
# 348 RUNNING FOR: WG
# DAILY SHAPE BEFORE: (4378, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:45:03.508615
# Getting DAILY prices for:WG
# DAILY FINAL SHAPE: (4379, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (905, 13)
# LAP 348 TIME -> 0:0:4
#
# 349 RUNNING FOR: WKP
# DAILY SHAPE BEFORE: (3896, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:45:10.584765
# Getting DAILY prices for:WKP
# DAILY FINAL SHAPE: (3897, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (916, 13)
# LAP 349 TIME -> 0:0:7
#
# 350 RUNNING FOR: WWH
# DAILY SHAPE BEFORE: (2952, 8)
# _st_date: 2019-09-27 00:00:00
# _en_date: 2019-09-30 08:45:17.370074
# Getting DAILY prices for:WWH
# DAILY FINAL SHAPE: (2953, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (614, 13)
#
#
#
# TOTAL ELAPSED TIME -> 0:37:51
#
# ERROR COUNT: 1
#     ERRORS -> [AttributeError("'bool' object has no attribute 'drop_duplicates'")]

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'all_hist_prices_d.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'all_hist_prices_d_TMP.h5',src_fldr_pth + r'all_hist_prices_d.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'all_hist_prices_d_TMP.h5',src_fldr_pth + r'all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d.h5
#
# SUCCESSFULLY RENAMED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d_TMP.h5 TO C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d.h5

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'all_hist_prices_w.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'all_hist_prices_w_TMP.h5',src_fldr_pth + r'all_hist_prices_w.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'all_hist_prices_w_TMP.h5',src_fldr_pth + r'all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w.h5
#
# SUCCESSFULLY RENAMED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w_TMP.h5 TO C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w.h5

# %% [markdown]
# # Exporting the FTSE ticker

# %%
#Export the ftse list
path = "C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\"
tick_ftse.to_csv(path_or_buf=path + "tick_ftse.csv")

# %%
#End the program
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Robert\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
