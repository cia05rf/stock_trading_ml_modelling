# %% [markdown]
# # Create indicators and find signals
# This code is designed to calculate the below indicators:
# - EMA
# - MACD
# - MACD mins and maxs
# - MACD positive turns
# - Support price
# - Target price
# - Prev week volume Vs 8 week average volume
#
# We will also bring in if the target price was hit within 8 weeks for ML training and validation.
#
# Each share has it's own trading pattern so we will train a different model for each share but use the same set of features, just the hyper paramenters will be tuned differenty.

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import tables
import os
import datetime as dt

# %%
#Clean column names
def clean_col_name(str_in):
    str_out = str_in.lower() #Change all to lower case
    str_out = re.sub(r'.*\.','',str_out) #Remove everything before a .
    str_out = re.sub(r' ','_',str_out) #Replace spaces with _
    str_out = re.sub(r'_?&_?','_and_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'_?@_?','_at_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'[^0-9a-z_]','',str_out) #Remove all non allowed characters
    str_out = re.sub(r'^_','',str_out) #Remove leading _
    return str_out

# %%
class process_time:
    def __init__(self,name:str = ''):
        self.st_time = dt.datetime.now()
        self.lap_li = []
        self.en_time = None
        self.name = name
    def calc_el_time(self,st_time,en_time):
        diff_time = en_time - st_time
        duration_in_s = diff_time.total_seconds()
        hours = int(divmod(duration_in_s, 3600)[0])
        duration_in_s += -(hours * 3600)
        minutes = int(divmod(duration_in_s, 60)[0])
        duration_in_s += -(minutes * 60)
        seconds = int(duration_in_s)
        return [hours,minutes,seconds]
    def lap(self):
        self.lap_li.append(dt.datetime.now())
    def end(self):
        self.en_time = dt.datetime.now()
        lap_time = self.calc_el_time(self.st_time,self.en_time)
        if self.name != '':
            print('TOTAL ELAPSED TIME OF {} -> {}:{}:{}'.format(self.name,lap_time[0],lap_time[1],lap_time[2]))
        else:
            print('TOTAL ELAPSED TIME -> {}:{}:{}'.format(lap_time[0],lap_time[1],lap_time[2]))
    def show_lap_times(self):
        tmp_count = 0
        for lap in self.lap_li:
            tmp_count += 1
            lap_time = self.calc_el_time(self.st_time,lap)
            print('LAP {} TIME -> {}:{}:{}'.format(tmp_count,lap_time[0],lap_time[1],lap_time[2]))
    def show_latest_lap_time(self):
        if len(self.lap_li) == 0:
            return
        elif len(self.lap_li) < 2:
            lap_time = self.calc_el_time(self.st_time,self.lap_li[-1])
        else:
            lap_time = self.calc_el_time(self.lap_li[-2],self.lap_li[-1])
        print('LAP {} TIME -> {}:{}:{}'.format(len(self.lap_li),lap_time[0],lap_time[1],lap_time[2]))

# %%
#Import the ftse list
path = "C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\"
tick_ftse = pd.read_csv(path + "tick_ftse.csv")
tick_ftse = tick_ftse.iloc[:,1:]
for col in tick_ftse:
    tick_ftse.rename(columns={col:clean_col_name(col)},inplace=True)
tick_ftse.head()
# Out:
#               company ticker    index
# 0                  3I    III  FTSE100
# 1       ADMIRAL GROUP    ADM  FTSE100
# 2  ANGLO AMERICAN PLC    AAL  FTSE100
# 3         ANTOFAGASTA   ANTO  FTSE100
# 4       ASHTEAD GROUP    AHT  FTSE100

# %%
#Import and combine prices files
# df_prices_w = pd.read_csv(path + tick_ftse["ticker"][1] + "_hist_prices_w.csv")
df_prices_w = pd.read_hdf(path + "all_hist_prices_w.h5")
#Rename columns
for col in df_prices_w:
    df_prices_w.rename(columns={col:clean_col_name(col)},inplace=True)
#Drop unwanted columns
try:
    df_prices_w.drop(columns=["unnamed_0","index"],inplace=True)
except Exception as e:
    print(e)
#Reformat columns where neccessary
df_prices_w["date"] = df_prices_w["date"].astype("datetime64")
print(df_prices_w.shape)
print(df_prices_w.dtypes)
df_prices_w.head()
# Out:
# "['unnamed_0' 'index'] not found in axis"
# (257341, 13)
# ticker               object
# date         datetime64[ns]
# high                float64
# low                 float64
# volume              float64
# open                float64
# close               float64
# change              float64
# ema12               float64
# ema26               float64
# macd_line           float64
# signal              float64
# macd                float64
# dtype: object
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal  macd
# 0    NaN        NaN     NaN   NaN
# 1    NaN        NaN     NaN   NaN
# 2    NaN        NaN     NaN   NaN
# 3    NaN        NaN     NaN   NaN
# 4    NaN        NaN     NaN   NaN

# %%
#Get in-row price change
def calc_changes(df_in,var_col,prev_col):
    df_in["change"] = df_in[var_col] - df_in[prev_col]
    df_in["per_change"] = df_in["change"] / df_in[prev_col]
    return (df_in["change"],df_in["per_change"])

#Relabel signal to signal_line
df_prices_w.rename(columns={"signal":"signal_line"},inplace=True)
for col in df_prices_w:
    df_prices_w.rename(columns={col:col.lower()},inplace=True)
    
df_prices_w["change_price"],df_prices_w["per_change_price"] = calc_changes(df_prices_w[["close","open"]].copy(),"close","open")
df_prices_w.drop(columns=["change"],inplace=True)
df_prices_w.head()
# Out:
#   ticker       date    high    low      volume   open  close  ema12  ema26  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0    NaN    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0    NaN    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0    NaN    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    NaN    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    NaN    NaN
#
#    macd_line  signal_line  macd  change_price  per_change_price
# 0        NaN          NaN   NaN         -30.0         -0.030151
# 1        NaN          NaN   NaN         -43.5         -0.044961
# 2        NaN          NaN   NaN         -16.0         -0.017448
# 3        NaN          NaN   NaN          26.5          0.029742
# 4        NaN          NaN   NaN          50.0          0.054885

# %%
#Remove tickers with fewer than 34 entries as this is where the MACD can be calculated
print('START ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('START TICK COUNT -> {}'.format(tick_ftse.shape[0]))
for tick in tick_ftse.ticker:
    if df_prices_w[df_prices_w.ticker == tick].shape[0] < 34:
        #Remove from dataframe
        print('\nTOO FEW RECORDS FOR {}'.format(tick))
        df_prices_w = df_prices_w.loc[df_prices_w.ticker != tick]
        print('    NEW ROW COUNT -> {}'.format(df_prices_w.shape[0]))
        #Remove from tick_ftse
        tick_ftse = tick_ftse.loc[tick_ftse.ticker != tick]
        print('    NEW TICK COUNT -> {}'.format(tick_ftse.shape[0]))
print('\nEND ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('END TICK COUNT -> {}'.format(tick_ftse.shape[0]))
# Out:
# START ROW COUNT -> 257341
# START TICK COUNT -> 350
#
# TOO FEW RECORDS FOR FLTR
#     NEW ROW COUNT -> 257329
#     NEW TICK COUNT -> 349
#
# TOO FEW RECORDS FOR AGT
#     NEW ROW COUNT -> 257320
#     NEW TICK COUNT -> 348
#
# TOO FEW RECORDS FOR NETW
#     NEW ROW COUNT -> 257300
#     NEW TICK COUNT -> 347
#
# END ROW COUNT -> 257300
# END TICK COUNT -> 347

# %% [markdown]
# # Create additional features, buy signals, and sell signals
# I am classifying a stock worth buying if it meets all the below criteria:
# - The target price (previous max) is hit within x (set as variable target_price_period) periods proceeding this period
# - The target price is an increase of x% (set as variable min_gain) over the proceeding day's open price
# - There is a drop in the closing price of less x% (set as variable max_drop) between this period and the x periods proceeding this period
#
# I am classifying the sell signals as:
# - The close price dips below the target price (previous max) x (set as variable target_price_period) periods proceeding this period
# - There is an increase in the closing price of less x% (set as variable max_drop) over the next x periods

# %%
#Define the variables
target_price_period = 12
period_high_volatility = 3
period_low_volatility = 1
min_gain = 0.1
max_drop = -0.05

# %%
#Programming note
#df.shift(1) looks 1 period into the past
#df.shift(-1) looks 1 period into the future

# %%
#Mark minimums and maximums
def flag_mins(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in > s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value > the previous value
        s_out += (s_in > s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value > the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out
def flag_maxs(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in < s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value < the previous value (if the previous value is not null)
        s_out += (s_in < s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value < the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out

# %%
#Calc vol as proportion of previous n-rows
def calc_prop_of_prev(s_in,periods:int = 4):
    s_cum = s_in.copy()
    for i in range(1,periods):
        s_cum += s_in.shift(i)
    return s_in / s_cum

# %%
#Mark points of macd positive entry
def pos_entry(s_in):
    return (s_in > s_in.shift(1)) & (s_in > 0) & (s_in.shift(1) < 0)
def neg_entry(s_in):
    return (s_in < s_in.shift(1)) & (s_in < 0) & (s_in.shift(1) > 0)

# %%
#Check if the target price is hit within the target_price_period
def target_hit_check(x,var_s,target_s,periods:int=12):
    check_s = False
    for i in range((x+1),(x+periods+1)):
        if (i >= 0) and (i < len(target_s)) and (target_s[x] <= var_s[i]):
            check_s = True
            break
    return check_s

# %%
def max_drop_check_b(ref_s,var_s,periods:int=12):
    lim_s = ref_s*(1+max_drop)
    check_s = lim_s == lim_s #Create an all true series
    for i in range(-(periods+1),-1):
        tmp_check_s = var_s.shift(i) >= lim_s #Treu if price is >= limit
        check_s = check_s & tmp_check_s
    return check_s

# %%
#Create a function for finding buy signals
def get_buys(df_in):
    tmp_df = df_in.copy()
    
    #Calc the target price
    tmp_df["target_price"] = tmp_df["open"].shift(-1) * (1+min_gain)
    
    #Check if the target price is hit within the target_price_period
    tmp_df["buy_target_check"] = [target_hit_check(x,tmp_df["close"],tmp_df["target_price"],target_price_period) for x in range(0,len(tmp_df))]
#     print("BUY_TARGET_CHECK COUNT:"+str(len(tmp_df[tmp_df["buy_target_check"]])))
    
    #min_gain check
    tmp_df["gain"] = tmp_df["prev_max_close"] - tmp_df["open"].shift(-1) #open price for the next period
    tmp_df["per_gain"] = tmp_df["gain"] / tmp_df["open"].shift(-1) #open price for the next period
    tmp_df["buy_gain_check"] = tmp_df["per_gain"] >= min_gain
    tmp_df.drop(columns=["gain","per_gain"],inplace=True)
#     tmp_df["buy_gain_check"] = True
#     print("BUY_GAIN_CHECK COUNT:"+str(len(tmp_df[tmp_df["buy_gain_check"]])))
    
    #Check if the sell price is hit within the target_price_period
#     tmp_df["buy_drop_check"] = max_drop_check_b(tmp_df["open"].shift(-1),tmp_df["close"],target_price_period)
    tmp_df["buy_drop_check"] = True
#     print("BUY_DROP_CHECK COUNT:"+str(len(tmp_df[tmp_df["buy_drop_check"]])))
    
    #Find the buy signals
    tmp_df["buy"] = tmp_df["buy_target_check"] & tmp_df["buy_gain_check"] & tmp_df["buy_drop_check"]
    print("BUY SIGNALS: "+str(len(tmp_df[tmp_df["buy"]])))
    
    #Join back into main table
    s_out = tmp_df["buy"]
    
    return s_out

# %%
#Perform if the target is crossed again
def target_cross_check(x,var_s,target_s,periods:int=12):
    check_s = False
    for i in range((x+1),(x+periods+1)):
        if (i >= 0) and (i < len(target_s)) and (target_s[x] >= var_s[i]):
            check_s = True
            break
    return check_s

# %%
def max_drop_check_s(ref_s,var_s,periods:int=12):
    lim_s = ref_s*(1+max_drop)
    check_s = lim_s != lim_s #Start as False and then if it drops below the threshold turn it to True
    for i in range(-(periods+1),-1):
        tmp_check_s = var_s.shift(i) <= lim_s #If price drops below the threshold price then turn to True
        check_s = tmp_check_s | check_s
    return check_s

# %%
#Function for finding sell signals
def get_sells(df_in):
    tmp_df = df_in.copy()
    
    #Perform if the target is crossed again
    tmp_df["sell_target_check"] = [target_cross_check(x,tmp_df["close"],tmp_df["prev_min_close"],target_price_period) for x in range(0,len(tmp_df))]
#     print("SELL_TARGET_CHECK COUNT:"+str(len(tmp_df[tmp_df["sell_target_check"]])))
    
    #Check if the target price is hit within the target_price_period
    tmp_df["sell_drop_check"] = max_drop_check_s(tmp_df["open"].shift(-1),tmp_df["close"],target_price_period)
#     print("SELL_DROP_CHECK COUNT:"+str(len(tmp_df[tmp_df["sell_drop_check"]])))
    
    #Find the sell signals
    tmp_df["sell"] = tmp_df["sell_target_check"] & tmp_df["sell_drop_check"]
    print("SELL SIGNALS: "+str(len(tmp_df[tmp_df["sell"]])))
    
    #Join back into main table
    s_out = tmp_df["sell"]
    
    return s_out

# %%
#Function to normalise current price compared to another
def norm_s(s_in,max_in,min_in):
    s_out = (s_in - min_in) / (max_in - min_in)
    s_out.fillna(1.0,inplace=True)
    return s_out

# %%
#Create a function which normalises a feature based only on the values which have come before it - avoids time series bias
def norm_time_s(_index,_s_in):
    _min = np.nanmin(_s_in[:_index+1].values)
    _max = np.nanmax(_s_in[:_index+1].values)
    _norm_val = (_s_in[_index] - _min) / (_max - _min)
    return _norm_val

# %%
#Function to find last max and mins
def prev_value(df_in,var_col,bool_col):
    df_in["prev_val"] = df_in.loc[df_in[bool_col],var_col]
    df_in["prev_val"] = df_in["prev_val"].fillna(method='ffill')
    df_in["prev_marker_date"] = df_in.loc[df_in[bool_col],"date"]
    df_in["prev_marker_date"] = df_in["prev_marker_date"].fillna(method='ffill')
    return (df_in["prev_val"],df_in["prev_marker_date"])

# %%
#Create separate columns for pos and neg values - allows for normalisation
def pos_neg_cols(s_in,gt_lt = "GT"):
    if gt_lt.upper() == "GT":
        bool_s = s_in >= 0
    elif gt_lt.upper() == "LT":
        bool_s = s_in <= 0
    df_out = s_in.to_frame()
    df_out["s_in"] = s_in
    df_out["val"] = abs(s_in[bool_s])
    val_s = df_out["val"].fillna(0,method=None)
    return (bool_s,val_s)

# %%
#Function for calculating the max and mins within a period
def max_min_period(s_in,periods:int=4):
    #Copy into max and min
    max_s = s_in.copy()
    min_s = s_in.copy()
    #Go through periods and mark where it is a new max or min
    for i in range(1,(periods+1)):
        #Calc max
        tmp_check_s = s_in.shift(i) >= max_s
        max_s[tmp_check_s] = s_in.shift(i)
        #Calc min
        tmp_check_s = s_in.shift(i) <= min_s
        min_s[tmp_check_s] = s_in.shift(i)
    #Normalise the series
    s_out = norm_s(s_in,max_s,min_s)
    return s_out

# %%
#Create a single function to run each stock through feature creation
def create_features(df_in):
    df_out = df_in.copy()
    
    #Calc vol as proportion of previous n-rows
    df_out["prop_vol"] = calc_prop_of_prev(df_out["volume"].copy().astype("float"),6)

    #Get period-period changes
    df_out["close_shift1"] = df_out["close"].shift(1)
    df_out["change_close_shift1"],df_out["per_change_close_shift1"] = calc_changes(df_out[["close","close_shift1"]].copy(),"close","close_shift1")

    df_out["vol_shift1"] = df_out["volume"].shift(1)
    df_out["change_vol_shift1"],df_out["per_change_vol_shift1"] = calc_changes(df_out[["volume","vol_shift1"]].copy(),"volume","vol_shift1")

    df_out["macd_shift1"] = df_out["macd"].shift(1)
    df_out["change_macd_shift1"],df_out["per_change_macd_shift1"] = calc_changes(df_out[["macd","vol_shift1"]].copy(),"macd","vol_shift1")

    df_out["ema26_shift1"] = df_out["ema26"].shift(1)
    df_out["change_ema26_shift1"],df_out["per_change_ema26_shift1"] = calc_changes(df_out[["ema26","ema26_shift1"]].copy(),"ema26","ema26_shift1")
    
    #Compare close to the max/mins within 13, 26 and 52 periods
    df_out["close_13_norm"] = max_min_period(df_out["close"],13)
    df_out["close_26_norm"] = max_min_period(df_out["close"],26)
    df_out["close_52_norm"] = max_min_period(df_out["close"],52)
    
    #Compare macd to the max/mins within 13, 26 and 52 periods
    df_out["macd_line_13_norm"] = max_min_period(df_out["macd_line"],13)
    df_out["macd_line_26_norm"] = max_min_period(df_out["macd_line"],26)
    df_out["macd_line_52_norm"] = max_min_period(df_out["macd_line"],52)
        
    #Mark points of macd positive entry
    df_out["macd_pos_ent"] = pos_entry(df_out["macd"])
    df_out["macd_neg_ent"] = neg_entry(df_out["macd"])
    
    #Create separate columns for pos and neg values - allows for normalisation
    df_out["macd_pos_bool"],df_out["macd_pos_val"] = pos_neg_cols(df_out["macd"],gt_lt = "GT")
    df_out["macd_neg_bool"],df_out["macd_neg_val"] = pos_neg_cols(df_out["macd"],gt_lt = "LT")
    df_out["signal_line_pos_bool"],df_out["signal_line_pos_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "GT")
    df_out["signal_line_neg_bool"],df_out["signal_line_neg_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "LT")
    df_out["change_price_pos_bool"],df_out["change_price_pos_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "GT")
    df_out["change_price_neg_bool"],df_out["change_price_neg_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "LT")
    df_out["per_change_price_pos_bool"],df_out["per_change_price_pos_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "GT")
    df_out["per_change_price_neg_bool"],df_out["per_change_price_neg_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "LT")

    #Create max min columns
    def mk_cols_max_min(tmp_df,col,period:int=4):
        tmp_df["{}_min".format(col)] = flag_mins(tmp_df[col],period)
        tmp_df["{}_max".format(col)] = flag_maxs(tmp_df[col],period)
        
    #Find last max and mins
    def mk_cols_prev_max_min(tmp_df,col,period:int=4):
        tmp_df["prev_max_{}".format(col)],tmp_df["prev_max_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_max".format(col)]].copy(),col,"{}_max".format(col))
        tmp_df["prev_min_{}".format(col)],tmp_df["prev_min_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_min".format(col)]].copy(),col,"{}_min".format(col))
        #Drop the old columns
        tmp_df.drop(columns=["{}_min".format(col),"{}_max".format(col)],inplace=True)
        #Shift the max min columns by n periods to not leak future information
        tmp_df["prev_max_{}".format(col)] = tmp_df["prev_max_{}".format(col)].shift(period)
        tmp_df["prev_min_{}".format(col)] = tmp_df["prev_min_{}".format(col)].shift(period)
        tmp_df["prev_max_{}_date".format(col)] = tmp_df["prev_max_{}_date".format(col)].shift(period)
        tmp_df["prev_min_{}_date".format(col)] = tmp_df["prev_min_{}_date".format(col)].shift(period)
    
    #Calc the value changes and percentage changes of these movements
    def mk_cols_prev_max_min_change(tmp_df,col):
        tmp_df["max_change_{}".format(col)],tmp_df["max_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_max_{}".format(col)]].copy(),col,"prev_max_{}".format(col))
        tmp_df["min_change_{}".format(col)],tmp_df["min_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_min_{}".format(col)]].copy(),col,"prev_min_{}".format(col))
     
        
    #Mark date change since max and mins and convert to periods
    def mk_cols_prev_max_min_date_change(tmp_df,col,period:int=7):
        tmp_df["prev_max_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_max_{}_date".format(col)]
        tmp_df["prev_min_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_min_{}_date".format(col)]
        #Convert all to period changes
        tmp_df["prev_max_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_max_{}_date_change".format(col)]]
        tmp_df["prev_min_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_min_{}_date_change".format(col)]]
    
    #Convert the max min changes into pos and neg columns
    def mk_cols_prev_max_min_change_pos_neg(tmp_df,col):
        #Only do pos changes for mins and neg changes for max (as it can only go below the max and above the min)
        tmp_df["max_change_{}_pos_bool".format(col)],tmp_df["max_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "GT")
        tmp_df["max_change_{}_neg_bool".format(col)],tmp_df["max_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "LT")
        tmp_df["min_change_{}_pos_bool".format(col)],tmp_df["min_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "GT")
        tmp_df["min_change_{}_neg_bool".format(col)],tmp_df["min_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "LT")
        #Drop the old columns
        tmp_df.drop(columns=["max_change_{}".format(col),"min_change_{}".format(col)],inplace=True)

    #Run function for columns - high volatility
    for col in ['close','signal_line']:
        mk_cols_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    #Run function for columns - low volatility
    for col in ['macd','ema26','macd_line']:
        mk_cols_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    
    #Get buy signals
    df_out["buy"] = get_buys(df_out[["date","open","close","prev_max_close"]])
    
    #Get buy signals
    df_out["sell"] = get_sells(df_out[["date","open","close","prev_min_close"]])
    
    #Get hold signals
    df_out["hold"] = (df_out["buy"] == False) & (df_out["sell"] == False)
    
    #Check for undefined
    df_out["no_signal"] = (df_out["buy"] == False) & (df_out["hold"] == False) & (df_out["sell"] == False)
    
    #Composite all singals into one column
    df_out["signal"] = None
    df_out.loc[df_out["buy"] == True,"signal"] = "buy"
    df_out.loc[df_out["hold"] == True,"signal"] = "hold"
    df_out.loc[df_out["sell"] == True,"signal"] = "sell"
    df_out.drop(columns=["buy","hold","sell"],inplace=True)
    print("SIGNAL COUNTS: {}".format(df_out["signal"].value_counts()))
    
    #Normalise the columns which need it
    norm_cols = [
        #Standard features
        "open"
        ,"close"
        ,"high"
        ,"low"
        ,"volume"
        ,"change_price"
        ,"per_change_price"
        #Proportional features
        ,"prop_vol"
        #Shifted features
        ,"close_shift1"
        ,"change_close_shift1"
        ,"vol_shift1"
        ,"change_vol_shift1"
        ,"ema26_shift1"
        ,"change_ema26_shift1"
        #Pos neg features
        ,"macd_pos_val"
        ,"macd_neg_val"
        ,"signal_line_pos_val"
        ,"signal_line_neg_val"
        ,"change_price_pos_val"
        ,"change_price_neg_val"
        ,"per_change_price_pos_val"
        ,"per_change_price_neg_val"
    ]
    #Append additional columns for key areas
    for col in ['close','macd','ema26','signal_line','macd_line']:
        #Prev max/min features
        norm_cols.append("prev_max_{}".format(col))
        norm_cols.append("prev_min_{}".format(col))
        #Min max change features
        norm_cols.append("max_change_{}_pos_val".format(col))
        norm_cols.append("max_change_{}_neg_val".format(col))
        norm_cols.append("min_change_{}_pos_val".format(col))
        norm_cols.append("min_change_{}_neg_val".format(col))
    #Reset the index
    df_out.reset_index(inplace=True,drop=True)
    #Normalise
    for col in norm_cols:
        tmp_s = df_out[col].copy() #Take a copy so as the values are changed this does not affect following calculations
        df_out[col] = [norm_time_s(x,tmp_s) for x in df_out.index]
    
    return df_out

# %%
#Define the columns for the output
out_cols = [
    #NON-NORMALISED COLS
    "ticker"
    ,"date"
    #NORMALISED COLS
    #Standard features
    ,"open"
    ,"close"
    ,"high"
    ,"low"
    ,"volume"
    ,"change_price"
    ,"per_change_price"
    #Shifted features
    ,"close_shift1"
    ,"change_close_shift1"
    ,"vol_shift1"
    ,"change_vol_shift1"
    ,"ema26_shift1"
    ,"change_ema26_shift1"
    #change to periodic max mins
    ,"close_13_norm"
    ,"close_26_norm"
    ,"close_52_norm"
    ,"macd_line_13_norm"
    ,"macd_line_26_norm"
    ,"macd_line_52_norm"
    #Pos neg features
    ,"macd_pos_val"
    ,"macd_neg_val"
    ,"signal_line_pos_val"
    ,"signal_line_neg_val"
    ,"change_price_pos_val"
    ,"change_price_neg_val"
    ,"per_change_price_pos_val"
    ,"per_change_price_neg_val"
]
#Append additional columns for key areas
for col in ['close','macd','ema26','signal_line','macd_line']:
    out_cols
    #Prev max/min features
#     out_cols.append("prev_max_{}".format(col))
#     out_cols.append("prev_min_{}".format(col))
    #date changes
    out_cols.append("prev_max_{}_date_change".format(col))
    out_cols.append("prev_min_{}_date_change".format(col))
    #Min max change features
    out_cols.append("max_change_{}_pos_val".format(col))
    out_cols.append("max_change_{}_neg_val".format(col))
    out_cols.append("min_change_{}_pos_val".format(col))
    out_cols.append("min_change_{}_neg_val".format(col))
#Append signal
out_cols.append("signal")

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(df_prices_w)
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'high': 7,
#  'low': 7,
#  'volume': 12,
#  'open': 7,
#  'close': 7,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23,
#  'change_price': 21,
#  'per_change_price': 23}

# %%
#Then loop the tickers and combine these into one large dataset
hf_store_name = path+'all_hist_prices_w_ft_eng2_TMP.h5'
h_store = pd.HDFStore(hf_store_name)
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse["ticker"]:
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print("\n{}".format(count))
        print("RUN FOR {}".format(tick))
        #Isolate this ticker
        this_tick_df = df_prices_w[df_prices_w["ticker"] == re.sub('[^a-zA-Z0-9\-]','',tick)].copy()
        print("shape before: {}".format(this_tick_df.shape))
        #Get the features and buy,sell signals
        this_tick_df = create_features(this_tick_df)
#         print(this_tick_df[out_cols])
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in out_cols:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
        print("shape after: {}".format(this_tick_df.shape))
        #Append this data to the group
        try:
            this_tick_df[out_cols].to_hdf(hf_store_name,key='weekly_data',append=True,min_itemsize=col_lens_tmp)
            print('ADDED TO {}'.format(hf_store_name))
        except Exception as e:
            print('ERROR READING TO FILE {}'.format(e))
    except Exception as e:
        h_store.close()
        errors.append({"ticker":tick,"Error":e})
        print('ERROR PROCESSING DATA {}'.format(e))
# h_store.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1
# RUN FOR III
# shape before: (608, 14)
# BUY SIGNALS: 75
# SELL SIGNALS: 216
# SIGNAL COUNTS: hold    342
# sell    216
# buy      50
# Name: signal, dtype: int64
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: All-NaN slice encountered
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: All-NaN slice encountered
#   after removing the cwd from sys.path.
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 1 TIME -> 0:0:0
#
# 2
# RUN FOR ADM
# shape before: (365, 14)
# BUY SIGNALS: 23
# SELL SIGNALS: 70
# SIGNAL COUNTS: hold    279
# sell     70
# buy      16
# Name: signal, dtype: int64
# shape after: (365, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 2 TIME -> 0:0:11
#
# 3
# RUN FOR AAL
# shape before: (1009, 14)
# BUY SIGNALS: 149
# SELL SIGNALS: 466
# SIGNAL COUNTS: sell    466
# hold    448
# buy      95
# Name: signal, dtype: int64
# shape after: (1009, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 3 TIME -> 0:0:7
#
# 4
# RUN FOR ANTO
# shape before: (1047, 14)
# BUY SIGNALS: 185
# SELL SIGNALS: 383
# SIGNAL COUNTS: hold    529
# sell    383
# buy     135
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 4 TIME -> 0:0:17
#
# 5
# RUN FOR AHT
# shape before: (1025, 14)
# BUY SIGNALS: 209
# SELL SIGNALS: 357
# SIGNAL COUNTS: hold    529
# sell    357
# buy     139
# Name: signal, dtype: int64
# shape after: (1025, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 5 TIME -> 0:0:17
#
# 6
# RUN FOR ABF
# shape before: (1047, 14)
# BUY SIGNALS: 85
# SELL SIGNALS: 336
# SIGNAL COUNTS: hold    647
# sell    336
# buy      64
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 6 TIME -> 0:0:18
#
# 7
# RUN FOR AZN
# shape before: (1047, 14)
# BUY SIGNALS: 75
# SELL SIGNALS: 376
# SIGNAL COUNTS: hold    607
# sell    376
# buy      64
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 7 TIME -> 0:0:19
#
# 8
# RUN FOR AUTO
# shape before: (232, 14)
# BUY SIGNALS: 22
# SELL SIGNALS: 82
# SIGNAL COUNTS: hold    130
# sell     82
# buy      20
# Name: signal, dtype: int64
# shape after: (232, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 8 TIME -> 0:0:18
#
# 9
# RUN FOR AVV
# shape before: (1047, 14)
# BUY SIGNALS: 139
# SELL SIGNALS: 303
# SIGNAL COUNTS: hold    633
# sell    303
# buy     111
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 9 TIME -> 0:0:5
#
# 10
# RUN FOR AV
# shape before: (1051, 14)
# BUY SIGNALS: 151
# SELL SIGNALS: 461
# SIGNAL COUNTS: hold    469
# sell    461
# buy     121
# Name: signal, dtype: int64
# shape after: (1051, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 10 TIME -> 0:0:19
#
# 11
# RUN FOR BA
# shape before: (1047, 14)
# BUY SIGNALS: 82
# SELL SIGNALS: 366
# SIGNAL COUNTS: hold    616
# sell    366
# buy      65
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 11 TIME -> 0:0:18
#
# 12
# RUN FOR BARC
# shape before: (1047, 14)
# BUY SIGNALS: 146
# SELL SIGNALS: 509
# SIGNAL COUNTS: sell    509
# hold    451
# buy      87
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 12 TIME -> 0:0:17
#
# 13
# RUN FOR BDEV
# shape before: (1047, 14)
# BUY SIGNALS: 198
# SELL SIGNALS: 381
# SIGNAL COUNTS: hold    525
# sell    381
# buy     141
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 13 TIME -> 0:0:17
#
# 14
# RUN FOR BKG
# shape before: (1047, 14)
# BUY SIGNALS: 143
# SELL SIGNALS: 373
# SIGNAL COUNTS: hold    570
# sell    373
# buy     104
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 14 TIME -> 0:0:17
#
# 15
# RUN FOR BHP
# shape before: (493, 14)
# BUY SIGNALS: 83
# SELL SIGNALS: 161
# SIGNAL COUNTS: hold    272
# sell    161
# buy      60
# Name: signal, dtype: int64
# shape after: (493, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 15 TIME -> 0:0:18
#
# 16
# RUN FOR BP
# shape before: (1047, 14)
# BUY SIGNALS: 103
# SELL SIGNALS: 395
# SIGNAL COUNTS: hold    563
# sell    395
# buy      89
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 16 TIME -> 0:0:9
#
# 17
# RUN FOR BATS
# shape before: (1047, 14)
# BUY SIGNALS: 58
# SELL SIGNALS: 266
# SIGNAL COUNTS: hold    734
# sell    266
# buy      47
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 17 TIME -> 0:0:17
#
# 18
# RUN FOR BLND
# shape before: (1047, 14)
# BUY SIGNALS: 68
# SELL SIGNALS: 386
# SIGNAL COUNTS: hold    614
# sell    386
# buy      47
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 18 TIME -> 0:0:18
#
# 19
# RUN FOR BT-A
# shape before: (1047, 14)
# BUY SIGNALS: 95
# SELL SIGNALS: 489
# SIGNAL COUNTS: hold    506
# sell    489
# buy      52
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 19 TIME -> 0:0:17
#
# 20
# RUN FOR BNZL
# shape before: (1044, 14)
# BUY SIGNALS: 58
# SELL SIGNALS: 309
# SIGNAL COUNTS: hold    683
# sell    309
# buy      52
# Name: signal, dtype: int64
# shape after: (1044, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 20 TIME -> 0:0:18
#
# 21
# RUN FOR BRBY
# shape before: (894, 14)
# BUY SIGNALS: 110
# SELL SIGNALS: 293
# SIGNAL COUNTS: hold    514
# sell    293
# buy      87
# Name: signal, dtype: int64
# shape after: (894, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 21 TIME -> 0:0:18
#
# 22
# RUN FOR CCL
# shape before: (983, 14)
# BUY SIGNALS: 135
# SELL SIGNALS: 394
# SIGNAL COUNTS: hold    483
# sell    394
# buy     106
# Name: signal, dtype: int64
# shape after: (983, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 22 TIME -> 0:0:16
#
# 23
# RUN FOR CNA
# shape before: (1047, 14)
# BUY SIGNALS: 57
# SELL SIGNALS: 458
# SIGNAL COUNTS: hold    541
# sell    458
# buy      48
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 23 TIME -> 0:0:17
#
# 24
# RUN FOR CCH
# shape before: (330, 14)
# BUY SIGNALS: 27
# SELL SIGNALS: 121
# SIGNAL COUNTS: hold    186
# sell    121
# buy      23
# Name: signal, dtype: int64
# shape after: (330, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 24 TIME -> 0:0:17
#
# 25
# RUN FOR CPG
# shape before: (1025, 14)
# BUY SIGNALS: 77
# SELL SIGNALS: 300
# SIGNAL COUNTS: hold    666
# sell    300
# buy      59
# Name: signal, dtype: int64
# shape after: (1025, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 25 TIME -> 0:0:6
#
# 26
# RUN FOR CRH
# shape before: (1025, 14)
# BUY SIGNALS: 130
# SELL SIGNALS: 381
# SIGNAL COUNTS: hold    534
# sell    381
# buy     110
# Name: signal, dtype: int64
# shape after: (1025, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 26 TIME -> 0:0:18
#
# 27
# RUN FOR CRDA
# shape before: (1039, 14)
# BUY SIGNALS: 86
# SELL SIGNALS: 299
# SIGNAL COUNTS: hold    674
# sell    299
# buy      66
# Name: signal, dtype: int64
# shape after: (1039, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 27 TIME -> 0:0:17
#
# 28
# RUN FOR DCC
# shape before: (1021, 14)
# BUY SIGNALS: 102
# SELL SIGNALS: 332
# SIGNAL COUNTS: hold    607
# sell    332
# buy      82
# Name: signal, dtype: int64
# shape after: (1021, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 28 TIME -> 0:0:18
#
# 29
# RUN FOR DGE
# shape before: (1047, 14)
# BUY SIGNALS: 63
# SELL SIGNALS: 274
# SIGNAL COUNTS: hold    724
# sell    274
# buy      49
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 29 TIME -> 0:0:18
#
# 30
# RUN FOR DLG
# shape before: (359, 14)
# BUY SIGNALS: 9
# SELL SIGNALS: 103
# SIGNAL COUNTS: hold    247
# sell    103
# buy       9
# Name: signal, dtype: int64
# shape after: (359, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 30 TIME -> 0:0:18
#
# 31
# RUN FOR EVR
# shape before: (407, 14)
# BUY SIGNALS: 111
# SELL SIGNALS: 182
# SIGNAL COUNTS: sell    182
# hold    157
# buy      68
# Name: signal, dtype: int64
# shape after: (407, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 31 TIME -> 0:0:7
#
# 32
# RUN FOR EXPN
# shape before: (672, 14)
# BUY SIGNALS: 57
# SELL SIGNALS: 224
# SIGNAL COUNTS: hold    398
# sell    224
# buy      50
# Name: signal, dtype: int64
# shape after: (672, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 32 TIME -> 0:0:8
#
# 33
# RUN FOR FERG
# shape before: (1047, 14)
# BUY SIGNALS: 117
# SELL SIGNALS: 400
# SIGNAL COUNTS: hold    576
# sell    400
# buy      71
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 33 TIME -> 0:0:12
#
# 34
# RUN FOR FRES
# shape before: (590, 14)
# BUY SIGNALS: 133
# SELL SIGNALS: 282
# SIGNAL COUNTS: sell    282
# hold    223
# buy      85
# Name: signal, dtype: int64
# shape after: (590, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 34 TIME -> 0:0:18
#
# 35
# RUN FOR GSK
# shape before: (1047, 14)
# BUY SIGNALS: 55
# SELL SIGNALS: 369
# SIGNAL COUNTS: hold    630
# sell    369
# buy      48
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 35 TIME -> 0:0:10
#
# 36
# RUN FOR GLEN
# shape before: (432, 14)
# BUY SIGNALS: 79
# SELL SIGNALS: 211
# SIGNAL COUNTS: sell    211
# hold    165
# buy      56
# Name: signal, dtype: int64
# shape after: (432, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 36 TIME -> 0:0:17
#
# 37
# RUN FOR HLMA
# shape before: (1015, 14)
# BUY SIGNALS: 71
# SELL SIGNALS: 253
# SIGNAL COUNTS: hold    699
# sell    253
# buy      63
# Name: signal, dtype: int64
# shape after: (1015, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 37 TIME -> 0:0:8
#
# 38
# RUN FOR HL
# shape before: (635, 14)
# BUY SIGNALS: 94
# SELL SIGNALS: 191
# SIGNAL COUNTS: hold    366
# sell    191
# buy      78
# Name: signal, dtype: int64
# shape after: (635, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 38 TIME -> 0:0:18
#
# 39
# RUN FOR HSX
# shape before: (1025, 14)
# BUY SIGNALS: 123
# SELL SIGNALS: 282
# SIGNAL COUNTS: hold    634
# sell    282
# buy     109
# Name: signal, dtype: int64
# shape after: (1025, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 39 TIME -> 0:0:11
#
# 40
# RUN FOR HSBA
# shape before: (1047, 14)
# BUY SIGNALS: 59
# SELL SIGNALS: 401
# SIGNAL COUNTS: hold    599
# sell    401
# buy      47
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 40 TIME -> 0:0:17
#
# 41
# RUN FOR IMB
# shape before: (1045, 14)
# BUY SIGNALS: 66
# SELL SIGNALS: 304
# SIGNAL COUNTS: hold    684
# sell    304
# buy      57
# Name: signal, dtype: int64
# shape after: (1045, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 41 TIME -> 0:0:17
#
# 42
# RUN FOR INF
# shape before: (1047, 14)
# BUY SIGNALS: 131
# SELL SIGNALS: 344
# SIGNAL COUNTS: hold    604
# sell    344
# buy      99
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 42 TIME -> 0:0:18
#
# 43
# RUN FOR IHG
# shape before: (868, 14)
# BUY SIGNALS: 100
# SELL SIGNALS: 308
# SIGNAL COUNTS: hold    490
# sell    308
# buy      70
# Name: signal, dtype: int64
# shape after: (868, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 43 TIME -> 0:0:18
#
# 44
# RUN FOR IAG
# shape before: (869, 14)
# BUY SIGNALS: 131
# SELL SIGNALS: 340
# SIGNAL COUNTS: hold    444
# sell    340
# buy      85
# Name: signal, dtype: int64
# shape after: (869, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 44 TIME -> 0:0:15
#
# 45
# RUN FOR ITRK
# shape before: (898, 14)
# BUY SIGNALS: 82
# SELL SIGNALS: 271
# SIGNAL COUNTS: hold    554
# sell    271
# buy      73
# Name: signal, dtype: int64
# shape after: (898, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 45 TIME -> 0:0:15
#
# 46
# RUN FOR ITV
# shape before: (1025, 14)
# BUY SIGNALS: 173
# SELL SIGNALS: 526
# SIGNAL COUNTS: sell    526
# hold    401
# buy      98
# Name: signal, dtype: int64
# shape after: (1025, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 46 TIME -> 0:0:15
#
# 47
# RUN FOR JD
# shape before: (163, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 20
# SIGNAL COUNTS: hold    129
# sell     20
# buy      14
# Name: signal, dtype: int64
# shape after: (163, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 47 TIME -> 0:0:20
#
# 48
# RUN FOR JMAT
# shape before: (1047, 14)
# BUY SIGNALS: 89
# SELL SIGNALS: 359
# SIGNAL COUNTS: hold    615
# sell    359
# buy      73
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 48 TIME -> 0:0:5
#
# 49
# RUN FOR JE
# shape before: (282, 14)
# BUY SIGNALS: 76
# SELL SIGNALS: 92
# SIGNAL COUNTS: hold    130
# sell     92
# buy      60
# Name: signal, dtype: int64
# shape after: (282, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 49 TIME -> 0:0:21
#
# 50
# RUN FOR KGF
# shape before: (1047, 14)
# BUY SIGNALS: 108
# SELL SIGNALS: 451
# SIGNAL COUNTS: hold    506
# sell    451
# buy      90
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 50 TIME -> 0:0:8
#
# 51
# RUN FOR LAND
# shape before: (1047, 14)
# BUY SIGNALS: 47
# SELL SIGNALS: 393
# SIGNAL COUNTS: hold    620
# sell    393
# buy      34
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 51 TIME -> 0:0:22
#
# 52
# RUN FOR LGEN
# shape before: (1047, 14)
# BUY SIGNALS: 118
# SELL SIGNALS: 403
# SIGNAL COUNTS: hold    560
# sell    403
# buy      84
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 52 TIME -> 0:0:21
#
# 53
# RUN FOR LLOY
# shape before: (1047, 14)
# BUY SIGNALS: 130
# SELL SIGNALS: 481
# SIGNAL COUNTS: sell    481
# hold    474
# buy      92
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 53 TIME -> 0:0:18
#
# 54
# RUN FOR LSE
# shape before: (945, 14)
# BUY SIGNALS: 96
# SELL SIGNALS: 275
# SIGNAL COUNTS: hold    606
# sell    275
# buy      64
# Name: signal, dtype: int64
# shape after: (945, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 54 TIME -> 0:0:17
#
# 55
# RUN FOR MKS
# shape before: (1047, 14)
# BUY SIGNALS: 101
# SELL SIGNALS: 494
# SIGNAL COUNTS: sell    494
# hold    477
# buy      76
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 55 TIME -> 0:0:15
#
# 56
# RUN FOR MRO
# shape before: (825, 14)
# BUY SIGNALS: 107
# SELL SIGNALS: 304
# SIGNAL COUNTS: hold    433
# sell    304
# buy      88
# Name: signal, dtype: int64
# shape after: (825, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 56 TIME -> 0:0:17
#
# 57
# RUN FOR MCRO
# shape before: (746, 14)
# BUY SIGNALS: 113
# SELL SIGNALS: 262
# SIGNAL COUNTS: hold    398
# sell    262
# buy      86
# Name: signal, dtype: int64
# shape after: (746, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 57 TIME -> 0:0:14
#
# 58
# RUN FOR MNDI
# shape before: (627, 14)
# BUY SIGNALS: 81
# SELL SIGNALS: 229
# SIGNAL COUNTS: hold    352
# sell    229
# buy      46
# Name: signal, dtype: int64
# shape after: (627, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 58 TIME -> 0:0:13
#
# 59
# RUN FOR MRW
# shape before: (1047, 14)
# BUY SIGNALS: 68
# SELL SIGNALS: 403
# SIGNAL COUNTS: hold    591
# sell    403
# buy      53
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 59 TIME -> 0:0:11
#
# 60
# RUN FOR NG
# shape before: (1047, 14)
# BUY SIGNALS: 50
# SELL SIGNALS: 305
# SIGNAL COUNTS: hold    696
# sell    305
# buy      46
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 60 TIME -> 0:0:17
#
# 61
# RUN FOR NXT
# shape before: (1047, 14)
# BUY SIGNALS: 115
# SELL SIGNALS: 325
# SIGNAL COUNTS: hold    641
# sell    325
# buy      81
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 61 TIME -> 0:0:17
#
# 62
# RUN FOR NMC
# shape before: (386, 14)
# BUY SIGNALS: 59
# SELL SIGNALS: 120
# SIGNAL COUNTS: hold    220
# sell    120
# buy      46
# Name: signal, dtype: int64
# shape after: (386, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 62 TIME -> 0:0:17
#
# 63
# RUN FOR OCDO
# shape before: (475, 14)
# BUY SIGNALS: 121
# SELL SIGNALS: 209
# SIGNAL COUNTS: sell    209
# hold    196
# buy      70
# Name: signal, dtype: int64
# shape after: (475, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 63 TIME -> 0:0:7
#
# 64
# RUN FOR PSON
# shape before: (1047, 14)
# BUY SIGNALS: 106
# SELL SIGNALS: 420
# SIGNAL COUNTS: hold    558
# sell    420
# buy      69
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 64 TIME -> 0:0:9
#
# 65
# RUN FOR PSN
# shape before: (1047, 14)
# BUY SIGNALS: 155
# SELL SIGNALS: 358
# SIGNAL COUNTS: hold    573
# sell    358
# buy     116
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 65 TIME -> 0:0:18
#
# 66
# RUN FOR PHNX
# shape before: (508, 14)
# BUY SIGNALS: 29
# SELL SIGNALS: 163
# SIGNAL COUNTS: hold    317
# sell    163
# buy      28
# Name: signal, dtype: int64
# shape after: (508, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 66 TIME -> 0:0:18
#
# 67
# RUN FOR PRU
# shape before: (1047, 14)
# BUY SIGNALS: 129
# SELL SIGNALS: 404
# SIGNAL COUNTS: hold    547
# sell    404
# buy      96
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 67 TIME -> 0:0:10
#
# 68
# RUN FOR RB
# shape before: (1047, 14)
# BUY SIGNALS: 43
# SELL SIGNALS: 278
# SIGNAL COUNTS: hold    737
# sell    278
# buy      32
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 68 TIME -> 0:0:17
#
# 69
# RUN FOR REL
# shape before: (1047, 14)
# BUY SIGNALS: 72
# SELL SIGNALS: 303
# SIGNAL COUNTS: hold    682
# sell    303
# buy      62
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 69 TIME -> 0:0:17
#
# 70
# RUN FOR RTO
# shape before: (1047, 14)
# BUY SIGNALS: 119
# SELL SIGNALS: 354
# SIGNAL COUNTS: hold    596
# sell    354
# buy      97
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 70 TIME -> 0:0:18
#
# 71
# RUN FOR RIO
# shape before: (1047, 14)
# BUY SIGNALS: 150
# SELL SIGNALS: 408
# SIGNAL COUNTS: hold    520
# sell    408
# buy     119
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 71 TIME -> 0:0:17
#
# 72
# RUN FOR RMV
# shape before: (703, 14)
# BUY SIGNALS: 82
# SELL SIGNALS: 191
# SIGNAL COUNTS: hold    446
# sell    191
# buy      66
# Name: signal, dtype: int64
# shape after: (703, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 72 TIME -> 0:0:17
#
# 73
# RUN FOR RR
# shape before: (1047, 14)
# BUY SIGNALS: 112
# SELL SIGNALS: 364
# SIGNAL COUNTS: hold    599
# sell    364
# buy      84
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 73 TIME -> 0:0:12
#
# 74
# RUN FOR RBS
# shape before: (1047, 14)
# BUY SIGNALS: 164
# SELL SIGNALS: 507
# SIGNAL COUNTS: sell    507
# hold    439
# buy     101
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 74 TIME -> 0:0:17
#
# 75
# RUN FOR RDSA
# shape before: (489, 14)
# BUY SIGNALS: 40
# SELL SIGNALS: 193
# SIGNAL COUNTS: hold    260
# sell    193
# buy      36
# Name: signal, dtype: int64
# shape after: (489, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 75 TIME -> 0:0:17
#
# 76
# RUN FOR RSA
# shape before: (1047, 14)
# BUY SIGNALS: 109
# SELL SIGNALS: 432
# SIGNAL COUNTS: hold    531
# sell    432
# buy      84
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 76 TIME -> 0:0:9
#
# 77
# RUN FOR SGE
# shape before: (1047, 14)
# BUY SIGNALS: 111
# SELL SIGNALS: 417
# SIGNAL COUNTS: hold    564
# sell    417
# buy      66
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 77 TIME -> 0:0:17
#
# 78
# RUN FOR SBRY
# shape before: (1047, 14)
# BUY SIGNALS: 101
# SELL SIGNALS: 443
# SIGNAL COUNTS: hold    527
# sell    443
# buy      77
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 78 TIME -> 0:0:17
#
# 79
# RUN FOR SDR
# shape before: (1047, 14)
# BUY SIGNALS: 151
# SELL SIGNALS: 415
# SIGNAL COUNTS: hold    519
# sell    415
# buy     113
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 79 TIME -> 0:0:17
#
# 80
# RUN FOR SMT
# shape before: (134, 14)
# BUY SIGNALS: 1
# SELL SIGNALS: 24
# SIGNAL COUNTS: hold    109
# sell     24
# buy       1
# Name: signal, dtype: int64
# shape after: (134, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 80 TIME -> 0:0:18
#
# 81
# RUN FOR SGRO
# shape before: (1047, 14)
# BUY SIGNALS: 80
# SELL SIGNALS: 362
# SIGNAL COUNTS: hold    627
# sell    362
# buy      58
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 81 TIME -> 0:0:4
#
# 82
# RUN FOR SVT
# shape before: (1047, 14)
# BUY SIGNALS: 52
# SELL SIGNALS: 334
# SIGNAL COUNTS: hold    666
# sell    334
# buy      47
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 82 TIME -> 0:0:18
#
# 83
# RUN FOR SN
# shape before: (1047, 14)
# BUY SIGNALS: 71
# SELL SIGNALS: 340
# SIGNAL COUNTS: hold    647
# sell    340
# buy      60
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 83 TIME -> 0:0:18
#
# 84
# RUN FOR SMDS
# shape before: (1047, 14)
# BUY SIGNALS: 157
# SELL SIGNALS: 383
# SIGNAL COUNTS: hold    550
# sell    383
# buy     114
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 84 TIME -> 0:0:18
#
# 85
# RUN FOR SMIN
# shape before: (1031, 14)
# BUY SIGNALS: 61
# SELL SIGNALS: 346
# SIGNAL COUNTS: hold    634
# sell    346
# buy      51
# Name: signal, dtype: int64
# shape after: (1031, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 85 TIME -> 0:0:19
#
# 86
# RUN FOR SKG
# shape before: (650, 14)
# BUY SIGNALS: 104
# SELL SIGNALS: 247
# SIGNAL COUNTS: hold    328
# sell    247
# buy      75
# Name: signal, dtype: int64
# shape after: (650, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 86 TIME -> 0:0:17
#
# 87
# RUN FOR SPX
# shape before: (1046, 14)
# BUY SIGNALS: 102
# SELL SIGNALS: 296
# SIGNAL COUNTS: hold    658
# sell    296
# buy      92
# Name: signal, dtype: int64
# shape after: (1046, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 87 TIME -> 0:0:12
#
# 88
# RUN FOR SSE
# shape before: (1047, 14)
# BUY SIGNALS: 32
# SELL SIGNALS: 356
# SIGNAL COUNTS: hold    660
# sell    356
# buy      31
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 88 TIME -> 0:0:17
#
# 89
# RUN FOR STAN
# shape before: (1047, 14)
# BUY SIGNALS: 123
# SELL SIGNALS: 434
# SIGNAL COUNTS: hold    519
# sell    434
# buy      94
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 89 TIME -> 0:0:18
#
# 90
# RUN FOR SLA
# shape before: (685, 14)
# BUY SIGNALS: 69
# SELL SIGNALS: 300
# SIGNAL COUNTS: hold    330
# sell    300
# buy      55
# Name: signal, dtype: int64
# shape after: (685, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 90 TIME -> 0:0:21
#
# 91
# RUN FOR STJ
# shape before: (1052, 14)
# BUY SIGNALS: 149
# SELL SIGNALS: 406
# SIGNAL COUNTS: hold    541
# sell    406
# buy     105
# Name: signal, dtype: int64
# shape after: (1052, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 91 TIME -> 0:0:15
#
# 92
# RUN FOR TW
# shape before: (1047, 14)
# BUY SIGNALS: 159
# SELL SIGNALS: 425
# SIGNAL COUNTS: hold    507
# sell    425
# buy     115
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 92 TIME -> 0:0:21
#
# 93
# RUN FOR TSCO
# shape before: (1047, 14)
# BUY SIGNALS: 84
# SELL SIGNALS: 412
# SIGNAL COUNTS: hold    576
# sell    412
# buy      59
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 93 TIME -> 0:0:21
#
# 94
# RUN FOR TUI
# shape before: (245, 14)
# BUY SIGNALS: 18
# SELL SIGNALS: 103
# SIGNAL COUNTS: hold    127
# sell    103
# buy      15
# Name: signal, dtype: int64
# shape after: (245, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 94 TIME -> 0:0:20
#
# 95
# RUN FOR ULVR
# shape before: (1047, 14)
# BUY SIGNALS: 70
# SELL SIGNALS: 308
# SIGNAL COUNTS: hold    678
# sell    308
# buy      61
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 95 TIME -> 0:0:5
#
# 96
# RUN FOR UU
# shape before: (1047, 14)
# BUY SIGNALS: 60
# SELL SIGNALS: 387
# SIGNAL COUNTS: hold    612
# sell    387
# buy      48
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 96 TIME -> 0:0:18
#
# 97
# RUN FOR VOD
# shape before: (1047, 14)
# BUY SIGNALS: 99
# SELL SIGNALS: 503
# SIGNAL COUNTS: sell    503
# hold    477
# buy      67
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 97 TIME -> 0:0:17
#
# 98
# RUN FOR WTB
# shape before: (1047, 14)
# BUY SIGNALS: 125
# SELL SIGNALS: 361
# SIGNAL COUNTS: hold    585
# sell    361
# buy     101
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 98 TIME -> 0:0:18
#
# 99
# RUN FOR WPP
# shape before: (679, 14)
# BUY SIGNALS: 72
# SELL SIGNALS: 245
# SIGNAL COUNTS: hold    376
# sell    245
# buy      58
# Name: signal, dtype: int64
# shape after: (679, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 99 TIME -> 0:0:17
#
# 100
# RUN FOR 3IN
# shape before: (603, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 75
# SIGNAL COUNTS: hold    513
# sell     75
# buy      15
# Name: signal, dtype: int64
# shape after: (603, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 100 TIME -> 0:0:12
#
# 101
# RUN FOR FOUR
# shape before: (1038, 14)
# BUY SIGNALS: 137
# SELL SIGNALS: 309
# SIGNAL COUNTS: hold    623
# sell    309
# buy     106
# Name: signal, dtype: int64
# shape after: (1038, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 101 TIME -> 0:0:11
#
# 102
# RUN FOR ASL
# shape before: (602, 14)
# BUY SIGNALS: 20
# SELL SIGNALS: 168
# SIGNAL COUNTS: hold    419
# sell    168
# buy      15
# Name: signal, dtype: int64
# shape after: (602, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 102 TIME -> 0:0:17
#
# 103
# RUN FOR ACA
# shape before: (493, 14)
# BUY SIGNALS: 132
# SELL SIGNALS: 260
# SIGNAL COUNTS: sell    260
# hold    153
# buy      80
# Name: signal, dtype: int64
# shape after: (493, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 103 TIME -> 0:0:11
#
# 104
# RUN FOR AGK
# shape before: (1047, 14)
# BUY SIGNALS: 161
# SELL SIGNALS: 410
# SIGNAL COUNTS: hold    519
# sell    410
# buy     118
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 104 TIME -> 0:0:9
#
# 105
# RUN FOR ATST
# shape before: (608, 14)
# BUY SIGNALS: 11
# SELL SIGNALS: 130
# SIGNAL COUNTS: hold    468
# sell    130
# buy      10
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 105 TIME -> 0:0:17
#
# 106
# RUN FOR AMGO
# shape before: (61, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 39
# SIGNAL COUNTS: sell    39
# hold    12
# buy     10
# Name: signal, dtype: int64
# shape after: (61, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 106 TIME -> 0:0:11
#
# 107
# RUN FOR APAX
# shape before: (214, 14)
# BUY SIGNALS: 0
# SELL SIGNALS: 53
# SIGNAL COUNTS: hold    161
# sell     53
# Name: signal, dtype: int64
# shape after: (214, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 107 TIME -> 0:0:3
#
# 108
# RUN FOR ASCL
# shape before: (185, 14)
# BUY SIGNALS: 14
# SELL SIGNALS: 33
# SIGNAL COUNTS: hold    138
# sell     33
# buy      14
# Name: signal, dtype: int64
# shape after: (185, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 108 TIME -> 0:0:5
#
# 109
# RUN FOR ASHM
# shape before: (672, 14)
# BUY SIGNALS: 103
# SELL SIGNALS: 262
# SIGNAL COUNTS: hold    330
# sell    262
# buy      80
# Name: signal, dtype: int64
# shape after: (672, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 109 TIME -> 0:0:5
#
# 110
# RUN FOR AGR
# shape before: (821, 14)
# BUY SIGNALS: 84
# SELL SIGNALS: 265
# SIGNAL COUNTS: hold    507
# sell    265
# buy      49
# Name: signal, dtype: int64
# shape after: (821, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 110 TIME -> 0:0:12
#
# 111
# RUN FOR AML
# shape before: (47, 14)
# BUY SIGNALS: 6
# SELL SIGNALS: 38
# SIGNAL COUNTS: sell    38
# hold     8
# buy      1
# Name: signal, dtype: int64
# shape after: (47, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 111 TIME -> 0:0:14
#
# 112
# RUN FOR AVST
# shape before: (68, 14)
# BUY SIGNALS: 7
# SELL SIGNALS: 0
# SIGNAL COUNTS: hold    61
# buy      7
# Name: signal, dtype: int64
# shape after: (68, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 112 TIME -> 0:0:3
#
# 113
# RUN FOR BAB
# shape before: (1028, 14)
# BUY SIGNALS: 114
# SELL SIGNALS: 382
# SIGNAL COUNTS: hold    556
# sell    382
# buy      90
# Name: signal, dtype: int64
# shape after: (1028, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 113 TIME -> 0:0:3
#
# 114
# RUN FOR BGFD
# shape before: (604, 14)
# BUY SIGNALS: 50
# SELL SIGNALS: 159
# SIGNAL COUNTS: hold    399
# sell    159
# buy      46
# Name: signal, dtype: int64
# shape after: (604, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 114 TIME -> 0:0:17
#
# 115
# RUN FOR BAKK
# shape before: (93, 14)
# BUY SIGNALS: 10
# SELL SIGNALS: 72
# SIGNAL COUNTS: sell    72
# hold    14
# buy      7
# Name: signal, dtype: int64
# shape after: (93, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 115 TIME -> 0:0:11
#
# 116
# RUN FOR BBY
# shape before: (1047, 14)
# BUY SIGNALS: 141
# SELL SIGNALS: 428
# SIGNAL COUNTS: hold    512
# sell    428
# buy     107
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 116 TIME -> 0:0:3
#
# 117
# RUN FOR BNKR
# shape before: (608, 14)
# BUY SIGNALS: 13
# SELL SIGNALS: 156
# SIGNAL COUNTS: hold    440
# sell    156
# buy      12
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 117 TIME -> 0:0:17
#
# 118
# RUN FOR BAG
# shape before: (1047, 14)
# BUY SIGNALS: 42
# SELL SIGNALS: 285
# SIGNAL COUNTS: hold    721
# sell    285
# buy      41
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 118 TIME -> 0:0:11
#
# 119
# RUN FOR BBA
# shape before: (1047, 14)
# BUY SIGNALS: 132
# SELL SIGNALS: 428
# SIGNAL COUNTS: hold    526
# sell    428
# buy      93
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 119 TIME -> 0:0:18
#
# 120
# RUN FOR BBGI
# shape before: (396, 14)
# BUY SIGNALS: 0
# SELL SIGNALS: 30
# SIGNAL COUNTS: hold    366
# sell     30
# Name: signal, dtype: int64
# shape after: (396, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 120 TIME -> 0:0:19
#
# 121
# RUN FOR BCA
# shape before: (241, 14)
# BUY SIGNALS: 20
# SELL SIGNALS: 73
# SIGNAL COUNTS: hold    152
# sell     73
# buy      16
# Name: signal, dtype: int64
# shape after: (241, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 121 TIME -> 0:0:9
#
# 122
# RUN FOR BGEO
# shape before: (612, 14)
# BUY SIGNALS: 111
# SELL SIGNALS: 234
# SIGNAL COUNTS: hold    309
# sell    234
# buy      69
# Name: signal, dtype: int64
# shape after: (612, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 122 TIME -> 0:0:6
#
# 123
# RUN FOR BEZ
# shape before: (876, 14)
# BUY SIGNALS: 71
# SELL SIGNALS: 227
# SIGNAL COUNTS: hold    584
# sell    227
# buy      65
# Name: signal, dtype: int64
# shape after: (876, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 123 TIME -> 0:0:11
#
# 124
# RUN FOR AJB
# shape before: (38, 14)
# BUY SIGNALS: 3
# SELL SIGNALS: 0
# SIGNAL COUNTS: hold    35
# buy      3
# Name: signal, dtype: int64
# shape after: (38, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 124 TIME -> 0:0:15
#
# 125
# RUN FOR BWY
# shape before: (1011, 14)
# BUY SIGNALS: 151
# SELL SIGNALS: 358
# SIGNAL COUNTS: hold    537
# sell    358
# buy     116
# Name: signal, dtype: int64
# shape after: (1011, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 125 TIME -> 0:0:3
#
# 126
# RUN FOR BYG
# shape before: (1007, 14)
# BUY SIGNALS: 68
# SELL SIGNALS: 346
# SIGNAL COUNTS: hold    613
# sell    346
# buy      48
# Name: signal, dtype: int64
# shape after: (1007, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 126 TIME -> 0:0:17
#
# 127
# RUN FOR BME
# shape before: (272, 14)
# BUY SIGNALS: 36
# SELL SIGNALS: 98
# SIGNAL COUNTS: hold    143
# sell     98
# buy      31
# Name: signal, dtype: int64
# shape after: (272, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 127 TIME -> 0:0:17
#
# 128
# RUN FOR BRSC
# shape before: (153, 14)
# BUY SIGNALS: 7
# SELL SIGNALS: 17
# SIGNAL COUNTS: hold    129
# sell     17
# buy       7
# Name: signal, dtype: int64
# shape after: (153, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 128 TIME -> 0:0:6
#
# 129
# RUN FOR BGSC
# shape before: (608, 14)
# BUY SIGNALS: 27
# SELL SIGNALS: 142
# SIGNAL COUNTS: hold    449
# sell    142
# buy      17
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 129 TIME -> 0:0:4
#
# 130
# RUN FOR BOY
# shape before: (1047, 14)
# BUY SIGNALS: 184
# SELL SIGNALS: 430
# SIGNAL COUNTS: hold    506
# sell    430
# buy     111
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 130 TIME -> 0:0:11
#
# 131
# RUN FOR BVS
# shape before: (1041, 14)
# BUY SIGNALS: 149
# SELL SIGNALS: 416
# SIGNAL COUNTS: hold    514
# sell    416
# buy     111
# Name: signal, dtype: int64
# shape after: (1041, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 131 TIME -> 0:0:18
#
# 132
# RUN FOR BTEM
# shape before: (597, 14)
# BUY SIGNALS: 14
# SELL SIGNALS: 155
# SIGNAL COUNTS: hold    431
# sell    155
# buy      11
# Name: signal, dtype: int64
# shape after: (597, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 132 TIME -> 0:0:17
#
# 133
# RUN FOR BVIC
# shape before: (716, 14)
# BUY SIGNALS: 56
# SELL SIGNALS: 248
# SIGNAL COUNTS: hold    424
# sell    248
# buy      44
# Name: signal, dtype: int64
# shape after: (716, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 133 TIME -> 0:0:11
#
# 134
# RUN FOR CNE
# shape before: (1047, 14)
# BUY SIGNALS: 239
# SELL SIGNALS: 434
# SIGNAL COUNTS: hold    449
# sell    434
# buy     164
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 134 TIME -> 0:0:13
#
# 135
# RUN FOR CLDN
# shape before: (606, 14)
# BUY SIGNALS: 15
# SELL SIGNALS: 168
# SIGNAL COUNTS: hold    425
# sell    168
# buy      13
# Name: signal, dtype: int64
# shape after: (606, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 135 TIME -> 0:0:17
#
# 136
# RUN FOR CAPC
# shape before: (485, 14)
# BUY SIGNALS: 30
# SELL SIGNALS: 134
# SIGNAL COUNTS: hold    322
# sell    134
# buy      29
# Name: signal, dtype: int64
# shape after: (485, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 136 TIME -> 0:0:11
#
# 137
# RUN FOR CPI
# shape before: (1058, 14)
# BUY SIGNALS: 146
# SELL SIGNALS: 468
# SIGNAL COUNTS: hold    481
# sell    468
# buy     109
# Name: signal, dtype: int64
# shape after: (1058, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 137 TIME -> 0:0:9
#
# 138
# RUN FOR CARD
# shape before: (276, 14)
# BUY SIGNALS: 38
# SELL SIGNALS: 132
# SIGNAL COUNTS: sell    132
# hold    117
# buy      27
# Name: signal, dtype: int64
# shape after: (276, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 138 TIME -> 0:0:20
#
# 139
# RUN FOR CEY
# shape before: (922, 14)
# BUY SIGNALS: 217
# SELL SIGNALS: 373
# SIGNAL COUNTS: hold    404
# sell    373
# buy     145
# Name: signal, dtype: int64
# shape after: (922, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 139 TIME -> 0:0:7
#
# 140
# RUN FOR CCFS
# shape before: (100, 14)
# BUY SIGNALS: 12
# SELL SIGNALS: 30
# SIGNAL COUNTS: hold    59
# sell    30
# buy     11
# Name: signal, dtype: int64
# shape after: (100, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 140 TIME -> 0:0:19
#
# 141
# RUN FOR CINE
# shape before: (644, 14)
# BUY SIGNALS: 47
# SELL SIGNALS: 221
# SIGNAL COUNTS: hold    384
# sell    221
# buy      39
# Name: signal, dtype: int64
# shape after: (644, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 141 TIME -> 0:0:4
#
# 142
# RUN FOR CTY
# shape before: (608, 14)
# BUY SIGNALS: 18
# SELL SIGNALS: 158
# SIGNAL COUNTS: hold    436
# sell    158
# buy      14
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 142 TIME -> 0:0:14
#
# 143
# RUN FOR CKN
# shape before: (1029, 14)
# BUY SIGNALS: 150
# SELL SIGNALS: 277
# SIGNAL COUNTS: hold    629
# sell    277
# buy     123
# Name: signal, dtype: int64
# shape after: (1029, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 143 TIME -> 0:0:13
#
# 144
# RUN FOR CBG
# shape before: (1047, 14)
# BUY SIGNALS: 136
# SELL SIGNALS: 434
# SIGNAL COUNTS: hold    523
# sell    434
# buy      90
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 144 TIME -> 0:0:21
#
# 145
# RUN FOR CLI
# shape before: (1046, 14)
# BUY SIGNALS: 85
# SELL SIGNALS: 301
# SIGNAL COUNTS: hold    680
# sell    301
# buy      65
# Name: signal, dtype: int64
# shape after: (1046, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 145 TIME -> 0:0:17
#
# 146
# RUN FOR COA
# ...
# sell    412
# buy     125
# Name: signal, dtype: int64
# shape after: (1027, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 299 TIME -> 0:0:11
#
# 300
# RUN FOR SEQI
# shape before: (228, 14)
# BUY SIGNALS: 0
# SELL SIGNALS: 18
# SIGNAL COUNTS: hold    210
# sell     18
# Name: signal, dtype: int64
# shape after: (228, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 300 TIME -> 0:0:17
#
# 301
# RUN FOR SRP
# shape before: (1047, 14)
# BUY SIGNALS: 157
# SELL SIGNALS: 428
# SIGNAL COUNTS: hold    518
# sell    428
# buy     101
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 301 TIME -> 0:0:5
#
# 302
# RUN FOR SHB
# shape before: (1030, 14)
# BUY SIGNALS: 70
# SELL SIGNALS: 323
# SIGNAL COUNTS: hold    661
# sell    323
# buy      46
# Name: signal, dtype: int64
# shape after: (1030, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 302 TIME -> 0:0:17
#
# 303
# RUN FOR SHI
# shape before: (1041, 14)
# BUY SIGNALS: 162
# SELL SIGNALS: 450
# SIGNAL COUNTS: hold    482
# sell    450
# buy     109
# Name: signal, dtype: int64
# shape after: (1041, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 303 TIME -> 0:0:17
#
# 304
# RUN FOR SXX
# shape before: (672, 14)
# BUY SIGNALS: 179
# SELL SIGNALS: 378
# SIGNAL COUNTS: sell    378
# hold    213
# buy      81
# Name: signal, dtype: int64
# shape after: (672, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 304 TIME -> 0:0:17
#
# 305
# RUN FOR SSON
# shape before: (39, 14)
# BUY SIGNALS: 0
# SELL SIGNALS: 1
# SIGNAL COUNTS: hold    38
# sell     1
# Name: signal, dtype: int64
# shape after: (39, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 305 TIME -> 0:0:12
#
# 306
# RUN FOR SCT
# shape before: (198, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 49
# SIGNAL COUNTS: hold    132
# sell     49
# buy      17
# Name: signal, dtype: int64
# shape after: (198, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 306 TIME -> 0:0:2
#
# 307
# RUN FOR SOPH
# shape before: (218, 14)
# BUY SIGNALS: 43
# SELL SIGNALS: 93
# SIGNAL COUNTS: hold    101
# sell     93
# buy      24
# Name: signal, dtype: int64
# shape after: (218, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 307 TIME -> 0:0:5
#
# 308
# RUN FOR SXS
# shape before: (1045, 14)
# BUY SIGNALS: 156
# SELL SIGNALS: 408
# SIGNAL COUNTS: hold    529
# sell    408
# buy     108
# Name: signal, dtype: int64
# shape after: (1045, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 308 TIME -> 0:0:5
#
# 309
# RUN FOR SPT
# shape before: (1046, 14)
# BUY SIGNALS: 228
# SELL SIGNALS: 442
# SIGNAL COUNTS: hold    449
# sell    442
# buy     155
# Name: signal, dtype: int64
# shape after: (1046, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 309 TIME -> 0:0:18
#
# 310
# RUN FOR SPD
# shape before: (652, 14)
# BUY SIGNALS: 96
# SELL SIGNALS: 262
# SIGNAL COUNTS: hold    321
# sell    262
# buy      69
# Name: signal, dtype: int64
# shape after: (652, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 310 TIME -> 0:0:21
#
# 311
# RUN FOR SSPG
# shape before: (268, 14)
# BUY SIGNALS: 3
# SELL SIGNALS: 37
# SIGNAL COUNTS: hold    228
# sell     37
# buy       3
# Name: signal, dtype: int64
# shape after: (268, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 311 TIME -> 0:0:14
#
# 312
# RUN FOR SMP
# shape before: (1040, 14)
# BUY SIGNALS: 104
# SELL SIGNALS: 379
# SIGNAL COUNTS: hold    595
# sell    379
# buy      66
# Name: signal, dtype: int64
# shape after: (1040, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 312 TIME -> 0:0:7
#
# 313
# RUN FOR SGC
# shape before: (981, 14)
# BUY SIGNALS: 129
# SELL SIGNALS: 376
# SIGNAL COUNTS: hold    503
# sell    376
# buy     102
# Name: signal, dtype: int64
# shape after: (981, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 313 TIME -> 0:0:20
#
# 314
# RUN FOR SYNC
# shape before: (351, 14)
# BUY SIGNALS: 4
# SELL SIGNALS: 39
# SIGNAL COUNTS: hold    308
# sell     39
# buy       4
# Name: signal, dtype: int64
# shape after: (351, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 314 TIME -> 0:0:20
#
# 315
# RUN FOR SYNT
# shape before: (1047, 14)
# BUY SIGNALS: 148
# SELL SIGNALS: 441
# SIGNAL COUNTS: hold    493
# sell    441
# buy     113
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 315 TIME -> 0:0:7
#
# 316
# RUN FOR TALK
# shape before: (492, 14)
# BUY SIGNALS: 65
# SELL SIGNALS: 188
# SIGNAL COUNTS: hold    247
# sell    188
# buy      57
# Name: signal, dtype: int64
# shape after: (492, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 316 TIME -> 0:0:17
#
# 317
# RUN FOR TATE
# shape before: (1047, 14)
# BUY SIGNALS: 104
# SELL SIGNALS: 385
# SIGNAL COUNTS: hold    573
# sell    385
# buy      89
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 317 TIME -> 0:0:9
#
# 318
# RUN FOR TBCG
# shape before: (159, 14)
# BUY SIGNALS: 7
# SELL SIGNALS: 66
# SIGNAL COUNTS: hold    89
# sell    66
# buy      4
# Name: signal, dtype: int64
# shape after: (159, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 318 TIME -> 0:0:17
#
# 319
# RUN FOR TED
# shape before: (1047, 14)
# BUY SIGNALS: 119
# SELL SIGNALS: 397
# SIGNAL COUNTS: hold    552
# sell    397
# buy      98
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 319 TIME -> 0:0:4
#
# 320
# RUN FOR TEP
# shape before: (996, 14)
# BUY SIGNALS: 133
# SELL SIGNALS: 376
# SIGNAL COUNTS: hold    522
# sell    376
# buy      98
# Name: signal, dtype: int64
# shape after: (996, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 320 TIME -> 0:0:17
#
# 321
# RUN FOR TMPL
# shape before: (603, 14)
# BUY SIGNALS: 14
# SELL SIGNALS: 165
# SIGNAL COUNTS: hold    427
# sell    165
# buy      11
# Name: signal, dtype: int64
# shape after: (603, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 321 TIME -> 0:0:16
#
# 322
# RUN FOR TEM
# shape before: (604, 14)
# BUY SIGNALS: 41
# SELL SIGNALS: 202
# SIGNAL COUNTS: hold    367
# sell    202
# buy      35
# Name: signal, dtype: int64
# shape after: (604, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 322 TIME -> 0:0:11
#
# 323
# RUN FOR TIFS
# shape before: (96, 14)
# BUY SIGNALS: 22
# SELL SIGNALS: 43
# SIGNAL COUNTS: sell    43
# hold    42
# buy     11
# Name: signal, dtype: int64
# shape after: (96, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 323 TIME -> 0:0:11
#
# 324
# RUN FOR TCAP
# shape before: (973, 14)
# BUY SIGNALS: 174
# SELL SIGNALS: 396
# SIGNAL COUNTS: hold    454
# sell    396
# buy     123
# Name: signal, dtype: int64
# shape after: (973, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 324 TIME -> 0:0:3
#
# 325
# RUN FOR TRY
# shape before: (602, 14)
# BUY SIGNALS: 31
# SELL SIGNALS: 173
# SIGNAL COUNTS: hold    404
# sell    173
# buy      25
# Name: signal, dtype: int64
# shape after: (602, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 325 TIME -> 0:0:16
#
# 326
# RUN FOR TPK
# shape before: (1047, 14)
# BUY SIGNALS: 103
# SELL SIGNALS: 386
# SIGNAL COUNTS: hold    582
# sell    386
# buy      79
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 326 TIME -> 0:0:11
#
# 327
# RUN FOR BBOX
# shape before: (293, 14)
# BUY SIGNALS: 0
# SELL SIGNALS: 37
# SIGNAL COUNTS: hold    256
# sell     37
# Name: signal, dtype: int64
# shape after: (293, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 327 TIME -> 0:0:17
#
# 328
# RUN FOR TLW
# shape before: (1039, 14)
# BUY SIGNALS: 202
# SELL SIGNALS: 449
# SIGNAL COUNTS: hold    452
# sell    449
# buy     138
# Name: signal, dtype: int64
# shape after: (1039, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 328 TIME -> 0:0:6
#
# 329
# RUN FOR UDG
# shape before: (1026, 14)
# BUY SIGNALS: 99
# SELL SIGNALS: 333
# SIGNAL COUNTS: hold    614
# sell    333
# buy      79
# Name: signal, dtype: int64
# shape after: (1026, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 329 TIME -> 0:0:20
#
# 330
# RUN FOR UKCM
# shape before: (603, 14)
# BUY SIGNALS: 11
# SELL SIGNALS: 159
# SIGNAL COUNTS: hold    435
# sell    159
# buy       9
# Name: signal, dtype: int64
# shape after: (603, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 330 TIME -> 0:0:20
#
# 331
# RUN FOR ULE
# shape before: (1043, 14)
# BUY SIGNALS: 67
# SELL SIGNALS: 315
# SIGNAL COUNTS: hold    668
# sell    315
# buy      60
# Name: signal, dtype: int64
# shape after: (1043, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 331 TIME -> 0:0:13
#
# 332
# RUN FOR UTG
# shape before: (1047, 14)
# BUY SIGNALS: 119
# SELL SIGNALS: 354
# SIGNAL COUNTS: hold    608
# sell    354
# buy      85
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 332 TIME -> 0:0:21
#
# 333
# RUN FOR VSVS
# shape before: (1047, 14)
# BUY SIGNALS: 167
# SELL SIGNALS: 418
# SIGNAL COUNTS: hold    509
# sell    418
# buy     120
# Name: signal, dtype: int64
# shape after: (1047, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 333 TIME -> 0:0:21
#
# 334
# RUN FOR VCT
# shape before: (1012, 14)
# BUY SIGNALS: 107
# SELL SIGNALS: 319
# SIGNAL COUNTS: hold    613
# sell    319
# buy      80
# Name: signal, dtype: int64
# shape after: (1012, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 334 TIME -> 0:0:18
#
# 335
# RUN FOR VEIL
# shape before: (159, 14)
# BUY SIGNALS: 4
# SELL SIGNALS: 34
# SIGNAL COUNTS: hold    121
# sell     34
# buy       4
# Name: signal, dtype: int64
# shape after: (159, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 335 TIME -> 0:0:17
#
# 336
# RUN FOR VOF
# shape before: (608, 14)
# BUY SIGNALS: 61
# SELL SIGNALS: 201
# SIGNAL COUNTS: hold    360
# sell    201
# buy      47
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 336 TIME -> 0:0:5
#
# 337
# RUN FOR VVO
# shape before: (69, 14)
# BUY SIGNALS: 17
# SELL SIGNALS: 38
# SIGNAL COUNTS: sell    38
# hold    20
# buy     11
# Name: signal, dtype: int64
# shape after: (69, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 337 TIME -> 0:0:11
#
# 338
# RUN FOR WEIR
# shape before: (1045, 14)
# BUY SIGNALS: 150
# SELL SIGNALS: 376
# SIGNAL COUNTS: hold    552
# sell    376
# buy     117
# Name: signal, dtype: int64
# shape after: (1045, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 338 TIME -> 0:0:3
#
# 339
# RUN FOR JDW
# shape before: (1043, 14)
# BUY SIGNALS: 105
# SELL SIGNALS: 369
# SIGNAL COUNTS: hold    589
# sell    369
# buy      85
# Name: signal, dtype: int64
# shape after: (1043, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 339 TIME -> 0:0:18
#
# 340
# RUN FOR SMWH
# shape before: (681, 14)
# BUY SIGNALS: 31
# SELL SIGNALS: 211
# SIGNAL COUNTS: hold    445
# sell    211
# buy      25
# Name: signal, dtype: int64
# shape after: (681, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 340 TIME -> 0:0:17
#
# 341
# RUN FOR WMH
# shape before: (897, 14)
# BUY SIGNALS: 101
# SELL SIGNALS: 392
# SIGNAL COUNTS: hold    431
# sell    392
# buy      74
# Name: signal, dtype: int64
# shape after: (897, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 341 TIME -> 0:0:12
#
# 342
# RUN FOR WTAN
# shape before: (608, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 145
# SIGNAL COUNTS: hold    448
# sell    145
# buy      15
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 342 TIME -> 0:0:15
#
# 343
# RUN FOR WIZZ
# shape before: (235, 14)
# BUY SIGNALS: 18
# SELL SIGNALS: 56
# SIGNAL COUNTS: hold    162
# sell     56
# buy      17
# Name: signal, dtype: int64
# shape after: (235, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 343 TIME -> 0:0:11
#
# 344
# RUN FOR WPCT
# shape before: (221, 14)
# BUY SIGNALS: 17
# SELL SIGNALS: 121
# SIGNAL COUNTS: sell    121
# hold     83
# buy      17
# Name: signal, dtype: int64
# shape after: (221, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 344 TIME -> 0:0:6
#
# 345
# RUN FOR WG
# shape before: (900, 14)
# BUY SIGNALS: 158
# SELL SIGNALS: 405
# SIGNAL COUNTS: sell    405
# hold    385
# buy     110
# Name: signal, dtype: int64
# shape after: (900, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 345 TIME -> 0:0:5
#
# 346
# RUN FOR WKP
# shape before: (911, 14)
# BUY SIGNALS: 75
# SELL SIGNALS: 280
# SIGNAL COUNTS: hold    568
# sell    280
# buy      63
# Name: signal, dtype: int64
# shape after: (911, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 346 TIME -> 0:0:15
#
# 347
# RUN FOR WWH
# shape before: (608, 14)
# BUY SIGNALS: 19
# SELL SIGNALS: 125
# SIGNAL COUNTS: hold    465
# sell    125
# buy      18
# Name: signal, dtype: int64
# shape after: (608, 133)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
#
#
#
# TOTAL ELAPSED TIME -> 1:19:34
#
# ERROR COUNT: 0

# %%
#close any open h5 files
tables.file._open_files.close_all()
# Out:
# Closing remaining open files:C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5...done

# %%
tmp_df = pd.read_hdf(hf_store_name,key='weekly_data',mode='r')
print("")
print("FINAL HDFSTORE SIZE: {}".format(tmp_df.shape))
print("FINAL BUY COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "buy"])))
print("FINAL SELL COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "sell"])))
h_store.close()
tmp_df.head(50)
# tmp_df[(tmp_df["ticker"] == 'ADM') & (tmp_df["date"] > '2013-12-01') & (tmp_df["date"] < '2014-02-01')].head(200)
# Out:
# FINAL HDFSTORE SIZE: (257300, 60)
# FINAL BUY COUNT: 20322
# FINAL SELL COUNT: 90868
#    ticker       date      open     close      high       low    volume  \
# 0     III 2007-12-31       NaN       NaN       NaN       NaN       NaN
# 1     III 2008-01-07  0.000000  0.000000  0.000000  0.000000  1.000000
# 2     III 2008-01-14  0.000000  0.000000  0.000000  0.000000  1.000000
# 3     III 2008-01-21  0.000000  0.257812  0.333333  0.000000  0.776440
# 4     III 2008-01-28  0.192308  0.937500  0.402299  0.478632  0.440501
# 5     III 2008-02-04  0.759615  0.351562  0.591954  0.581197  0.636501
# 6     III 2008-02-11  0.182692  0.289062  0.120690  0.504274  0.446567
# 7     III 2008-02-18  0.288462  0.000000  0.275862  0.282051  0.476198
# 8     III 2008-02-25  0.004808  0.000000  0.000000  0.000000  0.938878
# 9     III 2008-03-03  0.000000  0.000000  0.000000  0.000000  0.824143
# 10    III 2008-03-10  0.000000  0.000000  0.000000  0.000000  0.654455
# 11    III 2008-03-17  0.000000  0.080605  0.000000  0.000000  0.660293
# 12    III 2008-03-24  0.202454  0.362720  0.245763  0.315240  0.413488
# 13    III 2008-03-31  0.343558  0.581864  0.455508  0.373695  0.621723
# 14    III 2008-04-07  0.562372  0.435768  0.468220  0.511482  0.287221
# 15    III 2008-04-14  0.390593  0.614610  0.461864  0.478079  0.212186
# 16    III 2008-04-21  0.578732  0.556675  0.451271  0.478079  0.265450
# 17    III 2008-04-28  0.533742  0.491184  0.406780  0.524008  0.210532
# 18    III 2008-05-05  0.468303  0.584383  0.512712  0.505219  0.179288
# 19    III 2008-05-12  0.554192  0.770781  0.616525  0.530271  0.798383
# 20    III 2008-05-19  0.715746  0.465995  0.601695  0.561587  0.569271
# 21    III 2008-05-26  0.470348  0.599496  0.500000  0.561587  0.221706
# 22    III 2008-06-02  0.552147  0.478589  0.453390  0.567850  0.466823
# 23    III 2008-06-09  0.441718  0.309824  0.330508  0.331942  0.494679
# 24    III 2008-06-16  0.308793  0.312343  0.271186  0.369520  0.565805
# 25    III 2008-06-23  0.286299  0.267003  0.264831  0.356994  0.516996
# 26    III 2008-06-30  0.261759  0.186398  0.192797  0.294363  0.460547
# 27    III 2008-07-07  0.237219  0.093199  0.177966  0.219207  0.543214
# 28    III 2008-07-14  0.204499  0.765743  0.563559  0.294363  0.672471
# 29    III 2008-07-21  0.672802  0.604534  0.709746  0.578288  0.643902
# 30    III 2008-07-28  0.556237  0.705290  0.561441  0.544885  0.260657
# 31    III 2008-08-04  0.656442  0.952141  0.733051  0.724426  0.273814
# 32    III 2008-08-11  0.862986  0.717884  0.758475  0.724426  0.158885
# 33    III 2008-08-18  0.648262  0.617128  0.521186  0.532359  0.118785
# 34    III 2008-08-25  0.498978  0.770781  0.567797  0.578288  0.150290
# 35    III 2008-09-01  0.668712  0.619647  0.669492  0.680585  0.377312
# 36    III 2008-09-08  0.707566  0.682620  0.675847  0.643006  0.333184
# 37    III 2008-09-15  0.509202  0.405542  0.394068  0.106472  1.000000
# 38    III 2008-09-22  0.496933  0.113350  0.372881  0.246347  0.462561
# 39    III 2008-09-29  0.147239  0.000000  0.010593  0.000000  0.657322
# 40    III 2008-10-06  0.000000  0.000000  0.000000  0.000000  0.905799
# 41    III 2008-10-13  0.000000  0.000000  0.000000  0.000000  0.979021
# 42    III 2008-10-20  0.000000  0.076130  0.000000  0.000000  0.878454
# 43    III 2008-10-27  0.000000  0.165029  0.029652  0.016152  0.424401
# 44    III 2008-11-03  0.172023  0.047151  0.161554  0.061283  0.501998
# 45    III 2008-11-10  0.047732  0.000000  0.000000  0.000000  0.423464
# 46    III 2008-11-17  0.000000  0.000000  0.000000  0.000000  0.396013
# 47    III 2008-11-24  0.000000  0.081743  0.047739  0.039527  0.371998
# 48    III 2008-12-01  0.063358  0.000000  0.000000  0.000000  0.347933
# 49    III 2008-12-08  0.000000  0.000000  0.000000  0.000000  0.647935
#
#     change_price  per_change_price  close_shift1  ...  \
# 0            NaN               NaN           NaN  ...
# 1       0.000000          0.000000           NaN  ...
# 2       1.000000          1.000000      0.000000  ...
# 3       1.000000          1.000000      0.000000  ...
# 4       1.000000          1.000000      0.257812  ...
# 5       0.000000          0.000000      0.937500  ...
# 6       0.580311          0.567750      0.351562  ...
# 7       0.088083          0.064953      0.289062  ...
# 8       0.000000          0.000000      0.000000  ...
# 9       0.295547          0.269560      0.000000  ...
# 10      0.502024          0.492710      0.000000  ...
# 11      0.854251          0.910824      0.000000  ...
# 12      0.906883          0.950777      0.080605  ...
# 13      0.979757          1.000000      0.362720  ...
# 14      0.311741          0.308763      0.581864  ...
# 15      0.939271          0.952041      0.435768  ...
# 16      0.473684          0.470914      0.614610  ...
# 17      0.457490          0.453118      0.556675  ...
# 18      0.736842          0.736742      0.491184  ...
# 19      0.866397          0.862879      0.584383  ...
# 20      0.056680          0.076003      0.770781  ...
# 21      0.757085          0.757384      0.465995  ...
# 22      0.400810          0.397099      0.599496  ...
# 23      0.348178          0.336656      0.478589  ...
# 24      0.615385          0.613293      0.309824  ...
# 25      0.587045          0.582831      0.312343  ...
# 26      0.506073          0.494671      0.267003  ...
# 27      0.404858          0.383015      0.186398  ...
# 28      1.000000          1.000000      0.093199  ...
# 29      0.234987          0.223176      0.765743  ...
# 30      0.488251          0.456839      0.604534  ...
# 31      0.616188          0.571203      0.705290  ...
# 32      0.109661          0.121134      0.952141  ...
# 33      0.279373          0.262964      0.717884  ...
# 34      0.629243          0.593046      0.617128  ...
# 35      0.255875          0.242068      0.770781  ...
# 36      0.271540          0.257400      0.619647  ...
# 37      0.237598          0.219468      0.682620  ...
# 38      0.000000          0.000000      0.405542  ...
# 39      0.087065          0.049067      0.113350  ...
# 40      0.000000          0.000000      0.000000  ...
# 41      0.447717          0.384266      0.000000  ...
# 42      0.707658          0.762179      0.000000  ...
# 43      0.870398          1.000000      0.076130  ...
# 44      0.425626          0.362009      0.165029  ...
# 45      0.457290          0.369270      0.047151  ...
# 46      0.505891          0.399728      0.000000  ...
# 47      0.759205          0.866275      0.000000  ...
# 48      0.433726          0.274414      0.081743  ...
# 49      0.480118          0.318417      0.000000  ...
#
#     max_change_signal_line_neg_val  min_change_signal_line_pos_val  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# 5                              NaN                             NaN
# 6                              NaN                             NaN
# 7                              NaN                             NaN
# 8                              NaN                             NaN
# 9                              NaN                             NaN
# 10                             NaN                             NaN
# 11                             NaN                             NaN
# 12                             NaN                             NaN
# 13                             NaN                             NaN
# 14                             NaN                             NaN
# 15                             NaN                             NaN
# 16                             NaN                             NaN
# 17                             NaN                             NaN
# 18                             NaN                             NaN
# 19                             NaN                             NaN
# 20                             NaN                             NaN
# 21                             NaN                             NaN
# 22                             NaN                             NaN
# 23                             NaN                             NaN
# 24                             NaN                             NaN
# 25                             NaN                             NaN
# 26                             NaN                             NaN
# 27                             NaN                             NaN
# 28                             NaN                             NaN
# 29                             NaN                             NaN
# 30                             NaN                             NaN
# 31                             NaN                             NaN
# 32                             NaN                             NaN
# 33                             NaN                             NaN
# 34                             NaN                             NaN
# 35                             NaN                             NaN
# 36                             NaN                        1.000000
# 37                             NaN                        1.000000
# 38                             NaN                        0.878507
# 39                             NaN                        0.495103
# 40                             1.0                        0.000000
# 41                             1.0                        0.000000
# 42                             1.0                        0.000000
# 43                             1.0                        0.000000
# 44                             1.0                        0.000000
# 45                             1.0                        0.000000
# 46                             1.0                        0.000000
# 47                             1.0                        0.000000
# 48                             1.0                        0.000000
# 49                             1.0                        0.000000
#
#     min_change_signal_line_neg_val  prev_max_macd_line_date_change  \
# 0                              NaN                             NaN
# 1                              NaN                             1.0
# 2                              NaN                             1.0
# 3                              NaN                             1.0
# 4                              NaN                             1.0
# 5                              NaN                             1.0
# 6                              NaN                             1.0
# 7                              NaN                             1.0
# 8                              NaN                             1.0
# 9                              NaN                             1.0
# 10                             NaN                             1.0
# 11                             NaN                             1.0
# 12                             NaN                             1.0
# 13                             NaN                             1.0
# 14                             NaN                             1.0
# 15                             NaN                             1.0
# 16                             NaN                             1.0
# 17                             NaN                             1.0
# 18                             NaN                             1.0
# 19                             NaN                             1.0
# 20                             NaN                             1.0
# 21                             NaN                             1.0
# 22                             NaN                             1.0
# 23                             NaN                             1.0
# 24                             NaN                             1.0
# 25                             NaN                             1.0
# 26                             NaN                             1.0
# 27                             NaN                             1.0
# 28                             NaN                             1.0
# 29                             NaN                             1.0
# 30                             NaN                             1.0
# 31                             NaN                             1.0
# 32                             NaN                             1.0
# 33                             NaN                             1.0
# 34                             NaN                             1.0
# 35                             NaN                             1.0
# 36                             NaN                             1.0
# 37                             NaN                             1.0
# 38                             NaN                             1.0
# 39                             NaN                             1.0
# 40                             1.0                             1.0
# 41                             1.0                             1.0
# 42                             1.0                             1.0
# 43                             1.0                             1.0
# 44                             1.0                             1.0
# 45                             1.0                             1.0
# 46                             1.0                             1.0
# 47                             1.0                             1.0
# 48                             1.0                             1.0
# 49                             1.0                             1.0
#
#     prev_min_macd_line_date_change  max_change_macd_line_pos_val  \
# 0                              NaN                           NaN
# 1                              1.0                           NaN
# 2                              1.0                           NaN
# 3                              1.0                           NaN
# 4                              1.0                           NaN
# 5                              1.0                           NaN
# 6                              1.0                           NaN
# 7                              1.0                           NaN
# 8                              1.0                           NaN
# 9                              1.0                           NaN
# 10                             1.0                           NaN
# 11                             1.0                           NaN
# 12                             1.0                           NaN
# 13                             1.0                           NaN
# 14                             1.0                           NaN
# 15                             1.0                           NaN
# 16                             1.0                           NaN
# 17                             1.0                           NaN
# 18                             1.0                           NaN
# 19                             1.0                           NaN
# 20                             1.0                           NaN
# 21                             1.0                           NaN
# 22                             1.0                           NaN
# 23                             1.0                           NaN
# 24                             1.0                           NaN
# 25                             1.0                           NaN
# 26                             1.0                           NaN
# 27                             1.0                           NaN
# 28                             1.0                      1.000000
# 29                             1.0                      0.482290
# 30                             1.0                      0.591241
# 31                             1.0                      0.959896
# 32                             1.0                      0.282680
# 33                             1.0                      0.013907
# 34                             1.0                      0.308229
# 35                             1.0                      0.000000
# 36                             1.0                      0.059941
# 37                             1.0                      0.000000
# 38                             1.0                      0.000000
# 39                             1.0                      0.000000
# 40                             1.0                      0.000000
# 41                             1.0                      0.000000
# 42                             1.0                      0.000000
# 43                             1.0                      0.000000
# 44                             1.0                      0.000000
# 45                             1.0                      0.000000
# 46                             1.0                      0.000000
# 47                             1.0                      0.000000
# 48                             1.0                      0.000000
# 49                             1.0                      0.000000
#
#     max_change_macd_line_neg_val  min_change_macd_line_pos_val  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# 5                            NaN                           NaN
# 6                            NaN                           NaN
# 7                            NaN                           NaN
# 8                            NaN                           NaN
# 9                            NaN                           NaN
# 10                           NaN                           NaN
# 11                           NaN                           NaN
# 12                           NaN                           NaN
# 13                           NaN                           NaN
# 14                           NaN                           NaN
# 15                           NaN                           NaN
# 16                           NaN                           NaN
# 17                           NaN                           NaN
# 18                           NaN                           NaN
# 19                           NaN                           NaN
# 20                           NaN                           NaN
# 21                           NaN                           NaN
# 22                           NaN                           NaN
# 23                           NaN                           NaN
# 24                           NaN                           NaN
# 25                           NaN                           NaN
# 26                      1.000000                           NaN
# 27                      1.000000                           NaN
# 28                      0.000000                      1.000000
# 29                      0.000000                      0.482290
# 30                      0.000000                      0.591241
# 31                      0.000000                      0.959896
# 32                      0.000000                      0.282680
# 33                      0.000000                      0.013907
# 34                      0.000000                      0.308229
# 35                      0.149574                      0.000000
# 36                      0.000000                      0.059941
# 37                      1.000000                      0.000000
# 38                      1.000000                      0.000000
# 39                      1.000000                      0.000000
# 40                      1.000000                      0.000000
# 41                      0.899446                      0.000000
# 42                      0.559438                      0.000000
# 43                      0.267078                      0.000000
# 44                      0.352279                      0.000000
# 45                      0.399944                      0.000000
# 46                      0.455341                      0.000000
# 47                      0.156657                      0.000000
# 48                      0.284136                      0.000000
# 49                      0.256417                      0.000000
#
#     min_change_macd_line_neg_val  signal
# 0                            NaN    hold
# 1                            NaN    hold
# 2                            NaN    hold
# 3                            NaN    hold
# 4                            NaN    hold
# 5                            NaN    sell
# 6                            NaN    sell
# 7                            NaN    sell
# 8                            NaN    sell
# 9                            NaN     buy
# 10                           NaN     buy
# 11                           NaN     buy
# 12                           NaN     buy
# 13                           NaN    hold
# 14                           NaN    hold
# 15                           NaN    hold
# 16                           NaN    hold
# 17                           NaN    hold
# 18                           NaN    hold
# 19                           NaN    hold
# 20                           NaN    sell
# 21                           NaN    sell
# 22                           NaN    sell
# 23                           NaN     buy
# 24                           NaN     buy
# 25                           NaN     buy
# 26                      1.000000    sell
# 27                      1.000000    sell
# 28                      0.000000    sell
# 29                      0.000000    sell
# 30                      0.000000    sell
# 31                      0.000000    sell
# 32                      0.000000    sell
# 33                      0.000000    sell
# 34                      0.000000    sell
# 35                      0.149574    sell
# 36                      0.000000    sell
# 37                      1.000000    sell
# 38                      1.000000    sell
# 39                      1.000000    sell
# 40                      1.000000    sell
# 41                      0.899446    sell
# 42                      0.559438    sell
# 43                      0.267078    sell
# 44                      0.352279    sell
# 45                      0.399944    sell
# 46                      0.455341    sell
# 47                      0.156657    sell
# 48                      0.284136    sell
# 49                      0.256417    sell
#
# [50 rows x 60 columns]

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(path+'all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(path+'all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(path+'all_hist_prices_w_ft_eng2_TMP.h5',path+'all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(path+'all_hist_prices_w_ft_eng2_TMP.h5',path+'all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5

# %%
#Export a list of the features for this model
file_object = open(path+r'random_forest_model_feature_list.txt','w')
feature_str = ''
for i in out_cols:
    feature_str += '{},'.format(i)
feature_str = feature_str[:-1]
file_object.write(feature_str)
file_object.close()
feature_str
# Out:
# 'ticker,date,open,close,high,low,volume,change_price,per_change_price,close_shift1,change_close_shift1,vol_shift1,change_vol_shift1,ema26_shift1,change_ema26_shift1,close_13_norm,close_26_norm,close_52_norm,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,macd_pos_val,macd_neg_val,signal_line_pos_val,signal_line_neg_val,change_price_pos_val,change_price_neg_val,per_change_price_pos_val,per_change_price_neg_val,prev_max_close_date_change,prev_min_close_date_change,max_change_close_pos_val,max_change_close_neg_val,min_change_close_pos_val,min_change_close_neg_val,prev_max_macd_date_change,prev_min_macd_date_change,max_change_macd_pos_val,max_change_macd_neg_val,min_change_macd_pos_val,min_change_macd_neg_val,prev_max_ema26_date_change,prev_min_ema26_date_change,max_change_ema26_pos_val,max_change_ema26_neg_val,min_change_ema26_pos_val,min_change_ema26_neg_val,prev_max_signal_line_date_change,prev_min_signal_line_date_change,max_change_signal_line_pos_val,max_change_signal_line_neg_val,min_change_signal_line_pos_val,min_change_signal_line_neg_val,prev_max_macd_line_date_change,prev_min_macd_line_date_change,max_change_macd_line_pos_val,max_change_macd_line_neg_val,min_change_macd_line_pos_val,min_change_macd_line_neg_val,signal'
