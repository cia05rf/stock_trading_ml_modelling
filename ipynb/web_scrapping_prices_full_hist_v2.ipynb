# %% [markdown]
# # Web scrapping stock prices
# This code accesses site to retrieve stock price information and then saves it to an individual csv file for each stock.
#
# This code is for 10 YEAR STOCK HISTORY
#
# The sources of data are:
# - https://en.wikipedia.org/wiki/FTSE_100_Index -> list of FTSE 100 company stock tickers
# - https://en.wikipedia.org/wiki/FTSE_250_Index -> list of FTSE 250 company stock tickers
# - https://finance.yahoo.com/quote/{stock-ticker}/history?period1={start-time-mark}&period2={end-time-mark}&interval={interval}&filter=history&frequency={frequency} -> Example web address to retrieve information from Yahoo finance
#     - Data on this page is scroll loaded so many time indexes must be used toretrieve the dcorrect data
#     - Up to 145 records can be seen from initial page load note that this includes dividends so limit to 140 for safety
#
# The inputs required for scrapping are:
#  - {stock-ticker} -> this is the ticker taken from wiki with ".L" appended to it
#  - {start-tme-mark} -> This is the time in seconds since 01/01/1970 at which you would like the data retrieval to start, data retrieved is inclusive of this time
#  - {end-tme-mark} -> This is the time in seconds since 01/01/1970, data retrieved is inclusive of this time
#  - {interval} & {frequency} -> This is the interval for which values are given, the two must match
#      - 1d = 1 every 1 days
#      - 1wk = 1 every week
#      - 1mo = 1 eveery month

# %%
#Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
import requests as rq
import re
import datetime as dt
import os
import tables

# %%
#Set options for matplotlib
# %matplotlib inline

# %%
#Clean column names
def clean_col_name(str_in):
    str_out = str_in.lower() #Change all to lower case
    str_out = re.sub(r'.*\.','',str_out) #Remove everything before a .
    str_out = re.sub(r' ','_',str_out) #Replace spaces with _
    str_out = re.sub(r'_?&_?','_and_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'_?@_?','_at_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'[^0-9a-z_]','',str_out) #Remove all non allowed characters
    str_out = re.sub(r'^_','',str_out) #Remove leading _
    return str_out

# %%
class process_time:
    def __init__(self,name:str = ''):
        self.st_time = dt.datetime.now()
        self.lap_li = []
        self.en_time = None
        self.name = name
    def calc_el_time(self,st_time,en_time):
        diff_time = en_time - st_time
        duration_in_s = diff_time.total_seconds()
        hours = int(divmod(duration_in_s, 3600)[0])
        duration_in_s += -(hours * 3600)
        minutes = int(divmod(duration_in_s, 60)[0])
        duration_in_s += -(minutes * 60)
        seconds = int(duration_in_s)
        return [hours,minutes,seconds]
    def lap(self):
        self.lap_li.append(dt.datetime.now())
    def end(self):
        self.en_time = dt.datetime.now()
        lap_time = self.calc_el_time(self.st_time,self.en_time)
        if self.name != '':
            print('TOTAL ELAPSED TIME OF {} -> {}:{}:{}'.format(self.name,lap_time[0],lap_time[1],lap_time[2]))
        else:
            print('TOTAL ELAPSED TIME -> {}:{}:{}'.format(lap_time[0],lap_time[1],lap_time[2]))
    def show_lap_times(self):
        tmp_count = 0
        for lap in self.lap_li:
            tmp_count += 1
            lap_time = self.calc_el_time(self.st_time,lap)
            print('LAP {} TIME -> {}:{}:{}'.format(tmp_count,lap_time[0],lap_time[1],lap_time[2]))
    def show_latest_lap_time(self):
        if len(self.lap_li) == 0:
            return
        elif len(self.lap_li) < 2:
            lap_time = self.calc_el_time(self.st_time,self.lap_li[-1])
        else:
            lap_time = self.calc_el_time(self.lap_li[-2],self.lap_li[-1])
        print('LAP {} TIME -> {}:{}:{}'.format(len(self.lap_li),lap_time[0],lap_time[1],lap_time[2]))

# %% [markdown]
# # Delete the old temporary files (if they exist)

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 files
src_fldr_pth = r'C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\'
try:
    os.remove(src_fldr_pth + r'all_hist_prices_d_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_d_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.remove(src_fldr_pth + r'all_hist_prices_w_TMP.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_w_TMP.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d_TMP.h5
#
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w_TMP.h5

# %% [markdown]
# # Scraping tickers
# This section will scrap the ticker values for the FTSE 100 and FTSE 250 and store them in dataframes "tick_ftse100" and "tick_ftse250".
#
# Finally concatenate into 1 dataframe "tick_ftse".

# %%
#Fetch the data for ftse 100
web_add = 'https://en.wikipedia.org/wiki/FTSE_100_Index'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Get the table id=constituents
table = parser.find_all('table',id='constituents')[0]
#Get rows ignoring first row
rows = table.find_all('tr')[1:]
row_li = []
for r in rows:
    temp_row = []
    for r2 in r.find_all('td'):
        temp_row.append(re.sub('(?=[A-Z]*)\..*','',r2.text.upper().rstrip()))
    temp_row = temp_row[:2]
    row_li.append(temp_row)
#Create a dataframe
tick_ftse100 = pd.DataFrame(data=row_li,columns=['company','ticker'])
tick_ftse100['index'] = 'FTSE100'
tick_ftse100
# Out:
#                                company ticker    index
# 0                                   3I    III  FTSE100
# 1                        ADMIRAL GROUP    ADM  FTSE100
# 2                   ANGLO AMERICAN PLC    AAL  FTSE100
# 3                          ANTOFAGASTA   ANTO  FTSE100
# 4                        ASHTEAD GROUP    AHT  FTSE100
# 5             ASSOCIATED BRITISH FOODS    ABF  FTSE100
# 6                          ASTRAZENECA    AZN  FTSE100
# 7                    AUTO TRADER GROUP   AUTO  FTSE100
# 8                                AVEVA    AVV  FTSE100
# 9                                AVIVA     AV  FTSE100
# 10                         BAE SYSTEMS     BA  FTSE100
# 11                            BARCLAYS   BARC  FTSE100
# 12                BARRATT DEVELOPMENTS   BDEV  FTSE100
# 13             BERKELEY GROUP HOLDINGS    BKG  FTSE100
# 14                                 BHP    BHP  FTSE100
# 15                                  BP     BP  FTSE100
# 16            BRITISH AMERICAN TOBACCO   BATS  FTSE100
# 17                        BRITISH LAND   BLND  FTSE100
# 18                            BT GROUP   BT-A  FTSE100
# 19                               BUNZL   BNZL  FTSE100
# 20                            BURBERRY   BRBY  FTSE100
# 21          CARNIVAL CORPORATION & PLC    CCL  FTSE100
# 22                            CENTRICA    CNA  FTSE100
# 23                       COCA-COLA HBC    CCH  FTSE100
# 24                       COMPASS GROUP    CPG  FTSE100
# 25                             CRH PLC    CRH  FTSE100
# 26                 CRODA INTERNATIONAL   CRDA  FTSE100
# 27                             DCC PLC    DCC  FTSE100
# 28                              DIAGEO    DGE  FTSE100
# 29                   DIRECT LINE GROUP    DLG  FTSE100
# ..                                 ...    ...      ...
# 70                    RENTOKIL INITIAL    RTO  FTSE100
# 71                     RIO TINTO GROUP    RIO  FTSE100
# 72                           RIGHTMOVE    RMV  FTSE100
# 73                ROLLS-ROYCE HOLDINGS     RR  FTSE100
# 74        ROYAL BANK OF SCOTLAND GROUP    RBS  FTSE100
# 75                   ROYAL DUTCH SHELL   RDSA  FTSE100
# 76                 RSA INSURANCE GROUP    RSA  FTSE100
# 77                          SAGE GROUP    SGE  FTSE100
# 78                         SAINSBURY'S   SBRY  FTSE100
# 79                           SCHRODERS    SDR  FTSE100
# 80  SCOTTISH MORTGAGE INVESTMENT TRUST    SMT  FTSE100
# 81                               SEGRO   SGRO  FTSE100
# 82                        SEVERN TRENT    SVT  FTSE100
# 83                      SMITH & NEPHEW     SN  FTSE100
# 84                            SMITH, D   SMDS  FTSE100
# 85                        SMITHS GROUP   SMIN  FTSE100
# 86                       SMURFIT KAPPA    SKG  FTSE100
# 87            SPIRAX-SARCO ENGINEERING    SPX  FTSE100
# 88                             SSE PLC    SSE  FTSE100
# 89                  STANDARD CHARTERED   STAN  FTSE100
# 90              STANDARD LIFE ABERDEEN    SLA  FTSE100
# 91                                  ST    STJ  FTSE100
# 92                       TAYLOR WIMPEY     TW  FTSE100
# 93                               TESCO   TSCO  FTSE100
# 94                                 TUI    TUI  FTSE100
# 95                            UNILEVER   ULVR  FTSE100
# 96                    UNITED UTILITIES     UU  FTSE100
# 97                      VODAFONE GROUP    VOD  FTSE100
# 98                           WHITBREAD    WTB  FTSE100
# 99                             WPP PLC    WPP  FTSE100
#
# [100 rows x 3 columns]

# %%
#Fetch the data for ftse 250
web_add = 'https://en.wikipedia.org/wiki/FTSE_250_Index'
resp = rq.get(web_add)
parser = bs(resp.content,'html.parser')
#Get the table id=constituents
table = parser.find_all('table',id='constituents')[0]
#Get rows ignoring first row
rows = table.find_all('tr')[1:]
row_li = []
for r in rows:
    temp_row = []
    for r2 in r.find_all('td'):
        temp_row.append(re.sub('(?=[A-Z]*)\..*','',r2.text.upper().rstrip()))
    temp_row = temp_row[:2]
    row_li.append(temp_row)
#Create a dataframe
tick_ftse250 = pd.DataFrame(data=row_li,columns=['company','ticker'])
tick_ftse250['index'] = 'FTSE250'
tick_ftse250
# Out:
#                                          company ticker    index
# 0                              3I INFRASTRUCTURE    3IN  FTSE250
# 1                                       4IMPRINT   FOUR  FTSE250
# 2              ABERFORTH SMALLER COMPANIES TRUST    ASL  FTSE250
# 3                                  ACACIA MINING    ACA  FTSE250
# 4                                        AGGREKO    AGK  FTSE250
# 5                                 ALLIANCE TRUST   ATST  FTSE250
# 6                                          AMIGO   AMGO  FTSE250
# 7                              APAX GLOBAL ALPHA   APAX  FTSE250
# 8                                      ASCENTIAL   ASCL  FTSE250
# 9                                  ASHMORE GROUP   ASHM  FTSE250
# 10                                        ASSURA    AGR  FTSE250
# 11                          ASTON MARTIN LAGONDA    AML  FTSE250
# 12                                         AVAST   AVST  FTSE250
# 13                              AVI GLOBAL TRUST    AGT  FTSE250
# 14                         BABCOCK INTERNATIONAL    BAB  FTSE250
# 15                   BAILLIE GIFFORD JAPAN TRUST   BGFD  FTSE250
# 16                                      BAKKAVÖR   BAKK  FTSE250
# 17                                BALFOUR BEATTY    BBY  FTSE250
# 18                      BANKERS INVESTMENT TRUST   BNKR  FTSE250
# 19                                       BARR, A    BAG  FTSE250
# 20                                  BBA AVIATION    BBA  FTSE250
# 21                                          BBGI   BBGI  FTSE250
# 22                               BCA MARKETPLACE    BCA  FTSE250
# 23                               BANK OF GEORGIA   BGEO  FTSE250
# 24                                 BEAZLEY GROUP    BEZ  FTSE250
# 25                                       AJ BELL    AJB  FTSE250
# 26                                       BELLWAY    BWY  FTSE250
# 27                              BIG YELLOW GROUP    BYG  FTSE250
# 28                   B & M EUROPEAN RETAIL VALUE    BME  FTSE250
# 29             BLACKROCK SMALLER COMPANIES TRUST   BRSC  FTSE250
# ..                                           ...    ...      ...
# 220                                     TBC BANK   TBCG  FTSE250
# 221                                    TED BAKER    TED  FTSE250
# 222                                 TELECOM PLUS    TEP  FTSE250
# 223                  TEMPLE BAR INVESTMENT TRUST   TMPL  FTSE250
# 224  TEMPLETON EMERGING MARKETS INVESTMENT TRUST    TEM  FTSE250
# 225                             TI FLUID SYSTEMS   TIFS  FTSE250
# 226                                      TP ICAP   TCAP  FTSE250
# 227                               TRAVIS PERKINS    TRY  FTSE250
# 228                          TRITAX BIG BOX REIT    TPK  FTSE250
# 229                 TR PROPERTY INVESTMENT TRUST   BBOX  FTSE250
# 230                                   TULLOW OIL    TLW  FTSE250
# 231                               UDG HEALTHCARE    UDG  FTSE250
# 232                 UK COMMERCIAL PROPERTY TRUST   UKCM  FTSE250
# 233                   ULTRA ELECTRONICS HOLDINGS    ULE  FTSE250
# 234                                  UNITE GROUP    UTG  FTSE250
# 235                                     VESUVIUS   VSVS  FTSE250
# 236                                      VICTREX    VCT  FTSE250
# 237               VIETNAM ENTERPRISE INVESTMENTS   VEIL  FTSE250
# 238         VINACAPITAL VIETNAM OPPORTUNITY FUND    VOF  FTSE250
# 239                                  VIVO ENERGY    VVO  FTSE250
# 240                                   WEIR GROUP   WEIR  FTSE250
# 241                            WETHERSPOON (J D)    JDW  FTSE250
# 242                                    W H SMITH   SMWH  FTSE250
# 243                                 WILLIAM HILL    WMH  FTSE250
# 244                       WITAN INVESTMENT TRUST   WTAN  FTSE250
# 245                                     WIZZ AIR   WIZZ  FTSE250
# 246               WOODFORD PATIENT CAPITAL TRUST   WPCT  FTSE250
# 247                                   WOOD GROUP     WG  FTSE250
# 248                              WORKSPACE GROUP    WKP  FTSE250
# 249                   WORLDWIDE HEALTHCARE TRUST    WWH  FTSE250
#
# [250 rows x 3 columns]

# %%
#Combine into 1 dataframe
tick_ftse = pd.concat([tick_ftse100,tick_ftse250])
tick_ftse
# Out:
#                                          company ticker    index
# 0                                             3I    III  FTSE100
# 1                                  ADMIRAL GROUP    ADM  FTSE100
# 2                             ANGLO AMERICAN PLC    AAL  FTSE100
# 3                                    ANTOFAGASTA   ANTO  FTSE100
# 4                                  ASHTEAD GROUP    AHT  FTSE100
# 5                       ASSOCIATED BRITISH FOODS    ABF  FTSE100
# 6                                    ASTRAZENECA    AZN  FTSE100
# 7                              AUTO TRADER GROUP   AUTO  FTSE100
# 8                                          AVEVA    AVV  FTSE100
# 9                                          AVIVA     AV  FTSE100
# 10                                   BAE SYSTEMS     BA  FTSE100
# 11                                      BARCLAYS   BARC  FTSE100
# 12                          BARRATT DEVELOPMENTS   BDEV  FTSE100
# 13                       BERKELEY GROUP HOLDINGS    BKG  FTSE100
# 14                                           BHP    BHP  FTSE100
# 15                                            BP     BP  FTSE100
# 16                      BRITISH AMERICAN TOBACCO   BATS  FTSE100
# 17                                  BRITISH LAND   BLND  FTSE100
# 18                                      BT GROUP   BT-A  FTSE100
# 19                                         BUNZL   BNZL  FTSE100
# 20                                      BURBERRY   BRBY  FTSE100
# 21                    CARNIVAL CORPORATION & PLC    CCL  FTSE100
# 22                                      CENTRICA    CNA  FTSE100
# 23                                 COCA-COLA HBC    CCH  FTSE100
# 24                                 COMPASS GROUP    CPG  FTSE100
# 25                                       CRH PLC    CRH  FTSE100
# 26                           CRODA INTERNATIONAL   CRDA  FTSE100
# 27                                       DCC PLC    DCC  FTSE100
# 28                                        DIAGEO    DGE  FTSE100
# 29                             DIRECT LINE GROUP    DLG  FTSE100
# ..                                           ...    ...      ...
# 220                                     TBC BANK   TBCG  FTSE250
# 221                                    TED BAKER    TED  FTSE250
# 222                                 TELECOM PLUS    TEP  FTSE250
# 223                  TEMPLE BAR INVESTMENT TRUST   TMPL  FTSE250
# 224  TEMPLETON EMERGING MARKETS INVESTMENT TRUST    TEM  FTSE250
# 225                             TI FLUID SYSTEMS   TIFS  FTSE250
# 226                                      TP ICAP   TCAP  FTSE250
# 227                               TRAVIS PERKINS    TRY  FTSE250
# 228                          TRITAX BIG BOX REIT    TPK  FTSE250
# 229                 TR PROPERTY INVESTMENT TRUST   BBOX  FTSE250
# 230                                   TULLOW OIL    TLW  FTSE250
# 231                               UDG HEALTHCARE    UDG  FTSE250
# 232                 UK COMMERCIAL PROPERTY TRUST   UKCM  FTSE250
# 233                   ULTRA ELECTRONICS HOLDINGS    ULE  FTSE250
# 234                                  UNITE GROUP    UTG  FTSE250
# 235                                     VESUVIUS   VSVS  FTSE250
# 236                                      VICTREX    VCT  FTSE250
# 237               VIETNAM ENTERPRISE INVESTMENTS   VEIL  FTSE250
# 238         VINACAPITAL VIETNAM OPPORTUNITY FUND    VOF  FTSE250
# 239                                  VIVO ENERGY    VVO  FTSE250
# 240                                   WEIR GROUP   WEIR  FTSE250
# 241                            WETHERSPOON (J D)    JDW  FTSE250
# 242                                    W H SMITH   SMWH  FTSE250
# 243                                 WILLIAM HILL    WMH  FTSE250
# 244                       WITAN INVESTMENT TRUST   WTAN  FTSE250
# 245                                     WIZZ AIR   WIZZ  FTSE250
# 246               WOODFORD PATIENT CAPITAL TRUST   WPCT  FTSE250
# 247                                   WOOD GROUP     WG  FTSE250
# 248                              WORKSPACE GROUP    WKP  FTSE250
# 249                   WORLDWIDE HEALTHCARE TRUST    WWH  FTSE250
#
# [350 rows x 3 columns]

# %% [markdown]
# # Scraping a stock history
# Working backwards through time from now until 01/01/1970 collect all the daily data for a stock. Daily is used as it can later be summarised into weekly or monthly if required.
#
# This will then be put into a dataframe containing:
# - Ticker
# - Company name
# - Date
# - Open
# - High
# - Low
# - Close
# - Adjusted close (for divs and splits)
# - Volume

# %%
#Create a list of time intervals to be used with 140 days in each item
def create_sec_ref_li(_st_date:int,_en_date:int):
    #Establish the day ref of the dates compared to 01/01/1970
    _ep_date = pd.to_datetime(dt.datetime(1970,1,1),errors='coerce')
    _en_date = pd.to_datetime(_en_date,errors='coerce')
    _st_date = pd.to_datetime(_st_date,errors='coerce')
    print('_st_date: ' + str(_st_date))
    print('_en_date: ' + str(_en_date))
    _st_days = (_st_date - _ep_date).days
    _en_days = (_en_date - _ep_date).days
    #Loop adding to a list until reaching 0
    _sec_ref_li = []
    _days = 140
    while _en_days > _st_days:
        if _en_days - _days > _st_days:
            _sec_ref_li.append([(_en_days - _days)*86400,_en_days*86400])
        else:
            _sec_ref_li.append([_st_days*86400,_en_days*86400])        
        _en_days += -_days
    return _sec_ref_li

# %%
def calc_ema(s_in,periods):
    #Calc mod val
    mod = 2/(periods+1)
    #Make a df
    tmp_df = pd.DataFrame(s_in)
    #Calc sma
    tmp_df["sma"] = pd.Series([0] * len(s_in))
    for i in range(0,periods):
        tmp_df["sma"] += tmp_df[s_in.name].shift(i) / periods
    #Calc ema
    tmp_df["ema"] = tmp_df["sma"].copy()
    for row in tmp_df.iterrows():
        i = row[0]
        if i > 0 and not np.isnan(tmp_df["sma"][i-1]):
            tmp_df["ema"][i] = mod*(tmp_df[s_in.name][i] - tmp_df["ema"][i-1]) + tmp_df["ema"][i-1]
    return tmp_df["ema"].copy()

# %%
def calc_macd(ema_lng_s,ema_sht_s,sig_period):
    #Make a df
    tmp_df = pd.DataFrame([])
    tmp_df["ema_lng"] = ema_lng_s
    tmp_df["ema_sht"] = ema_sht_s
    #Calc the signal line
    tmp_df["macd_line"] = tmp_df["ema_sht"] - tmp_df["ema_lng"]
    tmp_df["signal"] = calc_ema(tmp_df["macd_line"],sig_period)
    tmp_df["macd_hist"] = tmp_df["macd_line"] - tmp_df["signal"]
    return (tmp_df["macd_line"].copy(),tmp_df["signal"].copy(),tmp_df["macd_hist"].copy())

# %%
col_lens = {
     'ticker': 4,
     'date': 19,
     'open': 7,
     'close': 7,
     'high': 7,
     'low': 7,
     'change': 21,
     'volume': 12,
     'ema12': 18,
     'ema26': 18,
     'macd_line': 23,
     'signal': 23,
     'macd': 23
}

# %%
#Get the price history for a specific ticker
def get_price_hist_d(_tick:str,_sec_ref_li:list):
    try:
        _tick = re.sub('[^A-Z0-9\-]','',_tick)
        print('Getting DAILY prices for:{}'.format(_tick))
        _tick_df = pd.DataFrame([])
        _cols = []

        for _secs in _sec_ref_li:
            try:
                _web_add = 'https://finance.yahoo.com/quote/{0}/history?period1={1}&period2={2}&interval={3}&filter=history&frequency={3}'.format(_tick+'.L',_secs[0],_secs[1],'1d')
#                 print('_web_add: {}'.format(_web_add))
                _resp = rq.get(_web_add)
                if int(_resp.status_code) != 200:
                    print('status code: {}'.format(_resp.status_code))
                    continue
                _parser = bs(_resp.content,'html.parser')
                #Get the table
                _table = _parser.find_all('table',attrs={'data-test':'historical-prices'})[0]
                #Grab the data rows
                _rows = _table.find_all('tbody')[0].find_all('tr')
                #Put the rows into the dataframe
                for _r in _rows:
                    if _tick_df.shape[0] == 0:
                        _cols = [clean_col_name(x.text) for x in _table.find_all('th')]
                        _tick_df = pd.DataFrame([],columns=_cols)
                    if len(_r.find_all('td')) == len(_cols):
                        _tick_df = _tick_df.append(pd.Series([x.text for x in _r.find_all('td')],index=_cols),ignore_index=True)
                    else:
                        continue
            except Exception as e:
                print('ERROR - CONTINUE:{}'.format(e))
                continue
        #Check for rows - if none then return
        if len(_tick_df) == 0:
            return _tick_df
        #Reformat
        def float_format(_str_in):
            if type(_str_in) == str:
                _str_in = _str_in.strip()
                _str_in = re.sub('[^0-9.]','',_str_in)
                if _str_in == '':
                    _str_in = 0
                return _str_in
            else:
                return _str_in
        _tick_df.loc[:,'open'] = _tick_df.loc[:,'open'].apply(float_format).astype(float)
        _tick_df.loc[:,'high'] = _tick_df.loc[:,'high'].apply(float_format).astype(float)
        _tick_df.loc[:,'low'] = _tick_df.loc[:,'low'].apply(float_format).astype(float)
        _tick_df.loc[:,'close'] = _tick_df.loc[:,'close'].apply(float_format).astype(float)
        _tick_df.loc[:,'adj_close'] = _tick_df.loc[:,'adj_close'].apply(float_format).astype(float)
        _tick_df.loc[:,'volume'] = _tick_df.loc[:,'volume'].apply(float_format).astype(float)
        _tick_df.loc[:,'change'] = _tick_df.loc[:,'close'] - _tick_df.loc[:,'open']
        def conv_date(_str_in):
            if type(_str_in) == str:
                return dt.datetime.strptime(_str_in,'%b %d, %Y')
            else:
                return _str_in
        _tick_df.loc[:,'date'] = _tick_df.loc[:,'date'].apply(conv_date)
        #Add the ticker series
        _tick_df.loc[:,'ticker'] = _tick    
        _tick_df = _tick_df.loc[:,['ticker','date','open','close','high','low','change','volume']]
        #CLEANING - Remove any rows with zero volume
        _tick_df = _tick_df[_tick_df['volume'] > 0]
        #CLEANING - Copy row above where the change has been more than 90%
        _tick_df['cl_change'] = (_tick_df['close'] - _tick_df['close'].shift(1))/_tick_df['close'].shift(1)
        _check_s = _tick_df['cl_change'] < -0.9
        _tick_df.loc[_check_s,'open'] = _tick_df['open'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'close'] = _tick_df['close'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'high'] = _tick_df['high'].shift(-1).copy().loc[_check_s]
        _tick_df.loc[_check_s,'low'] = _tick_df['low'].shift(-1).copy().loc[_check_s]
        _tick_df.drop(columns='cl_change',inplace=True)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

#Calc the ema and macds for the data
def calc_ema_macd(_tick_df):
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        #Sort clean and export
        _tick_df = _tick_df.sort_values(by='date')
        _tick_df = _tick_df.reset_index(drop=True)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

# %%
#Create a weekly table
def get_price_hist_w(_df_d):
    print('Converting daily prices to weekly prices')
    try:
        #Create a copy of the data
        _df_d = _df_d.copy()
        #Establish a week number for each date
        _df_d['isocalendar'] = [x.isocalendar()[:2] for x in _df_d['date']]
        #Get highs and lows
        _high_df = _df_d[['high','isocalendar']].groupby('isocalendar').max().reset_index()
        _low_df = _df_d[['low','isocalendar']].groupby('isocalendar').min().reset_index()
        #Get total volume for the week
        _vol_df = _df_d[['volume','isocalendar']].groupby('isocalendar').sum().reset_index()
        #Get open price
        _min_wk_day = _df_d[['date','isocalendar']].groupby('isocalendar').min().reset_index()
        _open_df = pd.merge(_df_d[['date','open']],_min_wk_day,left_on='date',right_on='date')
        #Get close price
        _max_wk_day = _df_d[['date','isocalendar']].groupby('isocalendar').max().reset_index()
        _close_df = pd.merge(_df_d[['date','close']],_max_wk_day,left_on='date',right_on='date').reset_index()
        #Form the final df
        _wk_df = pd.merge(_df_d[['ticker','isocalendar']],_min_wk_day,left_on='isocalendar',right_on='isocalendar') #date
        _wk_df = pd.merge(_wk_df,_high_df,left_on='isocalendar',right_on='isocalendar') #high
        _wk_df = pd.merge(_wk_df,_low_df,left_on='isocalendar',right_on='isocalendar') #low
        _wk_df = pd.merge(_wk_df,_vol_df,left_on='isocalendar',right_on='isocalendar') #volume
        _wk_df = pd.merge(_wk_df,_open_df[['isocalendar','open']],left_on='isocalendar',right_on='isocalendar') #open
        _wk_df = pd.merge(_wk_df,_close_df[['isocalendar','close']],left_on='isocalendar',right_on='isocalendar') #close
        _wk_df['change'] = _wk_df['close'] - _wk_df['open']
        _wk_df = _wk_df.drop_duplicates().reset_index(drop=True)
        #Get the monday of each week
        _wk_df['weekday'] = [dt.date.weekday(x) for x in _wk_df['date']]
        _wk_df['date'] = _wk_df['date'] - pd.Series([dt.timedelta(days=x) for x in _wk_df['weekday']])
        _wk_df.drop(columns=['isocalendar','weekday'],inplace=True)
        return _wk_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return False

# %%
#Establish the day ref of today compared to 01/01/1970
en_date = dt.date.today()
ep_date = dt.date(1970,1,1)
yrs = 20
st_date = dt.date(en_date.year - yrs,en_date.month,en_date.day)

# %%
#Scrape daily price data
hf_store_name_d = src_fldr_pth + r'all_hist_prices_d_TMP.h5'
hf_d = pd.HDFStore(hf_store_name_d)
group_name_d = r'daily_data'
hf_store_name_w = src_fldr_pth + r'all_hist_prices_w_TMP.h5'
hf_w = pd.HDFStore(hf_store_name_w)
group_name_w = r'weekly_data'
out_cols = ['ticker','date','open','close','high','low','change','volume']
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse['ticker']:
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print('\n{} RUNNING FOR: {}'.format(count,tick))
        
        #DAILY PRICES
        #Get daily price data
        tick_df = get_price_hist_d(tick,create_sec_ref_li(st_date,dt.datetime.today()+dt.timedelta(days=1))) #1 day ahead so today is included

        #Calc emas and macd
        tick_df = calc_ema_macd(tick_df)
        print('DAILY FINAL SHAPE: {}'.format(tick_df.shape))

        #Add to daily h5 file
        tick_df.to_hdf(hf_store_name_d,key=group_name_d,append=True,min_itemsize=col_lens)
        
        #WEEKLY PRICES
        #Convert to weekly prices
        df_w = get_price_hist_w(tick_df)

        #Calc emas and macd
        df_w = calc_ema_macd(df_w)
        print('WEEKLY FINAL SHAPE: {}'.format(df_w.shape))

        #Add to weekly h5 file
        df_w.to_hdf(hf_store_name_w,key=group_name_w,append=True,min_itemsize=col_lens)
    except Exception as e:
        print('ERROR:{}'.format(e))
        errors.append(e)
hf_d.close()
hf_w.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1 RUNNING FOR: III
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:09:45.727594
# Getting DAILY prices for:III
# DAILY FINAL SHAPE: (2947, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 1 TIME -> 0:0:0
#
# 2 RUNNING FOR: ADM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:10:34.143645
# Getting DAILY prices for:ADM
# DAILY FINAL SHAPE: (1714, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (362, 13)
# LAP 2 TIME -> 0:0:48
#
# 3 RUNNING FOR: AAL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:11:10.778655
# Getting DAILY prices for:AAL
# DAILY FINAL SHAPE: (4306, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1006, 13)
# LAP 3 TIME -> 0:0:36
#
# 4 RUNNING FOR: ANTO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:12:15.065124
# Getting DAILY prices for:ANTO
# DAILY FINAL SHAPE: (5068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 4 TIME -> 0:1:4
#
# 5 RUNNING FOR: AHT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:13:16.650722
# Getting DAILY prices for:AHT
# DAILY FINAL SHAPE: (4634, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 5 TIME -> 0:1:1
#
# 6 RUNNING FOR: ABF
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:14:19.740387
# Getting DAILY prices for:ABF
# DAILY FINAL SHAPE: (5047, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 6 TIME -> 0:1:3
#
# 7 RUNNING FOR: AZN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:15:23.881472
# Getting DAILY prices for:AZN
# DAILY FINAL SHAPE: (5025, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 7 TIME -> 0:1:4
#
# 8 RUNNING FOR: AUTO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:16:32.173883
# Getting DAILY prices for:AUTO
# DAILY FINAL SHAPE: (1114, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (229, 13)
# LAP 8 TIME -> 0:1:8
#
# 9 RUNNING FOR: AVV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:17:17.805526
# Getting DAILY prices for:AVV
# DAILY FINAL SHAPE: (4992, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 9 TIME -> 0:0:45
#
# 10 RUNNING FOR: AV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:18:36.003294
# Getting DAILY prices for:AV
# DAILY FINAL SHAPE: (5045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1048, 13)
# LAP 10 TIME -> 0:1:18
#
# 11 RUNNING FOR: BA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:19:50.951914
# Getting DAILY prices for:BA
# DAILY FINAL SHAPE: (5064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 11 TIME -> 0:1:14
#
# 12 RUNNING FOR: BARC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:21:08.143290
# Getting DAILY prices for:BARC
# DAILY FINAL SHAPE: (5005, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 12 TIME -> 0:1:17
#
# 13 RUNNING FOR: BDEV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:22:22.209822
# Getting DAILY prices for:BDEV
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 13 TIME -> 0:1:14
#
# 14 RUNNING FOR: BKG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:23:39.005017
# Getting DAILY prices for:BKG
# DAILY FINAL SHAPE: (5061, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 14 TIME -> 0:1:16
#
# 15 RUNNING FOR: BHP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:24:53.244178
# Getting DAILY prices for:BHP
# DAILY FINAL SHAPE: (2317, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (490, 13)
# LAP 15 TIME -> 0:1:14
#
# 16 RUNNING FOR: BP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:25:49.681293
# Getting DAILY prices for:BP
# DAILY FINAL SHAPE: (5022, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 16 TIME -> 0:0:56
#
# 17 RUNNING FOR: BATS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:27:07.860666
# Getting DAILY prices for:BATS
# DAILY FINAL SHAPE: (5032, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 17 TIME -> 0:1:18
#
# 18 RUNNING FOR: BLND
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:28:28.721173
# Getting DAILY prices for:BLND
# DAILY FINAL SHAPE: (5064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 18 TIME -> 0:1:20
#
# 19 RUNNING FOR: BT-A
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:29:45.282264
# Getting DAILY prices for:BT-A
# DAILY FINAL SHAPE: (5071, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 19 TIME -> 0:1:16
#
# 20 RUNNING FOR: BNZL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:31:23.222346
# Getting DAILY prices for:BNZL
# DAILY FINAL SHAPE: (4989, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1041, 13)
# LAP 20 TIME -> 0:1:37
#
# 21 RUNNING FOR: BRBY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:32:49.082363
# Getting DAILY prices for:BRBY
# DAILY FINAL SHAPE: (4337, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (891, 13)
# LAP 21 TIME -> 0:1:25
#
# 22 RUNNING FOR: CCL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:34:02.493959
# Getting DAILY prices for:CCL
# DAILY FINAL SHAPE: (4746, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (980, 13)
# LAP 22 TIME -> 0:1:13
#
# 23 RUNNING FOR: CNA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:35:28.862571
# Getting DAILY prices for:CNA
# DAILY FINAL SHAPE: (5063, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 23 TIME -> 0:1:26
#
# 24 RUNNING FOR: CCH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:36:58.070890
# Getting DAILY prices for:CCH
# DAILY FINAL SHAPE: (1598, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (327, 13)
# LAP 24 TIME -> 0:1:29
#
# 25 RUNNING FOR: CPG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:37:48.189502
# Getting DAILY prices for:CPG
# DAILY FINAL SHAPE: (4966, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 25 TIME -> 0:0:50
#
# 26 RUNNING FOR: CRH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:39:08.440900
# Getting DAILY prices for:CRH
# DAILY FINAL SHAPE: (4964, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 26 TIME -> 0:1:20
#
# 27 RUNNING FOR: CRDA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:40:22.537113
# Getting DAILY prices for:CRDA
# DAILY FINAL SHAPE: (5027, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1036, 13)
# LAP 27 TIME -> 0:1:14
#
# 28 RUNNING FOR: DCC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:41:39.788232
# Getting DAILY prices for:DCC
# DAILY FINAL SHAPE: (4742, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1018, 13)
# LAP 28 TIME -> 0:1:17
#
# 29 RUNNING FOR: DGE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:42:48.694493
# Getting DAILY prices for:DGE
# DAILY FINAL SHAPE: (5059, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 29 TIME -> 0:1:8
#
# 30 RUNNING FOR: DLG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:44:04.342995
# Getting DAILY prices for:DLG
# DAILY FINAL SHAPE: (1734, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (356, 13)
# LAP 30 TIME -> 0:1:15
#
# 31 RUNNING FOR: EVR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:44:53.989432
# Getting DAILY prices for:EVR
# DAILY FINAL SHAPE: (1973, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (404, 13)
# LAP 31 TIME -> 0:0:49
#
# 32 RUNNING FOR: EXPN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:45:48.095103
# Getting DAILY prices for:EXPN
# DAILY FINAL SHAPE: (3269, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (669, 13)
# LAP 32 TIME -> 0:0:54
#
# 33 RUNNING FOR: FERG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:46:58.166294
# Getting DAILY prices for:FERG
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 33 TIME -> 0:1:10
#
# 34 RUNNING FOR: FLTR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:48:06.204249
# Getting DAILY prices for:FLTR
# DAILY FINAL SHAPE: (45, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (9, 13)
# LAP 34 TIME -> 0:1:8
#
# 35 RUNNING FOR: FRES
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:48:39.980785
# Getting DAILY prices for:FRES
# DAILY FINAL SHAPE: (2859, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (587, 13)
# LAP 35 TIME -> 0:0:33
#
# 36 RUNNING FOR: GSK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:49:38.789103
# Getting DAILY prices for:GSK
# DAILY FINAL SHAPE: (5019, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 36 TIME -> 0:0:58
#
# 37 RUNNING FOR: GLEN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:50:48.109150
# Getting DAILY prices for:GLEN
# DAILY FINAL SHAPE: (2092, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (429, 13)
# LAP 37 TIME -> 0:1:9
#
# 38 RUNNING FOR: HLMA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:51:44.632420
# Getting DAILY prices for:HLMA
# DAILY FINAL SHAPE: (4478, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1012, 13)
# LAP 38 TIME -> 0:0:56
#
# 39 RUNNING FOR: HL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:53:01.835811
# Getting DAILY prices for:HL
# DAILY FINAL SHAPE: (3061, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (632, 13)
# LAP 39 TIME -> 0:1:17
#
# 40 RUNNING FOR: HSX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:53:58.789383
# Getting DAILY prices for:HSX
# DAILY FINAL SHAPE: (4944, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 40 TIME -> 0:0:56
#
# 41 RUNNING FOR: HSBA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:55:06.320031
# Getting DAILY prices for:HSBA
# DAILY FINAL SHAPE: (5036, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 41 TIME -> 0:1:7
#
# 42 RUNNING FOR: IMB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:56:23.797281
# Getting DAILY prices for:IMB
# DAILY FINAL SHAPE: (4803, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1042, 13)
# LAP 42 TIME -> 0:1:17
#
# 43 RUNNING FOR: INF
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:57:32.245284
# Getting DAILY prices for:INF
# DAILY FINAL SHAPE: (5075, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 43 TIME -> 0:1:8
#
# 44 RUNNING FOR: IHG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:58:46.587824
# Getting DAILY prices for:IHG
# DAILY FINAL SHAPE: (4143, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (865, 13)
# LAP 44 TIME -> 0:1:14
#
# 45 RUNNING FOR: IAG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 19:59:47.922957
# Getting DAILY prices for:IAG
# DAILY FINAL SHAPE: (4222, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (866, 13)
# LAP 45 TIME -> 0:1:1
#
# 46 RUNNING FOR: ITRK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:00:54.506311
# Getting DAILY prices for:ITRK
# DAILY FINAL SHAPE: (4183, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (895, 13)
# LAP 46 TIME -> 0:1:6
#
# 47 RUNNING FOR: ITV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:01:59.643756
# Getting DAILY prices for:ITV
# DAILY FINAL SHAPE: (4936, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1022, 13)
# LAP 47 TIME -> 0:1:5
#
# 48 RUNNING FOR: JD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:03:09.070368
# Getting DAILY prices for:JD
# DAILY FINAL SHAPE: (736, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (160, 13)
# LAP 48 TIME -> 0:1:9
#
# 49 RUNNING FOR: JMAT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:03:51.757882
# Getting DAILY prices for:JMAT
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 49 TIME -> 0:0:42
#
# 50 RUNNING FOR: JE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:04:59.827853
# Getting DAILY prices for:JE
# DAILY FINAL SHAPE: (1360, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (279, 13)
# LAP 50 TIME -> 0:1:8
#
# 51 RUNNING FOR: KGF
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:05:44.153137
# Getting DAILY prices for:KGF
# DAILY FINAL SHAPE: (5067, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 51 TIME -> 0:0:44
#
# 52 RUNNING FOR: LAND
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:07:07.266287
# Getting DAILY prices for:LAND
# DAILY FINAL SHAPE: (5037, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 52 TIME -> 0:1:23
#
# 53 RUNNING FOR: LGEN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:08:16.150499
# Getting DAILY prices for:LGEN
# DAILY FINAL SHAPE: (5037, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 53 TIME -> 0:1:8
#
# 54 RUNNING FOR: LLOY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:09:27.030129
# Getting DAILY prices for:LLOY
# DAILY FINAL SHAPE: (5072, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 54 TIME -> 0:1:10
#
# 55 RUNNING FOR: LSE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:10:36.380919
# Getting DAILY prices for:LSE
# DAILY FINAL SHAPE: (4572, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (942, 13)
# LAP 55 TIME -> 0:1:9
#
# 56 RUNNING FOR: MKS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:11:52.731871
# Getting DAILY prices for:MKS
# DAILY FINAL SHAPE: (5041, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 56 TIME -> 0:1:16
#
# 57 RUNNING FOR: MRO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:13:00.232113
# Getting DAILY prices for:MRO
# DAILY FINAL SHAPE: (3855, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (822, 13)
# LAP 57 TIME -> 0:1:7
#
# 58 RUNNING FOR: MCRO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:14:03.593535
# Getting DAILY prices for:MCRO
# DAILY FINAL SHAPE: (3614, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (743, 13)
# LAP 58 TIME -> 0:1:3
#
# 59 RUNNING FOR: MNDI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:15:14.682969
# Getting DAILY prices for:MNDI
# DAILY FINAL SHAPE: (3028, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (624, 13)
# LAP 59 TIME -> 0:1:11
#
# 60 RUNNING FOR: MRW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:16:12.588045
# Getting DAILY prices for:MRW
# DAILY FINAL SHAPE: (5059, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 60 TIME -> 0:0:57
#
# 61 RUNNING FOR: NG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:17:32.535336
# Getting DAILY prices for:NG
# DAILY FINAL SHAPE: (5065, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 61 TIME -> 0:1:19
#
# 62 RUNNING FOR: NXT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:18:44.901819
# Getting DAILY prices for:NXT
# DAILY FINAL SHAPE: (5044, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 62 TIME -> 0:1:12
#
# 63 RUNNING FOR: NMC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:20:03.556143
# Getting DAILY prices for:NMC
# DAILY FINAL SHAPE: (1869, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (383, 13)
# LAP 63 TIME -> 0:1:18
#
# 64 RUNNING FOR: OCDO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:20:53.179751
# Getting DAILY prices for:OCDO
# DAILY FINAL SHAPE: (2304, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (472, 13)
# LAP 64 TIME -> 0:0:49
#
# 65 RUNNING FOR: PSON
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:21:46.450998
# Getting DAILY prices for:PSON
# DAILY FINAL SHAPE: (5063, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 65 TIME -> 0:0:53
#
# 66 RUNNING FOR: PSN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:23:06.187236
# Getting DAILY prices for:PSN
# DAILY FINAL SHAPE: (5052, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 66 TIME -> 0:1:19
#
# 67 RUNNING FOR: PHNX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:24:15.960225
# Getting DAILY prices for:PHNX
# DAILY FINAL SHAPE: (2407, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (505, 13)
# LAP 67 TIME -> 0:1:9
#
# 68 RUNNING FOR: PRU
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:25:17.206382
# Getting DAILY prices for:PRU
# DAILY FINAL SHAPE: (5038, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 68 TIME -> 0:1:1
#
# 69 RUNNING FOR: RB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:26:25.665847
# Getting DAILY prices for:RB
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 69 TIME -> 0:1:8
#
# 70 RUNNING FOR: REL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:27:57.426850
# Getting DAILY prices for:REL
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 70 TIME -> 0:1:31
#
# 71 RUNNING FOR: RTO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:29:10.963503
# Getting DAILY prices for:RTO
# DAILY FINAL SHAPE: (5047, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 71 TIME -> 0:1:13
#
# 72 RUNNING FOR: RIO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:30:33.559616
# Getting DAILY prices for:RIO
# DAILY FINAL SHAPE: (5057, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 72 TIME -> 0:1:22
#
# 73 RUNNING FOR: RMV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:31:50.013996
# Getting DAILY prices for:RMV
# DAILY FINAL SHAPE: (3409, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (700, 13)
# LAP 73 TIME -> 0:1:16
#
# 74 RUNNING FOR: RR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:33:01.819409
# Getting DAILY prices for:RR
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 74 TIME -> 0:1:11
#
# 75 RUNNING FOR: RBS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:34:16.052875
# Getting DAILY prices for:RBS
# DAILY FINAL SHAPE: (5074, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 75 TIME -> 0:1:14
#
# 76 RUNNING FOR: RDSA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:35:30.367695
# Getting DAILY prices for:RDSA
# DAILY FINAL SHAPE: (2316, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (486, 13)
# LAP 76 TIME -> 0:1:14
#
# 77 RUNNING FOR: RSA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:36:33.356461
# Getting DAILY prices for:RSA
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 77 TIME -> 0:1:2
#
# 78 RUNNING FOR: SGE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:37:49.500452
# Getting DAILY prices for:SGE
# DAILY FINAL SHAPE: (5074, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 78 TIME -> 0:1:16
#
# 79 RUNNING FOR: SBRY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:39:05.166597
# Getting DAILY prices for:SBRY
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 79 TIME -> 0:1:15
#
# 80 RUNNING FOR: SDR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:40:16.425762
# Getting DAILY prices for:SDR
# DAILY FINAL SHAPE: (5050, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 80 TIME -> 0:1:11
#
# 81 RUNNING FOR: SMT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:41:39.183103
# Getting DAILY prices for:SMT
# DAILY FINAL SHAPE: (631, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (132, 13)
# LAP 81 TIME -> 0:1:22
#
# 82 RUNNING FOR: SGRO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:42:24.250310
# Getting DAILY prices for:SGRO
# DAILY FINAL SHAPE: (5060, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 82 TIME -> 0:0:45
#
# 83 RUNNING FOR: SVT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:43:55.711817
# Getting DAILY prices for:SVT
# DAILY FINAL SHAPE: (5061, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 83 TIME -> 0:1:31
#
# 84 RUNNING FOR: SN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:45:06.320322
# Getting DAILY prices for:SN
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 84 TIME -> 0:1:10
#
# 85 RUNNING FOR: SMDS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:46:27.298050
# Getting DAILY prices for:SMDS
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 85 TIME -> 0:1:20
#
# 86 RUNNING FOR: SMIN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:47:39.728611
# Getting DAILY prices for:SMIN
# DAILY FINAL SHAPE: (4565, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1028, 13)
# LAP 86 TIME -> 0:1:12
#
# 87 RUNNING FOR: SKG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:48:59.221881
# Getting DAILY prices for:SKG
# DAILY FINAL SHAPE: (3156, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (647, 13)
# LAP 87 TIME -> 0:1:19
#
# 88 RUNNING FOR: SPX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:49:55.898375
# Getting DAILY prices for:SPX
# DAILY FINAL SHAPE: (5065, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 88 TIME -> 0:0:56
#
# 89 RUNNING FOR: SSE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:51:07.547343
# Getting DAILY prices for:SSE
# DAILY FINAL SHAPE: (5028, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 89 TIME -> 0:1:11
#
# 90 RUNNING FOR: STAN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:52:29.026524
# Getting DAILY prices for:STAN
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 90 TIME -> 0:1:21
#
# 91 RUNNING FOR: SLA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:53:40.622581
# Getting DAILY prices for:SLA
# DAILY FINAL SHAPE: (3330, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (682, 13)
# LAP 91 TIME -> 0:1:11
#
# 92 RUNNING FOR: STJ
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:54:57.622643
# Getting DAILY prices for:STJ
# DAILY FINAL SHAPE: (4998, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1049, 13)
# LAP 92 TIME -> 0:1:17
#
# 93 RUNNING FOR: TW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:56:12.048265
# Getting DAILY prices for:TW
# DAILY FINAL SHAPE: (5065, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 93 TIME -> 0:1:14
#
# 94 RUNNING FOR: TSCO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:57:27.219238
# Getting DAILY prices for:TSCO
# DAILY FINAL SHAPE: (5045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 94 TIME -> 0:1:15
#
# 95 RUNNING FOR: TUI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:58:54.049070
# Getting DAILY prices for:TUI
# DAILY FINAL SHAPE: (1179, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (242, 13)
# LAP 95 TIME -> 0:1:26
#
# 96 RUNNING FOR: ULVR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 20:59:40.286961
# Getting DAILY prices for:ULVR
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 96 TIME -> 0:0:46
#
# 97 RUNNING FOR: UU
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:00:54.372229
# Getting DAILY prices for:UU
# DAILY FINAL SHAPE: (5071, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 97 TIME -> 0:1:14
#
# 98 RUNNING FOR: VOD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:02:25.716689
# Getting DAILY prices for:VOD
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 98 TIME -> 0:1:31
#
# 99 RUNNING FOR: WTB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:03:39.689622
# Getting DAILY prices for:WTB
# DAILY FINAL SHAPE: (5068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 99 TIME -> 0:1:13
#
# 100 RUNNING FOR: WPP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:05:24.353231
# Getting DAILY prices for:WPP
# DAILY FINAL SHAPE: (2872, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (676, 13)
# LAP 100 TIME -> 0:1:44
#
# 101 RUNNING FOR: 3IN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:06:36.146326
# Getting DAILY prices for:3IN
# DAILY FINAL SHAPE: (2923, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (601, 13)
# LAP 101 TIME -> 0:1:11
#
# 102 RUNNING FOR: FOUR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:07:56.294043
# Getting DAILY prices for:FOUR
# DAILY FINAL SHAPE: (4662, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1035, 13)
# LAP 102 TIME -> 0:1:20
#
# 103 RUNNING FOR: ASL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:09:04.515763
# Getting DAILY prices for:ASL
# DAILY FINAL SHAPE: (2826, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 103 TIME -> 0:1:8
#
# 104 RUNNING FOR: ACA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:10:08.992315
# Getting DAILY prices for:ACA
# DAILY FINAL SHAPE: (2385, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (490, 13)
# LAP 104 TIME -> 0:1:4
#
# 105 RUNNING FOR: AGK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:11:20.641748
# Getting DAILY prices for:AGK
# DAILY FINAL SHAPE: (5068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 105 TIME -> 0:1:11
#
# 106 RUNNING FOR: ATST
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:12:28.812757
# Getting DAILY prices for:ATST
# DAILY FINAL SHAPE: (2838, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 106 TIME -> 0:1:8
#
# 107 RUNNING FOR: AMGO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:13:51.904328
# Getting DAILY prices for:AMGO
# DAILY FINAL SHAPE: (279, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (58, 13)
# LAP 107 TIME -> 0:1:23
#
# 108 RUNNING FOR: APAX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:14:27.269105
# Getting DAILY prices for:APAX
# DAILY FINAL SHAPE: (1024, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (212, 13)
# LAP 108 TIME -> 0:0:35
#
# 109 RUNNING FOR: ASCL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:15:13.822309
# Getting DAILY prices for:ASCL
# DAILY FINAL SHAPE: (886, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (182, 13)
# LAP 109 TIME -> 0:0:46
#
# 110 RUNNING FOR: ASHM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:15:54.803625
# Getting DAILY prices for:ASHM
# DAILY FINAL SHAPE: (3262, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (669, 13)
# LAP 110 TIME -> 0:0:40
#
# 111 RUNNING FOR: AGR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:17:09.438793
# Getting DAILY prices for:AGR
# DAILY FINAL SHAPE: (3821, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (818, 13)
# LAP 111 TIME -> 0:1:14
#
# 112 RUNNING FOR: AML
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:18:15.714528
# Getting DAILY prices for:AML
# DAILY FINAL SHAPE: (212, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (44, 13)
# LAP 112 TIME -> 0:1:6
#
# 113 RUNNING FOR: AVST
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:19:20.469776
# Getting DAILY prices for:AVST
# DAILY FINAL SHAPE: (315, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (65, 13)
# LAP 113 TIME -> 0:1:4
#
# 114 RUNNING FOR: AGT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:19:57.883950
# Getting DAILY prices for:AGT
# DAILY FINAL SHAPE: (20, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (8, 13)
# LAP 114 TIME -> 0:0:37
#
# 115 RUNNING FOR: BAB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:20:37.120828
# Getting DAILY prices for:BAB
# DAILY FINAL SHAPE: (4605, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1025, 13)
# LAP 115 TIME -> 0:0:39
#
# 116 RUNNING FOR: BGFD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:22:12.282980
# Getting DAILY prices for:BGFD
# DAILY FINAL SHAPE: (2925, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (602, 13)
# LAP 116 TIME -> 0:1:35
#
# 117 RUNNING FOR: BAKK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:23:06.800806
# Getting DAILY prices for:BAKK
# DAILY FINAL SHAPE: (434, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (90, 13)
# LAP 117 TIME -> 0:0:54
#
# 118 RUNNING FOR: BBY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:24:14.272889
# Getting DAILY prices for:BBY
# DAILY FINAL SHAPE: (5069, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 118 TIME -> 0:1:7
#
# 119 RUNNING FOR: BNKR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:25:27.538613
# Getting DAILY prices for:BNKR
# DAILY FINAL SHAPE: (2944, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 119 TIME -> 0:1:13
#
# 120 RUNNING FOR: BAG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:26:45.377660
# Getting DAILY prices for:BAG
# DAILY FINAL SHAPE: (5005, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 120 TIME -> 0:1:17
#
# 121 RUNNING FOR: BBA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:28:19.441686
# Getting DAILY prices for:BBA
# DAILY FINAL SHAPE: (5064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 121 TIME -> 0:1:34
#
# 122 RUNNING FOR: BBGI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:29:32.624278
# Getting DAILY prices for:BBGI
# DAILY FINAL SHAPE: (1906, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (394, 13)
# LAP 122 TIME -> 0:1:13
#
# 123 RUNNING FOR: BCA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:30:48.302087
# Getting DAILY prices for:BCA
# DAILY FINAL SHAPE: (1125, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (238, 13)
# LAP 123 TIME -> 0:1:15
#
# 124 RUNNING FOR: BGEO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:31:34.479350
# Getting DAILY prices for:BGEO
# DAILY FINAL SHAPE: (2938, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (609, 13)
# LAP 124 TIME -> 0:0:46
#
# 125 RUNNING FOR: BEZ
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:32:31.021391
# Getting DAILY prices for:BEZ
# DAILY FINAL SHAPE: (4190, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (873, 13)
# LAP 125 TIME -> 0:0:56
#
# 126 RUNNING FOR: AJB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:33:37.825495
# Getting DAILY prices for:AJB
# DAILY FINAL SHAPE: (165, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (35, 13)
# LAP 126 TIME -> 0:1:6
#
# 127 RUNNING FOR: BWY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:34:29.979369
# Getting DAILY prices for:BWY
# DAILY FINAL SHAPE: (4427, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1008, 13)
# LAP 127 TIME -> 0:0:52
#
# 128 RUNNING FOR: BYG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:35:41.315472
# Getting DAILY prices for:BYG
# DAILY FINAL SHAPE: (4695, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1004, 13)
# LAP 128 TIME -> 0:1:11
#
# 129 RUNNING FOR: BME
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:36:50.988153
# Getting DAILY prices for:BME
# DAILY FINAL SHAPE: (1312, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (269, 13)
# LAP 129 TIME -> 0:1:9
#
# 130 RUNNING FOR: BRSC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:37:53.885172
# Getting DAILY prices for:BRSC
# DAILY FINAL SHAPE: (699, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (151, 13)
# LAP 130 TIME -> 0:1:2
#
# 131 RUNNING FOR: BGSC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:38:40.158968
# Getting DAILY prices for:BGSC
# DAILY FINAL SHAPE: (2939, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 131 TIME -> 0:0:46
#
# 132 RUNNING FOR: BOY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:39:35.917661
# Getting DAILY prices for:BOY
# DAILY FINAL SHAPE: (5058, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 132 TIME -> 0:0:55
#
# 133 RUNNING FOR: BVS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:40:56.491806
# Getting DAILY prices for:BVS
# DAILY FINAL SHAPE: (4949, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1038, 13)
# LAP 133 TIME -> 0:1:20
#
# 134 RUNNING FOR: BTEM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:42:15.091463
# Getting DAILY prices for:BTEM
# DAILY FINAL SHAPE: (2907, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (597, 13)
# LAP 134 TIME -> 0:1:18
#
# 135 RUNNING FOR: BVIC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:43:14.013502
# Getting DAILY prices for:BVIC
# DAILY FINAL SHAPE: (3477, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (713, 13)
# LAP 135 TIME -> 0:0:58
#
# 136 RUNNING FOR: BTG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:44:24.724613
# Getting DAILY prices for:BTG
# DAILY FINAL SHAPE: (5082, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 136 TIME -> 0:1:10
#
# 137 RUNNING FOR: CNE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:45:45.873948
# Getting DAILY prices for:CNE
# DAILY FINAL SHAPE: (5086, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 137 TIME -> 0:1:21
#
# 138 RUNNING FOR: CLDN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:46:57.641423
# Getting DAILY prices for:CLDN
# DAILY FINAL SHAPE: (2929, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (604, 13)
# LAP 138 TIME -> 0:1:11
#
# 139 RUNNING FOR: CAPC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:48:03.894700
# Getting DAILY prices for:CAPC
# DAILY FINAL SHAPE: (2352, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (482, 13)
# LAP 139 TIME -> 0:1:6
#
# 140 RUNNING FOR: CPI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:48:56.162858
# Getting DAILY prices for:CPI
# DAILY FINAL SHAPE: (5067, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1055, 13)
# LAP 140 TIME -> 0:0:52
#
# 141 RUNNING FOR: CARD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:50:25.546971
# Getting DAILY prices for:CARD
# DAILY FINAL SHAPE: (1332, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (273, 13)
# LAP 141 TIME -> 0:1:29
#
# 142 RUNNING FOR: CEY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:51:11.819575
# Getting DAILY prices for:CEY
# DAILY FINAL SHAPE: (4442, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (919, 13)
# LAP 142 TIME -> 0:0:46
#
# 143 RUNNING FOR: CCFS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:52:26.836742
# Getting DAILY prices for:CCFS
# DAILY FINAL SHAPE: (468, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (97, 13)
# LAP 143 TIME -> 0:1:15
#
# 144 RUNNING FOR: CINE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:53:16.013124
# Getting DAILY prices for:CINE
# DAILY FINAL SHAPE: (3085, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (641, 13)
# LAP 144 TIME -> 0:0:49
#
# 145 RUNNING FOR: CTY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:54:15.277690
# Getting DAILY prices for:CTY
# DAILY FINAL SHAPE: (2947, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 145 TIME -> 0:0:59
#
# 146 RUNNING FOR: CKN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:55:26.643055
# Getting DAILY prices for:CKN
# DAILY FINAL SHAPE: (4878, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1026, 13)
# LAP 146 TIME -> 0:1:11
#
# 147 RUNNING FOR: CBG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:56:50.287690
# Getting DAILY prices for:CBG
# DAILY FINAL SHAPE: (4957, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 147 TIME -> 0:1:23
#
# 148 RUNNING FOR: CLI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:58:15.668824
# Getting DAILY prices for:CLI
# DAILY FINAL SHAPE: (5036, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 148 TIME -> 0:1:25
#
# 149 RUNNING FOR: COA
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 21:59:28.910232
# Getting DAILY prices for:COA
# DAILY FINAL SHAPE: (3563, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (947, 13)
# LAP 149 TIME -> 0:1:13
#
# 150 RUNNING FOR: COB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:00:47.481237
# Getting DAILY prices for:COB
# DAILY FINAL SHAPE: (5064, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 150 TIME -> 0:1:18
#
# 151 RUNNING FOR: CCC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:01:59.166914
# Getting DAILY prices for:CCC
# DAILY FINAL SHAPE: (5071, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 151 TIME -> 0:1:11
#
# 152 RUNNING FOR: GLO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:03:12.229988
# Getting DAILY prices for:GLO
# DAILY FINAL SHAPE: (439, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (91, 13)
# LAP 152 TIME -> 0:1:13
#
# 153 RUNNING FOR: CTEC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:03:52.627646
# Getting DAILY prices for:CTEC
# DAILY FINAL SHAPE: (704, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (145, 13)
# LAP 153 TIME -> 0:0:40
#
# 154 RUNNING FOR: CSP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:04:39.413589
# Getting DAILY prices for:CSP
# DAILY FINAL SHAPE: (1927, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (401, 13)
# LAP 154 TIME -> 0:0:46
#
# 155 RUNNING FOR: CWK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:05:30.753085
# Getting DAILY prices for:CWK
# DAILY FINAL SHAPE: (5030, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 155 TIME -> 0:0:51
#
# 156 RUNNING FOR: CRST
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:06:48.789680
# Getting DAILY prices for:CRST
# DAILY FINAL SHAPE: (1648, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (338, 13)
# LAP 156 TIME -> 0:1:18
#
# 157 RUNNING FOR: CYBG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:07:39.380514
# Getting DAILY prices for:CYBG
# DAILY FINAL SHAPE: (892, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (183, 13)
# LAP 157 TIME -> 0:0:50
#
# 158 RUNNING FOR: DJAN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:08:25.257577
# Getting DAILY prices for:DJAN
# DAILY FINAL SHAPE: (4825, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1042, 13)
# LAP 158 TIME -> 0:0:45
#
# 159 RUNNING FOR: DPH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:09:47.991110
# Getting DAILY prices for:DPH
# DAILY FINAL SHAPE: (4399, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (964, 13)
# LAP 159 TIME -> 0:1:22
#
# 160 RUNNING FOR: DLN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:11:04.890554
# Getting DAILY prices for:DLN
# DAILY FINAL SHAPE: (5016, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 160 TIME -> 0:1:16
#
# 161 RUNNING FOR: DPLM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:12:27.030766
# Getting DAILY prices for:DPLM
# DAILY FINAL SHAPE: (5027, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 161 TIME -> 0:1:22
#
# 162 RUNNING FOR: DC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:13:50.343989
# Getting DAILY prices for:DC
# DAILY FINAL SHAPE: (2457, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (514, 13)
# LAP 162 TIME -> 0:1:23
#
# 163 RUNNING FOR: DOM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:14:48.040708
# Getting DAILY prices for:DOM
# DAILY FINAL SHAPE: (4987, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1028, 13)
# LAP 163 TIME -> 0:0:57
#
# 164 RUNNING FOR: DRX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:15:59.369477
# Getting DAILY prices for:DRX
# DAILY FINAL SHAPE: (3467, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (712, 13)
# LAP 164 TIME -> 0:1:11
#
# 165 RUNNING FOR: DNLM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:17:06.016489
# Getting DAILY prices for:DNLM
# DAILY FINAL SHAPE: (3257, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (668, 13)
# LAP 165 TIME -> 0:1:6
#
# 166 RUNNING FOR: EZJ
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:18:05.799049
# Getting DAILY prices for:EZJ
# DAILY FINAL SHAPE: (4732, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (977, 13)
# LAP 166 TIME -> 0:0:59
#
# 167 RUNNING FOR: EDIN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:19:15.593679
# Getting DAILY prices for:EDIN
# DAILY FINAL SHAPE: (2922, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 167 TIME -> 0:1:9
#
# 168 RUNNING FOR: EIG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:20:16.511743
# Getting DAILY prices for:EIG
# DAILY FINAL SHAPE: (3245, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (670, 13)
# LAP 168 TIME -> 0:1:0
#
# 169 RUNNING FOR: ECM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:21:23.559040
# Getting DAILY prices for:ECM
# DAILY FINAL SHAPE: (5027, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 169 TIME -> 0:1:7
#
# 170 RUNNING FOR: ELM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:22:34.476746
# Getting DAILY prices for:ELM
# DAILY FINAL SHAPE: (5073, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 170 TIME -> 0:1:10
#
# 171 RUNNING FOR: ENOG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:23:49.334065
# Getting DAILY prices for:ENOG
# DAILY FINAL SHAPE: (350, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (73, 13)
# LAP 171 TIME -> 0:1:14
#
# 172 RUNNING FOR: ETO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:24:26.627442
# Getting DAILY prices for:ETO
# DAILY FINAL SHAPE: (2646, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (604, 13)
# LAP 172 TIME -> 0:0:37
#
# 173 RUNNING FOR: EQN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:25:22.064481
# Getting DAILY prices for:EQN
# DAILY FINAL SHAPE: (958, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (197, 13)
# LAP 173 TIME -> 0:0:55
#
# 174 RUNNING FOR: ESNT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:26:06.338927
# Getting DAILY prices for:ESNT
# DAILY FINAL SHAPE: (3607, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (739, 13)
# LAP 174 TIME -> 0:0:44
#
# 175 RUNNING FOR: ERM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:27:04.095724
# Getting DAILY prices for:ERM
# DAILY FINAL SHAPE: (4704, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1037, 13)
# LAP 175 TIME -> 0:0:57
#
# 176 RUNNING FOR: FCPT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:28:13.803987
# Getting DAILY prices for:FCPT
# DAILY FINAL SHAPE: (2913, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (598, 13)
# LAP 176 TIME -> 0:1:9
#
# 177 RUNNING FOR: FDM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:29:07.633264
# Getting DAILY prices for:FDM
# DAILY FINAL SHAPE: (1302, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (268, 13)
# LAP 177 TIME -> 0:0:53
#
# 178 RUNNING FOR: FXPO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:29:49.869857
# Getting DAILY prices for:FXPO
# DAILY FINAL SHAPE: (3038, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (628, 13)
# LAP 178 TIME -> 0:0:42
#
# 179 RUNNING FOR: FCSS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:30:42.731037
# Getting DAILY prices for:FCSS
# DAILY FINAL SHAPE: (2334, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (480, 13)
# LAP 179 TIME -> 0:0:52
#
# 180 RUNNING FOR: FEV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:31:31.671672
# Getting DAILY prices for:FEV
# DAILY FINAL SHAPE: (2826, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 180 TIME -> 0:0:48
#
# 181 RUNNING FOR: FSV
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:32:33.626934
# Getting DAILY prices for:FSV
# DAILY FINAL SHAPE: (2824, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 181 TIME -> 0:1:1
#
# 182 RUNNING FOR: FGT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:33:36.016838
# Getting DAILY prices for:FGT
# DAILY FINAL SHAPE: (2920, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 182 TIME -> 0:1:2
#
# 183 RUNNING FOR: FGP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:34:38.342696
# Getting DAILY prices for:FGP
# DAILY FINAL SHAPE: (5062, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 183 TIME -> 0:1:2
#
# 184 RUNNING FOR: FSJ
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:35:46.005133
# Getting DAILY prices for:FSJ
# DAILY FINAL SHAPE: (4902, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1025, 13)
# LAP 184 TIME -> 0:1:7
#
# 185 RUNNING FOR: FRCL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:36:53.354873
# Getting DAILY prices for:FRCL
# DAILY FINAL SHAPE: (2969, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (685, 13)
# LAP 185 TIME -> 0:1:7
#
# 186 RUNNING FOR: FCH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:38:00.672079
# Getting DAILY prices for:FCH
# DAILY FINAL SHAPE: (213, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (44, 13)
# LAP 186 TIME -> 0:1:7
#
# 187 RUNNING FOR: FUTR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:38:38.993869
# Getting DAILY prices for:FUTR
# DAILY FINAL SHAPE: (4760, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 187 TIME -> 0:0:38
#
# 188 RUNNING FOR: GFS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:39:49.471794
# Getting DAILY prices for:GFS
# DAILY FINAL SHAPE: (4081, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (838, 13)
# LAP 188 TIME -> 0:1:10
#
# 189 RUNNING FOR: GFRD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:40:52.740960
# Getting DAILY prices for:GFRD
# DAILY FINAL SHAPE: (5068, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 189 TIME -> 0:1:3
#
# 190 RUNNING FOR: GAW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:42:02.485988
# Getting DAILY prices for:GAW
# DAILY FINAL SHAPE: (4885, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 190 TIME -> 0:1:9
#
# 191 RUNNING FOR: GCP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:43:13.895548
# Getting DAILY prices for:GCP
# DAILY FINAL SHAPE: (2199, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (467, 13)
# LAP 191 TIME -> 0:1:11
#
# 192 RUNNING FOR: GSS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:44:06.847134
# Getting DAILY prices for:GSS
# DAILY FINAL SHAPE: (2853, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (604, 13)
# LAP 192 TIME -> 0:0:52
#
# 193 RUNNING FOR: GNS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:45:03.799408
# Getting DAILY prices for:GNS
# DAILY FINAL SHAPE: (4235, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (946, 13)
# LAP 193 TIME -> 0:0:56
#
# 194 RUNNING FOR: GOG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:46:22.334546
# Getting DAILY prices for:GOG
# DAILY FINAL SHAPE: (4951, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1040, 13)
# LAP 194 TIME -> 0:1:18
#
# 195 RUNNING FOR: GPOR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:47:40.736874
# Getting DAILY prices for:GPOR
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 195 TIME -> 0:1:18
#
# 196 RUNNING FOR: GFTU
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:48:53.808990
# Getting DAILY prices for:GFTU
# DAILY FINAL SHAPE: (4180, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (887, 13)
# LAP 196 TIME -> 0:1:13
#
# 197 RUNNING FOR: GRI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:50:00.708986
# Getting DAILY prices for:GRI
# DAILY FINAL SHAPE: (5007, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 197 TIME -> 0:1:6
#
# 198 RUNNING FOR: UKW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:51:13.600067
# Getting DAILY prices for:UKW
# DAILY FINAL SHAPE: (1586, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (328, 13)
# LAP 198 TIME -> 0:1:12
#
# 199 RUNNING FOR: GNC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-05 22:52:02.754545
# Getting DAILY prices for:GNC
# DAILY FINAL SHAPE: (4731, 13)
# ...
# _en_date: 2019-08-06 00:18:24.599884
# Getting DAILY prices for:RNK
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 285 TIME -> 0:0:34
#
# 286 RUNNING FOR: RAT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:19:32.508795
# Getting DAILY prices for:RAT
# DAILY FINAL SHAPE: (4927, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1037, 13)
# LAP 286 TIME -> 0:1:7
#
# 287 RUNNING FOR: RDW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:20:44.000324
# Getting DAILY prices for:RDW
# DAILY FINAL SHAPE: (4963, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1041, 13)
# LAP 287 TIME -> 0:1:11
#
# 288 RUNNING FOR: TRIG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:22:00.218532
# Getting DAILY prices for:TRIG
# DAILY FINAL SHAPE: (1504, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (310, 13)
# LAP 288 TIME -> 0:1:16
#
# 289 RUNNING FOR: RSW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:22:45.451159
# Getting DAILY prices for:RSW
# DAILY FINAL SHAPE: (4941, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1038, 13)
# LAP 289 TIME -> 0:0:45
#
# 290 RUNNING FOR: RTN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:23:54.836311
# Getting DAILY prices for:RTN
# DAILY FINAL SHAPE: (5056, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 290 TIME -> 0:1:9
#
# 291 RUNNING FOR: RHIM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:25:03.896095
# Getting DAILY prices for:RHIM
# DAILY FINAL SHAPE: (448, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (93, 13)
# LAP 291 TIME -> 0:1:9
#
# 292 RUNNING FOR: RCP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:25:40.696813
# Getting DAILY prices for:RCP
# DAILY FINAL SHAPE: (297, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (64, 13)
# LAP 292 TIME -> 0:0:36
#
# 293 RUNNING FOR: RSE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:26:19.234310
# Getting DAILY prices for:RSE
# DAILY FINAL SHAPE: (1440, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (298, 13)
# LAP 293 TIME -> 0:0:38
#
# 294 RUNNING FOR: ROR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:27:08.859904
# Getting DAILY prices for:ROR
# DAILY FINAL SHAPE: (5066, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 294 TIME -> 0:0:49
#
# 295 RUNNING FOR: RMG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:28:27.215553
# Getting DAILY prices for:RMG
# DAILY FINAL SHAPE: (1483, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (304, 13)
# LAP 295 TIME -> 0:1:18
#
# 296 RUNNING FOR: SBRE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:29:11.330470
# Getting DAILY prices for:SBRE
# DAILY FINAL SHAPE: (420, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (87, 13)
# LAP 296 TIME -> 0:0:44
#
# 297 RUNNING FOR: SAFE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:29:49.915391
# Getting DAILY prices for:SAFE
# DAILY FINAL SHAPE: (3156, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (648, 13)
# LAP 297 TIME -> 0:0:38
#
# 298 RUNNING FOR: SNN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:31:01.054546
# Getting DAILY prices for:SNN
# DAILY FINAL SHAPE: (1098, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (227, 13)
# LAP 298 TIME -> 0:1:11
#
# 299 RUNNING FOR: SVS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:31:51.184953
# Getting DAILY prices for:SVS
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 299 TIME -> 0:0:50
#
# 300 RUNNING FOR: SDP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:33:08.403871
# Getting DAILY prices for:SDP
# DAILY FINAL SHAPE: (2924, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (601, 13)
# LAP 300 TIME -> 0:1:17
#
# 301 RUNNING FOR: SCIN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:34:19.191004
# Getting DAILY prices for:SCIN
# DAILY FINAL SHAPE: (2926, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (602, 13)
# LAP 301 TIME -> 0:1:10
#
# 302 RUNNING FOR: SNR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:35:23.125151
# Getting DAILY prices for:SNR
# DAILY FINAL SHAPE: (4558, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1024, 13)
# LAP 302 TIME -> 0:1:3
#
# 303 RUNNING FOR: SEQI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:36:45.486756
# Getting DAILY prices for:SEQI
# DAILY FINAL SHAPE: (1094, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (226, 13)
# LAP 303 TIME -> 0:1:22
#
# 304 RUNNING FOR: SRP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:37:33.861390
# Getting DAILY prices for:SRP
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 304 TIME -> 0:0:48
#
# 305 RUNNING FOR: SHB
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:38:51.011735
# Getting DAILY prices for:SHB
# DAILY FINAL SHAPE: (4561, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1027, 13)
# LAP 305 TIME -> 0:1:17
#
# 306 RUNNING FOR: SHI
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:40:07.912334
# Getting DAILY prices for:SHI
# DAILY FINAL SHAPE: (4961, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1038, 13)
# LAP 306 TIME -> 0:1:16
#
# 307 RUNNING FOR: SXX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:41:24.142927
# Getting DAILY prices for:SXX
# DAILY FINAL SHAPE: (2961, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (669, 13)
# LAP 307 TIME -> 0:1:16
#
# 308 RUNNING FOR: SSON
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:42:29.212327
# Getting DAILY prices for:SSON
# DAILY FINAL SHAPE: (165, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (37, 13)
# LAP 308 TIME -> 0:1:5
#
# 309 RUNNING FOR: SCT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:43:12.727671
# Getting DAILY prices for:SCT
# DAILY FINAL SHAPE: (947, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (195, 13)
# LAP 309 TIME -> 0:0:43
#
# 310 RUNNING FOR: SOPH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:44:03.102697
# Getting DAILY prices for:SOPH
# DAILY FINAL SHAPE: (1045, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (215, 13)
# LAP 310 TIME -> 0:0:50
#
# 311 RUNNING FOR: SXS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:44:59.409344
# Getting DAILY prices for:SXS
# DAILY FINAL SHAPE: (4960, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1042, 13)
# LAP 311 TIME -> 0:0:56
#
# 312 RUNNING FOR: SPT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:46:24.339172
# Getting DAILY prices for:SPT
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1043, 13)
# LAP 312 TIME -> 0:1:24
#
# 313 RUNNING FOR: SPD
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:47:41.354067
# Getting DAILY prices for:SPD
# DAILY FINAL SHAPE: (3170, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (649, 13)
# LAP 313 TIME -> 0:1:17
#
# 314 RUNNING FOR: SSPG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:48:45.855495
# Getting DAILY prices for:SSPG
# DAILY FINAL SHAPE: (1295, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (265, 13)
# LAP 314 TIME -> 0:1:4
#
# 315 RUNNING FOR: SMP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:49:35.279283
# Getting DAILY prices for:SMP
# DAILY FINAL SHAPE: (4931, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1037, 13)
# LAP 315 TIME -> 0:0:49
#
# 316 RUNNING FOR: SGC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:50:50.232492
# Getting DAILY prices for:SGC
# DAILY FINAL SHAPE: (4719, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (978, 13)
# LAP 316 TIME -> 0:1:14
#
# 317 RUNNING FOR: SYNC
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:52:11.390406
# Getting DAILY prices for:SYNC
# DAILY FINAL SHAPE: (1689, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (349, 13)
# LAP 317 TIME -> 0:1:21
#
# 318 RUNNING FOR: SYNT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:53:03.292821
# Getting DAILY prices for:SYNT
# DAILY FINAL SHAPE: (5067, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 318 TIME -> 0:0:51
#
# 319 RUNNING FOR: TALK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:54:33.414202
# Getting DAILY prices for:TALK
# DAILY FINAL SHAPE: (2383, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (489, 13)
# LAP 319 TIME -> 0:1:30
#
# 320 RUNNING FOR: TATE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:55:31.253746
# Getting DAILY prices for:TATE
# DAILY FINAL SHAPE: (5044, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 320 TIME -> 0:0:57
#
# 321 RUNNING FOR: TBCG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:56:52.529967
# Getting DAILY prices for:TBCG
# DAILY FINAL SHAPE: (750, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (156, 13)
# LAP 321 TIME -> 0:1:21
#
# 322 RUNNING FOR: TED
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:57:38.496067
# Getting DAILY prices for:TED
# DAILY FINAL SHAPE: (4959, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 322 TIME -> 0:0:45
#
# 323 RUNNING FOR: TEP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 00:58:53.675486
# Getting DAILY prices for:TEP
# DAILY FINAL SHAPE: (4820, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (993, 13)
# LAP 323 TIME -> 0:1:15
#
# 324 RUNNING FOR: TMPL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:00:12.950743
# Getting DAILY prices for:TMPL
# DAILY FINAL SHAPE: (2924, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (601, 13)
# LAP 324 TIME -> 0:1:19
#
# 325 RUNNING FOR: TEM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:01:15.682959
# Getting DAILY prices for:TEM
# DAILY FINAL SHAPE: (2830, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (602, 13)
# LAP 325 TIME -> 0:1:2
#
# 326 RUNNING FOR: TIFS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:02:28.101057
# Getting DAILY prices for:TIFS
# DAILY FINAL SHAPE: (450, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (93, 13)
# LAP 326 TIME -> 0:1:12
#
# 327 RUNNING FOR: TCAP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:03:10.036104
# Getting DAILY prices for:TCAP
# DAILY FINAL SHAPE: (4685, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (970, 13)
# LAP 327 TIME -> 0:0:41
#
# 328 RUNNING FOR: TRY
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:04:23.149100
# Getting DAILY prices for:TRY
# DAILY FINAL SHAPE: (2923, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (600, 13)
# LAP 328 TIME -> 0:1:13
#
# 329 RUNNING FOR: TPK
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:05:40.707648
# Getting DAILY prices for:TPK
# DAILY FINAL SHAPE: (5070, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 329 TIME -> 0:1:17
#
# 330 RUNNING FOR: BBOX
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:06:58.004510
# Getting DAILY prices for:BBOX
# DAILY FINAL SHAPE: (1408, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (291, 13)
# LAP 330 TIME -> 0:1:17
#
# 331 RUNNING FOR: TLW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:07:50.004795
# Getting DAILY prices for:TLW
# DAILY FINAL SHAPE: (4965, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1036, 13)
# LAP 331 TIME -> 0:0:52
#
# 332 RUNNING FOR: UDG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:09:13.256171
# Getting DAILY prices for:UDG
# DAILY FINAL SHAPE: (4349, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1023, 13)
# LAP 332 TIME -> 0:1:23
#
# 333 RUNNING FOR: UKCM
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:11:02.376707
# Getting DAILY prices for:UKCM
# DAILY FINAL SHAPE: (2924, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (601, 13)
# LAP 333 TIME -> 0:1:49
#
# 334 RUNNING FOR: ULE
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:12:07.739463
# Getting DAILY prices for:ULE
# DAILY FINAL SHAPE: (4937, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1040, 13)
# LAP 334 TIME -> 0:1:5
#
# 335 RUNNING FOR: UTG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:13:27.963877
# Getting DAILY prices for:UTG
# DAILY FINAL SHAPE: (5031, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 335 TIME -> 0:1:20
#
# 336 RUNNING FOR: VSVS
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:14:46.937550
# Getting DAILY prices for:VSVS
# DAILY FINAL SHAPE: (5074, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1044, 13)
# LAP 336 TIME -> 0:1:18
#
# 337 RUNNING FOR: VCT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:16:06.536229
# Getting DAILY prices for:VCT
# DAILY FINAL SHAPE: (4449, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1009, 13)
# LAP 337 TIME -> 0:1:19
#
# 338 RUNNING FOR: VEIL
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:17:25.832836
# Getting DAILY prices for:VEIL
# DAILY FINAL SHAPE: (754, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (157, 13)
# LAP 338 TIME -> 0:1:19
#
# 339 RUNNING FOR: VOF
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:18:16.070070
# Getting DAILY prices for:VOF
# DAILY FINAL SHAPE: (2942, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 339 TIME -> 0:0:50
#
# 340 RUNNING FOR: VVO
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:19:19.334927
# Getting DAILY prices for:VVO
# DAILY FINAL SHAPE: (317, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (66, 13)
# LAP 340 TIME -> 0:1:3
#
# 341 RUNNING FOR: WEIR
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:20:09.209953
# Getting DAILY prices for:WEIR
# DAILY FINAL SHAPE: (4959, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1042, 13)
# LAP 341 TIME -> 0:0:49
#
# 342 RUNNING FOR: JDW
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:22:48.605400
# Getting DAILY prices for:JDW
# DAILY FINAL SHAPE: (4947, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (1040, 13)
# LAP 342 TIME -> 0:2:39
#
# 343 RUNNING FOR: SMWH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:24:06.593089
# Getting DAILY prices for:SMWH
# DAILY FINAL SHAPE: (3302, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (678, 13)
# LAP 343 TIME -> 0:1:17
#
# 344 RUNNING FOR: WMH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:25:14.287693
# Getting DAILY prices for:WMH
# DAILY FINAL SHAPE: (4335, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (894, 13)
# LAP 344 TIME -> 0:1:7
#
# 345 RUNNING FOR: WTAN
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:26:25.283707
# Getting DAILY prices for:WTAN
# DAILY FINAL SHAPE: (2945, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
# LAP 345 TIME -> 0:1:10
#
# 346 RUNNING FOR: WIZZ
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:27:28.753386
# Getting DAILY prices for:WIZZ
# DAILY FINAL SHAPE: (1133, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (232, 13)
# LAP 346 TIME -> 0:1:3
#
# 347 RUNNING FOR: WPCT
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:28:23.938046
# Getting DAILY prices for:WPCT
# DAILY FINAL SHAPE: (1061, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (219, 13)
# LAP 347 TIME -> 0:0:55
#
# 348 RUNNING FOR: WG
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:29:16.177786
# Getting DAILY prices for:WG
# DAILY FINAL SHAPE: (4365, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (897, 13)
# LAP 348 TIME -> 0:0:52
#
# 349 RUNNING FOR: WKP
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:30:36.793734
# Getting DAILY prices for:WKP
# DAILY FINAL SHAPE: (3884, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (908, 13)
# LAP 349 TIME -> 0:1:20
#
# 350 RUNNING FOR: WWH
# _st_date: 1999-08-04 00:00:00
# _en_date: 2019-08-06 01:32:00.054676
# Getting DAILY prices for:WWH
# DAILY FINAL SHAPE: (2944, 13)
# Converting daily prices to weekly prices
# WEEKLY FINAL SHAPE: (605, 13)
#
#
#
# TOTAL ELAPSED TIME -> 6:23:21
#
# ERROR COUNT: 0

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'all_hist_prices_d.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'all_hist_prices_d_TMP.h5',src_fldr_pth + r'all_hist_prices_d.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'all_hist_prices_d_TMP.h5',src_fldr_pth + r'all_hist_prices_d.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d.h5
#
# SUCCESSFULLY RENAMED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d_TMP.h5 TO C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_d.h5

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(src_fldr_pth + r'all_hist_prices_w.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(src_fldr_pth + r'all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(src_fldr_pth + r'all_hist_prices_w_TMP.h5',src_fldr_pth + r'all_hist_prices_w.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(src_fldr_pth + r'all_hist_prices_w_TMP.h5',src_fldr_pth + r'all_hist_prices_w.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w.h5
#
# SUCCESSFULLY RENAMED C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w_TMP.h5 TO C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\all_hist_prices_w.h5

# %% [markdown]
# # Exporting the FTSE ticker list

# %%
#Export the ftse list
path = "C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\"
tick_ftse.to_csv(path_or_buf=path + "tick_ftse.csv")

# %%
#End the program
import sys
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Robert\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2969: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
