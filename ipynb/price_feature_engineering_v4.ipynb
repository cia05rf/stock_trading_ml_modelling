# %% [markdown]
# # Create indicators and find signals
# This code is designed to calculate the below indicators:
# - EMA
# - MACD
# - MACD mins and maxs
# - MACD positive turns
# - Support price
# - Target price
# - Prev week volume Vs 8 week average volume
#
# We will also bring in if the target price was hit within 8 weeks for ML training and validation.
#
# Each share has it's own trading pattern so we will train a different model for each share but use the same set of features, just the hyper paramenters will be tuned differenty.

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import tables
import os
import datetime as dt

# %%
#Clean column names
def clean_col_name(str_in):
    str_out = str_in.lower() #Change all to lower case
    str_out = re.sub(r'.*\.','',str_out) #Remove everything before a .
    str_out = re.sub(r' ','_',str_out) #Replace spaces with _
    str_out = re.sub(r'_?&_?','_and_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'_?@_?','_at_',str_out) #Put _ around & and @ and change to 'and' and 'at'
    str_out = re.sub(r'[^0-9a-z_]','',str_out) #Remove all non allowed characters
    str_out = re.sub(r'^_','',str_out) #Remove leading _
    return str_out

# %%
class process_time:
    def __init__(self,name:str = ''):
        self.st_time = dt.datetime.now()
        self.lap_li = []
        self.en_time = None
        self.name = name
    def calc_el_time(self,st_time,en_time):
        diff_time = en_time - st_time
        duration_in_s = diff_time.total_seconds()
        hours = int(divmod(duration_in_s, 3600)[0])
        duration_in_s += -(hours * 3600)
        minutes = int(divmod(duration_in_s, 60)[0])
        duration_in_s += -(minutes * 60)
        seconds = int(duration_in_s)
        return [hours,minutes,seconds]
    def lap(self):
        self.lap_li.append(dt.datetime.now())
    def end(self):
        self.en_time = dt.datetime.now()
        lap_time = self.calc_el_time(self.st_time,self.en_time)
        if self.name != '':
            print('TOTAL ELAPSED TIME OF {} -> {}:{}:{}'.format(self.name,lap_time[0],lap_time[1],lap_time[2]))
        else:
            print('TOTAL ELAPSED TIME -> {}:{}:{}'.format(lap_time[0],lap_time[1],lap_time[2]))
    def show_lap_times(self):
        tmp_count = 0
        for lap in self.lap_li:
            tmp_count += 1
            lap_time = self.calc_el_time(self.st_time,lap)
            print('LAP {} TIME -> {}:{}:{}'.format(tmp_count,lap_time[0],lap_time[1],lap_time[2]))
    def show_latest_lap_time(self):
        if len(self.lap_li) == 0:
            return
        elif len(self.lap_li) < 2:
            lap_time = self.calc_el_time(self.st_time,self.lap_li[-1])
        else:
            lap_time = self.calc_el_time(self.lap_li[-2],self.lap_li[-1])
        print('LAP {} TIME -> {}:{}:{}'.format(len(self.lap_li),lap_time[0],lap_time[1],lap_time[2]))

# %%
#Import the ftse list
path = "C:\\Users\\Robert\\Documents\\python_scripts\\stock_trading_ml_modelling\\historical_prices\\"
tick_ftse = pd.read_csv(path + "tick_ftse.csv")
tick_ftse = tick_ftse.iloc[:,1:]
for col in tick_ftse:
    tick_ftse.rename(columns={col:clean_col_name(col)},inplace=True)
tick_ftse.head()
# Out:
#               company ticker    index
# 0                  3I    III  FTSE100
# 1       ADMIRAL GROUP    ADM  FTSE100
# 2  ANGLO AMERICAN PLC    AAL  FTSE100
# 3         ANTOFAGASTA   ANTO  FTSE100
# 4       ASHTEAD GROUP    AHT  FTSE100

# %%
#Import and combine prices files
# df_prices_w = pd.read_csv(path + tick_ftse["ticker"][1] + "_hist_prices_w.csv")
df_prices_w = pd.read_hdf(path + "all_hist_prices_w.h5")
#Rename columns
for col in df_prices_w:
    df_prices_w.rename(columns={col:clean_col_name(col)},inplace=True)
#Drop unwanted columns
try:
    df_prices_w.drop(columns=["unnamed_0","index"],inplace=True)
except Exception as e:
    print(e)
#Reformat columns where neccessary
df_prices_w["date"] = df_prices_w["date"].astype("datetime64")
print(df_prices_w.shape)
print(df_prices_w.dtypes)
df_prices_w.head()
# Out:
# "['unnamed_0' 'index'] not found in axis"
# (258389, 13)
# ticker               object
# date         datetime64[ns]
# high                float64
# low                 float64
# volume              float64
# open                float64
# close               float64
# change              float64
# ema12               float64
# ema26               float64
# macd_line           float64
# signal              float64
# macd                float64
# dtype: object
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal  macd
# 0    NaN        NaN     NaN   NaN
# 1    NaN        NaN     NaN   NaN
# 2    NaN        NaN     NaN   NaN
# 3    NaN        NaN     NaN   NaN
# 4    NaN        NaN     NaN   NaN

# %%
#Remove tickers with fewer than 34 entries as this is where the MACD can be calculated
print('START ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('START TICK COUNT -> {}'.format(tick_ftse.shape[0]))
for tick in tick_ftse.ticker:
    if df_prices_w[df_prices_w.ticker == tick].shape[0] < 34:
        #Remove from dataframe
        print('\nTOO FEW RECORDS FOR {}'.format(tick))
        df_prices_w = df_prices_w.loc[df_prices_w.ticker != tick]
        print('    NEW ROW COUNT -> {}'.format(df_prices_w.shape[0]))
        #Remove from tick_ftse
        tick_ftse = tick_ftse.loc[tick_ftse.ticker != tick]
        print('    NEW TICK COUNT -> {}'.format(tick_ftse.shape[0]))
print('\nEND ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('END TICK COUNT -> {}'.format(tick_ftse.shape[0]))
# Out:
# START ROW COUNT -> 258389
# START TICK COUNT -> 350
#
# TOO FEW RECORDS FOR FLTR
#     NEW ROW COUNT -> 258374
#     NEW TICK COUNT -> 349
#
# TOO FEW RECORDS FOR AGT
#     NEW ROW COUNT -> 258362
#     NEW TICK COUNT -> 348
#
# TOO FEW RECORDS FOR NETW
#     NEW ROW COUNT -> 258339
#     NEW TICK COUNT -> 347
#
# END ROW COUNT -> 258339
# END TICK COUNT -> 347

# %%
#Get in-row price change
def calc_changes(df_in,var_col,prev_col):
    df_in["change"] = df_in[var_col] - df_in[prev_col]
    df_in["per_change"] = df_in["change"] / df_in[prev_col]
    return (df_in["change"],df_in["per_change"])

#Relabel signal to signal_line
df_prices_w.rename(columns={"signal":"signal_line"},inplace=True)
for col in df_prices_w:
    df_prices_w.rename(columns={col:col.lower()},inplace=True)
    
df_prices_w["change_price"],df_prices_w["per_change_price"] = calc_changes(df_prices_w[["close","open"]].copy(),"close","open")
df_prices_w.drop(columns=["change"],inplace=True)
df_prices_w.head()
# Out:
#   ticker       date    high    low      volume   open  close  ema12  ema26  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0    NaN    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0    NaN    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0    NaN    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    NaN    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    NaN    NaN
#
#    macd_line  signal_line  macd  change_price  per_change_price
# 0        NaN          NaN   NaN         -30.0         -0.030151
# 1        NaN          NaN   NaN         -43.5         -0.044961
# 2        NaN          NaN   NaN         -16.0         -0.017448
# 3        NaN          NaN   NaN          26.5          0.029742
# 4        NaN          NaN   NaN          50.0          0.054885

# %%
#Function for calculating ema
def calc_ema(_s_in,_periods):
    #Calc mod val
    _mod = 2/(_periods+1)
    #Calc sma
    _sma_s = [0] * _s_in.shape[0]
    for _i in range(0,_periods):
        _sma_s += _s_in.shift(_i) / _periods
    #Calc ema
    _ema_s = _sma_s.copy()
    _ema_s[(_ema_s > 0) & (np.isnan(_ema_s) == False)] = _mod*(_s_in - _ema_s.shift(1)) + _ema_s.shift(1)
    return _ema_s.copy()

# %%
#Function for calculating the MACD
def calc_macd(_ema_lng_s,_ema_sht_s,_sig_period:int):
    #Make a df
    _tmp_df = pd.DataFrame([])
    _tmp_df['ema_lng'] = _ema_lng_s
    _tmp_df['ema_sht'] = _ema_sht_s
    #Calc the signal line
    _tmp_df['macd_line'] = _tmp_df['ema_sht'] - _tmp_df['ema_lng']
    _tmp_df['signal'] = calc_ema(_tmp_df['macd_line'],_sig_period)
    _tmp_df['macd_hist'] = _tmp_df['macd_line'] - _tmp_df['signal']
    return (_tmp_df['macd_line'].copy(),_tmp_df['signal'].copy(),_tmp_df['macd_hist'].copy())

# %%
#Calc the ema and macds for the data
def calc_ema_macd(_df_in):
    _tick_df = _df_in.copy()
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
#         _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return _tick_df

# %%
#Create a function which normalises a feature based only on the values which have come before it - avoids time series bias
def norm_time_s(_index,_s_in):
    _min = np.nanmin(_s_in[:_index+1].values)
    _max = np.nanmax(_s_in[:_index+1].values)
    _norm_val = (_s_in[_index] - _min) / (_max - _min)
    return _norm_val

# %%
#Runt he functions
def norm_prices(_df_in):
    _df_out = _df_in.copy()
    
    #Normalise the columns which need it
    _norm_cols = [
        #Standard features
        "open"
        ,"close"
        ,"high"
        ,"low"
        ,"volume"
    ]
    #Reset the index
    _df_out.sort_values(['date'],ascending=True,inplace=True)
    #Normalise
    for _col in _norm_cols:
        _tmp_s = _df_out[_col].copy() #Take a copy so as the values are changed this does not affect following calculations
        _df_out[_col] = [norm_time_s(_x,_tmp_s) for _x in _df_out.index]
    
    return _df_out

# %%
#Normalize the prices by ticker and time then create emas and macds for each ticker
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print('NORALISING AND CALCULATING EMA & MACD VALUES')
count = 0
error_li = []
run_time = process_time()
run_time.lap()
for tick in tick_ftse.ticker:
    count += 1
    print('\nRUN FOR {} - {}'.format(tick,count))
    try:
        this_tick_df = df_prices_w[df_prices_w.ticker == tick]
        this_tick_df = norm_prices(this_tick_df.copy())
        #Calculate the ema and macd
        this_tick_df = calc_ema_macd(this_tick_df)
        #Append back on to the dataframe
        df_prices_w[df_prices_w.ticker == tick] = this_tick_df.copy()
        print('\tSUCCESS')
        run_time.lap()
        run_time.show_latest_lap_time()
    except Exception as e:
        print('\tERROR -> {}'.format(e))
        error_li.append(e)
run_time.end()
print('\n\nCOMPLETED - ERRORS ENCOUNTERED -> {}'.format(len(error_li)))
if len(error_li) > 0:
    print(error_li)
# Out:
# NORALISING AND CALCULATING EMA & MACD VALUES
#
# RUN FOR III - 1
# 	SUCCESS
# LAP 2 TIME -> 0:0:1
#
# RUN FOR ADM - 2
# 	SUCCESS
# LAP 3 TIME -> 0:0:1
#
# RUN FOR AAL - 3
# 	SUCCESS
# LAP 4 TIME -> 0:0:2
#
# RUN FOR ANTO - 4
# 	SUCCESS
# LAP 5 TIME -> 0:0:2
#
# RUN FOR AHT - 5
# 	SUCCESS
# LAP 6 TIME -> 0:0:2
#
# RUN FOR ABF - 6
# 	SUCCESS
# LAP 7 TIME -> 0:0:2
#
# RUN FOR AZN - 7
# 	SUCCESS
# LAP 8 TIME -> 0:0:2
#
# RUN FOR AUTO - 8
# 	SUCCESS
# LAP 9 TIME -> 0:0:0
#
# RUN FOR AVV - 9
# 	SUCCESS
# LAP 10 TIME -> 0:0:3
#
# RUN FOR AV - 10
# 	SUCCESS
# LAP 11 TIME -> 0:0:3
#
# RUN FOR BA - 11
# 	SUCCESS
# LAP 12 TIME -> 0:0:3
#
# RUN FOR BARC - 12
# 	SUCCESS
# LAP 13 TIME -> 0:0:2
#
# RUN FOR BDEV - 13
# 	SUCCESS
# LAP 14 TIME -> 0:0:2
#
# RUN FOR BKG - 14
# 	SUCCESS
# LAP 15 TIME -> 0:0:2
#
# RUN FOR BHP - 15
# 	SUCCESS
# LAP 16 TIME -> 0:0:1
#
# RUN FOR BP - 16
# 	SUCCESS
# LAP 17 TIME -> 0:0:2
#
# RUN FOR BATS - 17
# 	SUCCESS
# LAP 18 TIME -> 0:0:2
#
# RUN FOR BLND - 18
# 	SUCCESS
# LAP 19 TIME -> 0:0:2
#
# RUN FOR BT-A - 19
# 	SUCCESS
# LAP 20 TIME -> 0:0:2
#
# RUN FOR BNZL - 20
# 	SUCCESS
# LAP 21 TIME -> 0:0:2
#
# RUN FOR BRBY - 21
# 	SUCCESS
# LAP 22 TIME -> 0:0:2
#
# RUN FOR CCL - 22
# 	SUCCESS
# LAP 23 TIME -> 0:0:2
#
# RUN FOR CNA - 23
# 	SUCCESS
# LAP 24 TIME -> 0:0:2
#
# RUN FOR CCH - 24
# 	SUCCESS
# LAP 25 TIME -> 0:0:1
#
# RUN FOR CPG - 25
# 	SUCCESS
# LAP 26 TIME -> 0:0:2
#
# RUN FOR CRH - 26
# 	SUCCESS
# LAP 27 TIME -> 0:0:2
#
# RUN FOR CRDA - 27
# 	SUCCESS
# LAP 28 TIME -> 0:0:2
#
# RUN FOR DCC - 28
# 	SUCCESS
# LAP 29 TIME -> 0:0:2
#
# RUN FOR DGE - 29
# 	SUCCESS
# LAP 30 TIME -> 0:0:2
#
# RUN FOR DLG - 30
# 	SUCCESS
# LAP 31 TIME -> 0:0:1
#
# RUN FOR EVR - 31
# 	SUCCESS
# LAP 32 TIME -> 0:0:1
#
# RUN FOR EXPN - 32
# 	SUCCESS
# LAP 33 TIME -> 0:0:1
#
# RUN FOR FERG - 33
# 	SUCCESS
# LAP 34 TIME -> 0:0:2
#
# RUN FOR FRES - 34
# 	SUCCESS
# LAP 35 TIME -> 0:0:1
#
# RUN FOR GSK - 35
# 	SUCCESS
# LAP 36 TIME -> 0:0:2
#
# RUN FOR GLEN - 36
# 	SUCCESS
# LAP 37 TIME -> 0:0:1
#
# RUN FOR HLMA - 37
# 	SUCCESS
# LAP 38 TIME -> 0:0:3
#
# RUN FOR HL - 38
# 	SUCCESS
# LAP 39 TIME -> 0:0:2
#
# RUN FOR HSX - 39
# 	SUCCESS
# LAP 40 TIME -> 0:0:2
#
# RUN FOR HSBA - 40
# 	SUCCESS
# LAP 41 TIME -> 0:0:2
#
# RUN FOR IMB - 41
# 	SUCCESS
# LAP 42 TIME -> 0:0:2
#
# RUN FOR INF - 42
# 	SUCCESS
# LAP 43 TIME -> 0:0:2
#
# RUN FOR IHG - 43
# 	SUCCESS
# LAP 44 TIME -> 0:0:2
#
# RUN FOR IAG - 44
# 	SUCCESS
# LAP 45 TIME -> 0:0:2
#
# RUN FOR ITRK - 45
# 	SUCCESS
# LAP 46 TIME -> 0:0:2
#
# RUN FOR ITV - 46
# 	SUCCESS
# LAP 47 TIME -> 0:0:2
#
# RUN FOR JD - 47
# 	SUCCESS
# LAP 48 TIME -> 0:0:0
#
# RUN FOR JMAT - 48
# 	SUCCESS
# LAP 49 TIME -> 0:0:2
#
# RUN FOR JE - 49
# 	SUCCESS
# LAP 50 TIME -> 0:0:0
#
# RUN FOR KGF - 50
# 	SUCCESS
# LAP 51 TIME -> 0:0:2
#
# RUN FOR LAND - 51
# 	SUCCESS
# LAP 52 TIME -> 0:0:2
#
# RUN FOR LGEN - 52
# 	SUCCESS
# LAP 53 TIME -> 0:0:2
#
# RUN FOR LLOY - 53
# 	SUCCESS
# LAP 54 TIME -> 0:0:2
#
# RUN FOR LSE - 54
# 	SUCCESS
# LAP 55 TIME -> 0:0:2
#
# RUN FOR MKS - 55
# 	SUCCESS
# LAP 56 TIME -> 0:0:3
#
# RUN FOR MRO - 56
# 	SUCCESS
# LAP 57 TIME -> 0:0:2
#
# RUN FOR MCRO - 57
# 	SUCCESS
# LAP 58 TIME -> 0:0:2
#
# RUN FOR MNDI - 58
# 	SUCCESS
# LAP 59 TIME -> 0:0:2
#
# RUN FOR MRW - 59
# 	SUCCESS
# LAP 60 TIME -> 0:0:3
#
# RUN FOR NG - 60
# 	SUCCESS
# LAP 61 TIME -> 0:0:3
#
# RUN FOR NXT - 61
# 	SUCCESS
# LAP 62 TIME -> 0:0:3
#
# RUN FOR NMC - 62
# 	SUCCESS
# LAP 63 TIME -> 0:0:1
#
# RUN FOR OCDO - 63
# 	SUCCESS
# LAP 64 TIME -> 0:0:1
#
# RUN FOR PSON - 64
# 	SUCCESS
# LAP 65 TIME -> 0:0:3
#
# RUN FOR PSN - 65
# 	SUCCESS
# LAP 66 TIME -> 0:0:3
#
# RUN FOR PHNX - 66
# 	SUCCESS
# LAP 67 TIME -> 0:0:1
#
# RUN FOR PRU - 67
# 	SUCCESS
# LAP 68 TIME -> 0:0:3
#
# RUN FOR RB - 68
# 	SUCCESS
# LAP 69 TIME -> 0:0:3
#
# RUN FOR REL - 69
# 	SUCCESS
# LAP 70 TIME -> 0:0:3
#
# RUN FOR RTO - 70
# 	SUCCESS
# LAP 71 TIME -> 0:0:3
#
# RUN FOR RIO - 71
# 	SUCCESS
# LAP 72 TIME -> 0:0:3
#
# RUN FOR RMV - 72
# 	SUCCESS
# LAP 73 TIME -> 0:0:2
#
# RUN FOR RR - 73
# 	SUCCESS
# LAP 74 TIME -> 0:0:4
#
# RUN FOR RBS - 74
# 	SUCCESS
# LAP 75 TIME -> 0:0:4
#
# RUN FOR RDSA - 75
# 	SUCCESS
# LAP 76 TIME -> 0:0:2
#
# RUN FOR RSA - 76
# 	SUCCESS
# LAP 77 TIME -> 0:0:4
#
# RUN FOR SGE - 77
# 	SUCCESS
# LAP 78 TIME -> 0:0:3
#
# RUN FOR SBRY - 78
# 	SUCCESS
# LAP 79 TIME -> 0:0:3
#
# RUN FOR SDR - 79
# 	SUCCESS
# LAP 80 TIME -> 0:0:3
#
# RUN FOR SMT - 80
# 	SUCCESS
# LAP 81 TIME -> 0:0:0
#
# RUN FOR SGRO - 81
# 	SUCCESS
# LAP 82 TIME -> 0:0:3
#
# RUN FOR SVT - 82
# 	SUCCESS
# LAP 83 TIME -> 0:0:3
#
# RUN FOR SN - 83
# 	SUCCESS
# LAP 84 TIME -> 0:0:4
#
# RUN FOR SMDS - 84
# 	SUCCESS
# LAP 85 TIME -> 0:0:3
#
# RUN FOR SMIN - 85
# 	SUCCESS
# LAP 86 TIME -> 0:0:3
#
# RUN FOR SKG - 86
# 	SUCCESS
# LAP 87 TIME -> 0:0:2
#
# RUN FOR SPX - 87
# 	SUCCESS
# LAP 88 TIME -> 0:0:3
#
# RUN FOR SSE - 88
# 	SUCCESS
# LAP 89 TIME -> 0:0:3
#
# RUN FOR STAN - 89
# 	SUCCESS
# LAP 90 TIME -> 0:0:3
#
# RUN FOR SLA - 90
# 	SUCCESS
# LAP 91 TIME -> 0:0:2
#
# RUN FOR STJ - 91
# 	SUCCESS
# LAP 92 TIME -> 0:0:3
#
# RUN FOR TW - 92
# 	SUCCESS
# LAP 93 TIME -> 0:0:3
#
# RUN FOR TSCO - 93
# 	SUCCESS
# LAP 94 TIME -> 0:0:3
#
# RUN FOR TUI - 94
# 	SUCCESS
# LAP 95 TIME -> 0:0:1
#
# RUN FOR ULVR - 95
# 	SUCCESS
# LAP 96 TIME -> 0:0:3
#
# RUN FOR UU - 96
# 	SUCCESS
# LAP 97 TIME -> 0:0:3
#
# RUN FOR VOD - 97
# 	SUCCESS
# LAP 98 TIME -> 0:0:3
#
# RUN FOR WTB - 98
# 	SUCCESS
# LAP 99 TIME -> 0:0:3
#
# RUN FOR WPP - 99
# 	SUCCESS
# LAP 100 TIME -> 0:0:2
#
# RUN FOR 3IN - 100
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in double_scalars
#   """
# 	SUCCESS
# LAP 101 TIME -> 0:0:1
#
# RUN FOR FOUR - 101
# 	SUCCESS
# LAP 102 TIME -> 0:0:2
#
# RUN FOR ASL - 102
# 	SUCCESS
# LAP 103 TIME -> 0:0:1
#
# RUN FOR ACA - 103
# 	SUCCESS
# LAP 104 TIME -> 0:0:1
#
# RUN FOR AGK - 104
# 	SUCCESS
# LAP 105 TIME -> 0:0:2
#
# RUN FOR ATST - 105
# 	SUCCESS
# LAP 106 TIME -> 0:0:1
#
# RUN FOR AMGO - 106
# 	SUCCESS
# LAP 107 TIME -> 0:0:0
#
# RUN FOR APAX - 107
# 	SUCCESS
# LAP 108 TIME -> 0:0:0
#
# RUN FOR ASCL - 108
# 	SUCCESS
# LAP 109 TIME -> 0:0:0
#
# RUN FOR ASHM - 109
# 	SUCCESS
# LAP 110 TIME -> 0:0:1
#
# RUN FOR AGR - 110
# 	SUCCESS
# LAP 111 TIME -> 0:0:2
#
# RUN FOR AML - 111
# 	SUCCESS
# LAP 112 TIME -> 0:0:0
#
# RUN FOR AVST - 112
# 	SUCCESS
# LAP 113 TIME -> 0:0:0
#
# RUN FOR BAB - 113
# 	SUCCESS
# LAP 114 TIME -> 0:0:2
#
# RUN FOR BGFD - 114
# 	SUCCESS
# LAP 115 TIME -> 0:0:1
#
# RUN FOR BAKK - 115
# 	SUCCESS
# LAP 116 TIME -> 0:0:0
#
# RUN FOR BBY - 116
# 	SUCCESS
# LAP 117 TIME -> 0:0:2
#
# RUN FOR BNKR - 117
# 	SUCCESS
# LAP 118 TIME -> 0:0:1
#
# RUN FOR BAG - 118
# 	SUCCESS
# LAP 119 TIME -> 0:0:2
#
# RUN FOR BBA - 119
# 	SUCCESS
# LAP 120 TIME -> 0:0:2
#
# RUN FOR BBGI - 120
# 	SUCCESS
# LAP 121 TIME -> 0:0:1
#
# RUN FOR BCA - 121
# 	SUCCESS
# LAP 122 TIME -> 0:0:0
#
# RUN FOR BGEO - 122
# 	SUCCESS
# LAP 123 TIME -> 0:0:1
#
# RUN FOR BEZ - 123
# 	SUCCESS
# LAP 124 TIME -> 0:0:1
#
# RUN FOR AJB - 124
# 	SUCCESS
# LAP 125 TIME -> 0:0:0
#
# RUN FOR BWY - 125
# 	SUCCESS
# LAP 126 TIME -> 0:0:2
#
# RUN FOR BYG - 126
# 	SUCCESS
# LAP 127 TIME -> 0:0:2
#
# RUN FOR BME - 127
# 	SUCCESS
# LAP 128 TIME -> 0:0:0
#
# RUN FOR BRSC - 128
# 	SUCCESS
# LAP 129 TIME -> 0:0:0
#
# RUN FOR BGSC - 129
# 	SUCCESS
# LAP 130 TIME -> 0:0:1
#
# RUN FOR BOY - 130
# 	SUCCESS
# LAP 131 TIME -> 0:0:2
#
# RUN FOR BVS - 131
# 	SUCCESS
# LAP 132 TIME -> 0:0:2
#
# RUN FOR BTEM - 132
# 	SUCCESS
# LAP 133 TIME -> 0:0:1
#
# RUN FOR BVIC - 133
# 	SUCCESS
# LAP 134 TIME -> 0:0:1
#
# RUN FOR CNE - 134
# 	SUCCESS
# LAP 135 TIME -> 0:0:2
#
# RUN FOR CLDN - 135
# 	SUCCESS
# LAP 136 TIME -> 0:0:1
#
# RUN FOR CAPC - 136
# 	SUCCESS
# LAP 137 TIME -> 0:0:1
#
# RUN FOR CPI - 137
# 	SUCCESS
# LAP 138 TIME -> 0:0:2
#
# RUN FOR CARD - 138
# 	SUCCESS
# LAP 139 TIME -> 0:0:0
#
# RUN FOR CEY - 139
# 	SUCCESS
# LAP 140 TIME -> 0:0:2
#
# RUN FOR CCFS - 140
# 	SUCCESS
# LAP 141 TIME -> 0:0:0
#
# RUN FOR CINE - 141
# 	SUCCESS
# LAP 142 TIME -> 0:0:1
#
# RUN FOR CTY - 142
# 	SUCCESS
# LAP 143 TIME -> 0:0:1
#
# RUN FOR CKN - 143
# 	SUCCESS
# LAP 144 TIME -> 0:0:2
#
# RUN FOR CBG - 144
# 	SUCCESS
# LAP 145 TIME -> 0:0:2
#
# RUN FOR CLI - 145
# 	SUCCESS
# LAP 146 TIME -> 0:0:2
#
# RUN FOR COA - 146
# 	SUCCESS
# LAP 147 TIME -> 0:0:2
#
# RUN FOR COB - 147
# 	SUCCESS
# LAP 148 TIME -> 0:0:2
#
# RUN FOR CCC - 148
# 	SUCCESS
# LAP 149 TIME -> 0:0:2
#
# RUN FOR GLO - 149
# 	SUCCESS
# LAP 150 TIME -> 0:0:0
#
# RUN FOR CTEC - 150
# 	SUCCESS
# LAP 151 TIME -> 0:0:0
#
# RUN FOR CSP - 151
# 	SUCCESS
# LAP 152 TIME -> 0:0:1
#
# RUN FOR CWK - 152
# 	SUCCESS
# LAP 153 TIME -> 0:0:2
#
# RUN FOR CRST - 153
# 	SUCCESS
# LAP 154 TIME -> 0:0:0
#
# RUN FOR CYBG - 154
# 	SUCCESS
# LAP 155 TIME -> 0:0:0
#
# RUN FOR DJAN - 155
# 	SUCCESS
# LAP 156 TIME -> 0:0:2
#
# RUN FOR DPH - 156
# 	SUCCESS
# LAP 157 TIME -> 0:0:2
#
# RUN FOR DLN - 157
# 	SUCCESS
# LAP 158 TIME -> 0:0:2
#
# RUN FOR DPLM - 158
# 	SUCCESS
# LAP 159 TIME -> 0:0:2
#
# RUN FOR DC - 159
# 	SUCCESS
# LAP 160 TIME -> 0:0:1
#
# RUN FOR DOM - 160
# 	SUCCESS
# LAP 161 TIME -> 0:0:2
#
# RUN FOR DRX - 161
# 	SUCCESS
# LAP 162 TIME -> 0:0:1
#
# RUN FOR DNLM - 162
# 	SUCCESS
# LAP 163 TIME -> 0:0:1
#
# RUN FOR EZJ - 163
# 	SUCCESS
# LAP 164 TIME -> 0:0:2
#
# RUN FOR EDIN - 164
# 	SUCCESS
# LAP 165 TIME -> 0:0:1
#
# RUN FOR EIG - 165
# 	SUCCESS
# LAP 166 TIME -> 0:0:1
#
# RUN FOR ECM - 166
# 	SUCCESS
# LAP 167 TIME -> 0:0:2
#
# RUN FOR ELM - 167
# 	SUCCESS
# LAP 168 TIME -> 0:0:2
#
# RUN FOR ENOG - 168
# 	SUCCESS
# LAP 169 TIME -> 0:0:0
#
# RUN FOR ETO - 169
# 	SUCCESS
# LAP 170 TIME -> 0:0:1
#
# RUN FOR EQN - 170
# 	SUCCESS
# LAP 171 TIME -> 0:0:0
#
# RUN FOR ESNT - 171
# 	SUCCESS
# LAP 172 TIME -> 0:0:1
#
# RUN FOR ERM - 172
# 	SUCCESS
# LAP 173 TIME -> 0:0:2
#
# RUN FOR FCPT - 173
# 	SUCCESS
# LAP 174 TIME -> 0:0:1
#
# RUN FOR FDM - 174
# 	SUCCESS
# LAP 175 TIME -> 0:0:0
#
# RUN FOR FXPO - 175
# 	SUCCESS
# LAP 176 TIME -> 0:0:1
#
# RUN FOR FCSS - 176
# 	SUCCESS
# LAP 177 TIME -> 0:0:1
#
# RUN FOR FEV - 177
# 	SUCCESS
# LAP 178 TIME -> 0:0:1
#
# RUN FOR FSV - 178
# 	SUCCESS
# LAP 179 TIME -> 0:0:1
#
# RUN FOR FGT - 179
# 	SUCCESS
# LAP 180 TIME -> 0:0:1
#
# RUN FOR FGP - 180
# 	SUCCESS
# LAP 181 TIME -> 0:0:2
#
# RUN FOR FSJ - 181
# 	SUCCESS
# LAP 182 TIME -> 0:0:2
#
# RUN FOR FRCL - 182
# 	SUCCESS
# LAP 183 TIME -> 0:0:1
#
# RUN FOR FCH - 183
# 	SUCCESS
# LAP 184 TIME -> 0:0:0
#
# RUN FOR FUTR - 184
# 	SUCCESS
# LAP 185 TIME -> 0:0:2
#
# RUN FOR GFS - 185
# 	SUCCESS
# LAP 186 TIME -> 0:0:1
#
# RUN FOR GFRD - 186
# 	SUCCESS
# LAP 187 TIME -> 0:0:2
#
# RUN FOR GAW - 187
# 	SUCCESS
# LAP 188 TIME -> 0:0:2
#
# RUN FOR GCP - 188
# 	SUCCESS
# LAP 189 TIME -> 0:0:1
#
# RUN FOR GSS - 189
# 	SUCCESS
# LAP 190 TIME -> 0:0:1
#
# RUN FOR GNS - 190
# 	SUCCESS
# LAP 191 TIME -> 0:0:2
#
# RUN FOR GOG - 191
# 	SUCCESS
# LAP 192 TIME -> 0:0:2
#
# RUN FOR GPOR - 192
# 	SUCCESS
# LAP 193 TIME -> 0:0:2
#
# RUN FOR GFTU - 193
# 	SUCCESS
# LAP 194 TIME -> 0:0:1
#
# RUN FOR GRI - 194
# 	SUCCESS
# LAP 195 TIME -> 0:0:2
#
# RUN FOR UKW - 195
# 	SUCCESS
# LAP 196 TIME -> 0:0:0
#
# RUN FOR GNC - 196
# 	SUCCESS
# LAP 197 TIME -> 0:0:2
#
# RUN FOR GNK - 197
# 	SUCCESS
# LAP 198 TIME -> 0:0:2
#
# RUN FOR GRG - 198
# 	SUCCESS
# LAP 199 TIME -> 0:0:2
#
# RUN FOR GVC - 199
# 	SUCCESS
# LAP 200 TIME -> 0:0:1
#
# RUN FOR HMSO - 200
# 	SUCCESS
# LAP 201 TIME -> 0:0:2
#
# RUN FOR HVPE - 201
# 	SUCCESS
# LAP 202 TIME -> 0:0:1
#
# RUN FOR HSTG - 202
# 	SUCCESS
# LAP 203 TIME -> 0:0:0
#
# RUN FOR HAS - 203
# 	SUCCESS
# LAP 204 TIME -> 0:0:2
#
# RUN FOR HRI - 204
# 	SUCCESS
# LAP 205 TIME -> 0:0:1
#
# RUN FOR HGT - 205
# 	SUCCESS
# LAP 206 TIME -> 0:0:1
#
# RUN FOR HICL - 206
# 	SUCCESS
# LAP 207 TIME -> 0:0:1
#
# RUN FOR HIK - 207
# 	SUCCESS
# LAP 208 TIME -> 0:0:1
#
# RUN FOR HILS - 208
# 	SUCCESS
# LAP 209 TIME -> 0:0:2
#
# RUN FOR HFG - 209
# 	SUCCESS
# LAP 210 TIME -> 0:0:1
#
# RUN FOR HOC - 210
# 	SUCCESS
# LAP 211 TIME -> 0:0:1
#
# RUN FOR HSV - 211
# 	SUCCESS
# LAP 212 TIME -> 0:0:2
#
# RUN FOR HWDN - 212
# 	SUCCESS
# LAP 213 TIME -> 0:0:2
#
# RUN FOR HTG - 213
# 	SUCCESS
# LAP 214 TIME -> 0:0:2
#
# RUN FOR IBST - 214
# 	SUCCESS
# LAP 215 TIME -> 0:0:0
#
# RUN FOR IGG - 215
# 	SUCCESS
# LAP 216 TIME -> 0:0:1
#
# RUN FOR IMI - 216
# 	SUCCESS
# LAP 217 TIME -> 0:0:2
#
# RUN FOR INCH - 217
# 	SUCCESS
# LAP 218 TIME -> 0:0:2
#
# RUN FOR ISAT - 218
# 	SUCCESS
# LAP 219 TIME -> 0:0:1
#
# RUN FOR ICP - 219
# 	SUCCESS
# LAP 220 TIME -> 0:0:2
#
# RUN FOR IHP - 220
# 	SUCCESS
# LAP 221 TIME -> 0:0:0
#
# RUN FOR INPP - 221
# 	SUCCESS
# LAP 222 TIME -> 0:0:1
#
# RUN FOR INTU - 222
# 	SUCCESS
# LAP 223 TIME -> 0:0:2
#
# RUN FOR INVP - 223
# 	SUCCESS
# LAP 224 TIME -> 0:0:2
#
# RUN FOR IPO - 224
# 	SUCCESS
# LAP 225 TIME -> 0:0:1
#
# RUN FOR IWG - 225
# 	SUCCESS
# LAP 226 TIME -> 0:0:1
#
# RUN FOR JLG - 226
# 	SUCCESS
# LAP 227 TIME -> 0:0:0
#
# RUN FOR JII - 227
# 	SUCCESS
# LAP 228 TIME -> 0:0:1
#
# RUN FOR JAM - 228
# 	SUCCESS
# LAP 229 TIME -> 0:0:1
#
# RUN FOR JMG - 229
# 	SUCCESS
# LAP 230 TIME -> 0:0:1
#
# RUN FOR JFJ - 230
# 	SUCCESS
# LAP 231 TIME -> 0:0:1
#
# RUN FOR JEO - 231
# 	SUCCESS
# LAP 232 TIME -> 0:0:1
#
# RUN FOR JUP - 232
# 	SUCCESS
# LAP 233 TIME -> 0:0:1
#
# RUN FOR KNOS - 233
# 	SUCCESS
# LAP 234 TIME -> 0:0:0
#
# RUN FOR KAZ - 234
# 	SUCCESS
# LAP 235 TIME -> 0:0:1
#
# RUN FOR LRE - 235
# 	SUCCESS
# LAP 236 TIME -> 0:0:1
#
# RUN FOR LWDB - 236
# 	SUCCESS
# LAP 237 TIME -> 0:0:1
#
# RUN FOR LMP - 237
# 	SUCCESS
# LAP 238 TIME -> 0:0:1
#
# RUN FOR EMG - 238
# 	SUCCESS
# LAP 239 TIME -> 0:0:2
#
# RUN FOR MSLH - 239
# 	SUCCESS
# LAP 240 TIME -> 0:0:2
#
# RUN FOR MARS - 240
# 	SUCCESS
# LAP 241 TIME -> 0:0:1
#
# RUN FOR MCS - 241
# 	SUCCESS
# LAP 242 TIME -> 0:0:0
#
# RUN FOR MDC - 242
# 	SUCCESS
# LAP 243 TIME -> 0:0:0
#
# RUN FOR MGGT - 243
# 	SUCCESS
# LAP 244 TIME -> 0:0:2
#
# RUN FOR MRC - 244
# 	SUCCESS
# LAP 245 TIME -> 0:0:1
#
# RUN FOR MERL - 245
# 	SUCCESS
# LAP 246 TIME -> 0:0:0
#
# RUN FOR MTRO - 246
# 	SUCCESS
# LAP 247 TIME -> 0:0:0
#
# RUN FOR MLC - 247
# 	SUCCESS
# LAP 248 TIME -> 0:0:2
#
# RUN FOR MAB - 248
# 	SUCCESS
# LAP 249 TIME -> 0:0:1
#
# RUN FOR MONY - 249
# 	SUCCESS
# LAP 250 TIME -> 0:0:1
#
# RUN FOR MNKS - 250
# 	SUCCESS
# LAP 251 TIME -> 0:0:1
#
# RUN FOR MGAM - 251
# 	SUCCESS
# LAP 252 TIME -> 0:0:2
#
# RUN FOR MYI - 252
# 	SUCCESS
# LAP 253 TIME -> 0:0:1
#
# RUN FOR NEX - 253
# 	SUCCESS
# LAP 254 TIME -> 0:0:2
#
# RUN FOR NBLS - 254
# 	SUCCESS
# LAP 255 TIME -> 0:0:1
#
# RUN FOR NRR - 255
# 	SUCCESS
# LAP 256 TIME -> 0:0:1
#
# RUN FOR NESF - 256
# 	SUCCESS
# LAP 257 TIME -> 0:0:0
#
# RUN FOR OTB - 257
# 	SUCCESS
# LAP 258 TIME -> 0:0:0
#
# RUN FOR OXIG - 258
# 	SUCCESS
# LAP 259 TIME -> 0:0:2
#
# RUN FOR PAGE - 259
# 	SUCCESS
# LAP 260 TIME -> 0:0:2
#
# RUN FOR PIN - 260
# 	SUCCESS
# LAP 261 TIME -> 0:0:1
#
# RUN FOR PAG - 261
# 	SUCCESS
# LAP 262 TIME -> 0:0:2
#
# RUN FOR PAY - 262
# 	SUCCESS
# LAP 263 TIME -> 0:0:1
#
# RUN FOR PNN - 263
# 	SUCCESS
# LAP 264 TIME -> 0:0:2
#
# RUN FOR PLI - 264
# 	SUCCESS
# LAP 265 TIME -> 0:0:1
#
# RUN FOR PSH - 265
# 	SUCCESS
# LAP 266 TIME -> 0:0:0
#
# RUN FOR PNL - 266
# 	SUCCESS
# LAP 267 TIME -> 0:0:1
#
# RUN FOR PFC - 267
# 	SUCCESS
# LAP 268 TIME -> 0:0:1
#
# RUN FOR PETS - 268
# 	SUCCESS
# LAP 269 TIME -> 0:0:0
#
# RUN FOR PTEC - 269
# 	SUCCESS
# LAP 270 TIME -> 0:0:1
#
# RUN FOR PLUS - 270
# 	SUCCESS
# LAP 271 TIME -> 0:0:0
#
# RUN FOR PCT - 271
# 	SUCCESS
# LAP 272 TIME -> 0:0:1
#
# RUN FOR POLY - 272
# 	SUCCESS
# LAP 273 TIME -> 0:0:1
#
# RUN FOR PLP - 273
# 	SUCCESS
# LAP 274 TIME -> 0:0:0
#
# RUN FOR PPH - 274
# 	SUCCESS
# LAP 275 TIME -> 0:0:1
#
# RUN FOR PMO - 275
# 	SUCCESS
# LAP 276 TIME -> 0:0:2
#
# RUN FOR PHP - 276
# 	SUCCESS
# LAP 277 TIME -> 0:0:2
#
# RUN FOR PFG - 277
# 	SUCCESS
# LAP 278 TIME -> 0:0:2
#
# RUN FOR PRTC - 278
# 	SUCCESS
# LAP 279 TIME -> 0:0:0
#
# RUN FOR PZC - 279
# 	SUCCESS
# LAP 280 TIME -> 0:0:2
#
# RUN FOR QQ - 280
# 	SUCCESS
# LAP 281 TIME -> 0:0:1
#
# RUN FOR QLT - 281
# 	SUCCESS
# LAP 282 TIME -> 0:0:0
#
# RUN FOR RNK - 282
# 	SUCCESS
# LAP 283 TIME -> 0:0:2
#
# RUN FOR RAT - 283
# 	SUCCESS
# LAP 284 TIME -> 0:0:2
#
# RUN FOR RDW - 284
# 	SUCCESS
# LAP 285 TIME -> 0:0:2
#
# RUN FOR TRIG - 285
# 	SUCCESS
# LAP 286 TIME -> 0:0:0
#
# RUN FOR RSW - 286
# 	SUCCESS
# LAP 287 TIME -> 0:0:2
#
# RUN FOR RTN - 287
# 	SUCCESS
# LAP 288 TIME -> 0:0:2
#
# RUN FOR RHIM - 288
# 	SUCCESS
# LAP 289 TIME -> 0:0:0
#
# RUN FOR RCP - 289
# 	SUCCESS
# LAP 290 TIME -> 0:0:0
#
# RUN FOR RSE - 290
# 	SUCCESS
# LAP 291 TIME -> 0:0:0
#
# RUN FOR ROR - 291
# 	SUCCESS
# LAP 292 TIME -> 0:0:2
#
# RUN FOR RMG - 292
# 	SUCCESS
# LAP 293 TIME -> 0:0:0
#
# RUN FOR SBRE - 293
# 	SUCCESS
# LAP 294 TIME -> 0:0:0
#
# RUN FOR SAFE - 294
# 	SUCCESS
# LAP 295 TIME -> 0:0:1
#
# RUN FOR SNN - 295
# 	SUCCESS
# LAP 296 TIME -> 0:0:0
#
# RUN FOR SVS - 296
# 	SUCCESS
# LAP 297 TIME -> 0:0:2
#
# RUN FOR SDP - 297
# 	SUCCESS
# LAP 298 TIME -> 0:0:1
#
# RUN FOR SCIN - 298
# 	SUCCESS
# LAP 299 TIME -> 0:0:1
#
# RUN FOR SNR - 299
# 	SUCCESS
# LAP 300 TIME -> 0:0:2
#
# RUN FOR SEQI - 300
# 	SUCCESS
# LAP 301 TIME -> 0:0:0
#
# RUN FOR SRP - 301
# 	SUCCESS
# LAP 302 TIME -> 0:0:2
#
# RUN FOR SHB - 302
# 	SUCCESS
# LAP 303 TIME -> 0:0:2
#
# RUN FOR SHI - 303
# 	SUCCESS
# LAP 304 TIME -> 0:0:2
#
# RUN FOR SXX - 304
# 	SUCCESS
# LAP 305 TIME -> 0:0:1
#
# RUN FOR SSON - 305
# 	SUCCESS
# LAP 306 TIME -> 0:0:0
#
# RUN FOR SCT - 306
# 	SUCCESS
# LAP 307 TIME -> 0:0:0
#
# RUN FOR SOPH - 307
# 	SUCCESS
# LAP 308 TIME -> 0:0:0
#
# RUN FOR SXS - 308
# 	SUCCESS
# LAP 309 TIME -> 0:0:2
#
# RUN FOR SPT - 309
# 	SUCCESS
# LAP 310 TIME -> 0:0:2
#
# RUN FOR SPD - 310
# 	SUCCESS
# LAP 311 TIME -> 0:0:1
#
# RUN FOR SSPG - 311
# 	SUCCESS
# LAP 312 TIME -> 0:0:0
#
# RUN FOR SMP - 312
# 	SUCCESS
# LAP 313 TIME -> 0:0:2
#
# RUN FOR SGC - 313
# 	SUCCESS
# LAP 314 TIME -> 0:0:2
#
# RUN FOR SYNC - 314
# 	SUCCESS
# LAP 315 TIME -> 0:0:0
#
# RUN FOR SYNT - 315
# 	SUCCESS
# LAP 316 TIME -> 0:0:2
#
# RUN FOR TALK - 316
# 	SUCCESS
# LAP 317 TIME -> 0:0:1
#
# RUN FOR TATE - 317
# 	SUCCESS
# LAP 318 TIME -> 0:0:2
#
# RUN FOR TBCG - 318
# 	SUCCESS
# LAP 319 TIME -> 0:0:0
#
# RUN FOR TED - 319
# 	SUCCESS
# LAP 320 TIME -> 0:0:2
#
# RUN FOR TEP - 320
# 	SUCCESS
# LAP 321 TIME -> 0:0:2
#
# RUN FOR TMPL - 321
# 	SUCCESS
# LAP 322 TIME -> 0:0:1
#
# RUN FOR TEM - 322
# 	SUCCESS
# LAP 323 TIME -> 0:0:1
#
# RUN FOR TIFS - 323
# 	SUCCESS
# LAP 324 TIME -> 0:0:0
#
# RUN FOR TCAP - 324
# 	SUCCESS
# LAP 325 TIME -> 0:0:2
#
# RUN FOR TRY - 325
# 	SUCCESS
# LAP 326 TIME -> 0:0:1
#
# RUN FOR TPK - 326
# 	SUCCESS
# LAP 327 TIME -> 0:0:2
#
# RUN FOR BBOX - 327
# 	SUCCESS
# LAP 328 TIME -> 0:0:0
#
# RUN FOR TLW - 328
# 	SUCCESS
# LAP 329 TIME -> 0:0:2
#
# RUN FOR UDG - 329
# 	SUCCESS
# LAP 330 TIME -> 0:0:2
#
# RUN FOR UKCM - 330
# 	SUCCESS
# LAP 331 TIME -> 0:0:1
#
# RUN FOR ULE - 331
# 	SUCCESS
# LAP 332 TIME -> 0:0:2
#
# RUN FOR UTG - 332
# 	SUCCESS
# LAP 333 TIME -> 0:0:2
#
# RUN FOR VSVS - 333
# 	SUCCESS
# LAP 334 TIME -> 0:0:2
#
# RUN FOR VCT - 334
# 	SUCCESS
# LAP 335 TIME -> 0:0:2
#
# RUN FOR VEIL - 335
# 	SUCCESS
# LAP 336 TIME -> 0:0:0
#
# RUN FOR VOF - 336
# 	SUCCESS
# LAP 337 TIME -> 0:0:1
#
# RUN FOR VVO - 337
# 	SUCCESS
# LAP 338 TIME -> 0:0:0
#
# RUN FOR WEIR - 338
# 	SUCCESS
# LAP 339 TIME -> 0:0:2
#
# RUN FOR JDW - 339
# 	SUCCESS
# LAP 340 TIME -> 0:0:2
#
# RUN FOR SMWH - 340
# 	SUCCESS
# LAP 341 TIME -> 0:0:1
#
# RUN FOR WMH - 341
# 	SUCCESS
# LAP 342 TIME -> 0:0:2
#
# RUN FOR WTAN - 342
# 	SUCCESS
# LAP 343 TIME -> 0:0:1
#
# RUN FOR WIZZ - 343
# 	SUCCESS
# LAP 344 TIME -> 0:0:0
#
# RUN FOR WPCT - 344
# 	SUCCESS
# LAP 345 TIME -> 0:0:0
#
# RUN FOR WG - 345
# 	SUCCESS
# LAP 346 TIME -> 0:0:1
#
# RUN FOR WKP - 346
# 	SUCCESS
# LAP 347 TIME -> 0:0:2
#
# RUN FOR WWH - 347
# 	SUCCESS
# LAP 348 TIME -> 0:0:1
# TOTAL ELAPSED TIME -> 0:11:15
#
#
# COMPLETED - ERRORS ENCOUNTERED -> 0

# %%
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print(df_prices_w.ticker.unique())
df_prices_w.head()
# Out:
# ['3IN' 'AAL' 'ABF' 'ACA' 'ADM' 'AGK' 'AGR' 'AHT' 'AJB' 'AMGO' 'AML' 'ANTO'
#  'APAX' 'ASCL' 'ASHM' 'ASL' 'ATST' 'AUTO' 'AV' 'AVST' 'AVV' 'AZN' 'BA'
#  'BAB' 'BAG' 'BAKK' 'BARC' 'BATS' 'BBA' 'BBGI' 'BBOX' 'BBY' 'BCA' 'BDEV'
#  'BEZ' 'BGEO' 'BGFD' 'BGSC' 'BHP' 'BKG' 'BLND' 'BME' 'BNKR' 'BNZL' 'BOY'
#  'BP' 'BRBY' 'BRSC' 'BT-A' 'BTEM' 'BVIC' 'BVS' 'BWY' 'BYG' 'CAPC' 'CARD'
#  'CBG' 'CCC' 'CCFS' 'CCH' 'CCL' 'CEY' 'CINE' 'CKN' 'CLDN' 'CLI' 'CNA'
#  'CNE' 'COA' 'COB' 'CPG' 'CPI' 'CRDA' 'CRH' 'CRST' 'CSP' 'CTEC' 'CTY'
#  'CWK' 'CYBG' 'DC' 'DCC' 'DGE' 'DJAN' 'DLG' 'DLN' 'DNLM' 'DOM' 'DPH'
#  'DPLM' 'DRX' 'ECM' 'EDIN' 'EIG' 'ELM' 'EMG' 'ENOG' 'EQN' 'ERM' 'ESNT'
#  'ETO' 'EVR' 'EXPN' 'EZJ' 'FCH' 'FCPT' 'FCSS' 'FDM' 'FERG' 'FEV' 'FGP'
#  'FGT' 'FOUR' 'FRCL' 'FRES' 'FSJ' 'FSV' 'FUTR' 'FXPO' 'GAW' 'GCP' 'GFRD'
#  'GFS' 'GFTU' 'GLEN' 'GLO' 'GNC' 'GNK' 'GNS' 'GOG' 'GPOR' 'GRG' 'GRI'
#  'GSK' 'GSS' 'GVC' 'HAS' 'HFG' 'HGT' 'HICL' 'HIK' 'HILS' 'HL' 'HLMA'
#  'HMSO' 'HOC' 'HRI' 'HSBA' 'HSTG' 'HSV' 'HSX' 'HTG' 'HVPE' 'HWDN' 'IAG'
#  'IBST' 'ICP' 'IGG' 'IHG' 'IHP' 'III' 'IMB' 'IMI' 'INCH' 'INF' 'INPP'
#  'INTU' 'INVP' 'IPO' 'ISAT' 'ITRK' 'ITV' 'IWG' 'JAM' 'JD' 'JDW' 'JE' 'JEO'
#  'JFJ' 'JII' 'JLG' 'JMAT' 'JMG' 'JUP' 'KAZ' 'KGF' 'KNOS' 'LAND' 'LGEN'
#  'LLOY' 'LMP' 'LRE' 'LSE' 'LWDB' 'MAB' 'MARS' 'MCRO' 'MCS' 'MDC' 'MERL'
#  'MGAM' 'MGGT' 'MKS' 'MLC' 'MNDI' 'MNKS' 'MONY' 'MRC' 'MRO' 'MRW' 'MSLH'
#  'MTRO' 'MYI' 'NBLS' 'NESF' 'NEX' 'NG' 'NMC' 'NRR' 'NXT' 'OCDO' 'OTB'
#  'OXIG' 'PAG' 'PAGE' 'PAY' 'PCT' 'PETS' 'PFC' 'PFG' 'PHNX' 'PHP' 'PIN'
#  'PLI' 'PLP' 'PLUS' 'PMO' 'PNL' 'PNN' 'POLY' 'PPH' 'PRTC' 'PRU' 'PSH'
#  'PSN' 'PSON' 'PTEC' 'PZC' 'QLT' 'QQ' 'RAT' 'RB' 'RBS' 'RCP' 'RDSA' 'RDW'
#  'REL' 'RHIM' 'RIO' 'RMG' 'RMV' 'RNK' 'ROR' 'RR' 'RSA' 'RSE' 'RSW' 'RTN'
#  'RTO' 'SAFE' 'SBRE' 'SBRY' 'SCIN' 'SCT' 'SDP' 'SDR' 'SEQI' 'SGC' 'SGE'
#  'SGRO' 'SHB' 'SHI' 'SKG' 'SLA' 'SMDS' 'SMIN' 'SMP' 'SMT' 'SMWH' 'SN'
#  'SNN' 'SNR' 'SOPH' 'SPD' 'SPT' 'SPX' 'SRP' 'SSE' 'SSON' 'SSPG' 'STAN'
#  'STJ' 'SVS' 'SVT' 'SXS' 'SXX' 'SYNC' 'SYNT' 'TALK' 'TATE' 'TBCG' 'TCAP'
#  'TED' 'TEM' 'TEP' 'TIFS' 'TLW' 'TMPL' 'TPK' 'TRIG' 'TRY' 'TSCO' 'TUI'
#  'TW' 'UDG' 'UKCM' 'UKW' 'ULE' 'ULVR' 'UTG' 'UU' 'VCT' 'VEIL' 'VOD' 'VOF'
#  'VSVS' 'VVO' 'WEIR' 'WG' 'WIZZ' 'WKP' 'WMH' 'WPCT' 'WPP' 'WTAN' 'WTB'
#  'WWH']
#   ticker       date  high  low    volume      open  close  ema12  ema26  \
# 0    3IN 2007-12-31   NaN  NaN       NaN       NaN    NaN    NaN    NaN
# 1    3IN 2008-01-07   0.0  NaN  1.000000  0.000000    1.0    NaN    NaN
# 2    3IN 2008-01-14   1.0  1.0  0.799111  0.668246    1.0    NaN    NaN
# 3    3IN 2008-01-21   1.0  0.0  1.000000  0.336493    1.0    NaN    NaN
# 4    3IN 2008-01-28   1.0  1.0  0.670041  1.000000    1.0    NaN    NaN
#
#    macd_line  signal_line  macd  change_price  per_change_price
# 0        NaN          NaN   NaN         -1.75         -0.011731
# 1        NaN          NaN   NaN          1.76          0.011967
# 2        NaN          NaN   NaN          0.70          0.004714
# 3        NaN          NaN   NaN          4.22          0.028556
# 4        NaN          NaN   NaN          2.11          0.014077

# %% [markdown]
# # Create buy signals, and sell signals
# I am classifying a stock worth buying if it meets all the below criteria:
# - The target price (previous max) is hit within x (set as variable target_price_period) periods proceeding this period
# - The target price is an increase of x% (set as variable min_gain) over the proceeding day's open price
# - There is a drop in the closing price of less x% (set as variable max_drop) between this period and the x periods proceeding this period
#
# I am classifying the sell signals as:
# - The close price dips below the target price (previous max) x (set as variable target_price_period) periods proceeding this period
# - There is an increase in the closing price of less x% (set as variable max_drop) over the next x periods

# %%
#Define the variables
target_price_period = 12
period_high_volatility = 3
period_low_volatility = 1
min_gain = 0.1
max_drop = -0.05

# %%
#Programming note
#df.shift(1) looks 1 period into the past
#df.shift(-1) looks 1 period into the future

# %%
#Check if the target price is hit within the target_price_period
def min_gain_check(_var_s,_target_s,_periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,_periods+1):
        _tmp_check_s = _var_s.shift(-_i) > _target_s #True if price is >= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def max_drop_check(_var_s,_target_s,periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,periods+1):
        _tmp_check_s = _var_s.shift(-_i) < _target_s #True if price is <= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
#Create a function for finding buy signals
def get_buys(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == True #Function returns True when min_gain is hit
    print('BUY min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the sell price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == False #Function returns False when does not go below target
    print('BUY max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Find the buy signals
    s_out = min_gain_s & max_drop_s
    print('BUY ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Function for finding sell signals
def get_sells(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == True #Function returns True when max_drop is hit
    print('SELL max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Perform if the target is crossed again
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == False #Function returns False when min_gain is not hit
    print('SELL min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Find the sell signals
    s_out = max_drop_s & min_gain_s
    print('SELL ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Get buy signals
df_prices_w['buy'] = get_buys(df_prices_w['close'])

#Get sell signals
df_prices_w['sell'] = get_sells(df_prices_w['close'])

#Get hold signals
df_prices_w["hold"] = (df_prices_w["buy"] == False) & (df_prices_w["sell"] == False)

print('BUY PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['buy'] == True].shape[0]/df_prices_w.shape[0]))
print('SELL PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['sell'] == True].shape[0]/df_prices_w.shape[0]))
print('HOLD PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['hold'] == True].shape[0]/df_prices_w.shape[0]))
# Out:
# BUY min_gain_s -> (138213,)
# BUY max_drop_s -> (104310,)
# BUY ALL -> (82965,)
# SELL max_drop_s -> (154029,)
# SELL min_gain_s -> (120126,)
# SELL ALL -> (98781,)
# BUY PERCENTAGE -> 0.32%
# SELL PERCENTAGE -> 0.38%
# HOLD PERCENTAGE -> 0.30%

# %% [markdown]
# # Create additional features

# %%
#Mark minimums and maximums
def flag_mins(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in > s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value > the previous value
        s_out += (s_in > s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value > the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out
def flag_maxs(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in < s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value < the previous value (if the previous value is not null)
        s_out += (s_in < s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value < the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out

# %%
#Calc vol as proportion of previous n-rows
def calc_prop_of_prev(s_in,periods:int = 4):
    s_cum = s_in.copy()
    for i in range(1,periods):
        s_cum += s_in.shift(i)
    return s_in / s_cum

# %%
#Mark points of macd positive entry
def pos_entry(s_in):
    return (s_in > s_in.shift(1)) & (s_in > 0) & (s_in.shift(1) < 0)
def neg_entry(s_in):
    return (s_in < s_in.shift(1)) & (s_in < 0) & (s_in.shift(1) > 0)

# %%
#Function to normalise current price compared to another
def norm_s(s_in,max_in,min_in):
    s_out = (s_in - min_in) / (max_in - min_in)
    s_out.fillna(1.0,inplace=True)
    return s_out

# %%
#Function to find last max and mins
def prev_value(df_in,var_col,bool_col):
    df_in["prev_val"] = df_in.loc[df_in[bool_col],var_col]
    df_in["prev_val"] = df_in["prev_val"].fillna(method='ffill')
    df_in["prev_marker_date"] = df_in.loc[df_in[bool_col],"date"]
    df_in["prev_marker_date"] = df_in["prev_marker_date"].fillna(method='ffill')
    return (df_in["prev_val"],df_in["prev_marker_date"])

# %%
#Create separate columns for pos and neg values - allows for normalisation
def pos_neg_cols(s_in,gt_lt = "GT"):
    if gt_lt.upper() == "GT":
        bool_s = s_in >= 0
    elif gt_lt.upper() == "LT":
        bool_s = s_in <= 0
    df_out = s_in.to_frame()
    df_out["s_in"] = s_in
    df_out["val"] = abs(s_in[bool_s])
    val_s = df_out["val"].fillna(0,method=None)
    return (bool_s,val_s)

# %%
#Function for calculating the max and mins within a period
def max_min_period(s_in,periods:int=4):
    #Copy into max and min
    max_s = s_in.copy()
    min_s = s_in.copy()
    #Go through periods and mark where it is a new max or min
    for i in range(1,(periods+1)):
        #Calc max
        tmp_check_s = s_in.shift(i) >= max_s
        max_s[tmp_check_s] = s_in.shift(i)
        #Calc min
        tmp_check_s = s_in.shift(i) <= min_s
        min_s[tmp_check_s] = s_in.shift(i)
    #Normalise the series
    s_out = norm_s(s_in,max_s,min_s)
    return s_out

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(df_prices_w)
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'high': 22,
#  'low': 22,
#  'volume': 22,
#  'open': 22,
#  'close': 22,
#  'ema12': 22,
#  'ema26': 22,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23,
#  'change_price': 21,
#  'per_change_price': 23,
#  'buy': 5,
#  'sell': 5,
#  'hold': 5}

# %%
#Create a single function to run each stock through feature creation
def create_features(df_in):  
    
    df_out = df_in.copy() 
    
    #Calc vol as proportion of previous n-rows
    df_out["prop_vol"] = calc_prop_of_prev(df_out["volume"].copy().astype("float"),6)

    #Get period-period changes
    df_out["close_shift1"] = df_out["close"].shift(1)
    df_out["change_close_shift1"],df_out["per_change_close_shift1"] = calc_changes(df_out[["close","close_shift1"]].copy(),"close","close_shift1")

    df_out["vol_shift1"] = df_out["volume"].shift(1)
    df_out["change_vol_shift1"],df_out["per_change_vol_shift1"] = calc_changes(df_out[["volume","vol_shift1"]].copy(),"volume","vol_shift1")

    df_out["macd_shift1"] = df_out["macd"].shift(1)
    df_out["change_macd_shift1"],df_out["per_change_macd_shift1"] = calc_changes(df_out[["macd","vol_shift1"]].copy(),"macd","vol_shift1")

    df_out["ema26_shift1"] = df_out["ema26"].shift(1)
    df_out["change_ema26_shift1"],df_out["per_change_ema26_shift1"] = calc_changes(df_out[["ema26","ema26_shift1"]].copy(),"ema26","ema26_shift1")
    
    #Compare close to the max/mins within 13, 26 and 52 periods
    df_out["close_13_norm"] = max_min_period(df_out["close"],13)
    df_out["close_26_norm"] = max_min_period(df_out["close"],26)
    df_out["close_52_norm"] = max_min_period(df_out["close"],52)
    
    #Compare macd to the max/mins within 13, 26 and 52 periods
    df_out["macd_line_13_norm"] = max_min_period(df_out["macd_line"],13)
    df_out["macd_line_26_norm"] = max_min_period(df_out["macd_line"],26)
    df_out["macd_line_52_norm"] = max_min_period(df_out["macd_line"],52)
        
    #Mark points of macd positive entry
    df_out["macd_pos_ent"] = pos_entry(df_out["macd"])
    df_out["macd_neg_ent"] = neg_entry(df_out["macd"])
    
    #Create separate columns for pos and neg values - allows for normalisation
    df_out["macd_pos_bool"],df_out["macd_pos_val"] = pos_neg_cols(df_out["macd"],gt_lt = "GT")
    df_out["macd_neg_bool"],df_out["macd_neg_val"] = pos_neg_cols(df_out["macd"],gt_lt = "LT")
    df_out["signal_line_pos_bool"],df_out["signal_line_pos_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "GT")
    df_out["signal_line_neg_bool"],df_out["signal_line_neg_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "LT")
    df_out["change_price_pos_bool"],df_out["change_price_pos_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "GT")
    df_out["change_price_neg_bool"],df_out["change_price_neg_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "LT")
    df_out["per_change_price_pos_bool"],df_out["per_change_price_pos_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "GT")
    df_out["per_change_price_neg_bool"],df_out["per_change_price_neg_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "LT")

    #Create max min columns
    def mk_cols_max_min(tmp_df,col,period:int=4):
        tmp_df["{}_min".format(col)] = flag_mins(tmp_df[col],period)
        tmp_df["{}_max".format(col)] = flag_maxs(tmp_df[col],period)
        
    #Find previous max and mins, then look at:
        # - how many positive or negative moves in a row there has been
        # - what the move since the last (n-1) max/min was
        # - what the gradient is since the last (n-1) max/min
        # - what the move since the first max/min was
        # - what the gradient since the first max/min was
    def mk_cols_prev_max_min(tmp_df,col,period:int=4):
        #GETTING THE MAX/MINS
        tmp_df["prev_max_{}".format(col)],tmp_df["prev_max_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_max".format(col)]].copy(),col,"{}_max".format(col))
        tmp_df["prev_min_{}".format(col)],tmp_df["prev_min_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_min".format(col)]].copy(),col,"{}_min".format(col))
        #Shift the max min columns by n periods to not leak future information
        tmp_df["prev_max_{}".format(col)] = tmp_df["prev_max_{}".format(col)].shift(period)
        tmp_df["prev_min_{}".format(col)] = tmp_df["prev_min_{}".format(col)].shift(period)
        tmp_df["prev_max_{}_date".format(col)] = tmp_df["prev_max_{}_date".format(col)].shift(period)
        tmp_df["prev_min_{}_date".format(col)] = tmp_df["prev_min_{}_date".format(col)].shift(period)
        def mk_prev_move_float(_s_in):
            _s_out = _s_in - _s_in.shift(1)
            _s_out[_s_out == 0] = np.nan
            _s_out = _s_out.fillna(method='ffill')
            return _s_out
        def mk_prev_move_date(_s_in,_periods:int=7):
            _s_out = _s_in - _s_in.shift(1)
            _s_check = pd.Series([np.floor(_x.days) for _x in _s_out])
            _s_check[_s_check == 0] = np.nan
            _s_check = _s_check.fillna(method='ffill')
            _s_check = [np.floor(_x/_periods) for _x in _s_check]
            return _s_check
        #Create features for the cumulative sequential count of max/mins in a certain direction
        def mk_move_cum(_s_in,_gtlt:str='pos'):
            _li_out = []
            _prev_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _s_in.iteritems():
                    if _x < 0: #If less than 0 then reset to 0
                        _li_out.append(0)
                    else:
                        if len(_li_out) == 0: #If this is the first value add it to the list
                            _li_out.append(1)
                        else:
                            if _prev_x != _x: #if there has been a change in value from this and the previous value increment it by 1
                                _li_out.append(_li_out[-1] + 1)
                            else: #Otherwise just use the last added value
                                _li_out.append(_li_out[-1])
                    _prev_x = _x
            elif _gtlt.lower() == 'neg':
                for _i,_x in _s_in.iteritems():
                    if _x > 0:
                        _li_out.append(0)
                    else:
                        if len(_li_out) == 0:
                            _li_out.append(1)
                        else:
                            if _prev_x != _x:
                                _li_out.append(_li_out[-1] + 1)
                            else:
                                _li_out.append(_li_out[-1])
                    _prev_x = _x
            return _li_out
        #Create features showing the value change since the first min/max
        def mk_long_prev_move_float(_ref_s,_val_s,_gtlt:str='pos'):
            _li_out = []
            _st_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x < 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
            elif _gtlt.lower() == 'neg':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x > 0: #If greater than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
            return _li_out
        def mk_long_prev_move_date(_ref_s,_val_s,_gtlt:str='pos',_periods:int=7):
            _li_out = []
            _st_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x < 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
            elif _gtlt.lower() == 'neg':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x > 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
            return _li_out
        #WHAT WAS THE MOVE SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_max_{}".format(col)])
        tmp_df['prev_max_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_max_{}_date".format(col)])        
        tmp_df['prev_min_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_min_{}".format(col)])
        tmp_df['prev_min_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_min_{}_date".format(col)])
        #WHAT IS THE GRADIENT SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_grad_{}'.format(col)] = tmp_df['prev_max_move_{}'.format(col)] / tmp_df['prev_max_date_move_{}'.format(col)]
        tmp_df['prev_min_grad_{}'.format(col)] = tmp_df['prev_min_move_{}'.format(col)] / tmp_df['prev_min_date_move_{}'.format(col)]
        #HOW MANY PROGRESSIVE MAX/MINS IN A ROW HAVE THERE BEEN - UP OR DOWN FOR BOTH OPTIONS
        tmp_df['max_move_cum_pos_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)],'pos')
        tmp_df['max_move_cum_neg_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)],'neg')
        tmp_df['min_move_cum_pos_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)],'pos')
        tmp_df['min_move_cum_neg_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)],'neg')
        #WHAT WAS THE MOVE SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_pos_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)],'pos')
        tmp_df['long_prev_max_move_neg_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)],'neg')
        tmp_df['long_prev_min_move_pos_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)],'pos')
        tmp_df['long_prev_min_move_neg_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)],'neg')
        #WHAT WAS THE TIMEDELTA SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_pos_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)],'pos')
        tmp_df['long_prev_max_move_neg_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)],'neg')
        tmp_df['long_prev_min_move_pos_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)],'pos')
        tmp_df['long_prev_min_move_neg_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)],'neg')
        #WHAT IS THE GRADIENT SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_max_grad_pos_{}'.format(col)] = tmp_df['long_prev_max_move_pos_{}'.format(col)] / tmp_df['long_prev_max_move_pos_date_{}'.format(col)]
        tmp_df['long_max_grad_pos_{}'.format(col)] = tmp_df['long_max_grad_pos_{}'.format(col)].fillna(0)
        tmp_df['long_max_grad_neg_{}'.format(col)] = tmp_df['long_prev_max_move_neg_{}'.format(col)] / tmp_df['long_prev_max_move_neg_date_{}'.format(col)]
        tmp_df['long_max_grad_neg_{}'.format(col)] = tmp_df['long_max_grad_neg_{}'.format(col)].fillna(0)
        tmp_df['long_min_grad_pos_{}'.format(col)] = tmp_df['long_prev_min_move_pos_{}'.format(col)] / tmp_df['long_prev_min_move_pos_date_{}'.format(col)]
        tmp_df['long_min_grad_pos_{}'.format(col)] = tmp_df['long_min_grad_pos_{}'.format(col)].fillna(0)
        tmp_df['long_min_grad_neg_{}'.format(col)] = tmp_df['long_prev_min_move_neg_{}'.format(col)] / tmp_df['long_prev_min_move_neg_date_{}'.format(col)]
        tmp_df['long_min_grad_neg_{}'.format(col)] = tmp_df['long_min_grad_neg_{}'.format(col)].fillna(0)
    
    #Calc the value changes and percentage changes of these movements
    def mk_cols_prev_max_min_change(tmp_df,col):
        tmp_df["max_change_{}".format(col)],tmp_df["max_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_max_{}".format(col)]].copy(),col,"prev_max_{}".format(col))
        tmp_df["min_change_{}".format(col)],tmp_df["min_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_min_{}".format(col)]].copy(),col,"prev_min_{}".format(col))
        
    #Mark date change since max and mins and convert to periods
    def mk_cols_prev_max_min_date_change(tmp_df,col,period:int=7):
        tmp_df["prev_max_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_max_{}_date".format(col)]
        tmp_df["prev_min_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_min_{}_date".format(col)]
        #Convert all to period changes
        tmp_df["prev_max_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_max_{}_date_change".format(col)]]
        tmp_df["prev_min_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_min_{}_date_change".format(col)]]
    
    #Convert the max min changes into pos and neg columns
    def mk_cols_prev_max_min_change_pos_neg(tmp_df,col):
        #Only do pos changes for mins and neg changes for max (as it can only go below the max and above the min)
        tmp_df["max_change_{}_pos_bool".format(col)],tmp_df["max_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "GT")
        tmp_df["max_change_{}_neg_bool".format(col)],tmp_df["max_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "LT")
        tmp_df["min_change_{}_pos_bool".format(col)],tmp_df["min_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "GT")
        tmp_df["min_change_{}_neg_bool".format(col)],tmp_df["min_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "LT")
        #Drop the old columns
        tmp_df.drop(columns=["max_change_{}".format(col),"min_change_{}".format(col)],inplace=True)

    #Run function for columns - high volatility
    for col in ['close','signal_line']:
        mk_cols_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    #Run function for columns - low volatility
    for col in ['macd','ema26','macd_line']:
        mk_cols_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    
    #Check for undefined
    df_out["no_signal"] = (df_out["buy"] == False) & (df_out["hold"] == False) & (df_out["sell"] == False)
    
    #Composite all singals into one column
    df_out["signal"] = None
    df_out.loc[df_out["buy"] == True,"signal"] = "buy"
    df_out.loc[df_out["hold"] == True,"signal"] = "hold"
    df_out.loc[df_out["sell"] == True,"signal"] = "sell"
    df_out.drop(columns=["buy","hold","sell"],inplace=True)
    print("SIGNAL COUNTS: \n{}".format(df_out["signal"].value_counts()))
    
    return df_out

# %%
#Define the columns for the output
out_cols = [
    #NON-NORMALISED COLS
    "ticker"
    ,"date"
    #NORMALISED COLS
    #Standard features
    ,"open"
    ,"close"
    ,"high"
    ,"low"
    ,"volume"
    ,"change_price"
    ,"per_change_price"
    #Shifted features
    ,"close_shift1"
    ,"change_close_shift1"
    ,"vol_shift1"
    ,"change_vol_shift1"
    ,"ema26_shift1"
    ,"change_ema26_shift1"
    #change to periodic max mins
    ,"close_13_norm"
    ,"close_26_norm"
    ,"close_52_norm"
    ,"macd_line_13_norm"
    ,"macd_line_26_norm"
    ,"macd_line_52_norm"
    #Pos neg features
    ,"macd_pos_val"
    ,"macd_neg_val"
    ,"signal_line_pos_val"
    ,"signal_line_neg_val"
    ,"change_price_pos_val"
    ,"change_price_neg_val"
    ,"per_change_price_pos_val"
    ,"per_change_price_neg_val"
]
#Append additional columns for key areas
for col in ['close','macd','ema26','signal_line','macd_line']:
    out_cols
    #Prev max/min features
    out_cols.append("prev_max_{}".format(col))
    out_cols.append("prev_min_{}".format(col))
    #date changes
    out_cols.append("prev_max_{}_date_change".format(col))
    out_cols.append("prev_min_{}_date_change".format(col))
    #Min max change features
    out_cols.append("max_change_{}_pos_val".format(col))
    out_cols.append("max_change_{}_neg_val".format(col))
    out_cols.append("min_change_{}_pos_val".format(col))
    out_cols.append("min_change_{}_neg_val".format(col))
    #prev max/mins (n-1) - compared to previous
    out_cols.append('prev_max_grad_{}'.format(col))
    out_cols.append('prev_min_grad_{}'.format(col))
    #prev max/mins (n=0) - compared to first in this run
    out_cols.append('max_move_cum_pos_{}'.format(col))
    out_cols.append('max_move_cum_neg_{}'.format(col))
    out_cols.append('min_move_cum_pos_{}'.format(col))
    out_cols.append('min_move_cum_neg_{}'.format(col))
    out_cols.append('long_prev_max_move_pos_date_{}'.format(col))
    out_cols.append('long_prev_max_move_neg_date_{}'.format(col))
    out_cols.append('long_prev_min_move_pos_date_{}'.format(col))
    out_cols.append('long_prev_min_move_neg_date_{}'.format(col))
    out_cols.append('long_max_grad_pos_{}'.format(col))
    out_cols.append('long_max_grad_neg_{}'.format(col))
    out_cols.append('long_min_grad_pos_{}'.format(col))
    out_cols.append('long_min_grad_neg_{}'.format(col))
#Append signal
out_cols.append("signal")

# %%
#Then loop the tickers and combine these into one large dataset
hf_store_name = path+'all_hist_prices_w_ft_eng2_TMP.h5'
h_store = pd.HDFStore(hf_store_name)
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse["ticker"]:
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print("\n{}".format(count))
        print("RUN FOR {}".format(tick))
        #Isolate this ticker
        this_tick_df = df_prices_w[df_prices_w["ticker"] == re.sub('[^a-zA-Z0-9\-]','',tick)].copy()
        print("shape before: {}".format(this_tick_df.shape))
        #Create the features
        this_tick_df = create_features(this_tick_df)
#         print(this_tick_df[out_cols])
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in out_cols:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
        print("shape after: {}".format(this_tick_df.shape))
        #Append this data to the group
        try:
            this_tick_df[out_cols].to_hdf(hf_store_name,key='weekly_data',append=True,min_itemsize=col_lens_tmp)
            print('ADDED TO {}'.format(hf_store_name))
        except Exception as e:
            print('ERROR READING TO FILE {}'.format(e))
    except Exception as e:
        h_store.close()
        errors.append({"ticker":tick,"Error":e})
        print('ERROR PROCESSING DATA {}'.format(e))
h_store.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1
# RUN FOR III
# shape before: (612, 17)
# SIGNAL COUNTS:
# sell    269
# buy     185
# hold    158
# Name: signal, dtype: int64
# shape after: (612, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 1 TIME -> 0:0:0
#
# 2
# RUN FOR ADM
# shape before: (368, 17)
# SIGNAL COUNTS:
# buy     137
# hold    129
# sell    102
# Name: signal, dtype: int64
# shape after: (368, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 2 TIME -> 0:0:2
#
# 3
# RUN FOR AAL
# shape before: (1012, 17)
# SIGNAL COUNTS:
# sell    405
# buy     320
# hold    287
# Name: signal, dtype: int64
# shape after: (1012, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 3 TIME -> 0:0:2
#
# 4
# RUN FOR ANTO
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    405
# buy     382
# hold    263
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 4 TIME -> 0:0:3
#
# 5
# RUN FOR AHT
# shape before: (1028, 17)
# SIGNAL COUNTS:
# buy     400
# sell    373
# hold    255
# Name: signal, dtype: int64
# shape after: (1028, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 5 TIME -> 0:0:3
#
# 6
# RUN FOR ABF
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    431
# buy     372
# hold    247
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 6 TIME -> 0:0:3
#
# 7
# RUN FOR AZN
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    412
# hold    354
# buy     284
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 7 TIME -> 0:0:3
#
# 8
# RUN FOR AUTO
# shape before: (235, 17)
# SIGNAL COUNTS:
# hold    99
# buy     74
# sell    62
# Name: signal, dtype: int64
# shape after: (235, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 8 TIME -> 0:0:3
#
# 9
# RUN FOR AVV
# shape before: (1050, 17)
# SIGNAL COUNTS:
# buy     452
# sell    352
# hold    246
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 9 TIME -> 0:0:2
#
# 10
# RUN FOR AV
# shape before: (1054, 17)
# SIGNAL COUNTS:
# sell    482
# buy     301
# hold    271
# Name: signal, dtype: int64
# shape after: (1054, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 10 TIME -> 0:0:3
#
# 11
# RUN FOR BA
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    462
# buy     334
# hold    254
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 11 TIME -> 0:0:3
#
# 12
# RUN FOR BARC
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    538
# buy     263
# hold    249
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 12 TIME -> 0:0:3
#
# 13
# RUN FOR BDEV
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    422
# buy     392
# hold    236
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 13 TIME -> 0:0:3
#
# 14
# RUN FOR BKG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# buy     360
# hold    357
# sell    333
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 14 TIME -> 0:0:3
#
# 15
# RUN FOR BHP
# shape before: (496, 17)
# SIGNAL COUNTS:
# sell    185
# buy     182
# hold    129
# Name: signal, dtype: int64
# shape after: (496, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 15 TIME -> 0:0:3
#
# 16
# RUN FOR BP
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    416
# hold    356
# buy     278
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 16 TIME -> 0:0:2
#
# 17
# RUN FOR BATS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    371
# buy     348
# hold    331
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 17 TIME -> 0:0:3
#
# 18
# RUN FOR BLND
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    389
# buy     354
# hold    307
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 18 TIME -> 0:0:3
#
# 19
# RUN FOR BT-A
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    498
# buy     315
# hold    237
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 19 TIME -> 0:0:3
#
# 20
# RUN FOR BNZL
# shape before: (1047, 17)
# SIGNAL COUNTS:
# sell    375
# hold    343
# buy     329
# Name: signal, dtype: int64
# shape after: (1047, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 20 TIME -> 0:0:3
#
# 21
# RUN FOR BRBY
# shape before: (897, 17)
# SIGNAL COUNTS:
# sell    337
# buy     314
# hold    246
# Name: signal, dtype: int64
# shape after: (897, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 21 TIME -> 0:0:3
#
# 22
# RUN FOR CCL
# shape before: (986, 17)
# SIGNAL COUNTS:
# sell    413
# buy     320
# hold    253
# Name: signal, dtype: int64
# shape after: (986, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 22 TIME -> 0:0:3
#
# 23
# RUN FOR CNA
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    546
# buy     267
# hold    237
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 23 TIME -> 0:0:3
#
# 24
# RUN FOR CCH
# shape before: (333, 17)
# SIGNAL COUNTS:
# hold    121
# sell    113
# buy      99
# Name: signal, dtype: int64
# shape after: (333, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 24 TIME -> 0:0:3
#
# 25
# RUN FOR CPG
# shape before: (1028, 17)
# SIGNAL COUNTS:
# sell    394
# buy     325
# hold    309
# Name: signal, dtype: int64
# shape after: (1028, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 25 TIME -> 0:0:2
#
# 26
# RUN FOR CRH
# shape before: (1028, 17)
# SIGNAL COUNTS:
# hold    386
# sell    342
# buy     300
# Name: signal, dtype: int64
# shape after: (1028, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 26 TIME -> 0:0:3
#
# 27
# RUN FOR CRDA
# shape before: (1042, 17)
# SIGNAL COUNTS:
# hold    361
# buy     348
# sell    333
# Name: signal, dtype: int64
# shape after: (1042, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 27 TIME -> 0:0:3
#
# 28
# RUN FOR DCC
# shape before: (1024, 17)
# SIGNAL COUNTS:
# buy     373
# sell    348
# hold    303
# Name: signal, dtype: int64
# shape after: (1024, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 28 TIME -> 0:0:3
#
# 29
# RUN FOR DGE
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    372
# hold    350
# buy     328
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 29 TIME -> 0:0:3
#
# 30
# RUN FOR DLG
# shape before: (362, 17)
# SIGNAL COUNTS:
# sell    150
# buy     106
# hold    106
# Name: signal, dtype: int64
# shape after: (362, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 30 TIME -> 0:0:3
#
# 31
# RUN FOR EVR
# shape before: (410, 17)
# SIGNAL COUNTS:
# hold    151
# sell    144
# buy     115
# Name: signal, dtype: int64
# shape after: (410, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 31 TIME -> 0:0:2
#
# 32
# RUN FOR EXPN
# shape before: (675, 17)
# SIGNAL COUNTS:
# sell    246
# buy     234
# hold    195
# Name: signal, dtype: int64
# shape after: (675, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 32 TIME -> 0:0:2
#
# 33
# RUN FOR FERG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    436
# buy     322
# hold    292
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 33 TIME -> 0:0:3
#
# 34
# RUN FOR FRES
# shape before: (593, 17)
# SIGNAL COUNTS:
# sell    270
# buy     165
# hold    158
# Name: signal, dtype: int64
# shape after: (593, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 34 TIME -> 0:0:3
#
# 35
# RUN FOR GSK
# shape before: (1050, 17)
# SIGNAL COUNTS:
# hold    452
# sell    344
# buy     254
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 35 TIME -> 0:0:2
#
# 36
# RUN FOR GLEN
# shape before: (435, 17)
# SIGNAL COUNTS:
# sell    204
# buy     133
# hold     98
# Name: signal, dtype: int64
# shape after: (435, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 36 TIME -> 0:0:3
#
# 37
# RUN FOR HLMA
# shape before: (1018, 17)
# SIGNAL COUNTS:
# buy     392
# sell    348
# hold    278
# Name: signal, dtype: int64
# shape after: (1018, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 37 TIME -> 0:0:2
#
# 38
# RUN FOR HL
# shape before: (638, 17)
# SIGNAL COUNTS:
# buy     242
# sell    222
# hold    174
# Name: signal, dtype: int64
# shape after: (638, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 38 TIME -> 0:0:3
#
# 39
# RUN FOR HSX
# shape before: (1028, 17)
# SIGNAL COUNTS:
# sell    381
# buy     348
# hold    299
# Name: signal, dtype: int64
# shape after: (1028, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 39 TIME -> 0:0:3
#
# 40
# RUN FOR HSBA
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    509
# buy     283
# hold    258
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 40 TIME -> 0:0:3
#
# 41
# RUN FOR IMB
# shape before: (1048, 17)
# SIGNAL COUNTS:
# sell    402
# buy     340
# hold    306
# Name: signal, dtype: int64
# shape after: (1048, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 41 TIME -> 0:0:3
#
# 42
# RUN FOR INF
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    411
# buy     358
# hold    281
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 42 TIME -> 0:0:3
#
# 43
# RUN FOR IHG
# shape before: (871, 17)
# SIGNAL COUNTS:
# sell    320
# buy     295
# hold    256
# Name: signal, dtype: int64
# shape after: (871, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 43 TIME -> 0:0:3
#
# 44
# RUN FOR IAG
# shape before: (872, 17)
# SIGNAL COUNTS:
# sell    317
# buy     278
# hold    277
# Name: signal, dtype: int64
# shape after: (872, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 44 TIME -> 0:0:3
#
# 45
# RUN FOR ITRK
# shape before: (901, 17)
# SIGNAL COUNTS:
# buy     357
# sell    312
# hold    232
# Name: signal, dtype: int64
# shape after: (901, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 45 TIME -> 0:0:3
#
# 46
# RUN FOR ITV
# shape before: (1028, 17)
# SIGNAL COUNTS:
# sell    462
# buy     293
# hold    273
# Name: signal, dtype: int64
# shape after: (1028, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 46 TIME -> 0:0:3
#
# 47
# RUN FOR JD
# shape before: (166, 17)
# SIGNAL COUNTS:
# buy     77
# sell    52
# hold    37
# Name: signal, dtype: int64
# shape after: (166, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 47 TIME -> 0:0:3
#
# 48
# RUN FOR JMAT
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    403
# buy     370
# hold    277
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 48 TIME -> 0:0:2
#
# 49
# RUN FOR JE
# shape before: (285, 17)
# SIGNAL COUNTS:
# hold    114
# buy      93
# sell     78
# Name: signal, dtype: int64
# shape after: (285, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 49 TIME -> 0:0:3
#
# 50
# RUN FOR KGF
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    503
# buy     279
# hold    268
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 50 TIME -> 0:0:2
#
# 51
# RUN FOR LAND
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    470
# buy     339
# hold    241
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 51 TIME -> 0:0:4
#
# 52
# RUN FOR LGEN
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    454
# buy     320
# hold    276
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 52 TIME -> 0:0:3
#
# 53
# RUN FOR LLOY
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    523
# hold    277
# buy     250
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 53 TIME -> 0:0:4
#
# 54
# RUN FOR LSE
# shape before: (948, 17)
# SIGNAL COUNTS:
# buy     349
# hold    335
# sell    264
# Name: signal, dtype: int64
# shape after: (948, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 54 TIME -> 0:0:3
#
# 55
# RUN FOR MKS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    450
# hold    339
# buy     261
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 55 TIME -> 0:0:3
#
# 56
# RUN FOR MRO
# shape before: (828, 17)
# SIGNAL COUNTS:
# sell    307
# buy     305
# hold    216
# Name: signal, dtype: int64
# shape after: (828, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 56 TIME -> 0:0:4
#
# 57
# RUN FOR MCRO
# shape before: (749, 17)
# SIGNAL COUNTS:
# buy     277
# hold    240
# sell    232
# Name: signal, dtype: int64
# shape after: (749, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 57 TIME -> 0:0:3
#
# 58
# RUN FOR MNDI
# shape before: (630, 17)
# SIGNAL COUNTS:
# sell    248
# buy     210
# hold    172
# Name: signal, dtype: int64
# shape after: (630, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 58 TIME -> 0:0:3
#
# 59
# RUN FOR MRW
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    442
# hold    312
# buy     296
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 59 TIME -> 0:0:3
#
# 60
# RUN FOR NG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    373
# hold    347
# buy     330
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 60 TIME -> 0:0:4
#
# 61
# RUN FOR NXT
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    377
# buy     373
# hold    300
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 61 TIME -> 0:0:4
#
# 62
# RUN FOR NMC
# shape before: (389, 17)
# SIGNAL COUNTS:
# buy     170
# hold    116
# sell    103
# Name: signal, dtype: int64
# shape after: (389, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 62 TIME -> 0:0:4
#
# 63
# RUN FOR OCDO
# shape before: (478, 17)
# SIGNAL COUNTS:
# hold    178
# sell    155
# buy     145
# Name: signal, dtype: int64
# shape after: (478, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 63 TIME -> 0:0:3
#
# 64
# RUN FOR PSON
# shape before: (1050, 17)
# SIGNAL COUNTS:
# hold    387
# sell    382
# buy     281
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 64 TIME -> 0:0:3
#
# 65
# RUN FOR PSN
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    392
# buy     372
# hold    286
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 65 TIME -> 0:0:4
#
# 66
# RUN FOR PHNX
# shape before: (511, 17)
# SIGNAL COUNTS:
# sell    219
# buy     158
# hold    134
# Name: signal, dtype: int64
# shape after: (511, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 66 TIME -> 0:0:4
#
# 67
# RUN FOR PRU
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    424
# buy     335
# hold    291
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 67 TIME -> 0:0:3
#
# 68
# RUN FOR RB
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    364
# hold    358
# buy     328
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 68 TIME -> 0:0:4
#
# 69
# RUN FOR REL
# shape before: (1050, 17)
# SIGNAL COUNTS:
# hold    396
# sell    335
# buy     319
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 69 TIME -> 0:0:4
#
# 70
# RUN FOR RTO
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    450
# buy     385
# hold    215
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 70 TIME -> 0:0:4
#
# 71
# RUN FOR RIO
# shape before: (1050, 17)
# SIGNAL COUNTS:
# hold    384
# sell    353
# buy     313
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 71 TIME -> 0:0:4
#
# 72
# RUN FOR RMV
# shape before: (706, 17)
# SIGNAL COUNTS:
# buy     282
# sell    247
# hold    177
# Name: signal, dtype: int64
# shape after: (706, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 72 TIME -> 0:0:4
#
# 73
# RUN FOR RR
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    407
# buy     374
# hold    269
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 73 TIME -> 0:0:3
#
# 74
# RUN FOR RBS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    443
# hold    376
# buy     231
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 74 TIME -> 0:0:4
#
# 75
# RUN FOR RDSA
# shape before: (492, 17)
# SIGNAL COUNTS:
# sell    179
# hold    173
# buy     140
# Name: signal, dtype: int64
# shape after: (492, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 75 TIME -> 0:0:4
#
# 76
# RUN FOR RSA
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    474
# buy     305
# hold    271
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 76 TIME -> 0:0:3
#
# 77
# RUN FOR SGE
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    427
# buy     319
# hold    304
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 77 TIME -> 0:0:4
#
# 78
# RUN FOR SBRY
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    424
# hold    342
# buy     284
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 78 TIME -> 0:0:4
#
# 79
# RUN FOR SDR
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    399
# hold    333
# buy     318
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 79 TIME -> 0:0:4
#
# 80
# RUN FOR SMT
# shape before: (137, 17)
# SIGNAL COUNTS:
# hold    54
# buy     48
# sell    35
# Name: signal, dtype: int64
# shape after: (137, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 80 TIME -> 0:0:4
#
# 81
# RUN FOR SGRO
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    422
# buy     336
# hold    292
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 81 TIME -> 0:0:3
#
# 82
# RUN FOR SVT
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    423
# buy     337
# hold    290
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 82 TIME -> 0:0:4
#
# 83
# RUN FOR SN
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    401
# hold    327
# buy     322
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 83 TIME -> 0:0:4
#
# 84
# RUN FOR SMDS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    415
# buy     356
# hold    279
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 84 TIME -> 0:0:4
#
# 85
# RUN FOR SMIN
# shape before: (1034, 17)
# SIGNAL COUNTS:
# sell    380
# buy     345
# hold    309
# Name: signal, dtype: int64
# shape after: (1034, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 85 TIME -> 0:0:4
#
# 86
# RUN FOR SKG
# shape before: (653, 17)
# SIGNAL COUNTS:
# sell    282
# buy     218
# hold    153
# Name: signal, dtype: int64
# shape after: (653, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 86 TIME -> 0:0:4
#
# 87
# RUN FOR SPX
# shape before: (1049, 17)
# SIGNAL COUNTS:
# buy     423
# sell    353
# hold    273
# Name: signal, dtype: int64
# shape after: (1049, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 87 TIME -> 0:0:3
#
# 88
# RUN FOR SSE
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    494
# buy     306
# hold    250
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 88 TIME -> 0:0:4
#
# 89
# RUN FOR STAN
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    424
# hold    332
# buy     294
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 89 TIME -> 0:0:4
#
# 90
# RUN FOR SLA
# shape before: (688, 17)
# SIGNAL COUNTS:
# sell    266
# hold    229
# buy     193
# Name: signal, dtype: int64
# shape after: (688, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 90 TIME -> 0:0:5
#
# 91
# RUN FOR STJ
# shape before: (1055, 17)
# SIGNAL COUNTS:
# sell    417
# buy     356
# hold    282
# Name: signal, dtype: int64
# shape after: (1055, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 91 TIME -> 0:0:3
#
# 92
# RUN FOR TW
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    449
# buy     367
# hold    234
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 92 TIME -> 0:0:4
#
# 93
# RUN FOR TSCO
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    426
# buy     321
# hold    303
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 93 TIME -> 0:0:4
#
# 94
# RUN FOR TUI
# shape before: (248, 17)
# SIGNAL COUNTS:
# hold    94
# sell    86
# buy     68
# Name: signal, dtype: int64
# shape after: (248, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 94 TIME -> 0:0:4
#
# 95
# RUN FOR ULVR
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    381
# hold    341
# buy     328
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 95 TIME -> 0:0:3
#
# 96
# RUN FOR UU
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    408
# hold    361
# buy     281
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 96 TIME -> 0:0:4
#
# 97
# RUN FOR VOD
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    432
# hold    354
# buy     264
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 97 TIME -> 0:0:4
#
# 98
# RUN FOR WTB
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    399
# buy     362
# hold    289
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 98 TIME -> 0:0:4
#
# 99
# RUN FOR WPP
# shape before: (682, 17)
# SIGNAL COUNTS:
# sell    274
# buy     207
# hold    201
# Name: signal, dtype: int64
# shape after: (682, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 99 TIME -> 0:0:4
#
# 100
# RUN FOR 3IN
# shape before: (606, 17)
# SIGNAL COUNTS:
# sell    256
# hold    225
# buy     125
# Name: signal, dtype: int64
# shape after: (606, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 100 TIME -> 0:0:3
#
# 101
# RUN FOR FOUR
# shape before: (1041, 17)
# SIGNAL COUNTS:
# buy     398
# sell    383
# hold    260
# Name: signal, dtype: int64
# shape after: (1041, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 101 TIME -> 0:0:3
#
# 102
# RUN FOR ASL
# shape before: (605, 17)
# SIGNAL COUNTS:
# sell    231
# buy     220
# hold    154
# Name: signal, dtype: int64
# shape after: (605, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 102 TIME -> 0:0:4
#
# 103
# RUN FOR ACA
# shape before: (496, 17)
# SIGNAL COUNTS:
# sell    207
# hold    183
# buy     106
# Name: signal, dtype: int64
# shape after: (496, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 103 TIME -> 0:0:3
#
# 104
# RUN FOR AGK
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    409
# buy     365
# hold    276
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 104 TIME -> 0:0:3
#
# 105
# RUN FOR ATST
# shape before: (611, 17)
# SIGNAL COUNTS:
# hold    224
# sell    211
# buy     176
# Name: signal, dtype: int64
# shape after: (611, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 105 TIME -> 0:0:4
#
# 106
# RUN FOR AMGO
# shape before: (64, 17)
# SIGNAL COUNTS:
# hold    33
# sell    20
# buy     11
# Name: signal, dtype: int64
# shape after: (64, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 106 TIME -> 0:0:3
#
# 107
# RUN FOR APAX
# shape before: (217, 17)
# SIGNAL COUNTS:
# hold    86
# sell    77
# buy     54
# Name: signal, dtype: int64
# shape after: (217, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 107 TIME -> 0:0:3
#
# 108
# RUN FOR ASCL
# shape before: (188, 17)
# SIGNAL COUNTS:
# hold    74
# buy     63
# sell    51
# Name: signal, dtype: int64
# shape after: (188, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 108 TIME -> 0:0:3
#
# 109
# RUN FOR ASHM
# shape before: (675, 17)
# SIGNAL COUNTS:
# sell    269
# hold    206
# buy     200
# Name: signal, dtype: int64
# shape after: (675, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 109 TIME -> 0:0:3
#
# 110
# RUN FOR AGR
# shape before: (824, 17)
# SIGNAL COUNTS:
# sell    304
# hold    280
# buy     240
# Name: signal, dtype: int64
# shape after: (824, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 110 TIME -> 0:0:3
#
# 111
# RUN FOR AML
# shape before: (50, 17)
# SIGNAL COUNTS:
# sell    29
# hold    20
# buy      1
# Name: signal, dtype: int64
# shape after: (50, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 111 TIME -> 0:0:4
#
# 112
# RUN FOR AVST
# shape before: (71, 17)
# SIGNAL COUNTS:
# hold    39
# buy     22
# sell    10
# Name: signal, dtype: int64
# shape after: (71, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 112 TIME -> 0:0:3
#
# 113
# RUN FOR BAB
# shape before: (1031, 17)
# SIGNAL COUNTS:
# sell    406
# buy     325
# hold    300
# Name: signal, dtype: int64
# shape after: (1031, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 113 TIME -> 0:0:3
#
# 114
# RUN FOR BGFD
# shape before: (607, 17)
# SIGNAL COUNTS:
# buy     230
# sell    211
# hold    166
# Name: signal, dtype: int64
# shape after: (607, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 114 TIME -> 0:0:4
#
# 115
# RUN FOR BAKK
# shape before: (96, 17)
# SIGNAL COUNTS:
# hold    43
# sell    38
# buy     15
# Name: signal, dtype: int64
# shape after: (96, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 115 TIME -> 0:0:3
#
# 116
# RUN FOR BBY
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    475
# buy     322
# hold    253
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 116 TIME -> 0:0:3
#
# 117
# RUN FOR BNKR
# shape before: (612, 17)
# SIGNAL COUNTS:
# hold    332
# sell    193
# buy      87
# Name: signal, dtype: int64
# shape after: (612, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 117 TIME -> 0:0:4
#
# 118
# RUN FOR BAG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    389
# buy     375
# hold    286
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 118 TIME -> 0:0:3
#
# 119
# RUN FOR BBA
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    462
# buy     321
# hold    267
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 119 TIME -> 0:0:4
#
# 120
# RUN FOR BBGI
# shape before: (399, 17)
# SIGNAL COUNTS:
# hold    138
# sell    131
# buy     130
# Name: signal, dtype: int64
# shape after: (399, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 120 TIME -> 0:0:4
#
# 121
# RUN FOR BCA
# shape before: (244, 17)
# SIGNAL COUNTS:
# hold    115
# sell     77
# buy      52
# Name: signal, dtype: int64
# shape after: (244, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 121 TIME -> 0:0:3
#
# 122
# RUN FOR BGEO
# shape before: (615, 17)
# SIGNAL COUNTS:
# sell    257
# buy     233
# hold    125
# Name: signal, dtype: int64
# shape after: (615, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 122 TIME -> 0:0:3
#
# 123
# RUN FOR BEZ
# shape before: (879, 17)
# SIGNAL COUNTS:
# buy     309
# hold    297
# sell    273
# Name: signal, dtype: int64
# shape after: (879, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 123 TIME -> 0:0:4
#
# 124
# RUN FOR AJB
# shape before: (41, 17)
# SIGNAL COUNTS:
# buy     20
# hold    17
# sell     4
# Name: signal, dtype: int64
# shape after: (41, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 124 TIME -> 0:0:4
#
# 125
# RUN FOR BWY
# shape before: (1014, 17)
# SIGNAL COUNTS:
# buy     365
# sell    339
# hold    310
# Name: signal, dtype: int64
# shape after: (1014, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 125 TIME -> 0:0:3
#
# 126
# RUN FOR BYG
# shape before: (1010, 17)
# SIGNAL COUNTS:
# sell    385
# buy     366
# hold    259
# Name: signal, dtype: int64
# shape after: (1010, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 126 TIME -> 0:0:4
#
# 127
# RUN FOR BME
# shape before: (275, 17)
# SIGNAL COUNTS:
# hold    139
# sell     71
# buy      65
# Name: signal, dtype: int64
# shape after: (275, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 127 TIME -> 0:0:4
#
# 128
# RUN FOR BRSC
# shape before: (156, 17)
# SIGNAL COUNTS:
# buy     82
# sell    38
# hold    36
# Name: signal, dtype: int64
# shape after: (156, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 128 TIME -> 0:0:3
#
# 129
# RUN FOR BGSC
# shape before: (611, 17)
# SIGNAL COUNTS:
# hold    315
# sell    181
# buy     115
# Name: signal, dtype: int64
# shape after: (611, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 129 TIME -> 0:0:3
#
# 130
# RUN FOR BOY
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    422
# buy     321
# hold    307
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 130 TIME -> 0:0:4
#
# 131
# RUN FOR BVS
# shape before: (1044, 17)
# SIGNAL COUNTS:
# hold    379
# sell    353
# buy     312
# Name: signal, dtype: int64
# shape after: (1044, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 131 TIME -> 0:0:4
#
# 132
# RUN FOR BTEM
# shape before: (597, 17)
# SIGNAL COUNTS:
# sell    233
# hold    185
# buy     179
# Name: signal, dtype: int64
# shape after: (597, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 132 TIME -> 0:0:4
#
# 133
# RUN FOR BVIC
# shape before: (719, 17)
# SIGNAL COUNTS:
# sell    276
# buy     267
# hold    176
# Name: signal, dtype: int64
# shape after: (719, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 133 TIME -> 0:0:4
#
# 134
# RUN FOR CNE
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    423
# hold    326
# buy     301
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 134 TIME -> 0:0:4
#
# 135
# RUN FOR CLDN
# shape before: (609, 17)
# SIGNAL COUNTS:
# sell    226
# hold    194
# buy     189
# Name: signal, dtype: int64
# shape after: (609, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 135 TIME -> 0:0:4
#
# 136
# RUN FOR CAPC
# shape before: (488, 17)
# SIGNAL COUNTS:
# sell    200
# buy     183
# hold    105
# Name: signal, dtype: int64
# shape after: (488, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 136 TIME -> 0:0:4
#
# 137
# RUN FOR CPI
# shape before: (1061, 17)
# SIGNAL COUNTS:
# sell    445
# hold    324
# buy     292
# Name: signal, dtype: int64
# shape after: (1061, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 137 TIME -> 0:0:4
#
# 138
# RUN FOR CARD
# shape before: (279, 17)
# SIGNAL COUNTS:
# hold    136
# sell     85
# buy      58
# Name: signal, dtype: int64
# shape after: (279, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 138 TIME -> 0:0:4
#
# 139
# RUN FOR CEY
# shape before: (925, 17)
# SIGNAL COUNTS:
# hold    332
# sell    319
# buy     274
# Name: signal, dtype: int64
# shape after: (925, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 139 TIME -> 0:0:3
#
# 140
# RUN FOR CCFS
# shape before: (103, 17)
# SIGNAL COUNTS:
# hold    44
# sell    31
# buy     28
# Name: signal, dtype: int64
# shape after: (103, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 140 TIME -> 0:0:4
#
# 141
# RUN FOR CINE
# shape before: (647, 17)
# SIGNAL COUNTS:
# sell    243
# buy     239
# hold    165
# Name: signal, dtype: int64
# shape after: (647, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 141 TIME -> 0:0:3
#
# 142
# RUN FOR CTY
# shape before: (612, 17)
# SIGNAL COUNTS:
# hold    380
# sell    186
# buy      46
# Name: signal, dtype: int64
# shape after: (612, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 142 TIME -> 0:0:4
#
# 143
# RUN FOR CKN
# shape before: (1032, 17)
# SIGNAL COUNTS:
# buy     431
# sell    389
# hold    212
# Name: signal, dtype: int64
# shape after: (1032, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 143 TIME -> 0:0:4
#
# 144
# RUN FOR CBG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    424
# buy     322
# hold    304
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 144 TIME -> 0:0:4
#
# 145
# RUN FOR CLI
# shape before: (1049, 17)
# SIGNAL COUNTS:
# buy     415
# sell    374
# hold    260
# Name: signal, dtype: int64
# shape after: (1049, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 145 TIME -> 0:0:4
#
# 146
# RUN FOR COA
# shape before: (953, 17)
# SIGNAL COUNTS:
# sell    362
# buy     297
# hold    294
# Name: signal, dtype: int64
# shape after: (953, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 146 TIME -> 0:0:4
#
# 147
# RUN FOR COB
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    431
# buy     320
# hold    299
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 147 TIME -> 0:0:4
#
# 148
# RUN FOR CCC
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    432
# buy     353
# hold    265
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 148 TIME -> 0:0:5
#
# 149
# RUN FOR GLO
# shape before: (97, 17)
# SIGNAL COUNTS:
# hold    41
# sell    38
# buy     18
# Name: signal, dtype: int64
# shape after: (97, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 149 TIME -> 0:0:4
#
# 150
# RUN FOR CTEC
# shape before: (151, 17)
# SIGNAL COUNTS:
# hold    57
# sell    49
# buy     45
# Name: signal, dtype: int64
# shape after: (151, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 150 TIME -> 0:0:3
#
# 151
# RUN FOR CSP
# shape before: (407, 17)
# SIGNAL COUNTS:
# hold    158
# sell    136
# buy     113
# Name: signal, dtype: int64
# shape after: (407, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 151 TIME -> 0:0:3
#
# 152
# RUN FOR CWK
# shape before: (1050, 17)
# SIGNAL COUNTS:
# buy     371
# sell    360
# hold    319
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 152 TIME -> 0:0:4
#
# 153
# RUN FOR CRST
# shape before: (344, 17)
# SIGNAL COUNTS:
# hold    166
# sell    100
# buy      78
# Name: signal, dtype: int64
# shape after: (344, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 153 TIME -> 0:0:4
#
# 154
# RUN FOR CYBG
# shape before: (189, 17)
# SIGNAL COUNTS:
# buy     73
# sell    70
# hold    46
# Name: signal, dtype: int64
# shape after: (189, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 154 TIME -> 0:0:3
#
# 155
# RUN FOR DJAN
# shape before: (1048, 17)
# SIGNAL COUNTS:
# sell    412
# buy     329
# hold    307
# Name: signal, dtype: int64
# shape after: (1048, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 155 TIME -> 0:0:3
#
# 156
# RUN FOR DPH
# shape before: (970, 17)
# SIGNAL COUNTS:
# buy     368
# sell    350
# hold    252
# Name: signal, dtype: int64
# shape after: (970, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 156 TIME -> 0:0:4
#
# 157
# RUN FOR DLN
# shape before: (1049, 17)
# SIGNAL COUNTS:
# buy     396
# sell    378
# hold    275
# Name: signal, dtype: int64
# shape after: (1049, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 157 TIME -> 0:0:4
#
# 158
# RUN FOR DPLM
# shape before: (1050, 17)
# SIGNAL COUNTS:
# buy     390
# sell    343
# hold    317
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 158 TIME -> 0:0:4
#
# 159
# RUN FOR DC
# shape before: (520, 17)
# SIGNAL COUNTS:
# sell    210
# hold    171
# buy     139
# Name: signal, dtype: int64
# shape after: (520, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 159 TIME -> 0:0:4
#
# 160
# RUN FOR DOM
# shape before: (1034, 17)
# SIGNAL COUNTS:
# buy     438
# sell    376
# hold    220
# Name: signal, dtype: int64
# shape after: (1034, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 160 TIME -> 0:0:4
#
# 161
# RUN FOR DRX
# shape before: (718, 17)
# SIGNAL COUNTS:
# sell    299
# hold    224
# buy     195
# Name: signal, dtype: int64
# shape after: (718, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 161 TIME -> 0:0:4
#
# 162
# RUN FOR DNLM
# shape before: (674, 17)
# SIGNAL COUNTS:
# sell    293
# buy     197
# hold    184
# Name: signal, dtype: int64
# shape after: (674, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 162 TIME -> 0:0:4
#
# 163
# RUN FOR EZJ
# shape before: (983, 17)
# SIGNAL COUNTS:
# sell    360
# buy     356
# hold    267
# Name: signal, dtype: int64
# shape after: (983, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 163 TIME -> 0:0:4
#
# 164
# RUN FOR EDIN
# shape before: (605, 17)
# SIGNAL COUNTS:
# sell    237
# hold    223
# buy     145
# Name: signal, dtype: int64
# ...
# LAP 293 TIME -> 0:0:3
#
# 294
# RUN FOR SAFE
# shape before: (654, 17)
# SIGNAL COUNTS:
# sell    264
# buy     219
# hold    171
# Name: signal, dtype: int64
# shape after: (654, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 294 TIME -> 0:0:3
#
# 295
# RUN FOR SNN
# shape before: (233, 17)
# SIGNAL COUNTS:
# buy     83
# hold    83
# sell    67
# Name: signal, dtype: int64
# shape after: (233, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 295 TIME -> 0:0:3
#
# 296
# RUN FOR SVS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    393
# buy     364
# hold    293
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 296 TIME -> 0:0:3
#
# 297
# RUN FOR SDP
# shape before: (606, 17)
# SIGNAL COUNTS:
# sell    232
# buy     218
# hold    156
# Name: signal, dtype: int64
# shape after: (606, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 297 TIME -> 0:0:4
#
# 298
# RUN FOR SCIN
# shape before: (607, 17)
# SIGNAL COUNTS:
# hold    225
# sell    225
# buy     157
# Name: signal, dtype: int64
# shape after: (607, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 298 TIME -> 0:0:3
#
# 299
# RUN FOR SNR
# shape before: (1030, 17)
# SIGNAL COUNTS:
# sell    399
# buy     351
# hold    280
# Name: signal, dtype: int64
# shape after: (1030, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 299 TIME -> 0:0:3
#
# 300
# RUN FOR SEQI
# shape before: (231, 17)
# SIGNAL COUNTS:
# hold    120
# sell     61
# buy      50
# Name: signal, dtype: int64
# shape after: (231, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 300 TIME -> 0:0:4
#
# 301
# RUN FOR SRP
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    401
# hold    340
# buy     309
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 301 TIME -> 0:0:3
#
# 302
# RUN FOR SHB
# shape before: (1033, 17)
# SIGNAL COUNTS:
# hold    385
# sell    351
# buy     297
# Name: signal, dtype: int64
# shape after: (1033, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 302 TIME -> 0:0:4
#
# 303
# RUN FOR SHI
# shape before: (1044, 17)
# SIGNAL COUNTS:
# sell    382
# buy     347
# hold    315
# Name: signal, dtype: int64
# shape after: (1044, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 303 TIME -> 0:0:4
#
# 304
# RUN FOR SXX
# shape before: (675, 17)
# SIGNAL COUNTS:
# sell    280
# hold    229
# buy     166
# Name: signal, dtype: int64
# shape after: (675, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 304 TIME -> 0:0:4
#
# 305
# RUN FOR SSON
# shape before: (42, 17)
# SIGNAL COUNTS:
# hold    24
# buy     13
# sell     5
# Name: signal, dtype: int64
# shape after: (42, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 305 TIME -> 0:0:4
#
# 306
# RUN FOR SCT
# shape before: (201, 17)
# SIGNAL COUNTS:
# buy     86
# hold    69
# sell    46
# Name: signal, dtype: int64
# shape after: (201, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 306 TIME -> 0:0:3
#
# 307
# RUN FOR SOPH
# shape before: (221, 17)
# SIGNAL COUNTS:
# hold    115
# sell     54
# buy      52
# Name: signal, dtype: int64
# shape after: (221, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 307 TIME -> 0:0:3
#
# 308
# RUN FOR SXS
# shape before: (1048, 17)
# SIGNAL COUNTS:
# sell    372
# buy     361
# hold    315
# Name: signal, dtype: int64
# shape after: (1048, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 308 TIME -> 0:0:3
#
# 309
# RUN FOR SPT
# shape before: (1049, 17)
# SIGNAL COUNTS:
# sell    430
# buy     352
# hold    267
# Name: signal, dtype: int64
# shape after: (1049, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 309 TIME -> 0:0:4
#
# 310
# RUN FOR SPD
# shape before: (655, 17)
# SIGNAL COUNTS:
# sell    278
# buy     222
# hold    155
# Name: signal, dtype: int64
# shape after: (655, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 310 TIME -> 0:0:4
#
# 311
# RUN FOR SSPG
# shape before: (271, 17)
# SIGNAL COUNTS:
# buy     112
# hold     85
# sell     74
# Name: signal, dtype: int64
# shape after: (271, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 311 TIME -> 0:0:4
#
# 312
# RUN FOR SMP
# shape before: (1043, 17)
# SIGNAL COUNTS:
# sell    415
# buy     376
# hold    252
# Name: signal, dtype: int64
# shape after: (1043, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 312 TIME -> 0:0:3
#
# 313
# RUN FOR SGC
# shape before: (984, 17)
# SIGNAL COUNTS:
# sell    408
# buy     326
# hold    250
# Name: signal, dtype: int64
# shape after: (984, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 313 TIME -> 0:0:4
#
# 314
# RUN FOR SYNC
# shape before: (354, 17)
# SIGNAL COUNTS:
# hold    143
# buy     113
# sell     98
# Name: signal, dtype: int64
# shape after: (354, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 314 TIME -> 0:0:4
#
# 315
# RUN FOR SYNT
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    451
# buy     323
# hold    276
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 315 TIME -> 0:0:3
#
# 316
# RUN FOR TALK
# shape before: (495, 17)
# SIGNAL COUNTS:
# hold    181
# sell    167
# buy     147
# Name: signal, dtype: int64
# shape after: (495, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 316 TIME -> 0:0:4
#
# 317
# RUN FOR TATE
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    384
# buy     336
# hold    330
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 317 TIME -> 0:0:3
#
# 318
# RUN FOR TBCG
# shape before: (162, 17)
# SIGNAL COUNTS:
# hold    78
# sell    49
# buy     35
# Name: signal, dtype: int64
# shape after: (162, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 318 TIME -> 0:0:4
#
# 319
# RUN FOR TED
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    442
# buy     389
# hold    219
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 319 TIME -> 0:0:3
#
# 320
# RUN FOR TEP
# shape before: (999, 17)
# SIGNAL COUNTS:
# sell    362
# buy     355
# hold    282
# Name: signal, dtype: int64
# shape after: (999, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 320 TIME -> 0:0:4
#
# 321
# RUN FOR TMPL
# shape before: (606, 17)
# SIGNAL COUNTS:
# sell    233
# hold    227
# buy     146
# Name: signal, dtype: int64
# shape after: (606, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 321 TIME -> 0:0:4
#
# 322
# RUN FOR TEM
# shape before: (607, 17)
# SIGNAL COUNTS:
# sell    249
# buy     205
# hold    153
# Name: signal, dtype: int64
# shape after: (607, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 322 TIME -> 0:0:4
#
# 323
# RUN FOR TIFS
# shape before: (99, 17)
# SIGNAL COUNTS:
# hold    57
# sell    29
# buy     13
# Name: signal, dtype: int64
# shape after: (99, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 323 TIME -> 0:0:4
#
# 324
# RUN FOR TCAP
# shape before: (976, 17)
# SIGNAL COUNTS:
# sell    373
# hold    307
# buy     296
# Name: signal, dtype: int64
# shape after: (976, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 324 TIME -> 0:0:3
#
# 325
# RUN FOR TRY
# shape before: (605, 17)
# SIGNAL COUNTS:
# buy     211
# sell    206
# hold    188
# Name: signal, dtype: int64
# shape after: (605, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 325 TIME -> 0:0:4
#
# 326
# RUN FOR TPK
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    462
# buy     353
# hold    235
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 326 TIME -> 0:0:4
#
# 327
# RUN FOR BBOX
# shape before: (296, 17)
# SIGNAL COUNTS:
# hold    109
# buy      98
# sell     89
# Name: signal, dtype: int64
# shape after: (296, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 327 TIME -> 0:0:4
#
# 328
# RUN FOR TLW
# shape before: (1042, 17)
# SIGNAL COUNTS:
# sell    393
# hold    342
# buy     307
# Name: signal, dtype: int64
# shape after: (1042, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 328 TIME -> 0:0:3
#
# 329
# RUN FOR UDG
# shape before: (1029, 17)
# SIGNAL COUNTS:
# buy     383
# sell    382
# hold    264
# Name: signal, dtype: int64
# shape after: (1029, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 329 TIME -> 0:0:4
#
# 330
# RUN FOR UKCM
# shape before: (606, 17)
# SIGNAL COUNTS:
# sell    260
# hold    175
# buy     171
# Name: signal, dtype: int64
# shape after: (606, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 330 TIME -> 0:0:4
#
# 331
# RUN FOR ULE
# shape before: (1046, 17)
# SIGNAL COUNTS:
# sell    368
# buy     353
# hold    325
# Name: signal, dtype: int64
# shape after: (1046, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 331 TIME -> 0:0:4
#
# 332
# RUN FOR UTG
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    394
# buy     369
# hold    287
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 332 TIME -> 0:0:4
#
# 333
# RUN FOR VSVS
# shape before: (1050, 17)
# SIGNAL COUNTS:
# sell    452
# buy     326
# hold    272
# Name: signal, dtype: int64
# shape after: (1050, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 333 TIME -> 0:0:4
#
# 334
# RUN FOR VCT
# shape before: (1015, 17)
# SIGNAL COUNTS:
# buy     389
# sell    375
# hold    251
# Name: signal, dtype: int64
# shape after: (1015, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 334 TIME -> 0:0:4
#
# 335
# RUN FOR VEIL
# shape before: (162, 17)
# SIGNAL COUNTS:
# buy     60
# sell    53
# hold    49
# Name: signal, dtype: int64
# shape after: (162, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 335 TIME -> 0:0:4
#
# 336
# RUN FOR VOF
# shape before: (611, 17)
# SIGNAL COUNTS:
# sell    239
# hold    197
# buy     175
# Name: signal, dtype: int64
# shape after: (611, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 336 TIME -> 0:0:3
#
# 337
# RUN FOR VVO
# shape before: (72, 17)
# SIGNAL COUNTS:
# hold    41
# sell    23
# buy      8
# Name: signal, dtype: int64
# shape after: (72, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 337 TIME -> 0:0:4
#
# 338
# RUN FOR WEIR
# shape before: (1048, 17)
# SIGNAL COUNTS:
# buy     376
# sell    355
# hold    317
# Name: signal, dtype: int64
# shape after: (1048, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 338 TIME -> 0:0:3
#
# 339
# RUN FOR JDW
# shape before: (1046, 17)
# SIGNAL COUNTS:
# sell    411
# buy     344
# hold    291
# Name: signal, dtype: int64
# shape after: (1046, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 339 TIME -> 0:0:4
#
# 340
# RUN FOR SMWH
# shape before: (684, 17)
# SIGNAL COUNTS:
# sell    240
# buy     227
# hold    217
# Name: signal, dtype: int64
# shape after: (684, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 340 TIME -> 0:0:4
#
# 341
# RUN FOR WMH
# shape before: (900, 17)
# SIGNAL COUNTS:
# sell    380
# buy     282
# hold    238
# Name: signal, dtype: int64
# shape after: (900, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 341 TIME -> 0:0:4
#
# 342
# RUN FOR WTAN
# shape before: (612, 17)
# SIGNAL COUNTS:
# hold    329
# sell    195
# buy      88
# Name: signal, dtype: int64
# shape after: (612, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 342 TIME -> 0:0:4
#
# 343
# RUN FOR WIZZ
# shape before: (238, 17)
# SIGNAL COUNTS:
# hold    101
# buy      78
# sell     59
# Name: signal, dtype: int64
# shape after: (238, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 343 TIME -> 0:0:4
#
# 344
# RUN FOR WPCT
# shape before: (224, 17)
# SIGNAL COUNTS:
# sell    118
# buy      54
# hold     52
# Name: signal, dtype: int64
# shape after: (224, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 344 TIME -> 0:0:3
#
# 345
# RUN FOR WG
# shape before: (903, 17)
# SIGNAL COUNTS:
# sell    334
# buy     288
# hold    281
# Name: signal, dtype: int64
# shape after: (903, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 345 TIME -> 0:0:3
#
# 346
# RUN FOR WKP
# shape before: (914, 17)
# SIGNAL COUNTS:
# buy     386
# sell    318
# hold    210
# Name: signal, dtype: int64
# shape after: (914, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 346 TIME -> 0:0:4
#
# 347
# RUN FOR WWH
# shape before: (612, 17)
# SIGNAL COUNTS:
# hold    260
# sell    183
# buy     169
# Name: signal, dtype: int64
# shape after: (612, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
#
#
#
# TOTAL ELAPSED TIME -> 0:21:59
#
# ERROR COUNT: 0

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
tmp_df = pd.read_hdf(hf_store_name,key='weekly_data',mode='r')
print("")
print("FINAL HDFSTORE SIZE: {}".format(tmp_df.shape))
print("FINAL BUY COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "buy"])))
print("FINAL SELL COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "sell"])))
h_store.close()
tmp_df.head(50)
# tmp_df[(tmp_df["ticker"] == 'ADM') & (tmp_df["date"] > '2013-12-01') & (tmp_df["date"] < '2014-02-01')].head(200)
# Out:
# FINAL HDFSTORE SIZE: (258339, 140)
# FINAL BUY COUNT: 82965
# FINAL SELL COUNT: 98781
#        ticker       date      open     close      high       low    volume  \
# 119990    III 2007-12-31  0.837127  0.838986  0.855672  0.853120  0.053557
# 119991    III 2008-01-07  0.809307  0.802912  0.821356  0.811475  0.236390
# 119992    III 2008-01-14  0.758220  0.782676  0.767864  0.778785  0.325624
# 119993    III 2008-01-21  0.731917  0.797193  0.797134  0.748334  0.264801
# 119994    III 2008-01-28  0.752150  0.835467  0.803189  0.798488  0.173403
# 119995    III 2008-02-04  0.811836  0.802472  0.819843  0.809236  0.226728
# 119996    III 2008-02-11  0.751138  0.798953  0.778462  0.801175  0.175053
# 119997    III 2008-02-18  0.762266  0.766838  0.792087  0.777889  0.183115
# 119998    III 2008-02-25  0.732423  0.709648  0.738595  0.712062  0.308995
# 119999    III 2008-03-03  0.654527  0.674013  0.659366  0.685194  0.277779
# 120000    III 2008-03-10  0.617602  0.664335  0.645236  0.668625  0.231613
# 120001    III 2008-03-17  0.589782  0.678413  0.617481  0.638622  0.233201
# 120002    III 2008-03-24  0.639858  0.727685  0.676019  0.706241  0.166053
# 120003    III 2008-03-31  0.674760  0.765958  0.725979  0.718779  0.222707
# 120004    III 2008-04-07  0.728882  0.740443  0.729007  0.748334  0.131700
# 120005    III 2008-04-14  0.686394  0.771677  0.727493  0.741169  0.111286
# 120006    III 2008-04-21  0.732929  0.761559  0.724970  0.741169  0.125777
# 120007    III 2008-04-28  0.721801  0.750121  0.714372  0.751021  0.110836
# 120008    III 2008-05-05  0.705615  0.766398  0.739604  0.746991  0.102335
# 120009    III 2008-05-12  0.726859  0.798953  0.764332  0.752364  0.270771
# 120010    III 2008-05-19  0.766818  0.745722  0.760799  0.759081  0.208437
# 120011    III 2008-05-26  0.706120  0.769038  0.736577  0.759081  0.113876
# 120012    III 2008-06-02  0.726353  0.747921  0.725474  0.760425  0.180564
# 120013    III 2008-06-09  0.699039  0.718446  0.696205  0.709823  0.188143
# 120014    III 2008-06-16  0.666161  0.718886  0.682075  0.717883  0.207494
# 120015    III 2008-06-23  0.660597  0.710967  0.680561  0.715197  0.194215
# 120016    III 2008-06-30  0.654527  0.696890  0.663403  0.701763  0.178857
# 120017    III 2008-07-07  0.648457  0.680612  0.659871  0.685642  0.201348
# 120018    III 2008-07-14  0.640364  0.798073  0.751716  0.701763  0.236515
# 120019    III 2008-07-21  0.756196  0.769918  0.786536  0.762664  0.228742
# 120020    III 2008-07-28  0.727365  0.787515  0.751211  0.755499  0.124473
# 120021    III 2008-08-04  0.752150  0.830628  0.792087  0.794010  0.128053
# 120022    III 2008-08-11  0.803237  0.789714  0.798143  0.794010  0.096784
# 120023    III 2008-08-18  0.750126  0.772117  0.741623  0.752812  0.085874
# 120024    III 2008-08-25  0.713202  0.798953  0.752725  0.762664  0.094446
# 120025    III 2008-09-01  0.755185  0.772557  0.776948  0.784606  0.156211
# 120026    III 2008-09-08  0.764795  0.783555  0.778462  0.776546  0.144205
# 120027    III 2008-09-15  0.715731  0.735163  0.711344  0.661460  0.361832
# 120028    III 2008-09-22  0.712696  0.684132  0.706298  0.691463  0.196153
# 120029    III 2008-09-29  0.626201  0.624302  0.620004  0.585781  0.256193
# 120030    III 2008-10-06  0.560951  0.430293  0.553896  0.438006  0.332792
# 120031    III 2008-10-13  0.362165  0.391140  0.436314  0.382254  0.355365
# 120032    III 2008-10-20  0.312089  0.425234  0.362132  0.381807  0.324362
# 120033    III 2008-10-27  0.301973  0.465048  0.376766  0.389419  0.184389
# 120034    III 2008-11-03  0.394031  0.412256  0.441865  0.410690  0.208310
# 120035    III 2008-11-10  0.327516  0.363864  0.331348  0.356730  0.184100
# 120036    III 2008-11-17  0.247597  0.308873  0.253129  0.303665  0.175638
# 120037    III 2008-11-24  0.210420  0.352206  0.281893  0.325383  0.168235
# 120038    III 2008-12-01  0.250126  0.289517  0.241774  0.283514  0.160816
# 120039    III 2008-12-08  0.203844  0.263121  0.197618  0.263362  0.253299
#
#         change_price  per_change_price  close_shift1  ...  \
# 119990        -30.00         -0.030151           NaN  ...
# 119991        -43.50         -0.044961      0.838986  ...
# 119992        -16.00         -0.017448      0.802912  ...
# 119993         26.50          0.029742      0.782676  ...
# 119994         50.00          0.054885      0.797193  ...
# 119995        -46.50         -0.047938      0.835467  ...
# 119996          9.50          0.010440      0.802472  ...
# 119997        -38.00         -0.041260      0.798953  ...
# 119998        -73.50         -0.082445      0.766838  ...
# 119999        -37.00         -0.045427      0.709648  ...
# 120000        -11.50         -0.014781      0.674013  ...
# 120001         32.00          0.042638      0.664335  ...
# 120002         38.50          0.048125      0.678413  ...
# 120003         47.50          0.056920      0.727685  ...
# 120004        -35.00         -0.039414      0.765958  ...
# 120005         42.50          0.050236      0.740443  ...
# 120006        -15.00         -0.016816      0.771677  ...
# 120007        -17.00         -0.019296      0.761559  ...
# 120008         17.50          0.020231      0.750121  ...
# 120009         33.50          0.037810      0.766398  ...
# 120010        -66.50         -0.071853      0.798953  ...
# 120011         20.00          0.023108      0.745722  ...
# 120012        -24.00         -0.027103      0.769038  ...
# 120013        -30.50         -0.035527      0.747921  ...
# 120014          2.50          0.003027      0.718446  ...
# 120015         -1.00         -0.001219      0.718886  ...
# 120016        -11.00         -0.013505      0.710967  ...
# 120017        -23.50         -0.029066      0.696890  ...
# 120018        118.00          0.147408      0.680612  ...
# 120019        -28.50         -0.031148      0.798073  ...
# 120020         20.00          0.022561      0.769918  ...
# 120021         44.50          0.048847      0.787515  ...
# 120022        -52.50         -0.054602      0.830628  ...
# 120023        -20.00         -0.022002      0.789714  ...
# 120024         47.00          0.053868      0.772117  ...
# 120025        -24.50         -0.026805      0.798953  ...
# 120026        -21.50         -0.023281      0.772557  ...
# 120027        -28.00         -0.032000      0.783555  ...
# 120028        -83.00         -0.095183      0.735163  ...
# 120029        -65.50         -0.083280      0.684132  ...
# 120030       -221.50         -0.306787      0.624302  ...
# 120031        -69.50         -0.132255      0.430293  ...
# 120032         18.75          0.039391      0.391140  ...
# 120033         74.00          0.158798      0.425234  ...
# 120034        -77.00         -0.138241      0.465048  ...
# 120035        -66.25         -0.134860      0.412256  ...
# 120036        -49.75         -0.120679      0.363864  ...
# 120037         36.25          0.096538      0.308873  ...
# 120038        -74.25         -0.179024      0.352206  ...
# 120039        -58.50         -0.158537      0.289517  ...
#
#         min_move_cum_neg_macd_line  long_prev_max_move_pos_date_macd_line  \
# 119990                           1                                    NaN
# 119991                           2                                    NaN
# 119992                           3                                    NaN
# 119993                           4                                    NaN
# 119994                           5                                    NaN
# 119995                           6                                    NaN
# 119996                           7                                    NaN
# 119997                           8                                    NaN
# 119998                           9                                    NaN
# 119999                          10                                    NaN
# 120000                          11                                    NaN
# 120001                          12                                    NaN
# 120002                          13                                    NaN
# 120003                          14                                    NaN
# 120004                          15                                    NaN
# 120005                          16                                    NaN
# 120006                          17                                    NaN
# 120007                          18                                    NaN
# 120008                          19                                    NaN
# 120009                          20                                    NaN
# 120010                          21                                    NaN
# 120011                          22                                    NaN
# 120012                          23                                    NaN
# 120013                          24                                    NaN
# 120014                          25                                    NaN
# 120015                          26                                    NaN
# 120016                          27                                    NaN
# 120017                          28                                    NaN
# 120018                           0                                    NaN
# 120019                           0                                    NaN
# 120020                           1                                    0.0
# 120021                           0                                    0.0
# 120022                           0                                    1.0
# 120023                           1                                    0.0
# 120024                           0                                    0.0
# 120025                           0                                    1.0
# 120026                           1                                    0.0
# 120027                           0                                    0.0
# 120028                           1                                    0.0
# 120029                           2                                    0.0
# 120030                           3                                    0.0
# 120031                           4                                    0.0
# 120032                           5                                    0.0
# 120033                           6                                    0.0
# 120034                           7                                    0.0
# 120035                           8                                    0.0
# 120036                           9                                    0.0
# 120037                          10                                    0.0
# 120038                          11                                    0.0
# 120039                          12                                    0.0
#
#         long_prev_max_move_neg_date_macd_line  \
# 119990                                    NaN
# 119991                                    NaN
# 119992                                    NaN
# 119993                                    NaN
# 119994                                    NaN
# 119995                                    NaN
# 119996                                    NaN
# 119997                                    NaN
# 119998                                    NaN
# 119999                                    NaN
# 120000                                    NaN
# 120001                                    NaN
# 120002                                    NaN
# 120003                                    NaN
# 120004                                    NaN
# 120005                                    NaN
# 120006                                    NaN
# 120007                                    NaN
# 120008                                    NaN
# 120009                                    NaN
# 120010                                    NaN
# 120011                                    NaN
# 120012                                    NaN
# 120013                                    NaN
# 120014                                    NaN
# 120015                                    NaN
# 120016                                    NaN
# 120017                                    NaN
# 120018                                    0.0
# 120019                                    0.0
# 120020                                    0.0
# 120021                                    0.0
# 120022                                    0.0
# 120023                                    0.0
# 120024                                    0.0
# 120025                                    0.0
# 120026                                    0.0
# 120027                                    0.0
# 120028                                    0.0
# 120029                                    1.0
# 120030                                    2.0
# 120031                                    3.0
# 120032                                    4.0
# 120033                                    5.0
# 120034                                    6.0
# 120035                                    7.0
# 120036                                    8.0
# 120037                                    9.0
# 120038                                   10.0
# 120039                                   11.0
#
#         long_prev_min_move_pos_date_macd_line  \
# 119990                                    NaN
# 119991                                    NaN
# 119992                                    NaN
# 119993                                    NaN
# 119994                                    NaN
# 119995                                    NaN
# 119996                                    NaN
# 119997                                    NaN
# 119998                                    NaN
# 119999                                    NaN
# 120000                                    NaN
# 120001                                    NaN
# 120002                                    NaN
# 120003                                    NaN
# 120004                                    NaN
# 120005                                    NaN
# 120006                                    NaN
# 120007                                    NaN
# 120008                                    NaN
# 120009                                    NaN
# 120010                                    NaN
# 120011                                    NaN
# 120012                                    NaN
# 120013                                    NaN
# 120014                                    NaN
# 120015                                    NaN
# 120016                                    NaN
# 120017                                    NaN
# 120018                                    NaN
# 120019                                    NaN
# 120020                                    0.0
# 120021                                    0.0
# 120022                                    1.0
# 120023                                    0.0
# 120024                                    0.0
# 120025                                    1.0
# 120026                                    0.0
# 120027                                    0.0
# 120028                                    0.0
# 120029                                    0.0
# 120030                                    0.0
# 120031                                    0.0
# 120032                                    0.0
# 120033                                    0.0
# 120034                                    0.0
# 120035                                    0.0
# 120036                                    0.0
# 120037                                    0.0
# 120038                                    0.0
# 120039                                    0.0
#
#         long_prev_min_move_neg_date_macd_line  long_max_grad_pos_macd_line  \
# 119990                                    NaN                     0.000000
# 119991                                    NaN                     0.000000
# 119992                                    NaN                     0.000000
# 119993                                    NaN                     0.000000
# 119994                                    NaN                     0.000000
# 119995                                    NaN                     0.000000
# 119996                                    NaN                     0.000000
# 119997                                    NaN                     0.000000
# 119998                                    NaN                     0.000000
# 119999                                    NaN                     0.000000
# 120000                                    NaN                     0.000000
# 120001                                    NaN                     0.000000
# 120002                                    NaN                     0.000000
# 120003                                    NaN                     0.000000
# 120004                                    NaN                     0.000000
# 120005                                    NaN                     0.000000
# 120006                                    NaN                     0.000000
# 120007                                    NaN                     0.000000
# 120008                                    NaN                     0.000000
# 120009                                    NaN                     0.000000
# 120010                                    NaN                     0.000000
# 120011                                    NaN                     0.000000
# 120012                                    NaN                     0.000000
# 120013                                    NaN                     0.000000
# 120014                                    NaN                     0.000000
# 120015                                    NaN                     0.000000
# 120016                                    NaN                     0.000000
# 120017                                    NaN                     0.000000
# 120018                                    0.0                     0.000000
# 120019                                    0.0                     0.000000
# 120020                                    0.0                     0.000000
# 120021                                    0.0                     0.000000
# 120022                                    0.0                     0.006636
# 120023                                    0.0                     0.000000
# 120024                                    0.0                     0.000000
# 120025                                    0.0                     0.002170
# 120026                                    0.0                     0.000000
# 120027                                    0.0                     0.000000
# 120028                                    0.0                     0.000000
# 120029                                    1.0                     0.000000
# 120030                                    2.0                     0.000000
# 120031                                    3.0                     0.000000
# 120032                                    4.0                     0.000000
# 120033                                    5.0                     0.000000
# 120034                                    6.0                     0.000000
# 120035                                    7.0                     0.000000
# 120036                                    8.0                     0.000000
# 120037                                    9.0                     0.000000
# 120038                                   10.0                     0.000000
# 120039                                   11.0                     0.000000
#
#         long_max_grad_neg_macd_line  long_min_grad_pos_macd_line  \
# 119990                     0.000000                     0.000000
# 119991                     0.000000                     0.000000
# 119992                     0.000000                     0.000000
# 119993                     0.000000                     0.000000
# 119994                     0.000000                     0.000000
# 119995                     0.000000                     0.000000
# 119996                     0.000000                     0.000000
# 119997                     0.000000                     0.000000
# 119998                     0.000000                     0.000000
# 119999                     0.000000                     0.000000
# 120000                     0.000000                     0.000000
# 120001                     0.000000                     0.000000
# 120002                     0.000000                     0.000000
# 120003                     0.000000                     0.000000
# 120004                     0.000000                     0.000000
# 120005                     0.000000                     0.000000
# 120006                     0.000000                     0.000000
# 120007                     0.000000                     0.000000
# 120008                     0.000000                     0.000000
# 120009                     0.000000                     0.000000
# 120010                     0.000000                     0.000000
# 120011                     0.000000                     0.000000
# 120012                     0.000000                     0.000000
# 120013                     0.000000                     0.000000
# 120014                     0.000000                     0.000000
# 120015                     0.000000                     0.000000
# 120016                     0.000000                     0.000000
# 120017                     0.000000                     0.000000
# 120018                     0.000000                     0.000000
# 120019                     0.000000                     0.000000
# 120020                     0.000000                     0.000000
# 120021                     0.000000                     0.000000
# 120022                     0.000000                     0.006636
# 120023                     0.000000                     0.000000
# 120024                     0.000000                     0.000000
# 120025                     0.000000                     0.002170
# 120026                     0.000000                     0.000000
# 120027                     0.000000                     0.000000
# 120028                     0.000000                     0.000000
# 120029                    -0.004386                     0.000000
# 120030                    -0.004254                     0.000000
# 120031                    -0.007636                     0.000000
# 120032                    -0.010230                     0.000000
# 120033                    -0.010272                     0.000000
# 120034                    -0.010292                     0.000000
# 120035                    -0.011655                     0.000000
# 120036                    -0.012431                     0.000000
# 120037                    -0.013014                     0.000000
# 120038                    -0.013267                     0.000000
# 120039                    -0.013861                     0.000000
#
#         long_min_grad_neg_macd_line  signal
# 119990                     0.000000    sell
# 119991                     0.000000    sell
# 119992                     0.000000    sell
# 119993                     0.000000    sell
# 119994                     0.000000    sell
# 119995                     0.000000    sell
# 119996                     0.000000    sell
# 119997                     0.000000    sell
# 119998                     0.000000    hold
# 119999                     0.000000     buy
# 120000                     0.000000     buy
# 120001                     0.000000     buy
# 120002                     0.000000    hold
# 120003                     0.000000    sell
# 120004                     0.000000    sell
# 120005                     0.000000    sell
# 120006                     0.000000    sell
# 120007                     0.000000    sell
# 120008                     0.000000    sell
# 120009                     0.000000    sell
# 120010                     0.000000    hold
# 120011                     0.000000    sell
# 120012                     0.000000    hold
# 120013                     0.000000    hold
# 120014                     0.000000    hold
# 120015                     0.000000     buy
# 120016                     0.000000     buy
# 120017                     0.000000    hold
# 120018                     0.000000    sell
# 120019                     0.000000    sell
# 120020                     0.000000    sell
# 120021                     0.000000    sell
# 120022                     0.000000    sell
# 120023                     0.000000    sell
# 120024                     0.000000    sell
# 120025                     0.000000    sell
# 120026                     0.000000    sell
# 120027                     0.000000    sell
# 120028                     0.000000    sell
# 120029                    -0.004386    sell
# 120030                    -0.004254    sell
# 120031                    -0.007636    hold
# 120032                    -0.010230    sell
# 120033                    -0.010272    sell
# 120034                    -0.010292    sell
# 120035                    -0.011655    sell
# 120036                    -0.012431    hold
# 120037                    -0.013014    sell
# 120038                    -0.013267    sell
# 120039                    -0.013861    hold
#
# [50 rows x 140 columns]

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(path+'all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(path+'all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(path+'all_hist_prices_w_ft_eng2_TMP.h5',path+'all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(path+'all_hist_prices_w_ft_eng2_TMP.h5',path+'all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5

# %%
#Remove 'date' from out_cols
out_cols.remove('date')

# %%
#Export a list of the features for this model
file_object = open(path+r'feature_engineering_feature_list.txt','w')
feature_str = ''
for i in out_cols:
    feature_str += '{},'.format(i)
feature_str = feature_str[:-1]
file_object.write(feature_str)
file_object.close()
feature_str
# Out:
# 'ticker,open,close,high,low,volume,change_price,per_change_price,close_shift1,change_close_shift1,vol_shift1,change_vol_shift1,ema26_shift1,change_ema26_shift1,close_13_norm,close_26_norm,close_52_norm,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,macd_pos_val,macd_neg_val,signal_line_pos_val,signal_line_neg_val,change_price_pos_val,change_price_neg_val,per_change_price_pos_val,per_change_price_neg_val,prev_max_close,prev_min_close,prev_max_close_date_change,prev_min_close_date_change,max_change_close_pos_val,max_change_close_neg_val,min_change_close_pos_val,min_change_close_neg_val,prev_max_grad_close,prev_min_grad_close,max_move_cum_pos_close,max_move_cum_neg_close,min_move_cum_pos_close,min_move_cum_neg_close,long_prev_max_move_pos_date_close,long_prev_max_move_neg_date_close,long_prev_min_move_pos_date_close,long_prev_min_move_neg_date_close,long_max_grad_pos_close,long_max_grad_neg_close,long_min_grad_pos_close,long_min_grad_neg_close,prev_max_macd,prev_min_macd,prev_max_macd_date_change,prev_min_macd_date_change,max_change_macd_pos_val,max_change_macd_neg_val,min_change_macd_pos_val,min_change_macd_neg_val,prev_max_grad_macd,prev_min_grad_macd,max_move_cum_pos_macd,max_move_cum_neg_macd,min_move_cum_pos_macd,min_move_cum_neg_macd,long_prev_max_move_pos_date_macd,long_prev_max_move_neg_date_macd,long_prev_min_move_pos_date_macd,long_prev_min_move_neg_date_macd,long_max_grad_pos_macd,long_max_grad_neg_macd,long_min_grad_pos_macd,long_min_grad_neg_macd,prev_max_ema26,prev_min_ema26,prev_max_ema26_date_change,prev_min_ema26_date_change,max_change_ema26_pos_val,max_change_ema26_neg_val,min_change_ema26_pos_val,min_change_ema26_neg_val,prev_max_grad_ema26,prev_min_grad_ema26,max_move_cum_pos_ema26,max_move_cum_neg_ema26,min_move_cum_pos_ema26,min_move_cum_neg_ema26,long_prev_max_move_pos_date_ema26,long_prev_max_move_neg_date_ema26,long_prev_min_move_pos_date_ema26,long_prev_min_move_neg_date_ema26,long_max_grad_pos_ema26,long_max_grad_neg_ema26,long_min_grad_pos_ema26,long_min_grad_neg_ema26,prev_max_signal_line,prev_min_signal_line,prev_max_signal_line_date_change,prev_min_signal_line_date_change,max_change_signal_line_pos_val,max_change_signal_line_neg_val,min_change_signal_line_pos_val,min_change_signal_line_neg_val,prev_max_grad_signal_line,prev_min_grad_signal_line,max_move_cum_pos_signal_line,max_move_cum_neg_signal_line,min_move_cum_pos_signal_line,min_move_cum_neg_signal_line,long_prev_max_move_pos_date_signal_line,long_prev_max_move_neg_date_signal_line,long_prev_min_move_pos_date_signal_line,long_prev_min_move_neg_date_signal_line,long_max_grad_pos_signal_line,long_max_grad_neg_signal_line,long_min_grad_pos_signal_line,long_min_grad_neg_signal_line,prev_max_macd_line,prev_min_macd_line,prev_max_macd_line_date_change,prev_min_macd_line_date_change,max_change_macd_line_pos_val,max_change_macd_line_neg_val,min_change_macd_line_pos_val,min_change_macd_line_neg_val,prev_max_grad_macd_line,prev_min_grad_macd_line,max_move_cum_pos_macd_line,max_move_cum_neg_macd_line,min_move_cum_pos_macd_line,min_move_cum_neg_macd_line,long_prev_max_move_pos_date_macd_line,long_prev_max_move_neg_date_macd_line,long_prev_min_move_pos_date_macd_line,long_prev_min_move_neg_date_macd_line,long_max_grad_pos_macd_line,long_max_grad_neg_macd_line,long_min_grad_pos_macd_line,long_min_grad_neg_macd_line,signal'
