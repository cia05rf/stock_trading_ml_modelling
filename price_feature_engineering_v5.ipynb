# %% [markdown]
# # Create indicators and find signals
# This code is designed to calculate the features for model training.
#
# We will also bring in if the target price was hit within 8 weeks for ML training and validation.
#
# Each share has it's own trading pattern so we will train a different model for each share but use the same set of features, just the hyper paramenters will be tuned differenty.
#
# V5 build - Normalise vs rolling max 5 year window

# %%
#Import libraries
import pandas as pd
import numpy as np
import re
import tables
import os
import datetime as dt
from rf_modules import *

# %%
#Import the ftse list
path = r"C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices"
tick_ftse = pd.read_csv(path + r"\tick_ftse.csv")
tick_ftse = tick_ftse.iloc[:,1:]
for col in tick_ftse:
    tick_ftse.rename(columns={col:clean_col_name(col)},inplace=True)
tick_ftse.head()
# Out:
#   ticker         company    index
# 0    III         3I GRP.  FTSE100
# 1    ABF        A.B.FOOD  FTSE100
# 2    ADM     ADMIRAL GRP  FTSE100
# 3    AAL  ANGLO AMERICAN  FTSE100
# 4   ANTO     ANTOFAGASTA  FTSE100

# %%
#Import and combine prices files
df_prices_w = pd.read_hdf(path + r"\all_hist_prices_w.h5")
#Rename columns
for col in df_prices_w:
    df_prices_w.rename(columns={col:clean_col_name(col)},inplace=True)
#Drop unwanted columns
try:
    df_prices_w.drop(columns=["unnamed_0","index"],inplace=True)
except Exception as e:
    print(e)
#Reformat columns where neccessary
df_prices_w["date"] = df_prices_w["date"].astype("datetime64")
print(df_prices_w.shape)
print(df_prices_w.dtypes)
df_prices_w.head()
# Out:
# "['unnamed_0' 'index'] not found in axis"
# (275683, 13)
# ticker                 object
# date           datetime64[ns]
# high                  float64
# low                   float64
# volume                float64
# open                  float64
# close                 float64
# change                float64
# ema12                 float64
# ema26                 float64
# macd_line             float64
# signal_line           float64
# macd                  float64
# dtype: object
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Remove tickers with fewer than 34 entries as this is where the MACD can be calculated
print('START ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('START TICK COUNT -> {}'.format(tick_ftse.shape[0]))
for tick in tick_ftse.ticker:
    print(tick,' ->',df_prices_w[df_prices_w.ticker == tick].shape[0])
    if df_prices_w[df_prices_w.ticker == tick].shape[0] < 34:
        #Remove from dataframe
        print('\nTOO FEW RECORDS FOR {}'.format(tick))
        df_prices_w = df_prices_w.loc[df_prices_w.ticker != tick]
        print('\tNEW ROW COUNT -> {}'.format(df_prices_w.shape[0]))
        #Remove from tick_ftse
        tick_ftse = tick_ftse.loc[tick_ftse.ticker != tick]
        print('\tNEW TICK COUNT -> {}'.format(tick_ftse.shape[0]))
print('\nEND ROW COUNT -> {}'.format(df_prices_w.shape[0]))
print('END TICK COUNT -> {}'.format(tick_ftse.shape[0]))
# Out:
# START ROW COUNT -> 275683
# START TICK COUNT -> 351
# III  -> 613
# ABF  -> 1045
# ADM  -> 353
# AAL  -> 1008
# ANTO  -> 1045
# AHT  -> 1023
# AZN  -> 1045
# AUTO  -> 238
# AVV  -> 1045
# AV.  -> 1292
# BA.  -> 1534
# BARC  -> 1045
# BDEV  -> 1045
# BKG  -> 1045
# BHP  -> 524
# BP.  -> 1565
# BATS  -> 1045
# BLND  -> 1045
# BT.A  -> 0
#
# TOO FEW RECORDS FOR BT.A
# 	NEW ROW COUNT -> 275683
# 	NEW TICK COUNT -> 350
# BNZL  -> 1042
# BRBY  -> 900
# CCL  -> 989
# CNA  -> 1045
# CCH  -> 336
# CPG  -> 1031
# CRH  -> 1031
# CRDA  -> 1037
# DCC  -> 1027
# DGE  -> 1045
# EVR  -> 414
# EXPN  -> 678
# FERG  -> 1046
# FLTR  -> 18
#
# TOO FEW RECORDS FOR FLTR
# 	NEW ROW COUNT -> 275665
# 	NEW TICK COUNT -> 349
# FRES  -> 596
# GSK  -> 1045
# GLEN  -> 438
# HLMA  -> 1013
# HL.  -> 641
# HIK  -> 708
# HSX  -> 1012
# HSBA  -> 1256
# IMB  -> 1180
# INF  -> 1066
# IHG  -> 844
# ITRK  -> 884
# IAG  -> 856
# ITV  -> 1012
# JD.  -> 82
# JMAT  -> 1237
# JE.  -> 288
# KGF  -> 1256
# LAND  -> 1264
# LGEN  -> 1256
# LLOY  -> 1222
# LSE  -> 932
# MGGT  -> 1475
# MRO  -> 812
# MNDI  -> 614
# MRW  -> 1256
# NG.  -> 1243
# NXT  -> 1523
# NMC  -> 373
# OCDO  -> 462
# PSON  -> 1273
# PSN  -> 1463
# PHNX  -> 495
# POLY  -> 399
# PRU  -> 1503
# RDSA  -> 260
# RDSB  -> 996
# RB.  -> 1283
# REL  -> 1276
# RTO  -> 1244
# RMV  -> 691
# RIO  -> 1529
# RR.  -> 1554
# RBS  -> 1257
# RSA  -> 1246
# SGE  -> 1252
# SBRY  -> 1259
# SDR  -> 1247
# SMT  -> 139
# SGRO  -> 1535
# SVT  -> 1242
# SN.  -> 1587
# SMDS  -> 1425
# SMIN  -> 1486
# SKG  -> 638
# SPX  -> 1454
# SSE  -> 1273
# STJ  -> 1463
# STAN  -> 1528
# SLA  -> 673
# TW.  -> 1553
# TSCO  -> 1256
# TUI  -> 251
# ULVR  -> 1026
# UU.  -> 1292
# VOD  -> 1045
# WTB  -> 1045
# WPP  -> 682
# 3IN  -> 586
# FOUR  -> 1037
# ASL  -> 604
# AGK  -> 1046
# AAF  -> 14
#
# TOO FEW RECORDS FOR AAF
# 	NEW ROW COUNT -> 275651
# 	NEW TICK COUNT -> 348
# AJB  -> 45
# ATST  -> 615
# APAX  -> 217
# ASCL  -> 191
# ASHM  -> 678
# AGR  -> 827
# AML  -> 53
# AVST  -> 75
# AGT  -> 11
#
# TOO FEW RECORDS FOR AGT
# 	NEW ROW COUNT -> 275640
# 	NEW TICK COUNT -> 347
# BME  -> 279
# BAB  -> 1025
# BGFD  -> 606
# BAKK  -> 100
# BBY  -> 1045
# BGEO  -> 621
# BNKR  -> 614
# BAG  -> 1045
# BBA  -> 1046
# BBGI  -> 398
# BCA  -> 248
# BEZ  -> 161
# BWY  -> 1434
# BYG  -> 995
# BRSC  -> 274
# BCPT  -> 10
#
# TOO FEW RECORDS FOR BCPT
# 	NEW ROW COUNT -> 275630
# 	NEW TICK COUNT -> 346
# BGSC  -> 595
# BOY  -> 1248
# BVS  -> 1114
# BRW  -> 1124
# BVIC  -> 704
# CNE  -> 1400
# CLDN  -> 592
# CAPC  -> 473
# CPI  -> 1303
# CARD  -> 283
# CEY  -> 909
# CCFS  -> 109
# CINE  -> 631
# CTY  -> 596
# CKN  -> 1304
# CBG  -> 1240
# CLI  -> 1276
# COA  -> 1373
# COB  -> 1256
# CCC  -> 1098
# GLO  -> 100
# CTEC  -> 155
# CSP  -> 410
# CWK  -> 1113
# CRST  -> 328
# CYBG  -> 192
# DJAN  -> 1123
# DPH  -> 954
# DLN  -> 1193
# DPLM  -> 1480
# DLG  -> 346
# DC.  -> 523
# DOM  -> 1019
# DRX  -> 702
# DNLM  -> 658
# EZJ  -> 967
# EDIN  -> 586
# EIG  -> 661
# ECM  -> 1257
# ELM  -> 1535
# ENOG  -> 83
# ETO  -> 595
# EQN  -> 207
# ESNT  -> 729
# ERM  -> 1112
# FCIT  -> 587
# FDM  -> 278
# FXPO  -> 618
# FEV  -> 586
# FSV  -> 586
# FCSS  -> 466
# FIN  -> 21
#
# TOO FEW RECORDS FOR FIN
# 	NEW ROW COUNT -> 275609
# 	NEW TICK COUNT -> 345
# FGT  -> 585
# FGP  -> 1250
# FSJ  -> 1093
# FSFL  -> 282
# FUTR  -> 1041
# GFS  -> 828
# GFRD  -> 1462
# GAW  -> 1285
# GCP  -> 453
# DIGS  -> 306
# GSS  -> 594
# GNS  -> 937
# GOG  -> 1298
# GPOR  -> 1027
# GFTU  -> 897
# GRI  -> 1045
# UKW  -> 332
# GNC  -> 1032
# GNK  -> 1045
# GRG  -> 1045
# GVC  -> 736
# HMSO  -> 1045
# HVPE  -> 395
# HSTG  -> 209
# HAS  -> 1026
# HRI  -> 588
# HGT  -> 586
# HICL  -> 586
# HILS  -> 1025
# HFG  -> 628
# HOC  -> 656
# HSV  -> 1015
# HWDN  -> 1027
# HTG  -> 995
# IBST  -> 207
# IGG  -> 736
# IMI  -> 1027
# INCH  -> 1026
# ISAT  -> 729
# ICP  -> 1026
# IHP  -> 84
# INPP  -> 509
# INVP  -> 880
# IPO  -> 816
# IWG  -> 540
# JLG  -> 244
# JII  -> 595
# JAM  -> 586
# JMG  -> 585
# JFJ  -> 595
# JEO  -> 586
# JUP  -> 468
# KNOS  -> 222
# KAZ  -> 712
# LRE  -> 702
# LWDB  -> 383
# LMP  -> 510
# EMG  -> 1026
# MKS  -> 1027
# MSLH  -> 1027
# MARS  -> 778
# MCS  -> 104
# MDC  -> 191
# MRC  -> 569
# MERL  -> 291
# MCRO  -> 733
# MAB  -> 842
# MONY  -> 613
# MNKS  -> 587
# MGAM  -> 1464
# MYI  -> 585
# NEX  -> 1366
# NBLS  -> 413
# NETW  -> 27
#
# TOO FEW RECORDS FOR NETW
# 	NEW ROW COUNT -> 275582
# 	NEW TICK COUNT -> 344
# NRR  -> 464
# NESF  -> 276
# OSB  -> 279
# OXIG  -> 1460
# PAGE  -> 917
# PIN  -> 585
# PAG  -> 1481
# PAY  -> 767
# PNN  -> 1519
# PLI  -> 584
# PSH  -> 126
# PNL  -> 585
# PFC  -> 713
# PETS  -> 291
# PTEC  -> 687
# PLUS  -> 305
# PCT  -> 586
# PLP  -> 288
# PPH  -> 573
# PMO  -> 1458
# PHP  -> 1084
# PFG  -> 1026
# PRTC  -> 226
# PZC  -> 1012
# QQ.  -> 713
# QLT  -> 68
# RNK  -> 1029
# RAT  -> 1019
# RDW  -> 1023
# TRIG  -> 295
# RSW  -> 1021
# RTN  -> 1027
# RHIM  -> 102
# RCP  -> 74
# RSE  -> 284
# ROR  -> 1026
# RMG  -> 295
# SBRE  -> 97
# SAFE  -> 462
# SNN  -> 236
# SVS  -> 1412
# SDP  -> 589
# SOI  -> 586
# SCIN  -> 587
# SNR  -> 1428
# SEQI  -> 231
# SRP  -> 1286
# SHB  -> 1152
# SHI  -> 1318
# SXX  -> 659
# SRE  -> 623
# SSON  -> 41
# SCT  -> 205
# SOPH  -> 225
# SXS  -> 1479
# SPT  -> 1255
# SPD  -> 639
# SSPG  -> 275
# SMP  -> 1424
# SGC  -> 1152
# SYNC  -> 335
# SYNT  -> 1454
# TALK  -> 479
# TATE  -> 1260
# TBCG  -> 165
# TEP  -> 984
# TMPL  -> 586
# TEM  -> 586
# TIFS  -> 103
# TCAP  -> 961
# TRY  -> 585
# TRN  -> 15
#
# TOO FEW RECORDS FOR TRN
# 	NEW ROW COUNT -> 275567
# 	NEW TICK COUNT -> 343
# TPK  -> 1026
# BBOX  -> 276
# TLW  -> 1019
# UDG  -> 1008
# UKCM  -> 587
# ULE  -> 1023
# UTG  -> 342
# VSVS  -> 1256
# VCT  -> 1185
# VEIL  -> 161
# VOF  -> 595
# VVO  -> 75
# WOSG  -> 18
#
# TOO FEW RECORDS FOR WOSG
# 	NEW ROW COUNT -> 275549
# 	NEW TICK COUNT -> 342
# WEIR  -> 1468
# JDW  -> 1342
# SMWH  -> 668
# WMH  -> 884
# WTAN  -> 595
# WIZZ  -> 241
# WG.  -> 906
# WKP  -> 947
# WWH  -> 596
#
# END ROW COUNT -> 275549
# END TICK COUNT -> 342

# %%
#Function for calculating ema
def calc_ema(_s_in,_periods):
    #Calc mod val
    _mod = 2/(_periods+1)
    #Calc sma
    _sma_s = [0] * _s_in.shape[0]
    for _i in range(0,_periods):
        _sma_s += _s_in.shift(_i) / _periods
    #Calc ema
    _ema_s = _sma_s.copy()
    _ema_s[(_ema_s > 0) & (np.isnan(_ema_s) == False)] = _mod*(_s_in - _ema_s.shift(1)) + _ema_s.shift(1)
    return _ema_s.copy()

# %%
#Function for calculating the MACD
def calc_macd(_ema_lng_s,_ema_sht_s,_sig_period:int):
    #Make a df
    _tmp_df = pd.DataFrame([])
    _tmp_df['ema_lng'] = _ema_lng_s
    _tmp_df['ema_sht'] = _ema_sht_s
    #Calc the signal line
    _tmp_df['macd_line'] = _tmp_df['ema_sht'] - _tmp_df['ema_lng']
    _tmp_df['signal_line'] = calc_ema(_tmp_df['macd_line'],_sig_period)
    _tmp_df['macd_hist'] = _tmp_df['macd_line'] - _tmp_df['signal_line']
    return (_tmp_df['macd_line'].copy(),_tmp_df['signal_line'].copy(),_tmp_df['macd_hist'].copy())

# %%
#Calc the ema and macds for the data
def calc_ema_macd(_df_in):
    _tick_df = _df_in.copy()
    try:
        #Add in the ema and macd
        _tick_df = _tick_df.sort_values(by='date')
#         _tick_df = _tick_df.reset_index(drop=True)
        _tick_df['ema12'] = calc_ema(_tick_df['close'],12)
        _tick_df['ema26'] = calc_ema(_tick_df['close'],26)
        _tick_df['macd_line'],_tick_df['signal_line'],_tick_df['macd'] = calc_macd(_tick_df['ema26'],_tick_df['ema12'],9)
        return _tick_df
    except Exception as e:
        print('ERROR:{}'.format(e))
        return _tick_df

# %%
#Create a function which normalises a feature based only on the values which have come before it - avoids time series bias
def norm_time_s(_ind,_s_in,_window):
    _this_ind = _ind - _s_in.index.min()
    if _this_ind < _window:
        _min_ind = 0
    else:
        _min_ind = _this_ind - _window
    _min = np.nanmin(_s_in[_min_ind:_this_ind+1].values)
    _max = np.nanmax(_s_in[_min_ind:_this_ind+1].values)
    _norm_val = (_s_in[_ind] - _min) / (_max - _min)
    return _norm_val

# %%
#Runt he functions
def norm_prices(_df_in):
    _df_out = _df_in.copy()
    #Normalise the columns which need it
    _norm_cols = [
        #Standard features
        "open"
        ,"close"
        ,"high"
        ,"low"
        ,"volume"
    ]
    #Reset the index
    _df_out.sort_values(['date'],ascending=True,inplace=True)
    #Calc the 5yr window
    _5yr = 5*52
    #Normalise
    for _col in _norm_cols:
        _tmp_s = _df_out[_col].copy() #Take a copy so as the values are changed this does not affect following calculations
        _df_out[_col] = [norm_time_s(_x,_tmp_s,_5yr) for _x in _df_out.index]
    return _df_out

# %%
df_prices_w[df_prices_w.ticker == 'III'].head()
# Out:
#   ticker       date    high    low      volume   open  close  change  ema12  \
# 0    III 2007-12-31  1023.0  964.0   4511565.0  995.0  965.0   -30.0    NaN
# 1    III 2008-01-07   989.0  917.5  16056554.0  967.5  924.0   -43.5    NaN
# 2    III 2008-01-14   936.0  881.0  21691287.0  917.0  901.0   -16.0    NaN
# 3    III 2008-01-21   965.0  847.0  17850580.0  891.0  917.5    26.5    NaN
# 4    III 2008-01-28   971.0  903.0  12079245.0  911.0  961.0    50.0    NaN
#
#    ema26  macd_line  signal_line  macd
# 0    NaN        NaN          NaN   NaN
# 1    NaN        NaN          NaN   NaN
# 2    NaN        NaN          NaN   NaN
# 3    NaN        NaN          NaN   NaN
# 4    NaN        NaN          NaN   NaN

# %%
#Normalize the prices by ticker and time then create emas and macds for each ticker
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print('NORALISING AND CALCULATING EMA & MACD VALUES')
count = 0
error_li = []
run_time = process_time()
run_time.lap()
for tick in tick_ftse.ticker:
    count += 1
    print('\nRUN FOR {} - {}'.format(tick,count))
    try:
        this_tick_df = df_prices_w[df_prices_w.ticker == tick]
        this_tick_df = norm_prices(this_tick_df.copy())
        #Calculate the ema and macd
        this_tick_df = calc_ema_macd(this_tick_df)
        #Append back on to the dataframe
#         df_prices_w[df_prices_w.ticker == tick] = this_tick_df.copy()
        print('\tSUCCESS')
        run_time.lap()
        run_time.show_latest_lap_time()
    except Exception as e:
        print('\tERROR -> {}'.format(e))
        error_li.append(e)
run_time.end()
print('\n\nCOMPLETED - ERRORS ENCOUNTERED -> {}'.format(len(error_li)))
if len(error_li) > 0:
    print(error_li)
# Out:
# NORALISING AND CALCULATING EMA & MACD VALUES
#
# RUN FOR III - 1
# C:\Users\Robert\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in double_scalars
#   # Remove the CWD from sys.path while we load stuff.
# 	SUCCESS
# LAP 2 TIME -> 0:0:1
#
# RUN FOR ABF - 2
# 	SUCCESS
# LAP 3 TIME -> 0:0:2
#
# RUN FOR ADM - 3
# 	SUCCESS
# LAP 4 TIME -> 0:0:0
#
# RUN FOR AAL - 4
# 	SUCCESS
# LAP 5 TIME -> 0:0:2
#
# RUN FOR ANTO - 5
# 	SUCCESS
# LAP 6 TIME -> 0:0:2
#
# RUN FOR AHT - 6
# 	SUCCESS
# LAP 7 TIME -> 0:0:2
#
# RUN FOR AZN - 7
# 	SUCCESS
# LAP 8 TIME -> 0:0:2
#
# RUN FOR AUTO - 8
# 	SUCCESS
# LAP 9 TIME -> 0:0:0
#
# RUN FOR AVV - 9
# 	SUCCESS
# LAP 10 TIME -> 0:0:2
#
# RUN FOR AV. - 10
# 	SUCCESS
# LAP 11 TIME -> 0:0:3
#
# RUN FOR BA. - 11
# 	SUCCESS
# LAP 12 TIME -> 0:0:3
#
# RUN FOR BARC - 12
# 	SUCCESS
# LAP 13 TIME -> 0:0:2
#
# RUN FOR BDEV - 13
# 	SUCCESS
# LAP 14 TIME -> 0:0:2
#
# RUN FOR BKG - 14
# 	SUCCESS
# LAP 15 TIME -> 0:0:2
#
# RUN FOR BHP - 15
# 	SUCCESS
# LAP 16 TIME -> 0:0:1
#
# RUN FOR BP. - 16
# 	SUCCESS
# LAP 17 TIME -> 0:0:3
#
# RUN FOR BATS - 17
# 	SUCCESS
# LAP 18 TIME -> 0:0:2
#
# RUN FOR BLND - 18
# 	SUCCESS
# LAP 19 TIME -> 0:0:2
#
# RUN FOR BNZL - 19
# 	SUCCESS
# LAP 20 TIME -> 0:0:2
#
# RUN FOR BRBY - 20
# 	SUCCESS
# LAP 21 TIME -> 0:0:2
#
# RUN FOR CCL - 21
# 	SUCCESS
# LAP 22 TIME -> 0:0:2
#
# RUN FOR CNA - 22
# 	SUCCESS
# LAP 23 TIME -> 0:0:2
#
# RUN FOR CCH - 23
# 	SUCCESS
# LAP 24 TIME -> 0:0:0
#
# RUN FOR CPG - 24
# 	SUCCESS
# LAP 25 TIME -> 0:0:2
#
# RUN FOR CRH - 25
# 	SUCCESS
# LAP 26 TIME -> 0:0:2
#
# RUN FOR CRDA - 26
# 	SUCCESS
# LAP 27 TIME -> 0:0:2
#
# RUN FOR DCC - 27
# 	SUCCESS
# LAP 28 TIME -> 0:0:2
#
# RUN FOR DGE - 28
# 	SUCCESS
# LAP 29 TIME -> 0:0:2
#
# RUN FOR EVR - 29
# 	SUCCESS
# LAP 30 TIME -> 0:0:1
#
# RUN FOR EXPN - 30
# 	SUCCESS
# LAP 31 TIME -> 0:0:1
#
# RUN FOR FERG - 31
# 	SUCCESS
# LAP 32 TIME -> 0:0:2
#
# RUN FOR FRES - 32
# 	SUCCESS
# LAP 33 TIME -> 0:0:1
#
# RUN FOR GSK - 33
# 	SUCCESS
# LAP 34 TIME -> 0:0:2
#
# RUN FOR GLEN - 34
# 	SUCCESS
# LAP 35 TIME -> 0:0:1
#
# RUN FOR HLMA - 35
# 	SUCCESS
# LAP 36 TIME -> 0:0:2
#
# RUN FOR HL. - 36
# 	SUCCESS
# LAP 37 TIME -> 0:0:1
#
# RUN FOR HIK - 37
# 	SUCCESS
# LAP 38 TIME -> 0:0:1
#
# RUN FOR HSX - 38
# 	SUCCESS
# LAP 39 TIME -> 0:0:2
#
# RUN FOR HSBA - 39
# 	SUCCESS
# LAP 40 TIME -> 0:0:2
#
# RUN FOR IMB - 40
# 	SUCCESS
# LAP 41 TIME -> 0:0:2
#
# RUN FOR INF - 41
# 	SUCCESS
# LAP 42 TIME -> 0:0:2
#
# RUN FOR IHG - 42
# 	SUCCESS
# LAP 43 TIME -> 0:0:1
#
# RUN FOR ITRK - 43
# 	SUCCESS
# LAP 44 TIME -> 0:0:2
#
# RUN FOR IAG - 44
# 	SUCCESS
# LAP 45 TIME -> 0:0:1
#
# RUN FOR ITV - 45
# 	SUCCESS
# LAP 46 TIME -> 0:0:2
#
# RUN FOR JD. - 46
# 	SUCCESS
# LAP 47 TIME -> 0:0:0
#
# RUN FOR JMAT - 47
# 	SUCCESS
# LAP 48 TIME -> 0:0:2
#
# RUN FOR JE. - 48
# 	SUCCESS
# LAP 49 TIME -> 0:0:0
#
# RUN FOR KGF - 49
# 	SUCCESS
# LAP 50 TIME -> 0:0:2
#
# RUN FOR LAND - 50
# 	SUCCESS
# LAP 51 TIME -> 0:0:2
#
# RUN FOR LGEN - 51
# 	SUCCESS
# LAP 52 TIME -> 0:0:2
#
# RUN FOR LLOY - 52
# 	SUCCESS
# LAP 53 TIME -> 0:0:2
#
# RUN FOR LSE - 53
# 	SUCCESS
# LAP 54 TIME -> 0:0:2
#
# RUN FOR MGGT - 54
# 	SUCCESS
# LAP 55 TIME -> 0:0:4
#
# RUN FOR MRO - 55
# 	SUCCESS
# LAP 56 TIME -> 0:0:2
#
# RUN FOR MNDI - 56
# 	SUCCESS
# LAP 57 TIME -> 0:0:1
#
# RUN FOR MRW - 57
# 	SUCCESS
# LAP 58 TIME -> 0:0:3
#
# RUN FOR NG. - 58
# 	SUCCESS
# LAP 59 TIME -> 0:0:3
#
# RUN FOR NXT - 59
# 	SUCCESS
# LAP 60 TIME -> 0:0:3
#
# RUN FOR NMC - 60
# 	SUCCESS
# LAP 61 TIME -> 0:0:0
#
# RUN FOR OCDO - 61
# 	SUCCESS
# LAP 62 TIME -> 0:0:1
#
# RUN FOR PSON - 62
# 	SUCCESS
# LAP 63 TIME -> 0:0:2
#
# RUN FOR PSN - 63
# 	SUCCESS
# LAP 64 TIME -> 0:0:3
#
# RUN FOR PHNX - 64
# 	SUCCESS
# LAP 65 TIME -> 0:0:1
#
# RUN FOR POLY - 65
# 	SUCCESS
# LAP 66 TIME -> 0:0:0
#
# RUN FOR PRU - 66
# 	SUCCESS
# LAP 67 TIME -> 0:0:3
#
# RUN FOR RDSA - 67
# 	SUCCESS
# LAP 68 TIME -> 0:0:0
#
# RUN FOR RDSB - 68
# 	SUCCESS
# LAP 69 TIME -> 0:0:2
#
# RUN FOR RB. - 69
# 	SUCCESS
# LAP 70 TIME -> 0:0:2
#
# RUN FOR REL - 70
# 	SUCCESS
# LAP 71 TIME -> 0:0:2
#
# RUN FOR RTO - 71
# 	SUCCESS
# LAP 72 TIME -> 0:0:2
#
# RUN FOR RMV - 72
# 	SUCCESS
# LAP 73 TIME -> 0:0:1
#
# RUN FOR RIO - 73
# 	SUCCESS
# LAP 74 TIME -> 0:0:3
#
# RUN FOR RR. - 74
# 	SUCCESS
# LAP 75 TIME -> 0:0:3
#
# RUN FOR RBS - 75
# 	SUCCESS
# LAP 76 TIME -> 0:0:2
#
# RUN FOR RSA - 76
# 	SUCCESS
# LAP 77 TIME -> 0:0:2
#
# RUN FOR SGE - 77
# 	SUCCESS
# LAP 78 TIME -> 0:0:2
#
# RUN FOR SBRY - 78
# 	SUCCESS
# LAP 79 TIME -> 0:0:2
#
# RUN FOR SDR - 79
# 	SUCCESS
# LAP 80 TIME -> 0:0:2
#
# RUN FOR SMT - 80
# 	SUCCESS
# LAP 81 TIME -> 0:0:0
#
# RUN FOR SGRO - 81
# 	SUCCESS
# LAP 82 TIME -> 0:0:3
#
# RUN FOR SVT - 82
# 	SUCCESS
# LAP 83 TIME -> 0:0:2
#
# RUN FOR SN. - 83
# 	SUCCESS
# LAP 84 TIME -> 0:0:3
#
# RUN FOR SMDS - 84
# 	SUCCESS
# LAP 85 TIME -> 0:0:3
#
# RUN FOR SMIN - 85
# 	SUCCESS
# LAP 86 TIME -> 0:0:3
#
# RUN FOR SKG - 86
# 	SUCCESS
# LAP 87 TIME -> 0:0:1
#
# RUN FOR SPX - 87
# 	SUCCESS
# LAP 88 TIME -> 0:0:3
#
# RUN FOR SSE - 88
# 	SUCCESS
# LAP 89 TIME -> 0:0:3
#
# RUN FOR STJ - 89
# 	SUCCESS
# LAP 90 TIME -> 0:0:3
#
# RUN FOR STAN - 90
# 	SUCCESS
# LAP 91 TIME -> 0:0:3
#
# RUN FOR SLA - 91
# 	SUCCESS
# LAP 92 TIME -> 0:0:1
#
# RUN FOR TW. - 92
# 	SUCCESS
# LAP 93 TIME -> 0:0:4
#
# RUN FOR TSCO - 93
# 	SUCCESS
# LAP 94 TIME -> 0:0:3
#
# RUN FOR TUI - 94
# 	SUCCESS
# LAP 95 TIME -> 0:0:0
#
# RUN FOR ULVR - 95
# 	SUCCESS
# LAP 96 TIME -> 0:0:2
#
# RUN FOR UU. - 96
# 	SUCCESS
# LAP 97 TIME -> 0:0:3
#
# RUN FOR VOD - 97
# 	SUCCESS
# LAP 98 TIME -> 0:0:2
#
# RUN FOR WTB - 98
# 	SUCCESS
# LAP 99 TIME -> 0:0:3
#
# RUN FOR WPP - 99
# 	SUCCESS
# LAP 100 TIME -> 0:0:2
#
# RUN FOR 3IN - 100
# 	SUCCESS
# LAP 101 TIME -> 0:0:2
#
# RUN FOR FOUR - 101
# 	SUCCESS
# LAP 102 TIME -> 0:0:3
#
# RUN FOR ASL - 102
# 	SUCCESS
# LAP 103 TIME -> 0:0:1
#
# RUN FOR AGK - 103
# 	SUCCESS
# LAP 104 TIME -> 0:0:2
#
# RUN FOR AJB - 104
# 	SUCCESS
# LAP 105 TIME -> 0:0:0
#
# RUN FOR ATST - 105
# 	SUCCESS
# LAP 106 TIME -> 0:0:1
#
# RUN FOR APAX - 106
# 	SUCCESS
# LAP 107 TIME -> 0:0:0
#
# RUN FOR ASCL - 107
# 	SUCCESS
# LAP 108 TIME -> 0:0:0
#
# RUN FOR ASHM - 108
# 	SUCCESS
# LAP 109 TIME -> 0:0:1
#
# RUN FOR AGR - 109
# 	SUCCESS
# LAP 110 TIME -> 0:0:1
#
# RUN FOR AML - 110
# 	SUCCESS
# LAP 111 TIME -> 0:0:0
#
# RUN FOR AVST - 111
# 	SUCCESS
# LAP 112 TIME -> 0:0:0
#
# RUN FOR BME - 112
# 	SUCCESS
# LAP 113 TIME -> 0:0:0
#
# RUN FOR BAB - 113
# 	SUCCESS
# LAP 114 TIME -> 0:0:2
#
# RUN FOR BGFD - 114
# 	SUCCESS
# LAP 115 TIME -> 0:0:1
#
# RUN FOR BAKK - 115
# 	SUCCESS
# LAP 116 TIME -> 0:0:0
#
# RUN FOR BBY - 116
# 	SUCCESS
# LAP 117 TIME -> 0:0:2
#
# RUN FOR BGEO - 117
# 	SUCCESS
# LAP 118 TIME -> 0:0:1
#
# RUN FOR BNKR - 118
# 	SUCCESS
# LAP 119 TIME -> 0:0:1
#
# RUN FOR BAG - 119
# 	SUCCESS
# LAP 120 TIME -> 0:0:2
#
# RUN FOR BBA - 120
# 	SUCCESS
# LAP 121 TIME -> 0:0:2
#
# RUN FOR BBGI - 121
# 	SUCCESS
# LAP 122 TIME -> 0:0:1
#
# RUN FOR BCA - 122
# 	SUCCESS
# LAP 123 TIME -> 0:0:0
#
# RUN FOR BEZ - 123
# 	SUCCESS
# LAP 124 TIME -> 0:0:0
#
# RUN FOR BWY - 124
# 	SUCCESS
# LAP 125 TIME -> 0:0:3
#
# RUN FOR BYG - 125
# 	SUCCESS
# LAP 126 TIME -> 0:0:2
#
# RUN FOR BRSC - 126
# 	SUCCESS
# LAP 127 TIME -> 0:0:0
#
# RUN FOR BGSC - 127
# 	SUCCESS
# LAP 128 TIME -> 0:0:1
#
# RUN FOR BOY - 128
# 	SUCCESS
# LAP 129 TIME -> 0:0:2
#
# RUN FOR BVS - 129
# 	SUCCESS
# LAP 130 TIME -> 0:0:2
#
# RUN FOR BRW - 130
# 	SUCCESS
# LAP 131 TIME -> 0:0:2
#
# RUN FOR BVIC - 131
# 	SUCCESS
# LAP 132 TIME -> 0:0:1
#
# RUN FOR CNE - 132
# 	SUCCESS
# LAP 133 TIME -> 0:0:3
#
# RUN FOR CLDN - 133
# 	SUCCESS
# LAP 134 TIME -> 0:0:1
#
# RUN FOR CAPC - 134
# 	SUCCESS
# LAP 135 TIME -> 0:0:1
#
# RUN FOR CPI - 135
# 	SUCCESS
# LAP 136 TIME -> 0:0:2
#
# RUN FOR CARD - 136
# 	SUCCESS
# LAP 137 TIME -> 0:0:0
#
# RUN FOR CEY - 137
# 	SUCCESS
# LAP 138 TIME -> 0:0:2
#
# RUN FOR CCFS - 138
# 	SUCCESS
# LAP 139 TIME -> 0:0:0
#
# RUN FOR CINE - 139
# 	SUCCESS
# LAP 140 TIME -> 0:0:1
#
# RUN FOR CTY - 140
# 	SUCCESS
# LAP 141 TIME -> 0:0:1
#
# RUN FOR CKN - 141
# 	SUCCESS
# LAP 142 TIME -> 0:0:2
#
# RUN FOR CBG - 142
# 	SUCCESS
# LAP 143 TIME -> 0:0:2
#
# RUN FOR CLI - 143
# 	SUCCESS
# LAP 144 TIME -> 0:0:2
#
# RUN FOR COA - 144
# 	SUCCESS
# LAP 145 TIME -> 0:0:3
#
# RUN FOR COB - 145
# 	SUCCESS
# LAP 146 TIME -> 0:0:2
#
# RUN FOR CCC - 146
# 	SUCCESS
# LAP 147 TIME -> 0:0:2
#
# RUN FOR GLO - 147
# 	SUCCESS
# LAP 148 TIME -> 0:0:0
#
# RUN FOR CTEC - 148
# 	SUCCESS
# LAP 149 TIME -> 0:0:0
#
# RUN FOR CSP - 149
# 	SUCCESS
# LAP 150 TIME -> 0:0:1
#
# RUN FOR CWK - 150
# 	SUCCESS
# LAP 151 TIME -> 0:0:2
#
# RUN FOR CRST - 151
# 	SUCCESS
# LAP 152 TIME -> 0:0:0
#
# RUN FOR CYBG - 152
# 	SUCCESS
# LAP 153 TIME -> 0:0:0
#
# RUN FOR DJAN - 153
# 	SUCCESS
# LAP 154 TIME -> 0:0:2
#
# RUN FOR DPH - 154
# 	SUCCESS
# LAP 155 TIME -> 0:0:2
#
# RUN FOR DLN - 155
# 	SUCCESS
# LAP 156 TIME -> 0:0:2
#
# RUN FOR DPLM - 156
# 	SUCCESS
# LAP 157 TIME -> 0:0:3
#
# RUN FOR DLG - 157
# 	SUCCESS
# LAP 158 TIME -> 0:0:0
#
# RUN FOR DC. - 158
# 	SUCCESS
# LAP 159 TIME -> 0:0:1
#
# RUN FOR DOM - 159
# 	SUCCESS
# LAP 160 TIME -> 0:0:2
#
# RUN FOR DRX - 160
# 	SUCCESS
# LAP 161 TIME -> 0:0:1
#
# RUN FOR DNLM - 161
# 	SUCCESS
# LAP 162 TIME -> 0:0:1
#
# RUN FOR EZJ - 162
# 	SUCCESS
# LAP 163 TIME -> 0:0:2
#
# RUN FOR EDIN - 163
# 	SUCCESS
# LAP 164 TIME -> 0:0:1
#
# RUN FOR EIG - 164
# 	SUCCESS
# LAP 165 TIME -> 0:0:1
#
# RUN FOR ECM - 165
# 	SUCCESS
# LAP 166 TIME -> 0:0:3
#
# RUN FOR ELM - 166
# 	SUCCESS
# LAP 167 TIME -> 0:0:3
#
# RUN FOR ENOG - 167
# 	SUCCESS
# LAP 168 TIME -> 0:0:0
#
# RUN FOR ETO - 168
# 	SUCCESS
# LAP 169 TIME -> 0:0:1
#
# RUN FOR EQN - 169
# 	SUCCESS
# LAP 170 TIME -> 0:0:0
#
# RUN FOR ESNT - 170
# 	SUCCESS
# LAP 171 TIME -> 0:0:1
#
# RUN FOR ERM - 171
# 	SUCCESS
# LAP 172 TIME -> 0:0:2
#
# RUN FOR FCIT - 172
# 	SUCCESS
# LAP 173 TIME -> 0:0:1
#
# RUN FOR FDM - 173
# 	SUCCESS
# LAP 174 TIME -> 0:0:0
#
# RUN FOR FXPO - 174
# 	SUCCESS
# LAP 175 TIME -> 0:0:1
#
# RUN FOR FEV - 175
# 	SUCCESS
# LAP 176 TIME -> 0:0:1
#
# RUN FOR FSV - 176
# 	SUCCESS
# LAP 177 TIME -> 0:0:1
#
# RUN FOR FCSS - 177
# 	SUCCESS
# LAP 178 TIME -> 0:0:1
#
# RUN FOR FGT - 178
# 	SUCCESS
# LAP 179 TIME -> 0:0:1
#
# RUN FOR FGP - 179
# 	SUCCESS
# LAP 180 TIME -> 0:0:2
#
# RUN FOR FSJ - 180
# 	SUCCESS
# LAP 181 TIME -> 0:0:2
#
# RUN FOR FSFL - 181
# 	SUCCESS
# LAP 182 TIME -> 0:0:0
#
# RUN FOR FUTR - 182
# 	SUCCESS
# LAP 183 TIME -> 0:0:2
#
# RUN FOR GFS - 183
# 	SUCCESS
# LAP 184 TIME -> 0:0:1
#
# RUN FOR GFRD - 184
# 	SUCCESS
# LAP 185 TIME -> 0:0:3
#
# RUN FOR GAW - 185
# 	SUCCESS
# LAP 186 TIME -> 0:0:2
#
# RUN FOR GCP - 186
# 	SUCCESS
# LAP 187 TIME -> 0:0:1
#
# RUN FOR DIGS - 187
# 	SUCCESS
# LAP 188 TIME -> 0:0:0
#
# RUN FOR GSS - 188
# 	SUCCESS
# LAP 189 TIME -> 0:0:1
#
# RUN FOR GNS - 189
# 	SUCCESS
# LAP 190 TIME -> 0:0:2
#
# RUN FOR GOG - 190
# 	SUCCESS
# LAP 191 TIME -> 0:0:3
#
# RUN FOR GPOR - 191
# 	SUCCESS
# LAP 192 TIME -> 0:0:2
#
# RUN FOR GFTU - 192
# 	SUCCESS
# LAP 193 TIME -> 0:0:2
#
# RUN FOR GRI - 193
# 	SUCCESS
# LAP 194 TIME -> 0:0:2
#
# RUN FOR UKW - 194
# 	SUCCESS
# LAP 195 TIME -> 0:0:0
#
# RUN FOR GNC - 195
# 	SUCCESS
# LAP 196 TIME -> 0:0:2
#
# RUN FOR GNK - 196
# 	SUCCESS
# LAP 197 TIME -> 0:0:2
#
# RUN FOR GRG - 197
# 	SUCCESS
# LAP 198 TIME -> 0:0:2
#
# RUN FOR GVC - 198
# 	SUCCESS
# LAP 199 TIME -> 0:0:1
#
# RUN FOR HMSO - 199
# 	SUCCESS
# LAP 200 TIME -> 0:0:2
#
# RUN FOR HVPE - 200
# 	SUCCESS
# LAP 201 TIME -> 0:0:0
#
# RUN FOR HSTG - 201
# 	SUCCESS
# LAP 202 TIME -> 0:0:0
#
# RUN FOR HAS - 202
# 	SUCCESS
# LAP 203 TIME -> 0:0:2
#
# RUN FOR HRI - 203
# 	SUCCESS
# LAP 204 TIME -> 0:0:1
#
# RUN FOR HGT - 204
# 	SUCCESS
# LAP 205 TIME -> 0:0:1
#
# RUN FOR HICL - 205
# 	SUCCESS
# LAP 206 TIME -> 0:0:1
#
# RUN FOR HILS - 206
# 	SUCCESS
# LAP 207 TIME -> 0:0:2
#
# RUN FOR HFG - 207
# 	SUCCESS
# LAP 208 TIME -> 0:0:1
#
# RUN FOR HOC - 208
# 	SUCCESS
# LAP 209 TIME -> 0:0:1
#
# RUN FOR HSV - 209
# 	SUCCESS
# LAP 210 TIME -> 0:0:2
#
# RUN FOR HWDN - 210
# 	SUCCESS
# LAP 211 TIME -> 0:0:2
#
# RUN FOR HTG - 211
# 	SUCCESS
# LAP 212 TIME -> 0:0:2
#
# RUN FOR IBST - 212
# 	SUCCESS
# LAP 213 TIME -> 0:0:0
#
# RUN FOR IGG - 213
# 	SUCCESS
# LAP 214 TIME -> 0:0:2
#
# RUN FOR IMI - 214
# 	SUCCESS
# LAP 215 TIME -> 0:0:3
#
# RUN FOR INCH - 215
# 	SUCCESS
# LAP 216 TIME -> 0:0:3
#
# RUN FOR ISAT - 216
# 	SUCCESS
# LAP 217 TIME -> 0:0:1
#
# RUN FOR ICP - 217
# 	SUCCESS
# LAP 218 TIME -> 0:0:2
#
# RUN FOR IHP - 218
# 	SUCCESS
# LAP 219 TIME -> 0:0:0
#
# RUN FOR INPP - 219
# 	SUCCESS
# LAP 220 TIME -> 0:0:1
#
# RUN FOR INVP - 220
# 	SUCCESS
# LAP 221 TIME -> 0:0:2
#
# RUN FOR IPO - 221
# 	SUCCESS
# LAP 222 TIME -> 0:0:1
#
# RUN FOR IWG - 222
# 	SUCCESS
# LAP 223 TIME -> 0:0:1
#
# RUN FOR JLG - 223
# 	SUCCESS
# LAP 224 TIME -> 0:0:0
#
# RUN FOR JII - 224
# 	SUCCESS
# LAP 225 TIME -> 0:0:1
#
# RUN FOR JAM - 225
# 	SUCCESS
# LAP 226 TIME -> 0:0:1
#
# RUN FOR JMG - 226
# 	SUCCESS
# LAP 227 TIME -> 0:0:1
#
# RUN FOR JFJ - 227
# 	SUCCESS
# LAP 228 TIME -> 0:0:1
#
# RUN FOR JEO - 228
# 	SUCCESS
# LAP 229 TIME -> 0:0:1
#
# RUN FOR JUP - 229
# 	SUCCESS
# LAP 230 TIME -> 0:0:1
#
# RUN FOR KNOS - 230
# 	SUCCESS
# LAP 231 TIME -> 0:0:0
#
# RUN FOR KAZ - 231
# 	SUCCESS
# LAP 232 TIME -> 0:0:1
#
# RUN FOR LRE - 232
# 	SUCCESS
# LAP 233 TIME -> 0:0:1
#
# RUN FOR LWDB - 233
# 	SUCCESS
# LAP 234 TIME -> 0:0:0
#
# RUN FOR LMP - 234
# 	SUCCESS
# LAP 235 TIME -> 0:0:1
#
# RUN FOR EMG - 235
# 	SUCCESS
# LAP 236 TIME -> 0:0:2
#
# RUN FOR MKS - 236
# 	SUCCESS
# LAP 237 TIME -> 0:0:2
#
# RUN FOR MSLH - 237
# 	SUCCESS
# LAP 238 TIME -> 0:0:2
#
# RUN FOR MARS - 238
# 	SUCCESS
# LAP 239 TIME -> 0:0:1
#
# RUN FOR MCS - 239
# 	SUCCESS
# LAP 240 TIME -> 0:0:0
#
# RUN FOR MDC - 240
# 	SUCCESS
# LAP 241 TIME -> 0:0:0
#
# RUN FOR MRC - 241
# 	SUCCESS
# LAP 242 TIME -> 0:0:1
#
# RUN FOR MERL - 242
# 	SUCCESS
# LAP 243 TIME -> 0:0:0
#
# RUN FOR MCRO - 243
# 	SUCCESS
# LAP 244 TIME -> 0:0:1
#
# RUN FOR MAB - 244
# 	SUCCESS
# LAP 245 TIME -> 0:0:1
#
# RUN FOR MONY - 245
# 	SUCCESS
# LAP 246 TIME -> 0:0:1
#
# RUN FOR MNKS - 246
# 	SUCCESS
# LAP 247 TIME -> 0:0:1
#
# RUN FOR MGAM - 247
# 	SUCCESS
# LAP 248 TIME -> 0:0:3
#
# RUN FOR MYI - 248
# 	SUCCESS
# LAP 249 TIME -> 0:0:1
#
# RUN FOR NEX - 249
# 	SUCCESS
# LAP 250 TIME -> 0:0:3
#
# RUN FOR NBLS - 250
# 	SUCCESS
# LAP 251 TIME -> 0:0:1
#
# RUN FOR NRR - 251
# 	SUCCESS
# LAP 252 TIME -> 0:0:1
#
# RUN FOR NESF - 252
# 	SUCCESS
# LAP 253 TIME -> 0:0:0
#
# RUN FOR OSB - 253
# 	SUCCESS
# LAP 254 TIME -> 0:0:0
#
# RUN FOR OXIG - 254
# 	SUCCESS
# LAP 255 TIME -> 0:0:3
#
# RUN FOR PAGE - 255
# 	SUCCESS
# LAP 256 TIME -> 0:0:2
#
# RUN FOR PIN - 256
# 	SUCCESS
# LAP 257 TIME -> 0:0:1
#
# RUN FOR PAG - 257
# 	SUCCESS
# LAP 258 TIME -> 0:0:3
#
# RUN FOR PAY - 258
# 	SUCCESS
# LAP 259 TIME -> 0:0:1
#
# RUN FOR PNN - 259
# 	SUCCESS
# LAP 260 TIME -> 0:0:3
#
# RUN FOR PLI - 260
# 	SUCCESS
# LAP 261 TIME -> 0:0:1
#
# RUN FOR PSH - 261
# 	SUCCESS
# LAP 262 TIME -> 0:0:0
#
# RUN FOR PNL - 262
# 	SUCCESS
# LAP 263 TIME -> 0:0:1
#
# RUN FOR PFC - 263
# 	SUCCESS
# LAP 264 TIME -> 0:0:1
#
# RUN FOR PETS - 264
# 	SUCCESS
# LAP 265 TIME -> 0:0:0
#
# RUN FOR PTEC - 265
# 	SUCCESS
# LAP 266 TIME -> 0:0:1
#
# RUN FOR PLUS - 266
# 	SUCCESS
# LAP 267 TIME -> 0:0:0
#
# RUN FOR PCT - 267
# 	SUCCESS
# LAP 268 TIME -> 0:0:1
#
# RUN FOR PLP - 268
# 	SUCCESS
# LAP 269 TIME -> 0:0:0
#
# RUN FOR PPH - 269
# 	SUCCESS
# LAP 270 TIME -> 0:0:1
#
# RUN FOR PMO - 270
# 	SUCCESS
# LAP 271 TIME -> 0:0:3
#
# RUN FOR PHP - 271
# 	SUCCESS
# LAP 272 TIME -> 0:0:2
#
# RUN FOR PFG - 272
# 	SUCCESS
# LAP 273 TIME -> 0:0:2
#
# RUN FOR PRTC - 273
# 	SUCCESS
# LAP 274 TIME -> 0:0:0
#
# RUN FOR PZC - 274
# 	SUCCESS
# LAP 275 TIME -> 0:0:2
#
# RUN FOR QQ. - 275
# 	SUCCESS
# LAP 276 TIME -> 0:0:1
#
# RUN FOR QLT - 276
# 	SUCCESS
# LAP 277 TIME -> 0:0:0
#
# RUN FOR RNK - 277
# 	SUCCESS
# LAP 278 TIME -> 0:0:2
#
# RUN FOR RAT - 278
# 	SUCCESS
# LAP 279 TIME -> 0:0:2
#
# RUN FOR RDW - 279
# 	SUCCESS
# LAP 280 TIME -> 0:0:2
#
# RUN FOR TRIG - 280
# 	SUCCESS
# LAP 281 TIME -> 0:0:0
#
# RUN FOR RSW - 281
# 	SUCCESS
# LAP 282 TIME -> 0:0:2
#
# RUN FOR RTN - 282
# 	SUCCESS
# LAP 283 TIME -> 0:0:2
#
# RUN FOR RHIM - 283
# 	SUCCESS
# LAP 284 TIME -> 0:0:0
#
# RUN FOR RCP - 284
# 	SUCCESS
# LAP 285 TIME -> 0:0:0
#
# RUN FOR RSE - 285
# 	SUCCESS
# LAP 286 TIME -> 0:0:0
#
# RUN FOR ROR - 286
# 	SUCCESS
# LAP 287 TIME -> 0:0:2
#
# RUN FOR RMG - 287
# 	SUCCESS
# LAP 288 TIME -> 0:0:0
#
# RUN FOR SBRE - 288
# 	SUCCESS
# LAP 289 TIME -> 0:0:0
#
# RUN FOR SAFE - 289
# 	SUCCESS
# LAP 290 TIME -> 0:0:1
#
# RUN FOR SNN - 290
# 	SUCCESS
# LAP 291 TIME -> 0:0:0
#
# RUN FOR SVS - 291
# 	SUCCESS
# LAP 292 TIME -> 0:0:3
#
# RUN FOR SDP - 292
# 	SUCCESS
# LAP 293 TIME -> 0:0:1
#
# RUN FOR SOI - 293
# 	SUCCESS
# LAP 294 TIME -> 0:0:1
#
# RUN FOR SCIN - 294
# 	SUCCESS
# LAP 295 TIME -> 0:0:1
#
# RUN FOR SNR - 295
# 	SUCCESS
# LAP 296 TIME -> 0:0:3
#
# RUN FOR SEQI - 296
# 	SUCCESS
# LAP 297 TIME -> 0:0:0
#
# RUN FOR SRP - 297
# 	SUCCESS
# LAP 298 TIME -> 0:0:2
#
# RUN FOR SHB - 298
# 	SUCCESS
# LAP 299 TIME -> 0:0:2
#
# RUN FOR SHI - 299
# 	SUCCESS
# LAP 300 TIME -> 0:0:3
#
# RUN FOR SXX - 300
# 	SUCCESS
# LAP 301 TIME -> 0:0:2
#
# RUN FOR SRE - 301
# 	SUCCESS
# LAP 302 TIME -> 0:0:1
#
# RUN FOR SSON - 302
# 	SUCCESS
# LAP 303 TIME -> 0:0:0
#
# RUN FOR SCT - 303
# 	SUCCESS
# LAP 304 TIME -> 0:0:0
#
# RUN FOR SOPH - 304
# 	SUCCESS
# LAP 305 TIME -> 0:0:0
#
# RUN FOR SXS - 305
# 	SUCCESS
# LAP 306 TIME -> 0:0:3
#
# RUN FOR SPT - 306
# 	SUCCESS
# LAP 307 TIME -> 0:0:2
#
# RUN FOR SPD - 307
# 	SUCCESS
# LAP 308 TIME -> 0:0:1
#
# RUN FOR SSPG - 308
# 	SUCCESS
# LAP 309 TIME -> 0:0:0
#
# RUN FOR SMP - 309
# 	SUCCESS
# LAP 310 TIME -> 0:0:3
#
# RUN FOR SGC - 310
# 	SUCCESS
# LAP 311 TIME -> 0:0:2
#
# RUN FOR SYNC - 311
# 	SUCCESS
# LAP 312 TIME -> 0:0:0
#
# RUN FOR SYNT - 312
# 	SUCCESS
# LAP 313 TIME -> 0:0:3
#
# RUN FOR TALK - 313
# 	SUCCESS
# LAP 314 TIME -> 0:0:1
#
# RUN FOR TATE - 314
# 	SUCCESS
# LAP 315 TIME -> 0:0:2
#
# RUN FOR TBCG - 315
# 	SUCCESS
# LAP 316 TIME -> 0:0:0
#
# RUN FOR TEP - 316
# 	SUCCESS
# LAP 317 TIME -> 0:0:2
#
# RUN FOR TMPL - 317
# 	SUCCESS
# LAP 318 TIME -> 0:0:1
#
# RUN FOR TEM - 318
# 	SUCCESS
# LAP 319 TIME -> 0:0:1
#
# RUN FOR TIFS - 319
# 	SUCCESS
# LAP 320 TIME -> 0:0:0
#
# RUN FOR TCAP - 320
# 	SUCCESS
# LAP 321 TIME -> 0:0:2
#
# RUN FOR TRY - 321
# 	SUCCESS
# LAP 322 TIME -> 0:0:1
#
# RUN FOR TPK - 322
# 	SUCCESS
# LAP 323 TIME -> 0:0:2
#
# RUN FOR BBOX - 323
# 	SUCCESS
# LAP 324 TIME -> 0:0:0
#
# RUN FOR TLW - 324
# 	SUCCESS
# LAP 325 TIME -> 0:0:2
#
# RUN FOR UDG - 325
# 	SUCCESS
# LAP 326 TIME -> 0:0:2
#
# RUN FOR UKCM - 326
# 	SUCCESS
# LAP 327 TIME -> 0:0:1
#
# RUN FOR ULE - 327
# 	SUCCESS
# LAP 328 TIME -> 0:0:2
#
# RUN FOR UTG - 328
# 	SUCCESS
# LAP 329 TIME -> 0:0:0
#
# RUN FOR VSVS - 329
# 	SUCCESS
# LAP 330 TIME -> 0:0:2
#
# RUN FOR VCT - 330
# 	SUCCESS
# LAP 331 TIME -> 0:0:2
#
# RUN FOR VEIL - 331
# 	SUCCESS
# LAP 332 TIME -> 0:0:0
#
# RUN FOR VOF - 332
# 	SUCCESS
# LAP 333 TIME -> 0:0:1
#
# RUN FOR VVO - 333
# 	SUCCESS
# LAP 334 TIME -> 0:0:0
#
# RUN FOR WEIR - 334
# 	SUCCESS
# LAP 335 TIME -> 0:0:3
#
# RUN FOR JDW - 335
# 	SUCCESS
# LAP 336 TIME -> 0:0:3
#
# RUN FOR SMWH - 336
# 	SUCCESS
# LAP 337 TIME -> 0:0:1
#
# RUN FOR WMH - 337
# 	SUCCESS
# LAP 338 TIME -> 0:0:2
#
# RUN FOR WTAN - 338
# 	SUCCESS
# LAP 339 TIME -> 0:0:1
#
# RUN FOR WIZZ - 339
# 	SUCCESS
# LAP 340 TIME -> 0:0:0
#
# RUN FOR WG. - 340
# 	SUCCESS
# LAP 341 TIME -> 0:0:2
#
# RUN FOR WKP - 341
# 	SUCCESS
# LAP 342 TIME -> 0:0:2
#
# RUN FOR WWH - 342
# 	SUCCESS
# LAP 343 TIME -> 0:0:1
# TOTAL ELAPSED TIME -> 0:10:59
#
#
# COMPLETED - ERRORS ENCOUNTERED -> 0

# %%
#Get in-row price change
def calc_changes(df_in,var_col,prev_col):
    df_in["change"] = df_in[var_col] - df_in[prev_col]
    df_in["per_change"] = df_in["change"] / df_in[prev_col]
    return (df_in["change"],df_in["per_change"])

#Relabel col names
for col in df_prices_w:
    df_prices_w.rename(columns={col:col.lower()},inplace=True)
    
df_prices_w["change_price"],df_prices_w["per_change_price"] = calc_changes(df_prices_w[["close","open"]].copy(),"close","open")
df_prices_w.drop(columns=["change"],inplace=True)
df_prices_w.head()
# Out:
#   ticker       date    high     low     volume    open   close  ema12  ema26  \
# 0    3IN 2007-12-31  149.89  147.07  1373801.0  149.18  147.43    NaN    NaN
# 1    3IN 2008-01-07  149.54  147.07  2345191.0  147.07  148.83    NaN    NaN
# 2    3IN 2008-01-14  150.59  147.43  2150049.0  148.48  149.18    NaN    NaN
# 3    3IN 2008-01-21  154.82  145.32  3070968.0  147.78  152.00    NaN    NaN
# 4    3IN 2008-01-28  154.82  148.83  2510972.0  149.89  152.00    NaN    NaN
#
#    macd_line  signal_line  macd  change_price  per_change_price
# 0        NaN          NaN   NaN         -1.75         -0.011731
# 1        NaN          NaN   NaN          1.76          0.011967
# 2        NaN          NaN   NaN          0.70          0.004714
# 3        NaN          NaN   NaN          4.22          0.028556
# 4        NaN          NaN   NaN          2.11          0.014077

# %%
df_prices_w = df_prices_w.sort_values(['ticker','date'],ascending=[True,True])
df_prices_w.reset_index(inplace=True,drop=True)
print(df_prices_w.ticker.unique())
df_prices_w.head()
# Out:
# ['3IN' 'AAL' 'ABF' 'ADM' 'AGK' 'AGR' 'AHT' 'AJB' 'AML' 'ANTO' 'APAX'
#  'ASCL' 'ASHM' 'ASL' 'ATST' 'AUTO' 'AV.' 'AVST' 'AVV' 'AZN' 'BA.' 'BAB'
#  'BAG' 'BAKK' 'BARC' 'BATS' 'BBA' 'BBGI' 'BBOX' 'BBY' 'BCA' 'BDEV' 'BEZ'
#  'BGEO' 'BGFD' 'BGSC' 'BHP' 'BKG' 'BLND' 'BME' 'BNKR' 'BNZL' 'BOY' 'BP.'
#  'BRBY' 'BRSC' 'BRW' 'BVIC' 'BVS' 'BWY' 'BYG' 'CAPC' 'CARD' 'CBG' 'CCC'
#  'CCFS' 'CCH' 'CCL' 'CEY' 'CINE' 'CKN' 'CLDN' 'CLI' 'CNA' 'CNE' 'COA'
#  'COB' 'CPG' 'CPI' 'CRDA' 'CRH' 'CRST' 'CSP' 'CTEC' 'CTY' 'CWK' 'CYBG'
#  'DC.' 'DCC' 'DGE' 'DIGS' 'DJAN' 'DLG' 'DLN' 'DNLM' 'DOM' 'DPH' 'DPLM'
#  'DRX' 'ECM' 'EDIN' 'EIG' 'ELM' 'EMG' 'ENOG' 'EQN' 'ERM' 'ESNT' 'ETO'
#  'EVR' 'EXPN' 'EZJ' 'FCIT' 'FCSS' 'FDM' 'FERG' 'FEV' 'FGP' 'FGT' 'FOUR'
#  'FRES' 'FSFL' 'FSJ' 'FSV' 'FUTR' 'FXPO' 'GAW' 'GCP' 'GFRD' 'GFS' 'GFTU'
#  'GLEN' 'GLO' 'GNC' 'GNK' 'GNS' 'GOG' 'GPOR' 'GRG' 'GRI' 'GSK' 'GSS' 'GVC'
#  'HAS' 'HFG' 'HGT' 'HICL' 'HIK' 'HILS' 'HL.' 'HLMA' 'HMSO' 'HOC' 'HRI'
#  'HSBA' 'HSTG' 'HSV' 'HSX' 'HTG' 'HVPE' 'HWDN' 'IAG' 'IBST' 'ICP' 'IGG'
#  'IHG' 'IHP' 'III' 'IMB' 'IMI' 'INCH' 'INF' 'INPP' 'INVP' 'IPO' 'ISAT'
#  'ITRK' 'ITV' 'IWG' 'JAM' 'JD.' 'JDW' 'JE.' 'JEO' 'JFJ' 'JII' 'JLG' 'JMAT'
#  'JMG' 'JUP' 'KAZ' 'KGF' 'KNOS' 'LAND' 'LGEN' 'LLOY' 'LMP' 'LRE' 'LSE'
#  'LWDB' 'MAB' 'MARS' 'MCRO' 'MCS' 'MDC' 'MERL' 'MGAM' 'MGGT' 'MKS' 'MNDI'
#  'MNKS' 'MONY' 'MRC' 'MRO' 'MRW' 'MSLH' 'MYI' 'NBLS' 'NESF' 'NEX' 'NG.'
#  'NMC' 'NRR' 'NXT' 'OCDO' 'OSB' 'OXIG' 'PAG' 'PAGE' 'PAY' 'PCT' 'PETS'
#  'PFC' 'PFG' 'PHNX' 'PHP' 'PIN' 'PLI' 'PLP' 'PLUS' 'PMO' 'PNL' 'PNN'
#  'POLY' 'PPH' 'PRTC' 'PRU' 'PSH' 'PSN' 'PSON' 'PTEC' 'PZC' 'QLT' 'QQ.'
#  'RAT' 'RB.' 'RBS' 'RCP' 'RDSA' 'RDSB' 'RDW' 'REL' 'RHIM' 'RIO' 'RMG'
#  'RMV' 'RNK' 'ROR' 'RR.' 'RSA' 'RSE' 'RSW' 'RTN' 'RTO' 'SAFE' 'SBRE'
#  'SBRY' 'SCIN' 'SCT' 'SDP' 'SDR' 'SEQI' 'SGC' 'SGE' 'SGRO' 'SHB' 'SHI'
#  'SKG' 'SLA' 'SMDS' 'SMIN' 'SMP' 'SMT' 'SMWH' 'SN.' 'SNN' 'SNR' 'SOI'
#  'SOPH' 'SPD' 'SPT' 'SPX' 'SRE' 'SRP' 'SSE' 'SSON' 'SSPG' 'STAN' 'STJ'
#  'SVS' 'SVT' 'SXS' 'SXX' 'SYNC' 'SYNT' 'TALK' 'TATE' 'TBCG' 'TCAP' 'TEM'
#  'TEP' 'TIFS' 'TLW' 'TMPL' 'TPK' 'TRIG' 'TRY' 'TSCO' 'TUI' 'TW.' 'UDG'
#  'UKCM' 'UKW' 'ULE' 'ULVR' 'UTG' 'UU.' 'VCT' 'VEIL' 'VOD' 'VOF' 'VSVS'
#  'VVO' 'WEIR' 'WG.' 'WIZZ' 'WKP' 'WMH' 'WPP' 'WTAN' 'WTB' 'WWH']
#   ticker       date    high     low     volume    open   close  ema12  ema26  \
# 0    3IN 2007-12-31  149.89  147.07  1373801.0  149.18  147.43    NaN    NaN
# 1    3IN 2008-01-07  149.54  147.07  2345191.0  147.07  148.83    NaN    NaN
# 2    3IN 2008-01-14  150.59  147.43  2150049.0  148.48  149.18    NaN    NaN
# 3    3IN 2008-01-21  154.82  145.32  3070968.0  147.78  152.00    NaN    NaN
# 4    3IN 2008-01-28  154.82  148.83  2510972.0  149.89  152.00    NaN    NaN
#
#    macd_line  signal_line  macd  change_price  per_change_price
# 0        NaN          NaN   NaN         -1.75         -0.011731
# 1        NaN          NaN   NaN          1.76          0.011967
# 2        NaN          NaN   NaN          0.70          0.004714
# 3        NaN          NaN   NaN          4.22          0.028556
# 4        NaN          NaN   NaN          2.11          0.014077

# %% [markdown]
# # Create buy signals, and sell signals
# I am classifying a stock worth buying if it meets all the below criteria:
# - The target price (previous max) is hit within x (set as variable target_price_period) periods proceeding this period
# - The target price is an increase of x% (set as variable min_gain) over the proceeding day's open price
# - There is a drop in the closing price of less x% (set as variable max_drop) between this period and the x periods proceeding this period
#
# I am classifying the sell signals as:
# - The close price dips below the target price (previous max) x (set as variable target_price_period) periods proceeding this period
# - There is an increase in the closing price of less x% (set as variable max_drop) over the next x periods

# %%
#Define the variables
target_price_period = 12
period_high_volatility = 3
period_low_volatility = 1
min_gain = 0.1
max_drop = -0.05

# %%
#Programming note
#df.shift(1) looks 1 period into the past
#df.shift(-1) looks 1 period into the future

# %%
#Check if the target price is hit within the target_price_period
def min_gain_check(_var_s,_target_s,_periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,_periods+1):
        _tmp_check_s = _var_s.shift(-_i) > _target_s #True if price is >= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def max_drop_check(_var_s,_target_s,periods:int=12):
    _check_s = [False] * _var_s.shape[0]
    for _i in range(1,periods+1):
        _tmp_check_s = _var_s.shift(-_i) < _target_s #True if price is <= limit
        _check_s = _check_s | _tmp_check_s
    return _check_s

# %%
def close_vs_close(_var_s,_shift:int=1):
    _check_s = _var_s.shift(_shift) - _var_s
    return _check_s

# %%
#Create a function for finding buy signals
def get_buys(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == True #Function returns True when min_gain is hit
    print('BUY min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the sell price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == False #Function returns False when does not go below target
    print('BUY max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Check if the following day is a positive change on today's close price
    close_vs_close_pos_s = close_vs_close(var_s,-1) > 0
    print('BUY close_vs_close_pos_s -> {}'.format(close_vs_close_pos_s[max_drop_s == True].shape))
    
    #Find the buy signals
    s_out = min_gain_s & max_drop_s & close_vs_close_pos_s
    print('BUY ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Function for finding sell signals
def get_sells(var_s):
    
    #Check if the target price is hit within the target_price_period
    target_s = var_s * (1+max_drop)
    max_drop_s = max_drop_check(var_s,target_s,target_price_period) == True #Function returns True when max_drop is hit
    print('SELL max_drop_s -> {}'.format(max_drop_s[max_drop_s == True].shape))
    
    #Perform if the target is crossed again
    target_s = var_s * (1+min_gain)
    min_gain_s = min_gain_check(var_s,target_s,target_price_period) == False #Function returns False when min_gain is not hit
    print('SELL min_gain_s -> {}'.format(min_gain_s[min_gain_s == True].shape))
    
    #Check if the following day is a negative change on today's close price
    close_vs_close_neg_s = close_vs_close(var_s,-1) < 0
    print('SELL close_vs_close_pos_s -> {}'.format(close_vs_close_neg_s[max_drop_s == True].shape))
    
    #Find the sell signals
    s_out = max_drop_s & min_gain_s & close_vs_close_neg_s
    print('SELL ALL -> {}'.format(s_out[s_out == True].shape))
    
    return s_out

# %%
#Get buy signals
df_prices_w['buy'] = get_buys(df_prices_w['close'])

#Get sell signals
df_prices_w['sell'] = get_sells(df_prices_w['close'])

#Get hold signals
df_prices_w["hold"] = (df_prices_w["buy"] == False) & (df_prices_w["sell"] == False)

print('BUY PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['buy'] == True].shape[0]*100/df_prices_w.shape[0]))
print('SELL PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['sell'] == True].shape[0]*100/df_prices_w.shape[0]))
print('HOLD PERCENTAGE -> {:.2f}%'.format(df_prices_w[df_prices_w['hold'] == True].shape[0]*100/df_prices_w.shape[0]))
# Out:
# BUY min_gain_s -> (107516,)
# BUY max_drop_s -> (141432,)
# BUY close_vs_close_pos_s -> (141432,)
# BUY ALL -> (59397,)
# SELL max_drop_s -> (134117,)
# SELL min_gain_s -> (168033,)
# SELL close_vs_close_pos_s -> (134117,)
# SELL ALL -> (69571,)
# BUY PERCENTAGE -> 21.56%
# SELL PERCENTAGE -> 25.25%
# HOLD PERCENTAGE -> 53.20%

# %%
df_prices_w[df_prices_w.ticker=='SBRY'].iloc[-5:]
# Out:
#        ticker       date   high     low      volume   open  close       ema12  \
# 210943   SBRY 2019-09-23  222.8  212.31  45313711.0  218.9  222.5  207.077519
# 210944   SBRY 2019-09-30  223.1  219.80  15534699.0  219.8  222.1  209.388670
# 210945   SBRY 2019-09-30  223.1  219.80  15534699.0  219.8  219.8  210.990413
# 210946   SBRY 2019-09-30  223.1  219.80  15534699.0  221.9  222.1  212.699580
# 210947   SBRY 2019-09-30  223.1  219.80  15534699.0  221.9  219.8  213.791953
#
#              ema26  macd_line  signal_line      macd  change_price  \
# 210943  213.667923  -6.590404   -12.409913  5.819509           3.6
# 210944  214.292521  -4.903851   -10.908701  6.004849           2.3
# 210945  214.700483  -3.710070    -9.468974  5.758905           0.0
# 210946  215.248595  -2.549015    -8.084983  5.535968           0.2
# 210947  215.585736  -1.793784    -6.826743  5.032959          -2.1
#
#         per_change_price    buy   sell   hold
# 210943          0.016446  False  False   True
# 210944          0.010464  False  False   True
# 210945          0.000000   True  False  False
# 210946          0.000901  False  False   True
# 210947         -0.009464   True  False  False

# %% [markdown]
# # Create additional features

# %%
#Mark minimums and maximums
def flag_mins(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in > s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value > the previous value
        s_out += (s_in > s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value > the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out
def flag_maxs(s_in,period):
    s_out = 0
    for i in range(1,period):
        s_out += (s_in < s_in.shift(i)) & (s_in.shift(-i).isnull() == False) #Is this value < the previous value (if the previous value is not null)
        s_out += (s_in < s_in.shift(-i)) | (s_in.shift(-i).isnull()) #Is this value < the next value OR is it the last available value (IE the next value is null)
        s_out += s_in.isnull()
#     s_out[((s_in.index == 0) & (s_in.isnull() == False)) | ((s_in.shift(1).isnull()) & (s_in.isnull() == False))] = 0 #set the first non-NaN result to 0
    s_out = s_out == 0
    return s_out

# %%
#Calc vol as proportion of previous n-rows
def calc_prop_of_prev(s_in,periods:int = 4):
    s_cum = s_in.copy()
    for i in range(1,periods):
        s_cum += s_in.shift(i)
    return s_in / s_cum

# %%
#Mark points of macd positive entry
def pos_entry(s_in):
    return (s_in > s_in.shift(1)) & (s_in > 0) & (s_in.shift(1) < 0)
def neg_entry(s_in):
    return (s_in < s_in.shift(1)) & (s_in < 0) & (s_in.shift(1) > 0)

# %%
#Function to normalise current price compared to another
def norm_s(s_in,max_in,min_in):
    s_out = (s_in - min_in) / (max_in - min_in)
    s_out.fillna(1.0,inplace=True)
    return s_out

# %%
#Function to find last max and mins
def prev_value(df_in,var_col,bool_col):
    df_in["prev_val"] = df_in.loc[df_in[bool_col],var_col]
    df_in["prev_val"] = df_in["prev_val"].fillna(method='ffill')
    df_in["prev_marker_date"] = df_in.loc[df_in[bool_col],"date"]
    df_in["prev_marker_date"] = df_in["prev_marker_date"].fillna(method='ffill')
    return (df_in["prev_val"],df_in["prev_marker_date"])

# %%
#Create separate columns for pos and neg values - allows for normalisation
def pos_neg_cols(s_in,gt_lt = "GT"):
    if gt_lt.upper() == "GT":
        bool_s = s_in >= 0
    elif gt_lt.upper() == "LT":
        bool_s = s_in <= 0
    df_out = s_in.to_frame()
    df_out["s_in"] = s_in
    df_out["val"] = abs(s_in[bool_s])
    val_s = df_out["val"].fillna(0,method=None)
    return (bool_s,val_s)

# %%
#Function for calculating the max and mins within a period
def max_min_period(s_in,periods:int=4):
    #Copy into max and min
    max_s = s_in.copy()
    min_s = s_in.copy()
    #Go through periods and mark where it is a new max or min
    for i in range(1,(periods+1)):
        #Calc max
        tmp_check_s = s_in.shift(i) >= max_s
        max_s[tmp_check_s] = s_in.shift(i)
        #Calc min
        tmp_check_s = s_in.shift(i) <= min_s
        min_s[tmp_check_s] = s_in.shift(i)
    #Normalise the series
    s_out = norm_s(s_in,max_s,min_s)
    return s_out

# %%
#Create a dictionary of max character lengths of fields for use later in h5 file appending
def get_col_lens(_df_in):
    _col_lens = {}
    for c in _df_in:
        _tmp_s = pd.Series([len(str(x)) for x in _df_in[c]])
        _col_lens[c] = _tmp_s.max()
    return _col_lens
col_lens = get_col_lens(df_prices_w)
col_lens
# Out:
# {'ticker': 4,
#  'date': 19,
#  'high': 8,
#  'low': 8,
#  'volume': 13,
#  'open': 8,
#  'close': 8,
#  'ema12': 18,
#  'ema26': 18,
#  'macd_line': 23,
#  'signal_line': 23,
#  'macd': 23,
#  'change_price': 21,
#  'per_change_price': 23,
#  'buy': 5,
#  'sell': 5,
#  'hold': 5}

# %%
#Create a single function to run each stock through feature creation
def create_features(df_in):  
    
    df_out = df_in.copy() 
    
    #Calc vol as proportion of previous n-rows
    df_out["prop_vol"] = calc_prop_of_prev(df_out["volume"].copy().astype("float"),6)

    #Get period-period changes
    df_out["close_shift1"] = df_out["close"].shift(1)
    df_out["change_close_shift1"],df_out["per_change_close_shift1"] = calc_changes(df_out[["close","close_shift1"]].copy(),"close","close_shift1")

    df_out["vol_shift1"] = df_out["volume"].shift(1)
    df_out["change_vol_shift1"],df_out["per_change_vol_shift1"] = calc_changes(df_out[["volume","vol_shift1"]].copy(),"volume","vol_shift1")

    df_out["macd_shift1"] = df_out["macd"].shift(1)
    df_out["change_macd_shift1"],df_out["per_change_macd_shift1"] = calc_changes(df_out[["macd","vol_shift1"]].copy(),"macd","vol_shift1")

    df_out["ema26_shift1"] = df_out["ema26"].shift(1)
    df_out["change_ema26_shift1"],df_out["per_change_ema26_shift1"] = calc_changes(df_out[["ema26","ema26_shift1"]].copy(),"ema26","ema26_shift1")
    
    #Compare close to the max/mins within 13, 26 and 52 periods
    df_out["close_13_norm"] = max_min_period(df_out["close"],13)
    df_out["close_26_norm"] = max_min_period(df_out["close"],26)
    df_out["close_52_norm"] = max_min_period(df_out["close"],52)
    
    #Compare macd to the max/mins within 13, 26 and 52 periods
    df_out["macd_line_13_norm"] = max_min_period(df_out["macd_line"],13)
    df_out["macd_line_26_norm"] = max_min_period(df_out["macd_line"],26)
    df_out["macd_line_52_norm"] = max_min_period(df_out["macd_line"],52)
        
    #Mark points of macd positive entry
    df_out["macd_pos_ent"] = pos_entry(df_out["macd"])
    df_out["macd_neg_ent"] = neg_entry(df_out["macd"])
    
    #Create separate columns for pos and neg values - allows for normalisation
    df_out["macd_pos_bool"],df_out["macd_pos_val"] = pos_neg_cols(df_out["macd"],gt_lt = "GT")
    df_out["macd_neg_bool"],df_out["macd_neg_val"] = pos_neg_cols(df_out["macd"],gt_lt = "LT")
    df_out["signal_line_pos_bool"],df_out["signal_line_pos_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "GT")
    df_out["signal_line_neg_bool"],df_out["signal_line_neg_val"] = pos_neg_cols(df_out["signal_line"],gt_lt = "LT")
    df_out["change_price_pos_bool"],df_out["change_price_pos_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "GT")
    df_out["change_price_neg_bool"],df_out["change_price_neg_val"] = pos_neg_cols(df_out["change_price"],gt_lt = "LT")
    df_out["per_change_price_pos_bool"],df_out["per_change_price_pos_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "GT")
    df_out["per_change_price_neg_bool"],df_out["per_change_price_neg_val"] = pos_neg_cols(df_out["per_change_price"],gt_lt = "LT")

    #Create max min columns
    def mk_cols_max_min(tmp_df,col,period:int=4):
        tmp_df["{}_min".format(col)] = flag_mins(tmp_df[col],period)
        tmp_df["{}_max".format(col)] = flag_maxs(tmp_df[col],period)
        
    #Find previous max and mins, then look at:
        # - how many positive or negative moves in a row there has been
        # - what the move since the last (n-1) max/min was
        # - what the gradient is since the last (n-1) max/min
        # - what the move since the first max/min was
        # - what the gradient since the first max/min was
    def mk_cols_prev_max_min(tmp_df,col,period:int=4):
        #GETTING THE MAX/MINS
        tmp_df["prev_max_{}".format(col)],tmp_df["prev_max_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_max".format(col)]].copy(),col,"{}_max".format(col))
        tmp_df["prev_min_{}".format(col)],tmp_df["prev_min_{}_date".format(col)] = prev_value(tmp_df[["date",col,"{}_min".format(col)]].copy(),col,"{}_min".format(col))
        #Shift the max min columns by n periods to not leak future information
        tmp_df["prev_max_{}".format(col)] = tmp_df["prev_max_{}".format(col)].shift(period)
        tmp_df["prev_min_{}".format(col)] = tmp_df["prev_min_{}".format(col)].shift(period)
        tmp_df["prev_max_{}_date".format(col)] = tmp_df["prev_max_{}_date".format(col)].shift(period)
        tmp_df["prev_min_{}_date".format(col)] = tmp_df["prev_min_{}_date".format(col)].shift(period)
        def mk_prev_move_float(_s_in):
            _s_out = _s_in - _s_in.shift(1)
            _s_out[_s_out == 0] = np.nan
            _s_out = _s_out.fillna(method='ffill')
            return _s_out
        def mk_prev_move_date(_s_in,_periods:int=7):
            _s_out = _s_in - _s_in.shift(1)
            _s_check = pd.Series([np.floor(_x.days) for _x in _s_out])
            _s_check[_s_check == 0] = np.nan
            _s_check = _s_check.fillna(method='ffill')
            _s_check = [np.floor(_x/_periods) for _x in _s_check]
            return _s_check
        #Create features for the cumulative sequential count of max/mins in a certain direction
        def mk_move_cum(_s_in,_gtlt:str='pos'):
            _li_out = []
            _prev_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _s_in.iteritems():
                    if _x < 0: #If less than 0 then reset to 0
                        _li_out.append(0)
                    else:
                        if len(_li_out) == 0: #If this is the first value add it to the list
                            _li_out.append(1)
                        else:
                            if _prev_x != _x: #if there has been a change in value from this and the previous value increment it by 1
                                _li_out.append(_li_out[-1] + 1)
                            else: #Otherwise just use the last added value
                                _li_out.append(_li_out[-1])
                    _prev_x = _x
            elif _gtlt.lower() == 'neg':
                for _i,_x in _s_in.iteritems():
                    if _x > 0:
                        _li_out.append(0)
                    else:
                        if len(_li_out) == 0:
                            _li_out.append(1)
                        else:
                            if _prev_x != _x:
                                _li_out.append(_li_out[-1] + 1)
                            else:
                                _li_out.append(_li_out[-1])
                    _prev_x = _x
            return _li_out
        #Create features showing the value change since the first min/max
        def mk_long_prev_move_float(_ref_s,_val_s,_gtlt:str='pos'):
            _li_out = []
            _st_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x < 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
            elif _gtlt.lower() == 'neg':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x > 0: #If greater than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(_val_s[_i] - _st_x) #Now calculate the difference and add it to the list
            return _li_out
        def mk_long_prev_move_date(_ref_s,_val_s,_gtlt:str='pos',_periods:int=7):
            _li_out = []
            _st_x = None
            #Check which direction we are looking for
            if _gtlt.lower() == 'pos':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x < 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
            elif _gtlt.lower() == 'neg':
                #Loop through each value in _s_in
                for _i,_x in _ref_s.iteritems():
                    if _x > 0: #If less than 0 then reset to 0, and reset _st_x
                        _li_out.append(0)
                        _st_x = None
                    else:
                        if _st_x == None: #If _st_x has not been set yet set it to this value
                            _st_x = _val_s[_i]
                        _li_out.append(np.floor((_val_s[_i] - _st_x).days/_periods)) #Now calculate the difference and add it to the list
            return _li_out
        #WHAT WAS THE MOVE SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_max_{}".format(col)])
        tmp_df['prev_max_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_max_{}_date".format(col)])        
        tmp_df['prev_min_move_{}'.format(col)] = mk_prev_move_float(tmp_df["prev_min_{}".format(col)])
        tmp_df['prev_min_date_move_{}'.format(col)] = mk_prev_move_date(tmp_df["prev_min_{}_date".format(col)])
        #WHAT IS THE GRADIENT SINCE THE LAST (N-1) MAX/MIN
        tmp_df['prev_max_grad_{}'.format(col)] = tmp_df['prev_max_move_{}'.format(col)] / tmp_df['prev_max_date_move_{}'.format(col)]
        tmp_df['prev_min_grad_{}'.format(col)] = tmp_df['prev_min_move_{}'.format(col)] / tmp_df['prev_min_date_move_{}'.format(col)]
        #HOW MANY PROGRESSIVE MAX/MINS IN A ROW HAVE THERE BEEN - UP OR DOWN FOR BOTH OPTIONS
        tmp_df['max_move_cum_pos_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)],'pos')
        tmp_df['max_move_cum_neg_{}'.format(col)] = mk_move_cum(tmp_df['prev_max_move_{}'.format(col)],'neg')
        tmp_df['min_move_cum_pos_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)],'pos')
        tmp_df['min_move_cum_neg_{}'.format(col)] = mk_move_cum(tmp_df['prev_min_move_{}'.format(col)],'neg')
        #WHAT WAS THE MOVE SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_pos_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)],'pos')
        tmp_df['long_prev_max_move_neg_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}'.format(col)],'neg')
        tmp_df['long_prev_min_move_pos_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)],'pos')
        tmp_df['long_prev_min_move_neg_{}'.format(col)] = mk_long_prev_move_float(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}'.format(col)],'neg')
        #WHAT WAS THE TIMEDELTA SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_prev_max_move_pos_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)],'pos')
        tmp_df['long_prev_max_move_neg_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_max_move_{}'.format(col)],tmp_df['prev_max_{}_date'.format(col)],'neg')
        tmp_df['long_prev_min_move_pos_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)],'pos')
        tmp_df['long_prev_min_move_neg_date_{}'.format(col)] = mk_long_prev_move_date(tmp_df['prev_min_move_{}'.format(col)],tmp_df['prev_min_{}_date'.format(col)],'neg')
        #WHAT IS THE GRADIENT SINCE THE FIRST (N=0) MAX/MIN
        tmp_df['long_max_grad_pos_{}'.format(col)] = tmp_df['long_prev_max_move_pos_{}'.format(col)] / tmp_df['long_prev_max_move_pos_date_{}'.format(col)]
        tmp_df['long_max_grad_pos_{}'.format(col)] = tmp_df['long_max_grad_pos_{}'.format(col)].fillna(0)
        tmp_df['long_max_grad_neg_{}'.format(col)] = tmp_df['long_prev_max_move_neg_{}'.format(col)] / tmp_df['long_prev_max_move_neg_date_{}'.format(col)]
        tmp_df['long_max_grad_neg_{}'.format(col)] = tmp_df['long_max_grad_neg_{}'.format(col)].fillna(0)
        tmp_df['long_min_grad_pos_{}'.format(col)] = tmp_df['long_prev_min_move_pos_{}'.format(col)] / tmp_df['long_prev_min_move_pos_date_{}'.format(col)]
        tmp_df['long_min_grad_pos_{}'.format(col)] = tmp_df['long_min_grad_pos_{}'.format(col)].fillna(0)
        tmp_df['long_min_grad_neg_{}'.format(col)] = tmp_df['long_prev_min_move_neg_{}'.format(col)] / tmp_df['long_prev_min_move_neg_date_{}'.format(col)]
        tmp_df['long_min_grad_neg_{}'.format(col)] = tmp_df['long_min_grad_neg_{}'.format(col)].fillna(0)
    
    #Calc the value changes and percentage changes of these movements
    def mk_cols_prev_max_min_change(tmp_df,col):
        tmp_df["max_change_{}".format(col)],tmp_df["max_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_max_{}".format(col)]].copy(),col,"prev_max_{}".format(col))
        tmp_df["min_change_{}".format(col)],tmp_df["min_per_change_{}".format(col)] = calc_changes(tmp_df[[col,"prev_min_{}".format(col)]].copy(),col,"prev_min_{}".format(col))
        
    #Mark date change since max and mins and convert to periods
    def mk_cols_prev_max_min_date_change(tmp_df,col,period:int=7):
        tmp_df["prev_max_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_max_{}_date".format(col)]
        tmp_df["prev_min_{}_date_change".format(col)] = tmp_df["date"] - tmp_df["prev_min_{}_date".format(col)]
        #Convert all to period changes
        tmp_df["prev_max_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_max_{}_date_change".format(col)]]
        tmp_df["prev_min_{}_date_change".format(col)] = [np.floor(x.days/period) for x in tmp_df["prev_min_{}_date_change".format(col)]]
    
    #Convert the max min changes into pos and neg columns
    def mk_cols_prev_max_min_change_pos_neg(tmp_df,col):
        #Only do pos changes for mins and neg changes for max (as it can only go below the max and above the min)
        tmp_df["max_change_{}_pos_bool".format(col)],tmp_df["max_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "GT")
        tmp_df["max_change_{}_neg_bool".format(col)],tmp_df["max_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["max_change_{}".format(col)],gt_lt = "LT")
        tmp_df["min_change_{}_pos_bool".format(col)],tmp_df["min_change_{}_pos_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "GT")
        tmp_df["min_change_{}_neg_bool".format(col)],tmp_df["min_change_{}_neg_val".format(col)] = pos_neg_cols(tmp_df["min_change_{}".format(col)],gt_lt = "LT")
        #Drop the old columns
        tmp_df.drop(columns=["max_change_{}".format(col),"min_change_{}".format(col)],inplace=True)

    #Run function for columns - high volatility
    for col in ['close','signal_line']:
        mk_cols_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min(df_out,col,period_high_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    #Run function for columns - low volatility
    for col in ['macd','ema26','macd_line']:
        mk_cols_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min(df_out,col,period_low_volatility)
        mk_cols_prev_max_min_change(df_out,col) 
        mk_cols_prev_max_min_date_change(df_out,col,7)
        mk_cols_prev_max_min_change_pos_neg(df_out,col)
    
    #Check for undefined
    df_out["no_signal"] = (df_out["buy"] == False) & (df_out["hold"] == False) & (df_out["sell"] == False)
    
    #Composite all singals into one column
    df_out["signal"] = None
    df_out.loc[df_out["buy"] == True,"signal"] = "buy"
    df_out.loc[df_out["hold"] == True,"signal"] = "hold"
    df_out.loc[df_out["sell"] == True,"signal"] = "sell"
    df_out.drop(columns=["buy","hold","sell"],inplace=True)
    print("SIGNAL COUNTS: \n{}".format(df_out["signal"].value_counts()))
    
    return df_out

# %%
#Define the columns for the output
out_cols = [
    #NON-NORMALISED COLS
    "ticker"
    ,"date"
    #NORMALISED COLS
    #Standard features
    ,"open"
    ,"close"
    ,"high"
    ,"low"
    ,"volume"
    ,"change_price"
    ,"per_change_price"
    #Shifted features
    ,"close_shift1"
    ,"change_close_shift1"
    ,"vol_shift1"
    ,"change_vol_shift1"
    ,"ema26_shift1"
    ,"change_ema26_shift1"
    #change to periodic max mins
    ,"close_13_norm"
    ,"close_26_norm"
    ,"close_52_norm"
    ,"macd_line_13_norm"
    ,"macd_line_26_norm"
    ,"macd_line_52_norm"
    #Pos neg features
    ,"macd_pos_val"
    ,"macd_neg_val"
    ,"signal_line_pos_val"
    ,"signal_line_neg_val"
    ,"change_price_pos_val"
    ,"change_price_neg_val"
    ,"per_change_price_pos_val"
    ,"per_change_price_neg_val"
]
#Append additional columns for key areas
for col in ['close','macd','ema26','signal_line','macd_line']:
    out_cols
    #Prev max/min features
    out_cols.append("prev_max_{}".format(col))
    out_cols.append("prev_min_{}".format(col))
    #date changes
    out_cols.append("prev_max_{}_date_change".format(col))
    out_cols.append("prev_min_{}_date_change".format(col))
    #Min max change features
    out_cols.append("max_change_{}_pos_val".format(col))
    out_cols.append("max_change_{}_neg_val".format(col))
    out_cols.append("min_change_{}_pos_val".format(col))
    out_cols.append("min_change_{}_neg_val".format(col))
    #prev max/mins (n-1) - compared to previous
    out_cols.append('prev_max_grad_{}'.format(col))
    out_cols.append('prev_min_grad_{}'.format(col))
    #prev max/mins (n=0) - compared to first in this run
    out_cols.append('max_move_cum_pos_{}'.format(col))
    out_cols.append('max_move_cum_neg_{}'.format(col))
    out_cols.append('min_move_cum_pos_{}'.format(col))
    out_cols.append('min_move_cum_neg_{}'.format(col))
    out_cols.append('long_prev_max_move_pos_date_{}'.format(col))
    out_cols.append('long_prev_max_move_neg_date_{}'.format(col))
    out_cols.append('long_prev_min_move_pos_date_{}'.format(col))
    out_cols.append('long_prev_min_move_neg_date_{}'.format(col))
    out_cols.append('long_max_grad_pos_{}'.format(col))
    out_cols.append('long_max_grad_neg_{}'.format(col))
    out_cols.append('long_min_grad_pos_{}'.format(col))
    out_cols.append('long_min_grad_neg_{}'.format(col))
#Append signal
out_cols.append("signal")

# %%
#Then loop the tickers and combine these into one large dataset
hf_store_name = path+r'\all_hist_prices_w_ft_eng2_TMP.h5'
h_store = pd.HDFStore(hf_store_name)
count = 0
errors = []
run_time = process_time()
for tick in tick_ftse["ticker"]:
    try:
        run_time.show_latest_lap_time()
        run_time.lap()
        count += 1
        print("\n{}".format(count))
        print("RUN FOR {}".format(tick))
        #Isolate this ticker
        this_tick_df = df_prices_w[df_prices_w["ticker"] == re.sub('[^a-zA-Z0-9\-]','',tick)].copy()
        print("shape before: {}".format(this_tick_df.shape))
        #Create the features
        this_tick_df = create_features(this_tick_df)
#         print(this_tick_df[out_cols])
        #Clarify col_lens with cur cols in data
        col_lens_tmp = {}
        for col in out_cols:
            if col in col_lens:
                col_lens_tmp[col] = col_lens[col]
        print("shape after: {}".format(this_tick_df.shape))
        #Append this data to the group
        try:
            this_tick_df[out_cols].to_hdf(hf_store_name,key='weekly_data',append=True,min_itemsize=col_lens_tmp)
            print('ADDED TO {}'.format(hf_store_name))
        except Exception as e:
            print('ERROR READING TO FILE {}'.format(e))
    except Exception as e:
        h_store.close()
        errors.append({"ticker":tick,"Error":e})
        print('ERROR PROCESSING DATA {}'.format(e))
h_store.close()
print('\n\n')
run_time.end()
print('\nERROR COUNT: {}'.format(len(errors)))
if len(errors) > 0:
    print('    ERRORS -> {}'.format(errors))
# Out:
# 1
# RUN FOR III
# shape before: (613, 17)
# SIGNAL COUNTS:
# hold    314
# sell    165
# buy     134
# Name: signal, dtype: int64
# shape after: (613, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 1 TIME -> 0:0:0
#
# 2
# RUN FOR ABF
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    584
# sell    255
# buy     206
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 2 TIME -> 0:0:3
#
# 3
# RUN FOR ADM
# shape before: (353, 17)
# SIGNAL COUNTS:
# hold    194
# buy      99
# sell     60
# Name: signal, dtype: int64
# shape after: (353, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 3 TIME -> 0:0:3
#
# 4
# RUN FOR AAL
# shape before: (1008, 17)
# SIGNAL COUNTS:
# hold    455
# sell    290
# buy     263
# Name: signal, dtype: int64
# shape after: (1008, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 4 TIME -> 0:0:2
#
# 5
# RUN FOR ANTO
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    458
# buy     300
# sell    287
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 5 TIME -> 0:0:3
#
# 6
# RUN FOR AHT
# shape before: (1023, 17)
# SIGNAL COUNTS:
# hold    479
# buy     300
# sell    244
# Name: signal, dtype: int64
# shape after: (1023, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 6 TIME -> 0:0:3
#
# 7
# RUN FOR AZN
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    557
# sell    287
# buy     201
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 7 TIME -> 0:0:3
#
# 8
# RUN FOR AUTO
# shape before: (238, 17)
# SIGNAL COUNTS:
# hold    114
# sell     67
# buy      57
# Name: signal, dtype: int64
# shape after: (238, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 8 TIME -> 0:0:3
#
# 9
# RUN FOR AVV
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    518
# buy     306
# sell    221
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 9 TIME -> 0:0:2
#
# 10
# RUN FOR AV.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 10 TIME -> 0:0:3
#
# 11
# RUN FOR BA.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 11 TIME -> 0:0:1
#
# 12
# RUN FOR BARC
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    510
# sell    346
# buy     189
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 12 TIME -> 0:0:1
#
# 13
# RUN FOR BDEV
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    459
# buy     299
# sell    287
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 13 TIME -> 0:0:3
#
# 14
# RUN FOR BKG
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    515
# buy     280
# sell    250
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 14 TIME -> 0:0:3
#
# 15
# RUN FOR BHP
# shape before: (524, 17)
# SIGNAL COUNTS:
# hold    244
# buy     153
# sell    127
# Name: signal, dtype: int64
# shape after: (524, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 15 TIME -> 0:0:3
#
# 16
# RUN FOR BP.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 16 TIME -> 0:0:3
#
# 17
# RUN FOR BATS
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    590
# sell    237
# buy     218
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 17 TIME -> 0:0:1
#
# 18
# RUN FOR BLND
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    573
# sell    277
# buy     195
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 18 TIME -> 0:0:3
#
# 19
# RUN FOR BNZL
# shape before: (1042, 17)
# SIGNAL COUNTS:
# hold    615
# sell    237
# buy     190
# Name: signal, dtype: int64
# shape after: (1042, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 19 TIME -> 0:0:3
#
# 20
# RUN FOR BRBY
# shape before: (900, 17)
# SIGNAL COUNTS:
# hold    435
# buy     245
# sell    220
# Name: signal, dtype: int64
# shape after: (900, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 20 TIME -> 0:0:3
#
# 21
# RUN FOR CCL
# shape before: (989, 17)
# SIGNAL COUNTS:
# hold    466
# sell    278
# buy     245
# Name: signal, dtype: int64
# shape after: (989, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 21 TIME -> 0:0:3
#
# 22
# RUN FOR CNA
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    570
# sell    336
# buy     139
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 22 TIME -> 0:0:3
#
# 23
# RUN FOR CCH
# shape before: (336, 17)
# SIGNAL COUNTS:
# hold    172
# sell     95
# buy      69
# Name: signal, dtype: int64
# shape after: (336, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 23 TIME -> 0:0:3
#
# 24
# RUN FOR CPG
# shape before: (1031, 17)
# SIGNAL COUNTS:
# hold    577
# sell    246
# buy     208
# Name: signal, dtype: int64
# shape after: (1031, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 24 TIME -> 0:0:2
#
# 25
# RUN FOR CRH
# shape before: (1031, 17)
# SIGNAL COUNTS:
# hold    512
# sell    294
# buy     225
# Name: signal, dtype: int64
# shape after: (1031, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 25 TIME -> 0:0:3
#
# 26
# RUN FOR CRDA
# shape before: (1037, 17)
# SIGNAL COUNTS:
# hold    548
# buy     250
# sell    239
# Name: signal, dtype: int64
# shape after: (1037, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 26 TIME -> 0:0:3
#
# 27
# RUN FOR DCC
# shape before: (1027, 17)
# SIGNAL COUNTS:
# hold    543
# buy     250
# sell    234
# Name: signal, dtype: int64
# shape after: (1027, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 27 TIME -> 0:0:3
#
# 28
# RUN FOR DGE
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    693
# sell    215
# buy     137
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 28 TIME -> 0:0:4
#
# 29
# RUN FOR EVR
# shape before: (414, 17)
# SIGNAL COUNTS:
# hold    187
# sell    118
# buy     109
# Name: signal, dtype: int64
# shape after: (414, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 29 TIME -> 0:0:4
#
# 30
# RUN FOR EXPN
# shape before: (678, 17)
# SIGNAL COUNTS:
# hold    376
# sell    160
# buy     142
# Name: signal, dtype: int64
# shape after: (678, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 30 TIME -> 0:0:3
#
# 31
# RUN FOR FERG
# shape before: (1046, 17)
# SIGNAL COUNTS:
# hold    564
# sell    266
# buy     216
# Name: signal, dtype: int64
# shape after: (1046, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 31 TIME -> 0:0:3
#
# 32
# RUN FOR FRES
# shape before: (596, 17)
# SIGNAL COUNTS:
# hold    281
# sell    189
# buy     126
# Name: signal, dtype: int64
# shape after: (596, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 32 TIME -> 0:0:4
#
# 33
# RUN FOR GSK
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    613
# sell    296
# buy     136
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 33 TIME -> 0:0:2
#
# 34
# RUN FOR GLEN
# shape before: (438, 17)
# SIGNAL COUNTS:
# hold    187
# sell    153
# buy      98
# Name: signal, dtype: int64
# shape after: (438, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 34 TIME -> 0:0:3
#
# 35
# RUN FOR HLMA
# shape before: (1013, 17)
# SIGNAL COUNTS:
# hold    550
# buy     234
# sell    229
# Name: signal, dtype: int64
# shape after: (1013, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 35 TIME -> 0:0:2
#
# 36
# RUN FOR HL.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 36 TIME -> 0:0:3
#
# 37
# RUN FOR HIK
# shape before: (708, 17)
# SIGNAL COUNTS:
# hold    327
# buy     201
# sell    180
# Name: signal, dtype: int64
# shape after: (708, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 37 TIME -> 0:0:1
#
# 38
# RUN FOR HSX
# shape before: (1012, 17)
# SIGNAL COUNTS:
# hold    538
# sell    237
# buy     237
# Name: signal, dtype: int64
# shape after: (1012, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 38 TIME -> 0:0:3
#
# 39
# RUN FOR HSBA
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    693
# sell    338
# buy     225
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 39 TIME -> 0:0:3
#
# 40
# RUN FOR IMB
# shape before: (1180, 17)
# SIGNAL COUNTS:
# hold    641
# sell    289
# buy     250
# Name: signal, dtype: int64
# shape after: (1180, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 40 TIME -> 0:0:3
#
# 41
# RUN FOR INF
# shape before: (1066, 17)
# SIGNAL COUNTS:
# hold    549
# sell    275
# buy     242
# Name: signal, dtype: int64
# shape after: (1066, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 41 TIME -> 0:0:3
#
# 42
# RUN FOR IHG
# shape before: (844, 17)
# SIGNAL COUNTS:
# hold    435
# sell    210
# buy     199
# Name: signal, dtype: int64
# shape after: (844, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 42 TIME -> 0:0:3
#
# 43
# RUN FOR ITRK
# shape before: (884, 17)
# SIGNAL COUNTS:
# hold    455
# buy     232
# sell    197
# Name: signal, dtype: int64
# shape after: (884, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 43 TIME -> 0:0:3
#
# 44
# RUN FOR IAG
# shape before: (856, 17)
# SIGNAL COUNTS:
# hold    393
# buy     234
# sell    229
# Name: signal, dtype: int64
# shape after: (856, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 44 TIME -> 0:0:3
#
# 45
# RUN FOR ITV
# shape before: (1012, 17)
# SIGNAL COUNTS:
# hold    494
# sell    312
# buy     206
# Name: signal, dtype: int64
# shape after: (1012, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 45 TIME -> 0:0:3
#
# 46
# RUN FOR JD.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 46 TIME -> 0:0:3
#
# 47
# RUN FOR JMAT
# shape before: (1237, 17)
# SIGNAL COUNTS:
# hold    616
# sell    333
# buy     288
# Name: signal, dtype: int64
# shape after: (1237, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 47 TIME -> 0:0:1
#
# 48
# RUN FOR JE.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 48 TIME -> 0:0:4
#
# 49
# RUN FOR KGF
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    617
# sell    386
# buy     253
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 49 TIME -> 0:0:1
#
# 50
# RUN FOR LAND
# shape before: (1264, 17)
# SIGNAL COUNTS:
# hold    713
# sell    327
# buy     224
# Name: signal, dtype: int64
# shape after: (1264, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 50 TIME -> 0:0:4
#
# 51
# RUN FOR LGEN
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    664
# sell    320
# buy     272
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 51 TIME -> 0:0:4
#
# 52
# RUN FOR LLOY
# shape before: (1222, 17)
# SIGNAL COUNTS:
# hold    603
# sell    392
# buy     227
# Name: signal, dtype: int64
# shape after: (1222, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 52 TIME -> 0:0:4
#
# 53
# RUN FOR LSE
# shape before: (932, 17)
# SIGNAL COUNTS:
# hold    463
# buy     257
# sell    212
# Name: signal, dtype: int64
# shape after: (932, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 53 TIME -> 0:0:4
#
# 54
# RUN FOR MGGT
# shape before: (1475, 17)
# SIGNAL COUNTS:
# hold    749
# sell    376
# buy     350
# Name: signal, dtype: int64
# shape after: (1475, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 54 TIME -> 0:0:3
#
# 55
# RUN FOR MRO
# shape before: (812, 17)
# SIGNAL COUNTS:
# hold    391
# buy     217
# sell    204
# Name: signal, dtype: int64
# shape after: (812, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 55 TIME -> 0:0:4
#
# 56
# RUN FOR MNDI
# shape before: (614, 17)
# SIGNAL COUNTS:
# hold    308
# sell    155
# buy     151
# Name: signal, dtype: int64
# shape after: (614, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 56 TIME -> 0:0:3
#
# 57
# RUN FOR MRW
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    672
# sell    350
# buy     234
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 57 TIME -> 0:0:3
#
# 58
# RUN FOR NG.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 58 TIME -> 0:0:4
#
# 59
# RUN FOR NXT
# shape before: (1523, 17)
# SIGNAL COUNTS:
# hold    792
# buy     390
# sell    341
# Name: signal, dtype: int64
# shape after: (1523, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 59 TIME -> 0:0:1
#
# 60
# RUN FOR NMC
# shape before: (373, 17)
# SIGNAL COUNTS:
# hold    177
# buy     118
# sell     78
# Name: signal, dtype: int64
# shape after: (373, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 60 TIME -> 0:0:4
#
# 61
# RUN FOR OCDO
# shape before: (462, 17)
# SIGNAL COUNTS:
# hold    223
# sell    120
# buy     119
# Name: signal, dtype: int64
# shape after: (462, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 61 TIME -> 0:0:2
#
# 62
# RUN FOR PSON
# shape before: (1273, 17)
# SIGNAL COUNTS:
# hold    693
# sell    341
# buy     239
# Name: signal, dtype: int64
# shape after: (1273, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 62 TIME -> 0:0:3
#
# 63
# RUN FOR PSN
# shape before: (1463, 17)
# SIGNAL COUNTS:
# hold    690
# sell    396
# buy     377
# Name: signal, dtype: int64
# shape after: (1463, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 63 TIME -> 0:0:4
#
# 64
# RUN FOR PHNX
# shape before: (495, 17)
# SIGNAL COUNTS:
# hold    290
# sell    138
# buy      67
# Name: signal, dtype: int64
# shape after: (495, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 64 TIME -> 0:0:4
#
# 65
# RUN FOR POLY
# shape before: (399, 17)
# SIGNAL COUNTS:
# hold    177
# sell    130
# buy      92
# Name: signal, dtype: int64
# shape after: (399, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 65 TIME -> 0:0:3
#
# 66
# RUN FOR PRU
# shape before: (1503, 17)
# SIGNAL COUNTS:
# hold    749
# sell    406
# buy     348
# Name: signal, dtype: int64
# shape after: (1503, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 66 TIME -> 0:0:3
#
# 67
# RUN FOR RDSA
# shape before: (260, 17)
# SIGNAL COUNTS:
# hold    158
# sell     80
# buy      22
# Name: signal, dtype: int64
# shape after: (260, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 67 TIME -> 0:0:4
#
# 68
# RUN FOR RDSB
# shape before: (996, 17)
# SIGNAL COUNTS:
# hold    533
# sell    301
# buy     162
# Name: signal, dtype: int64
# shape after: (996, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 68 TIME -> 0:0:2
#
# 69
# RUN FOR RB.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 69 TIME -> 0:0:4
#
# 70
# RUN FOR REL
# shape before: (1276, 17)
# SIGNAL COUNTS:
# hold    732
# sell    301
# buy     243
# Name: signal, dtype: int64
# shape after: (1276, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 70 TIME -> 0:0:1
#
# 71
# RUN FOR RTO
# shape before: (1244, 17)
# SIGNAL COUNTS:
# hold    637
# sell    314
# buy     293
# Name: signal, dtype: int64
# shape after: (1244, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 71 TIME -> 0:0:4
#
# 72
# RUN FOR RMV
# shape before: (691, 17)
# SIGNAL COUNTS:
# hold    324
# buy     209
# sell    158
# Name: signal, dtype: int64
# shape after: (691, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 72 TIME -> 0:0:4
#
# 73
# RUN FOR RIO
# shape before: (1529, 17)
# SIGNAL COUNTS:
# hold    723
# sell    424
# buy     382
# Name: signal, dtype: int64
# shape after: (1529, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 73 TIME -> 0:0:3
#
# 74
# RUN FOR RR.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 74 TIME -> 0:0:4
#
# 75
# RUN FOR RBS
# shape before: (1257, 17)
# SIGNAL COUNTS:
# hold    614
# sell    382
# buy     261
# Name: signal, dtype: int64
# shape after: (1257, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 75 TIME -> 0:0:1
#
# 76
# RUN FOR RSA
# shape before: (1246, 17)
# SIGNAL COUNTS:
# hold    659
# sell    346
# buy     241
# Name: signal, dtype: int64
# shape after: (1246, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 76 TIME -> 0:0:4
#
# 77
# RUN FOR SGE
# shape before: (1252, 17)
# SIGNAL COUNTS:
# hold    629
# buy     321
# sell    302
# Name: signal, dtype: int64
# shape after: (1252, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 77 TIME -> 0:0:4
#
# 78
# RUN FOR SBRY
# shape before: (1259, 17)
# SIGNAL COUNTS:
# hold    672
# sell    370
# buy     217
# Name: signal, dtype: int64
# shape after: (1259, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 78 TIME -> 0:0:4
#
# 79
# RUN FOR SDR
# shape before: (1247, 17)
# SIGNAL COUNTS:
# hold    593
# sell    358
# buy     296
# Name: signal, dtype: int64
# shape after: (1247, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 79 TIME -> 0:0:4
#
# 80
# RUN FOR SMT
# shape before: (139, 17)
# SIGNAL COUNTS:
# hold    87
# sell    27
# buy     25
# Name: signal, dtype: int64
# shape after: (139, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 80 TIME -> 0:0:4
#
# 81
# RUN FOR SGRO
# shape before: (1535, 17)
# SIGNAL COUNTS:
# hold    817
# sell    418
# buy     300
# Name: signal, dtype: int64
# shape after: (1535, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 81 TIME -> 0:0:2
#
# 82
# RUN FOR SVT
# shape before: (1242, 17)
# SIGNAL COUNTS:
# hold    746
# sell    308
# buy     188
# Name: signal, dtype: int64
# shape after: (1242, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 82 TIME -> 0:0:4
#
# 83
# RUN FOR SN.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 83 TIME -> 0:0:4
#
# 84
# RUN FOR SMDS
# shape before: (1425, 17)
# SIGNAL COUNTS:
# hold    735
# sell    372
# buy     318
# Name: signal, dtype: int64
# shape after: (1425, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 84 TIME -> 0:0:1
#
# 85
# RUN FOR SMIN
# shape before: (1486, 17)
# SIGNAL COUNTS:
# hold    797
# sell    378
# buy     311
# Name: signal, dtype: int64
# shape after: (1486, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 85 TIME -> 0:0:4
#
# 86
# RUN FOR SKG
# shape before: (638, 17)
# SIGNAL COUNTS:
# hold    289
# sell    176
# buy     173
# Name: signal, dtype: int64
# shape after: (638, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 86 TIME -> 0:0:4
#
# 87
# RUN FOR SPX
# shape before: (1454, 17)
# SIGNAL COUNTS:
# hold    797
# buy     359
# sell    298
# Name: signal, dtype: int64
# shape after: (1454, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 87 TIME -> 0:0:3
#
# 88
# RUN FOR SSE
# shape before: (1273, 17)
# SIGNAL COUNTS:
# hold    778
# sell    327
# buy     168
# Name: signal, dtype: int64
# shape after: (1273, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 88 TIME -> 0:0:4
#
# 89
# RUN FOR STJ
# shape before: (1463, 17)
# SIGNAL COUNTS:
# hold    714
# sell    388
# buy     361
# Name: signal, dtype: int64
# shape after: (1463, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 89 TIME -> 0:0:4
#
# 90
# RUN FOR STAN
# shape before: (1528, 17)
# SIGNAL COUNTS:
# hold    707
# sell    438
# buy     383
# Name: signal, dtype: int64
# shape after: (1528, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 90 TIME -> 0:0:4
#
# 91
# RUN FOR SLA
# shape before: (673, 17)
# SIGNAL COUNTS:
# hold    317
# sell    219
# buy     137
# Name: signal, dtype: int64
# shape after: (673, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 91 TIME -> 0:0:4
#
# 92
# RUN FOR TW.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 92 TIME -> 0:0:3
#
# 93
# RUN FOR TSCO
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    706
# sell    305
# buy     245
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 93 TIME -> 0:0:1
#
# 94
# RUN FOR TUI
# shape before: (251, 17)
# SIGNAL COUNTS:
# hold    138
# sell     70
# buy      43
# Name: signal, dtype: int64
# shape after: (251, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 94 TIME -> 0:0:4
#
# 95
# RUN FOR ULVR
# shape before: (1026, 17)
# SIGNAL COUNTS:
# hold    613
# sell    238
# buy     175
# Name: signal, dtype: int64
# shape after: (1026, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 95 TIME -> 0:0:3
#
# 96
# RUN FOR UU.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 96 TIME -> 0:0:4
#
# 97
# RUN FOR VOD
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    562
# sell    309
# buy     174
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 97 TIME -> 0:0:1
#
# 98
# RUN FOR WTB
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    524
# sell    268
# buy     253
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 98 TIME -> 0:0:4
#
# 99
# RUN FOR WPP
# shape before: (682, 17)
# SIGNAL COUNTS:
# hold    353
# sell    192
# buy     137
# Name: signal, dtype: int64
# shape after: (682, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 99 TIME -> 0:0:4
#
# 100
# RUN FOR 3IN
# shape before: (586, 17)
# SIGNAL COUNTS:
# hold    481
# sell     60
# buy      45
# Name: signal, dtype: int64
# shape after: (586, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 100 TIME -> 0:0:4
#
# 101
# RUN FOR FOUR
# shape before: (1037, 17)
# SIGNAL COUNTS:
# hold    548
# buy     249
# sell    240
# Name: signal, dtype: int64
# shape after: (1037, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 101 TIME -> 0:0:3
#
# 102
# RUN FOR ASL
# shape before: (604, 17)
# SIGNAL COUNTS:
# hold    359
# sell    131
# buy     114
# Name: signal, dtype: int64
# shape after: (604, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 102 TIME -> 0:0:4
#
# 103
# RUN FOR AGK
# shape before: (1046, 17)
# SIGNAL COUNTS:
# hold    479
# sell    295
# buy     272
# Name: signal, dtype: int64
# shape after: (1046, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 103 TIME -> 0:0:3
#
# 104
# RUN FOR AJB
# shape before: (45, 17)
# SIGNAL COUNTS:
# buy     23
# hold    16
# sell     6
# Name: signal, dtype: int64
# shape after: (45, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 104 TIME -> 0:0:4
#
# 105
# RUN FOR ATST
# shape before: (615, 17)
# SIGNAL COUNTS:
# hold    450
# sell    107
# buy      58
# Name: signal, dtype: int64
# shape after: (615, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 105 TIME -> 0:0:2
#
# 106
# RUN FOR APAX
# shape before: (217, 17)
# SIGNAL COUNTS:
# hold    141
# sell     52
# buy      24
# Name: signal, dtype: int64
# shape after: (217, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 106 TIME -> 0:0:3
#
# 107
# RUN FOR ASCL
# shape before: (191, 17)
# SIGNAL COUNTS:
# hold    90
# buy     55
# sell    46
# Name: signal, dtype: int64
# shape after: (191, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 107 TIME -> 0:0:3
#
# 108
# RUN FOR ASHM
# shape before: (678, 17)
# SIGNAL COUNTS:
# hold    328
# sell    188
# buy     162
# Name: signal, dtype: int64
# shape after: (678, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 108 TIME -> 0:0:3
#
# 109
# RUN FOR AGR
# shape before: (827, 17)
# SIGNAL COUNTS:
# hold    513
# sell    180
# buy     134
# Name: signal, dtype: int64
# shape after: (827, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 109 TIME -> 0:0:3
#
# 110
# RUN FOR AML
# shape before: (53, 17)
# SIGNAL COUNTS:
# hold    30
# sell    23
# Name: signal, dtype: int64
# shape after: (53, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 110 TIME -> 0:0:4
#
# 111
# RUN FOR AVST
# shape before: (75, 17)
# SIGNAL COUNTS:
# hold    33
# buy     26
# sell    16
# Name: signal, dtype: int64
# shape after: (75, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 111 TIME -> 0:0:2
#
# 112
# RUN FOR BME
# shape before: (279, 17)
# SIGNAL COUNTS:
# hold    135
# sell     84
# buy      60
# Name: signal, dtype: int64
# shape after: (279, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 112 TIME -> 0:0:2
#
# 113
# RUN FOR BAB
# shape before: (1025, 17)
# SIGNAL COUNTS:
# hold    524
# sell    271
# buy     230
# Name: signal, dtype: int64
# shape after: (1025, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 113 TIME -> 0:0:3
#
# 114
# RUN FOR BGFD
# shape before: (606, 17)
# SIGNAL COUNTS:
# hold    336
# buy     145
# sell    125
# Name: signal, dtype: int64
# shape after: (606, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 114 TIME -> 0:0:4
#
# 115
# RUN FOR BAKK
# shape before: (100, 17)
# SIGNAL COUNTS:
# hold    50
# sell    35
# buy     15
# Name: signal, dtype: int64
# shape after: (100, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 115 TIME -> 0:0:4
#
# 116
# RUN FOR BBY
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    512
# sell    307
# buy     226
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 116 TIME -> 0:0:4
#
# 117
# RUN FOR BGEO
# shape before: (621, 17)
# SIGNAL COUNTS:
# hold    278
# sell    172
# buy     171
# Name: signal, dtype: int64
# shape after: (621, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 117 TIME -> 0:0:5
#
# 118
# RUN FOR BNKR
# shape before: (614, 17)
# SIGNAL COUNTS:
# hold    442
# sell    108
# buy      64
# Name: signal, dtype: int64
# shape after: (614, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 118 TIME -> 0:0:4
#
# 119
# RUN FOR BAG
# shape before: (1045, 17)
# SIGNAL COUNTS:
# hold    610
# sell    236
# buy     199
# Name: signal, dtype: int64
# shape after: (1045, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 119 TIME -> 0:0:4
#
# 120
# RUN FOR BBA
# shape before: (1046, 17)
# SIGNAL COUNTS:
# hold    536
# sell    292
# buy     218
# Name: signal, dtype: int64
# shape after: (1046, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 120 TIME -> 0:0:4
#
# 121
# RUN FOR BBGI
# shape before: (398, 17)
# SIGNAL COUNTS:
# hold    365
# sell     25
# buy       8
# Name: signal, dtype: int64
# shape after: (398, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 121 TIME -> 0:0:4
#
# 122
# RUN FOR BCA
# shape before: (248, 17)
# SIGNAL COUNTS:
# hold    133
# sell     68
# buy      47
# Name: signal, dtype: int64
# shape after: (248, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 122 TIME -> 0:0:3
#
# 123
# RUN FOR BEZ
# shape before: (161, 17)
# SIGNAL COUNTS:
# hold    93
# buy     34
# sell    34
# Name: signal, dtype: int64
# shape after: (161, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 123 TIME -> 0:0:3
#
# 124
# RUN FOR BWY
# shape before: (1434, 17)
# SIGNAL COUNTS:
# hold    676
# buy     382
# sell    376
# Name: signal, dtype: int64
# shape after: (1434, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 124 TIME -> 0:0:3
#
# 125
# RUN FOR BYG
# shape before: (995, 17)
# SIGNAL COUNTS:
# hold    508
# sell    252
# buy     235
# Name: signal, dtype: int64
# shape after: (995, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 125 TIME -> 0:0:4
#
# 126
# RUN FOR BRSC
# shape before: (274, 17)
# SIGNAL COUNTS:
# hold    147
# buy      79
# sell     48
# Name: signal, dtype: int64
# shape after: (274, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 126 TIME -> 0:0:4
#
# 127
# RUN FOR BGSC
# shape before: (595, 17)
# SIGNAL COUNTS:
# hold    405
# sell    101
# buy      89
# Name: signal, dtype: int64
# shape after: (595, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 127 TIME -> 0:0:3
#
# 128
# RUN FOR BOY
# shape before: (1248, 17)
# SIGNAL COUNTS:
# hold    582
# sell    344
# buy     322
# Name: signal, dtype: int64
# shape after: (1248, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 128 TIME -> 0:0:3
#
# 129
# RUN FOR BVS
# shape before: (1114, 17)
# SIGNAL COUNTS:
# hold    527
# sell    302
# buy     285
# Name: signal, dtype: int64
# shape after: (1114, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 129 TIME -> 0:0:4
#
# 130
# RUN FOR BRW
# shape before: (1124, 17)
# SIGNAL COUNTS:
# hold    541
# buy     297
# sell    286
# Name: signal, dtype: int64
# shape after: (1124, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 130 TIME -> 0:0:4
#
# 131
# RUN FOR BVIC
# shape before: (704, 17)
# SIGNAL COUNTS:
# hold    352
# buy     181
# sell    171
# Name: signal, dtype: int64
# shape after: (704, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 131 TIME -> 0:0:4
#
# 132
# RUN FOR CNE
# shape before: (1400, 17)
# SIGNAL COUNTS:
# hold    762
# sell    365
# buy     273
# Name: signal, dtype: int64
# shape after: (1400, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 132 TIME -> 0:0:3
#
# 133
# RUN FOR CLDN
# shape before: (592, 17)
# SIGNAL COUNTS:
# hold    400
# sell    134
# buy      58
# Name: signal, dtype: int64
# shape after: (592, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 133 TIME -> 0:0:5
#
# 134
# RUN FOR CAPC
# shape before: (473, 17)
# SIGNAL COUNTS:
# hold    242
# sell    125
# buy     106
# Name: signal, dtype: int64
# shape after: (473, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 134 TIME -> 0:0:3
#
# 135
# RUN FOR CPI
# shape before: (1303, 17)
# SIGNAL COUNTS:
# hold    706
# sell    303
# buy     294
# Name: signal, dtype: int64
# shape after: (1303, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 135 TIME -> 0:0:3
#
# 136
# RUN FOR CARD
# shape before: (283, 17)
# SIGNAL COUNTS:
# hold    135
# sell     83
# buy      65
# Name: signal, dtype: int64
# shape after: (283, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 136 TIME -> 0:0:4
#
# 137
# RUN FOR CEY
# shape before: (909, 17)
# SIGNAL COUNTS:
# hold    462
# sell    227
# buy     220
# Name: signal, dtype: int64
# shape after: (909, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 137 TIME -> 0:0:3
#
# 138
# RUN FOR CCFS
# shape before: (109, 17)
# SIGNAL COUNTS:
# hold    48
# buy     35
# sell    26
# Name: signal, dtype: int64
# shape after: (109, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 138 TIME -> 0:0:4
#
# 139
# RUN FOR CINE
# shape before: (631, 17)
# SIGNAL COUNTS:
# hold    313
# sell    169
# buy     149
# Name: signal, dtype: int64
# shape after: (631, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 139 TIME -> 0:0:3
#
# 140
# RUN FOR CTY
# shape before: (596, 17)
# SIGNAL COUNTS:
# hold    452
# sell    111
# buy      33
# Name: signal, dtype: int64
# shape after: (596, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 140 TIME -> 0:0:4
#
# 141
# RUN FOR CKN
# shape before: (1304, 17)
# SIGNAL COUNTS:
# hold    642
# buy     355
# sell    307
# Name: signal, dtype: int64
# shape after: (1304, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 141 TIME -> 0:0:4
#
# 142
# RUN FOR CBG
# shape before: (1240, 17)
# SIGNAL COUNTS:
# hold    629
# sell    337
# buy     274
# Name: signal, dtype: int64
# shape after: (1240, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 142 TIME -> 0:0:5
#
# 143
# RUN FOR CLI
# shape before: (1276, 17)
# SIGNAL COUNTS:
# hold    711
# buy     285
# sell    280
# Name: signal, dtype: int64
# shape after: (1276, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 143 TIME -> 0:0:5
#
# 144
# RUN FOR COA
# shape before: (1373, 17)
# SIGNAL COUNTS:
# hold    787
# sell    359
# buy     227
# Name: signal, dtype: int64
# shape after: (1373, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 144 TIME -> 0:0:4
#
# 145
# RUN FOR COB
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    638
# sell    340
# buy     278
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 145 TIME -> 0:0:5
#
# 146
# RUN FOR CCC
# shape before: (1098, 17)
# SIGNAL COUNTS:
# hold    522
# sell    311
# buy     265
# Name: signal, dtype: int64
# shape after: (1098, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 146 TIME -> 0:0:4
#
# 147
# RUN FOR GLO
# shape before: (100, 17)
# SIGNAL COUNTS:
# hold    49
# sell    38
# buy     13
# Name: signal, dtype: int64
# shape after: (100, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 147 TIME -> 0:0:4
#
# 148
# RUN FOR CTEC
# shape before: (155, 17)
# SIGNAL COUNTS:
# hold    68
# sell    45
# buy     42
# Name: signal, dtype: int64
# shape after: (155, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 148 TIME -> 0:0:3
#
# 149
# RUN FOR CSP
# shape before: (410, 17)
# SIGNAL COUNTS:
# hold    219
# sell    101
# buy      90
# Name: signal, dtype: int64
# shape after: (410, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 149 TIME -> 0:0:3
#
# 150
# RUN FOR CWK
# shape before: (1113, 17)
# SIGNAL COUNTS:
# hold    603
# buy     272
# sell    238
# Name: signal, dtype: int64
# shape after: (1113, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 150 TIME -> 0:0:3
#
# 151
# RUN FOR CRST
# shape before: (328, 17)
# SIGNAL COUNTS:
# hold    154
# sell    102
# buy      72
# Name: signal, dtype: int64
# shape after: (328, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 151 TIME -> 0:0:4
#
# 152
# RUN FOR CYBG
# shape before: (192, 17)
# SIGNAL COUNTS:
# hold    102
# sell     49
# buy      41
# Name: signal, dtype: int64
# shape after: (192, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 152 TIME -> 0:0:3
#
# 153
# RUN FOR DJAN
# shape before: (1123, 17)
# SIGNAL COUNTS:
# hold    607
# sell    269
# buy     247
# Name: signal, dtype: int64
# shape after: (1123, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 153 TIME -> 0:0:3
#
# 154
# RUN FOR DPH
# shape before: (954, 17)
# SIGNAL COUNTS:
# hold    514
# buy     237
# sell    203
# Name: signal, dtype: int64
# shape after: (954, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 154 TIME -> 0:0:4
#
# 155
# RUN FOR DLN
# shape before: (1193, 17)
# SIGNAL COUNTS:
# hold    657
# buy     283
# sell    253
# Name: signal, dtype: int64
# shape after: (1193, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 155 TIME -> 0:0:4
#
# 156
# RUN FOR DPLM
# shape before: (1480, 17)
# SIGNAL COUNTS:
# hold    777
# buy     366
# sell    337
# Name: signal, dtype: int64
# shape after: (1480, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 156 TIME -> 0:0:4
#
# 157
# RUN FOR DLG
# shape before: (346, 17)
# SIGNAL COUNTS:
# hold    192
# sell     89
# buy      65
# Name: signal, dtype: int64
# shape after: (346, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 157 TIME -> 0:0:5
#
# 158
# RUN FOR DC.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 158 TIME -> 0:0:3
#
# 159
# RUN FOR DOM
# shape before: (1019, 17)
# SIGNAL COUNTS:
# hold    492
# buy     286
# sell    241
# Name: signal, dtype: int64
# shape after: (1019, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 159 TIME -> 0:0:1
#
# 160
# RUN FOR DRX
# shape before: (702, 17)
# SIGNAL COUNTS:
# hold    339
# sell    221
# buy     142
# Name: signal, dtype: int64
# shape after: (702, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 160 TIME -> 0:0:4
#
# 161
# RUN FOR DNLM
# shape before: (658, 17)
# SIGNAL COUNTS:
# hold    322
# sell    197
# buy     139
# Name: signal, dtype: int64
# shape after: (658, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 161 TIME -> 0:0:4
#
# 162
# RUN FOR EZJ
# shape before: (967, 17)
# SIGNAL COUNTS:
# hold    420
# buy     284
# sell    263
# Name: signal, dtype: int64
# shape after: (967, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 162 TIME -> 0:0:4
#
# 163
# RUN FOR EDIN
# shape before: (586, 17)
# SIGNAL COUNTS:
# hold    423
# sell    119
# buy      44
# Name: signal, dtype: int64
# shape after: (586, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 163 TIME -> 0:0:5
#
# 164
# RUN FOR EIG
# shape before: (661, 17)
# SIGNAL COUNTS:
# hold    328
# sell    200
# buy     133
# Name: signal, dtype: int64
# shape after: (661, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 164 TIME -> 0:0:2
#
# 165
# RUN FOR ECM
# shape before: (1257, 17)
# SIGNAL COUNTS:
# hold    608
# sell    366
# buy     283
# Name: signal, dtype: int64
# shape after: (1257, 253)
# ...
# LAP 288 TIME -> 0:0:3
#
# 289
# RUN FOR SAFE
# shape before: (462, 17)
# SIGNAL COUNTS:
# hold    238
# buy     117
# sell    107
# Name: signal, dtype: int64
# shape after: (462, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 289 TIME -> 0:0:2
#
# 290
# RUN FOR SNN
# shape before: (236, 17)
# SIGNAL COUNTS:
# hold    112
# buy      70
# sell     54
# Name: signal, dtype: int64
# shape after: (236, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 290 TIME -> 0:0:3
#
# 291
# RUN FOR SVS
# shape before: (1412, 17)
# SIGNAL COUNTS:
# hold    688
# buy     386
# sell    338
# Name: signal, dtype: int64
# shape after: (1412, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 291 TIME -> 0:0:3
#
# 292
# RUN FOR SDP
# shape before: (589, 17)
# SIGNAL COUNTS:
# hold    371
# sell    120
# buy      98
# Name: signal, dtype: int64
# shape after: (589, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 292 TIME -> 0:0:6
#
# 293
# RUN FOR SOI
# shape before: (586, 17)
# SIGNAL COUNTS:
# hold    386
# sell    124
# buy      76
# Name: signal, dtype: int64
# shape after: (586, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 293 TIME -> 0:0:4
#
# 294
# RUN FOR SCIN
# shape before: (587, 17)
# SIGNAL COUNTS:
# hold    409
# sell    119
# buy      59
# Name: signal, dtype: int64
# shape after: (587, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 294 TIME -> 0:0:5
#
# 295
# RUN FOR SNR
# shape before: (1428, 17)
# SIGNAL COUNTS:
# hold    676
# sell    394
# buy     358
# Name: signal, dtype: int64
# shape after: (1428, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 295 TIME -> 0:0:5
#
# 296
# RUN FOR SEQI
# shape before: (231, 17)
# SIGNAL COUNTS:
# hold    212
# sell     19
# Name: signal, dtype: int64
# shape after: (231, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 296 TIME -> 0:0:5
#
# 297
# RUN FOR SRP
# shape before: (1286, 17)
# SIGNAL COUNTS:
# hold    691
# sell    306
# buy     289
# Name: signal, dtype: int64
# shape after: (1286, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 297 TIME -> 0:0:3
#
# 298
# RUN FOR SHB
# shape before: (1152, 17)
# SIGNAL COUNTS:
# hold    668
# sell    255
# buy     229
# Name: signal, dtype: int64
# shape after: (1152, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 298 TIME -> 0:0:5
#
# 299
# RUN FOR SHI
# shape before: (1318, 17)
# SIGNAL COUNTS:
# hold    615
# sell    383
# buy     320
# Name: signal, dtype: int64
# shape after: (1318, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 299 TIME -> 0:0:5
#
# 300
# RUN FOR SXX
# shape before: (659, 17)
# SIGNAL COUNTS:
# hold    353
# sell    185
# buy     121
# Name: signal, dtype: int64
# shape after: (659, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 300 TIME -> 0:0:5
#
# 301
# RUN FOR SRE
# shape before: (623, 17)
# SIGNAL COUNTS:
# hold    369
# sell    148
# buy     106
# Name: signal, dtype: int64
# shape after: (623, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 301 TIME -> 0:0:4
#
# 302
# RUN FOR SSON
# shape before: (41, 17)
# SIGNAL COUNTS:
# hold    30
# sell     6
# buy      5
# Name: signal, dtype: int64
# shape after: (41, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 302 TIME -> 0:0:4
#
# 303
# RUN FOR SCT
# shape before: (205, 17)
# SIGNAL COUNTS:
# hold    81
# buy     79
# sell    45
# Name: signal, dtype: int64
# shape after: (205, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 303 TIME -> 0:0:3
#
# 304
# RUN FOR SOPH
# shape before: (225, 17)
# SIGNAL COUNTS:
# hold    122
# sell     55
# buy      48
# Name: signal, dtype: int64
# shape after: (225, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 304 TIME -> 0:0:3
#
# 305
# RUN FOR SXS
# shape before: (1479, 17)
# SIGNAL COUNTS:
# hold    719
# buy     391
# sell    369
# Name: signal, dtype: int64
# shape after: (1479, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 305 TIME -> 0:0:3
#
# 306
# RUN FOR SPT
# shape before: (1255, 17)
# SIGNAL COUNTS:
# hold    625
# sell    324
# buy     306
# Name: signal, dtype: int64
# shape after: (1255, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 306 TIME -> 0:0:5
#
# 307
# RUN FOR SPD
# shape before: (639, 17)
# SIGNAL COUNTS:
# hold    295
# sell    175
# buy     169
# Name: signal, dtype: int64
# shape after: (639, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 307 TIME -> 0:0:5
#
# 308
# RUN FOR SSPG
# shape before: (275, 17)
# SIGNAL COUNTS:
# hold    156
# buy      72
# sell     47
# Name: signal, dtype: int64
# shape after: (275, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 308 TIME -> 0:0:4
#
# 309
# RUN FOR SMP
# shape before: (1424, 17)
# SIGNAL COUNTS:
# hold    791
# sell    330
# buy     303
# Name: signal, dtype: int64
# shape after: (1424, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 309 TIME -> 0:0:3
#
# 310
# RUN FOR SGC
# shape before: (1152, 17)
# SIGNAL COUNTS:
# hold    545
# buy     310
# sell    297
# Name: signal, dtype: int64
# shape after: (1152, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 310 TIME -> 0:0:5
#
# 311
# RUN FOR SYNC
# shape before: (335, 17)
# SIGNAL COUNTS:
# hold    253
# buy      43
# sell     39
# Name: signal, dtype: int64
# shape after: (335, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 311 TIME -> 0:0:5
#
# 312
# RUN FOR SYNT
# shape before: (1454, 17)
# SIGNAL COUNTS:
# hold    742
# sell    393
# buy     319
# Name: signal, dtype: int64
# shape after: (1454, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 312 TIME -> 0:0:4
#
# 313
# RUN FOR TALK
# shape before: (479, 17)
# SIGNAL COUNTS:
# hold    219
# sell    145
# buy     115
# Name: signal, dtype: int64
# shape after: (479, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 313 TIME -> 0:0:6
#
# 314
# RUN FOR TATE
# shape before: (1260, 17)
# SIGNAL COUNTS:
# hold    690
# sell    307
# buy     263
# Name: signal, dtype: int64
# shape after: (1260, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 314 TIME -> 0:0:4
#
# 315
# RUN FOR TBCG
# shape before: (165, 17)
# SIGNAL COUNTS:
# hold    80
# sell    53
# buy     32
# Name: signal, dtype: int64
# shape after: (165, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 315 TIME -> 0:0:4
#
# 316
# RUN FOR TEP
# shape before: (984, 17)
# SIGNAL COUNTS:
# hold    462
# sell    266
# buy     256
# Name: signal, dtype: int64
# shape after: (984, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 316 TIME -> 0:0:3
#
# 317
# RUN FOR TMPL
# shape before: (586, 17)
# SIGNAL COUNTS:
# hold    408
# sell    124
# buy      54
# Name: signal, dtype: int64
# shape after: (586, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 317 TIME -> 0:0:4
#
# 318
# RUN FOR TEM
# shape before: (586, 17)
# SIGNAL COUNTS:
# hold    339
# sell    142
# buy     105
# Name: signal, dtype: int64
# shape after: (586, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 318 TIME -> 0:0:4
#
# 319
# RUN FOR TIFS
# shape before: (103, 17)
# SIGNAL COUNTS:
# hold    50
# sell    37
# buy     16
# Name: signal, dtype: int64
# shape after: (103, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 319 TIME -> 0:0:3
#
# 320
# RUN FOR TCAP
# shape before: (961, 17)
# SIGNAL COUNTS:
# hold    472
# sell    264
# buy     225
# Name: signal, dtype: int64
# shape after: (961, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 320 TIME -> 0:0:3
#
# 321
# RUN FOR TRY
# shape before: (585, 17)
# SIGNAL COUNTS:
# hold    331
# sell    147
# buy     107
# Name: signal, dtype: int64
# shape after: (585, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 321 TIME -> 0:0:5
#
# 322
# RUN FOR TPK
# shape before: (1026, 17)
# SIGNAL COUNTS:
# hold    521
# sell    283
# buy     222
# Name: signal, dtype: int64
# shape after: (1026, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 322 TIME -> 0:0:4
#
# 323
# RUN FOR BBOX
# shape before: (276, 17)
# SIGNAL COUNTS:
# hold    227
# sell     38
# buy      11
# Name: signal, dtype: int64
# shape after: (276, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 323 TIME -> 0:0:5
#
# 324
# RUN FOR TLW
# shape before: (1019, 17)
# SIGNAL COUNTS:
# hold    481
# sell    288
# buy     250
# Name: signal, dtype: int64
# shape after: (1019, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 324 TIME -> 0:0:4
#
# 325
# RUN FOR UDG
# shape before: (1008, 17)
# SIGNAL COUNTS:
# hold    575
# sell    218
# buy     215
# Name: signal, dtype: int64
# shape after: (1008, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 325 TIME -> 0:0:6
#
# 326
# RUN FOR UKCM
# shape before: (587, 17)
# SIGNAL COUNTS:
# hold    430
# sell    117
# buy      40
# Name: signal, dtype: int64
# shape after: (587, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 326 TIME -> 0:0:5
#
# 327
# RUN FOR ULE
# shape before: (1023, 17)
# SIGNAL COUNTS:
# hold    594
# sell    239
# buy     190
# Name: signal, dtype: int64
# shape after: (1023, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 327 TIME -> 0:0:4
#
# 328
# RUN FOR UTG
# shape before: (342, 17)
# SIGNAL COUNTS:
# hold    208
# buy      74
# sell     60
# Name: signal, dtype: int64
# shape after: (342, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 328 TIME -> 0:0:5
#
# 329
# RUN FOR VSVS
# shape before: (1256, 17)
# SIGNAL COUNTS:
# hold    590
# sell    372
# buy     294
# Name: signal, dtype: int64
# shape after: (1256, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 329 TIME -> 0:0:4
#
# 330
# RUN FOR VCT
# shape before: (1185, 17)
# SIGNAL COUNTS:
# hold    589
# sell    300
# buy     296
# Name: signal, dtype: int64
# shape after: (1185, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 330 TIME -> 0:0:6
#
# 331
# RUN FOR VEIL
# shape before: (161, 17)
# SIGNAL COUNTS:
# hold    92
# buy     36
# sell    33
# Name: signal, dtype: int64
# shape after: (161, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 331 TIME -> 0:0:6
#
# 332
# RUN FOR VOF
# shape before: (595, 17)
# SIGNAL COUNTS:
# hold    364
# sell    127
# buy     104
# Name: signal, dtype: int64
# shape after: (595, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 332 TIME -> 0:0:4
#
# 333
# RUN FOR VVO
# shape before: (75, 17)
# SIGNAL COUNTS:
# hold    37
# sell    29
# buy      9
# Name: signal, dtype: int64
# shape after: (75, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 333 TIME -> 0:0:4
#
# 334
# RUN FOR WEIR
# shape before: (1468, 17)
# SIGNAL COUNTS:
# hold    693
# buy     392
# sell    383
# Name: signal, dtype: int64
# shape after: (1468, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 334 TIME -> 0:0:3
#
# 335
# RUN FOR JDW
# shape before: (1342, 17)
# SIGNAL COUNTS:
# hold    659
# buy     356
# sell    327
# Name: signal, dtype: int64
# shape after: (1342, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 335 TIME -> 0:0:6
#
# 336
# RUN FOR SMWH
# shape before: (668, 17)
# SIGNAL COUNTS:
# hold    341
# sell    168
# buy     159
# Name: signal, dtype: int64
# shape after: (668, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 336 TIME -> 0:0:6
#
# 337
# RUN FOR WMH
# shape before: (884, 17)
# SIGNAL COUNTS:
# hold    438
# sell    261
# buy     185
# Name: signal, dtype: int64
# shape after: (884, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 337 TIME -> 0:0:4
#
# 338
# RUN FOR WTAN
# shape before: (595, 17)
# SIGNAL COUNTS:
# hold    419
# sell    105
# buy      71
# Name: signal, dtype: int64
# shape after: (595, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 338 TIME -> 0:0:5
#
# 339
# RUN FOR WIZZ
# shape before: (241, 17)
# SIGNAL COUNTS:
# hold    102
# buy      73
# sell     66
# Name: signal, dtype: int64
# shape after: (241, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 339 TIME -> 0:0:4
#
# 340
# RUN FOR WG.
# shape before: (0, 17)
# SIGNAL COUNTS:
# Series([], Name: signal, dtype: int64)
# shape after: (0, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 340 TIME -> 0:0:4
#
# 341
# RUN FOR WKP
# shape before: (947, 17)
# SIGNAL COUNTS:
# hold    469
# buy     255
# sell    223
# Name: signal, dtype: int64
# shape after: (947, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
# LAP 341 TIME -> 0:0:1
#
# 342
# RUN FOR WWH
# shape before: (596, 17)
# SIGNAL COUNTS:
# hold    382
# buy     119
# sell     95
# Name: signal, dtype: int64
# shape after: (596, 253)
# ADDED TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5
#
#
#
# TOTAL ELAPSED TIME -> 0:21:28
#
# ERROR COUNT: 0

# %%
#close any open h5 files
tables.file._open_files.close_all()

# %%
tmp_df = pd.read_hdf(hf_store_name,key='weekly_data',mode='r')
print("")
print("FINAL HDFSTORE SIZE: {}".format(tmp_df.shape))
print("FINAL BUY COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "buy"])))
print("FINAL SELL COUNT: {}".format(len(tmp_df[tmp_df["signal"] == "sell"])))
h_store.close()
tmp_df.head(50)
# tmp_df[(tmp_df["ticker"] == 'ADM') & (tmp_df["date"] > '2013-12-01') & (tmp_df["date"] < '2014-02-01')].head(200)
# Out:
# FINAL HDFSTORE SIZE: (259493, 140)
# FINAL BUY COUNT: 56042
# FINAL SELL COUNT: 65286
#        ticker       date    open   close     high     low      volume  \
# 123991    III 2007-12-31  995.00  965.00  1023.00  964.00   4511565.0
# 123992    III 2008-01-07  967.50  924.00   989.00  917.50  16056554.0
# 123993    III 2008-01-14  917.00  901.00   936.00  881.00  21691287.0
# 123994    III 2008-01-21  891.00  917.50   965.00  847.00  17850580.0
# 123995    III 2008-01-28  911.00  961.00   971.00  903.00  12079245.0
# 123996    III 2008-02-04  970.00  923.50   987.50  915.00  15446478.0
# 123997    III 2008-02-11  910.00  919.50   946.50  906.00  12183466.0
# 123998    III 2008-02-18  921.00  883.00   960.00  880.00  12692521.0
# 123999    III 2008-02-25  891.50  818.00   907.00  806.50  20641227.0
# 124000    III 2008-03-03  814.50  777.50   828.50  776.50  18670109.0
# 124001    III 2008-03-10  778.00  766.50   814.50  758.00  15754920.0
# 124002    III 2008-03-17  750.50  782.50   787.00  724.50  15855220.0
# 124003    III 2008-03-24  800.00  838.50   845.00  800.00  11615169.0
# 124004    III 2008-03-31  834.50  882.00   894.50  814.00  15192588.0
# 124005    III 2008-04-07  888.00  853.00   897.50  847.00   9445941.0
# 124006    III 2008-04-14  846.00  888.50   896.00  839.00   8156868.0
# 124007    III 2008-04-21  892.00  877.00   893.50  839.00   9071925.0
# 124008    III 2008-04-28  881.00  864.00   883.00  850.00   8128444.0
# 124009    III 2008-05-05  865.00  882.50   908.00  845.50   7591685.0
# 124010    III 2008-05-12  886.00  919.50   932.50  851.50  18227558.0
# 124011    III 2008-05-19  925.50  859.00   929.00  859.00  14291476.0
# 124012    III 2008-05-26  865.50  885.50   905.00  859.00   8320405.0
# 124013    III 2008-06-02  885.50  861.50   894.00  860.50  12531455.0
# 124014    III 2008-06-09  858.50  828.00   865.00  804.00  13010012.0
# 124015    III 2008-06-16  826.00  828.50   851.00  813.00  14231934.0
# 124016    III 2008-06-23  820.50  819.50   849.50  810.00  13393420.0
# 124017    III 2008-06-30  814.50  803.50   832.50  795.00  12423638.0
# 124018    III 2008-07-07  808.50  785.00   829.00  777.00  13843822.0
# 124019    III 2008-07-14  800.50  918.50   920.00  795.00  16064438.0
# 124020    III 2008-07-21  915.00  886.50   954.50  863.00  15573620.0
# 124021    III 2008-07-28  886.50  906.50   919.50  855.00   8989584.0
# 124022    III 2008-08-04  911.00  955.50   960.00  898.00   9215608.0
# 124023    III 2008-08-11  961.50  909.00   966.00  898.00   7241169.0
# 124024    III 2008-08-18  909.00  889.00   910.00  852.00   6552252.0
# 124025    III 2008-08-25  872.50  919.50   921.00  863.00   7093498.0
# 124026    III 2008-09-01  914.00  889.50   945.00  887.50  10993673.0
# 124027    III 2008-09-08  923.50  902.00   946.50  878.50  10235568.0
# 124028    III 2008-09-15  875.00  847.00   880.00  750.00  23977621.0
# 124029    III 2008-09-22  872.00  789.00   875.00  783.50  13515797.0
# 124030    III 2008-09-29  786.50  721.00   789.50  665.50  17307029.0
# 124031    III 2008-10-06  722.00  500.50   724.00  500.50  22143905.0
# 124032    III 2008-10-13  525.50  456.00   607.50  438.25  23569245.0
# 124033    III 2008-10-20  476.00  494.75   534.00  437.75  21611591.0
# 124034    III 2008-10-27  466.00  540.00   548.50  446.25  12772985.0
# 124035    III 2008-11-03  557.00  480.00   613.00  470.00  14283484.0
# 124036    III 2008-11-10  491.25  425.00   503.50  409.75  12754743.0
# 124037    III 2008-11-17  412.25  362.50   426.00  350.50  12220375.0
# 124038    III 2008-11-24  375.50  411.75   454.50  374.75  11752897.0
# 124039    III 2008-12-01  414.75  340.50   414.75  328.00  11284456.0
# 124040    III 2008-12-08  369.00  310.50   371.00  305.50  17124301.0
#
#         change_price  per_change_price  close_shift1  ...  \
# 123991        -30.00         -0.030151           NaN  ...
# 123992        -43.50         -0.044961        965.00  ...
# 123993        -16.00         -0.017448        924.00  ...
# 123994         26.50          0.029742        901.00  ...
# 123995         50.00          0.054885        917.50  ...
# 123996        -46.50         -0.047938        961.00  ...
# 123997          9.50          0.010440        923.50  ...
# 123998        -38.00         -0.041260        919.50  ...
# 123999        -73.50         -0.082445        883.00  ...
# 124000        -37.00         -0.045427        818.00  ...
# 124001        -11.50         -0.014781        777.50  ...
# 124002         32.00          0.042638        766.50  ...
# 124003         38.50          0.048125        782.50  ...
# 124004         47.50          0.056920        838.50  ...
# 124005        -35.00         -0.039414        882.00  ...
# 124006         42.50          0.050236        853.00  ...
# 124007        -15.00         -0.016816        888.50  ...
# 124008        -17.00         -0.019296        877.00  ...
# 124009         17.50          0.020231        864.00  ...
# 124010         33.50          0.037810        882.50  ...
# 124011        -66.50         -0.071853        919.50  ...
# 124012         20.00          0.023108        859.00  ...
# 124013        -24.00         -0.027103        885.50  ...
# 124014        -30.50         -0.035527        861.50  ...
# 124015          2.50          0.003027        828.00  ...
# 124016         -1.00         -0.001219        828.50  ...
# 124017        -11.00         -0.013505        819.50  ...
# 124018        -23.50         -0.029066        803.50  ...
# 124019        118.00          0.147408        785.00  ...
# 124020        -28.50         -0.031148        918.50  ...
# 124021         20.00          0.022561        886.50  ...
# 124022         44.50          0.048847        906.50  ...
# 124023        -52.50         -0.054602        955.50  ...
# 124024        -20.00         -0.022002        909.00  ...
# 124025         47.00          0.053868        889.00  ...
# 124026        -24.50         -0.026805        919.50  ...
# 124027        -21.50         -0.023281        889.50  ...
# 124028        -28.00         -0.032000        902.00  ...
# 124029        -83.00         -0.095183        847.00  ...
# 124030        -65.50         -0.083280        789.00  ...
# 124031       -221.50         -0.306787        721.00  ...
# 124032        -69.50         -0.132255        500.50  ...
# 124033         18.75          0.039391        456.00  ...
# 124034         74.00          0.158798        494.75  ...
# 124035        -77.00         -0.138241        540.00  ...
# 124036        -66.25         -0.134860        480.00  ...
# 124037        -49.75         -0.120679        425.00  ...
# 124038         36.25          0.096538        362.50  ...
# 124039        -74.25         -0.179024        411.75  ...
# 124040        -58.50         -0.158537        340.50  ...
#
#         min_move_cum_neg_macd_line  long_prev_max_move_pos_date_macd_line  \
# 123991                           1                                    NaN
# 123992                           2                                    NaN
# 123993                           3                                    NaN
# 123994                           4                                    NaN
# 123995                           5                                    NaN
# 123996                           6                                    NaN
# 123997                           7                                    NaN
# 123998                           8                                    NaN
# 123999                           9                                    NaN
# 124000                          10                                    NaN
# 124001                          11                                    NaN
# 124002                          12                                    NaN
# 124003                          13                                    NaN
# 124004                          14                                    NaN
# 124005                          15                                    NaN
# 124006                          16                                    NaN
# 124007                          17                                    NaN
# 124008                          18                                    NaN
# 124009                          19                                    NaN
# 124010                          20                                    NaN
# 124011                          21                                    NaN
# 124012                          22                                    NaN
# 124013                          23                                    NaN
# 124014                          24                                    NaN
# 124015                          25                                    NaN
# 124016                          26                                    NaN
# 124017                          27                                    NaN
# 124018                          28                                    0.0
# 124019                          29                                    0.0
# 124020                           0                                    0.0
# 124021                           0                                    1.0
# 124022                           0                                    2.0
# 124023                           0                                    3.0
# 124024                           0                                    4.0
# 124025                           0                                    5.0
# 124026                           0                                    6.0
# 124027                           1                                    0.0
# 124028                           0                                    0.0
# 124029                           1                                    0.0
# 124030                           2                                    0.0
# 124031                           3                                    0.0
# 124032                           4                                    0.0
# 124033                           5                                    0.0
# 124034                           6                                    0.0
# 124035                           7                                    0.0
# 124036                           8                                    0.0
# 124037                           9                                    0.0
# 124038                          10                                    0.0
# 124039                          11                                    0.0
# 124040                          12                                    0.0
#
#         long_prev_max_move_neg_date_macd_line  \
# 123991                                    NaN
# 123992                                    NaN
# 123993                                    NaN
# 123994                                    NaN
# 123995                                    NaN
# 123996                                    NaN
# 123997                                    NaN
# 123998                                    NaN
# 123999                                    NaN
# 124000                                    NaN
# 124001                                    NaN
# 124002                                    NaN
# 124003                                    NaN
# 124004                                    NaN
# 124005                                    NaN
# 124006                                    NaN
# 124007                                    NaN
# 124008                                    NaN
# 124009                                    NaN
# 124010                                    NaN
# 124011                                    NaN
# 124012                                    NaN
# 124013                                    NaN
# 124014                                    NaN
# 124015                                    NaN
# 124016                                    NaN
# 124017                                    NaN
# 124018                                    NaN
# 124019                                    NaN
# 124020                                    0.0
# 124021                                    0.0
# 124022                                    0.0
# 124023                                    0.0
# 124024                                    0.0
# 124025                                    0.0
# 124026                                    0.0
# 124027                                    0.0
# 124028                                    0.0
# 124029                                    0.0
# 124030                                    1.0
# 124031                                    2.0
# 124032                                    3.0
# 124033                                    4.0
# 124034                                    5.0
# 124035                                    6.0
# 124036                                    7.0
# 124037                                    8.0
# 124038                                    9.0
# 124039                                   10.0
# 124040                                   11.0
#
#         long_prev_min_move_pos_date_macd_line  \
# 123991                                    NaN
# 123992                                    NaN
# 123993                                    NaN
# 123994                                    NaN
# 123995                                    NaN
# 123996                                    NaN
# 123997                                    NaN
# 123998                                    NaN
# 123999                                    NaN
# 124000                                    NaN
# 124001                                    NaN
# 124002                                    NaN
# 124003                                    NaN
# 124004                                    NaN
# 124005                                    NaN
# 124006                                    NaN
# 124007                                    NaN
# 124008                                    NaN
# 124009                                    NaN
# 124010                                    NaN
# 124011                                    NaN
# 124012                                    NaN
# 124013                                    NaN
# 124014                                    NaN
# 124015                                    NaN
# 124016                                    NaN
# 124017                                    NaN
# 124018                                    0.0
# 124019                                    0.0
# 124020                                    0.0
# 124021                                    1.0
# 124022                                    2.0
# 124023                                    3.0
# 124024                                    4.0
# 124025                                    5.0
# 124026                                    6.0
# 124027                                    0.0
# 124028                                    0.0
# 124029                                    0.0
# 124030                                    0.0
# 124031                                    0.0
# 124032                                    0.0
# 124033                                    0.0
# 124034                                    0.0
# 124035                                    0.0
# 124036                                    0.0
# 124037                                    0.0
# 124038                                    0.0
# 124039                                    0.0
# 124040                                    0.0
#
#         long_prev_min_move_neg_date_macd_line  long_max_grad_pos_macd_line  \
# 123991                                    NaN                     0.000000
# 123992                                    NaN                     0.000000
# 123993                                    NaN                     0.000000
# 123994                                    NaN                     0.000000
# 123995                                    NaN                     0.000000
# 123996                                    NaN                     0.000000
# 123997                                    NaN                     0.000000
# 123998                                    NaN                     0.000000
# 123999                                    NaN                     0.000000
# 124000                                    NaN                     0.000000
# 124001                                    NaN                     0.000000
# 124002                                    NaN                     0.000000
# 124003                                    NaN                     0.000000
# 124004                                    NaN                     0.000000
# 124005                                    NaN                     0.000000
# 124006                                    NaN                     0.000000
# 124007                                    NaN                     0.000000
# 124008                                    NaN                     0.000000
# 124009                                    NaN                     0.000000
# 124010                                    NaN                     0.000000
# 124011                                    NaN                     0.000000
# 124012                                    NaN                     0.000000
# 124013                                    NaN                     0.000000
# 124014                                    NaN                     0.000000
# 124015                                    NaN                     0.000000
# 124016                                    NaN                     0.000000
# 124017                                    NaN                     0.000000
# 124018                                    NaN                     0.000000
# 124019                                    NaN                     0.000000
# 124020                                    0.0                     0.000000
# 124021                                    0.0                     3.846884
# 124022                                    0.0                     4.281395
# 124023                                    0.0                     5.406400
# 124024                                    0.0                     4.618484
# 124025                                    0.0                     3.716972
# 124026                                    0.0                     3.507231
# 124027                                    0.0                     0.000000
# 124028                                    0.0                     0.000000
# 124029                                    0.0                     0.000000
# 124030                                    1.0                     0.000000
# 124031                                    2.0                     0.000000
# 124032                                    3.0                     0.000000
# 124033                                    4.0                     0.000000
# 124034                                    5.0                     0.000000
# 124035                                    6.0                     0.000000
# 124036                                    7.0                     0.000000
# 124037                                    8.0                     0.000000
# 124038                                    9.0                     0.000000
# 124039                                   10.0                     0.000000
# 124040                                   11.0                     0.000000
#
#         long_max_grad_neg_macd_line  long_min_grad_pos_macd_line  \
# 123991                     0.000000                     0.000000
# 123992                     0.000000                     0.000000
# 123993                     0.000000                     0.000000
# 123994                     0.000000                     0.000000
# 123995                     0.000000                     0.000000
# 123996                     0.000000                     0.000000
# 123997                     0.000000                     0.000000
# 123998                     0.000000                     0.000000
# 123999                     0.000000                     0.000000
# 124000                     0.000000                     0.000000
# 124001                     0.000000                     0.000000
# 124002                     0.000000                     0.000000
# 124003                     0.000000                     0.000000
# 124004                     0.000000                     0.000000
# 124005                     0.000000                     0.000000
# 124006                     0.000000                     0.000000
# 124007                     0.000000                     0.000000
# 124008                     0.000000                     0.000000
# 124009                     0.000000                     0.000000
# 124010                     0.000000                     0.000000
# 124011                     0.000000                     0.000000
# 124012                     0.000000                     0.000000
# 124013                     0.000000                     0.000000
# 124014                     0.000000                     0.000000
# 124015                     0.000000                     0.000000
# 124016                     0.000000                     0.000000
# 124017                     0.000000                     0.000000
# 124018                     0.000000                     0.000000
# 124019                     0.000000                     0.000000
# 124020                     0.000000                     0.000000
# 124021                     0.000000                     3.846884
# 124022                     0.000000                     4.281395
# 124023                     0.000000                     5.406400
# 124024                     0.000000                     4.618484
# 124025                     0.000000                     3.716972
# 124026                     0.000000                     3.507231
# 124027                     0.000000                     0.000000
# 124028                     0.000000                     0.000000
# 124029                     0.000000                     0.000000
# 124030                    -7.881973                     0.000000
# 124031                    -9.716901                     0.000000
# 124032                   -15.298158                     0.000000
# 124033                   -17.423607                     0.000000
# 124034                   -16.899505                     0.000000
# 124035                   -15.260764                     0.000000
# 124036                   -14.412304                     0.000000
# 124037                   -13.933614                     0.000000
# 124038                   -13.724171                     0.000000
# 124039                   -12.766277                     0.000000
# 124040                   -12.289200                     0.000000
#
#         long_min_grad_neg_macd_line  signal
# 123991                     0.000000    sell
# 123992                     0.000000    sell
# 123993                     0.000000    hold
# 123994                     0.000000    hold
# 123995                     0.000000    sell
# 123996                     0.000000    sell
# 123997                     0.000000    sell
# 123998                     0.000000    sell
# 123999                     0.000000    hold
# 124000                     0.000000    hold
# 124001                     0.000000     buy
# 124002                     0.000000     buy
# 124003                     0.000000    hold
# 124004                     0.000000    sell
# 124005                     0.000000    hold
# 124006                     0.000000    sell
# 124007                     0.000000    sell
# 124008                     0.000000    hold
# 124009                     0.000000    hold
# 124010                     0.000000    sell
# 124011                     0.000000    hold
# 124012                     0.000000    sell
# 124013                     0.000000    hold
# 124014                     0.000000    hold
# 124015                     0.000000    hold
# 124016                     0.000000    hold
# 124017                     0.000000    hold
# 124018                     0.000000    hold
# 124019                     0.000000    sell
# 124020                     0.000000    hold
# 124021                     0.000000    hold
# 124022                     0.000000    sell
# 124023                     0.000000    sell
# 124024                     0.000000    hold
# 124025                     0.000000    sell
# 124026                     0.000000    hold
# 124027                     0.000000    sell
# 124028                     0.000000    sell
# 124029                     0.000000    sell
# 124030                    -7.881973    sell
# 124031                    -9.716901    sell
# 124032                   -15.298158    hold
# 124033                   -17.423607    hold
# 124034                   -16.899505    sell
# 124035                   -15.260764    sell
# 124036                   -14.412304    sell
# 124037                   -13.933614    hold
# 124038                   -13.724171    sell
# 124039                   -12.766277    sell
# 124040                   -12.289200    hold
#
# [50 rows x 140 columns]

# %%
#close any open h5 files
tables.file._open_files.close_all()
# Out:
# Closing remaining open files:C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_d_TMP.h5...done

# %%
#Delete the old h5 file and rename the TMP
try:
    os.remove(path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY REMOVED {}'.format(path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - REMOVING:{}'.format(e))
try:
    os.rename(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5')
    print('\nSUCCESSFULLY RENAMED {} TO {}'.format(path+r'\all_hist_prices_w_ft_eng2_TMP.h5',path+r'\all_hist_prices_w_ft_eng2.h5'))
except Exception as e:
    print('\nERROR - RENAMING:{}'.format(e))
# Out:
# SUCCESSFULLY REMOVED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5
#
# SUCCESSFULLY RENAMED C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2_TMP.h5 TO C:\Users\Robert\Documents\python_scripts\stock_trading_ml_modelling\historical_prices\all_hist_prices_w_ft_eng2.h5

# %%
#Remove 'date' from out_cols
out_cols.remove('date')

# %%
#Export a list of the features for this model
file_object = open(path+r'\feature_engineering_feature_list.txt','w')
feature_str = ''
for i in out_cols:
    feature_str += '{},'.format(i)
feature_str = feature_str[:-1]
file_object.write(feature_str)
file_object.close()
feature_str
# Out:
# 'ticker,open,close,high,low,volume,change_price,per_change_price,close_shift1,change_close_shift1,vol_shift1,change_vol_shift1,ema26_shift1,change_ema26_shift1,close_13_norm,close_26_norm,close_52_norm,macd_line_13_norm,macd_line_26_norm,macd_line_52_norm,macd_pos_val,macd_neg_val,signal_line_pos_val,signal_line_neg_val,change_price_pos_val,change_price_neg_val,per_change_price_pos_val,per_change_price_neg_val,prev_max_close,prev_min_close,prev_max_close_date_change,prev_min_close_date_change,max_change_close_pos_val,max_change_close_neg_val,min_change_close_pos_val,min_change_close_neg_val,prev_max_grad_close,prev_min_grad_close,max_move_cum_pos_close,max_move_cum_neg_close,min_move_cum_pos_close,min_move_cum_neg_close,long_prev_max_move_pos_date_close,long_prev_max_move_neg_date_close,long_prev_min_move_pos_date_close,long_prev_min_move_neg_date_close,long_max_grad_pos_close,long_max_grad_neg_close,long_min_grad_pos_close,long_min_grad_neg_close,prev_max_macd,prev_min_macd,prev_max_macd_date_change,prev_min_macd_date_change,max_change_macd_pos_val,max_change_macd_neg_val,min_change_macd_pos_val,min_change_macd_neg_val,prev_max_grad_macd,prev_min_grad_macd,max_move_cum_pos_macd,max_move_cum_neg_macd,min_move_cum_pos_macd,min_move_cum_neg_macd,long_prev_max_move_pos_date_macd,long_prev_max_move_neg_date_macd,long_prev_min_move_pos_date_macd,long_prev_min_move_neg_date_macd,long_max_grad_pos_macd,long_max_grad_neg_macd,long_min_grad_pos_macd,long_min_grad_neg_macd,prev_max_ema26,prev_min_ema26,prev_max_ema26_date_change,prev_min_ema26_date_change,max_change_ema26_pos_val,max_change_ema26_neg_val,min_change_ema26_pos_val,min_change_ema26_neg_val,prev_max_grad_ema26,prev_min_grad_ema26,max_move_cum_pos_ema26,max_move_cum_neg_ema26,min_move_cum_pos_ema26,min_move_cum_neg_ema26,long_prev_max_move_pos_date_ema26,long_prev_max_move_neg_date_ema26,long_prev_min_move_pos_date_ema26,long_prev_min_move_neg_date_ema26,long_max_grad_pos_ema26,long_max_grad_neg_ema26,long_min_grad_pos_ema26,long_min_grad_neg_ema26,prev_max_signal_line,prev_min_signal_line,prev_max_signal_line_date_change,prev_min_signal_line_date_change,max_change_signal_line_pos_val,max_change_signal_line_neg_val,min_change_signal_line_pos_val,min_change_signal_line_neg_val,prev_max_grad_signal_line,prev_min_grad_signal_line,max_move_cum_pos_signal_line,max_move_cum_neg_signal_line,min_move_cum_pos_signal_line,min_move_cum_neg_signal_line,long_prev_max_move_pos_date_signal_line,long_prev_max_move_neg_date_signal_line,long_prev_min_move_pos_date_signal_line,long_prev_min_move_neg_date_signal_line,long_max_grad_pos_signal_line,long_max_grad_neg_signal_line,long_min_grad_pos_signal_line,long_min_grad_neg_signal_line,prev_max_macd_line,prev_min_macd_line,prev_max_macd_line_date_change,prev_min_macd_line_date_change,max_change_macd_line_pos_val,max_change_macd_line_neg_val,min_change_macd_line_pos_val,min_change_macd_line_neg_val,prev_max_grad_macd_line,prev_min_grad_macd_line,max_move_cum_pos_macd_line,max_move_cum_neg_macd_line,min_move_cum_pos_macd_line,min_move_cum_neg_macd_line,long_prev_max_move_pos_date_macd_line,long_prev_max_move_neg_date_macd_line,long_prev_min_move_pos_date_macd_line,long_prev_min_move_neg_date_macd_line,long_max_grad_pos_macd_line,long_max_grad_neg_macd_line,long_min_grad_pos_macd_line,long_min_grad_neg_macd_line,signal'
